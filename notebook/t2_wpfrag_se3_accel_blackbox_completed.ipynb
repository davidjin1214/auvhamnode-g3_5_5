# %% [markdown]
# # Black-box current-evidence rerun (clean-only) — `se3_accel_blackbox`
#
# **Goal.** Regenerate a black-box / semi-structured baseline on the current-main
# (`g3_5_7` mirror) regime so the chapter-section-8 "structured >> black-box" claim has a
# clean-mirror anchor directly comparable to the four T2 models. Catalog-era black-box numbers
# come from the 2026-04 `sweep_oc_core_default_*` suite — a different regime that collapsed
# `phnode_full` on 3/6 clean seeds and flipped `phnode_qforce` clean 0.57<->3.76, so they
# cannot be cross-compared with T2.
#
# **Matrix (this notebook).** `se3_accel_blackbox` x {clean} x seeds {42,43,44,45,46} = 5 training
# runs (clean-only via `PHASE1A_PROTOCOLS=clean`), then the clean suite is evaluated across
# {clean, nominal_eval, degraded_eval, heading_biased_eval} under iid_noisy_ic + v4_lite eval
# protocols — identical to the eval the T2 clean suites received.
#
# **Parallelism.** Run the three black-box notebooks (`blackbox_fullstate`,
# `se3_momentum_blackbox`, `se3_accel_blackbox`) in separate Colab sessions. Distinct
# `RUN_TAG`s, no collision.
#
# **After all three finish:** sync `checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_*`
# back, then locally rerun `scripts/export_section8_t2_evidence.py` — the black-box models are
# already in its MODELS list, so the clean rows append to `aggregate.csv` automatically.
#
# > Watch list: black-box models are collapse-prone (`blackbox_fullstate` was nan/86.8m in the
# > old catalog). The anomaly-scan cell flags any clean-mirror collapse; a real collapse is a
# > legitimate instability finding (handle per B1: exclude from aggregate, annotate).

# %%
# !nvidia-smi
# Out:
# Mon May 25 11:45:08 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   30C    P8             18W /   72W |       0MiB /  23034MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import torch
print(f"PyTorch: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"CUDA: {torch.version.cuda}")
print(f"cuDNN: {torch.backends.cudnn.version()}")
# Out:
# PyTorch: 2.10.0+cu128
# CUDA available: True
# CUDA: 12.8
# cuDNN: 91002

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
from pathlib import Path

PROJECT_DIR = Path(os.environ.get(
    "AUV_PROJECT_DIR",
    "/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7",
))
assert PROJECT_DIR.exists(), f"Project directory not found: {PROJECT_DIR}"
# %cd $PROJECT_DIR
# Out:
# /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7

# %%
# %pip install -q torchdiffeq pandas

# %% [markdown]
# ## 0. Configuration

# %%
import os

# Runtime
os.environ["PYTHON_BIN"] = "python"
os.environ["DEVICE"] = "cuda"
os.environ["LOCAL_PROXY_ROOT"] = "/content/_proxy_suites"

# ---- identity (one black-box model per notebook) ----
os.environ["RUN_TAG"] = "t2_wpfrag_se3_accel_blackbox"
os.environ["DATASET"] = "data/auv_oc_traj1000_blk150_s23_d0be9434.pkl"
os.environ["NOISE_REFERENCE"] = "remus100_dr"
os.environ["PHASE1A_LOG_DIR"] = str(PROJECT_DIR / "checkpoints" / "phase1a_logs" / os.environ["RUN_TAG"])
os.environ["PHASE1A_METADATA_DIR"] = str(PROJECT_DIR / "checkpoints" / f"phase1a_metadata_{os.environ['RUN_TAG']}")

# ---- matrix: single black-box model x CLEAN-ONLY x 5 seeds ----
os.environ["PHASE1A_MODELS"] = "se3_accel_blackbox"
os.environ["SMOKE1_MODELS"] = "se3_accel_blackbox"
os.environ["PHASE1A_PROTOCOLS"] = "clean"        # clean-only knob (driver default is "clean iid v4lite")
os.environ["SMOKE_SEEDS"] = "42"                 # cheap protocol-correctness gate (1 seed)
os.environ["DECISION_SEEDS"] = "42 43 44 45 46"  # full current-evidence seed set (matches T2)

# ---- Evaluation contract (identical to T2 clean suite) ----
os.environ["SMOKE_EVAL_NUM_TRAJ_PER_SCENARIO"] = "6"
os.environ["DECISION_EVAL_NUM_TRAJ_PER_SCENARIO"] = "30"
os.environ["EVAL_TIMES"] = "10 30 60"
os.environ["EVAL_SCENARIOS"] = "PRBS CHIRP OU"
os.environ["EVAL_BASE_SEED"] = "42"
os.environ["EVAL_NOISE_SEED"] = "2024"
os.environ["EVAL_PROGRESS_EVERY"] = "5"
os.environ["EVAL_NUM_DIAGNOSTIC_PLOTS"] = "6"
# Full robustness set: evaluate the clean-trained suite across all 4 profiles (caveat B).
os.environ["IID_EVAL_PROFILES"] = "clean nominal_eval degraded_eval heading_biased_eval"
os.environ["V4_EVAL_PROFILES"] = "nominal_eval"

# ---- Audit gate ----
os.environ["STRICT_ZERO_NOISE_AUDIT"] = "1"
os.environ["SOFT_MIN_EPOCH_SCALE"] = "0.05"

print("RUN_TAG          =", os.environ["RUN_TAG"])
print("PHASE1A_MODELS   =", os.environ["PHASE1A_MODELS"])
print("PHASE1A_PROTOCOLS=", os.environ["PHASE1A_PROTOCOLS"])
print("DECISION_SEEDS   =", os.environ["DECISION_SEEDS"])
print("IID_EVAL_PROFILES=", os.environ["IID_EVAL_PROFILES"])
# Out:
# RUN_TAG          = t2_wpfrag_se3_accel_blackbox
# PHASE1A_MODELS   = se3_accel_blackbox
# PHASE1A_PROTOCOLS= clean
# DECISION_SEEDS   = 42 43 44 45 46
# IID_EVAL_PROFILES= clean nominal_eval degraded_eval heading_biased_eval

# %% [markdown]
# ## 1. Preflight
# Confirms target suite/proxy dirs are absent and saves suite-level run config + environment metadata. If it fails, change `RUN_TAG` or remove the target dirs.

# %%
os.environ["MODE"] = "preflight"
# !bash scripts/run_phase1a_oc_v4lite.sh
# Out:
# [phase1a]
# MODE=preflight
# RUN_TAG=t2_wpfrag_se3_accel_blackbox
# DATASET=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# DEVICE=cuda
# PHASE1A_MODELS=se3_accel_blackbox
# PHASE1A_PROTOCOLS=clean
# SMOKE1_MODELS=se3_accel_blackbox
# SMOKE_SEEDS=42
# DECISION_SEEDS=42 43 44 45 46
# NOISE_REFERENCE=remus100_dr
# PHASE1A_LOG_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_logs/t2_wpfrag_se3_accel_blackbox
# PHASE1A_METADATA_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_metadata_t2_wpfrag_se3_accel_blackbox
# Preflight passed: all Phase-1A target suite/proxy directories are absent.
# [metadata] /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_metadata_t2_wpfrag_se3_accel_blackbox

# %% [markdown]
# ## 2. Smoke gate (seed 42, clean only)
# Cheap protocol-correctness check for the clean path + strict zero-noise audit. Smoke results are flow-validation only — never cited.

# %%
os.environ["MODE"] = "smoke1_train"
# !bash scripts/run_phase1a_oc_v4lite.sh
# Out:
# [phase1a]
# MODE=smoke1_train
# RUN_TAG=t2_wpfrag_se3_accel_blackbox
# DATASET=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# DEVICE=cuda
# PHASE1A_MODELS=se3_accel_blackbox
# PHASE1A_PROTOCOLS=clean
# SMOKE1_MODELS=se3_accel_blackbox
# SMOKE_SEEDS=42
# DECISION_SEEDS=42 43 44 45 46
# NOISE_REFERENCE=remus100_dr
# PHASE1A_LOG_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_logs/t2_wpfrag_se3_accel_blackbox
# PHASE1A_METADATA_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_metadata_t2_wpfrag_se3_accel_blackbox
# [train] suite=sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox models=se3_accel_blackbox seeds=42 protocol=auto
# Training all models with profile-based noisy IC.
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Group: all
# Explicit models: se3_accel_blackbox
# Seeds: 42
# Noise config: protocol=auto, profile=clean, scale=1.0, warmup=20, ramp=80, mix_ratio=0.5
# Auto-eval profiles: block=[clean nominal_eval heading_biased_eval] heldout=[clean nominal_eval degraded_eval heading_biased_eval]
# Suite directory: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Models (1): se3_accel_blackbox
# Seeds: 42
# [train] baseline_se3_accel_blackbox_seed42
# Loading dataset...
# Loaded: 83850 train, 21000 test, t_eval=[0.   0.05 0.1  0.15 0.2 ]
# Dataset split: trajectory | train trajectories: 559 | test trajectories: 140
# Dataset ID: d0be9434
# Dataset path: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl | velocity convention: body_total | state dim: 27
# Position std: [0.1508, 0.1400, 0.0370]
# Velocity std: u=0.4722, v=0.0898, w=0.0718, p=0.0248, q=0.0906, r=0.0526
# Actuator std: a0=0.1543, a1=0.1555, a2=299.0037
# Training noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# Model: SE(3) Acceleration Black-Box [baseline/core] | canonical type: se3_accel_blackbox
# Model parameters: 63,129
# Training dataset: id=d0be9434 | path=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Mass matrix initialized from physics
# Training: epochs<=300, target_steps=5000, warmup_steps=400, lr=6.00e-03 -> 1.00e-04, solver=rk4, so3_reg=1.00e-03
# Train samples: 83850, Test samples: 21000
# Epoch    1 | Step    20/ 5000 | Train 4.4822e-01 | Test 4.2767e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 4.10e-04 | 5.6s
# Epoch    2 | Step    40/ 5000 | Train 4.2415e-01 | Test 3.7117e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 7.05e-04 | 3.7s
# Epoch    3 | Step    60/ 5000 | Train 3.5819e-01 | Test 3.2556e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 1.00e-03 | 3.8s
# Epoch    4 | Step    80/ 5000 | Train 3.3472e-01 | Test 3.8365e-01 | SO3(train/test) 1.13e-07/1.14e-07 | Fail(train/test) 0/0 | LR 1.29e-03 | 3.8s
# Epoch    5 | Step   100/ 5000 | Train 3.2082e-01 | Test 2.7574e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 1.59e-03 | 3.7s
# Epoch    6 | Step   120/ 5000 | Train 2.5783e-01 | Test 2.2832e-01 | SO3(train/test) 1.13e-07/1.14e-07 | Fail(train/test) 0/0 | LR 1.88e-03 | 3.7s
# Epoch    7 | Step   140/ 5000 | Train 2.2753e-01 | Test 1.9989e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 2.18e-03 | 3.7s
# Epoch    8 | Step   160/ 5000 | Train 2.1388e-01 | Test 1.8720e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 2.47e-03 | 3.9s
# Epoch    9 | Step   180/ 5000 | Train 2.0928e-01 | Test 1.9059e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 2.77e-03 | 3.7s
# Epoch   10 | Step   200/ 5000 | Train 2.1027e-01 | Test 1.9814e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 3.06e-03 | 3.7s
# Epoch   11 | Step   220/ 5000 | Train 2.1015e-01 | Test 2.0700e-01 | SO3(train/test) 1.13e-07/1.14e-07 | Fail(train/test) 0/0 | LR 3.36e-03 | 3.8s
# Epoch   12 | Step   240/ 5000 | Train 2.1015e-01 | Test 2.1373e-01 | SO3(train/test) 1.14e-07/1.13e-07 | Fail(train/test) 0/0 | LR 3.65e-03 | 3.7s
# Epoch   13 | Step   260/ 5000 | Train 2.0965e-01 | Test 2.1604e-01 | SO3(train/test) 1.13e-07/1.14e-07 | Fail(train/test) 0/0 | LR 3.95e-03 | 3.7s
# Epoch   14 | Step   280/ 5000 | Train 2.0862e-01 | Test 2.2724e-01 | SO3(train/test) 1.14e-07/1.13e-07 | Fail(train/test) 0/0 | LR 4.24e-03 | 3.8s
# Epoch   15 | Step   300/ 5000 | Train 2.0920e-01 | Test 2.3518e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 4.54e-03 | 3.7s
# Epoch   16 | Step   320/ 5000 | Train 2.0893e-01 | Test 2.5067e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 4.83e-03 | 3.7s
# Epoch   17 | Step   340/ 5000 | Train 2.0806e-01 | Test 2.3397e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.13e-03 | 3.8s
# Epoch   18 | Step   360/ 5000 | Train 2.0301e-01 | Test 2.1893e-01 | SO3(train/test) 1.14e-07/1.13e-07 | Fail(train/test) 0/0 | LR 5.42e-03 | 3.9s
# Epoch   19 | Step   380/ 5000 | Train 1.9307e-01 | Test 1.7484e-01 | SO3(train/test) 1.14e-07/1.13e-07 | Fail(train/test) 0/0 | LR 5.72e-03 | 3.8s
# Epoch   20 | Step   400/ 5000 | Train 1.8182e-01 | Test 1.7546e-01 | SO3(train/test) 1.14e-07/1.13e-07 | Fail(train/test) 0/0 | LR 6.00e-03 | 3.7s
# Epoch   21 | Step   420/ 5000 | Train 1.7314e-01 | Test 1.6408e-01 | SO3(train/test) 1.14e-07/1.13e-07 | Fail(train/test) 0/0 | LR 6.00e-03 | 3.8s
# Epoch   22 | Step   440/ 5000 | Train 1.6668e-01 | Test 1.5641e-01 | SO3(train/test) 1.14e-07/1.13e-07 | Fail(train/test) 0/0 | LR 6.00e-03 | 3.7s
# Epoch   23 | Step   460/ 5000 | Train 1.5907e-01 | Test 1.5639e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 6.00e-03 | 3.7s
# Epoch   24 | Step   480/ 5000 | Train 1.5516e-01 | Test 1.5438e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 6.00e-03 | 3.8s
# Epoch   25 | Step   500/ 5000 | Train 1.5097e-01 | Test 1.5018e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.99e-03 | 3.7s
# Epoch   26 | Step   520/ 5000 | Train 1.4650e-01 | Test 1.4337e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.99e-03 | 3.7s
# Epoch   27 | Step   540/ 5000 | Train 1.4220e-01 | Test 1.3931e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.99e-03 | 3.7s
# Epoch   28 | Step   560/ 5000 | Train 1.3956e-01 | Test 1.3913e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.98e-03 | 3.7s
# Epoch   29 | Step   580/ 5000 | Train 1.3936e-01 | Test 1.4367e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.98e-03 | 3.8s
# Epoch   30 | Step   600/ 5000 | Train 1.3702e-01 | Test 1.2292e-01 | SO3(train/test) 1.14e-07/1.13e-07 | Fail(train/test) 0/0 | LR 5.97e-03 | 3.6s
# Epoch   31 | Step   620/ 5000 | Train 1.3749e-01 | Test 1.3478e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.97e-03 | 3.7s
# Epoch   32 | Step   640/ 5000 | Train 1.3385e-01 | Test 1.2039e-01 | SO3(train/test) 1.14e-07/1.13e-07 | Fail(train/test) 0/0 | LR 5.96e-03 | 3.7s
# Epoch   33 | Step   660/ 5000 | Train 1.2933e-01 | Test 1.1178e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.95e-03 | 3.7s
# Epoch   34 | Step   680/ 5000 | Train 1.2556e-01 | Test 1.2256e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.95e-03 | 3.7s
# Epoch   35 | Step   700/ 5000 | Train 1.2371e-01 | Test 1.1998e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.94e-03 | 3.7s
# Epoch   36 | Step   720/ 5000 | Train 1.2384e-01 | Test 1.1065e-01 | SO3(train/test) 1.14e-07/1.13e-07 | Fail(train/test) 0/0 | LR 5.93e-03 | 3.7s
# Epoch   37 | Step   740/ 5000 | Train 1.2345e-01 | Test 1.3800e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.92e-03 | 3.7s
# Epoch   38 | Step   760/ 5000 | Train 1.3104e-01 | Test 1.4006e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.91e-03 | 3.7s
# Epoch   39 | Step   780/ 5000 | Train 1.3060e-01 | Test 1.1565e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.90e-03 | 3.8s
# Epoch   40 | Step   800/ 5000 | Train 1.2287e-01 | Test 1.1106e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.89e-03 | 3.7s
# Epoch   41 | Step   820/ 5000 | Train 1.1880e-01 | Test 1.2688e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.88e-03 | 3.8s
# Epoch   42 | Step   840/ 5000 | Train 1.2050e-01 | Test 1.0950e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.87e-03 | 3.7s
# Epoch   43 | Step   860/ 5000 | Train 1.1975e-01 | Test 1.2015e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.86e-03 | 3.7s
# Epoch   44 | Step   880/ 5000 | Train 1.1626e-01 | Test 1.0985e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.84e-03 | 3.7s
# Epoch   45 | Step   900/ 5000 | Train 1.1291e-01 | Test 1.1163e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.83e-03 | 3.8s
# Epoch   46 | Step   920/ 5000 | Train 1.1230e-01 | Test 1.0897e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.82e-03 | 3.7s
# Epoch   47 | Step   940/ 5000 | Train 1.1269e-01 | Test 1.0916e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.80e-03 | 3.7s
# Epoch   48 | Step   960/ 5000 | Train 1.1097e-01 | Test 1.0789e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.79e-03 | 3.7s
# Epoch   49 | Step   980/ 5000 | Train 1.0890e-01 | Test 1.0753e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.77e-03 | 3.6s
# Epoch   50 | Step  1000/ 5000 | Train 1.0806e-01 | Test 1.0299e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.76e-03 | 3.8s
# Epoch   51 | Step  1020/ 5000 | Train 1.0803e-01 | Test 1.0436e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.74e-03 | 3.8s
# Epoch   52 | Step  1040/ 5000 | Train 1.0727e-01 | Test 1.0388e-01 | SO3(train/test) 1.14e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.72e-03 | 3.7s
# Epoch   53 | Step  1060/ 5000 | Train 1.0737e-01 | Test 1.0404e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.71e-03 | 3.7s
# Epoch   54 | Step  1080/ 5000 | Train 1.0812e-01 | Test 1.0765e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.69e-03 | 3.7s
# Epoch   55 | Step  1100/ 5000 | Train 1.0842e-01 | Test 1.0644e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.67e-03 | 3.7s
# Epoch   56 | Step  1120/ 5000 | Train 1.0991e-01 | Test 1.1495e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.65e-03 | 3.7s
# Epoch   57 | Step  1140/ 5000 | Train 1.1356e-01 | Test 1.0992e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.63e-03 | 3.7s
# Epoch   58 | Step  1160/ 5000 | Train 1.0945e-01 | Test 1.0900e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.61e-03 | 3.8s
# Epoch   59 | Step  1180/ 5000 | Train 1.1003e-01 | Test 9.9886e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.59e-03 | 3.7s
# Epoch   60 | Step  1200/ 5000 | Train 1.1566e-01 | Test 1.1703e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.57e-03 | 3.8s
# Epoch   61 | Step  1220/ 5000 | Train 1.0925e-01 | Test 9.9953e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.55e-03 | 3.7s
# Epoch   62 | Step  1240/ 5000 | Train 1.0510e-01 | Test 1.0496e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.53e-03 | 3.7s
# Epoch   63 | Step  1260/ 5000 | Train 1.0398e-01 | Test 1.0346e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.51e-03 | 3.7s
# Epoch   64 | Step  1280/ 5000 | Train 1.0261e-01 | Test 1.0339e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.48e-03 | 3.7s
# Epoch   65 | Step  1300/ 5000 | Train 1.0270e-01 | Test 1.0426e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.46e-03 | 3.7s
# Epoch   66 | Step  1320/ 5000 | Train 1.0306e-01 | Test 1.0241e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.44e-03 | 3.8s
# Epoch   67 | Step  1340/ 5000 | Train 1.0171e-01 | Test 1.0181e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.41e-03 | 3.7s
# Epoch   68 | Step  1360/ 5000 | Train 1.0098e-01 | Test 9.9344e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.39e-03 | 3.7s
# Epoch   69 | Step  1380/ 5000 | Train 1.0099e-01 | Test 1.0046e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.36e-03 | 3.7s
# Epoch   70 | Step  1400/ 5000 | Train 1.0103e-01 | Test 1.0089e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.34e-03 | 3.7s
# Epoch   71 | Step  1420/ 5000 | Train 1.0018e-01 | Test 1.0037e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.31e-03 |
-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 2.20e-04 | 3.7s
# Epoch  230 | Step  4600/ 5000 | Train 8.9978e-02 | Test 9.6029e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 2.09e-04 | 3.7s
# Epoch  231 | Step  4620/ 5000 | Train 8.9840e-02 | Test 9.6179e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 1.98e-04 | 3.7s
# Epoch  232 | Step  4640/ 5000 | Train 8.9634e-02 | Test 9.6840e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 1.88e-04 | 3.7s
# Epoch  233 | Step  4660/ 5000 | Train 8.9536e-02 | Test 9.6859e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 1.79e-04 | 3.7s
# Epoch  234 | Step  4680/ 5000 | Train 8.9501e-02 | Test 9.6142e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 1.70e-04 | 3.8s
# Epoch  235 | Step  4700/ 5000 | Train 8.9442e-02 | Test 9.5850e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 1.61e-04 | 3.7s
# Epoch  236 | Step  4720/ 5000 | Train 8.9092e-02 | Test 9.5156e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 1.53e-04 | 3.8s
# Epoch  237 | Step  4740/ 5000 | Train 8.9162e-02 | Test 9.5414e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 1.46e-04 | 3.7s
# Epoch  238 | Step  4760/ 5000 | Train 8.8887e-02 | Test 9.5709e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 1.39e-04 | 3.7s
# Epoch  239 | Step  4780/ 5000 | Train 8.8688e-02 | Test 9.5100e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 1.33e-04 | 3.8s
# Epoch  240 | Step  4800/ 5000 | Train 8.8573e-02 | Test 9.6542e-02 | SO3(train/test) 1.14e-07/1.13e-07 | Fail(train/test) 0/0 | LR 1.27e-04 | 3.7s
# Epoch  241 | Step  4820/ 5000 | Train 8.8440e-02 | Test 9.5987e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 1.22e-04 | 3.7s
# Epoch  242 | Step  4840/ 5000 | Train 8.8181e-02 | Test 9.4543e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 1.17e-04 | 3.7s
# Epoch  243 | Step  4860/ 5000 | Train 8.8160e-02 | Test 9.4843e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 1.13e-04 | 3.7s
# Epoch  244 | Step  4880/ 5000 | Train 8.7918e-02 | Test 9.4502e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 1.10e-04 | 3.7s
# Epoch  245 | Step  4900/ 5000 | Train 8.7787e-02 | Test 9.4825e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 1.07e-04 | 3.7s
# Epoch  246 | Step  4920/ 5000 | Train 8.7743e-02 | Test 9.4723e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 1.04e-04 | 3.8s
# Epoch  247 | Step  4940/ 5000 | Train 8.7488e-02 | Test 9.4236e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 1.02e-04 | 3.7s
# Epoch  248 | Step  4960/ 5000 | Train 8.7242e-02 | Test 9.3866e-02 | SO3(train/test) 1.14e-07/1.13e-07 | Fail(train/test) 0/0 | LR 1.01e-04 | 3.7s
# Epoch  249 | Step  4980/ 5000 | Train 8.7015e-02 | Test 9.3985e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 1.00e-04 | 3.8s
# Epoch  250 | Step  5000/ 5000 | Train 8.6747e-02 | Test 9.3858e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 1.00e-04 | 3.7s
# Reached target optimizer steps: 5000/5000
# Done. Best validation score: failure_rate=0.0000, test_loss=9.3858e-02 (epoch 250)
# Running detailed evaluation...
# Block evaluation profile: clean
# Block evaluation noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0003 +/- 0.0002  (max 0.0012)
# Rotation geo [rad]:  0.0011 +/- 0.0006  (max 0.0028)
# Lin vel RMSE [m/s]:  0.0038 +/- 0.0021
# Ang vel RMSE [r/s]:  0.0091 +/- 0.0054
# Components:  u=0.0038  v=0.0028  w=0.0032  p=0.0055  q=0.0110  r=0.0069
# SO(3) violation:  |det-1|=5.76e-08  ||RR^T-I||=1.18e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# Block evaluation profile: nominal_eval
# Block evaluation noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0013 +/- 0.0008  (max 0.0055)
# Rotation geo [rad]:  0.0083 +/- 0.0058  (max 0.0369)
# Lin vel RMSE [m/s]:  0.0059 +/- 0.0025
# Ang vel RMSE [r/s]:  0.0096 +/- 0.0054
# Components:  u=0.0066  v=0.0044  w=0.0048  p=0.0069  q=0.0111  r=0.0071
# SO(3) violation:  |det-1|=2.77e-07  ||RR^T-I||=6.08e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# Block evaluation profile: heading_biased_eval
# Block evaluation noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0049 +/- 0.0017  (max 0.0109)
# Rotation geo [rad]:  0.0351 +/- 0.0096  (max 0.0656)
# Lin vel RMSE [m/s]:  0.0090 +/- 0.0037
# Ang vel RMSE [r/s]:  0.0096 +/- 0.0054
# Components:  u=0.0086  v=0.0098  w=0.0051  p=0.0069  q=0.0111  r=0.0071
# SO(3) violation:  |det-1|=2.99e-07  ||RR^T-I||=6.34e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Block Evaluation Relative To Clean
# ==================================================
# [nominal_eval]
# position_rmse: ratio=4.969  degradation=+396.9%
# rotation_geodesic: ratio=7.357  degradation=+635.7%
# velocity_rmse: ratio=1.547  degradation=+54.7%
# angular_rmse: ratio=1.063  degradation=+6.3%
# failure_rate: ratio=1.000  degradation=+0.0%
# [heading_biased_eval]
# position_rmse: ratio=18.561  degradation=+1756.1%
# rotation_geodesic: ratio=31.014  degradation=+3001.4%
# velocity_rmse: ratio=2.340  degradation=+134.0%
# angular_rmse: ratio=1.063  degradation=+6.3%
# failure_rate: ratio=1.000  degradation=+0.0%
# Running held-out trajectory evaluation...
# Held-out evaluation profile: clean
# Held-out evaluation noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0002 (median 0.0002, p95 0.0003)
# Rotation geo [rad]:  0.0009 (median 0.0009, p95 0.0013)
# Lin vel RMSE [m/s]:  0.0030  Ang vel RMSE [r/s]:  0.0067
# SO(3) violation:  |det-1|=5.87e-08  ||RR^T-I||=1.14e-07
# Noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# [CHIRP] pos=0.0001 m, rot=0.0006 rad, success=1.0000
# [OU] pos=0.0003 m, rot=0.0010 rad, success=1.0000
# [PRBS] pos=0.0002 m, rot=0.0010 rad, success=1.0000
# Held-out evaluation profile: nominal_eval
# Held-out evaluation noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0011 (median 0.0011, p95 0.0014)
# Rotation geo [rad]:  0.0087 (median 0.0086, p95 0.0096)
# Lin vel RMSE [m/s]:  0.0052  Ang vel RMSE [r/s]:  0.0075
# SO(3) violation:  |det-1|=2.94e-07  ||RR^T-I||=6.27e-07
# Noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# [CHIRP] pos=0.0011 m, rot=0.0086 rad, success=1.0000
# [OU] pos=0.0011 m, rot=0.0088 rad, success=1.0000
# [PRBS] pos=0.0012 m, rot=0.0086 rad, success=1.0000
# Held-out evaluation profile: degraded_eval
# Held-out evaluation noise budget: protocol=iid_noisy_ic | profile=degraded_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0026 (median 0.0026, p95 0.0033)
# Rotation geo [rad]:  0.0210 (median 0.0209, p95 0.0234)
# Lin vel RMSE [m/s]:  0.0090  Ang vel RMSE [r/s]:  0.0090
# SO(3) violation:  |det-1|=2.96e-07  ||RR^T-I||=6.28e-07
# Noise budget: protocol=iid_noisy_ic | profile=degraded_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250]
# [CHIRP] pos=0.0025 m, rot=0.0209 rad, success=1.0000
# [OU] pos=0.0026 m, rot=0.0212 rad, success=1.0000
# [PRBS] pos=0.0027 m, rot=0.0209 rad, success=1.0000
# Held-out evaluation profile: heading_biased_eval
# Held-out evaluation noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0040 (median 0.0040, p95 0.0052)
# Rotation geo [rad]:  0.0351 (median 0.0351, p95 0.0363)
# Lin vel RMSE [m/s]:  0.0075  Ang vel RMSE [r/s]:  0.0075
# SO(3) violation:  |det-1|=2.90e-07  ||RR^T-I||=6.21e-07
# Noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# [CHIRP] pos=0.0039 m, rot=0.0353 rad, success=1.0000
# [OU] pos=0.0039 m, rot=0.0349 rad, success=1.0000
# [PRBS] pos=0.0041 m, rot=0.0351 rad, success=1.0000
# ==================================================
# Held-Out Evaluation Relative To Clean
# ==================================================
# [nominal_eval]
# position_rmse: ratio=5.027  degradation=+402.7%
# rotation_geodesic: ratio=9.424  degradation=+842.4%
# velocity_rmse: ratio=1.744  degradation=+74.4%
# angular_rmse: ratio=1.106  degradation=+10.6%
# success_rate: ratio=1.000  degradation=+0.0%
# trajectory_failure_rate: ratio=1.000  degradation=+0.0%
# [degraded_eval]
# position_rmse: ratio=11.607  degradation=+1060.7%
# rotation_geodesic: ratio=22.824  degradation=+2182.4%
# velocity_rmse: ratio=3.030  degradation=+203.0%
# angular_rmse: ratio=1.339  degradation=+33.9%
# success_rate: ratio=1.000  degradation=+0.0%
# trajectory_failure_rate: ratio=1.000  degradation=+0.0%
# [heading_biased_eval]
# position_rmse: ratio=17.831  degradation=+1683.1%
# rotation_geodesic: ratio=38.089  degradation=+3708.9%
# velocity_rmse: ratio=2.523  degradation=+152.3%
# angular_rmse: ratio=1.106  degradation=+10.6%
# success_rate: ratio=1.000  degradation=+0.0%
# trajectory_failure_rate: ratio=1.000  degradation=+0.0%
#
# Training finished. Results: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42
# Training sweep complete.
# Manifest: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox/runs.tsv
# Next step:
#   scripts/batch_eval_models.sh --suite-dir "/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox"
#
# Training complete.
# Suite directory: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox
# Next step:
#   bash scripts/eval_all_models_noise_profile.sh --suite-dir "/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox"
# [audit] /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox
#                                                 suite_name    group         model_type  seed train_noise_protocol  best_epoch  best_loss  noise_warmup_epochs  noise_ramp_epochs  noise_mix_ratio  epoch_scale_at_best  is_effectively_clean_at_best
# sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox baseline se3_accel_blackbox    42                clean         250   0.093858                   20                 80              0.5                  0.0                          True
# [validate_v4] skipped: v4lite not in PHASE1A_PROTOCOLS=clean

# %%
os.environ["MODE"] = "smoke1_eval"
# !bash scripts/run_phase1a_oc_v4lite.sh
# Out:
# [phase1a]
# MODE=smoke1_eval
# RUN_TAG=t2_wpfrag_se3_accel_blackbox
# DATASET=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# DEVICE=cuda
# PHASE1A_MODELS=se3_accel_blackbox
# PHASE1A_PROTOCOLS=clean
# SMOKE1_MODELS=se3_accel_blackbox
# SMOKE_SEEDS=42
# DECISION_SEEDS=42 43 44 45 46
# NOISE_REFERENCE=remus100_dr
# PHASE1A_LOG_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_logs/t2_wpfrag_se3_accel_blackbox
# PHASE1A_METADATA_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_metadata_t2_wpfrag_se3_accel_blackbox
# [eval] suite=sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox eval_protocol=iid_noisy_ic profiles=clean nominal_eval degraded_eval heading_biased_eval
# Suite directory: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox
# Manifest: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox/runs.tsv
# Mode: resampled
# [eval] baseline_se3_accel_blackbox_seed42
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=clean | noise_protocol=clean | noise_budget=protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000] | scenarios=PRBS,CHIRP,OU | trajectories=18 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_120258/clean
# [scenario 1/3] PRBS | 6 trajectories
# [1/18] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=13m10.4s
# [5/18] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=2m00.9s
# [6/18] PRBS seed=47 done | reason=completed | sim_time=60.00s | eta=1m33.0s
# [scenario done] PRBS | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=7.8687 m | pos_p95=21.6424 m | rot_med=0.2143 rad | completion=1.000 | elapsed=46.5s
# [scenario 2/3] CHIRP | 6 trajectories
# [7/18] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=2m25.1s
# [11/18] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=58.8s
# [12/18] CHIRP seed=100047 done | reason=completed | sim_time=60.00s | eta=46.2s
# [scenario done] CHIRP | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=1.2128 m | pos_p95=5.5939 m | rot_med=0.0712 rad | completion=1.000 | elapsed=1m32.4s
# [scenario 3/3] OU | 6 trajectories
# [13/18] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=53.3s
# [17/18] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=8.2s
# [18/18] OU seed=200047 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=15.1464 m | pos_p95=17.8118 m | rot_med=0.5847 rad | completion=1.000 | elapsed=2m18.6s
# Benchmark finished in 2m32.1s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_120258/clean
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: SE(3) Acceleration Black-Box [baseline/core]
# Canonical model type: se3_accel_blackbox
# Energy semantics: not_comparable
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 6
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.6274 m | pos p95=1.6191 m | rot median=0.0560 rad | total vel median=0.0577 m/s | rel vel median=0.0565 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=2.1294 m | pos p95=6.0547 m | rot median=0.0648 rad | total vel median=0.0568 m/s | rel vel median=0.0501 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=7.8625 m | pos p95=19.4408 m | rot median=0.1961 rad | total vel median=0.0973 m/s | rel vel median=0.0481 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=18 | completed=18 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.4981 m | pos p95=1.1997 m | rot median=0.0618 rad | total vel median=0.0663 m/s | rel vel median=0.0565 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.8240 m | pos p95=8.2437 m | rot median=0.0907 rad | total vel median=0.0600 m/s | rel vel median=0.0599 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=7.8687 m | pos p95=21.6424 m | rot median=0.2143 rad | total vel median=0.1210 m/s | rel vel median=0.0481 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.3949 m | pos p95=0.6031 m | rot median=0.0524 rad | total vel median=0.0424 m/s | rel vel median=0.0336 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.6718 m | pos p95=2.3922 m | rot median=0.0321 rad | total vel median=0.0431 m/s | rel vel median=0.0382 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.2128 m | pos p95=5.5939 m | rot median=0.0712 rad | total vel median=0.0472 m/s | rel vel median=0.0382 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=1.0541 m | pos p95=1.6842 m | rot median=0.1764 rad | total vel median=0.0598 m/s | rel vel median=0.0698 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=3.6007 m | pos p95=5.3542 m | rot median=0.2568 rad | total vel median=0.0875 m/s | rel vel median=0.0649 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=15.1464 m | pos p95=17.8118 m | rot median=0.5847 rad | total vel median=0.1675 m/s | rel vel median=0.1564 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Largest completed terminal errors
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=25.9845 m | rot=0.2242 rad | total_vel_violation=0
#   OU seed=200044 | reason=completed | sim_time=60.00s | pos=18.2861 m | rot=0.5755 rad | total_vel_violation=0
#   OU seed=200045 | reason=completed | sim_time=60.00s | pos=16.3891 m | rot=0.5939 rad | total_vel_violation=0
#   OU seed=200042 | reason=completed | sim_time=60.00s | pos=15.8794 m | rot=0.1879 rad | total_vel_violation=0
#   OU seed=200043 | reason=completed | sim_time=60.00s | pos=14.4134 m | rot=0.7809 rad | total_vel_violation=0
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# PRBS seed=42 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_120258/clean/diagnostic_plots/high_terminal_error_PRBS_seed42.png
# OU seed=200044 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_120258/clean/diagnostic_plots/high_terminal_error_OU_seed200044.png
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=nominal_eval | noise_protocol=iid_noisy_ic | noise_budget=protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | scenarios=PRBS,CHIRP,OU | trajectories=18 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_120258/nominal_eval
# [scenario 1/3] PRBS | 6 trajectories
# [1/18] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=1m34.6s
# [5/18] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=14.5s
# [6/18] PRBS seed=47 done | reason=completed | sim_time=60.00s | eta=11.2s
# [scenario done] PRBS | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=8.9417 m | pos_p95=23.7762 m | rot_med=0.2257 rad | completion=1.000 | elapsed=5.6s
# [scenario 2/3] CHIRP | 6 trajectories
# [7/18] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=17.2s
# [11/18] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=7.0s
# [12/18] CHIRP seed=100047 done | reason=completed | sim_time=60.00s | eta=5.5s
# [scenario done] CHIRP | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=1.3073 m | pos_p95=5.9670 m | rot_med=0.0705 rad | completion=1.000 | elapsed=11.0s
# [scenario 3/3] OU | 6 trajectories
# [13/18] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=6.3s
# [17/18] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=1.0s
# [18/18] OU seed=200047 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=14.5818 m | pos_p95=17.9597 m | rot_med=0.5857 rad | completion=1.000 | elapsed=16.3s
# Benchmark finished in 29.1s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_120258/nominal_eval
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: SE(3) Acceleration Black-Box [baseline/core]
# Canonical model type: se3_accel_blackbox
# Energy semantics: not_comparable
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 6
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.6101 m | pos p95=1.7349 m | rot median=0.0585 rad | total vel median=0.0585 m/s | rel vel median=0.0564 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=2.2419 m | pos p95=6.7391 m | rot median=0.0674 rad | total vel median=0.0563 m/s | rel vel median=0.0501 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=8.3281 m | pos p95=20.0951 m | rot median=0.2002 rad | total vel median=0.0991 m/s | rel vel median=0.0481 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=18 | completed=18 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.5588 m | pos p95=1.5089 m | rot median=0.0732 rad | total vel median=0.0683 m/s | rel vel median=0.0564 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.9965 m | pos p95=9.4344 m | rot median=0.0962 rad | total vel median=0.0601 m/s | rel vel median=0.0598 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=8.9417 m | pos p95=23.7762 m | rot median=0.2257 rad | total vel median=0.1248 m/s | rel vel median=0.0481 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.4388 m | pos p95=0.5959 m | rot median=0.0515 rad | total vel median=0.0423 m/s | rel vel median=0.0336 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.7175 m | pos p95=2.6785 m | rot median=0.0320 rad | total vel median=0.0437 m/s | rel vel median=0.0382 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.3073 m | pos p95=5.9670 m | rot median=0.0705 rad | total vel median=0.0470 m/s | rel vel median=0.0383 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=1.0967 m | pos p95=1.6946 m | rot median=0.1763 rad | total vel median=0.0600 m/s | rel vel median=0.0698 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=3.5618 m | pos p95=5.3820 m | rot median=0.2488 rad | total vel median=0.0852 m/s | rel vel median=0.0650 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=14.5818 m | pos p95=17.9597 m | rot median=0.5857 rad | total vel median=0.1676 m/s | rel vel median=0.1564 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Largest completed terminal errors
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=28.6384 m | rot=0.2439 rad | total_vel_violation=0
#   OU seed=200044 | reason=completed | sim_time=60.00s | pos=18.5874 m | rot=0.5813 rad | total_vel_violation=0
#   OU seed=200045 | reason=completed | sim_time=60.00s | pos=16.0766 m | rot=0.5901 rad | total_vel_violation=0
#   OU seed=200042 | reason=completed | sim_time=60.00s | pos=15.0472 m | rot=0.1928 rad | total_vel_violation=0
#   OU seed=200043 | reason=completed | sim_time=60.00s | pos=14.1165 m | rot=0.7774 rad | total_vel_violation=0
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# PRBS seed=42 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_120258/nominal_eval/diagnostic_plots/high_terminal_error_PRBS_seed42.png
# OU seed=200044 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_120258/nominal_eval/diagnostic_plots/high_terminal_error_OU_seed200044.png
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=degraded_eval | noise_protocol=iid_noisy_ic | noise_budget=protocol=iid_noisy_ic | profile=degraded_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250] | scenarios=PRBS,CHIRP,OU | trajectories=18 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_120258/degraded_eval
# [scenario 1/3] PRBS | 6 trajectories
# [1/18] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=1m32.9s
# [5/18] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=14.2s
# [6/18] PRBS seed=47 done | reason=completed | sim_time=60.00s | eta=11.0s
# [scenario done] PRBS | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=10.1784 m | pos_p95=27.2513 m | rot_med=0.2432 rad | completion=1.000 | elapsed=5.5s
# [scenario 2/3] CHIRP | 6 trajectories
# [7/18] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=17.1s
# [11/18] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=6.9s
# [12/18] CHIRP seed=100047 done | reason=completed | sim_time=60.00s | eta=5.5s
# [scenario done] CHIRP | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=1.6595 m | pos_p95=6.5633 m | rot_med=0.0696 rad | completion=1.000 | elapsed=10.9s
# [scenario 3/3] OU | 6 trajectories
# [13/18] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=6.3s
# [17/18] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=1.0s
# [18/18] OU seed=200047 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=13.7231 m | pos_p95=18.1964 m | rot_med=0.5874 rad | completion=1.000 | elapsed=16.3s
# Benchmark finished in 29.2s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_120258/degraded_eval
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: SE(3) Acceleration Black-Box [baseline/core]
# Canonical model type: se3_accel_blackbox
# Energy semantics: not_comparable
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 6
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.6091 m | pos p95=1.8487 m | rot median=0.0676 rad | total vel median=0.0597 m/s | rel vel median=0.0562 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=2.3030 m | pos p95=8.0365 m | rot median=0.0720 rad | total vel median=0.0556 m/s | rel vel median=0.0501 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=8.9806 m | pos p95=21.0922 m | rot median=0.2071 rad | total vel median=0.1022 m/s | rel vel median=0.0480 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=18 | completed=18 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.6518 m | pos p95=2.0480 m | rot median=0.0814 rad | total vel median=0.0715 m/s | rel vel median=0.0562 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=2.3807 m | pos p95=11.2345 m | rot median=0.1043 rad | total vel median=0.0609 m/s | rel vel median=0.0597 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=10.1784 m | pos p95=27.2513 m | rot median=0.2432 rad | total vel median=0.1303 m/s | rel vel median=0.0480 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.5712 m | pos p95=0.6139 m | rot median=0.0506 rad | total vel median=0.0424 m/s | rel vel median=0.0335 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.7961 m | pos p95=3.1319 m | rot median=0.0319 rad | total vel median=0.0447 m/s | rel vel median=0.0382 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.6595 m | pos p95=6.5633 m | rot median=0.0696 rad | total vel median=0.0466 m/s | rel vel median=0.0383 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=1.1635 m | pos p95=1.7023 m | rot median=0.1764 rad | total vel median=0.0603 m/s | rel vel median=0.0697 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=3.4971 m | pos p95=5.4340 m | rot median=0.2367 rad | total vel median=0.0818 m/s | rel vel median=0.0652 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=13.7231 m | pos p95=18.1964 m | rot median=0.5874 rad | total vel median=0.1676 m/s | rel vel median=0.1564 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Largest completed terminal errors
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=32.6248 m | rot=0.2735 rad | total_vel_violation=0
#   OU seed=200044 | reason=completed | sim_time=60.00s | pos=19.0571 m | rot=0.5904 rad | total_vel_violation=0
#   OU seed=200045 | reason=completed | sim_time=60.00s | pos=15.6142 m | rot=0.5845 rad | total_vel_violation=0
#   OU seed=200042 | reason=completed | sim_time=60.00s | pos=13.8150 m | rot=0.2013 rad | total_vel_violation=0
#   OU seed=200043 | reason=completed | sim_time=60.00s | pos=13.6313 m | rot=0.7716 rad | total_vel_violation=0
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# PRBS seed=42 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_120258/degraded_eval/diagnostic_plots/high_terminal_error_PRBS_seed42.png
# OU seed=200044 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_120258/degraded_eval/diagnostic_plots/high_terminal_error_OU_seed200044.png
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=heading_biased_eval | noise_protocol=iid_noisy_ic | noise_budget=protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350] | scenarios=PRBS,CHIRP,OU | trajectories=18 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_120258/heading_biased_eval
# [scenario 1/3] PRBS | 6 trajectories
# [1/18] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=1m31.5s
# [5/18] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=14.0s
# [6/18] PRBS seed=47 done | reason=completed | sim_time=60.00s | eta=10.8s
# [scenario done] PRBS | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=11.5818 m | pos_p95=20.9510 m | rot_med=0.2272 rad | completion=1.000 | elapsed=5.4s
# [scenario 2/3] CHIRP | 6 trajectories
# [7/18] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=17.1s
# [11/18] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=6.9s
# [12/18] CHIRP seed=100047 done | reason=completed | sim_time=60.00s | eta=5.4s
# [scenario done] CHIRP | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=3.4799 m | pos_p95=9.0491 m | rot_med=0.0747 rad | completion=1.000 | elapsed=10.9s
# [scenario 3/3] OU | 6 trajectories
# [13/18] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=6.3s
# [17/18] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=1.0s
# [18/18] OU seed=200047 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=12.3150 m | pos_p95=18.7146 m | rot_med=0.5878 rad | completion=1.000 | elapsed=16.4s
# Benchmark finished in 29.2s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_120258/heading_biased_eval
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: SE(3) Acceleration Black-Box [baseline/core]
# Canonical model type: se3_accel_blackbox
# Energy semantics: not_comparable
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 6
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.7367 m | pos p95=1.5911 m | rot median=0.0830 rad | total vel median=0.0583 m/s | rel vel median=0.0562 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=2.5407 m | pos p95=7.9165 m | rot median=0.0819 rad | total vel median=0.0590 m/s | rel vel median=0.0501 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=9.2028 m | pos p95=21.0103 m | rot median=0.2095 rad | total vel median=0.1048 m/s | rel vel median=0.0482 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=18 | completed=18 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.6818 m | pos p95=1.0427 m | rot median=0.1073 rad | total vel median=0.0731 m/s | rel vel median=0.0562 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=3.2638 m | pos p95=8.1773 m | rot median=0.1284 rad | total vel median=0.0591 m/s | rel vel median=0.0601 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=11.5818 m | pos p95=20.9510 m | rot median=0.2272 rad | total vel median=0.1280 m/s | rel vel median=0.0482 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.6701 m | pos p95=0.9005 m | rot median=0.0561 rad | total vel median=0.0427 m/s | rel vel median=0.0339 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.7234 m | pos p95=4.1253 m | rot median=0.0614 rad | total vel median=0.0456 m/s | rel vel median=0.0384 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=3.4799 m | pos p95=9.0491 m | rot median=0.0747 rad | total vel median=0.0541 m/s | rel vel median=0.0383 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=1.0730 m | pos p95=2.1925 m | rot median=0.1725 rad | total vel median=0.0631 m/s | rel vel median=0.0695 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=3.0580 m | pos p95=6.2917 m | rot median=0.2170 rad | total vel median=0.0770 m/s | rel vel median=0.0653 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=12.3150 m | pos p95=18.7146 m | rot median=0.5878 rad | total vel median=0.1653 m/s | rel vel median=0.1566 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Largest completed terminal errors
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=24.0577 m | rot=0.2099 rad | total_vel_violation=0
#   OU seed=200044 | reason=completed | sim_time=60.00s | pos=20.4725 m | rot=0.6175 rad | total_vel_violation=0
#   OU seed=200045 | reason=completed | sim_time=60.00s | pos=13.4408 m | rot=0.5582 rad | total_vel_violation=0
#   OU seed=200042 | reason=completed | sim_time=60.00s | pos=12.8105 m | rot=0.2091 rad | total_vel_violation=0
#   OU seed=200043 | reason=completed | sim_time=60.00s | pos=11.8195 m | rot=0.7502 rad | total_vel_violation=0
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# PRBS seed=42 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_120258/heading_biased_eval/diagnostic_plots/high_terminal_error_PRBS_seed42.png
# OU seed=200044 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_120258/heading_biased_eval/diagnostic_plots/high_terminal_error_OU_seed200044.png
# Batch evaluation complete.
# [eval] suite=sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox eval_protocol=v4_lite profiles=nominal_eval
# Suite directory: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox
# Manifest: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox/runs.tsv
# Mode: resampled
# [eval] baseline_se3_accel_blackbox_seed42
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=nominal_eval | noise_protocol=v4_lite | noise_budget=protocol=v4_lite | profile=nominal_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | scenarios=PRBS,CHIRP,OU | trajectories=18 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_v4eval_traj6_seed42_20260525_120701
# [scenario 1/3] PRBS | 6 trajectories
# [1/18] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=1m34.8s
# [5/18] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=14.5s
# [6/18] PRBS seed=47 done | reason=completed | sim_time=60.00s | eta=11.2s
# [scenario done] PRBS | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=8.7584 m | pos_p95=21.3873 m | rot_med=0.2145 rad | completion=1.000 | elapsed=5.6s
# [scenario 2/3] CHIRP | 6 trajectories
# [7/18] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=17.0s
# [11/18] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=6.9s
# [12/18] CHIRP seed=100047 done | reason=completed | sim_time=60.00s | eta=5.4s
# [scenario done] CHIRP | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=2.2775 m | pos_p95=5.2755 m | rot_med=0.0714 rad | completion=1.000 | elapsed=10.8s
# [scenario 3/3] OU | 6 trajectories
# [13/18] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=6.2s
# [17/18] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=0.9s
# [18/18] OU seed=200047 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=15.2623 m | pos_p95=18.8879 m | rot_med=0.6001 rad | completion=1.000 | elapsed=16.2s
# Benchmark finished in 29.5s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_v4eval_traj6_seed42_20260525_120701
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: SE(3) Acceleration Black-Box [baseline/core]
# Canonical model type: se3_accel_blackbox
# Energy semantics: not_comparable
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 6
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.6683 m | pos p95=1.6690 m | rot median=0.0539 rad | total vel median=0.0570 m/s | rel vel median=0.0566 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=2.2601 m | pos p95=6.5048 m | rot median=0.0668 rad | total vel median=0.0561 m/s | rel vel median=0.0501 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=8.3900 m | pos p95=20.4109 m | rot median=0.1988 rad | total vel median=0.1010 m/s | rel vel median=0.0481 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=18 | completed=18 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.5133 m | pos p95=1.1401 m | rot median=0.0663 rad | total vel median=0.0677 m/s | rel vel median=0.0566 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.9604 m | pos p95=8.1481 m | rot median=0.1013 rad | total vel median=0.0595 m/s | rel vel median=0.0600 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=8.7584 m | pos p95=21.3873 m | rot median=0.2145 rad | total vel median=0.1242 m/s | rel vel median=0.0481 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.3741 m | pos p95=0.6922 m | rot median=0.0512 rad | total vel median=0.0430 m/s | rel vel median=0.0335 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.8280 m | pos p95=2.1692 m | rot median=0.0240 rad | total vel median=0.0427 m/s | rel vel median=0.0382 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=2.2775 m | pos p95=5.2755 m | rot median=0.0714 rad | total vel median=0.0473 m/s | rel vel median=0.0383 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=1.1873 m | pos p95=1.6970 m | rot median=0.1881 rad | total vel median=0.0594 m/s | rel vel median=0.0698 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=3.7175 m | pos p95=5.7802 m | rot median=0.2585 rad | total vel median=0.0878 m/s | rel vel median=0.0649 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=15.2623 m | pos p95=18.8879 m | rot median=0.6001 rad | total vel median=0.1677 m/s | rel vel median=0.1564 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Largest completed terminal errors
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=25.4067 m | rot=0.2200 rad | total_vel_violation=0
#   OU seed=200044 | reason=completed | sim_time=60.00s | pos=19.5293 m | rot=0.5992 rad | total_vel_violation=0
#   OU seed=200045 | reason=completed | sim_time=60.00s | pos=16.9637 m | rot=0.6010 rad | total_vel_violation=0
#   OU seed=200042 | reason=completed | sim_time=60.00s | pos=15.7788 m | rot=0.1885 rad | total_vel_violation=0
#   OU seed=200043 | reason=completed | sim_time=60.00s | pos=14.7458 m | rot=0.7849 rad | total_vel_violation=0
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# PRBS seed=42 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_v4eval_traj6_seed42_20260525_120701/diagnostic_plots/high_terminal_error_PRBS_seed42.png
# OU seed=200044 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_v4eval_traj6_seed42_20260525_120701/diagnostic_plots/high_terminal_error_OU_seed200044.png
# Batch evaluation complete.
# + /usr/bin/python3 /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/scripts/register_existing_runs_as_suite.py --suite-dir /content/_proxy_suites/sweep_oc_phase1a_smoke1_proxy_t2_wpfrag_se3_accel_blackbox --run baseline se3_accel_blackbox 42 clean__baseline_se3_accel_blackbox_seed42 /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42
# Registered suite: /content/_proxy_suites/sweep_oc_phase1a_smoke1_proxy_t2_wpfrag_se3_accel_blackbox
# Runs: 1
# Manifest: /content/_proxy_suites/sweep_oc_phase1a_smoke1_proxy_t2_wpfrag_se3_accel_blackbox/runs.tsv
# + /usr/bin/python3 /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/scripts/summarize_sweep.py --suite-dir /content/_proxy_suites/sweep_oc_phase1a_smoke1_proxy_t2_wpfrag_se3_accel_blackbox
# + /usr/bin/python3 /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/scripts/build_experiment_report.py --suite-dir /content/_proxy_suites/sweep_oc_phase1a_smoke1_proxy_t2_wpfrag_se3_accel_blackbox
# /content/_proxy_suites/sweep_oc_phase1a_smoke1_proxy_t2_wpfrag_se3_accel_blackbox/phase1a_decision_brief.md
# [proxy] local: /content/_proxy_suites/sweep_oc_phase1a_smoke1_proxy_t2_wpfrag_se3_accel_blackbox

# %% [markdown]
# ## 3. Decision train (clean x 5 seeds)
# The 5 evidence-bearing clean training runs for this black-box model.

# %%
os.environ["MODE"] = "decision_train"
# !bash scripts/run_phase1a_oc_v4lite.sh
# Out:
# [phase1a]
# MODE=decision_train
# RUN_TAG=t2_wpfrag_se3_accel_blackbox
# DATASET=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# DEVICE=cuda
# PHASE1A_MODELS=se3_accel_blackbox
# PHASE1A_PROTOCOLS=clean
# SMOKE1_MODELS=se3_accel_blackbox
# SMOKE_SEEDS=42
# DECISION_SEEDS=42 43 44 45 46
# NOISE_REFERENCE=remus100_dr
# PHASE1A_LOG_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_logs/t2_wpfrag_se3_accel_blackbox
# PHASE1A_METADATA_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_metadata_t2_wpfrag_se3_accel_blackbox
# [train] suite=sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox models=se3_accel_blackbox seeds=42 43 44 45 46 protocol=auto
# Training all models with profile-based noisy IC.
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Group: all
# Explicit models: se3_accel_blackbox
# Seeds: 42 43 44 45 46
# Noise config: protocol=auto, profile=clean, scale=1.0, warmup=20, ramp=80, mix_ratio=0.5
# Auto-eval profiles: block=[clean nominal_eval heading_biased_eval] heldout=[clean nominal_eval degraded_eval heading_biased_eval]
# Suite directory: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Models (1): se3_accel_blackbox
# Seeds: 42 43 44 45 46
# [train] baseline_se3_accel_blackbox_seed42
# Loading dataset...
# Loaded: 83850 train, 21000 test, t_eval=[0.   0.05 0.1  0.15 0.2 ]
# Dataset split: trajectory | train trajectories: 559 | test trajectories: 140
# Dataset ID: d0be9434
# Dataset path: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl | velocity convention: body_total | state dim: 27
# Position std: [0.1508, 0.1400, 0.0370]
# Velocity std: u=0.4722, v=0.0898, w=0.0718, p=0.0248, q=0.0906, r=0.0526
# Actuator std: a0=0.1543, a1=0.1555, a2=299.0037
# Training noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# Model: SE(3) Acceleration Black-Box [baseline/core] | canonical type: se3_accel_blackbox
# Model parameters: 63,129
# Training dataset: id=d0be9434 | path=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Mass matrix initialized from physics
# Training: epochs<=300, target_steps=5000, warmup_steps=400, lr=6.00e-03 -> 1.00e-04, solver=rk4, so3_reg=1.00e-03
# Train samples: 83850, Test samples: 21000
# Epoch    1 | Step    20/ 5000 | Train 4.4822e-01 | Test 4.2767e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 4.10e-04 | 4.1s
# Epoch    2 | Step    40/ 5000 | Train 4.2415e-01 | Test 3.7117e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 7.05e-04 | 3.8s
# Epoch    3 | Step    60/ 5000 | Train 3.5819e-01 | Test 3.2556e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 1.00e-03 | 3.7s
# Epoch    4 | Step    80/ 5000 | Train 3.3472e-01 | Test 3.8365e-01 | SO3(train/test) 1.13e-07/1.14e-07 | Fail(train/test) 0/0 | LR 1.29e-03 | 3.7s
# Epoch    5 | Step   100/ 5000 | Train 3.2082e-01 | Test 2.7574e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 1.59e-03 | 3.7s
# Epoch    6 | Step   120/ 5000 | Train 2.5783e-01 | Test 2.2832e-01 | SO3(train/test) 1.13e-07/1.14e-07 | Fail(train/test) 0/0 | LR 1.88e-03 | 3.7s
# Epoch    7 | Step   140/ 5000 | Train 2.2753e-01 | Test 1.9989e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 2.18e-03 | 3.7s
# Epoch    8 | Step   160/ 5000 | Train 2.1388e-01 | Test 1.8720e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 2.47e-03 | 3.8s
# Epoch    9 | Step   180/ 5000 | Train 2.0928e-01 | Test 1.9059e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 2.77e-03 | 3.7s
# Epoch   10 | Step   200/ 5000 | Train 2.1027e-01 | Test 1.9814e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 3.06e-03 | 3.7s
# Epoch   11 | Step   220/ 5000 | Train 2.1015e-01 | Test 2.0700e-01 | SO3(train/test) 1.13e-07/1.14e-07 | Fail(train/test) 0/0 | LR 3.36e-03 | 3.7s
# Epoch   12 | Step   240/ 5000 | Train 2.1015e-01 | Test 2.1373e-01 | SO3(train/test) 1.14e-07/1.13e-07 | Fail(train/test) 0/0 | LR 3.65e-03 | 3.6s
# Epoch   13 | Step   260/ 5000 | Train 2.0965e-01 | Test 2.1604e-01 | SO3(train/test) 1.13e-07/1.14e-07 | Fail(train/test) 0/0 | LR 3.95e-03 | 3.7s
# Epoch   14 | Step   280/ 5000 | Train 2.0862e-01 | Test 2.2724e-01 | SO3(train/test) 1.14e-07/1.13e-07 | Fail(train/test) 0/0 | LR 4.24e-03 | 3.7s
# Epoch   15 | Step   300/ 5000 | Train 2.0920e-01 | Test 2.3518e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 4.54e-03 | 3.7s
# Epoch   16 | Step   320/ 5000 | Train 2.0893e-01 | Test 2.5067e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 4.83e-03 | 3.7s
# Epoch   17 | Step   340/ 5000 | Train 2.0806e-01 | Test 2.3397e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.13e-03 | 3.8s
# Epoch   18 | Step   360/ 5000 | Train 2.0301e-01 | Test 2.1893e-01 | SO3(train/test) 1.14e-07/1.13e-07 | Fail(train/test) 0/0 | LR 5.42e-03 | 3.7s
# Epoch   19 | Step   380/ 5000 | Train 1.9307e-01 | Test 1.7484e-01 | SO3(train/test) 1.14e-07/1.13e-07 | Fail(train/test) 0/0 | LR 5.72e-03 | 3.7s
# Epoch   20 | Step   400/ 5000 | Train 1.8182e-01 | Test 1.7546e-01 | SO3(train/test) 1.14e-07/1.13e-07 | Fail(train/test) 0/0 | LR 6.00e-03 | 3.7s
# Epoch   21 | Step   420/ 5000 | Train 1.7314e-01 | Test 1.6408e-01 | SO3(train/test) 1.14e-07/1.13e-07 | Fail(train/test) 0/0 | LR 6.00e-03 | 3.7s
# Epoch   22 | Step   440/ 5000 | Train 1.6668e-01 | Test 1.5641e-01 | SO3(train/test) 1.14e-07/1.13e-07 | Fail(train/test) 0/0 | LR 6.00e-03 | 3.7s
# Epoch   23 | Step   460/ 5000 | Train 1.5907e-01 | Test 1.5639e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 6.00e-03 | 3.8s
# Epoch   24 | Step   480/ 5000 | Train 1.5516e-01 | Test 1.5438e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 6.00e-03 | 3.7s
# Epoch   25 | Step   500/ 5000 | Train 1.5097e-01 | Test 1.5018e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.99e-03 | 3.7s
# Epoch   26 | Step   520/ 5000 | Train 1.4650e-01 | Test 1.4337e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.99e-03 | 3.7s
# Epoch   27 | Step   540/ 5000 | Train 1.4220e-01 | Test 1.3931e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.99e-03 | 3.7s
# Epoch   28 | Step   560/ 5000 | Train 1.3956e-01 | Test 1.3913e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.98e-03 | 3.7s
# Epoch   29 | Step   580/ 5000 | Train 1.3936e-01 | Test 1.4367e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.98e-03 | 3.8s
# Epoch   30 | Step   600/ 5000 | Train 1.3702e-01 | Test 1.2292e-01 | SO3(train/test) 1.14e-07/1.13e-07 | Fail(train/test) 0/0 | LR 5.97e-03 | 3.7s
# Epoch   31 | Step   620/ 5000 | Train 1.3749e-01 | Test 1.3478e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.97e-03 | 3.7s
# Epoch   32 | Step   640/ 5000 | Train 1.3385e-01 | Test 1.2039e-01 | SO3(train/test) 1.14e-07/1.13e-07 | Fail(train/test) 0/0 | LR 5.96e-03 | 3.7s
# Epoch   33 | Step   660/ 5000 | Train 1.2933e-01 | Test 1.1178e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.95e-03 | 3.7s
# Epoch   34 | Step   680/ 5000 | Train 1.2556e-01 | Test 1.2256e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.95e-03 | 3.8s
# Epoch   35 | Step   700/ 5000 | Train 1.2371e-01 | Test 1.1998e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.94e-03 | 3.7s
# Epoch   36 | Step   720/ 5000 | Train 1.2384e-01 | Test 1.1065e-01 | SO3(train/test) 1.14e-07/1.13e-07 | Fail(train/test) 0/0 | LR 5.93e-03 | 3.7s
# Epoch   37 | Step   740/ 5000 | Train 1.2345e-01 | Test 1.3800e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.92e-03 | 3.7s
# Epoch   38 | Step   760/ 5000 | Train 1.3104e-01 | Test 1.4006e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.91e-03 | 3.7s
# Epoch   39 | Step   780/ 5000 | Train 1.3060e-01 | Test 1.1565e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.90e-03 | 3.7s
# Epoch   40 | Step   800/ 5000 | Train 1.2287e-01 | Test 1.1106e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.89e-03 | 3.7s
# Epoch   41 | Step   820/ 5000 | Train 1.1880e-01 | Test 1.2688e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.88e-03 | 3.8s
# Epoch   42 | Step   840/ 5000 | Train 1.2050e-01 | Test 1.0950e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.87e-03 | 3.7s
# Epoch   43 | Step   860/ 5000 | Train 1.1975e-01 | Test 1.2015e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.86e-03 | 3.7s
# Epoch   44 | Step   880/ 5000 | Train 1.1626e-01 | Test 1.0985e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.84e-03 | 3.8s
# Epoch   45 | Step   900/ 5000 | Train 1.1291e-01 | Test 1.1163e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.83e-03 | 3.7s
# Epoch   46 | Step   920/ 5000 | Train 1.1230e-01 | Test 1.0897e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.82e-03 | 3.8s
# Epoch   47 | Step   940/ 5000 | Train 1.1269e-01 | Test 1.0916e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.80e-03 | 3.8s
# Epoch   48 | Step   960/ 5000 | Train 1.1097e-01 | Test 1.0789e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.79e-03 | 3.8s
# Epoch   49 | Step   980/ 5000 | Train 1.0890e-01 | Test 1.0753e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.77e-03 | 3.7s
# Epoch   50 | Step  1000/ 5000 | Train 1.0806e-01 | Test 1.0299e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.76e-03 | 3.9s
# Epoch   51 | Step  1020/ 5000 | Train 1.0803e-01 | Test 1.0436e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.74e-03 | 3.8s
# Epoch   52 | Step  1040/ 5000 | Train 1.0727e-01 | Test 1.0388e-01 | SO3(train/test) 1.14e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.72e-03 | 3.8s
# Epoch   53 | Step  1060/ 5000 | Train 1.0737e-01 | Test 1.0404e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.71e-03 | 3.7s
# Epoch   54 | Step  1080/ 5000 | Train 1.0812e-01 | Test 1.0765e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.69e-03 | 3.8s
# Epoch   55 | Step  1100/ 5000 | Train 1.0842e-01 | Test 1.0644e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.67e-03 | 3.9s
# Epoch   56 | Step  1120/ 5000 | Train 1.0991e-01 | Test 1.1495e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.65e-03 | 3.7s
# Epoch   57 | Step  1140/ 5000 | Train 1.1356e-01 | Test 1.0992e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.63e-03 | 3.8s
# Epoch   58 | Step  1160/ 5000 | Train 1.0945e-01 | Test 1.0900e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.61e-03 | 3.8s
# Epoch   59 | Step  1180/ 5000 | Train 1.1003e-01 | Test 9.9886e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.59e-03 | 3.8s
# Epoch   60 | Step  1200/ 5000 | Train 1.1566e-01 | Test 1.1703e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.57e-03 | 3.8s
# Epoch   61 | Step  1220/ 5000 | Train 1.0925e-01 | Test 9.9953e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.55e-03 | 3.8s
# Epoch   62 | Step  1240/ 5000 | Train 1.0510e-01 | Test 1.0496e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.53e-03 | 3.7s
# Epoch   63 | Step  1260/ 5000 | Train 1.0398e-01 | Test 1.0346e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.51e-03 | 3.7s
# Epoch   64 | Step  1280/ 5000 | Train 1.0261e-01 | Test 1.0339e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.48e-03 | 3.8s
# Epoch   65 | Step  1300/ 5000 | Train 1.0270e-01 | Test 1.0426e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.46e-03 | 3.8s
# Epoch   66 | Step  1320/ 5000 | Train 1.0306e-01 | Test 1.0241e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.44e-03 | 3.7s
# Epoch   67 | Step  1340/ 5000 | Train 1.0171e-01 | Test 1.0181e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.41e-03 | 3.7s
# Epoch   68 | Step  1360/ 5000 | Train 1.0098e-01 | Test 9.9344e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.39e-03 | 3.7s
# Epoch   69 | Step  1380/ 5000 | Train 1.0099e-01 | Test 1.0046e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.36e-03 | 3.7s
# Epoch   70 | Step  1400/ 5000 | Train 1.0103e-01 | Test 1.0089e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.34e-03 | 3.7s
# Epoch   71 | Step  1420/ 5000 | Train 1.0018e-01 | Test 1.0037e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.31e-03 | 3.8s
# Epoch   72 | Step  1440/ 5000 | Train 1.0072e-01 | Test 1.0552e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.29e-03 | 3.7s
# Epoch   73 | Step  1460/ 5000 | Train 1.0075e-01 | Test 1.0278e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.26e-03 | 3.7s
# Epoch   74 | Step  1480/ 5000 | Train 1.0002e-01 | Test 1.0141e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.23e-03 | 3.8s
# Epoch   75 | Step  1500/ 5000 | Train 9.9833e-02 | Test 9.9153e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.21e-03 | 3.7s
# Epoch   76 | Step  1520/ 5000 | Train 9.9740e-02 | Test 1.0478e-01 | SO3(train/test) 1.14e-07/1.13e-07 | Fail(train/test) 0/0 | LR 5.18e-03 | 3.8s
# Epoch   77 | Step  1540/ 5000 | Train 1.0162e-01 | Test 1.0014e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.15e-03 | 3.7s
# Epoch   78 | Step  1560/ 5000 | Train 1.0163e-01 | Test 1.0741e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.12e-03 | 3.7s
# Epoch   79 | Step  1580/ 5000 | Train 1.0311e-01 | Test 1.0115e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.09e-03 | 3.7s
# Epoch   80 | Step  1600/ 5000 | Train 1.0040e-01 | Test 1.0016e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.06e-03 | 3.7s
# Epoch   81 | Step  1620/ 5000 | Train 9.9122e-02 | Test 1.0002e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.03e-03 | 3.7s
# Epoch   82 | Step  1640/ 5000 | Train 9.9113e-02 | Test 9.9996e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.00e-03 | 3.7s
# Epoch   83 | Step  1660/ 5000 | Train 9.8959e-02 | Test 1.0052e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 4.97e-03 | 3.7s
# Epoch   84 | Step  1680/ 5000 | Train 9.8782e-02 | Test 1.0021e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 4.94e-03 | 3.7s
# Epoch   85 | Step  1700/ 5000 | Train 9.8581e-02 | Test 1.0143e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 4.91e-03 | 3.7s
# Epoch   86 | Step  1720/ 5000 | Train 9.9591e-02 | Test 1.0155e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 4.88e-03 | 3.8s
# Epoch   87 | Step  1740/ 5000 | Train 9.9208e-02 | Test 1.0071e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 4.85e-03 | 3.7s
# Epoch   88 | Step  1760/ 5000 | Train 9.8666e-02 | Test 9.7297e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 4.82e-03 | 3.8s
# Epoch   89 | Step  1780/ 5000 | Train 9.9328e-02 | Test 1.0017e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 4.78e-03 | 3.7s
# Epoch   90 | Step  1800/ 5000 | Train 9.8640e-02 | Test 9.8921e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 4.75e-03 | 3.7s
# Epoch   91 | Step  1820/ 5000 | Train 9.8654e-02 | Test 1.0004e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 4.72e-03 | 3.7s
# Epoch   92 | Step  1840/ 5000 | Train 9.7159e-02 | Test 9.9318e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 4.68e-03 | 3.8s
# Epoch   93 | Step  1860/ 5000 | Train 9.7214e-02 | Test 1.0219e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 4.65e-03 | 3.7s
# Epoch   94 | Step  1880/ 5000 | Train 9.7079e-02 | Test 1.0223e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 4.62e-03 | 3.7s
# Epoch   95 | Step  1900/ 5000 | Train 9.7079e-02 | Test 9.9213e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 4.58e-03 | 3.7s
# Epoch   96 | Step  1920/ 5000 | Train 9.6817e-02 | Test 1.0031e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 4.55e-03 | 3.7s
# Epoch   97 | Step  1940/ 5000 | Train 9.7142e-02 | Test 9.8430e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 4.51e-03 | 3.8s
# Epoch   98 | Step  1960/ 5000 | Train 9.6339e-02 | Test 9.7523e-02 | SO3(train/test) 1.14e-07/1.13e-07 | Fail(train/test) 0/0 | LR 4.48e-03 | 3.7s
# Epoch   99 | Step  1980/ 5000 | Train 9.6730e-02 | Test 9.8758e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 4.44e-03 | 3.7s
# Epoch  100 | Step  2000/ 5000 | Train 9.6450e-02 | Test 9.9043e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 4.41e-03 | 3.7s
# Epoch  101 | Step  2020/ 5000 | Train 9.5936e-02 | Test 9.8480e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 4.37e-03 | 3.7s
# Epoch  102 | Step  2040/ 5000 | Train 9.5759e-02 | Test 9.8064e-02 | SO3(train/test) 1.14e-07/1.13e-07 | Fail(train/test) 0/0 | LR 4.33e-03 | 3.7s
# Epoch  103 | Step  2060/ 5000 | Train 9.5931e-02 | Test 9.7543e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 4.30e-03 | 3.7s
# Epoch  104 | Step  2080/ 5000 | Train 9.5541e-02 | Test 1.0057e-01 | SO3(train/test) 1.14e-07/1.13e-07 | Fail(train/test) 0/0 | LR
-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 4.49e-04 | 3.7s
# Epoch  215 | Step  4300/ 5000 | Train 9.0978e-02 | Test 9.6594e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 4.30e-04 | 3.7s
# Epoch  216 | Step  4320/ 5000 | Train 9.1129e-02 | Test 9.7718e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 4.12e-04 | 3.7s
# Epoch  217 | Step  4340/ 5000 | Train 9.0870e-02 | Test 9.6986e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 3.94e-04 | 3.7s
# Epoch  218 | Step  4360/ 5000 | Train 9.0843e-02 | Test 9.6963e-02 | SO3(train/test) 1.14e-07/1.13e-07 | Fail(train/test) 0/0 | LR 3.77e-04 | 3.8s
# Epoch  219 | Step  4380/ 5000 | Train 9.0867e-02 | Test 9.6320e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 3.60e-04 | 3.8s
# Epoch  220 | Step  4400/ 5000 | Train 9.0757e-02 | Test 9.7100e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 3.44e-04 | 3.7s
# Epoch  221 | Step  4420/ 5000 | Train 9.0564e-02 | Test 9.7515e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 3.28e-04 | 3.7s
# Epoch  222 | Step  4440/ 5000 | Train 9.0663e-02 | Test 9.6523e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 3.12e-04 | 3.7s
# Epoch  223 | Step  4460/ 5000 | Train 9.0469e-02 | Test 9.7033e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 2.98e-04 | 3.8s
# Epoch  224 | Step  4480/ 5000 | Train 9.0482e-02 | Test 9.6980e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 2.83e-04 | 3.7s
# Epoch  225 | Step  4500/ 5000 | Train 9.0482e-02 | Test 9.6970e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 2.70e-04 | 3.7s
# Epoch  226 | Step  4520/ 5000 | Train 9.0333e-02 | Test 9.5956e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 2.57e-04 | 3.8s
# Epoch  227 | Step  4540/ 5000 | Train 9.0183e-02 | Test 9.7777e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 2.44e-04 | 3.7s
# Epoch  228 | Step  4560/ 5000 | Train 9.0334e-02 | Test 9.5611e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 2.32e-04 | 3.7s
# Epoch  229 | Step  4580/ 5000 | Train 9.0083e-02 | Test 9.5967e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 2.20e-04 | 3.7s
# Epoch  230 | Step  4600/ 5000 | Train 8.9978e-02 | Test 9.6029e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 2.09e-04 | 3.7s
# Epoch  231 | Step  4620/ 5000 | Train 8.9840e-02 | Test 9.6179e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 1.98e-04 | 3.7s
# Epoch  232 | Step  4640/ 5000 | Train 8.9634e-02 | Test 9.6840e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 1.88e-04 | 3.7s
# Epoch  233 | Step  4660/ 5000 | Train 8.9536e-02 | Test 9.6859e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 1.79e-04 | 3.8s
# Epoch  234 | Step  4680/ 5000 | Train 8.9501e-02 | Test 9.6142e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 1.70e-04 | 3.7s
# Epoch  235 | Step  4700/ 5000 | Train 8.9442e-02 | Test 9.5850e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 1.61e-04 | 3.8s
# Epoch  236 | Step  4720/ 5000 | Train 8.9092e-02 | Test 9.5156e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 1.53e-04 | 3.8s
# Epoch  237 | Step  4740/ 5000 | Train 8.9162e-02 | Test 9.5414e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 1.46e-04 | 3.7s
# Epoch  238 | Step  4760/ 5000 | Train 8.8887e-02 | Test 9.5709e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 1.39e-04 | 3.7s
# Epoch  239 | Step  4780/ 5000 | Train 8.8688e-02 | Test 9.5100e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 1.33e-04 | 3.9s
# Epoch  240 | Step  4800/ 5000 | Train 8.8573e-02 | Test 9.6542e-02 | SO3(train/test) 1.14e-07/1.13e-07 | Fail(train/test) 0/0 | LR 1.27e-04 | 3.8s
# Epoch  241 | Step  4820/ 5000 | Train 8.8440e-02 | Test 9.5987e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 1.22e-04 | 3.8s
# Epoch  242 | Step  4840/ 5000 | Train 8.8181e-02 | Test 9.4543e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 1.17e-04 | 3.8s
# Epoch  243 | Step  4860/ 5000 | Train 8.8160e-02 | Test 9.4843e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 1.13e-04 | 3.8s
# Epoch  244 | Step  4880/ 5000 | Train 8.7918e-02 | Test 9.4502e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 1.10e-04 | 3.8s
# Epoch  245 | Step  4900/ 5000 | Train 8.7787e-02 | Test 9.4825e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 1.07e-04 | 3.7s
# Epoch  246 | Step  4920/ 5000 | Train 8.7743e-02 | Test 9.4723e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 1.04e-04 | 3.8s
# Epoch  247 | Step  4940/ 5000 | Train 8.7488e-02 | Test 9.4236e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 1.02e-04 | 3.7s
# Epoch  248 | Step  4960/ 5000 | Train 8.7242e-02 | Test 9.3866e-02 | SO3(train/test) 1.14e-07/1.13e-07 | Fail(train/test) 0/0 | LR 1.01e-04 | 3.7s
# Epoch  249 | Step  4980/ 5000 | Train 8.7015e-02 | Test 9.3985e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 1.00e-04 | 3.8s
# Epoch  250 | Step  5000/ 5000 | Train 8.6747e-02 | Test 9.3858e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 1.00e-04 | 3.7s
# Reached target optimizer steps: 5000/5000
# Done. Best validation score: failure_rate=0.0000, test_loss=9.3858e-02 (epoch 250)
# Running detailed evaluation...
# Block evaluation profile: clean
# Block evaluation noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0003 +/- 0.0002  (max 0.0012)
# Rotation geo [rad]:  0.0011 +/- 0.0006  (max 0.0028)
# Lin vel RMSE [m/s]:  0.0038 +/- 0.0021
# Ang vel RMSE [r/s]:  0.0091 +/- 0.0054
# Components:  u=0.0038  v=0.0028  w=0.0032  p=0.0055  q=0.0110  r=0.0069
# SO(3) violation:  |det-1|=5.76e-08  ||RR^T-I||=1.18e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# Block evaluation profile: nominal_eval
# Block evaluation noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0013 +/- 0.0008  (max 0.0055)
# Rotation geo [rad]:  0.0083 +/- 0.0058  (max 0.0369)
# Lin vel RMSE [m/s]:  0.0059 +/- 0.0025
# Ang vel RMSE [r/s]:  0.0096 +/- 0.0054
# Components:  u=0.0066  v=0.0044  w=0.0048  p=0.0069  q=0.0111  r=0.0071
# SO(3) violation:  |det-1|=2.77e-07  ||RR^T-I||=6.08e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# Block evaluation profile: heading_biased_eval
# Block evaluation noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0049 +/- 0.0017  (max 0.0109)
# Rotation geo [rad]:  0.0351 +/- 0.0096  (max 0.0656)
# Lin vel RMSE [m/s]:  0.0090 +/- 0.0037
# Ang vel RMSE [r/s]:  0.0096 +/- 0.0054
# Components:  u=0.0086  v=0.0098  w=0.0051  p=0.0069  q=0.0111  r=0.0071
# SO(3) violation:  |det-1|=2.99e-07  ||RR^T-I||=6.34e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Block Evaluation Relative To Clean
# ==================================================
# [nominal_eval]
# position_rmse: ratio=4.969  degradation=+396.9%
# rotation_geodesic: ratio=7.357  degradation=+635.7%
# velocity_rmse: ratio=1.547  degradation=+54.7%
# angular_rmse: ratio=1.063  degradation=+6.3%
# failure_rate: ratio=1.000  degradation=+0.0%
# [heading_biased_eval]
# position_rmse: ratio=18.561  degradation=+1756.1%
# rotation_geodesic: ratio=31.014  degradation=+3001.4%
# velocity_rmse: ratio=2.340  degradation=+134.0%
# angular_rmse: ratio=1.063  degradation=+6.3%
# failure_rate: ratio=1.000  degradation=+0.0%
# Running held-out trajectory evaluation...
# Held-out evaluation profile: clean
# Held-out evaluation noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0002 (median 0.0002, p95 0.0003)
# Rotation geo [rad]:  0.0009 (median 0.0009, p95 0.0013)
# Lin vel RMSE [m/s]:  0.0030  Ang vel RMSE [r/s]:  0.0067
# SO(3) violation:  |det-1|=5.87e-08  ||RR^T-I||=1.14e-07
# Noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# [CHIRP] pos=0.0001 m, rot=0.0006 rad, success=1.0000
# [OU] pos=0.0003 m, rot=0.0010 rad, success=1.0000
# [PRBS] pos=0.0002 m, rot=0.0010 rad, success=1.0000
# Held-out evaluation profile: nominal_eval
# Held-out evaluation noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0011 (median 0.0011, p95 0.0014)
# Rotation geo [rad]:  0.0087 (median 0.0086, p95 0.0096)
# Lin vel RMSE [m/s]:  0.0052  Ang vel RMSE [r/s]:  0.0075
# SO(3) violation:  |det-1|=2.94e-07  ||RR^T-I||=6.27e-07
# Noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# [CHIRP] pos=0.0011 m, rot=0.0086 rad, success=1.0000
# [OU] pos=0.0011 m, rot=0.0088 rad, success=1.0000
# [PRBS] pos=0.0012 m, rot=0.0086 rad, success=1.0000
# Held-out evaluation profile: degraded_eval
# Held-out evaluation noise budget: protocol=iid_noisy_ic | profile=degraded_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0026 (median 0.0026, p95 0.0033)
# Rotation geo [rad]:  0.0210 (median 0.0209, p95 0.0234)
# Lin vel RMSE [m/s]:  0.0090  Ang vel RMSE [r/s]:  0.0090
# SO(3) violation:  |det-1|=2.96e-07  ||RR^T-I||=6.28e-07
# Noise budget: protocol=iid_noisy_ic | profile=degraded_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250]
# [CHIRP] pos=0.0025 m, rot=0.0209 rad, success=1.0000
# [OU] pos=0.0026 m, rot=0.0212 rad, success=1.0000
# [PRBS] pos=0.0027 m, rot=0.0209 rad, success=1.0000
# Held-out evaluation profile: heading_biased_eval
# Held-out evaluation noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Held-Out Trajectory Evaluation
# ...
# Epoch  231 | Step  4620/ 5000 | Train 5.0265e-03 | Test 5.3226e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.98e-04 | 3.8s
# Epoch  232 | Step  4640/ 5000 | Train 5.0287e-03 | Test 5.3167e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.88e-04 | 3.7s
# Epoch  233 | Step  4660/ 5000 | Train 5.0183e-03 | Test 5.3093e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.79e-04 | 3.8s
# Epoch  234 | Step  4680/ 5000 | Train 5.0097e-03 | Test 5.3215e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.70e-04 | 3.7s
# Epoch  235 | Step  4700/ 5000 | Train 5.0072e-03 | Test 5.2955e-03 | SO3(train/test) 1.17e-07/1.18e-07 | Fail(train/test) 0/0 | LR 1.61e-04 | 3.8s
# Epoch  236 | Step  4720/ 5000 | Train 5.0046e-03 | Test 5.3112e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.53e-04 | 3.7s
# Epoch  237 | Step  4740/ 5000 | Train 4.9963e-03 | Test 5.2810e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.46e-04 | 3.7s
# Epoch  238 | Step  4760/ 5000 | Train 4.9830e-03 | Test 5.2795e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.39e-04 | 3.7s
# Epoch  239 | Step  4780/ 5000 | Train 4.9843e-03 | Test 5.2918e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.33e-04 | 3.8s
# Epoch  240 | Step  4800/ 5000 | Train 4.9808e-03 | Test 5.2751e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.27e-04 | 3.7s
# Epoch  241 | Step  4820/ 5000 | Train 4.9782e-03 | Test 5.2701e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.22e-04 | 3.7s
# Epoch  242 | Step  4840/ 5000 | Train 4.9784e-03 | Test 5.2733e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.17e-04 | 3.7s
# Epoch  243 | Step  4860/ 5000 | Train 4.9700e-03 | Test 5.2586e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.13e-04 | 3.6s
# Epoch  244 | Step  4880/ 5000 | Train 4.9716e-03 | Test 5.2600e-03 | SO3(train/test) 1.17e-07/1.18e-07 | Fail(train/test) 0/0 | LR 1.10e-04 | 3.8s
# Epoch  245 | Step  4900/ 5000 | Train 4.9681e-03 | Test 5.2520e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.07e-04 | 3.7s
# Epoch  246 | Step  4920/ 5000 | Train 4.9564e-03 | Test 5.2500e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.04e-04 | 3.7s
# Epoch  247 | Step  4940/ 5000 | Train 4.9612e-03 | Test 5.2470e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.02e-04 | 3.7s
# Epoch  248 | Step  4960/ 5000 | Train 4.9526e-03 | Test 5.2444e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.01e-04 | 3.7s
# Epoch  249 | Step  4980/ 5000 | Train 4.9485e-03 | Test 5.2411e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.00e-04 | 3.7s
# Epoch  250 | Step  5000/ 5000 | Train 4.9451e-03 | Test 5.2399e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.00e-04 | 3.7s
# Reached target optimizer steps: 5000/5000
# Done. Best validation score: failure_rate=0.0000, test_loss=5.2399e-03 (epoch 250)
# Running detailed evaluation...
# Block evaluation profile: clean
# Block evaluation noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0002 +/- 0.0001  (max 0.0006)
# Rotation geo [rad]:  0.0005 +/- 0.0000  (max 0.0006)
# Lin vel RMSE [m/s]:  0.0019 +/- 0.0014
# Ang vel RMSE [r/s]:  0.0010 +/- 0.0005
# Components:  u=0.0031  v=0.0006  w=0.0006  p=0.0008  q=0.0008  r=0.0009
# SO(3) violation:  |det-1|=6.33e-08  ||RR^T-I||=1.30e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# Block evaluation profile: nominal_eval
# Block evaluation noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0013 +/- 0.0008  (max 0.0077)
# Rotation geo [rad]:  0.0085 +/- 0.0060  (max 0.0448)
# Lin vel RMSE [m/s]:  0.0051 +/- 0.0021
# Ang vel RMSE [r/s]:  0.0033 +/- 0.0019
# Components:  u=0.0066  v=0.0033  w=0.0030  p=0.0051  q=0.0011  r=0.0015
# SO(3) violation:  |det-1|=2.99e-07  ||RR^T-I||=6.34e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# Block evaluation profile: heading_biased_eval
# Block evaluation noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0049 +/- 0.0016  (max 0.0105)
# Rotation geo [rad]:  0.0352 +/- 0.0099  (max 0.0652)
# Lin vel RMSE [m/s]:  0.0085 +/- 0.0038
# Ang vel RMSE [r/s]:  0.0033 +/- 0.0019
# Components:  u=0.0089  v=0.0091  w=0.0034  p=0.0051  q=0.0011  r=0.0015
# SO(3) violation:  |det-1|=2.78e-07  ||RR^T-I||=6.03e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Block Evaluation Relative To Clean
# ==================================================
# [nominal_eval]
# position_rmse: ratio=7.913  degradation=+691.3%
# rotation_geodesic: ratio=17.364  degradation=+1636.4%
# velocity_rmse: ratio=2.618  degradation=+161.8%
# angular_rmse: ratio=3.401  degradation=+240.1%
# failure_rate: ratio=1.000  degradation=+0.0%
# [heading_biased_eval]
# position_rmse: ratio=29.301  degradation=+2830.1%
# rotation_geodesic: ratio=71.829  degradation=+7082.9%
# velocity_rmse: ratio=4.415  degradation=+341.5%
# angular_rmse: ratio=3.407  degradation=+240.7%
# failure_rate: ratio=1.000  degradation=+0.0%
# Running held-out trajectory evaluation...
# Held-out evaluation profile: clean
# Held-out evaluation noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0002 (median 0.0002, p95 0.0002)
# Rotation geo [rad]:  0.0005 (median 0.0005, p95 0.0005)
# Lin vel RMSE [m/s]:  0.0017  Ang vel RMSE [r/s]:  0.0008
# SO(3) violation:  |det-1|=6.06e-08  ||RR^T-I||=1.17e-07
# Noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# [CHIRP] pos=0.0001 m, rot=0.0005 rad, success=1.0000
# [OU] pos=0.0002 m, rot=0.0005 rad, success=1.0000
# [PRBS] pos=0.0002 m, rot=0.0005 rad, success=1.0000
# Held-out evaluation profile: nominal_eval
# Held-out evaluation noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0011 (median 0.0011, p95 0.0014)
# Rotation geo [rad]:  0.0087 (median 0.0086, p95 0.0094)
# Lin vel RMSE [m/s]:  0.0045  Ang vel RMSE [r/s]:  0.0032
# SO(3) violation:  |det-1|=2.90e-07  ||RR^T-I||=6.21e-07
# Noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# [CHIRP] pos=0.0011 m, rot=0.0087 rad, success=1.0000
# [OU] pos=0.0011 m, rot=0.0086 rad, success=1.0000
# [PRBS] pos=0.0012 m, rot=0.0086 rad, success=1.0000
# Held-out evaluation profile: degraded_eval
# Held-out evaluation noise budget: protocol=iid_noisy_ic | profile=degraded_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0026 (median 0.0026, p95 0.0033)
# Rotation geo [rad]:  0.0212 (median 0.0211, p95 0.0229)
# Lin vel RMSE [m/s]:  0.0087  Ang vel RMSE [r/s]:  0.0061
# SO(3) violation:  |det-1|=2.94e-07  ||RR^T-I||=6.26e-07
# Noise budget: protocol=iid_noisy_ic | profile=degraded_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250]
# [CHIRP] pos=0.0026 m, rot=0.0213 rad, success=1.0000
# [OU] pos=0.0026 m, rot=0.0211 rad, success=1.0000
# [PRBS] pos=0.0027 m, rot=0.0211 rad, success=1.0000
# Held-out evaluation profile: heading_biased_eval
# Held-out evaluation noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0040 (median 0.0039, p95 0.0052)
# Rotation geo [rad]:  0.0353 (median 0.0352, p95 0.0366)
# Lin vel RMSE [m/s]:  0.0071  Ang vel RMSE [r/s]:  0.0032
# SO(3) violation:  |det-1|=2.91e-07  ||RR^T-I||=6.20e-07
# Noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# [CHIRP] pos=0.0039 m, rot=0.0352 rad, success=1.0000
# [OU] pos=0.0039 m, rot=0.0352 rad, success=1.0000
# [PRBS] pos=0.0042 m, rot=0.0353 rad, success=1.0000
# ==================================================
# Held-Out Evaluation Relative To Clean
# ==================================================
# [nominal_eval]
# position_rmse: ratio=7.427  degradation=+642.7%
# rotation_geodesic: ratio=17.665  degradation=+1666.5%
# velocity_rmse: ratio=2.600  degradation=+160.0%
# angular_rmse: ratio=3.918  degradation=+291.8%
# success_rate: ratio=1.000  degradation=+0.0%
# trajectory_failure_rate: ratio=1.000  degradation=+0.0%
# [degraded_eval]
# position_rmse: ratio=17.367  degradation=+1636.7%
# rotation_geodesic: ratio=43.202  degradation=+4220.2%
# velocity_rmse: ratio=4.960  degradation=+396.0%
# angular_rmse: ratio=7.510  degradation=+651.0%
# success_rate: ratio=1.000  degradation=+0.0%
# trajectory_failure_rate: ratio=1.000  degradation=+0.0%
# [heading_biased_eval]
# position_rmse: ratio=26.606  degradation=+2560.6%
# rotation_geodesic: ratio=71.955  degradation=+7095.5%
# velocity_rmse: ratio=4.044  degradation=+304.4%
# angular_rmse: ratio=3.918  degradation=+291.8%
# success_rate: ratio=1.000  degradation=+0.0%
# trajectory_failure_rate: ratio=1.000  degradation=+0.0%
#
# Training finished. Results: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed46
# Training sweep complete.
# Manifest: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/runs.tsv
# Next step:
#   scripts/batch_eval_models.sh --suite-dir "/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox"
#
# Training complete.
# Suite directory: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox
# Next step:
#   bash scripts/eval_all_models_noise_profile.sh --suite-dir "/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox"
# [audit] /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox
#                                                   suite_name    group         model_type  seed train_noise_protocol  best_epoch  best_loss  noise_warmup_epochs  noise_ramp_epochs  noise_mix_ratio  epoch_scale_at_best  is_effectively_clean_at_best
# sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox baseline se3_accel_blackbox    42                clean         250   0.093858                   20                 80              0.5                  0.0                          True
# sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox baseline se3_accel_blackbox    43                clean         250   0.006754                   20                 80              0.5                  0.0                          True
# sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox baseline se3_accel_blackbox    44                clean         250   0.008389                   20                 80              0.5                  0.0                          True
# sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox baseline se3_accel_blackbox    45                clean         250   0.006007                   20                 80              0.5                  0.0                          True
# sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox baseline se3_accel_blackbox    46                clean         250   0.005240                   20                 80              0.5                  0.0                          True
# [validate_v4] skipped: v4lite not in PHASE1A_PROTOCOLS=clean

# %% [markdown]
# ## 4. Decision rollout eval (clean suite x 4 robustness profiles)
# Evaluates the clean-trained suite across `clean nominal_eval degraded_eval heading_biased_eval` (iid eval protocol) plus the `v4_lite` eval at `nominal_eval`.

# %%
os.environ["MODE"] = "decision_eval"
# !bash scripts/run_phase1a_oc_v4lite.sh
# Out:
# [phase1a]
# MODE=decision_eval
# RUN_TAG=t2_wpfrag_se3_accel_blackbox
# DATASET=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# DEVICE=cuda
# PHASE1A_MODELS=se3_accel_blackbox
# PHASE1A_PROTOCOLS=clean
# SMOKE1_MODELS=se3_accel_blackbox
# SMOKE_SEEDS=42
# DECISION_SEEDS=42 43 44 45 46
# NOISE_REFERENCE=remus100_dr
# PHASE1A_LOG_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_logs/t2_wpfrag_se3_accel_blackbox
# PHASE1A_METADATA_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_metadata_t2_wpfrag_se3_accel_blackbox
# [eval] suite=sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox eval_protocol=iid_noisy_ic profiles=clean nominal_eval degraded_eval heading_biased_eval
# Suite directory: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox
# Manifest: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/runs.tsv
# Mode: resampled
# [eval] baseline_se3_accel_blackbox_seed42
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=clean | noise_protocol=clean | noise_budget=protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000] | scenarios=PRBS,CHIRP,OU | trajectories=90 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_132823/clean
# [scenario 1/3] PRBS | 30 trajectories
# [1/90] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=5h07m39.4s
# [5/90] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=58m46.2s
# [10/90] PRBS seed=51 done | reason=completed | sim_time=60.00s | eta=27m39.5s
# [15/90] PRBS seed=56 done | reason=completed | sim_time=60.00s | eta=17m17.3s
# [20/90] PRBS seed=61 done | reason=completed | sim_time=60.00s | eta=12m06.1s
# [25/90] PRBS seed=66 done | reason=completed | sim_time=60.00s | eta=8m59.4s
# [30/90] PRBS seed=71 done | reason=completed | sim_time=60.00s | eta=6m55.0s
# [scenario done] PRBS | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=4.9104 m | pos_p95=22.1450 m | rot_med=0.1088 rad | completion=1.000 | elapsed=3m27.5s
# [scenario 2/3] CHIRP | 30 trajectories
# [31/90] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=13m10.5s
# [35/90] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=10m52.7s
# [40/90] CHIRP seed=100051 done | reason=completed | sim_time=60.00s | eta=8m39.2s
# [45/90] CHIRP seed=100056 done | reason=completed | sim_time=60.00s | eta=6m55.4s
# [50/90] CHIRP seed=100061 done | reason=completed | sim_time=60.00s | eta=5m32.3s
# [55/90] CHIRP seed=100066 done | reason=completed | sim_time=60.00s | eta=4m24.4s
# [60/90] CHIRP seed=100071 done | reason=completed | sim_time=60.00s | eta=3m27.7s
# [scenario done] CHIRP | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=2.1346 m | pos_p95=7.1481 m | rot_med=0.0561 rad | completion=1.000 | elapsed=6m55.5s
# [scenario 3/3] OU | 30 trajectories
# [61/90] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=4m56.2s
# [65/90] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=3m59.7s
# [70/90] OU seed=200051 done | reason=completed | sim_time=60.00s | eta=2m58.0s
# [75/90] OU seed=200056 done | reason=completed | sim_time=60.00s | eta=2m04.6s
# [80/90] OU seed=200061 done | reason=completed | sim_time=60.00s | eta=1m17.9s
# [85/90] OU seed=200066 done | reason=pred_divergence | sim_time=55.75s | eta=36.7s
# [90/90] OU seed=200071 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=29/30 | gt_div=0 | model_fail=1 | H=60.0s cond_n=29/30 | pos_med=16.3891 m | pos_p95=29.2609 m | rot_med=0.4678 rad | completion=0.967 | elapsed=10m23.2s
# Benchmark finished in 10m41.9s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_132823/clean
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: SE(3) Acceleration Black-Box [baseline/core]
# Canonical model type: se3_accel_blackbox
# Energy semantics: not_comparable
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 30
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.5540 m | pos p95=1.9664 m | rot median=0.0605 rad | total vel median=0.0552 m/s | rel vel median=0.0510 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=1.7238 m | pos p95=9.1360 m | rot median=0.0722 rad | total vel median=0.0549 m/s | rel vel median=0.0465 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=5.6333 m | pos p95=25.8959 m | rot median=0.1252 rad | total vel median=0.0674 m/s | rel vel median=0.0465 m/s | cond_n=89/90 | completion=0.989 | gt_fail_by_h=0.000 | model_fail_by_h=0.011
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=90 | completed=89 (0.989) | gt_divergence=0 (0.000) | pred_divergence=1 (0.011) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.3233 m | pos p95=1.1225 m | rot median=0.0497 rad | total vel median=0.0558 m/s | rel vel median=0.0534 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.5794 m | pos p95=5.8436 m | rot median=0.0693 rad | total vel median=0.0583 m/s | rel vel median=0.0543 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=4.9104 m | pos p95=22.1450 m | rot median=0.1088 rad | total vel median=0.0774 m/s | rel vel median=0.0481 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.3520 m | pos p95=0.8852 m | rot median=0.0499 rad | total vel median=0.0394 m/s | rel vel median=0.0292 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.9995 m | pos p95=2.5824 m | rot median=0.0377 rad | total vel median=0.0367 m/s | rel vel median=0.0309 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=2.1346 m | pos p95=7.1481 m | rot median=0.0561 rad | total vel median=0.0412 m/s | rel vel median=0.0333 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=30 | completed=29 (0.967) | gt_divergence=0 (0.000) | pred_divergence=1 (0.033) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=1.0950 m | pos p95=2.7204 m | rot median=0.1990 rad | total vel median=0.0877 m/s | rel vel median=0.0729 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=4.6913 m | pos p95=11.5866 m | rot median=0.2537 rad | total vel median=0.0904 m/s | rel vel median=0.0666 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=16.3891 m | pos p95=29.2609 m | rot median=0.4678 rad | total vel median=0.1597 m/s | rel vel median=0.0839 m/s | cond_n=29/30 | completion=0.967 | gt_fail_by_h=0.000 | model_fail_by_h=0.033
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Earliest rollout failures
#   OU seed=200066 | reason=pred_divergence | sim_time=55.75s | pos=nan m | rot=nan rad | total_vel_violation=0
#
# Largest completed terminal errors
#   OU seed=200068 | reason=completed | sim_time=60.00s | pos=30.3067 m | rot=0.4997 rad | total_vel_violation=0
#   OU seed=200064 | reason=completed | sim_time=60.00s | pos=29.7603 m | rot=1.9695 rad | total_vel_violation=0
#   OU seed=200057 | reason=completed | sim_time=60.00s | pos=28.5118 m | rot=0.4072 rad | total_vel_violation=0
#   OU seed=200049 | reason=completed | sim_time=60.00s | pos=26.2918 m | rot=0.6555 rad | total_vel_violation=0
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=25.9845 m | rot=0.2242 rad | total_vel_violation=0
#
# Completed rollouts with velocity violations
#   OU seed=200062 | reason=completed | sim_time=60.00s | pos=10.8608 m | rot=0.4028 rad | total_vel_violation=1
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# OU seed=200066 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_132823/clean/diagnostic_plots/rollout_failure_OU_seed200066.png
# OU seed=200062 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_132823/clean/diagnostic_plots/velocity_violation_OU_seed200062.png
# OU seed=200068 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_132823/clean/diagnostic_plots/high_terminal_error_OU_seed200068.png
# OU seed=200064 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_132823/clean/diagnostic_plots/high_terminal_error_OU_seed200064.png
# OU seed=200057 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_132823/clean/diagnostic_plots/high_terminal_error_OU_seed200057.png
# OU seed=200049 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_132823/clean/diagnostic_plots/high_terminal_error_OU_seed200049.png
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=nominal_eval | noise_protocol=iid_noisy_ic | noise_budget=protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | scenarios=PRBS,CHIRP,OU | trajectories=90 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_132823/nominal_eval
# [scenario 1/3] PRBS | 30 trajectories
# [1/90] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=11m15.0s
# [5/90] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=2m09.1s
# [10/90] PRBS seed=51 done | reason=completed | sim_time=60.00s | eta=1m00.9s
# [15/90] PRBS seed=56 done | reason=completed | sim_time=60.00s | eta=38.1s
# [20/90] PRBS seed=61 done | reason=completed | sim_time=60.00s | eta=26.7s
# [25/90] PRBS seed=66 done | reason=completed | sim_time=60.00s | eta=19.9s
# [30/90] PRBS seed=71 done | reason=completed | sim_time=60.00s | eta=15.3s
# [scenario done] PRBS | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=4.7698 m | pos_p95=22.3272 m | rot_med=0.1130 rad | completion=1.000 | elapsed=7.7s
# [scenario 2/3] CHIRP | 30 trajectories
# [31/90] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=28.5s
# [35/90] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=23.5s
# [40/90] CHIRP seed=100051 done | reason=completed | sim_time=60.00s | eta=18.7s
# [45/90] CHIRP seed=100056 done | reason=completed | sim_time=60.00s | eta=15.0s
# [50/90] CHIRP seed=100061 done | reason=completed | sim_time=60.00s | eta=12.0s
# [55/90] CHIRP seed=100066 done | reason=completed | sim_time=60.00s | eta=9.6s
# [60/90] CHIRP seed=100071 done | reason=completed | sim_time=60.00s | eta=7.5s
# [scenario done] CHIRP | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=2.6725 m | pos_p95=8.1540 m | rot_med=0.0557 rad | completion=1.000 | elapsed=15.1s
# [scenario 3/3] OU | 30 trajectories
# [61/90] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=10.6s
# [65/90] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=8.6s
# [70/90] OU seed=200051 done | reason=completed | sim_time=60.00s | eta=6.4s
# [75/90] OU seed=200056 done | reason=completed | sim_time=60.00s | eta=4.5s
# [80/90] OU seed=200061 done | reason=completed | sim_time=60.00s | eta=2.8s
# [85/90] OU seed=200066 done | reason=pred_divergence | sim_time=55.75s | eta=1.3s
# [90/90] OU seed=200071 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=29/30 | gt_div=0 | model_fail=1 | H=60.0s cond_n=29/30 | pos_med=16.0766 m | pos_p95=28.9790 m | rot_med=0.4795 rad | completion=0.967 | elapsed=22.5s
# Benchmark finished in 40.8s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_132823/nominal_eval
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: SE(3) Acceleration Black-Box [baseline/core]
# Canonical model type: se3_accel_blackbox
# Energy semantics: not_comparable
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 30
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.5860 m | pos p95=1.8732 m | rot median=0.0624 rad | total vel median=0.0547 m/s | rel vel median=0.0510 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=1.8639 m | pos p95=9.1775 m | rot median=0.0728 rad | total vel median=0.0558 m/s | rel vel median=0.0465 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=5.5226 m | pos p95=26.7440 m | rot median=0.1259 rad | total vel median=0.0678 m/s | rel vel median=0.0466 m/s | cond_n=89/90 | completion=0.989 | gt_fail_by_h=0.000 | model_fail_by_h=0.011
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=90 | completed=89 (0.989) | gt_divergence=0 (0.000) | pred_divergence=1 (0.011) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.3671 m | pos p95=1.2278 m | rot median=0.0534 rad | total vel median=0.0558 m/s | rel vel median=0.0533 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.8317 m | pos p95=6.1959 m | rot median=0.0698 rad | total vel median=0.0613 m/s | rel vel median=0.0541 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=4.7698 m | pos p95=22.3272 m | rot median=0.1130 rad | total vel median=0.0802 m/s | rel vel median=0.0481 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.4834 m | pos p95=0.8845 m | rot median=0.0523 rad | total vel median=0.0392 m/s | rel vel median=0.0293 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.1317 m | pos p95=2.8246 m | rot median=0.0369 rad | total vel median=0.0364 m/s | rel vel median=0.0310 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=2.6725 m | pos p95=8.1540 m | rot median=0.0557 rad | total vel median=0.0400 m/s | rel vel median=0.0333 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=30 | completed=29 (0.967) | gt_divergence=0 (0.000) | pred_divergence=1 (0.033) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=1.0478 m | pos p95=2.6338 m | rot median=0.2046 rad | total vel median=0.0885 m/s | rel vel median=0.0729 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=4.2855 m | pos p95=10.9345 m | rot median=0.2605 rad | total vel median=0.0886 m/s | rel vel median=0.0667 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=16.0766 m | pos p95=28.9790 m | rot median=0.4795 rad | total vel median=0.1598 m/s | rel vel median=0.0839 m/s | cond_n=29/30 | completion=0.967 | gt_fail_by_h=0.000 | model_fail_by_h=0.033
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Earliest rollout failures
#   OU seed=200066 | reason=pred_divergence | sim_time=55.75s | pos=nan m | rot=nan rad | total_vel_violation=0
#
# Largest completed terminal errors
#   OU seed=200064 | reason=completed | sim_time=60.00s | pos=30.2454 m | rot=1.9826 rad | total_vel_violation=0
#   OU seed=200068 | reason=completed | sim_time=60.00s | pos=30.0903 m | rot=0.4975 rad | total_vel_violation=0
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=28.6384 m | rot=0.2439 rad | total_vel_violation=0
#   OU seed=200057 | reason=completed | sim_time=60.00s | pos=27.3120 m | rot=0.3929 rad | total_vel_violation=0
#   OU seed=200049 | reason=completed | sim_time=60.00s | pos=27.2604 m | rot=0.6711 rad | total_vel_violation=0
#
# Completed rollouts with velocity violations
#   OU seed=200062 | reason=completed | sim_time=60.00s | pos=10.7043 m | rot=0.4121 rad | total_vel_violation=1
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# OU seed=200066 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_132823/nominal_eval/diagnostic_plots/rollout_failure_OU_seed200066.png
# OU seed=200062 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_132823/nominal_eval/diagnostic_plots/velocity_violation_OU_seed200062.png
# OU seed=200064 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_132823/nominal_eval/diagnostic_plots/high_terminal_error_OU_seed200064.png
# OU seed=200068 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_132823/nominal_eval/diagnostic_plots/high_terminal_error_OU_seed200068.png
# PRBS seed=42 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_132823/nominal_eval/diagnostic_plots/high_terminal_error_PRBS_seed42.png
# OU seed=200057 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_132823/nominal_eval/diagnostic_plots/high_terminal_error_OU_seed200057.png
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=degraded_eval | noise_protocol=iid_noisy_ic | noise_budget=protocol=iid_noisy_ic | profile=degraded_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250] | scenarios=PRBS,CHIRP,OU | trajectories=90 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_132823/degraded_eval
# [scenario 1/3] PRBS | 30 trajectories
# [1/90] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=10m47.4s
# [5/90] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=2m03.9s
# [10/90] PRBS seed=51 done | reason=completed | sim_time=60.00s | eta=58.4s
# [15/90] PRBS seed=56 done | reason=completed | sim_time=60.00s | eta=36.6s
# [20/90] PRBS seed=61 done | reason=completed | sim_time=60.00s | eta=25.7s
# [25/90] PRBS seed=66 done | reason=completed | sim_time=60.00s | eta=19.1s
# [30/90] PRBS seed=71 done | reason=completed | sim_time=60.00s | eta=14.7s
# [scenario done] PRBS | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=5.8372 m | pos_p95=22.6384 m | rot_med=0.1233 rad | completion=1.000 | elapsed=7.4s
# [scenario 2/3] CHIRP | 30 trajectories
# [31/90] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=28.1s
# [35/90] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=23.2s
# [40/90] CHIRP seed=100051 done | reason=completed | sim_time=60.00s | eta=18.5s
# [45/90] CHIRP seed=100056 done | reason=completed | sim_time=60.00s | eta=14.8s
# [50/90] CHIRP seed=100061 done | reason=completed | sim_time=60.00s | eta=11.9s
# [55/90] CHIRP seed=100066 done | reason=completed | sim_time=60.00s | eta=9.4s
# [60/90] CHIRP seed=100071 done | reason=completed | sim_time=60.00s | eta=7.4s
# [scenario done] CHIRP | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=2.6682 m | pos_p95=9.1328 m | rot_med=0.0583 rad | completion=1.000 | elapsed=14.9s
# [scenario 3/3] OU | 30 trajectories
# [61/90] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=10.5s
# [65/90] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=8.5s
# [70/90] OU seed=200051 done | reason=completed | sim_time=60.00s | eta=6.3s
# [75/90] OU seed=200056 done | reason=completed | sim_time=60.00s | eta=4.4s
# [80/90] OU seed=200061 done | reason=completed | sim_time=60.00s | eta=2.8s
# [85/90] OU seed=200066 done | reason=pred_divergence | sim_time=55.75s | eta=1.3s
# [90/90] OU seed=200071 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=29/30 | gt_div=0 | model_fail=1 | H=60.0s cond_n=29/30 | pos_med=15.6142 m | pos_p95=29.2901 m | rot_med=0.4929 rad | completion=0.967 | elapsed=22.2s
# Benchmark finished in 40.4s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_132823/degraded_eval
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: SE(3) Acceleration Black-Box [baseline/core]
# Canonical model type: se3_accel_blackbox
# Energy semantics: not_comparable
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 30
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.6666 m | pos p95=2.1571 m | rot median=0.0670 rad | total vel median=0.0537 m/s | rel vel median=0.0509 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=2.0351 m | pos p95=9.4101 m | rot median=0.0812 rad | total vel median=0.0559 m/s | rel vel median=0.0465 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=6.1369 m | pos p95=25.9726 m | rot median=0.1461 rad | total vel median=0.0695 m/s | rel vel median=0.0466 m/s | cond_n=89/90 | completion=0.989 | gt_fail_by_h=0.000 | model_fail_by_h=0.011
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=90 | completed=89 (0.989) | gt_divergence=0 (0.000) | pred_divergence=1 (0.011) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.4322 m | pos p95=1.5052 m | rot median=0.0644 rad | total vel median=0.0553 m/s | rel vel median=0.0532 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.8848 m | pos p95=7.1025 m | rot median=0.0720 rad | total vel median=0.0654 m/s | rel vel median=0.0538 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=5.8372 m | pos p95=22.6384 m | rot median=0.1233 rad | total vel median=0.0817 m/s | rel vel median=0.0480 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.5871 m | pos p95=1.0599 m | rot median=0.0581 rad | total vel median=0.0393 m/s | rel vel median=0.0295 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.3949 m | pos p95=3.4521 m | rot median=0.0442 rad | total vel median=0.0372 m/s | rel vel median=0.0311 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=2.6682 m | pos p95=9.1328 m | rot median=0.0583 rad | total vel median=0.0393 m/s | rel vel median=0.0334 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=30 | completed=29 (0.967) | gt_divergence=0 (0.000) | pred_divergence=1 (0.033) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=1.1012 m | pos p95=2.6990 m | rot median=0.2054 rad | total vel median=0.0899 m/s | rel vel median=0.0729 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=4.3035 m | pos p95=10.0524 m | rot median=0.2606 rad | total vel median=0.0882 m/s | rel vel median=0.0668 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=15.6142 m | pos p95=29.2901 m | rot median=0.4929 rad | total vel median=0.1603 m/s | rel vel median=0.0839 m/s | cond_n=29/30 | completion=0.967 | gt_fail_by_h=0.000 | model_fail_by_h=0.033
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Earliest rollout failures
#   OU seed=200066 | reason=pred_divergence | sim_time=55.75s | pos=nan m | rot=nan rad | total_vel_violation=0
#
# Largest completed terminal errors
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=32.6248 m | rot=0.2735 rad | total_vel_violation=0
#   OU seed=200064 | reason=completed | sim_time=60.00s | pos=30.9574 m | rot=2.0017 rad | total_vel_violation=0
#   OU seed=200068 | reason=completed | sim_time=60.00s | pos=29.6874 m | rot=0.4934 rad | total_vel_violation=0
#   OU seed=200049 | reason=completed | sim_time=60.00s | pos=28.6941 m | rot=0.6938 rad | total_vel_violation=0
#   OU seed=200058 | reason=completed | sim_time=60.00s | pos=26.2691 m | rot=0.8513 rad | total_vel_violation=0
#
# Completed rollouts with velocity violations
#   OU seed=200062 | reason=completed | sim_time=60.00s | pos=10.9579 m | rot=0.4265 rad | total_vel_violation=1
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# OU seed=200066 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_132823/degraded_eval/diagnostic_plots/rollout_failure_OU_seed200066.png
# OU seed=200062 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_132823/degraded_eval/diagnostic_plots/velocity_violation_OU_seed200062.png
# PRBS seed=42 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_132823/degraded_eval/diagnostic_plots/high_terminal_error_PRBS_seed42.png
# OU seed=200064 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_132823/degraded_eval/diagnostic_plots/high_terminal_error_OU_seed200064.png
# OU seed=200068 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_132823/degraded_eval/diagnostic_plots/high_terminal_error_OU_seed200068.png
# OU seed=200049 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_132823/degraded_eval/diagnostic_plots/high_terminal_error_OU_seed200049.png
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=heading_biased_eval | noise_protocol=iid_noisy_ic | noise_budget=protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350] | scenarios=PRBS,CHIRP,OU | trajectories=90 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_132823/heading_biased_eval
# [scenario 1/3] PRBS | 30 trajectories
# [1/90] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=10m46.9s
# [5/90] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=2m03.8s
# [10/90] PRBS seed=51 done | reason=completed | sim_time=60.00s | eta=58.4s
# [15/90] PRBS seed=56 done | reason=completed | sim_time=60.00s | eta=36.6s
# [20/90] PRBS seed=61 done | reason=completed | sim_time=60.00s | eta=25.7s
# [25/90] PRBS seed=66 done | reason=completed | sim_time=60.00s | eta=19.1s
# [30/90] PRBS seed=71 done | reason=completed | sim_time=60.00s | eta=14.7s
# [scenario done] PRBS | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=7.0861 m | pos_p95=20.1571 m | rot_med=0.1378 rad | completion=1.000 | elapsed=7.4s
# [scenario 2/3] CHIRP | 30 trajectories
# [31/90] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=27.9s
# [35/90] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=23.1s
# [40/90] CHIRP seed=100051 done | reason=completed | sim_time=60.00s | eta=18.4s
# [45/90] CHIRP seed=100056 done | reason=completed | sim_time=60.00s | eta=14.7s
# [50/90] CHIRP seed=100061 done | reason=completed | sim_time=60.00s | eta=11.8s
# [55/90] CHIRP seed=100066 done | reason=completed | sim_time=60.00s | eta=9.4s
# [60/90] CHIRP seed=100071 done | reason=completed | sim_time=60.00s | eta=7.4s
# [scenario done] CHIRP | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=3.7329 m | pos_p95=7.0682 m | rot_med=0.0701 rad | completion=1.000 | elapsed=14.8s
# [scenario 3/3] OU | 30 trajectories
# [61/90] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=10.5s
# [65/90] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=8.5s
# [70/90] OU seed=200051 done | reason=completed | sim_time=60.00s | eta=6.3s
# [75/90] OU seed=200056 done | reason=completed | sim_time=60.00s | eta=4.4s
# [80/90] OU seed=200061 done | reason=completed | sim_time=60.00s | eta=2.8s
# [85/90] OU seed=200066 done | reason=pred_divergence | sim_time=55.75s | eta=1.3s
# [90/90] OU seed=200071 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=29/30 | gt_div=0 | model_fail=1 | H=60.0s cond_n=29/30 | pos_med=13.4409 m | pos_p95=29.2095 m | rot_med=0.4468 rad | completion=0.967 | elapsed=22.2s
# Benchmark finished in 40.0s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_132823/heading_biased_eval
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: SE(3) Acceleration Black-Box [baseline/core]
# Canonical model type: se3_accel_blackbox
# Energy semantics: not_comparable
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 30
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.7430 m | pos p95=2.2214 m | rot median=0.0767 rad | total vel median=0.0579 m/s | rel vel median=0.0503 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=2.4784 m | pos p95=9.4514 m | rot median=0.0899 rad | total vel median=0.0576 m/s | rel vel median=0.0467 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=6.4674 m | pos p95=25.0173 m | rot median=0.1375 rad | total vel median=0.0688 m/s | rel vel median=0.0465 m/s | cond_n=89/90 | completion=0.989 | gt_fail_by_h=0.000 | model_fail_by_h=0.011
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=90 | completed=89 (0.989) | gt_divergence=0 (0.000) | pred_divergence=1 (0.011) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.5917 m | pos p95=1.0268 m | rot median=0.0758 rad | total vel median=0.0580 m/s | rel vel median=0.0534 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=2.5072 m | pos p95=6.5580 m | rot median=0.1007 rad | total vel median=0.0619 m/s | rel vel median=0.0542 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=7.0861 m | pos p95=20.1571 m | rot median=0.1378 rad | total vel median=0.0724 m/s | rel vel median=0.0482 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.7344 m | pos p95=0.9954 m | rot median=0.0474 rad | total vel median=0.0376 m/s | rel vel median=0.0294 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.6617 m | pos p95=2.9907 m | rot median=0.0556 rad | total vel median=0.0347 m/s | rel vel median=0.0311 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=3.7329 m | pos p95=7.0682 m | rot median=0.0701 rad | total vel median=0.0419 m/s | rel vel median=0.0333 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=30 | completed=29 (0.967) | gt_divergence=0 (0.000) | pred_divergence=1 (0.033) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=1.1744 m | pos p95=2.8860 m | rot median=0.2012 rad | total vel median=0.0930 m/s | rel vel median=0.0728 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=3.9851 m | pos p95=10.1722 m | rot median=0.2299 rad | total vel median=0.0849 m/s | rel vel median=0.0671 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=13.4409 m | pos p95=29.2095 m | rot median=0.4468 rad | total vel median=0.1637 m/s | rel vel median=0.0835 m/s | cond_n=29/30 | completion=0.967 | gt_fail_by_h=0.000 | model_fail_by_h=0.033
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Earliest rollout failures
#   OU seed=200066 | reason=pred_divergence | sim_time=55.75s | pos=nan m | rot=nan rad | total_vel_violation=0
#
# Largest completed terminal errors
#   OU seed=200068 | reason=completed | sim_time=60.00s | pos=32.9974 m | rot=0.5271 rad | total_vel_violation=0
#   OU seed=200064 | reason=completed | sim_time=60.00s | pos=31.4383 m | rot=2.0145 rad | total_vel_violation=0
#   OU seed=200055 | reason=completed | sim_time=60.00s | pos=25.8664 m | rot=0.5919 rad | total_vel_violation=0
#   OU seed=200050 | reason=completed | sim_time=60.00s | pos=25.7351 m | rot=0.8055 rad | total_vel_violation=0
#   OU seed=200049 | reason=completed | sim_time=60.00s | pos=25.1485 m | rot=0.6367 rad | total_vel_violation=0
#
# Completed rollouts with velocity violations
#   OU seed=200062 | reason=completed | sim_time=60.00s | pos=11.0345 m | rot=0.4282 rad | total_vel_violation=1
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# OU seed=200066 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_132823/heading_biased_eval/diagnostic_plots/rollout_failure_OU_seed200066.png
# OU seed=200062 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_132823/heading_biased_eval/diagnostic_plots/velocity_violation_OU_seed200062.png
# OU seed=200068 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_132823/heading_biased_eval/diagnostic_plots/high_terminal_error_OU_seed200068.png
# OU seed=200064 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_132823/heading_biased_eval/diagnostic_plots/high_terminal_error_OU_seed200064.png
# OU seed=200055 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_132823/heading_biased_eval/diagnostic_plots/high_terminal_error_OU_seed200055.png
# OU seed=200050 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_132823/heading_biased_eval/diagnostic_plots/high_terminal_error_OU_seed200050.png
# [eval] baseline_se3_accel_blackbox_seed43
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed43/best_model.pt | device=cuda | mode=resampled | noise_profile=clean | noise_protocol=clean | noise_budget=protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000] | scenarios=PRBS,CHIRP,OU | trajectories=90 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed43/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_134109/clean
# [scenario 1/3] PRBS | 30 trajectories
# [1/90] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=5h07m26.1s
# [5/90] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=58m43.6s
# [10/90] PRBS seed=51 done | reason=completed | sim_time=60.00s | eta=27m38.3s
# [15/90] PRBS seed=56 done | reason=completed | sim_time=60.00s | eta=17m16.5s
# [20/90] PRBS seed=61 done | reason=completed | sim_time=60.00s | eta=12m05.6s
# [25/90] PRBS seed=66 done | reason=completed | sim_time=60.00s | eta=8m59.1s
# [30/90] PRBS seed=71 done | reason=completed | sim_time=60.00s | eta=6m54.7s
# [scenario done] PRBS | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=1.7043 m | pos_p95=4.1931 m | rot_med=0.0365 rad | completion=1.000 | elapsed=3m27.4s
# [scenario 2/3] CHIRP | 30 trajectories
# [31/90] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=13m10.1s
# [35/90] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=10m52.4s
# [40/90] CHIRP seed=100051 done | reason=completed | sim_time=60.00s | eta=8m39.0s
# [45/90] CHIRP seed=100056 done | reason=completed | sim_time=60.00s | eta=6m55.2s
# [50/90] CHIRP seed=100061 done | reason=completed | sim_time=60.00s | eta=5m32.2s
# [55/90] CHIRP seed=100066 done | reason=completed | sim_time=60.00s | eta=4m24.2s
# [60/90] CHIRP seed=100071 done | reason=completed | sim_time=60.00s | eta=3m27.6s
# [scenario done] CHIRP | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=1.2051 m | pos_p95=2.8933 m | rot_med=0.0251 rad | completion=1.000 | elapsed=6m55.3s
# [scenario 3/3] OU | 30 trajectories
# ...
#   H=10.0s | pos median=0.1643 m | pos p95=0.3428 m | rot median=0.0146 rad | total vel median=0.0130 m/s | rel vel median=0.0108 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.6062 m | pos p95=1.2768 m | rot median=0.0236 rad | total vel median=0.0145 m/s | rel vel median=0.0134 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.6303 m | pos p95=3.5048 m | rot median=0.0427 rad | total vel median=0.0153 m/s | rel vel median=0.0115 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=30 | completed=29 (0.967) | gt_divergence=0 (0.000) | pred_divergence=1 (0.033) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.2696 m | pos p95=0.4587 m | rot median=0.0213 rad | total vel median=0.0194 m/s | rel vel median=0.0193 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.7356 m | pos p95=1.7752 m | rot median=0.0279 rad | total vel median=0.0267 m/s | rel vel median=0.0266 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.8396 m | pos p95=4.8546 m | rot median=0.0518 rad | total vel median=0.0401 m/s | rel vel median=0.0338 m/s | cond_n=29/30 | completion=0.967 | gt_fail_by_h=0.000 | model_fail_by_h=0.033
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Earliest rollout failures
#   OU seed=200066 | reason=pred_divergence | sim_time=58.95s | pos=nan m | rot=nan rad | total_vel_violation=0
#
# Largest completed terminal errors
#   OU seed=200045 | reason=completed | sim_time=60.00s | pos=6.5627 m | rot=0.1020 rad | total_vel_violation=0
#   OU seed=200050 | reason=completed | sim_time=60.00s | pos=5.1496 m | rot=0.1619 rad | total_vel_violation=0
#   CHIRP seed=100048 | reason=completed | sim_time=60.00s | pos=4.4712 m | rot=0.0786 rad | total_vel_violation=0
#   OU seed=200047 | reason=completed | sim_time=60.00s | pos=4.4121 m | rot=0.0821 rad | total_vel_violation=0
#   PRBS seed=62 | reason=completed | sim_time=60.00s | pos=4.3846 m | rot=0.0490 rad | total_vel_violation=0
#
# Completed rollouts with velocity violations
#   OU seed=200061 | reason=completed | sim_time=60.00s | pos=2.9952 m | rot=0.0145 rad | total_vel_violation=1
#   OU seed=200055 | reason=completed | sim_time=60.00s | pos=1.3862 m | rot=0.0480 rad | total_vel_violation=1
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# OU seed=200066 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed45/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260525_143507/diagnostic_plots/rollout_failure_OU_seed200066.png
# OU seed=200061 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed45/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260525_143507/diagnostic_plots/velocity_violation_OU_seed200061.png
# OU seed=200055 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed45/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260525_143507/diagnostic_plots/velocity_violation_OU_seed200055.png
# OU seed=200045 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed45/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260525_143507/diagnostic_plots/high_terminal_error_OU_seed200045.png
# OU seed=200050 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed45/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260525_143507/diagnostic_plots/high_terminal_error_OU_seed200050.png
# CHIRP seed=100048 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed45/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260525_143507/diagnostic_plots/high_terminal_error_CHIRP_seed100048.png
# [eval] baseline_se3_accel_blackbox_seed46
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed46/best_model.pt | device=cuda | mode=resampled | noise_profile=nominal_eval | noise_protocol=v4_lite | noise_budget=protocol=v4_lite | profile=nominal_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | scenarios=PRBS,CHIRP,OU | trajectories=90 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260525_143552
# [scenario 1/3] PRBS | 30 trajectories
# [1/90] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=11m22.4s
# [5/90] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=2m10.6s
# [10/90] PRBS seed=51 done | reason=completed | sim_time=60.00s | eta=1m01.6s
# [15/90] PRBS seed=56 done | reason=completed | sim_time=60.00s | eta=38.5s
# [20/90] PRBS seed=61 done | reason=completed | sim_time=60.00s | eta=27.0s
# [25/90] PRBS seed=66 done | reason=completed | sim_time=60.00s | eta=20.1s
# [30/90] PRBS seed=71 done | reason=completed | sim_time=60.00s | eta=15.5s
# [scenario done] PRBS | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=1.1129 m | pos_p95=3.1812 m | rot_med=0.0195 rad | completion=1.000 | elapsed=7.8s
# [scenario 2/3] CHIRP | 30 trajectories
# [31/90] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=28.6s
# [35/90] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=23.6s
# [40/90] CHIRP seed=100051 done | reason=completed | sim_time=60.00s | eta=18.8s
# [45/90] CHIRP seed=100056 done | reason=completed | sim_time=60.00s | eta=15.1s
# [50/90] CHIRP seed=100061 done | reason=completed | sim_time=60.00s | eta=12.1s
# [55/90] CHIRP seed=100066 done | reason=completed | sim_time=60.00s | eta=9.6s
# [60/90] CHIRP seed=100071 done | reason=completed | sim_time=60.00s | eta=7.6s
# [scenario done] CHIRP | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=0.9685 m | pos_p95=2.7530 m | rot_med=0.0126 rad | completion=1.000 | elapsed=15.1s
# [scenario 3/3] OU | 30 trajectories
# [61/90] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=10.6s
# [65/90] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=8.6s
# [70/90] OU seed=200051 done | reason=pred_divergence | sim_time=42.95s | eta=6.4s
# [75/90] OU seed=200056 done | reason=completed | sim_time=60.00s | eta=4.5s
# [80/90] OU seed=200061 done | reason=completed | sim_time=60.00s | eta=2.8s
# [85/90] OU seed=200066 done | reason=completed | sim_time=60.00s | eta=1.3s
# [90/90] OU seed=200071 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=29/30 | gt_div=0 | model_fail=1 | H=60.0s cond_n=29/30 | pos_med=1.7812 m | pos_p95=5.1167 m | rot_med=0.0427 rad | completion=0.967 | elapsed=22.5s
# Benchmark finished in 41.1s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260525_143552
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed46/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: SE(3) Acceleration Black-Box [baseline/core]
# Canonical model type: se3_accel_blackbox
# Energy semantics: not_comparable
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 30
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.1774 m | pos p95=0.3536 m | rot median=0.0130 rad | total vel median=0.0151 m/s | rel vel median=0.0141 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=0.5732 m | pos p95=1.5032 m | rot median=0.0167 rad | total vel median=0.0139 m/s | rel vel median=0.0135 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=1.2138 m | pos p95=3.7359 m | rot median=0.0206 rad | total vel median=0.0144 m/s | rel vel median=0.0156 m/s | cond_n=89/90 | completion=0.989 | gt_fail_by_h=0.000 | model_fail_by_h=0.011
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=90 | completed=89 (0.989) | gt_divergence=0 (0.000) | pred_divergence=1 (0.011) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.2180 m | pos p95=0.3590 m | rot median=0.0104 rad | total vel median=0.0176 m/s | rel vel median=0.0180 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.5210 m | pos p95=0.9823 m | rot median=0.0150 rad | total vel median=0.0159 m/s | rel vel median=0.0155 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.1129 m | pos p95=3.1812 m | rot median=0.0195 rad | total vel median=0.0226 m/s | rel vel median=0.0206 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1490 m | pos p95=0.3547 m | rot median=0.0113 rad | total vel median=0.0123 m/s | rel vel median=0.0110 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.4714 m | pos p95=1.2060 m | rot median=0.0160 rad | total vel median=0.0101 m/s | rel vel median=0.0081 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=0.9685 m | pos p95=2.7530 m | rot median=0.0126 rad | total vel median=0.0107 m/s | rel vel median=0.0105 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=30 | completed=29 (0.967) | gt_divergence=0 (0.000) | pred_divergence=1 (0.033) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1985 m | pos p95=0.3374 m | rot median=0.0151 rad | total vel median=0.0184 m/s | rel vel median=0.0172 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.6645 m | pos p95=1.9274 m | rot median=0.0294 rad | total vel median=0.0165 m/s | rel vel median=0.0146 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.7812 m | pos p95=5.1167 m | rot median=0.0427 rad | total vel median=0.0270 m/s | rel vel median=0.0239 m/s | cond_n=29/30 | completion=0.967 | gt_fail_by_h=0.000 | model_fail_by_h=0.033
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Earliest rollout failures
#   OU seed=200051 | reason=pred_divergence | sim_time=42.95s | pos=nan m | rot=nan rad | total_vel_violation=0
#
# Largest completed terminal errors
#   OU seed=200048 | reason=completed | sim_time=60.00s | pos=6.9268 m | rot=0.1648 rad | total_vel_violation=0
#   OU seed=200061 | reason=completed | sim_time=60.00s | pos=5.3457 m | rot=0.0759 rad | total_vel_violation=1
#   OU seed=200068 | reason=completed | sim_time=60.00s | pos=4.7731 m | rot=0.0582 rad | total_vel_violation=1
#   OU seed=200070 | reason=completed | sim_time=60.00s | pos=4.5560 m | rot=0.0944 rad | total_vel_violation=0
#   PRBS seed=46 | reason=completed | sim_time=60.00s | pos=3.9552 m | rot=0.0849 rad | total_vel_violation=0
#
# Completed rollouts with velocity violations
#   OU seed=200061 | reason=completed | sim_time=60.00s | pos=5.3457 m | rot=0.0759 rad | total_vel_violation=1
#   OU seed=200068 | reason=completed | sim_time=60.00s | pos=4.7731 m | rot=0.0582 rad | total_vel_violation=1
#   OU seed=200053 | reason=completed | sim_time=60.00s | pos=2.6547 m | rot=0.0422 rad | total_vel_violation=1
#   OU seed=200055 | reason=completed | sim_time=60.00s | pos=2.3570 m | rot=0.0526 rad | total_vel_violation=1
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# OU seed=200051 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260525_143552/diagnostic_plots/rollout_failure_OU_seed200051.png
# OU seed=200061 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260525_143552/diagnostic_plots/velocity_violation_OU_seed200061.png
# OU seed=200068 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260525_143552/diagnostic_plots/velocity_violation_OU_seed200068.png
# OU seed=200053 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260525_143552/diagnostic_plots/velocity_violation_OU_seed200053.png
# OU seed=200055 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260525_143552/diagnostic_plots/velocity_violation_OU_seed200055.png
# OU seed=200048 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_accel_blackbox/baseline_se3_accel_blackbox_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260525_143552/diagnostic_plots/high_terminal_error_OU_seed200048.png
# Batch evaluation complete.

# %% [markdown]
# ## 5. Provenance injection (per-run `_audit_meta/`)
# Records git HEAD + environment fingerprint into every decision run dir so these runs are distinguishable from catalog-era drift.

# %%
# Inject per-run provenance. The training flow does NOT write these automatically,
# so for paper-grade evidence we record them here (see docs/provenance_audit_phnode_full_clean.md sec 5.2).
import os, sys, subprocess, datetime
from pathlib import Path
import torch

RUN_TAG = os.environ["RUN_TAG"]
ckpt = PROJECT_DIR / "checkpoints"
# clean-only sweep: only the clean suite exists, but we scan the full triple defensively.
suites = [ckpt / f"sweep_oc_phase1a_decision_{p}_{RUN_TAG}" for p in ("clean", "iid", "v4lite")]

def _sh(args):
    try:
        return subprocess.run(args, cwd=PROJECT_DIR, capture_output=True, text=True).stdout.strip()
    except Exception as exc:  # noqa: BLE001
        return f"<unavailable: {exc}>"

head = _sh(["git", "rev-parse", "HEAD"])
diffstat = _sh(["git", "diff", "HEAD", "--stat"])
env_txt = "\n".join([
    f"python={sys.version.split()[0]}",
    f"torch={torch.__version__}",
    f"cuda={torch.version.cuda}",
    f"cudnn={torch.backends.cudnn.version()}",
    f"gpu={torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'cpu'}",
    f"captured_at={datetime.datetime.now().isoformat()}",
])

n = 0
for suite in suites:
    if not suite.exists():
        continue
    for cfg in suite.rglob("config.json"):
        run_dir = cfg.parent
        meta = run_dir / "_audit_meta"
        meta.mkdir(exist_ok=True)
        (meta / "code_revision.txt").write_text(f"git_head={head}\n\n{diffstat}\n")
        (meta / "environment.txt").write_text(env_txt + "\n")
        n += 1
print(f"provenance written for {n} run dirs")
print("git_head =", head)
# Out:
# provenance written for 5 run dirs
# git_head =

# %% [markdown]
# ## 6. Anomaly scan
# Flags any run with the `no successful training batches` catastrophic-gradient signature. For black-box models a clean-mirror collapse is a legitimate instability result — flag and handle per B1 (exclude from the quantitative aggregate, annotate).

# %%
# Quick anomaly scan: catch seed46/seed43-style catastrophic training before trusting numbers.
# Black-box models are collapse-prone (blackbox_fullstate collapsed in the 2026-04 catalog:
# s44=86.8m, s42/s43=nan), so a clean-mirror collapse here is a LEGITIMATE black-box instability
# finding, not an artifact -- still flag it and handle per the B1 policy (exclude from the
# quantitative aggregate, annotate transparently).
import os, re
from pathlib import Path

RUN_TAG = os.environ["RUN_TAG"]
ckpt = PROJECT_DIR / "checkpoints"
suites = [ckpt / f"sweep_oc_phase1a_decision_{p}_{RUN_TAG}" for p in ("clean", "iid", "v4lite")]

print(f"{'suite':<48}{'run':<32}{'best_epoch':>10}{'best_loss':>14}{'nbad':>6}  flag")
for suite in suites:
    if not suite.exists():
        continue
    for cfg in sorted(suite.rglob("config.json")):
        run_dir = cfg.parent
        log = run_dir / "training.log"
        text = log.read_text() if log.exists() else ""
        nbad = text.count("no successful training batches")
        best_epoch, best_loss = "?", "?"
        m = re.findall(r"[Bb]est.*?epoch[^0-9]*([0-9]+).*?([0-9]+\.[0-9eE+-]+)", text)
        if m:
            best_epoch, best_loss = m[-1]
        flag = "  <-- CHECK (possible artifact / instability)" if nbad > 0 else ""
        print(f"{suite.name[:46]:<48}{run_dir.name[:30]:<32}{str(best_epoch):>10}{str(best_loss):>14}{nbad:>6}{flag}")
print("\nFlagged seeds: handle per B1 (exclude from aggregate via train_anomaly, annotate).")
# Out:
# suite                                           run                             best_epoch     best_loss  nbad  flag
# sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_  baseline_se3_accel_blackbox_se           ?             ?     0
# sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_  baseline_se3_accel_blackbox_se           ?             ?     0
# sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_  baseline_se3_accel_blackbox_se           ?             ?     0
# sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_  baseline_se3_accel_blackbox_se           ?             ?     0
# sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_  baseline_se3_accel_blackbox_se           ?             ?     0
#
# Flagged seeds: handle per B1 (exclude from aggregate via train_anomaly, annotate).

# %% [markdown]
# ## 7. Next step (after all three black-box notebooks finish)
# 1. Ensure `checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_{blackbox_fullstate,se3_momentum_blackbox,se3_accel_blackbox}` are synced back.
# 2. Locally rerun `python scripts/export_section8_t2_evidence.py` (black-box models are already in MODELS).
# 3. The clean rows append to `analysis/section8_current_evidence/aggregate.csv` for the §8 structured-vs-black-box table.
# 4. No shared-catalog rebuild is needed — the export reads the decision suites directly.
