# %% [markdown]
# # Black-box current-evidence rerun (clean-only) — `blackbox_fullstate`
#
# **Goal.** Regenerate a black-box / semi-structured baseline on the current-main
# (`g3_5_7` mirror) regime so the chapter-section-8 "structured >> black-box" claim has a
# clean-mirror anchor directly comparable to the four T2 models. Catalog-era black-box numbers
# come from the 2026-04 `sweep_oc_core_default_*` suite — a different regime that collapsed
# `phnode_full` on 3/6 clean seeds and flipped `phnode_qforce` clean 0.57<->3.76, so they
# cannot be cross-compared with T2.
#
# **Matrix (this notebook).** `blackbox_fullstate` x {clean} x seeds {42,43,44,45,46} = 5 training
# runs (clean-only via `PHASE1A_PROTOCOLS=clean`), then the clean suite is evaluated across
# {clean, nominal_eval, degraded_eval, heading_biased_eval} under iid_noisy_ic + v4_lite eval
# protocols — identical to the eval the T2 clean suites received.
#
# **Parallelism.** Run the three black-box notebooks (`blackbox_fullstate`,
# `se3_momentum_blackbox`, `se3_accel_blackbox`) in separate Colab sessions. Distinct
# `RUN_TAG`s, no collision.
#
# **After all three finish:** sync `checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_*`
# back, then locally rerun `scripts/export_section8_t2_evidence.py` — the black-box models are
# already in its MODELS list, so the clean rows append to `aggregate.csv` automatically.
#
# > Watch list: black-box models are collapse-prone (`blackbox_fullstate` was nan/86.8m in the
# > old catalog). The anomaly-scan cell flags any clean-mirror collapse; a real collapse is a
# > legitimate instability finding (handle per B1: exclude from aggregate, annotate).

# %%
# !nvidia-smi
# Out:
# Mon May 25 11:40:35 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   67C    P8             16W /   72W |       0MiB /  23034MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import torch
print(f"PyTorch: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"CUDA: {torch.version.cuda}")
print(f"cuDNN: {torch.backends.cudnn.version()}")
# Out:
# PyTorch: 2.10.0+cu128
# CUDA available: True
# CUDA: 12.8
# cuDNN: 91002

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
from pathlib import Path

PROJECT_DIR = Path(os.environ.get(
    "AUV_PROJECT_DIR",
    "/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7",
))
assert PROJECT_DIR.exists(), f"Project directory not found: {PROJECT_DIR}"
# %cd $PROJECT_DIR
# Out:
# /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7

# %%
# %pip install -q torchdiffeq pandas

# %% [markdown]
# ## 0. Configuration

# %%
import os

# Runtime
os.environ["PYTHON_BIN"] = "python"
os.environ["DEVICE"] = "cuda"
os.environ["LOCAL_PROXY_ROOT"] = "/content/_proxy_suites"

# ---- identity (one black-box model per notebook) ----
os.environ["RUN_TAG"] = "t2_wpfrag_blackbox_fullstate"
os.environ["DATASET"] = "data/auv_oc_traj1000_blk150_s23_d0be9434.pkl"
os.environ["NOISE_REFERENCE"] = "remus100_dr"
os.environ["PHASE1A_LOG_DIR"] = str(PROJECT_DIR / "checkpoints" / "phase1a_logs" / os.environ["RUN_TAG"])
os.environ["PHASE1A_METADATA_DIR"] = str(PROJECT_DIR / "checkpoints" / f"phase1a_metadata_{os.environ['RUN_TAG']}")

# ---- matrix: single black-box model x CLEAN-ONLY x 5 seeds ----
os.environ["PHASE1A_MODELS"] = "blackbox_fullstate"
os.environ["SMOKE1_MODELS"] = "blackbox_fullstate"
os.environ["PHASE1A_PROTOCOLS"] = "clean"        # clean-only knob (driver default is "clean iid v4lite")
os.environ["SMOKE_SEEDS"] = "42"                 # cheap protocol-correctness gate (1 seed)
os.environ["DECISION_SEEDS"] = "42 43 44 45 46"  # full current-evidence seed set (matches T2)

# ---- Evaluation contract (identical to T2 clean suite) ----
os.environ["SMOKE_EVAL_NUM_TRAJ_PER_SCENARIO"] = "6"
os.environ["DECISION_EVAL_NUM_TRAJ_PER_SCENARIO"] = "30"
os.environ["EVAL_TIMES"] = "10 30 60"
os.environ["EVAL_SCENARIOS"] = "PRBS CHIRP OU"
os.environ["EVAL_BASE_SEED"] = "42"
os.environ["EVAL_NOISE_SEED"] = "2024"
os.environ["EVAL_PROGRESS_EVERY"] = "5"
os.environ["EVAL_NUM_DIAGNOSTIC_PLOTS"] = "6"
# Full robustness set: evaluate the clean-trained suite across all 4 profiles (caveat B).
os.environ["IID_EVAL_PROFILES"] = "clean nominal_eval degraded_eval heading_biased_eval"
os.environ["V4_EVAL_PROFILES"] = "nominal_eval"

# ---- Audit gate ----
os.environ["STRICT_ZERO_NOISE_AUDIT"] = "1"
os.environ["SOFT_MIN_EPOCH_SCALE"] = "0.05"

print("RUN_TAG          =", os.environ["RUN_TAG"])
print("PHASE1A_MODELS   =", os.environ["PHASE1A_MODELS"])
print("PHASE1A_PROTOCOLS=", os.environ["PHASE1A_PROTOCOLS"])
print("DECISION_SEEDS   =", os.environ["DECISION_SEEDS"])
print("IID_EVAL_PROFILES=", os.environ["IID_EVAL_PROFILES"])
# Out:
# RUN_TAG          = t2_wpfrag_blackbox_fullstate
# PHASE1A_MODELS   = blackbox_fullstate
# PHASE1A_PROTOCOLS= clean
# DECISION_SEEDS   = 42 43 44 45 46
# IID_EVAL_PROFILES= clean nominal_eval degraded_eval heading_biased_eval

# %% [markdown]
# ## 1. Preflight
# Confirms target suite/proxy dirs are absent and saves suite-level run config + environment metadata. If it fails, change `RUN_TAG` or remove the target dirs.

# %%
os.environ["MODE"] = "preflight"
# !bash scripts/run_phase1a_oc_v4lite.sh
# Out:
# [phase1a]
# MODE=preflight
# RUN_TAG=t2_wpfrag_blackbox_fullstate
# DATASET=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# DEVICE=cuda
# PHASE1A_MODELS=blackbox_fullstate
# PHASE1A_PROTOCOLS=clean
# SMOKE1_MODELS=blackbox_fullstate
# SMOKE_SEEDS=42
# DECISION_SEEDS=42 43 44 45 46
# NOISE_REFERENCE=remus100_dr
# PHASE1A_LOG_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_logs/t2_wpfrag_blackbox_fullstate
# PHASE1A_METADATA_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_metadata_t2_wpfrag_blackbox_fullstate
# Preflight passed: all Phase-1A target suite/proxy directories are absent.
# [metadata] /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_metadata_t2_wpfrag_blackbox_fullstate

# %% [markdown]
# ## 2. Smoke gate (seed 42, clean only)
# Cheap protocol-correctness check for the clean path + strict zero-noise audit. Smoke results are flow-validation only — never cited.

# %%
os.environ["MODE"] = "smoke1_train"
# !bash scripts/run_phase1a_oc_v4lite.sh
# Out:
# [phase1a]
# MODE=smoke1_train
# RUN_TAG=t2_wpfrag_blackbox_fullstate
# DATASET=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# DEVICE=cuda
# PHASE1A_MODELS=blackbox_fullstate
# PHASE1A_PROTOCOLS=clean
# SMOKE1_MODELS=blackbox_fullstate
# SMOKE_SEEDS=42
# DECISION_SEEDS=42 43 44 45 46
# NOISE_REFERENCE=remus100_dr
# PHASE1A_LOG_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_logs/t2_wpfrag_blackbox_fullstate
# PHASE1A_METADATA_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_metadata_t2_wpfrag_blackbox_fullstate
# [train] suite=sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate models=blackbox_fullstate seeds=42 protocol=auto
# Training all models with profile-based noisy IC.
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Group: all
# Explicit models: blackbox_fullstate
# Seeds: 42
# Noise config: protocol=auto, profile=clean, scale=1.0, warmup=20, ramp=80, mix_ratio=0.5
# Auto-eval profiles: block=[clean nominal_eval heading_biased_eval] heldout=[clean nominal_eval degraded_eval heading_biased_eval]
# Suite directory: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Models (1): blackbox_fullstate
# Seeds: 42
# [train] baseline_blackbox_fullstate_seed42
# Loading dataset...
# Loaded: 83850 train, 21000 test, t_eval=[0.   0.05 0.1  0.15 0.2 ]
# Dataset split: trajectory | train trajectories: 559 | test trajectories: 140
# Dataset ID: d0be9434
# Dataset path: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl | velocity convention: body_total | state dim: 27
# Position std: [0.1508, 0.1400, 0.0370]
# Velocity std: u=0.4722, v=0.0898, w=0.0718, p=0.0248, q=0.0906, r=0.0526
# Actuator std: a0=0.1543, a1=0.1555, a2=299.0037
# Training noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# Model: Full-State Black-Box [baseline/core] | canonical type: blackbox_fullstate
# Model parameters: 61,538
# Training dataset: id=d0be9434 | path=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Mass matrix initialized from physics
# Training: epochs<=300, target_steps=5000, warmup_steps=400, lr=6.00e-03 -> 1.00e-04, solver=rk4, so3_reg=1.00e-03
# Train samples: 83850, Test samples: 21000
# Epoch    1 | Step    20/ 5000 | Train 1.4444e+00 | Test 1.5934e+00 | SO3(train/test) 7.32e-04/3.56e-03 | Fail(train/test) 0/0 | LR 4.10e-04 | 5.5s
# Epoch    2 | Step    40/ 5000 | Train 1.3100e+00 | Test 1.1446e+00 | SO3(train/test) 3.25e-02/1.21e-01 | Fail(train/test) 0/0 | LR 7.05e-04 | 3.6s
# Epoch    3 | Step    60/ 5000 | Train 7.2322e-01 | Test 5.5477e-01 | SO3(train/test) 3.20e-01/3.20e-01 | Fail(train/test) 0/0 | LR 1.00e-03 | 3.8s
# Epoch    4 | Step    80/ 5000 | Train 5.1359e-01 | Test 4.7452e-01 | SO3(train/test) 2.21e-01/1.89e-01 | Fail(train/test) 0/0 | LR 1.29e-03 | 3.6s
# Epoch    5 | Step   100/ 5000 | Train 4.7443e-01 | Test 4.5579e-01 | SO3(train/test) 1.56e-01/1.25e-01 | Fail(train/test) 0/0 | LR 1.59e-03 | 3.6s
# Epoch    6 | Step   120/ 5000 | Train 4.5461e-01 | Test 4.4526e-01 | SO3(train/test) 1.06e-01/8.04e-02 | Fail(train/test) 0/0 | LR 1.88e-03 | 3.6s
# Epoch    7 | Step   140/ 5000 | Train 4.2799e-01 | Test 4.1170e-01 | SO3(train/test) 6.45e-02/5.04e-02 | Fail(train/test) 0/0 | LR 2.18e-03 | 3.6s
# Epoch    8 | Step   160/ 5000 | Train 3.9827e-01 | Test 4.1198e-01 | SO3(train/test) 4.24e-02/4.01e-02 | Fail(train/test) 0/0 | LR 2.47e-03 | 3.7s
# Epoch    9 | Step   180/ 5000 | Train 3.8250e-01 | Test 3.9993e-01 | SO3(train/test) 4.61e-02/5.74e-02 | Fail(train/test) 0/0 | LR 2.77e-03 | 3.6s
# Epoch   10 | Step   200/ 5000 | Train 3.7293e-01 | Test 3.7030e-01 | SO3(train/test) 7.28e-02/9.11e-02 | Fail(train/test) 0/0 | LR 3.06e-03 | 3.7s
# Epoch   11 | Step   220/ 5000 | Train 4.1388e-01 | Test 3.6501e-01 | SO3(train/test) 1.10e-01/1.41e-01 | Fail(train/test) 0/0 | LR 3.36e-03 | 3.6s
# Epoch   12 | Step   240/ 5000 | Train 3.6859e-01 | Test 3.3968e-01 | SO3(train/test) 1.67e-01/1.92e-01 | Fail(train/test) 0/0 | LR 3.65e-03 | 3.6s
# Epoch   13 | Step   260/ 5000 | Train 3.6392e-01 | Test 3.2150e-01 | SO3(train/test) 2.08e-01/2.28e-01 | Fail(train/test) 0/0 | LR 3.95e-03 | 3.7s
# Epoch   14 | Step   280/ 5000 | Train 3.4430e-01 | Test 3.1323e-01 | SO3(train/test) 2.30e-01/2.32e-01 | Fail(train/test) 0/0 | LR 4.24e-03 | 3.7s
# Epoch   15 | Step   300/ 5000 | Train 3.1733e-01 | Test 3.1757e-01 | SO3(train/test) 2.30e-01/2.30e-01 | Fail(train/test) 0/0 | LR 4.54e-03 | 3.6s
# Epoch   16 | Step   320/ 5000 | Train 3.6036e-01 | Test 3.2606e-01 | SO3(train/test) 2.46e-01/2.63e-01 | Fail(train/test) 0/0 | LR 4.83e-03 | 3.6s
# Epoch   17 | Step   340/ 5000 | Train 3.2353e-01 | Test 3.0328e-01 | SO3(train/test) 2.75e-01/2.75e-01 | Fail(train/test) 0/0 | LR 5.13e-03 | 3.6s
# Epoch   18 | Step   360/ 5000 | Train 3.0794e-01 | Test 3.2366e-01 | SO3(train/test) 2.77e-01/2.69e-01 | Fail(train/test) 0/0 | LR 5.42e-03 | 3.7s
# Epoch   19 | Step   380/ 5000 | Train 3.0476e-01 | Test 3.1092e-01 | SO3(train/test) 2.75e-01/2.64e-01 | Fail(train/test) 0/0 | LR 5.72e-03 | 3.5s
# Epoch   20 | Step   400/ 5000 | Train 2.9276e-01 | Test 2.9865e-01 | SO3(train/test) 2.64e-01/2.49e-01 | Fail(train/test) 0/0 | LR 6.00e-03 | 3.5s
# Epoch   21 | Step   420/ 5000 | Train 2.8317e-01 | Test 2.8654e-01 | SO3(train/test) 2.47e-01/2.33e-01 | Fail(train/test) 0/0 | LR 6.00e-03 | 3.6s
# Epoch   22 | Step   440/ 5000 | Train 2.7400e-01 | Test 2.8106e-01 | SO3(train/test) 2.31e-01/2.18e-01 | Fail(train/test) 0/0 | LR 6.00e-03 | 3.5s
# Epoch   23 | Step   460/ 5000 | Train 2.6839e-01 | Test 2.7085e-01 | SO3(train/test) 2.18e-01/2.07e-01 | Fail(train/test) 0/0 | LR 6.00e-03 | 3.5s
# Epoch   24 | Step   480/ 5000 | Train 2.6351e-01 | Test 2.6516e-01 | SO3(train/test) 2.07e-01/1.97e-01 | Fail(train/test) 0/0 | LR 6.00e-03 | 3.7s
# Epoch   25 | Step   500/ 5000 | Train 2.5883e-01 | Test 2.5840e-01 | SO3(train/test) 1.98e-01/1.90e-01 | Fail(train/test) 0/0 | LR 5.99e-03 | 3.5s
# Epoch   26 | Step   520/ 5000 | Train 2.5389e-01 | Test 2.5079e-01 | SO3(train/test) 1.92e-01/1.84e-01 | Fail(train/test) 0/0 | LR 5.99e-03 | 3.5s
# Epoch   27 | Step   540/ 5000 | Train 2.5104e-01 | Test 2.5212e-01 | SO3(train/test) 1.86e-01/1.80e-01 | Fail(train/test) 0/0 | LR 5.99e-03 | 3.5s
# Epoch   28 | Step   560/ 5000 | Train 2.4827e-01 | Test 2.4742e-01 | SO3(train/test) 1.82e-01/1.76e-01 | Fail(train/test) 0/0 | LR 5.98e-03 | 3.5s
# Epoch   29 | Step   580/ 5000 | Train 2.4764e-01 | Test 2.4979e-01 | SO3(train/test) 1.78e-01/1.76e-01 | Fail(train/test) 0/0 | LR 5.98e-03 | 3.6s
# Epoch   30 | Step   600/ 5000 | Train 2.5401e-01 | Test 2.4071e-01 | SO3(train/test) 1.80e-01/1.85e-01 | Fail(train/test) 0/0 | LR 5.97e-03 | 3.5s
# Epoch   31 | Step   620/ 5000 | Train 3.1962e-01 | Test 2.8275e-01 | SO3(train/test) 1.92e-01/2.10e-01 | Fail(train/test) 0/0 | LR 5.97e-03 | 3.5s
# Epoch   32 | Step   640/ 5000 | Train 2.9654e-01 | Test 2.7471e-01 | SO3(train/test) 2.19e-01/2.28e-01 | Fail(train/test) 0/0 | LR 5.96e-03 | 3.5s
# Epoch   33 | Step   660/ 5000 | Train 2.7083e-01 | Test 2.6252e-01 | SO3(train/test) 2.33e-01/2.42e-01 | Fail(train/test) 0/0 | LR 5.95e-03 | 3.6s
# Epoch   34 | Step   680/ 5000 | Train 2.5992e-01 | Test 2.4023e-01 | SO3(train/test) 2.44e-01/2.39e-01 | Fail(train/test) 0/0 | LR 5.95e-03 | 3.5s
# Epoch   35 | Step   700/ 5000 | Train 2.4873e-01 | Test 2.6262e-01 | SO3(train/test) 2.47e-01/2.38e-01 | Fail(train/test) 0/0 | LR 5.94e-03 | 3.5s
# Epoch   36 | Step   720/ 5000 | Train 2.4224e-01 | Test 2.5249e-01 | SO3(train/test) 2.45e-01/2.43e-01 | Fail(train/test) 0/0 | LR 5.93e-03 | 3.5s
# Epoch   37 | Step   740/ 5000 | Train 2.3331e-01 | Test 2.3927e-01 | SO3(train/test) 2.41e-01/2.34e-01 | Fail(train/test) 0/0 | LR 5.92e-03 | 3.5s
# Epoch   38 | Step   760/ 5000 | Train 2.2930e-01 | Test 2.2991e-01 | SO3(train/test) 2.33e-01/2.24e-01 | Fail(train/test) 0/0 | LR 5.91e-03 | 3.5s
# Epoch   39 | Step   780/ 5000 | Train 2.2620e-01 | Test 2.3757e-01 | SO3(train/test) 2.26e-01/2.18e-01 | Fail(train/test) 0/0 | LR 5.90e-03 | 3.6s
# Epoch   40 | Step   800/ 5000 | Train 2.2326e-01 | Test 2.3200e-01 | SO3(train/test) 2.18e-01/2.12e-01 | Fail(train/test) 0/0 | LR 5.89e-03 | 3.5s
# Epoch   41 | Step   820/ 5000 | Train 2.2004e-01 | Test 2.3573e-01 | SO3(train/test) 2.12e-01/2.05e-01 | Fail(train/test) 0/0 | LR 5.88e-03 | 3.5s
# Epoch   42 | Step   840/ 5000 | Train 2.1559e-01 | Test 2.3005e-01 | SO3(train/test) 2.06e-01/2.01e-01 | Fail(train/test) 0/0 | LR 5.87e-03 | 3.5s
# Epoch   43 | Step   860/ 5000 | Train 2.1169e-01 | Test 2.2523e-01 | SO3(train/test) 2.02e-01/1.96e-01 | Fail(train/test) 0/0 | LR 5.86e-03 | 3.4s
# Epoch   44 | Step   880/ 5000 | Train 2.0475e-01 | Test 2.1964e-01 | SO3(train/test) 1.98e-01/1.91e-01 | Fail(train/test) 0/0 | LR 5.84e-03 | 3.5s
# Epoch   45 | Step   900/ 5000 | Train 2.0133e-01 | Test 2.1641e-01 | SO3(train/test) 1.94e-01/1.89e-01 | Fail(train/test) 0/0 | LR 5.83e-03 | 3.6s
# Epoch   46 | Step   920/ 5000 | Train 1.9842e-01 | Test 2.1092e-01 | SO3(train/test) 1.90e-01/1.85e-01 | Fail(train/test) 0/0 | LR 5.82e-03 | 3.5s
# Epoch   47 | Step   940/ 5000 | Train 1.9701e-01 | Test 2.1456e-01 | SO3(train/test) 1.87e-01/1.82e-01 | Fail(train/test) 0/0 | LR 5.80e-03 | 3.5s
# Epoch   48 | Step   960/ 5000 | Train 1.9805e-01 | Test 2.1266e-01 | SO3(train/test) 1.84e-01/1.79e-01 | Fail(train/test) 0/0 | LR 5.79e-03 | 3.6s
# Epoch   49 | Step   980/ 5000 | Train 2.0151e-01 | Test 2.1758e-01 | SO3(train/test) 1.79e-01/1.77e-01 | Fail(train/test) 0/0 | LR 5.77e-03 | 3.6s
# Epoch   50 | Step  1000/ 5000 | Train 2.0347e-01 | Test 2.3043e-01 | SO3(train/test) 1.78e-01/1.75e-01 | Fail(train/test) 0/0 | LR 5.76e-03 | 3.6s
# Epoch   51 | Step  1020/ 5000 | Train 2.1118e-01 | Test 2.2811e-01 | SO3(train/test) 1.82e-01/1.89e-01 | Fail(train/test) 0/0 | LR 5.74e-03 | 3.5s
# Epoch   52 | Step  1040/ 5000 | Train 2.0855e-01 | Test 2.3019e-01 | SO3(train/test) 1.96e-01/1.97e-01 | Fail(train/test) 0/0 | LR 5.72e-03 | 3.5s
# Epoch   53 | Step  1060/ 5000 | Train 1.9686e-01 | Test 2.0819e-01 | SO3(train/test) 2.03e-01/1.97e-01 | Fail(train/test) 0/0 | LR 5.71e-03 | 3.5s
# Epoch   54 | Step  1080/ 5000 | Train 1.9042e-01 | Test 1.9294e-01 | SO3(train/test) 1.98e-01/1.91e-01 | Fail(train/test) 0/0 | LR 5.69e-03 | 3.5s
# Epoch   55 | Step  1100/ 5000 | Train 1.8755e-01 | Test 2.0044e-01 | SO3(train/test) 1.91e-01/1.85e-01 | Fail(train/test) 0/0 | LR 5.67e-03 | 3.5s
# Epoch   56 | Step  1120/ 5000 | Train 1.8666e-01 | Test 1.9728e-01 | SO3(train/test) 1.86e-01/1.79e-01 | Fail(train/test) 0/0 | LR 5.65e-03 | 3.5s
# Epoch   57 | Step  1140/ 5000 | Train 1.8566e-01 | Test 1.9521e-01 | SO3(train/test) 1.81e-01/1.76e-01 | Fail(train/test) 0/0 | LR 5.63e-03 | 3.5s
# Epoch   58 | Step  1160/ 5000 | Train 1.8467e-01 | Test 1.9476e-01 | SO3(train/test) 1.77e-01/1.72e-01 | Fail(train/test) 0/0 | LR 5.61e-03 | 3.5s
# Epoch   59 | Step  1180/ 5000 | Train 1.8449e-01 | Test 1.9811e-01 | SO3(train/test) 1.74e-01/1.70e-01 | Fail(train/test) 0/0 | LR 5.59e-03 | 3.5s
# Epoch   60 | Step  1200/ 5000 | Train 1.8308e-01 | Test 1.9174e-01 | SO3(train/test) 1.72e-01/1.68e-01 | Fail(train/test) 0/0 | LR 5.57e-03 | 3.6s
# Epoch   61 | Step  1220/ 5000 | Train 1.8090e-01 | Test 1.8823e-01 | SO3(train/test) 1.70e-01/1.66e-01 | Fail(train/test) 0/0 | LR 5.55e-03 | 3.5s
# Epoch   62 | Step  1240/ 5000 | Train 1.8011e-01 | Test 1.8994e-01 | SO3(train/test) 1.68e-01/1.67e-01 | Fail(train/test) 0/0 | LR 5.53e-03 | 3.5s
# Epoch   63 | Step  1260/ 5000 | Train 1.7921e-01 | Test 1.8471e-01 | SO3(train/test) 1.67e-01/1.69e-01 | Fail(train/test) 0/0 | LR 5.51e-03 | 3.5s
# Epoch   64 | Step  1280/ 5000 | Train 1.7769e-01 | Test 1.8078e-01 | SO3(train/test) 1.68e-01/1.65e-01 | Fail(train/test) 0/0 | LR 5.48e-03 | 3.5s
# Epoch   65 | Step  1300/ 5000 | Train 1.7744e-01 | Test 1.9440e-01 | SO3(train/test) 1.67e-01/1.65e-01 | Fail(train/test) 0/0 | LR 5.46e-03 | 3.5s
# Epoch   66 | Step  1320/ 5000 | Train 1.8062e-01 | Test 2.0163e-01 | SO3(train/test) 1.66e-01/1.67e-01 | Fail(train/test) 0/0 | LR 5.44e-03 | 3.6s
# Epoch   67 | Step  1340/ 5000 | Train 1.8731e-01 | Test 1.9121e-01 | SO3(train/test) 1.70e-01/1.71e-01 | Fail(train/test) 0/0 | LR 5.41e-03 | 3.5s
# Epoch   68 | Step  1360/ 5000 | Train 1.8646e-01 | Test 2.1919e-01 | SO3(train/test) 1.77e-01/1.80e-01 | Fail(train/test) 0/0 | LR 5.39e-03 | 3.5s
# Epoch   69 | Step  1380/ 5000 | Train 1.8787e-01 | Test 1.9535e-01 | SO3(train/test) 1.92e-01/1.99e-01 | Fail(train/test) 0/0 | LR 5.36e-03 | 3.5s
# Epoch   70 | Step  1400/ 5000 | Train 1.7984e-01 | Test 2.2812e-01 | SO3(train/test) 2.03e-01/2.01e-01 | Fail(train/test) 0/0 | LR 5.34e-03 | 3.5s
# Epoch   71 | Step  1420/ 5000 | Train 1.9362e-01 | Test 1.9265e-01 | SO3(train/test) 2.02e-01/1.98e-01 | Fail(train/test) 0/0 | LR 5.31e-03 | 3.6s
# Epoch   72 | Step  1440/ 5000 | Train 1.8304e-01 | Test 1.9707e-01 | SO3(train/test) 1.97e-01/1.87e-01 | Fail(train/test) 0/0 | LR 5.29e-03 | 3.4s
# Epoch   73 | Step  1460/ 5000 | Train 1.7256e-01 | Test 1.7273e-01 | SO3(train/test) 1.88e-01/1.78e-01 | Fail(train/test) 0/0 | LR 5.26e-03 | 3.5s
# Epoch   74 | Step  1480/ 5000 | Train 1.6861e-01 | Test 1.7416e-01 | SO3(train/test) 1.79e-01/1.69e-01 | Fail(train/test) 0/0 | LR 5.23e-03 | 3.5s
# Epoch   75 | Step  1500/ 5000 | Train 1.6606e-01 | Test 1.7842e-01 | SO3(train/test) 1.71e-01/1.62e-01 | Fail(train/test) 0/0 | LR 5.21e-03 | 3.5s
# Epoch   76 | Step  1520/ 5000 | Train 1.6656e-01 | Test 1.7289e-01 | SO3(train/test) 1.65e-01/1.56e-01 | Fail(train/test) 0/0 | LR 5.18e-03 | 3.5s
# Epoch   77 | Step  1540/ 5000 | Train 1.6411e-01 | Test 1.7198e-01 | SO3(train/test) 1.61e-01/1.54e-01 | Fail(train/test) 0/0 | LR 5.15e-03 | 3.5s
# Epoch   78 | Step  1560/ 5000 | Train 1.6143e-01 | Test 1.6875e-01 | SO3(train/test) 1.60e-01/1.55e-01 | Fail(train/test) 0/0 | LR 5.12e-03 | 3.5s
# Epoch   79 | Step  1580/ 5000 | Train 1.5772e-01 | Test 1.6729e-01 | SO3(train/test) 1.62e-01/1.58e-01 | Fail(train/test) 0/0 | LR 5.09e-03 | 3.5s
# Epoch   80 | Step  1600/ 5000 | Train 1.5556e-01 | Test 1.6349e-01 | SO3(train/test) 1.62e-01/1.56e-01 | Fail(train/test) 0/0 | LR 5.06e-03 | 3.5s
# Epoch   81 | Step  1620/ 5000 | Train 1.5283e-01 | Test 1.6168e-01 | SO3(train/test) 1.63e-01/1.58e-01 | Fail(train/test) 0/0 | LR 5.03e-03 | 3.6s
# Epoch   82 | Step  1640/ 5000 | Train 1.5101e-01 | Test 1.5898e-01 | SO3(train/test) 1.62e-01/1.55e-01 | Fail(train/test) 0/0 | LR 5.00e-03 | 3.4s
# Epoch   83 | Step  1660/ 5000 | Train 1.4875e-01 | Test 1.5879e-01 | SO3(train/test) 1.61e-01/1.57e-01 | Fail(train/test) 0/0 | LR 4.97e-03 | 3.5s
# Epoch   84 | Step  1680/ 5000 | Train 1.4663e-01 | Test 1.5256e-01 | SO3(train/test) 1.62e-01/1.61e-01 | Fail(train/test) 0/0 | LR 4.94e-03 | 3.5s
# Epoch   85 | Step  1700/ 5000 | Train 1.4247e-01 | Test 1.4656e-01 | SO3(train/test) 1.67e-01/1.65e-01 | Fail(train/test) 0/0 | LR 4.91e-03 | 3.5s
# Epoch   86 | Step  1720/ 5000 | Train 1.3932e-01 | Test 1.5012e-01 | SO3(train/test) 1.76e-01/1.70e-01 | Fail(train/test) 0/0 | LR 4.88e-03 | 3.4s
# Epoch   87 | Step  1740/ 5000 | Train 1.3814e-01 | Test 1.3920e-01 | SO3(train/test) 1.89e-01/1.98e-01 | Fail(train/test) 0/0 | LR 4.85e-03 | 3.6s
# Epoch   88 | Step  1760/ 5000 | Train 1.2864e-01 | Test 1.3211e-01 | SO3(train/test) 2.10e-01/2.16e-01 | Fail(train/test) 0/0 | LR 4.82e-03 | 3.5s
# Epoch   89 | Step  1780/ 5000 | Train 1.1867e-01 | Test 1.3198e-01 | SO3(train/test) 2.32e-01/2.25e-01 | Fail(train/test) 0/0 | LR 4.78e-03 | 3.5s
# Epoch   90 | Step  1800/ 5000 | Train 1.1303e-01 | Test 1.1831e-01 | SO3(train/test) 2.32e-01/2.14e-01 | Fail(train/test) 0/0 | LR 4.75e-03 | 3.5s
# Epoch   91 | Step  1820/ 5000 | Train 1.0755e-01 | Test 1.1529e-01 | SO3(train/test) 2.19e-01/2.03e-01 | Fail(train/test) 0/0 | LR 4.72e-03 | 3.5s
# Epoch   92 | Step  1840/ 5000 | Train 1.0459e-01 | Test 1.1388e-01 | SO3(train/test) 2.10e-01/2.00e-01 | Fail(train/test) 0/0 | LR 4.68e-03 | 3.7s
# Epoch   93 | Step  1860/ 5000 | Train 1.0219e-01 | Test 1.1485e-01 | SO3(train/test) 2.10e-01/2.01e-01 | Fail(train/test) 0/0 | LR 4.65e-03 | 3.4s
# Epoch   94 | Step  1880/ 5000 | Train 1.0108e-01 | Test 1.1838e-01 | SO3(train/test) 2.08e-01/2.00e-01 | Fail(train/test) 0/0 | LR 4.62e-03 | 3.5s
# Epoch   95 | Step  1900/ 5000 | Train 9.7527e-02 | Test 1.0992e-01 | SO3(train/test) 2.04e-01/1.96e-01 | Fail(train/test) 0/0 | LR 4.58e-03 | 3.5s
# Epoch   96 | Step  1920/ 5000 | Train 9.2837e-02 | Test 1.0270e-01 | SO3(train/test) 1.96e-01/1.81e-01 | Fail(train/test) 0/0 | LR 4.55e-03 | 3.5s
# Epoch   97 | Step  1940/ 5000 | Train 9.1339e-02 | Test 9.6094e-02 | SO3(train/test) 1.84e-01/1.68e-01 | Fail(train/test) 0/0 | LR 4.51e-03 | 3.5s
# Epoch   98 | Step  1960/ 5000 | Train 1.0548e-01 | Test 1.0033e-01 | SO3(train/test) 1.56e-01/1.38e-01 | Fail(train/test) 0/0 | LR 4.48e-03 | 3.5s
# Epoch   99 | Step  1980/ 5000 | Train 9.7862e-02 | Test 1.0519e-01 | SO3(train/test) 1.57e-01/1.59e-01 | Fail(train/test) 0/0 | LR 4.44e-03 | 3.5s
# Epoch  100 | Step  2000/ 5000 | Train 9.6382e-02 | Test 1.1679e-01 | SO3(train/test) 1.70e-01/1.61e-01 | Fail(train/test) 0/0 | LR 4.41e-03 | 3.5s
# Epoch  101 | Step  2020/ 5000 | Train 9.3994e-02 | Test 1.1130e-01 | SO3(train/test) 1.73e-01/1.65e-01 | Fail(train/test) 0/0 | LR 4.37e-03 | 3.5s
# Epoch  102 | Step  2040/ 5000 | Train 8.1794e-02 | Test 9.6350e-02 | SO3(train/test) 1.69e-01/1.62e-01 | Fail(train/test) 0/0 | LR 4.33e-03 | 3.6s
# Epoch  103 | Step  2060/ 5000 | Train 7.3821e-02 | Test 8.1606e-02 | SO3(train/test) 1.71e-01/1.65e-01 | Fail(train/test) 0/0 | LR 4.30e-03 | 3.5s
# Epoch  104 | Step  2080/ 5000 | Train 7.0740e-02 | Test 7.9607e-02 | SO3(train/test) 1.75e-01/1.70e-01 | Fail(train/test) 0/0 | LR 4.26e-03 | 3.5s
# Epoch  105 | Step  2100/ 5000 | Train 6.6982e-02 | Test 7.8378e-02 | SO3(train/test) 1.79e-01/1.76e-01 | Fail(train/test) 0/0 | LR 4.22e-03 | 3.5s
# Epoch  106 | Step  2120/ 5000 | Train 6.3683e-02 | Test 7.4121e-02 | SO3(train/test) 1.83e-01/1.79e-01 | Fail(train/test) 0/0 | LR 4.19e-03 | 3.6s
# Epoch  107 | Step  2140/ 5000 | Train 6.0949e-02 | Test 7.1756e-02 | SO3(train/test) 1.85e-01/1.82e-01 | Fail(train/test) 0/0 | LR 4.15e-03 | 3.5s
# Epoch  108 | Step  2160/ 5000 | Train 5.8783e-02 | Test 6.8122e-02 | SO3(train/test) 1.85e-01/1.81e-01 | Fail(train/test) 0/0 | LR 4.11e-03 | 3.6s
# Epoch  109 | Step  2180/ 5000 | Train 5.6568e-02 | Test 6.7929e-02 | SO3(train/test) 1.83e-01/1.79e-01 | Fail(train/test) 0/0 | LR 4.08e-03 | 3.5s
# Epoch  110 | Step  2200/ 5000 | Train 5.4210e-02 | Test 6.2928e-02 | SO3(train/test) 1.79e-01/1.77e-01 | Fail(train/test) 0/0 | LR 4.04e-03 | 3.5s
# Epoch  111 | Step  2220/ 5000 | Train 5.3600e-02 | Test 7.1378e-02 | SO3(train/test) 1.75e-01/1.71e-01 | Fail(train/test) 0/0 | LR 4.00e-03 | 3.5s
# Epoch  112 | Step  2240/ 5000 | Train 5.3810e-02 | Test 6.7687e-02 | SO3(train/test) 1.70e-01/1.73e-01 | Fail(train/test) 0/0 | LR 3.96e-03 | 3.4s
# Epoch  113 | Step  2260/ 5000 | Train 5.2958e-02 | Test 6.0209e-02 | SO3(train/test) 1.66e-01/1.65e-01 | Fail(train/test) 0/0 | LR 3.92e-03 | 3.6s
# Epoch  114 | Step  2280/ 5000 | Train 4.9416e-02 | Test 6.0723e-02 | SO3(train/test) 1.59e-01/1.61e-01 | Fail(train/test) 0/0 | LR 3.88e-03 | 3.5s
# Epoch  115 | Step  2300/ 5000 | Train 4.8616e-02 | Test 6.0953e-02 | SO3(train/test) 1.57e-01/1.61e-01 | Fail(train/test) 0/0 | LR 3.85e-03 | 3.5s
# Epoch  116 | Step  2320/ 5000 | Train 4.8073e-02 | Test 5.8687e-02 | SO3(train/test) 1.54e-01/1.57e-01 | Fail(train/test) 0/0 | LR 3.81e-03 | 3.5s
# Epoch  117 | Step  2340/ 5000 | Train 4.6664e-02 | Test 5.8370e-02 | SO3(train/test) 1.51e-01/1.58e-01 | Fail(train/test) 0/0 | LR 3.77e-03 | 3.5s
# Epoch  118 | Step  2360/ 5000 | Train 4.5021e-02 | Test 5.4737e-02 | SO3(train/test) 1.50e-01/1.54e-01 | Fail(train/test) 0/0 | LR 3.73e-03 | 3.5s
# Epoch  119 | Step  2380/ 5000 | Train 4.4047e-02 | Test 5.4204e-02 | SO3(train/test) 1.48e-01/1.53e-01 | Fail(train/test) 0/0 | LR 3.69e-03 | 3.5s
# Epoch  120 | Step  2400/ 5000 | Train 4.2949e-02 | Test 5.3666e-02 | SO3(train/test) 1.47e-01/1.53e-01 | Fail(train/test) 0/0 | LR 3.65e-03 | 3.5s
# Epoch  121 | Step  2420/ 5000 | Train 4.2085e-02 | Test 5.3959e-02 | SO3(train/test) 1.46e-01/1.53e-01 | Fail(train/test) 0/0 | LR 3.61e-03 | 3.5s
# Epoch  122 | Step  2440/ 5000 | Train 4.0922e-02 | Test 5.1562e-02 | SO3(train/test) 1.45e-01/1.51e-01 | Fail(train/test) 0/0 | LR 3.57e-03 | 3.5s
# Epoch  123 | Step  2460/ 5000 | Train 4.0069e-02 | Test 5.0010e-02 | SO3(train/test) 1.45e-01/1.52e-01 | Fail(train/test) 0/0 | LR 3.53e-03 | 3.6s
# Epoch  124 | Step  2480/ 5000 | Train 3.9271e-02 | Test 5.1355e-02 | SO3(train/test) 1.44e-01/1.49e-01 | Fail(train/test) 0/0 | LR 3.49e-03 | 3.5s
# Epoch  125 | Step  2500/ 5000 | Train 3.8624e-02 | Test 4.7277e-02 | SO3(train/test) 1.44e-01/1.52e-01 | Fail(train/test) 0/0 | LR 3.45e-03 | 3.5s
# Epoch  126 | Step  2520/ 5000 | Train 3.7798e-02 | Test 4.7299e-02 | SO3(train/test) 1.43e-01/1.51e-01 | Fail(train/test) 0/0 | LR 3.41e-03 | 3.5s
# Epoch  127 | Step  2540/ 5000 | Train 3.6786e-02 | Test 4.7842e-02 | SO3(train/test) 1.43e-01/1.49e-01 | Fail(train/test) 0/0 | LR 3.37e-03 | 3.5s
# Epoch  128 | Step  2560/ 5000 | Train 3.5684e-02 | Test 4.3771e-02 | SO3(train/test) 1.43e-01/1.52e-01 | Fail(train/test) 0/0 | LR 3.33e-03 | 3.5s
# Epoch  129 | Step  2580/ 5000 | Train 3.4561e-02 | Test 4.2206e-02 | SO3(train/test) 1.44e-01/1.52e-01 | Fail(train/test) 0/0 | LR 3.29e-03 | 3.6s
# Epoch  130 | Step  2600/ 5000 | Train 3.3472e-02 | Test 4.0692e-02 | SO3(train/test) 1.44e-01/1.50e-01 | Fail(train/test) 0/0 | LR 3.25e-03 | 3.5s
# Epoch  131 | Step  2620/ 5000 | Train 3.2648e-02 | Test 3.8609e-02 | SO3(train/test) 1.44e-01/1.51e-01 | Fail(train/test) 0/0 | LR 3.21e-03 | 3.5s
# Epoch  132 | Step  2640/ 5000 | Train 3.2124e-02 | Test 3.9757e-02 | SO3(train/test) 1.44e-01/1.51e-01 | Fail(train/test) 0/0 | LR 3.17e-03 | 3.5s
# Epoch  133 | Step  2660/ 5000 | Train 3.1105e-02 | Test 3.9593e-02 | SO3(train/test) 1.44e-01/1.50e-01 | Fail(train/test) 0/0 | LR 3.13e-03 | 3.4s
# Epoch  134 | Step  2680/ 5000 | Train 3.0435e-02 | Test 3.7420e-02 | SO3(train/test) 1.44e-01/1.52e-01 | Fail(train/test) 0/0 | LR 3.09e-03 | 3.7s
# Epoch  135 | Step  2700/ 5000 | Train 2.9638e-02 | Test 3.5667e-02 | SO3(train/test) 1.45e-01/1.52e-01 | Fail(train/test) 0/0 | LR 3.05e-03 | 3.5s
# Epoch  136 | Step  2720/ 5000 | Train 2.9099e-02 | Test 3.5781e-02 | SO3(train/test) 1.45e-01/1.54e-01 | Fail(train/test) 0/0 | LR 3.01e-03 | 3.5s
# Epoch  137 | Step  2740/ 5000 | Train 2.8704e-02 | Test 3.6547e-02 | SO3(train/test) 1.46e-01/1.53e-01 | Fail(train/test) 0/0 | LR 2.97e-03 | 3.5s
# Epoch  138 | Step  2760/ 5000 | Train 2.8447e-02 | Test 3.5282e-02 | SO3(train/test) 1.46e-01/1.56e-01 | Fail(train/test) 0/0 | LR 2.93e-03 | 3.5s
# Epoch  139 | Step  2780/ 5000 | Train 2.8609e-02 | Test 3.4920e-02 | SO3(train/test) 1.47e-01/1.54e-01 | Fail(train/test) 0/0 | LR 2.89e-03 | 3.5s
# Epoch  140 | Step  2800/ 5000 | Train 2.8025e-02 | Test 3.2807e-02 | SO3(train/test) 1.48e-01/1.55e-01 | Fail(train/test) 0/0 | LR 2.85e-03 | 3.5s
# Epoch  141 | Step  2820/ 5000 | Train 2.7413e-02 | Test 3.4754e-02 | SO3(train/test) 1.47e-01/1.56e-01 | Fail(train/test) 0/0 | LR 2.81e-03 | 3.5s
# Epoch  142 | Step  2840/ 5000 | Train 2.6136e-02 | Test 3.1390e-02 | SO3(train/test) 1.47e-01/1.54e-01 | Fail(train/test) 0/0 | LR 2.77e-03 | 3.5s
# Epoch  143 | Step  2860/ 5000 | Train 2.5494e-02 | Test 3.1520e-02 | SO3(train/test) 1.48e-01/1.56e-01 | Fail(train/test) 0/0 | LR 2.73e-03 | 3.5s
# Epoch  144 | Step  2880/ 5000 | Train 2.4673e-02 | Test 3.0719e-02 | SO3(train/test) 1.48e-01/1.56e-01 | Fail(train/test) 0/0 | LR 2.69e-03 | 3.6s
# Epoch  145 | Step  2900/ 5000 | Train 2.4393e-02 | Test 3.0392e-02 | SO3(train/test) 1.49e-01/1.56e-01 | Fail(train/test) 0/0 | LR 2.65e-03 | 3.5s
# Epoch  146 | Step  2920/ 5000 | Train 2.3972e-02 | Test 2.8988e-02 | SO3(train/test) 1.49e-01/1.57e-01 | Fail(train/test) 0/0 | LR 2.61e-03 | 3.5s
# Epoch  147 | Step  2940/ 5000 | Train 2.3792e-02 | Test 2.9005e-02 | SO3(train/test) 1.50e-01/1.58e-01 | Fail(train/test) 0/0 | LR 2.57e-03 | 3.4s
# Epoch  148 | Step  2960/ 5000 | Train 2.3246e-02 | Test 2.8651e-02 | SO3(train/test) 1.51e-01/1.58e-01 | Fail(train/test) 0/0 | LR 2.53e-03 | 3.5s
# Epoch  149 | Step  2980/ 5000 | Train 2.3155e-02 | Test 2.7937e-02 | SO3(train/test) 1.51e-01/1.59e-01 | Fail(train/test) 0/0 | LR 2.49e-03 | 3.5s
# Epoch  150 | Step  3000/ 5000 | Train 2.2540e-02 | Test 2.8054e-02 | SO3(train/test) 1.52e-01/1.60e-01 | Fail(train/test) 0/0 | LR 2.45e-03 | 3.6s
# Epoch  151 | Step  3020/ 5000 | Train 2.2335e-02 | Test 2.7450e-02 | SO3(train/test) 1.52e-01/1.60e-01 | Fail(train/test) 0/0 | LR 2.41e-03 | 3.5s
# Epoch  152 | Step  3040/ 5000 | Train 2.1855e-02 | Test 2.5994e-02 | SO3(train/test) 1.53e-01/1.61e-01 | Fail(train/test) 0/0 | LR 2.37e-03 | 3.5s
# Epoch  153 | Step  3060/ 5000 | Train 2.1742e-02 | Test 2.7290e-02 | SO3(train/test) 1.53e-01/1.61e-01 | Fail(train/test) 0/0 | LR 2.33e-03 | 3.5s
# Epoch  154 | Step  3080/ 5000 | Train 2.0988e-02 | Test 2.5555e-02 | SO3(train/test) 1.54e-01/1.61e-01 | Fail(train/test) 0/0 | LR 2.29e-03 | 3.4s
# Epoch  155 | Step  3100/ 5000 | Train 2.0798e-02 | Test 2.5495e-02 | SO3(train/test) 1.54e-01/1.62e-01 | Fail(train/test) 0/0 | LR 2.25e-03 | 3.6s
# Epoch  156 | Step  3120/ 5000 | Train 2.0272e-02 | Test 2.3893e-02 | SO3(train/test) 1.54e-01/1.63e-01 | Fail(train/test) 0/0 | LR 2.21e-03 | 3.5s
# Epoch  157 | Step  3140/ 5000 | Train 1.9976e-02 | Test 2.4656e-02 | SO3(train/test) 1.55e-01/1.63e-01 | Fail(train/test) 0/0 | LR 2.18e-03 | 3.5s
# Epoch  158 | Step  3160/ 5000 | Train 1.9511e-02 | Test 2.4022e-02 | SO3(train/test) 1.55e-01/1.64e-01 | Fail(train/test) 0/0 | LR 2.14e-03 | 3.4s
# Epoch  159 | Step  3180/ 5000 | Train 1.9230e-02 | Test 2.3751e-02 | SO3(train/test) 1.56e-01/1.63e-01 | Fail(train/test) 0/0 | LR 2.10e-03 | 3.5s
# Epoch  160 | Step  3200/ 5000 | Train 1.9050e-02 | Test 2.2247e-02 | SO3(train/test) 1.56e-01/1.65e-01 | Fail(train/test) 0/0 | LR 2.06e-03 | 3.5s
# Epoch  161 | Step  3220/ 5000 | Train 1.8771e-02 | Test 2.4341e-02 | SO3(train/test) 1.57e-01/1.64e-01 | Fail(train/test) 0/0 | LR 2.02e-03 | 3.5s
# Epoch  162 | Step  3240/ 5000 | Train 1.8450e-02 | Test 2.1364e-02 | SO3(train/test) 1.57e-01/1.66e-01 | Fail(train/test) 0/0 | LR 1.99e-03 | 3.5s
# Epoch  163 | Step  3260/ 5000 | Train 1.8145e-02 | Test 2.2319e-02 | SO3(train/test) 1.58e-01/1.65e-01 | Fail(train/test) 0/0 | LR 1.95e-03 | 3.5s
# Epoch  164 | Step  3280/ 5000 | Train 1.7717e-02 | Test 2.1277e-02 | SO3(train/test) 1.58e-01/1.66e-01 | Fail(train/test) 0/0 | LR 1.91e-03 | 3.5s
# Epoch  165 | Step  3300/ 5000 | Train 1.7365e-02 | Test 2.0603e-02 | SO3(train/test) 1.59e-01/1.67e-01 | Fail(train/test) 0/0 | LR 1.87e-03 | 3.5s
# Epoch  166 | Step  3320/ 5000 | Train 1.7142e-02 | Test 2.0642e-02 | SO3(train/test) 1.59e-01/1.67e-01 | Fail(train/test) 0/0 | LR 1.84e-03 | 3.5s
# Epoch  167 | Step  3340/ 5000 | Train 1.6911e-02 | Test 2.1279e-02 | SO3(train/test) 1.59e-01/1.67e-01 | Fail(train/test) 0/0 | LR 1.80e-03 | 3.5s
# Epoch  168 | Step  3360/ 5000 | Train 1.6712e-02 | Test 1.9892e-02 | SO3(train/test) 1.60e-01/1.68e-01 | Fail(train/test) 0/0 | LR 1.76e-03 | 3.4s
# Epoch  169 | Step  3380/ 5000 | Train 1.6531e-02 | Test 1.9630e-02 | SO3(train/test) 1.60e-01/1.68e-01 | Fail(train/test) 0/0 | LR 1.73e-03 | 3.5s
# Epoch  170 | Step  3400/ 5000 | Train 1.6268e-02 | Test 1.9501e-02 | SO3(train/test) 1.61e-01/1.69e-01 | Fail(train/test) 0/0 | LR 1.69e-03 | 3.5s
# Epoch  171 | Step  3420/ 5000 | Train 1.6026e-02 | Test 1.9437e-02 | SO3(train/test) 1.61e-01/1.69e-01 | Fail(train/test) 0/0 | LR 1.66e-03 | 3.6s
# Epoch  172 | Step  3440/ 5000 | Train 1.5773e-02 | Test 1.8384e-02 | SO3(train/test) 1.61e-01/1.70e-01 | Fail(train/test) 0/0 | LR 1.62e-03 | 3.4s
# Epoch  173 | Step  3460/ 5000 | Train 1.5607e-02 | Test 1.9041e-02 | SO3(train/test) 1.62e-01/1.71e-01 | Fail(train/test) 0/0 | LR 1.59e-03 | 3.5s
# Epoch  174 | Step  3480/ 5000 | Train 1.5474e-02 | Test 1.8102e-02 | SO3(train/test) 1.62e-01/1.71e-01 | Fail(train/test) 0/0 | LR 1.55e-03 | 3.5s
# Epoch  175 | Step  3500/ 5000 | Train 1.5224e-02 | Test 1.7835e-02 | SO3(train/test) 1.62e-01/1.71e-01 | Fail(train/test) 0/0 | LR 1.52e-03 | 3.4s
# Epoch  176 | Step  3520/ 5000 | Train 1.5103e-02 | Test 1.7922e-02 | SO3(train/test) 1.63e-01/1.71e-01 | Fail(train/test) 0/0 | LR 1.48e-03 | 3.6s
# Epoch  177 | Step  3540/ 5000 | Train 1.4891e-02 | Test 1.7579e-02 | SO3(train/test) 1.63e-01/1.71e-01 | Fail(train/test) 0/0 | LR 1.45e-03 | 3.5s
# Epoch  178 | Step  3560/ 5000 | Train 1.4789e-02 | Test 1.7082e-02 | SO3(train/test) 1.63e-01/1.70e-01 | Fail(train/test) 0/0 | LR 1.41e-03 | 3.5s
# Epoch  179 | Step  3580/ 5000 | Train 1.4655e-02 | Test 1.7498e-02 | SO3(train/test) 1.63e-01/1.71e-01 | Fail(train/test) 0/0 | LR 1.38e-03 | 3.4s
# Epoch  180 | Step  3600/ 5000 | Train 1.4537e-02 | Test 1.7176e-02 | SO3(train/test) 1.63e-01/1.71e-01 | Fail(train/test) 0/0 | LR 1.35e-03 | 3.4s
# Epoch  181 | Step  3620/ 5000 | Train 1.4300e-02 | Test 1.7085e-02 | SO3(train/test) 1.63e-01/1.71e-01 | Fail(train/test) 0/0 | LR 1.31e-03 | 3.5s
# Epoch  182 | Step  3640/ 5000 | Train 1.4125e-02 | Test 1.6740e-02 | SO3(train/test) 1.63e-01/1.71e-01 | Fail(train/test) 0/0 | LR 1.28e-03 | 3.5s
# Epoch  183 | Step  3660/ 5000 | Train 1.3935e-02 | Test 1.6202e-02 | SO3(train/test) 1.64e-01/1.72e-01 | Fail(train/test) 0/0 | LR 1.25e-03 | 3.5s
# Epoch  184 | Step  3680/ 5000 | Train 1.3816e-02 | Test 1.6194e-02 | SO3(train/test) 1.64e-01/1.72e-01 | Fail(train/test) 0/0 | LR 1.22e-03 | 3.5s
# Epoch  185 | Step  3700/ 5000 | Train 1.3752e-02 | Test 1.6287e-02 | SO3(train/test) 1.64e-01/1.72e-01 | Fail(train/test) 0/0 | LR 1.19e-03 | 3.5s
# Epoch  186 | Step  3720/ 5000 | Train 1.3843e-02 | Test 1.7409e-02 | SO3(train/test) 1.64e-01/1.73e-01 | Fail(train/test) 0/0 | LR 1.16e-03 | 3.6s
# Epoch  187 | Step  3740/ 5000 | Train 1.5037e-02 | Test 1.7249e-02 | SO3(train/test) 1.64e-01/1.71e-01 | Fail(train/test) 0/0 | LR 1.13e-03 | 3.4s
# Epoch  188 | Step  3760/ 5000 | Train 1.4390e-02 | Test 1.6463e-02 | SO3(train/test) 1.63e-01/1.69e-01 | Fail(train/test) 0/0 | LR 1.10e-03 | 3.5s
# Epoch  189 | Step  3780/ 5000 | Train 1.3625e-02 | Test 1.5841e-02 | SO3(train/test) 1.61e-01/1.69e-01 | Fail(train/test) 0/0 | LR 1.07e-03 | 3.4s
# Epoch  190 | Step  3800/ 5000 | Train 1.2946e-02 | Test 1.5367e-02 | SO3(train/test) 1.62e-01/1.70e-01 | Fail(train/test) 0/0 | LR 1.04e-03 | 3.4s
# Epoch  191 | Step  3820/ 5000 | Train 1.3755e-02 | Test 1.9134e-02 | SO3(train/test) 1.63e-01/1.71e-01 | Fail(train/test) 0/0 | LR 1.01e-03 | 3.5s
# Epoch  192 | Step  3840/ 5000 | Train 1.4513e-02 | Test 1.5774e-02 | SO3(train/test) 1.63e-01/1.70e-01 | Fail(train/test) 0/0 | LR 9.77e-04 | 3.6s
# Epoch  193 | Step  3860/ 5000 | Train 1.3296e-02 | Test 1.5479e-02 | SO3(train/test) 1.63e-01/1.70e-01 | Fail(train/test) 0/0 | LR 9.49e-04 | 3.5s
# Epoch  194 | Step  3880/ 5000 | Train 1.2716e-02 | Test 1.5065e-02 | SO3(train/test) 1.63e-01/1.70e-01 | Fail(train/test) 0/0 | LR 9.21e-04 | 3.5s
# Epoch  195 | Step  3900/ 5000 | Train 1.2573e-02 | Test 1.4930e-02 | SO3(train/test) 1.63e-01/1.70e-01 | Fail(train/test) 0/0 | LR 8.93e-04 | 3.5s
# Epoch  196 | Step  3920/ 5000 | Train 1.2453e-02 | Test 1.4878e-02 | SO3(train/test) 1.63e-01/1.70e-01 | Fail(train/test) 0/0 | LR 8.66e-04 | 3.5s
# Epoch  197 | Step  3940/ 5000 | Train 1.2377e-02 | Test 1.4592e-02 | SO3(train/test) 1.63e-01/1.71e-01 | Fail(train/test) 0/0 | LR 8.39e-04 | 3.6s
# Epoch  198 | Step  3960/ 5000 | Train 1.2321e-02 | Test 1.4405e-02 | SO3(train/test) 1.63e-01/1.71e-01 | Fail(train/test) 0/0 | LR 8.12e-04 | 3.5s
# Epoch  199 | Step  3980/ 5000 | Train 1.2265e-02 | Test 1.4805e-02 | SO3(train/test) 1.64e-01/1.71e-01 | Fail(train/test) 0/0 | LR 7.86e-04 | 3.6s
# Epoch  200 | Step  4000/ 5000 | Train 1.2218e-02 | Test 1.4200e-02 | SO3(train/test) 1.64e-01/1.72e-01 | Fail(train/test) 0/0 | LR 7.61e-04 | 3.5s
# Epoch  201 | Step  4020/ 5000 | Train 1.2016e-02 | Test 1.4049e-02 | SO3(train/test) 1.64e-01/1.71e-01 | Fail(train/test) 0/0 | LR 7.35e-04 | 3.4s
# Epoch  202 | Step  4040/ 5000 | Train 1.1686e-02 | Test 1.3954e-02 | SO3(train/test) 1.65e-01/1.72e-01 | Fail(train/test) 0/0 | LR 7.11e-04 | 3.5s
# Epoch  203 | Step  4060/ 5000 | Train 1.1602e-02 | Test 1.3732e-02 | SO3(train/test) 1.66e-01/1.73e-01 | Fail(train/test) 0/0 | LR 6.86e-04 | 3.5s
# Epoch  204 | Step  4080/ 5000 | Train 1.1484e-02 | Test 1.3687e-02 | SO3(train/test) 1.66e-01/1.73e-01 | Fail(train/test) 0/0 | LR 6.62e-04 | 3.5s
# Epoch  205 | Step  4100/ 5000 | Train 1.1437e-02 | Test 1.3617e-02 | SO3(train/test) 1.67e-01/1.74e-01 | Fail(train/test) 0/0 | LR 6.39e-04 | 3.5s
# Epoch  206 | Step  4120/ 5000 | Train 1.1439e-02 | Test 1.3567e-02 | SO3(train/test) 1.67e-01/1.74e-01 | Fail(train/test) 0/0 | LR 6.16e-04 | 3.5s
# Epoch  207 | Step  4140/ 5000 | Train 1.1414e-02 | Test 1.3521e-02 | SO3(train/test) 1.68e-01/1.75e-01 | Fail(train/test) 0/0 | LR 5.93e-04 | 3.6s
# Epoch  208 | Step  4160/ 5000 | Train 1.1367e-02 | Test 1.3443e-02 | SO3(train/test) 1.68e-01/1.74e-01 | Fail(train/test) 0/0 | LR 5.71e-04 | 3.5s
# Epoch  209 | Step  4180/ 5000 | Train 1.1257e-02 | Test 1.3357e-02 | SO3(train/test) 1.68e-01/1.75e-01 | Fail(train/test) 0/0 | LR 5.50e-04 | 3.5s
# Epoch  210 | Step  4200/ 5000 | Train 1.1185e-02 | Test 1.3306e-02 | SO3(train/test) 1.69e-01/1.75e-01 | Fail(train/test) 0/0 | LR 5.29e-04 | 3.5s
# Epoch  211 | Step  4220/ 5000 | Train 1.1127e-02 | Test 1.3180e-02 | SO3(train/test) 1.69e-01/1.76e-01 | Fail(train/test) 0/0 | LR 5.08e-04 | 3.5s
# Epoch  212 | Step  4240/ 5000 | Train 1.1116e-02 | Test 1.3058e-02 | SO3(train/test) 1.69e-01/1.75e-01 | Fail(train/test) 0/0 | LR 4.88e-04 | 3.5s
# Epoch  213 | Step  4260/ 5000 | Train 1.1061e-02 | Test 1.3092e-02 | SO3(train/test) 1.69e-01/1.75e-01 | Fail(train/test) 0/0 | LR 4.68e-04 | 3.6s
# Epoch  214 | Step  4280/ 5000 | Train 1.1026e-02 | Test 1.3111e-02 | SO3(train/test) 1.70e-01/1.76e-01 | Fail(train/test) 0/0 | LR 4.49e-04 | 3.5s
# Epoch  215 | Step  4300/ 5000 | Train 1.0978e-02 | Test 1.3030e-02 | SO3(train/test) 1.70e-01/1.75e-01 | Fail(train/test) 0/0 | LR 4.30e-04 | 3.5s
# Epoch  216 | Step  4320/ 5000 | Train 1.0958e-02 | Test 1.2855e-02 | SO3(train/test) 1.70e-01/1.75e-01 | Fail(train/test) 0/0 | LR 4.12e-04 | 3.5s
# Epoch  217 | Step  4340/ 5000 | Train 1.0892e-02 | Test 1.2944e-02 | SO3(train/test) 1.70e-01/1.76e-01 | Fail(train/test) 0/0 | LR 3.94e-04 | 3.5s
# Epoch  218 | Step  4360/ 5000 | Train 1.0863e-02 | Test 1.2823e-02 | SO3(train/test) 1.70e-01/1.75e-01 | Fail(train/test) 0/0 | LR 3.77e-04 | 3.6s
# Epoch  219 | Step  4380/ 5000 | Train 1.0831e-02 | Test 1.2771e-02 | SO3(train/test) 1.70e-01/1.76e-01 | Fail(train/test) 0/0 | LR 3.60e-04 | 3.5s
# Epoch  220 | Step  4400/ 5000 | Train 1.0783e-02 | Test 1.2740e-02 | SO3(train/test) 1.70e-01/1.76e-01 | Fail(train/test) 0/0 | LR 3.44e-04 | 3.5s
# Epoch  221 | Step  4420/ 5000 | Train 1.0760e-02 | Test 1.2804e-02 | SO3(train/test) 1.70e-01/1.76e-01 | Fail(train/test) 0/0 | LR 3.28e-04 | 3.5s
# Epoch  222 | Step  4440/ 5000 | Train 1.0716e-02 | Test 1.2605e-02 | SO3(train/test) 1.70e-01/1.76e-01 | Fail(train/test) 0/0 | LR 3.12e-04 | 3.5s
# Epoch  223 | Step  4460/ 5000 | Train 1.0663e-02 | Test 1.2575e-02 | SO3(train/test) 1.70e-01/1.76e-01 | Fail(train/test) 0/0 | LR 2.98e-04 | 3.5s
# Epoch  224 | Step  4480/ 5000 | Train 1.0640e-02 | Test 1.2533e-02 | SO3(train/test) 1.70e-01/1.76e-01 | Fail(train/test) 0/0 | LR 2.83e-04 | 3.5s
# Epoch  225 | Step  4500/ 5000 | Train 1.0619e-02 | Test 1.2514e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 2.70e-04 | 3.5s
# Epoch  226 | Step  4520/ 5000 | Train 1.0572e-02 | Test 1.2503e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 2.57e-04 | 3.5s
# Epoch  227 | Step  4540/ 5000 | Train 1.0567e-02 | Test 1.2464e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 2.44e-04 | 3.5s
# Epoch  228 | Step  4560/ 5000 | Train 1.0529e-02 | Test 1.2383e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 2.32e-04 | 3.6s
# Epoch  229 | Step  4580/ 5000 | Train 1.0472e-02 | Test 1.2346e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 2.20e-04 | 3.4s
# Epoch  230 | Step  4600/ 5000 | Train 1.0457e-02 | Test 1.2344e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 2.09e-04 | 3.5s
# Epoch  231 | Step  4620/ 5000 | Train 1.0449e-02 | Test 1.2272e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 1.98e-04 | 3.5s
# Epoch  232 | Step  4640/ 5000 | Train 1.0416e-02 | Test 1.2263e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 1.88e-04 | 3.5s
# Epoch  233 | Step  4660/ 5000 | Train 1.0397e-02 | Test 1.2233e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 1.79e-04 | 3.5s
# Epoch  234 | Step  4680/ 5000 | Train 1.0357e-02 | Test 1.2210e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 1.70e-04 | 3.6s
# Epoch  235 | Step  4700/ 5000 | Train 1.0339e-02 | Test 1.2167e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 1.61e-04 | 3.5s
# Epoch  236 | Step  4720/ 5000 | Train 1.0302e-02 | Test 1.2125e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 1.53e-04 | 3.5s
# Epoch  237 | Step  4740/ 5000 | Train 1.0286e-02 | Test 1.2103e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 1.46e-04 | 3.5s
# Epoch  238 | Step  4760/ 5000 | Train 1.0262e-02 | Test 1.2075e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 1.39e-04 | 3.5s
# Epoch  239 | Step  4780/ 5000 | Train 1.0250e-02 | Test 1.2058e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 1.33e-04 | 3.6s
# Epoch  240 | Step  4800/ 5000 | Train 1.0222e-02 | Test 1.1989e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 1.27e-04 | 3.4s
# Epoch  241 | Step  4820/ 5000 | Train 1.0218e-02 | Test 1.2034e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 1.22e-04 | 3.4s
# Epoch  242 | Step  4840/ 5000 | Train 1.0184e-02 | Test 1.1964e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 1.17e-04 | 3.5s
# Epoch  243 | Step  4860/ 5000 | Train 1.0178e-02 | Test 1.1965e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 1.13e-04 | 3.4s
# Epoch  244 | Step  4880/ 5000 | Train 1.0158e-02 | Test 1.1930e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 1.10e-04 | 3.4s
# Epoch  245 | Step  4900/ 5000 | Train 1.0133e-02 | Test 1.1911e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 1.07e-04 | 3.5s
# Epoch  246 | Step  4920/ 5000 | Train 1.0114e-02 | Test 1.1903e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 1.04e-04 | 3.5s
# Epoch  247 | Step  4940/ 5000 | Train 1.0089e-02 | Test 1.1877e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 1.02e-04 | 3.5s
# Epoch  248 | Step  4960/ 5000 | Train 1.0089e-02 | Test 1.1842e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 1.01e-04 | 3.5s
# Epoch  249 | Step  4980/ 5000 | Train 1.0074e-02 | Test 1.1838e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 1.00e-04 | 3.6s
# Epoch  250 | Step  5000/ 5000 | Train 1.0054e-02 | Test 1.1799e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 1.00e-04 | 3.4s
# Reached target optimizer steps: 5000/5000
# Done. Best validation score: failure_rate=0.0000, test_loss=1.1799e-02 (epoch 250)
# Running detailed evaluation...
# Block evaluation profile: clean
# Block evaluation noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0048 +/- 0.0019  (max 0.0117)
# Rotation geo [rad]:  0.0130 +/- 0.0075  (max 0.0439)
# Lin vel RMSE [m/s]:  0.0129 +/- 0.0084
# Ang vel RMSE [r/s]:  0.0016 +/- 0.0008
# Components:  u=0.0177  v=0.0098  w=0.0039  p=0.0013  q=0.0014  r=0.0016
# SO(3) violation:  |det-1|=8.31e-02  ||RR^T-I||=1.85e-01
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# Block evaluation profile: nominal_eval
# Block evaluation noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0050 +/- 0.0021  (max 0.0132)
# Rotation geo [rad]:  0.0168 +/- 0.0083  (max 0.0551)
# Lin vel RMSE [m/s]:  0.0139 +/- 0.0080
# Ang vel RMSE [r/s]:  0.0036 +/- 0.0020
# Components:  u=0.0189  v=0.0105  w=0.0053  p=0.0051  q=0.0016  r=0.0020
# SO(3) violation:  |det-1|=8.31e-02  ||RR^T-I||=1.86e-01
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# Block evaluation profile: heading_biased_eval
# Block evaluation noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0065 +/- 0.0030  (max 0.0167)
# Rotation geo [rad]:  0.0382 +/- 0.0116  (max 0.0876)
# Lin vel RMSE [m/s]:  0.0152 +/- 0.0086
# Ang vel RMSE [r/s]:  0.0036 +/- 0.0020
# Components:  u=0.0198  v=0.0136  w=0.0055  p=0.0051  q=0.0016  r=0.0020
# SO(3) violation:  |det-1|=8.31e-02  ||RR^T-I||=1.85e-01
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Block Evaluation Relative To Clean
# ==================================================
# [nominal_eval]
# position_rmse: ratio=1.043  degradation=+4.3%
# rotation_geodesic: ratio=1.291  degradation=+29.1%
# velocity_rmse: ratio=1.075  degradation=+7.5%
# angular_rmse: ratio=2.215  degradation=+121.5%
# failure_rate: ratio=1.000  degradation=+0.0%
# [heading_biased_eval]
# position_rmse: ratio=1.368  degradation=+36.8%
# rotation_geodesic: ratio=2.935  degradation=+193.5%
# velocity_rmse: ratio=1.177  degradation=+17.7%
# angular_rmse: ratio=2.213  degradation=+121.3%
# failure_rate: ratio=1.000  degradation=+0.0%
# Running held-out trajectory evaluation...
# Held-out evaluation profile: clean
# Held-out evaluation noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0045 (median 0.0041, p95 0.0076)
# Rotation geo [rad]:  0.0099 (median 0.0091, p95 0.0175)
# Lin vel RMSE [m/s]:  0.0103  Ang vel RMSE [r/s]:  0.0014
# SO(3) violation:  |det-1|=6.92e-02  ||RR^T-I||=1.73e-01
# Noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# [CHIRP] pos=0.0032 m, rot=0.0087 rad, success=1.0000
# [OU] pos=0.0051 m, rot=0.0127 rad, success=1.0000
# [PRBS] pos=0.0046 m, rot=0.0080 rad, success=1.0000
# Held-out evaluation profile: nominal_eval
# Held-out evaluation noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0047 (median 0.0043, p95 0.0078)
# Rotation geo [rad]:  0.0145 (median 0.0140, p95 0.0208)
# Lin vel RMSE [m/s]:  0.0114  Ang vel RMSE [r/s]:  0.0034
# SO(3) violation:  |det-1|=6.94e-02  ||RR^T-I||=1.73e-01
# Noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# [CHIRP] pos=0.0034 m, rot=0.0135 rad, success=1.0000
# [OU] pos=0.0053 m, rot=0.0169 rad, success=1.0000
# [PRBS] pos=0.0048 m, rot=0.0129 rad, success=1.0000
# Held-out evaluation profile: degraded_eval
# Held-out evaluation noise budget: protocol=iid_noisy_ic | profile=degraded_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0054 (median 0.0050, p95 0.0085)
# Rotation geo [rad]:  0.0249 (median 0.0245, p95 0.0295)
# Lin vel RMSE [m/s]:  0.0139  Ang vel RMSE [r/s]:  0.0060
# SO(3) violation:  |det-1|=7.00e-02  ||RR^T-I||=1.75e-01
# Noise budget: protocol=iid_noisy_ic | profile=degraded_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250]
# [CHIRP] pos=0.0043 m, rot=0.0242 rad, success=1.0000
# [OU] pos=0.0059 m, rot=0.0268 rad, success=1.0000
# [PRBS] pos=0.0055 m, rot=0.0236 rad, success=1.0000
# Held-out evaluation profile: heading_biased_eval
# Held-out evaluation noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0061 (median 0.0058, p95 0.0089)
# Rotation geo [rad]:  0.0373 (median 0.0371, p95 0.0401)
# Lin vel RMSE [m/s]:  0.0125  Ang vel RMSE [r/s]:  0.0034
# SO(3) violation:  |det-1|=6.94e-02  ||RR^T-I||=1.73e-01
# Noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# [CHIRP] pos=0.0051 m, rot=0.0369 rad, success=1.0000
# [OU] pos=0.0065 m, rot=0.0385 rad, success=1.0000
# [PRBS] pos=0.0062 m, rot=0.0365 rad, success=1.0000
# ==================================================
# Held-Out Evaluation Relative To Clean
# ==================================================
# [nominal_eval]
# position_rmse: ratio=1.042  degradation=+4.2%
# rotation_geodesic: ratio=1.466  degradation=+46.6%
# velocity_rmse: ratio=1.105  degradation=+10.5%
# angular_rmse: ratio=2.340  degradation=+134.0%
# success_rate: ratio=1.000  degradation=+0.0%
# trajectory_failure_rate: ratio=1.000  degradation=+0.0%
# [degraded_eval]
# position_rmse: ratio=1.199  degradation=+19.9%
# rotation_geodesic: ratio=2.520  degradation=+152.0%
# velocity_rmse: ratio=1.348  degradation=+34.8%
# angular_rmse: ratio=4.215  degradation=+321.5%
# success_rate: ratio=1.000  degradation=+0.0%
# trajectory_failure_rate: ratio=1.000  degradation=+0.0%
# [heading_biased_eval]
# position_rmse: ratio=1.350  degradation=+35.0%
# rotation_geodesic: ratio=3.772  degradation=+277.2%
# velocity_rmse: ratio=1.213  degradation=+21.3%
# angular_rmse: ratio=2.340  degradation=+134.0%
# success_rate: ratio=1.000  degradation=+0.0%
# trajectory_failure_rate: ratio=1.000  degradation=+0.0%
#
# Training finished. Results: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42
# Training sweep complete.
# Manifest: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate/runs.tsv
# Next step:
#   scripts/batch_eval_models.sh --suite-dir "/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate"
#
# Training complete.
# Suite directory: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate
# Next step:
#   bash scripts/eval_all_models_noise_profile.sh --suite-dir "/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate"
# [audit] /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate
#                                                 suite_name    group         model_type  seed train_noise_protocol  best_epoch  best_loss  noise_warmup_epochs  noise_ramp_epochs  noise_mix_ratio  epoch_scale_at_best  is_effectively_clean_at_best
# sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate baseline blackbox_fullstate    42                clean         250   0.011799                   20                 80              0.5                  0.0                          True
# [validate_v4] skipped: v4lite not in PHASE1A_PROTOCOLS=clean

# %%
os.environ["MODE"] = "smoke1_eval"
# !bash scripts/run_phase1a_oc_v4lite.sh
# Out:
# [phase1a]
# MODE=smoke1_eval
# RUN_TAG=t2_wpfrag_blackbox_fullstate
# DATASET=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# DEVICE=cuda
# PHASE1A_MODELS=blackbox_fullstate
# PHASE1A_PROTOCOLS=clean
# SMOKE1_MODELS=blackbox_fullstate
# SMOKE_SEEDS=42
# DECISION_SEEDS=42 43 44 45 46
# NOISE_REFERENCE=remus100_dr
# PHASE1A_LOG_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_logs/t2_wpfrag_blackbox_fullstate
# PHASE1A_METADATA_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_metadata_t2_wpfrag_blackbox_fullstate
# [eval] suite=sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate eval_protocol=iid_noisy_ic profiles=clean nominal_eval degraded_eval heading_biased_eval
# Suite directory: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate
# Manifest: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate/runs.tsv
# Mode: resampled
# [eval] baseline_blackbox_fullstate_seed42
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=clean | noise_protocol=clean | noise_budget=protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000] | scenarios=PRBS,CHIRP,OU | trajectories=18 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_115812/clean
# [scenario 1/3] PRBS | 6 trajectories
# [1/18] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=12m26.6s
# [5/18] PRBS seed=46 done | reason=pred_divergence | sim_time=19.35s | eta=1m54.2s
# [6/18] PRBS seed=47 done | reason=pred_divergence | sim_time=15.15s | eta=1m27.9s
# [scenario done] PRBS | completed=1/6 | gt_div=0 | model_fail=5 | H=60.0s cond_n=1/6 | pos_med=128.9447 m | pos_p95=128.9447 m | rot_med=3.0673 rad | completion=0.167 | elapsed=44.0s
# [scenario 2/3] CHIRP | 6 trajectories
# [7/18] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=2m18.4s
# [11/18] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=56.0s
# [12/18] CHIRP seed=100047 done | reason=completed | sim_time=60.00s | eta=44.0s
# [scenario done] CHIRP | completed=4/6 | gt_div=0 | model_fail=2 | H=60.0s cond_n=4/6 | pos_med=105.2749 m | pos_p95=141.9824 m | rot_med=2.9290 rad | completion=0.667 | elapsed=1m28.1s
# [scenario 3/3] OU | 6 trajectories
# [13/18] OU seed=200042 done | reason=pred_divergence | sim_time=29.35s | eta=51.0s
# [17/18] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=7.8s
# [18/18] OU seed=200047 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=4/6 | gt_div=0 | model_fail=2 | H=60.0s cond_n=4/6 | pos_med=66.5365 m | pos_p95=81.2954 m | rot_med=2.9937 rad | completion=0.667 | elapsed=2m12.6s
# Benchmark finished in 2m25.8s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_115812/clean
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: Full-State Black-Box [baseline/core]
# Canonical model type: blackbox_fullstate
# Energy semantics: not_comparable
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 6
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=11.9274 m | pos p95=17.3591 m | rot median=2.9973 rad | total vel median=0.5385 m/s | rel vel median=0.2000 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=41.0432 m | pos p95=68.7949 m | rot median=2.9432 rad | total vel median=0.7705 m/s | rel vel median=0.4812 m/s | cond_n=12/18 | completion=0.667 | gt_fail_by_h=0.000 | model_fail_by_h=0.333
# H=60.0s | pos median=76.3006 m | pos p95=139.7079 m | rot median=3.0090 rad | total vel median=0.8219 m/s | rel vel median=0.5114 m/s | cond_n=9/18 | completion=0.500 | gt_fail_by_h=0.000 | model_fail_by_h=0.500
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=18 | completed=9 (0.500) | gt_divergence=0 (0.000) | pred_divergence=9 (0.500) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=6 | completed=1 (0.167) | gt_divergence=0 (0.000) | pred_divergence=5 (0.833) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=11.9274 m | pos p95=16.9815 m | rot median=3.0227 rad | total vel median=0.7584 m/s | rel vel median=0.2050 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=66.7055 m | pos p95=70.8843 m | rot median=3.0766 rad | total vel median=1.0218 m/s | rel vel median=0.4071 m/s | cond_n=3/6 | completion=0.500 | gt_fail_by_h=0.000 | model_fail_by_h=0.500
#   H=60.0s | pos median=128.9447 m | pos p95=128.9447 m | rot median=3.0673 rad | total vel median=1.2775 m/s | rel vel median=0.7416 m/s | cond_n=1/6 | completion=0.167 | gt_fail_by_h=0.000 | model_fail_by_h=0.833
#
# CHIRP
#   n=6 | completed=4 (0.667) | gt_divergence=0 (0.000) | pred_divergence=2 (0.333) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=11.2019 m | pos p95=15.9452 m | rot median=3.0035 rad | total vel median=0.5645 m/s | rel vel median=0.2581 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=45.6456 m | pos p95=59.7655 m | rot median=2.8778 rad | total vel median=1.1164 m/s | rel vel median=0.6686 m/s | cond_n=4/6 | completion=0.667 | gt_fail_by_h=0.000 | model_fail_by_h=0.333
#   H=60.0s | pos median=105.2749 m | pos p95=141.9824 m | rot median=2.9290 rad | total vel median=0.8745 m/s | rel vel median=0.4707 m/s | cond_n=4/6 | completion=0.667 | gt_fail_by_h=0.000 | model_fail_by_h=0.333
#
# OU
#   n=6 | completed=4 (0.667) | gt_divergence=0 (0.000) | pred_divergence=2 (0.333) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=11.5334 m | pos p95=17.1613 m | rot median=2.9310 rad | total vel median=0.2080 m/s | rel vel median=0.1508 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=33.8626 m | pos p95=41.6084 m | rot median=2.7821 rad | total vel median=0.4155 m/s | rel vel median=0.4072 m/s | cond_n=5/6 | completion=0.833 | gt_fail_by_h=0.000 | model_fail_by_h=0.167
#   H=60.0s | pos median=66.5365 m | pos p95=81.2954 m | rot median=2.9937 rad | total vel median=0.7158 m/s | rel vel median=0.7177 m/s | cond_n=4/6 | completion=0.667 | gt_fail_by_h=0.000 | model_fail_by_h=0.333
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Earliest rollout failures
#   PRBS seed=47 | reason=pred_divergence | sim_time=15.15s | pos=nan m | rot=nan rad | total_vel_violation=0
#   CHIRP seed=100044 | reason=pred_divergence | sim_time=17.95s | pos=nan m | rot=nan rad | total_vel_violation=0
#   PRBS seed=46 | reason=pred_divergence | sim_time=19.35s | pos=nan m | rot=nan rad | total_vel_violation=0
#   CHIRP seed=100043 | reason=pred_divergence | sim_time=23.15s | pos=nan m | rot=nan rad | total_vel_violation=0
#   PRBS seed=43 | reason=pred_divergence | sim_time=28.15s | pos=nan m | rot=nan rad | total_vel_violation=0
#
# Largest completed terminal errors
#   CHIRP seed=100045 | reason=completed | sim_time=60.00s | pos=143.3470 m | rot=2.8255 rad | total_vel_violation=0
#   CHIRP seed=100042 | reason=completed | sim_time=60.00s | pos=134.2492 m | rot=2.6044 rad | total_vel_violation=0
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=128.9447 m | rot=3.0673 rad | total_vel_violation=1
#   OU seed=200044 | reason=completed | sim_time=60.00s | pos=83.2484 m | rot=2.9784 rad | total_vel_violation=1
#   CHIRP seed=100046 | reason=completed | sim_time=60.00s | pos=76.3006 m | rot=3.0326 rad | total_vel_violation=0
#
# Completed rollouts with velocity violations
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=128.9447 m | rot=3.0673 rad | total_vel_violation=1
#   OU seed=200044 | reason=completed | sim_time=60.00s | pos=83.2484 m | rot=2.9784 rad | total_vel_violation=1
#   OU seed=200047 | reason=completed | sim_time=60.00s | pos=62.8449 m | rot=3.1211 rad | total_vel_violation=1
#   OU seed=200045 | reason=completed | sim_time=60.00s | pos=34.9906 m | rot=3.0090 rad | total_vel_violation=1
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# PRBS seed=47 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_115812/clean/diagnostic_plots/rollout_failure_PRBS_seed47.png
# CHIRP seed=100044 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_115812/clean/diagnostic_plots/rollout_failure_CHIRP_seed100044.png
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=nominal_eval | noise_protocol=iid_noisy_ic | noise_budget=protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | scenarios=PRBS,CHIRP,OU | trajectories=18 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_115812/nominal_eval
# [scenario 1/3] PRBS | 6 trajectories
# [1/18] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=1m09.4s
# [5/18] PRBS seed=46 done | reason=pred_divergence | sim_time=19.35s | eta=10.6s
# [6/18] PRBS seed=47 done | reason=pred_divergence | sim_time=15.15s | eta=8.2s
# [scenario done] PRBS | completed=1/6 | gt_div=0 | model_fail=5 | H=60.0s cond_n=1/6 | pos_med=128.6552 m | pos_p95=128.6552 m | rot_med=3.0664 rad | completion=0.167 | elapsed=4.1s
# [scenario 2/3] CHIRP | 6 trajectories
# [7/18] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=12.7s
# [11/18] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=5.1s
# [12/18] CHIRP seed=100047 done | reason=completed | sim_time=60.00s | eta=4.0s
# [scenario done] CHIRP | completed=4/6 | gt_div=0 | model_fail=2 | H=60.0s cond_n=4/6 | pos_med=105.2450 m | pos_p95=141.7733 m | rot_med=2.9281 rad | completion=0.667 | elapsed=8.1s
# [scenario 3/3] OU | 6 trajectories
# [13/18] OU seed=200042 done | reason=pred_divergence | sim_time=29.35s | eta=4.7s
# [17/18] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=0.7s
# [18/18] OU seed=200047 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=4/6 | gt_div=0 | model_fail=2 | H=60.0s cond_n=4/6 | pos_med=66.6177 m | pos_p95=81.3375 m | rot_med=2.9941 rad | completion=0.667 | elapsed=12.2s
# Benchmark finished in 24.7s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_115812/nominal_eval
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: Full-State Black-Box [baseline/core]
# Canonical model type: blackbox_fullstate
# Energy semantics: not_comparable
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 6
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=11.9433 m | pos p95=17.3581 m | rot median=2.9970 rad | total vel median=0.5403 m/s | rel vel median=0.1965 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=40.9504 m | pos p95=68.6688 m | rot median=2.9416 rad | total vel median=0.7712 m/s | rel vel median=0.4851 m/s | cond_n=12/18 | completion=0.667 | gt_fail_by_h=0.000 | model_fail_by_h=0.333
# H=60.0s | pos median=76.2946 m | pos p95=139.5445 m | rot median=3.0098 rad | total vel median=0.8220 m/s | rel vel median=0.5116 m/s | cond_n=9/18 | completion=0.500 | gt_fail_by_h=0.000 | model_fail_by_h=0.500
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=18 | completed=9 (0.500) | gt_divergence=0 (0.000) | pred_divergence=9 (0.500) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=6 | completed=1 (0.167) | gt_divergence=0 (0.000) | pred_divergence=5 (0.833) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=11.9433 m | pos p95=16.9903 m | rot median=3.0225 rad | total vel median=0.7569 m/s | rel vel median=0.2037 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=66.6242 m | pos p95=70.7134 m | rot median=3.0770 rad | total vel median=1.0157 m/s | rel vel median=0.3970 m/s | cond_n=3/6 | completion=0.500 | gt_fail_by_h=0.000 | model_fail_by_h=0.500
#   H=60.0s | pos median=128.6552 m | pos p95=128.6552 m | rot median=3.0664 rad | total vel median=1.2786 m/s | rel vel median=0.7406 m/s | cond_n=1/6 | completion=0.167 | gt_fail_by_h=0.000 | model_fail_by_h=0.833
#
# CHIRP
#   n=6 | completed=4 (0.667) | gt_divergence=0 (0.000) | pred_divergence=2 (0.333) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=11.1958 m | pos p95=15.9344 m | rot median=3.0027 rad | total vel median=0.5596 m/s | rel vel median=0.2553 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=45.5600 m | pos p95=59.7036 m | rot median=2.8755 rad | total vel median=1.1168 m/s | rel vel median=0.6694 m/s | cond_n=4/6 | completion=0.667 | gt_fail_by_h=0.000 | model_fail_by_h=0.333
#   H=60.0s | pos median=105.2450 m | pos p95=141.7733 m | rot median=2.9281 rad | total vel median=0.8747 m/s | rel vel median=0.4702 m/s | cond_n=4/6 | completion=0.667 | gt_fail_by_h=0.000 | model_fail_by_h=0.333
#
# OU
#   n=6 | completed=4 (0.667) | gt_divergence=0 (0.000) | pred_divergence=2 (0.333) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=11.5482 m | pos p95=17.1659 m | rot median=2.9287 rad | total vel median=0.2082 m/s | rel vel median=0.1522 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=33.8811 m | pos p95=41.4723 m | rot median=2.7782 rad | total vel median=0.4152 m/s | rel vel median=0.4066 m/s | cond_n=5/6 | completion=0.833 | gt_fail_by_h=0.000 | model_fail_by_h=0.167
#   H=60.0s | pos median=66.6177 m | pos p95=81.3375 m | rot median=2.9941 rad | total vel median=0.7161 m/s | rel vel median=0.7190 m/s | cond_n=4/6 | completion=0.667 | gt_fail_by_h=0.000 | model_fail_by_h=0.333
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Earliest rollout failures
#   PRBS seed=47 | reason=pred_divergence | sim_time=15.15s | pos=nan m | rot=nan rad | total_vel_violation=0
#   CHIRP seed=100044 | reason=pred_divergence | sim_time=18.15s | pos=nan m | rot=nan rad | total_vel_violation=0
#   PRBS seed=46 | reason=pred_divergence | sim_time=19.35s | pos=nan m | rot=nan rad | total_vel_violation=0
#   CHIRP seed=100043 | reason=pred_divergence | sim_time=23.15s | pos=nan m | rot=nan rad | total_vel_violation=0
#   PRBS seed=43 | reason=pred_divergence | sim_time=28.15s | pos=nan m | rot=nan rad | total_vel_violation=0
#
# Largest completed terminal errors
#   CHIRP seed=100045 | reason=completed | sim_time=60.00s | pos=143.1106 m | rot=2.8237 rad | total_vel_violation=0
#   CHIRP seed=100042 | reason=completed | sim_time=60.00s | pos=134.1953 m | rot=2.6044 rad | total_vel_violation=0
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=128.6552 m | rot=3.0664 rad | total_vel_violation=1
#   OU seed=200044 | reason=completed | sim_time=60.00s | pos=83.3006 m | rot=2.9784 rad | total_vel_violation=1
#   CHIRP seed=100046 | reason=completed | sim_time=60.00s | pos=76.2946 m | rot=3.0326 rad | total_vel_violation=0
#
# Completed rollouts with velocity violations
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=128.6552 m | rot=3.0664 rad | total_vel_violation=1
#   OU seed=200044 | reason=completed | sim_time=60.00s | pos=83.3006 m | rot=2.9784 rad | total_vel_violation=1
#   OU seed=200047 | reason=completed | sim_time=60.00s | pos=63.0217 m | rot=3.1206 rad | total_vel_violation=1
#   OU seed=200045 | reason=completed | sim_time=60.00s | pos=34.9540 m | rot=3.0098 rad | total_vel_violation=1
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# PRBS seed=47 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_115812/nominal_eval/diagnostic_plots/rollout_failure_PRBS_seed47.png
# CHIRP seed=100044 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_115812/nominal_eval/diagnostic_plots/rollout_failure_CHIRP_seed100044.png
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=degraded_eval | noise_protocol=iid_noisy_ic | noise_budget=protocol=iid_noisy_ic | profile=degraded_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250] | scenarios=PRBS,CHIRP,OU | trajectories=18 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_115812/degraded_eval
# [scenario 1/3] PRBS | 6 trajectories
# [1/18] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=1m05.7s
# [5/18] PRBS seed=46 done | reason=pred_divergence | sim_time=19.35s | eta=10.1s
# [6/18] PRBS seed=47 done | reason=pred_divergence | sim_time=15.15s | eta=7.8s
# [scenario done] PRBS | completed=1/6 | gt_div=0 | model_fail=5 | H=60.0s cond_n=1/6 | pos_med=128.3187 m | pos_p95=128.3187 m | rot_med=3.0653 rad | completion=0.167 | elapsed=3.9s
# [scenario 2/3] CHIRP | 6 trajectories
# [7/18] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=12.4s
# [11/18] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=5.0s
# [12/18] CHIRP seed=100047 done | reason=completed | sim_time=60.00s | eta=4.0s
# [scenario done] CHIRP | completed=4/6 | gt_div=0 | model_fail=2 | H=60.0s cond_n=4/6 | pos_med=105.2151 m | pos_p95=141.5629 m | rot_med=2.9272 rad | completion=0.667 | elapsed=7.9s
# [scenario 3/3] OU | 6 trajectories
# [13/18] OU seed=200042 done | reason=pred_divergence | sim_time=29.35s | eta=4.6s
# [17/18] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=0.7s
# [18/18] OU seed=200047 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=4/6 | gt_div=0 | model_fail=2 | H=60.0s cond_n=4/6 | pos_med=66.6998 m | pos_p95=81.3757 m | rot_med=2.9945 rad | completion=0.667 | elapsed=12.0s
# Benchmark finished in 24.5s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_115812/degraded_eval
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: Full-State Black-Box [baseline/core]
# Canonical model type: blackbox_fullstate
# Energy semantics: not_comparable
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 6
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=11.9602 m | pos p95=17.3526 m | rot median=2.9969 rad | total vel median=0.5420 m/s | rel vel median=0.1927 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=40.8535 m | pos p95=68.5216 m | rot median=2.9399 rad | total vel median=0.7717 m/s | rel vel median=0.4900 m/s | cond_n=12/18 | completion=0.667 | gt_fail_by_h=0.000 | model_fail_by_h=0.333
# H=60.0s | pos median=76.2890 m | pos p95=139.3800 m | rot median=3.0105 rad | total vel median=0.8220 m/s | rel vel median=0.5119 m/s | cond_n=9/18 | completion=0.500 | gt_fail_by_h=0.000 | model_fail_by_h=0.500
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=18 | completed=9 (0.500) | gt_divergence=0 (0.000) | pred_divergence=9 (0.500) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=6 | completed=1 (0.167) | gt_divergence=0 (0.000) | pred_divergence=5 (0.833) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=11.9602 m | pos p95=17.0010 m | rot median=3.0223 rad | total vel median=0.7556 m/s | rel vel median=0.2018 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=66.5411 m | pos p95=70.5020 m | rot median=3.0773 rad | total vel median=1.0100 m/s | rel vel median=0.3861 m/s | cond_n=3/6 | completion=0.500 | gt_fail_by_h=0.000 | model_fail_by_h=0.500
#   H=60.0s | pos median=128.3187 m | pos p95=128.3187 m | rot median=3.0653 rad | total vel median=1.2806 m/s | rel vel median=0.7396 m/s | cond_n=1/6 | completion=0.167 | gt_fail_by_h=0.000 | model_fail_by_h=0.833
#
# CHIRP
#   n=6 | completed=4 (0.667) | gt_divergence=0 (0.000) | pred_divergence=2 (0.333) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=11.1902 m | pos p95=15.9307 m | rot median=3.0020 rad | total vel median=0.5546 m/s | rel vel median=0.2524 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=45.4744 m | pos p95=59.6417 m | rot median=2.8731 rad | total vel median=1.1171 m/s | rel vel median=0.6703 m/s | cond_n=4/6 | completion=0.667 | gt_fail_by_h=0.000 | model_fail_by_h=0.333
#   H=60.0s | pos median=105.2151 m | pos p95=141.5629 m | rot median=2.9272 rad | total vel median=0.8749 m/s | rel vel median=0.4698 m/s | cond_n=4/6 | completion=0.667 | gt_fail_by_h=0.000 | model_fail_by_h=0.333
#
# OU
#   n=6 | completed=4 (0.667) | gt_divergence=0 (0.000) | pred_divergence=2 (0.333) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=11.5642 m | pos p95=17.1660 m | rot median=2.9261 rad | total vel median=0.2085 m/s | rel vel median=0.1536 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=33.8969 m | pos p95=41.3362 m | rot median=2.7735 rad | total vel median=0.4149 m/s | rel vel median=0.4061 m/s | cond_n=5/6 | completion=0.833 | gt_fail_by_h=0.000 | model_fail_by_h=0.167
#   H=60.0s | pos median=66.6998 m | pos p95=81.3757 m | rot median=2.9945 rad | total vel median=0.7162 m/s | rel vel median=0.7199 m/s | cond_n=4/6 | completion=0.667 | gt_fail_by_h=0.000 | model_fail_by_h=0.333
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Earliest rollout failures
#   PRBS seed=47 | reason=pred_divergence | sim_time=15.15s | pos=nan m | rot=nan rad | total_vel_violation=0
#   CHIRP seed=100044 | reason=pred_divergence | sim_time=18.35s | pos=nan m | rot=nan rad | total_vel_violation=0
#   PRBS seed=46 | reason=pred_divergence | sim_time=19.35s | pos=nan m | rot=nan rad | total_vel_violation=0
#   CHIRP seed=100043 | reason=pred_divergence | sim_time=23.15s | pos=nan m | rot=nan rad | total_vel_violation=0
#   PRBS seed=43 | reason=pred_divergence | sim_time=28.15s | pos=nan m | rot=nan rad | total_vel_violation=0
#
# Largest completed terminal errors
#   CHIRP seed=100045 | reason=completed | sim_time=60.00s | pos=142.8726 m | rot=2.8218 rad | total_vel_violation=0
#   CHIRP seed=100042 | reason=completed | sim_time=60.00s | pos=134.1411 m | rot=2.6044 rad | total_vel_violation=0
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=128.3187 m | rot=3.0653 rad | total_vel_violation=1
#   OU seed=200044 | reason=completed | sim_time=60.00s | pos=83.3480 m | rot=2.9785 rad | total_vel_violation=1
#   CHIRP seed=100046 | reason=completed | sim_time=60.00s | pos=76.2890 m | rot=3.0326 rad | total_vel_violation=0
#
# Completed rollouts with velocity violations
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=128.3187 m | rot=3.0653 rad | total_vel_violation=1
#   OU seed=200044 | reason=completed | sim_time=60.00s | pos=83.3480 m | rot=2.9785 rad | total_vel_violation=1
#   OU seed=200047 | reason=completed | sim_time=60.00s | pos=63.2005 m | rot=3.1200 rad | total_vel_violation=1
#   OU seed=200045 | reason=completed | sim_time=60.00s | pos=34.9360 m | rot=3.0105 rad | total_vel_violation=1
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# PRBS seed=47 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_115812/degraded_eval/diagnostic_plots/rollout_failure_PRBS_seed47.png
# CHIRP seed=100044 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_115812/degraded_eval/diagnostic_plots/rollout_failure_CHIRP_seed100044.png
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=heading_biased_eval | noise_protocol=iid_noisy_ic | noise_budget=protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350] | scenarios=PRBS,CHIRP,OU | trajectories=18 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_115812/heading_biased_eval
# [scenario 1/3] PRBS | 6 trajectories
# [1/18] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=1m05.4s
# [5/18] PRBS seed=46 done | reason=pred_divergence | sim_time=19.35s | eta=10.0s
# [6/18] PRBS seed=47 done | reason=pred_divergence | sim_time=15.15s | eta=7.7s
# [scenario done] PRBS | completed=1/6 | gt_div=0 | model_fail=5 | H=60.0s cond_n=1/6 | pos_med=128.9307 m | pos_p95=128.9307 m | rot_med=3.0674 rad | completion=0.167 | elapsed=3.9s
# [scenario 2/3] CHIRP | 6 trajectories
# [7/18] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=12.2s
# [11/18] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=5.0s
# [12/18] CHIRP seed=100047 done | reason=completed | sim_time=60.00s | eta=3.9s
# [scenario done] CHIRP | completed=4/6 | gt_div=0 | model_fail=2 | H=60.0s cond_n=4/6 | pos_med=105.2043 m | pos_p95=141.6771 m | rot_med=2.9279 rad | completion=0.667 | elapsed=7.8s
# [scenario 3/3] OU | 6 trajectories
# [13/18] OU seed=200042 done | reason=pred_divergence | sim_time=29.15s | eta=4.5s
# [17/18] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=0.7s
# [18/18] OU seed=200047 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=4/6 | gt_div=0 | model_fail=2 | H=60.0s cond_n=4/6 | pos_med=66.8836 m | pos_p95=81.3302 m | rot_med=2.9932 rad | completion=0.667 | elapsed=11.8s
# Benchmark finished in 24.4s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_115812/heading_biased_eval
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: Full-State Black-Box [baseline/core]
# Canonical model type: blackbox_fullstate
# Energy semantics: not_comparable
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 6
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=11.9427 m | pos p95=17.2990 m | rot median=2.9983 rad | total vel median=0.5434 m/s | rel vel median=0.1964 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=40.8646 m | pos p95=68.7363 m | rot median=2.9404 rad | total vel median=0.7738 m/s | rel vel median=0.4805 m/s | cond_n=12/18 | completion=0.667 | gt_fail_by_h=0.000 | model_fail_by_h=0.333
# H=60.0s | pos median=76.2054 m | pos p95=139.4789 m | rot median=3.0080 rad | total vel median=0.8219 m/s | rel vel median=0.5121 m/s | cond_n=9/18 | completion=0.500 | gt_fail_by_h=0.000 | model_fail_by_h=0.500
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=18 | completed=9 (0.500) | gt_divergence=0 (0.000) | pred_divergence=9 (0.500) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=6 | completed=1 (0.167) | gt_divergence=0 (0.000) | pred_divergence=5 (0.833) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=11.9427 m | pos p95=16.9908 m | rot median=3.0224 rad | total vel median=0.7557 m/s | rel vel median=0.2030 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=66.6137 m | pos p95=70.8589 m | rot median=3.0769 rad | total vel median=1.0139 m/s | rel vel median=0.3919 m/s | cond_n=3/6 | completion=0.500 | gt_fail_by_h=0.000 | model_fail_by_h=0.500
#   H=60.0s | pos median=128.9307 m | pos p95=128.9307 m | rot median=3.0674 rad | total vel median=1.2774 m/s | rel vel median=0.7417 m/s | cond_n=1/6 | completion=0.167 | gt_fail_by_h=0.000 | model_fail_by_h=0.833
#
# CHIRP
#   n=6 | completed=4 (0.667) | gt_divergence=0 (0.000) | pred_divergence=2 (0.333) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=11.2036 m | pos p95=15.8691 m | rot median=3.0022 rad | total vel median=0.5549 m/s | rel vel median=0.2539 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=45.4750 m | pos p95=59.7024 m | rot median=2.8744 rad | total vel median=1.1175 m/s | rel vel median=0.6687 m/s | cond_n=4/6 | completion=0.667 | gt_fail_by_h=0.000 | model_fail_by_h=0.333
#   H=60.0s | pos median=105.2043 m | pos p95=141.6771 m | rot median=2.9279 rad | total vel median=0.8751 m/s | rel vel median=0.4700 m/s | cond_n=4/6 | completion=0.667 | gt_fail_by_h=0.000 | model_fail_by_h=0.333
#
# OU
#   n=6 | completed=4 (0.667) | gt_divergence=0 (0.000) | pred_divergence=2 (0.333) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=11.5408 m | pos p95=17.1350 m | rot median=2.9129 rad | total vel median=0.2094 m/s | rel vel median=0.1525 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=33.8601 m | pos p95=41.4166 m | rot median=2.7697 rad | total vel median=0.4143 m/s | rel vel median=0.4072 m/s | cond_n=5/6 | completion=0.833 | gt_fail_by_h=0.000 | model_fail_by_h=0.167
#   H=60.0s | pos median=66.8836 m | pos p95=81.3302 m | rot median=2.9932 rad | total vel median=0.7153 m/s | rel vel median=0.7159 m/s | cond_n=4/6 | completion=0.667 | gt_fail_by_h=0.000 | model_fail_by_h=0.333
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Earliest rollout failures
#   PRBS seed=47 | reason=pred_divergence | sim_time=15.15s | pos=nan m | rot=nan rad | total_vel_violation=0
#   CHIRP seed=100044 | reason=pred_divergence | sim_time=18.35s | pos=nan m | rot=nan rad | total_vel_violation=0
#   PRBS seed=46 | reason=pred_divergence | sim_time=19.35s | pos=nan m | rot=nan rad | total_vel_violation=0
#   CHIRP seed=100043 | reason=pred_divergence | sim_time=23.35s | pos=nan m | rot=nan rad | total_vel_violation=0
#   PRBS seed=43 | reason=pred_divergence | sim_time=28.15s | pos=nan m | rot=nan rad | total_vel_violation=0
#
# Largest completed terminal errors
#   CHIRP seed=100045 | reason=completed | sim_time=60.00s | pos=142.9960 m | rot=2.8232 rad | total_vel_violation=0
#   CHIRP seed=100042 | reason=completed | sim_time=60.00s | pos=134.2033 m | rot=2.6045 rad | total_vel_violation=0
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=128.9307 m | rot=3.0674 rad | total_vel_violation=1
#   OU seed=200044 | reason=completed | sim_time=60.00s | pos=83.2597 m | rot=2.9784 rad | total_vel_violation=1
#   CHIRP seed=100046 | reason=completed | sim_time=60.00s | pos=76.2054 m | rot=3.0326 rad | total_vel_violation=0
#
# Completed rollouts with velocity violations
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=128.9307 m | rot=3.0674 rad | total_vel_violation=1
#   OU seed=200044 | reason=completed | sim_time=60.00s | pos=83.2597 m | rot=2.9784 rad | total_vel_violation=1
#   OU seed=200047 | reason=completed | sim_time=60.00s | pos=63.3704 m | rot=3.1200 rad | total_vel_violation=1
#   OU seed=200045 | reason=completed | sim_time=60.00s | pos=35.2130 m | rot=3.0080 rad | total_vel_violation=1
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# PRBS seed=47 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_115812/heading_biased_eval/diagnostic_plots/rollout_failure_PRBS_seed47.png
# CHIRP seed=100044 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_115812/heading_biased_eval/diagnostic_plots/rollout_failure_CHIRP_seed100044.png
# Batch evaluation complete.
# [eval] suite=sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate eval_protocol=v4_lite profiles=nominal_eval
# Suite directory: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate
# Manifest: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate/runs.tsv
# Mode: resampled
# [eval] baseline_blackbox_fullstate_seed42
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=nominal_eval | noise_protocol=v4_lite | noise_budget=protocol=v4_lite | profile=nominal_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | scenarios=PRBS,CHIRP,OU | trajectories=18 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_v4eval_traj6_seed42_20260525_120155
# [scenario 1/3] PRBS | 6 trajectories
# [1/18] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=1m13.1s
# [5/18] PRBS seed=46 done | reason=pred_divergence | sim_time=19.35s | eta=11.2s
# [6/18] PRBS seed=47 done | reason=pred_divergence | sim_time=15.15s | eta=8.6s
# [scenario done] PRBS | completed=1/6 | gt_div=0 | model_fail=5 | H=60.0s cond_n=1/6 | pos_med=129.1200 m | pos_p95=129.1200 m | rot_med=3.0679 rad | completion=0.167 | elapsed=4.3s
# [scenario 2/3] CHIRP | 6 trajectories
# [7/18] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=13.0s
# [11/18] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=5.3s
# [12/18] CHIRP seed=100047 done | reason=completed | sim_time=60.00s | eta=4.1s
# [scenario done] CHIRP | completed=4/6 | gt_div=0 | model_fail=2 | H=60.0s cond_n=4/6 | pos_med=105.2452 m | pos_p95=142.2402 m | rot_med=2.9303 rad | completion=0.667 | elapsed=8.3s
# [scenario 3/3] OU | 6 trajectories
# [13/18] OU seed=200042 done | reason=pred_divergence | sim_time=29.35s | eta=4.7s
# [17/18] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=0.7s
# [18/18] OU seed=200047 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=4/6 | gt_div=0 | model_fail=2 | H=60.0s cond_n=4/6 | pos_med=66.4666 m | pos_p95=81.2173 m | rot_med=2.9939 rad | completion=0.667 | elapsed=12.4s
# Benchmark finished in 25.6s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_v4eval_traj6_seed42_20260525_120155
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: Full-State Black-Box [baseline/core]
# Canonical model type: blackbox_fullstate
# Energy semantics: not_comparable
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 6
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=11.9238 m | pos p95=17.3713 m | rot median=2.9981 rad | total vel median=0.5380 m/s | rel vel median=0.2036 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=41.0952 m | pos p95=68.8275 m | rot median=2.9447 rad | total vel median=0.7701 m/s | rel vel median=0.4791 m/s | cond_n=12/18 | completion=0.667 | gt_fail_by_h=0.000 | model_fail_by_h=0.333
# H=60.0s | pos median=76.3480 m | pos p95=139.8585 m | rot median=3.0095 rad | total vel median=0.8219 m/s | rel vel median=0.5116 m/s | cond_n=9/18 | completion=0.500 | gt_fail_by_h=0.000 | model_fail_by_h=0.500
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=18 | completed=9 (0.500) | gt_divergence=0 (0.000) | pred_divergence=9 (0.500) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=6 | completed=1 (0.167) | gt_divergence=0 (0.000) | pred_divergence=5 (0.833) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=11.9238 m | pos p95=16.9692 m | rot median=3.0163 rad | total vel median=0.7571 m/s | rel vel median=0.2042 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=66.6758 m | pos p95=70.9792 m | rot median=3.0767 rad | total vel median=1.0302 m/s | rel vel median=0.4190 m/s | cond_n=3/6 | completion=0.500 | gt_fail_by_h=0.000 | model_fail_by_h=0.500
#   H=60.0s | pos median=129.1200 m | pos p95=129.1200 m | rot median=3.0679 rad | total vel median=1.2770 m/s | rel vel median=0.7423 m/s | cond_n=1/6 | completion=0.167 | gt_fail_by_h=0.000 | model_fail_by_h=0.833
#
# CHIRP
#   n=6 | completed=4 (0.667) | gt_divergence=0 (0.000) | pred_divergence=2 (0.333) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=11.2025 m | pos p95=15.9457 m | rot median=3.0043 rad | total vel median=0.5733 m/s | rel vel median=0.2615 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=45.7480 m | pos p95=59.7127 m | rot median=2.8807 rad | total vel median=1.1166 m/s | rel vel median=0.6682 m/s | cond_n=4/6 | completion=0.667 | gt_fail_by_h=0.000 | model_fail_by_h=0.333
#   H=60.0s | pos median=105.2452 m | pos p95=142.2402 m | rot median=2.9303 rad | total vel median=0.8747 m/s | rel vel median=0.4713 m/s | cond_n=4/6 | completion=0.667 | gt_fail_by_h=0.000 | model_fail_by_h=0.333
#
# OU
#   n=6 | completed=4 (0.667) | gt_divergence=0 (0.000) | pred_divergence=2 (0.333) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=11.5174 m | pos p95=17.1695 m | rot median=2.9344 rad | total vel median=0.2080 m/s | rel vel median=0.1508 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=33.8096 m | pos p95=41.6734 m | rot median=2.7817 rad | total vel median=0.4157 m/s | rel vel median=0.4076 m/s | cond_n=5/6 | completion=0.833 | gt_fail_by_h=0.000 | model_fail_by_h=0.167
#   H=60.0s | pos median=66.4666 m | pos p95=81.2173 m | rot median=2.9939 rad | total vel median=0.7159 m/s | rel vel median=0.7184 m/s | cond_n=4/6 | completion=0.667 | gt_fail_by_h=0.000 | model_fail_by_h=0.333
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Earliest rollout failures
#   PRBS seed=47 | reason=pred_divergence | sim_time=15.15s | pos=nan m | rot=nan rad | total_vel_violation=0
#   CHIRP seed=100044 | reason=pred_divergence | sim_time=17.95s | pos=nan m | rot=nan rad | total_vel_violation=0
#   PRBS seed=46 | reason=pred_divergence | sim_time=19.35s | pos=nan m | rot=nan rad | total_vel_violation=0
#   CHIRP seed=100043 | reason=pred_divergence | sim_time=23.15s | pos=nan m | rot=nan rad | total_vel_violation=0
#   PRBS seed=43 | reason=pred_divergence | sim_time=28.15s | pos=nan m | rot=nan rad | total_vel_violation=0
#
# Largest completed terminal errors
#   CHIRP seed=100045 | reason=completed | sim_time=60.00s | pos=143.6692 m | rot=2.8281 rad | total_vel_violation=0
#   CHIRP seed=100042 | reason=completed | sim_time=60.00s | pos=134.1425 m | rot=2.6044 rad | total_vel_violation=0
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=129.1200 m | rot=3.0679 rad | total_vel_violation=1
#   OU seed=200044 | reason=completed | sim_time=60.00s | pos=83.1535 m | rot=2.9784 rad | total_vel_violation=1
#   CHIRP seed=100046 | reason=completed | sim_time=60.00s | pos=76.3480 m | rot=3.0326 rad | total_vel_violation=0
#
# Completed rollouts with velocity violations
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=129.1200 m | rot=3.0679 rad | total_vel_violation=1
#   OU seed=200044 | reason=completed | sim_time=60.00s | pos=83.1535 m | rot=2.9784 rad | total_vel_violation=1
#   OU seed=200047 | reason=completed | sim_time=60.00s | pos=62.6878 m | rot=3.1214 rad | total_vel_violation=1
#   OU seed=200045 | reason=completed | sim_time=60.00s | pos=34.9323 m | rot=3.0095 rad | total_vel_violation=1
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# PRBS seed=47 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_v4eval_traj6_seed42_20260525_120155/diagnostic_plots/rollout_failure_PRBS_seed47.png
# CHIRP seed=100044 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_v4eval_traj6_seed42_20260525_120155/diagnostic_plots/rollout_failure_CHIRP_seed100044.png
# Batch evaluation complete.
# + /usr/bin/python3 /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/scripts/register_existing_runs_as_suite.py --suite-dir /content/_proxy_suites/sweep_oc_phase1a_smoke1_proxy_t2_wpfrag_blackbox_fullstate --run baseline blackbox_fullstate 42 clean__baseline_blackbox_fullstate_seed42 /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42
# Registered suite: /content/_proxy_suites/sweep_oc_phase1a_smoke1_proxy_t2_wpfrag_blackbox_fullstate
# Runs: 1
# Manifest: /content/_proxy_suites/sweep_oc_phase1a_smoke1_proxy_t2_wpfrag_blackbox_fullstate/runs.tsv
# + /usr/bin/python3 /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/scripts/summarize_sweep.py --suite-dir /content/_proxy_suites/sweep_oc_phase1a_smoke1_proxy_t2_wpfrag_blackbox_fullstate
# + /usr/bin/python3 /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/scripts/build_experiment_report.py --suite-dir /content/_proxy_suites/sweep_oc_phase1a_smoke1_proxy_t2_wpfrag_blackbox_fullstate
# /content/_proxy_suites/sweep_oc_phase1a_smoke1_proxy_t2_wpfrag_blackbox_fullstate/phase1a_decision_brief.md
# [proxy] local: /content/_proxy_suites/sweep_oc_phase1a_smoke1_proxy_t2_wpfrag_blackbox_fullstate

# %% [markdown]
# ## 3. Decision train (clean x 5 seeds)
# The 5 evidence-bearing clean training runs for this black-box model.

# %%
os.environ["MODE"] = "decision_train"
# !bash scripts/run_phase1a_oc_v4lite.sh
# Out:
# [phase1a]
# MODE=decision_train
# RUN_TAG=t2_wpfrag_blackbox_fullstate
# DATASET=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# DEVICE=cuda
# PHASE1A_MODELS=blackbox_fullstate
# PHASE1A_PROTOCOLS=clean
# SMOKE1_MODELS=blackbox_fullstate
# SMOKE_SEEDS=42
# DECISION_SEEDS=42 43 44 45 46
# NOISE_REFERENCE=remus100_dr
# PHASE1A_LOG_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_logs/t2_wpfrag_blackbox_fullstate
# PHASE1A_METADATA_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_metadata_t2_wpfrag_blackbox_fullstate
# [train] suite=sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate models=blackbox_fullstate seeds=42 43 44 45 46 protocol=auto
# Training all models with profile-based noisy IC.
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Group: all
# Explicit models: blackbox_fullstate
# Seeds: 42 43 44 45 46
# Noise config: protocol=auto, profile=clean, scale=1.0, warmup=20, ramp=80, mix_ratio=0.5
# Auto-eval profiles: block=[clean nominal_eval heading_biased_eval] heldout=[clean nominal_eval degraded_eval heading_biased_eval]
# Suite directory: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Models (1): blackbox_fullstate
# Seeds: 42 43 44 45 46
# [train] baseline_blackbox_fullstate_seed42
# Loading dataset...
# Loaded: 83850 train, 21000 test, t_eval=[0.   0.05 0.1  0.15 0.2 ]
# Dataset split: trajectory | train trajectories: 559 | test trajectories: 140
# Dataset ID: d0be9434
# Dataset path: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl | velocity convention: body_total | state dim: 27
# Position std: [0.1508, 0.1400, 0.0370]
# Velocity std: u=0.4722, v=0.0898, w=0.0718, p=0.0248, q=0.0906, r=0.0526
# Actuator std: a0=0.1543, a1=0.1555, a2=299.0037
# Training noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# Model: Full-State Black-Box [baseline/core] | canonical type: blackbox_fullstate
# Model parameters: 61,538
# Training dataset: id=d0be9434 | path=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Mass matrix initialized from physics
# Training: epochs<=300, target_steps=5000, warmup_steps=400, lr=6.00e-03 -> 1.00e-04, solver=rk4, so3_reg=1.00e-03
# Train samples: 83850, Test samples: 21000
# Epoch    1 | Step    20/ 5000 | Train 1.4444e+00 | Test 1.5934e+00 | SO3(train/test) 7.32e-04/3.56e-03 | Fail(train/test) 0/0 | LR 4.10e-04 | 3.9s
# Epoch    2 | Step    40/ 5000 | Train 1.3100e+00 | Test 1.1446e+00 | SO3(train/test) 3.25e-02/1.21e-01 | Fail(train/test) 0/0 | LR 7.05e-04 | 3.5s
# Epoch    3 | Step    60/ 5000 | Train 7.2322e-01 | Test 5.5477e-01 | SO3(train/test) 3.20e-01/3.20e-01 | Fail(train/test) 0/0 | LR 1.00e-03 | 3.5s
# Epoch    4 | Step    80/ 5000 | Train 5.1359e-01 | Test 4.7452e-01 | SO3(train/test) 2.21e-01/1.89e-01 | Fail(train/test) 0/0 | LR 1.29e-03 | 3.5s
# Epoch    5 | Step   100/ 5000 | Train 4.7443e-01 | Test 4.5579e-01 | SO3(train/test) 1.56e-01/1.25e-01 | Fail(train/test) 0/0 | LR 1.59e-03 | 3.5s
# Epoch    6 | Step   120/ 5000 | Train 4.5461e-01 | Test 4.4526e-01 | SO3(train/test) 1.06e-01/8.04e-02 | Fail(train/test) 0/0 | LR 1.88e-03 | 3.4s
# Epoch    7 | Step   140/ 5000 | Train 4.2799e-01 | Test 4.1170e-01 | SO3(train/test) 6.45e-02/5.04e-02 | Fail(train/test) 0/0 | LR 2.18e-03 | 3.4s
# Epoch    8 | Step   160/ 5000 | Train 3.9827e-01 | Test 4.1198e-01 | SO3(train/test) 4.24e-02/4.01e-02 | Fail(train/test) 0/0 | LR 2.47e-03 | 3.6s
# Epoch    9 | Step   180/ 5000 | Train 3.8250e-01 | Test 3.9993e-01 | SO3(train/test) 4.61e-02/5.74e-02 | Fail(train/test) 0/0 | LR 2.77e-03 | 3.5s
# Epoch   10 | Step   200/ 5000 | Train 3.7293e-01 | Test 3.7030e-01 | SO3(train/test) 7.28e-02/9.11e-02 | Fail(train/test) 0/0 | LR 3.06e-03 | 3.5s
# Epoch   11 | Step   220/ 5000 | Train 4.1388e-01 | Test 3.6501e-01 | SO3(train/test) 1.10e-01/1.41e-01 | Fail(train/test) 0/0 | LR 3.36e-03 | 3.5s
# Epoch   12 | Step   240/ 5000 | Train 3.6859e-01 | Test 3.3968e-01 | SO3(train/test) 1.67e-01/1.92e-01 | Fail(train/test) 0/0 | LR 3.65e-03 | 3.5s
# Epoch   13 | Step   260/ 5000 | Train 3.6392e-01 | Test 3.2150e-01 | SO3(train/test) 2.08e-01/2.28e-01 | Fail(train/test) 0/0 | LR 3.95e-03 | 3.5s
# Epoch   14 | Step   280/ 5000 | Train 3.4430e-01 | Test 3.1323e-01 | SO3(train/test) 2.30e-01/2.32e-01 | Fail(train/test) 0/0 | LR 4.24e-03 | 3.4s
# Epoch   15 | Step   300/ 5000 | Train 3.1733e-01 | Test 3.1757e-01 | SO3(train/test) 2.30e-01/2.30e-01 | Fail(train/test) 0/0 | LR 4.54e-03 | 3.5s
# Epoch   16 | Step   320/ 5000 | Train 3.6036e-01 | Test 3.2606e-01 | SO3(train/test) 2.46e-01/2.63e-01 | Fail(train/test) 0/0 | LR 4.83e-03 | 3.5s
# Epoch   17 | Step   340/ 5000 | Train 3.2353e-01 | Test 3.0328e-01 | SO3(train/test) 2.75e-01/2.75e-01 | Fail(train/test) 0/0 | LR 5.13e-03 | 3.5s
# Epoch   18 | Step   360/ 5000 | Train 3.0794e-01 | Test 3.2366e-01 | SO3(train/test) 2.77e-01/2.69e-01 | Fail(train/test) 0/0 | LR 5.42e-03 | 3.4s
# Epoch   19 | Step   380/ 5000 | Train 3.0476e-01 | Test 3.1092e-01 | SO3(train/test) 2.75e-01/2.64e-01 | Fail(train/test) 0/0 | LR 5.72e-03 | 3.5s
# Epoch   20 | Step   400/ 5000 | Train 2.9276e-01 | Test 2.9865e-01 | SO3(train/test) 2.64e-01/2.49e-01 | Fail(train/test) 0/0 | LR 6.00e-03 | 3.5s
# Epoch   21 | Step   420/ 5000 | Train 2.8317e-01 | Test 2.8654e-01 | SO3(train/test) 2.47e-01/2.33e-01 | Fail(train/test) 0/0 | LR 6.00e-03 | 3.5s
# Epoch   22 | Step   440/ 5000 | Train 2.7400e-01 | Test 2.8106e-01 | SO3(train/test) 2.31e-01/2.18e-01 | Fail(train/test) 0/0 | LR 6.00e-03 | 3.4s
# Epoch   23 | Step   460/ 5000 | Train 2.6839e-01 | Test 2.7085e-01 | SO3(train/test) 2.18e-01/2.07e-01 | Fail(train/test) 0/0 | LR 6.00e-03 | 3.6s
# Epoch   24 | Step   480/ 5000 | Train 2.6351e-01 | Test 2.6516e-01 | SO3(train/test) 2.07e-01/1.97e-01 | Fail(train/test) 0/0 | LR 6.00e-03 | 3.4s
# Epoch   25 | Step   500/ 5000 | Train 2.5883e-01 | Test 2.5840e-01 | SO3(train/test) 1.98e-01/1.90e-01 | Fail(train/test) 0/0 | LR 5.99e-03 | 3.5s
# Epoch   26 | Step   520/ 5000 | Train 2.5389e-01 | Test 2.5079e-01 | SO3(train/test) 1.92e-01/1.84e-01 | Fail(train/test) 0/0 | LR 5.99e-03 | 3.5s
# Epoch   27 | Step   540/ 5000 | Train 2.5104e-01 | Test 2.5212e-01 | SO3(train/test) 1.86e-01/1.80e-01 | Fail(train/test) 0/0 | LR 5.99e-03 | 3.5s
# Epoch   28 | Step   560/ 5000 | Train 2.4827e-01 | Test 2.4742e-01 | SO3(train/test) 1.82e-01/1.76e-01 | Fail(train/test) 0/0 | LR 5.98e-03 | 3.4s
# Epoch   29 | Step   580/ 5000 | Train 2.4764e-01 | Test 2.4979e-01 | SO3(train/test) 1.78e-01/1.76e-01 | Fail(train/test) 0/0 | LR 5.98e-03 | 3.5s
# Epoch   30 | Step   600/ 5000 | Train 2.5401e-01 | Test 2.4071e-01 | SO3(train/test) 1.80e-01/1.85e-01 | Fail(train/test) 0/0 | LR 5.97e-03 | 3.5s
# Epoch   31 | Step   620/ 5000 | Train 3.1962e-01 | Test 2.8275e-01 | SO3(train/test) 1.92e-01/2.10e-01 | Fail(train/test) 0/0 | LR 5.97e-03 | 3.4s
# Epoch   32 | Step   640/ 5000 | Train 2.9654e-01 | Test 2.7471e-01 | SO3(train/test) 2.19e-01/2.28e-01 | Fail(train/test) 0/0 | LR 5.96e-03 | 3.4s
# Epoch   33 | Step   660/ 5000 | Train 2.7083e-01 | Test 2.6252e-01 | SO3(train/test) 2.33e-01/2.42e-01 | Fail(train/test) 0/0 | LR 5.95e-03 | 3.4s
# Epoch   34 | Step   680/ 5000 | Train 2.5992e-01 | Test 2.4023e-01 | SO3(train/test) 2.44e-01/2.39e-01 | Fail(train/test) 0/0 | LR 5.95e-03 | 3.6s
# Epoch   35 | Step   700/ 5000 | Train 2.4873e-01 | Test 2.6262e-01 | SO3(train/test) 2.47e-01/2.38e-01 | Fail(train/test) 0/0 | LR 5.94e-03 | 3.4s
# Epoch   36 | Step   720/ 5000 | Train 2.4224e-01 | Test 2.5249e-01 | SO3(train/test) 2.45e-01/2.43e-01 | Fail(train/test) 0/0 | LR 5.93e-03 | 3.4s
# Epoch   37 | Step   740/ 5000 | Train 2.3331e-01 | Test 2.3927e-01 | SO3(train/test) 2.41e-01/2.34e-01 | Fail(train/test) 0/0 | LR 5.92e-03 | 3.5s
# Epoch   38 | Step   760/ 5000 | Train 2.2930e-01 | Test 2.2991e-01 | SO3(train/test) 2.33e-01/2.24e-01 | Fail(train/test) 0/0 | LR 5.91e-03 | 3.5s
# Epoch   39 | Step   780/ 5000 | Train 2.2620e-01 | Test 2.3757e-01 | SO3(train/test) 2.26e-01/2.18e-01 | Fail(train/test) 0/0 | LR 5.90e-03 | 3.4s
# Epoch   40 | Step   800/ 5000 | Train 2.2326e-01 | Test 2.3200e-01 | SO3(train/test) 2.18e-01/2.12e-01 | Fail(train/test) 0/0 | LR 5.89e-03 | 3.4s
# Epoch   41 | Step   820/ 5000 | Train 2.2004e-01 | Test 2.3573e-01 | SO3(train/test) 2.12e-01/2.05e-01 | Fail(train/test) 0/0 | LR 5.88e-03 | 3.5s
# Epoch   42 | Step   840/ 5000 | Train 2.1559e-01 | Test 2.3005e-01 | SO3(train/test) 2.06e-01/2.01e-01 | Fail(train/test) 0/0 | LR 5.87e-03 | 3.4s
# Epoch   43 | Step   860/ 5000 | Train 2.1169e-01 | Test 2.2523e-01 | SO3(train/test) 2.02e-01/1.96e-01 | Fail(train/test) 0/0 | LR 5.86e-03 | 3.4s
# Epoch   44 | Step   880/ 5000 | Train 2.0475e-01 | Test 2.1964e-01 | SO3(train/test) 1.98e-01/1.91e-01 | Fail(train/test) 0/0 | LR 5.84e-03 | 3.5s
# Epoch   45 | Step   900/ 5000 | Train 2.0133e-01 | Test 2.1641e-01 | SO3(train/test) 1.94e-01/1.89e-01 | Fail(train/test) 0/0 | LR 5.83e-03 | 3.5s
# Epoch   46 | Step   920/ 5000 | Train 1.9842e-01 | Test 2.1092e-01 | SO3(train/test) 1.90e-01/1.85e-01 | Fail(train/test) 0/0 | LR 5.82e-03 | 3.4s
# Epoch   47 | Step   940/ 5000 | Train 1.9701e-01 | Test 2.1456e-01 | SO3(train/test) 1.87e-01/1.82e-01 | Fail(train/test) 0/0 | LR 5.80e-03 | 3.4s
# Epoch   48 | Step   960/ 5000 | Train 1.9805e-01 | Test 2.1266e-01 | SO3(train/test) 1.84e-01/1.79e-01 | Fail(train/test) 0/0 | LR 5.79e-03 | 3.5s
# Epoch   49 | Step   980/ 5000 | Train 2.0151e-01 | Test 2.1758e-01 | SO3(train/test) 1.79e-01/1.77e-01 | Fail(train/test) 0/0 | LR 5.77e-03 | 3.4s
# Epoch   50 | Step  1000/ 5000 | Train 2.0347e-01 | Test 2.3043e-01 | SO3(train/test) 1.78e-01/1.75e-01 | Fail(train/test) 0/0 | LR 5.76e-03 | 3.5s
# Epoch   51 | Step  1020/ 5000 | Train 2.1118e-01 | Test 2.2811e-01 | SO3(train/test) 1.82e-01/1.89e-01 | Fail(train/test) 0/0 | LR 5.74e-03 | 3.5s
# Epoch   52 | Step  1040/ 5000 | Train 2.0855e-01 | Test 2.3019e-01 | SO3(train/test) 1.96e-01/1.97e-01 | Fail(train/test) 0/0 | LR 5.72e-03 | 3.5s
# Epoch   53 | Step  1060/ 5000 | Train 1.9686e-01 | Test 2.0819e-01 | SO3(train/test) 2.03e-01/1.97e-01 | Fail(train/test) 0/0 | LR 5.71e-03 | 3.4s
# Epoch   54 | Step  1080/ 5000 | Train 1.9042e-01 | Test 1.9294e-01 | SO3(train/test) 1.98e-01/1.91e-01 | Fail(train/test) 0/0 | LR 5.69e-03 | 3.4s
# Epoch   55 | Step  1100/ 5000 | Train 1.8755e-01 | Test 2.0044e-01 | SO3(train/test) 1.91e-01/1.85e-01 | Fail(train/test) 0/0 | LR 5.67e-03 | 3.6s
# Epoch   56 | Step  1120/ 5000 | Train 1.8666e-01 | Test 1.9728e-01 | SO3(train/test) 1.86e-01/1.79e-01 | Fail(train/test) 0/0 | LR 5.65e-03 | 3.5s
# Epoch   57 | Step  1140/ 5000 | Train 1.8566e-01 | Test 1.9521e-01 | SO3(train/test) 1.81e-01/1.76e-01 | Fail(train/test) 0/0 | LR 5.63e-03 | 3.4s
# Epoch   58 | Step  1160/ 5000 | Train 1.8467e-01 | Test 1.9476e-01 | SO3(train/test) 1.77e-01/1.72e-01 | Fail(train/test) 0/0 | LR 5.61e-03 | 3.4s
# Epoch   59 | Step  1180/ 5000 | Train 1.8449e-01 | Test 1.9811e-01 | SO3(train/test) 1.74e-01/1.70e-01 | Fail(train/test) 0/0 | LR 5.59e-03 | 3.5s
# Epoch   60 | Step  1200/ 5000 | Train 1.8308e-01 | Test 1.9174e-01 | SO3(train/test) 1.72e-01/1.68e-01 | Fail(train/test) 0/0 | LR 5.57e-03 | 3.4s
# Epoch   61 | Step  1220/ 5000 | Train 1.8090e-01 | Test 1.8823e-01 | SO3(train/test) 1.70e-01/1.66e-01 | Fail(train/test) 0/0 | LR 5.55e-03 | 3.4s
# Epoch   62 | Step  1240/ 5000 | Train 1.8011e-01 | Test 1.8994e-01 | SO3(train/test) 1.68e-01/1.67e-01 | Fail(train/test) 0/0 | LR 5.53e-03 | 3.4s
# Epoch   63 | Step  1260/ 5000 | Train 1.7921e-01 | Test 1.8471e-01 | SO3(train/test) 1.67e-01/1.69e-01 | Fail(train/test) 0/0 | LR 5.51e-03 | 3.6s
# Epoch   64 | Step  1280/ 5000 | Train 1.7769e-01 | Test 1.8078e-01 | SO3(train/test) 1.68e-01/1.65e-01 | Fail(train/test) 0/0 | LR 5.48e-03 | 3.4s
# Epoch   65 | Step  1300/ 5000 | Train 1.7744e-01 | Test 1.9440e-01 | SO3(train/test) 1.67e-01/1.65e-01 | Fail(train/test) 0/0 | LR 5.46e-03 | 3.5s
# Epoch   66 | Step  1320/ 5000 | Train 1.8062e-01 | Test 2.0163e-01 | SO3(train/test) 1.66e-01/1.67e-01 | Fail(train/test) 0/0 | LR 5.44e-03 | 3.5s
# Epoch   67 | Step  1340/ 5000 | Train 1.8731e-01 | Test 1.9121e-01 | SO3(train/test) 1.70e-01/1.71e-01 | Fail(train/test) 0/0 | LR 5.41e-03 | 3.4s
# Epoch   68 | Step  1360/ 5000 | Train 1.8646e-01 | Test 2.1919e-01 | SO3(train/test) 1.77e-01/1.80e-01 | Fail(train/test) 0/0 | LR 5.39e-03 | 3.4s
# Epoch   69 | Step  1380/ 5000 | Train 1.8787e-01 | Test 1.9535e-01 | SO3(train/test) 1.92e-01/1.99e-01 | Fail(train/test) 0/0 | LR 5.36e-03 | 3.4s
# Epoch   70 | Step  1400/ 5000 | Train 1.7984e-01 | Test 2.2812e-01 | SO3(train/test) 2.03e-01/2.01e-01 | Fail(train/test) 0/0 | LR 5.34e-03 | 3.5s
# Epoch   71 | Step  1420/ 5000 | Train 1.9362e-01 | Test 1.9265e-01 | SO3(train/test) 2.02e-01/1.98e-01 | Fail(train/test) 0/0 | LR 5.31e-03 | 3.5s
# Epoch   72 | Step  1440/ 5000 | Train 1.8304e-01 | Test 1.9707e-01 | SO3(train/test) 1.97e-01/1.87e-01 | Fail(train/test) 0/0 | LR 5.29e-03 | 3.5s
# Epoch   73 | Step  1460/ 5000 | Train 1.7256e-01 | Test 1.7273e-01 | SO3(train/test) 1.88e-01/1.78e-01 | Fail(train/test) 0/0 | LR 5.26e-03 | 3.5s
# Epoch   74 | Step  1480/ 5000 | Train 1.6861e-01 | Test 1.7416e-01 | SO3(train/test) 1.79e-01/1.69e-01 | Fail(train/test) 0/0 | LR 5.23e-03 | 3.5s
# Epoch   75 | Step  1500/ 5000 | Train 1.6606e-01 | Test 1.7842e-01 | SO3(train/test) 1.71e-01/1.62e-01 | Fail(train/test) 0/0 | LR 5.21e-03 | 3.4s
# Epoch   76 | Step  1520/ 5000 | Train 1.6656e-01 | Test 1.7289e-01 | SO3(train/test) 1.65e-01/1.56e-01 | Fail(train/test) 0/0 | LR 5.18e-03 | 3.5s
# Epoch   77 | Step  1540/ 5000 | Train 1.6411e-01 | Test 1.7198e-01 | SO3(train/test) 1.61e-01/1.54e-01 | Fail(train/test) 0/0 | LR 5.15e-03 | 3.5s
# Epoch   78 | Step  1560/ 5000 | Train 1.6143e-01 | Test 1.6875e-01 | SO3(train/test) 1.60e-01/1.55e-01 | Fail(train/test) 0/0 | LR 5.12e-03 | 3.4s
# Epoch   79 | Step  1580/ 5000 | Train 1.5772e-01 | Test 1.6729e-01 | SO3(train/test) 1.62e-01/1.58e-01 | Fail(train/test) 0/0 | LR 5.09e-03 | 3.4s
# Epoch   80 | Step  1600/ 5000 | Train 1.5556e-01 | Test 1.6349e-01 | SO3(train/test) 1.62e-01/1.56e-01 | Fail(train/test) 0/0 | LR 5.06e-03 | 3.5s
# Epoch   81 | Step  1620/ 5000 | Train 1.5283e-01 | Test 1.6168e-01 | SO3(train/test) 1.63e-01/1.58e-01 | Fail(train/test) 0/0 | LR 5.03e-03 | 3.6s
# Epoch   82 | Step  1640/ 5000 | Train 1.5101e-01 | Test 1.5898e-01 | SO3(train/test) 1.62e-01/1.55e-01 | Fail(train/test) 0/0 | LR 5.00e-03 | 3.5s
# Epoch   83 | Step  1660/ 5000 | Train 1.4875e-01 | Test 1.5879e-01 | SO3(train/test) 1.61e-01/1.57e-01 | Fail(train/test) 0/0 | LR 4.97e-03 | 3.5s
# Epoch   84 | Step  1680/ 5000 | Train 1.4663e-01 | Test 1.5256e-01 | SO3(train/test) 1.62e-01/1.61e-01 | Fail(train/test) 0/0 | LR 4.94e-03 | 3.6s
# Epoch   85 | Step  1700/ 5000 | Train 1.4247e-01 | Test 1.4656e-01 | SO3(train/test) 1.67e-01/1.65e-01 | Fail(train/test) 0/0 | LR 4.91e-03 | 3.5s
# Epoch   86 | Step  1720/ 5000 | Train 1.3932e-01 | Test 1.5012e-01 | SO3(train/test) 1.76e-01/1.70e-01 | Fail(train/test) 0/0 | LR 4.88e-03 | 3.6s
# Epoch   87 | Step  1740/ 5000 | Train 1.3814e-01 | Test 1.3920e-01 | SO3(train/test) 1.89e-01/1.98e-01 | Fail(train/test) 0/0 | LR 4.85e-03 | 3.5s
# Epoch   88 | Step  1760/ 5000 | Train 1.2864e-01 | Test 1.3211e-01 | SO3(train/test) 2.10e-01/2.16e-01 | Fail(train/test) 0/0 | LR 4.82e-03 | 3.6s
# Epoch   89 | Step  1780/ 5000 | Train 1.1867e-01 | Test 1.3198e-01 | SO3(train/test) 2.32e-01/2.25e-01 | Fail(train/test) 0/0 | LR 4.78e-03 | 3.5s
# Epoch   90 | Step  1800/ 5000 | Train 1.1303e-01 | Test 1.1831e-01 | SO3(train/test) 2.32e-01/2.14e-01 | Fail(train/test) 0/0 | LR 4.75e-03 | 3.5s
# Epoch   91 | Step  1820/ 5000 | Train 1.0755e-01 | Test 1.1529e-01 | SO3(train/test) 2.19e-01/2.03e-01 | Fail(train/test) 0/0 | LR 4.72e-03 | 3.6s
# Epoch   92 | Step  1840/ 5000 | Train 1.0459e-01 | Test 1.1388e-01 | SO3(train/test) 2.10e-01/2.00e-01 | Fail(train/test) 0/0 | LR 4.68e-03 | 3.6s
# Epoch   93 | Step  1860/ 5000 | Train 1.0219e-01 | Test 1.1485e-01 | SO3(train/test) 2.10e-01/2.01e-01 | Fail(train/test) 0/0 | LR 4.65e-03 | 3.5s
# Epoch   94 | Step  1880/ 5000 | Train 1.0108e-01 | Test 1.1838e-01 | SO3(train/test) 2.08e-01/2.00e-01 | Fail(train/test) 0/0 | LR 4.62e-03 | 3.5s
# Epoch   95 | Step  1900/ 5000 | Train 9.7527e-02 | Test 1.0992e-01 | SO3(train/test) 2.04e-01/1.96e-01 | Fail(train/test) 0/0 | LR 4.58e-03 | 3.6s
# Epoch   96 | Step  1920/ 5000 | Train 9.2837e-02 | Test 1.0270e-01 | SO3(train/test) 1.96e-01/1.81e-01 | Fail(train/test) 0/0 | LR 4.55e-03 | 3.5s
# Epoch   97 | Step  1940/ 5000 | Train 9.1339e-02 | Test 9.6094e-02 | SO3(train/test) 1.84e-01/1.68e-01 | Fail(train/test) 0/0 | LR 4.51e-03 | 3.6s
# Epoch   98 | Step  1960/ 5000 | Train 1.0548e-01 | Test 1.0033e-01 | SO3(train/test) 1.56e-01/1.38e-01 | Fail(train/test) 0/0 | LR 4.48e-03 | 3.5s
# Epoch   99 | Step  1980/ 5000 | Train 9.7862e-02 | Test 1.0519e-01 | SO3(train/test) 1.57e-01/1.59e-01 | Fail(train/test) 0/0 | LR 4.44e-03 | 3.5s
# Epoch  100 | Step  2000/ 5000 | Train 9.6382e-02 | Test 1.1679e-01 | SO3(train/test) 1.70e-01/1.61e-01 | Fail(train/test) 0/0 | LR 4.41e-03 | 3.5s
# Epoch  101 | Step  2020/ 5000 | Train 9.3994e-02 | Test 1.1130e-01 | SO3(train/test) 1.73e-01/1.65e-01 | Fail(train/test) 0/0 | LR 4.37e-03 | 3.5s
# Epoch  102 | Step  2040/ 5000 | Train 8.1794e-02 | Test 9.6350e-02 | SO3(train/test) 1.69e-01/1.62e-01 | Fail(train/test) 0/0 | LR 4.33e-03 | 3.6s
# Epoch  103 | Step  2060/ 5000 | Train 7.3821e-02 | Test 8.1606e-02 | SO3(train/test) 1.71e-01/1.65e-01 | Fail(train/test) 0/0 | LR 4.30e-03 | 3.5s
# Epoch  104 | Step  2080/ 5000 | Train 7.0740e-02 | Test 7.9607e-02 | SO3(train/test) 1.75e-01/1.70e-01 | Fail(train/test) 0/0 | LR 4.26e-03 | 3.5s
# Epoch  105 | Step  2100/ 5000 | Train 6.6982e-02 | Test 7.8378e-02 | SO3(train/test) 1.79e-01/1.76e-01 | Fail(train/test) 0/0 | LR 4.22e-03 | 3.6s
# Epoch  106 | Step  2120/ 5000 | Train 6.3683e-02 | Test 7.4121e-02 | SO3(train/test) 1.83e-01/1.79e-01 | Fail(train/test) 0/0 | LR 4.19e-03 | 3.6s
# Epoch  107 | Step  2140/ 5000 | Train 6.0949e-02 | Test 7.1756e-02 | SO3(train/test) 1.85e-01/1.82e-01 | Fail(train/test) 0/0 | LR 4.15e-03 | 3.6s
# Epoch  108 | Step  2160/ 5000 | Train 5.8783e-02 | Test 6.8122e-02 | SO3(train/test) 1.85e-01/1.81e-01 | Fail(train/test) 0/0 | LR 4.11e-03 | 3.5s
# Epoch  109 | Step  2180/ 5000 | Train 5.6568e-02 | Test 6.7929e-02 | SO3(train/test) 1.83e-01/1.79e-01 | Fail(train/test) 0/0 | LR 4.08e-03 | 3.6s
# Epoch  110 | Step  2200/ 5000 | Train 5.4210e-02 | Test 6.2928e-02 | SO3(train/test) 1.79e-01/1.77e-01 | Fail(train/test) 0/0 | LR 4.04e-03 | 3.5s
# Epoch  111 | Step  2220/ 5000 | Train 5.3600e-02 | Test 7.1378e-02 | SO3(train/test) 1.75e-01/1.71e-01 | Fail(train/test) 0/0 | LR 4.00e-03 | 3.5s
# Epoch  112 | Step  2240/ 5000 | Train 5.3810e-02 | Test 6.7687e-02 | SO3(train/test) 1.70e-01/1.73e-01 | Fail(train/test) 0/0 | LR 3.96e-03 | 3.5s
# Epoch  113 | Step  2260/ 5000 | Train 5.2958e-02 | Test 6.0209e-02 | SO3(train/test) 1.66e-01/1.65e-01 | Fail(train/test) 0/0 | LR 3.92e-03 | 3.7s
# Epoch  114 | Step  2280/ 5000 | Train 4.9416e-02 | Test 6.0723e-02 | SO3(train/test) 1.59e-01/1.61e-01 | Fail(train/test) 0/0 | LR 3.88e-03 | 3.5s
# Epoch  115 | Step  2300/ 5000 | Train 4.8616e-02 | Test 6.0953e-02 | SO3(train/test) 1.57e-01/1.61e-01 | Fail(train/test) 0/0 | LR 3.85e-03 | 3.5s
# Epoch  116 | Step  2320/ 5000 | Train 4.8073e-02 | Test 5.8687e-02 | SO3(train/test) 1.54e-01/1.57e-01 | Fail(train/test) 0/0 | LR 3.81e-03 | 3.6s
# Epoch  117 | Step  2340/ 5000 | Train 4.6664e-02 | Test 5.8370e-02 | SO3(train/test) 1.51e-01/1.58e-01 | Fail(train/test) 0/0 | LR 3.77e-03 | 3.5s
# Epoch  118 | Step  2360/ 5000 | Train 4.5021e-02 | Test 5.4737e-02 | SO3(train/test) 1.50e-01/1.54e-01 | Fail(train/test) 0/0 | LR 3.73e-03 | 3.6s
# Epoch  119 | Step  2380/ 5000 | Train 4.4047e-02 | Test 5.4204e-02 | SO3(train/test) 1.48e-01/1.53e-01 | Fail(train/test) 0/0 | LR 3.69e-03 | 3.5s
# Epoch  120 | Step  2400/ 5000 | Train 4.2949e-02 | Test 5.3666e-02 | SO3(train/test) 1.47e-01/1.53e-01 | Fail(train/test) 0/0 | LR 3.65e-03 | 3.6s
# Epoch  121 | Step  2420/ 5000 | Train 4.2085e-02 | Test 5.3959e-02 | SO3(train/test) 1.46e-01/1.53e-01 | Fail(train/test) 0/0 | LR 3.61e-03 | 3.5s
# Epoch  122 | Step  2440/ 5000 | Train 4.0922e-02 | Test 5.1562e-02 | SO3(train/test) 1.45e-01/1.51e-01 | Fail(train/test) 0/0 | LR 3.57e-03 | 3.5s
# Epoch  123 | Step  2460/ 5000 | Train 4.0069e-02 | Test 5.0010e-02 | SO3(train/test) 1.45e-01/1.52e-01 | Fail(train/test) 0/0 | LR 3.53e-03 | 3.6s
# Epoch  124 | Step  2480/ 5000 | Train 3.9271e-02 | Test 5.1355e-02 | SO3(train/test) 1.44e-01/1.49e-01 | Fail(train/test) 0/0 | LR 3.49e-03 | 3.6s
# Epoch  125 | Step  2500/ 5000 | Train 3.8624e-02 | Test 4.7277e-02 | SO3(train/test) 1.44e-01/1.52e-01 | Fail(train/test) 0/0 | LR 3.45e-03 | 3.5s
# Epoch  126 | Step  2520/ 5000 | Train 3.7798e-02 | Test 4.7299e-02 | SO3(train/test) 1.43e-01/1.51e-01 | Fail(train/test) 0/0 | LR 3.41e-03 | 3.5s
# Epoch  127 | Step  2540/ 5000 | Train 3.6786e-02 | Test 4.7842e-02 | SO3(train/test) 1.43e-01/1.49e-01 | Fail(train/test) 0/0 | LR 3.37e-03 | 3.6s
# Epoch  128 | Step  2560/ 5000 | Train 3.5684e-02 | Test 4.3771e-02 | SO3(train/test) 1.43e-01/1.52e-01 | Fail(train/test) 0/0 | LR 3.33e-03 | 3.6s
# Epoch  129 | Step  2580/ 5000 | Train 3.4561e-02 | Test 4.2206e-02 | SO3(train/test) 1.44e-01/1.52e-01 | Fail(train/test) 0/0 | LR 3.29e-03 | 3.5s
# Epoch  130 | Step  2600/ 5000 | Train 3.3472e-02 | Test 4.0692e-02 | SO3(train/test) 1.44e-01/1.50e-01 | Fail(train/test) 0/0 | LR 3.25e-03 | 3.6s
# Epoch  131 | Step  2620/ 5000 | Train 3.2648e-02 | Test 3.8609e-02 | SO3(train/test) 1.44e-01/1.51e-01 | Fail(train/test) 0/0 | LR 3.21e-03 | 3.5s
# Epoch  132 | Step  2640/ 5000 | Train 3.2124e-02 | Test 3.9757e-02 | SO3(train/test) 1.44e-01/1.51e-01 | Fail(train/test) 0/0 | LR 3.17e-03 | 3.5s
# Epoch  133 | Step  2660/ 5000 | Train 3.1105e-02 | Test 3.9593e-02 | SO3(train/test) 1.44e-01/1.50e-01 | Fail(train/test) 0/0 | LR 3.13e-03 | 3.5s
# Epoch  134 | Step  2680/ 5000 | Train 3.0435e-02 | Test 3.7420e-02 | SO3(train/test) 1.44e-01/1.52e-01 | Fail(train/test) 0/0 | LR 3.09e-03 | 3.7s
# Epoch  135 | Step  2700/ 5000 | Train 2.9638e-02 | Test 3.5667e-02 | SO3(train/test) 1.45e-01/1.52e-01 | Fail(train/test) 0/0 | LR 3.05e-03 | 3.5s
# Epoch  136 | Step  2720/ 5000 | Train 2.9099e-02 | Test 3.5781e-02 | SO3(train/test) 1.45e-01/1.54e-01 | Fail(train/test) 0/0 | LR 3.01e-03 | 3.5s
# Epoch  137 | Step  2740/ 5000 | Train 2.8704e-02 | Test 3.6547e-02 | SO3(train/test) 1.46e-01/1.53e-01 | Fail(train/test) 0/0 | LR 2.97e-03 | 3.6s
# Epoch  138 | Step  2760/ 5000 | Train 2.8447e-02 | Test 3.5282e-02 | SO3(train/test) 1.46e-01/1.56e-01 | Fail(train/test) 0/0 | LR 2.93e-03 | 3.5s
# Epoch  139 | Step  2780/ 5000 | Train 2.8609e-02 | Test 3.4920e-02 | SO3(train/test) 1.47e-01/1.54e-01 | Fail(train/test) 0/0 | LR 2.89e-03 | 3.6s
# Epoch  140 | Step  2800/ 5000 | Train 2.8025e-02 | Test 3.2807e-02 | SO3(train/test) 1.48e-01/1.55e-01 | Fail(train/test) 0/0 | LR 2.85e-03 | 3.5s
# Epoch  141 | Step  2820/ 5000 | Train 2.7413e-02 | Test 3.4754e-02 | SO3(train/test) 1.47e-01/1.56e-01 | Fail(train/test) 0/0 | LR 2.81e-03 | 3.6s
# Epoch  142 | Step  2840/ 5000 | Train 2.6136e-02 | Test 3.1390e-02 | SO3(train/test) 1.47e-01/1.54e-01 | Fail(train/test) 0/0 | LR 2.77e-03 | 3.5s
# Epoch  143 | Step  2860/ 5000 | Train 2.5494e-02 | Test 3.1520e-02 | SO3(train/test) 1.48e-01/1.56e-01 | Fail(train/test) 0/0 | LR 2.73e-03 | 3.5s
# Epoch  144 | Step  2880/ 5000 | Train 2.4673e-02 | Test 3.0719e-02 | SO3(train/test) 1.48e-01/1.56e-01 | Fail(train/test) 0/0 | LR 2.69e-03 | 3.5s
# Epoch  145 | Step  2900/ 5000 | Train 2.4393e-02 | Test 3.0392e-02 | SO3(train/test) 1.49e-01/1.56e-01 | Fail(train/test) 0/0 | LR 2.65e-03 | 3.5s
# Epoch  146 | Step  2920/ 5000 | Train 2.3972e-02 | Test 2.8988e-02 | SO3(train/test) 1.49e-01/1.57e-01 | Fail(train/test) 0/0 | LR 2.61e-03 | 3.5s
# Epoch  147 | Step  2940/ 5000 | Train 2.3792e-02 | Test 2.9005e-02 | SO3(train/test) 1.50e-01/1.58e-01 | Fail(train/test) 0/0 | LR 2.57e-03 | 3.5s
# Epoch  148 | Step  2960/ 5000 | Train 2.3246e-02 | Test 2.8651e-02 | SO3(train/test) 1.51e-01/1.58e-01 | Fail(train/test) 0/0 | LR 2.53e-03 | 3.6s
# Epoch  149 | Step  2980/ 5000 | Train 2.3155e-02 | Test 2.7937e-02 | SO3(train/test) 1.51e-01/1.59e-01 | Fail(train/test) 0/0 | LR 2.49e-03 | 3.6s
# Epoch  150 | Step  3000/ 5000 | Train 2.2540e-02 | Test 2.8054e-02 | SO3(train/test) 1.52e-01/1.60e-01 | Fail(train/test) 0/0 | LR 2.45e-03 | 3.4s
# Epoch  151 | Step  3020/ 5000 | Train 2.2335e-02 | Test 2.7450e-02 | SO3(train/test) 1.52e-01/1.60e-01 | Fail(train/test) 0/0 | LR 2.41e-03 | 3.5s
# Epoch  152 | Step  3040/ 5000 | Train 2.1855e-02 | Test 2.5994e-02 | SO3(train/test) 1.53e-01/1.61e-01 | Fail(train/test) 0/0 | LR 2.37e-03 | 3.5s
# Epoch  153 | Step  3060/ 5000 | Train 2.1742e-02 | Test 2.7290e-02 | SO3(train/test) 1.53e-01/1.61e-01 | Fail(train/test) 0/0 | LR 2.33e-03 | 3.5s
# Epoch  154 | Step  3080/ 5000 | Train 2.0988e-02 | Test 2.5555e-02 | SO3(train/test) 1.54e-01/1.61e-01 | Fail(train/test) 0/0 | LR 2.29e-03 | 3.5s
# Epoch  155 | Step  3100/ 5000 | Train 2.0798e-02 | Test 2.5495e-02 | SO3(train/test) 1.54e-01/1.62e-01 | Fail(train/test) 0/0 | LR 2.25e-03 | 3.6s
# Epoch  156 | Step  3120/ 5000 | Train 2.0272e-02 | Test 2.3893e-02 | SO3(train/test) 1.54e-01/1.63e-01 | Fail(train/test) 0/0 | LR 2.21e-03 | 3.5s
# Epoch  157 | Step  3140/ 5000 | Train 1.9976e-02 | Test 2.4656e-02 | SO3(train/test) 1.55e-01/1.63e-01 | Fail(train/test) 0/0 | LR 2.18e-03 | 3.5s
# Epoch  158 | Step  3160/ 5000 | Train 1.9511e-02 | Test 2.4022e-02 | SO3(train/test) 1.55e-01/1.64e-01 | Fail(train/test) 0/0 | LR 2.14e-03 | 3.5s
# Epoch  159 | Step  3180/ 5000 | Train 1.9230e-02 | Test 2.3751e-02 | SO3(train/test) 1.56e-01/1.63e-01 | Fail(train/test) 0/0 | LR 2.10e-03 | 3.5s
# Epoch  160 | Step  3200/ 5000 | Train 1.9050e-02 | Test 2.2247e-02 | SO3(train/test) 1.56e-01/1.65e-01 | Fail(train/test) 0/0 | LR 2.06e-03 | 3.6s
# Epoch  161 | Step  3220/ 5000 | Train 1.8771e-02 | Test 2.4341e-02 | SO3(train/test) 1.57e-01/1.64e-01 | Fail(train/test) 0/0 | LR 2.02e-03 | 3.5s
# Epoch  162 | Step  3240/ 5000 | Train 1.8450e-02 | Test 2.1364e-02 | SO3(train/test) 1.57e-01/1.66e-01 | Fail(train/test) 0/0 | LR 1.99e-03 | 3.5s
# Epoch  163 | Step  3260/ 5000 | Train 1.8145e-02 | Test 2.2319e-02 | SO3(train/test) 1.58e-01/1.65e-01 | Fail(train/test) 0/0 | LR 1.95e-03 | 3.5s
# Epoch  164 | Step  3280/ 5000 | Train 1.7717e-02 | Test 2.1277e-02 | SO3(train/test) 1.58e-01/1.66e-01 | Fail(train/test) 0/0 | LR 1.91e-03 | 3.5s
# Epoch  165 | Step  3300/ 5000 | Train 1.7365e-02 | Test 2.0603e-02 | SO3(train/test) 1.59e-01/1.67e-01 | Fail(train/test) 0/0 | LR 1.87e-03 | 3.5s
# Epoch  166 | Step  3320/ 5000 | Train 1.7142e-02 | Test 2.0642e-02 | SO3(train/test) 1.59e-01/1.67e-01 | Fail(train/test) 0/0 | LR 1.84e-03 | 3.5s
# Epoch  167 | Step  3340/ 5000 | Train 1.6911e-02 | Test 2.1279e-02 | SO3(train/test) 1.59e-01/1.67e-01 | Fail(train/test) 0/0 | LR 1.80e-03 | 3.4s
# Epoch  168 | Step  3360/ 5000 | Train 1.6712e-02 | Test 1.9892e-02 | SO3(train/test) 1.60e-01/1.68e-01 | Fail(train/test) 0/0 | LR 1.76e-03 | 3.5s
# Epoch  169 | Step  3380/ 5000 | Train 1.6531e-02 | Test 1.9630e-02 | SO3(train/test) 1.60e-01/1.68e-01 | Fail(train/test) 0/0 | LR 1.73e-03 | 3.5s
# Epoch  170 | Step  3400/ 5000 | Train 1.6268e-02 | Test 1.9501e-02 | SO3(train/test) 1.61e-01/1.69e-01 | Fail(train/test) 0/0 | LR 1.69e-03 | 3.6s
# Epoch  171 | Step  3420/ 5000 | Train 1.6026e-02 | Test 1.9437e-02 | SO3(train/test) 1.61e-01/1.69e-01 | Fail(train/test) 0/0 | LR 1.66e-03 | 3.5s
# Epoch  172 | Step  3440/ 5000 | Train 1.5773e-02 | Test 1.8384e-02 | SO3(train/test) 1.61e-01/1.70e-01 | Fail(train/test) 0/0 | LR 1.62e-03 | 3.5s
# Epoch  173 | Step  3460/ 5000 | Train 1.5607e-02 | Test 1.9041e-02 | SO3(train/test) 1.62e-01/1.71e-01 | Fail(train/test) 0/0 | LR 1.59e-03 | 3.6s
# Epoch  174 | Step  3480/ 5000 | Train 1.5474e-02 | Test 1.8102e-02 | SO3(train/test) 1.62e-01/1.71e-01 | Fail(train/test) 0/0 | LR 1.55e-03 | 3.4s
# Epoch  175 | Step  3500/ 5000 | Train 1.5224e-02 | Test 1.7835e-02 | SO3(train/test) 1.62e-01/1.71e-01 | Fail(train/test) 0/0 | LR 1.52e-03 | 3.4s
# Epoch  176 | Step  3520/ 5000 | Train 1.5103e-02 | Test 1.7922e-02 | SO3(train/test) 1.63e-01/1.71e-01 | Fail(train/test) 0/0 | LR 1.48e-03 | 3.6s
# Epoch  177 | Step  3540/ 5000 | Train 1.4891e-02 | Test 1.7579e-02 | SO3(train/test) 1.63e-01/1.71e-01 | Fail(train/test) 0/0 | LR 1.45e-03 | 3.5s
# Epoch  178 | Step  3560/ 5000 | Train 1.4789e-02 | Test 1.7082e-02 | SO3(train/test) 1.63e-01/1.70e-01 | Fail(train/test) 0/0 | LR 1.41e-03 | 3.4s
# Epoch  179 | Step  3580/ 5000 | Train 1.4655e-02 | Test 1.7498e-02 | SO3(train/test) 1.63e-01/1.71e-01 | Fail(train/test) 0/0 | LR 1.38e-03 | 3.5s
# Epoch  180 | Step  3600/ 5000 | Train 1.4537e-02 | Test 1.7176e-02 | SO3(train/test) 1.63e-01/1.71e-01 | Fail(train/test) 0/0 | LR 1.35e-03 | 3.5s
# Epoch  181 | Step  3620/ 5000 | Train 1.4300e-02 | Test 1.7085e-02 | SO3(train/test) 1.63e-01/1.71e-01 | Fail(train/test) 0/0 | LR 1.31e-03 | 3.6s
# Epoch  182 | Step  3640/ 5000 | Train 1.4125e-02 | Test 1.6740e-02 | SO3(train/test) 1.63e-01/1.71e-01 | Fail(train/test) 0/0 | LR 1.28e-03 | 3.4s
# Epoch  183 | Step  3660/ 5000 | Train 1.3935e-02 | Test 1.6202e-02 | SO3(train/test) 1.64e-01/1.72e-01 | Fail(train/test) 0/0 | LR 1.25e-03 | 3.5s
# Epoch  184 | Step  3680/ 5000 | Train 1.3816e-02 | Test 1.6194e-02 | SO3(train/test) 1.64e-01/1.72e-01 | Fail(train/test) 0/0 | LR 1.22e-03 | 3.5s
# Epoch  185 | Step  3700/ 5000 | Train 1.3752e-02 | Test 1.6287e-02 | SO3(train/test) 1.64e-01/1.72e-01 | Fail(train/test) 0/0 | LR 1.19e-03 | 3.4s
# Epoch  186 | Step  3720/ 5000 | Train 1.3843e-02 | Test 1.7409e-02 | SO3(train/test) 1.64e-01/1.73e-01 | Fail(train/test) 0/0 | LR 1.16e-03 | 3.4s
# Epoch  187 | Step  3740/ 5000 | Train 1.5037e-02 | Test 1.7249e-02 | SO3(train/test) 1.64e-01/1.71e-01 | Fail(train/test) 0/0 | LR 1.13e-03 | 3.5s
# Epoch  188 | Step  3760/ 5000 | Train 1.4390e-02 | Test 1.6463e-02 | SO3(train/test) 1.63e-01/1.69e-01 | Fail(train/test) 0/0 | LR 1.10e-03 | 3.5s
# Epoch  189 | Step  3780/ 5000 | Train 1.3625e-02 | Test 1.5841e-02 | SO3(train/test) 1.61e-01/1.69e-01 | Fail(train/test) 0/0 | LR 1.07e-03 | 3.4s
# Epoch  190 | Step  3800/ 5000 | Train 1.2946e-02 | Test 1.5367e-02 | SO3(train/test) 1.62e-01/1.70e-01 | Fail(train/test) 0/0 | LR 1.04e-03 | 3.4s
# Epoch  191 | Step  3820/ 5000 | Train 1.3755e-02 | Test 1.9134e-02 | SO3(train/test) 1.63e-01/1.71e-01 | Fail(train/test) 0/0 | LR 1.01e-03 | 3.6s
# Epoch  192 | Step  3840/ 5000 | Train 1.4513e-02 | Test 1.5774e-02 | SO3(train/test) 1.63e-01/1.70e-01 | Fail(train/test) 0/0 | LR 9.77e-04 | 3.5s
# Epoch  193 | Step  3860/ 5000 | Train 1.3296e-02 | Test 1.5479e-02 | SO3(train/test) 1.63e-01/1.70e-01 | Fail(train/test) 0/0 | LR 9.49e-04 | 3.4s
# Epoch  194 | Step  3880/ 5000 | Train 1.2716e-02 | Test 1.5065e-02 | SO3(train/test) 1.63e-01/1.70e-01 | Fail(train/test) 0/0 | LR 9.21e-04 | 3.4s
# Epoch  195 | Step  3900/ 5000 | Train 1.2573e-02 | Test 1.4930e-02 | SO3(train/test) 1.63e-01/1.70e-01 | Fail(train/test) 0/0 | LR 8.93e-04 | 3.5s
# Epoch  196 | Step  3920/ 5000 | Train 1.2453e-02 | Test 1.4878e-02 | SO3(train/test) 1.63e-01/1.70e-01 | Fail(train/test) 0/0 | LR 8.66e-04 | 3.4s
# Epoch  197 | Step  3940/ 5000 | Train 1.2377e-02 | Test 1.4592e-02 | SO3(train/test) 1.63e-01/1.71e-01 | Fail(train/test) 0/0 | LR 8.39e-04 | 3.5s
# Epoch  198 | Step  3960/ 5000 | Train 1.2321e-02 | Test 1.4405e-02 | SO3(train/test) 1.63e-01/1.71e-01 | Fail(train/test) 0/0 | LR 8.12e-04 | 3.5s
# Epoch  199 | Step  3980/ 5000 | Train 1.2265e-02 | Test 1.4805e-02 | SO3(train/test) 1.64e-01/1.71e-01 | Fail(train/test) 0/0 | LR 7.86e-04 | 3.4s
# Epoch  200 | Step  4000/ 5000 | Train 1.2218e-02 | Test 1.4200e-02 | SO3(train/test) 1.64e-01/1.72e-01 | Fail(train/test) 0/0 | LR 7.61e-04 | 3.4s
# Epoch  201 | Step  4020/ 5000 | Train 1.2016e-02 | Test 1.4049e-02 | SO3(train/test) 1.64e-01/1.71e-01 | Fail(train/test) 0/0 | LR 7.35e-04 | 3.4s
# Epoch  202 | Step  4040/ 5000 | Train 1.1686e-02 | Test 1.3954e-02 | SO3(train/test) 1.65e-01/1.72e-01 | Fail(train/test) 0/0 | LR 7.11e-04 | 3.6s
# Epoch  203 | Step  4060/ 5000 | Train 1.1602e-02 | Test 1.3732e-02 | SO3(train/test) 1.66e-01/1.73e-01 | Fail(train/test) 0/0 | LR 6.86e-04 | 3.4s
# Epoch  204 | Step  4080/ 5000 | Train 1.1484e-02 | Test 1.3687e-02 | SO3(train/test) 1.66e-01/1.73e-01 | Fail(train/test) 0/0 | LR 6.62e-04 | 3.4s
# Epoch  205 | Step  4100/ 5000 | Train 1.1437e-02 | Test 1.3617e-02 | SO3(train/test) 1.67e-01/1.74e-01 | Fail(train/test) 0/0 | LR 6.39e-04 | 3.5s
# Epoch  206 | Step  4120/ 5000 | Train 1.1439e-02 | Test 1.3567e-02 | SO3(train/test) 1.67e-01/1.74e-01 | Fail(train/test) 0/0 | LR 6.16e-04 | 3.5s
# Epoch  207 | Step  4140/ 5000 | Train 1.1414e-02 | Test 1.3521e-02 | SO3(train/test) 1.68e-01/1.75e-01 | Fail(train/test) 0/0 | LR 5.93e-04 | 3.4s
# Epoch  208 | Step  4160/ 5000 | Train 1.1367e-02 | Test 1.3443e-02 | SO3(train/test) 1.68e-01/1.74e-01 | Fail(train/test) 0/0 | LR 5.71e-04 | 3.5s
# Epoch  209 | Step  4180/ 5000 | Train 1.1257e-02 | Test 1.3357e-02 | SO3(train/test) 1.68e-01/1.75e-01 | Fail(train/test) 0/0 | LR 5.50e-04 | 3.5s
# Epoch  210 | Step  4200/ 5000 | Train 1.1185e-02 | Test 1.3306e-02 | SO3(train/test) 1.69e-01/1.75e-01 | Fail(train/test) 0/0 | LR 5.29e-04 | 3.5s
# Epoch  211 | Step  4220/ 5000 | Train 1.1127e-02 | Test 1.3180e-02 | SO3(train/test) 1.69e-01/1.76e-01 | Fail(train/test) 0/0 | LR 5.08e-04 | 3.4s
# Epoch  212 | Step  4240/ 5000 | Train 1.1116e-02 | Test 1.3058e-02 | SO3(train/test) 1.69e-01/1.75e-01 | Fail(train/test) 0/0 | LR 4.88e-04 | 3.6s
# Epoch  213 | Step  4260/ 5000 | Train 1.1061e-02 | Test 1.3092e-02 | SO3(train/test) 1.69e-01/1.75e-01 | Fail(train/test) 0/0 | LR 4.68e-04 | 3.5s
# Epoch  214 | Step  4280/ 5000 | Train 1.1026e-02 | Test 1.3111e-02 | SO3(train/test) 1.70e-01/1.76e-01 | Fail(train/test) 0/0 | LR 4.49e-04 | 3.4s
# Epoch  215 | Step  4300/ 5000 | Train 1.0978e-02 | Test 1.3030e-02 | SO3(train/test) 1.70e-01/1.75e-01 | Fail(train/test) 0/0 | LR 4.30e-04 | 3.4s
# Epoch  216 | Step  4320/ 5000 | Train 1.0958e-02 | Test 1.2855e-02 | SO3(train/test) 1.70e-01/1.75e-01 | Fail(train/test) 0/0 | LR 4.12e-04 | 3.5s
# Epoch  217 | Step  4340/ 5000 | Train 1.0892e-02 | Test 1.2944e-02 | SO3(train/test) 1.70e-01/1.76e-01 | Fail(train/test) 0/0 | LR 3.94e-04 | 3.4s
# Epoch  218 | Step  4360/ 5000 | Train 1.0863e-02 | Test 1.2823e-02 | SO3(train/test) 1.70e-01/1.75e-01 | Fail(train/test) 0/0 | LR 3.77e-04 | 3.5s
# Epoch  219 | Step  4380/ 5000 | Train 1.0831e-02 | Test 1.2771e-02 | SO3(train/test) 1.70e-01/1.76e-01 | Fail(train/test) 0/0 | LR 3.60e-04 | 3.5s
# Epoch  220 | Step  4400/ 5000 | Train 1.0783e-02 | Test 1.2740e-02 | SO3(train/test) 1.70e-01/1.76e-01 | Fail(train/test) 0/0 | LR 3.44e-04 | 3.6s
# Epoch  221 | Step  4420/ 5000 | Train 1.0760e-02 | Test 1.2804e-02 | SO3(train/test) 1.70e-01/1.76e-01 | Fail(train/test) 0/0 | LR 3.28e-04 | 3.4s
# Epoch  222 | Step  4440/ 5000 | Train 1.0716e-02 | Test 1.2605e-02 | SO3(train/test) 1.70e-01/1.76e-01 | Fail(train/test) 0/0 | LR 3.12e-04 | 3.4s
# Epoch  223 | Step  4460/ 5000 | Train 1.0663e-02 | Test 1.2575e-02 | SO3(train/test) 1.70e-01/1.76e-01 | Fail(train/test) 0/0 | LR 2.98e-04 | 3.6s
# Epoch  224 | Step  4480/ 5000 | Train 1.0640e-02 | Test 1.2533e-02 | SO3(train/test) 1.70e-01/1.76e-01 | Fail(train/test) 0/0 | LR 2.83e-04 | 3.5s
# Epoch  225 | Step  4500/ 5000 | Train 1.0619e-02 | Test 1.2514e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 2.70e-04 | 3.5s
# Epoch  226 | Step  4520/ 5000 | Train 1.0572e-02 | Test 1.2503e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 2.57e-04 | 3.4s
# Epoch  227 | Step  4540/ 5000 | Train 1.0567e-02 | Test 1.2464e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 2.44e-04 | 3.5s
# Epoch  228 | Step  4560/ 5000 | Train 1.0529e-02 | Test 1.2383e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 2.32e-04 | 3.5s
# Epoch  229 | Step  4580/ 5000 | Train 1.0472e-02 | Test 1.2346e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 2.20e-04 | 3.4s
# Epoch  230 | Step  4600/ 5000 | Train 1.0457e-02 | Test 1.2344e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 2.09e-04 | 3.5s
# Epoch  231 | Step  4620/ 5000 | Train 1.0449e-02 | Test 1.2272e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 1.98e-04 | 3.5s
# Epoch  232 | Step  4640/ 5000 | Train 1.0416e-02 | Test 1.2263e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 1.88e-04 | 3.4s
# Epoch  233 | Step  4660/ 5000 | Train 1.0397e-02 | Test 1.2233e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 1.79e-04 | 3.6s
# Epoch  234 | Step  4680/ 5000 | Train 1.0357e-02 | Test 1.2210e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 1.70e-04 | 3.5s
# Epoch  235 | Step  4700/ 5000 | Train 1.0339e-02 | Test 1.2167e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 1.61e-04 | 3.5s
# Epoch  236 | Step  4720/ 5000 | Train 1.0302e-02 | Test 1.2125e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 1.53e-04 | 3.4s
# Epoch  237 | Step  4740/ 5000 | Train 1.0286e-02 | Test 1.2103e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 1.46e-04 | 3.4s
# Epoch  238 | Step  4760/ 5000 | Train 1.0262e-02 | Test 1.2075e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 1.39e-04 | 3.5s
# Epoch  239 | Step  4780/ 5000 | Train 1.0250e-02 | Test 1.2058e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 1.33e-04 | 3.6s
# Epoch  240 | Step  4800/ 5000 | Train 1.0222e-02 | Test 1.1989e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 1.27e-04 | 3.4s
# Epoch  241 | Step  4820/ 5000 | Train 1.0218e-02 | Test 1.2034e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 1.22e-04 | 3.5s
# Epoch  242 | Step  4840/ 5000 | Train 1.0184e-02 | Test 1.1964e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 1.17e-04 | 3.5s
# Epoch  243 | Step  4860/ 5000 | Train 1.0178e-02 | Test 1.1965e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 1.13e-04 | 3.4s
# Epoch  244 | Step  4880/ 5000 | Train 1.0158e-02 | Test 1.1930e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 1.10e-04 | 3.5s
# Epoch  245 | Step  4900/ 5000 | Train 1.0133e-02 | Test 1.1911e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 1.07e-04 | 3.5s
# Epoch  246 | Step  4920/ 5000 | Train 1.0114e-02 | Test 1.1903e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 1.04e-04 | 3.4s
# Epoch  247 | Step  4940/ 5000 | Train 1.0089e-02 | Test 1.1877e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 1.02e-04 | 3.4s
# Epoch  248 | Step  4960/ 5000 | Train 1.0089e-02 | Test 1.1842e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 1.01e-04 | 3.4s
# Epoch  249 | Step  4980/ 5000 | Train 1.0074e-02 | Test 1.1838e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 1.00e-04 | 3.5s
# Epoch  250 | Step  5000/ 5000 | Train 1.0054e-02 | Test 1.1799e-02 | SO3(train/test) 1.71e-01/1.76e-01 | Fail(train/test) 0/0 | LR 1.00e-04 | 3.4s
# Reached target optimizer steps: 5000/5000
# Done. Best validation score: failure_rate=0.0000, test_loss=1.1799e-02 (epoch 250)
# Running detailed evaluation...
# Block evaluation profile: clean
# Block evaluation noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0048 +/- 0.0019  (max 0.0117)
# Rotation geo [rad]:  0.0130 +/- 0.0075  (max 0.0439)
# Lin vel RMSE [m/s]:  0.0129 +/- 0.0084
# Ang vel RMSE [r/s]:  0.0016 +/- 0.0008
# Components:  u=0.0177  v=0.0098  w=0.0039  p=0.0013  q=0.0014  r=0.0016
# SO(3) violation:  |det-1|=8.31e-02  ||RR^T-I||=1.85e-01
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# Block evaluation profile: nominal_eval
# Block evaluation noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0050 +/- 0.0021  (max 0.0132)
# Rotation geo [rad]:  0.0168 +/- 0.0083  (max 0.0551)
# Lin vel RMSE [m/s]:  0.0139 +/- 0.0080
# Ang vel RMSE [r/s]:  0.0036 +/- 0.0020
# Components:  u=0.0189  v=0.0105  w=0.0053  p=0.0051  q=0.0016  r=0.0020
# SO(3) violation:  |det-1|=8.31e-02  ||RR^T-I||=1.86e-01
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# Block evaluation profile: heading_biased_eval
# Block evaluation noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0065 +/- 0.0030  (max 0.0167)
# Rotation geo [rad]:  0.0382 +/- 0.0116  (max 0.0876)
# Lin vel RMSE [m/s]:  0.0152 +/- 0.0086
# Ang vel RMSE [r/s]:  0.0036 +/- 0.0020
# Components:  u=0.0198  v=0.0136  w=0.0055  p=0.0051  q=0.0016  r=0.0020
# SO(3) violation:  |det-1|=8.31e-02  ||RR^T-I||=1.85e-01
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Block Evaluation Relative To Clean
# ==================================================
# [nominal_eval]
# position_rmse: ratio=1.043  degradation=+4.3%
# rotation_geodesic: ratio=1.291  degradation=+29.1%
# velocity_rmse: ratio=1.075  degradation=+7.5%
# angular_rmse: ratio=2.215  degradation=+121.5%
# failure_rate: ratio=1.000  degradation=+0.0%
# [heading_biased_eval]
# position_rmse: ratio=1.368  degradation=+36.8%
# rotation_geodesic: ratio=2.935  degradation=+193.5%
# velocity_rmse: ratio=1.177  degradation=+17.7%
# angular_rmse: ratio=2.213  degradation=+121.3%
# failure_rate: ratio=1.000  degradation=+0.0%
# Running held-out trajectory evaluation...
# Held-out evaluation profile: clean
# Held-out evaluation noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0045 (median 0.0041, p95 0.0076)
# Rotation geo [rad]:  0.0099 (median 0.0091, p95 0.0175)
# Lin vel RMSE [m/s]:  0.0103  Ang vel RMSE [r/s]:  0.0014
# SO(3) violation:  |det-1|=6.92e-02  ||RR^T-I||=1.73e-01
# Noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# [CHIRP] pos=0.0032 m, rot=0.0087 rad, success=1.0000
# [OU] pos=0.0051 m, rot=0.0127 rad, success=1.0000
# [PRBS] pos=0.0046 m, rot=0.0080 rad, success=1.0000
# Held-out evaluation profile: nominal_eval
# Held-out evaluation noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0047 (median 0.0043, p95 0.0078)
# Rotation geo [rad]:  0.0145 (median 0.0140, p95 0.0208)
# Lin vel RMSE [m/s]:  0.0114  Ang vel RMSE [r/s]:  0.0034
# SO(3) violation:  |det-1|=6.94e-02  ||RR^T-I||=1.73e-01
# Noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# [CHIRP] pos=0.0034 m, rot=0.0135 rad, success=1.0000
# [OU] pos=0.0053 m, rot=0.0169 rad, success=1.0000
# [PRBS] pos=0.0048 m, rot=0.0129 rad, success=1.0000
# Held-out evaluation profile: degraded_eval
# Held-out evaluation noise budget: protocol=iid_noisy_ic | profile=degraded_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0054 (median 0.0050, p95 0.0085)
# Rotation geo [rad]:  0.0249 (median 0.0245, p95 0.0295)
# Lin vel RMSE [m/s]:  0.0139  Ang vel RMSE [r/s]:  0.0060
# SO(3) violation:  |det-1|=7.00e-02  ||RR^T-I||=1.75e-01
# Noise budget: protocol=iid_noisy_ic | profile=degraded_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250]
# [CHIRP] pos=0.0043 m, rot=0.0242 rad, success=1.0000
# [OU] pos=0.0059 m, rot=0.0268 rad, success=1.0000
# [PRBS] pos=0.0055 m, rot=0.0236 rad, success=1.0000
# Held-out evaluation profile: heading_biased_eval
# Held-out evaluation noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Held-Out Trajectory Evaluation
# ...
# Epoch  231 | Step  4620/ 5000 | Train 1.1664e-02 | Test 1.3655e-02 | SO3(train/test) 1.88e-01/1.85e-01 | Fail(train/test) 0/0 | LR 1.98e-04 | 3.5s
# Epoch  232 | Step  4640/ 5000 | Train 1.1661e-02 | Test 1.3625e-02 | SO3(train/test) 1.88e-01/1.85e-01 | Fail(train/test) 0/0 | LR 1.88e-04 | 3.5s
# Epoch  233 | Step  4660/ 5000 | Train 1.1636e-02 | Test 1.3646e-02 | SO3(train/test) 1.88e-01/1.85e-01 | Fail(train/test) 0/0 | LR 1.79e-04 | 3.5s
# Epoch  234 | Step  4680/ 5000 | Train 1.1626e-02 | Test 1.3621e-02 | SO3(train/test) 1.88e-01/1.84e-01 | Fail(train/test) 0/0 | LR 1.70e-04 | 3.4s
# Epoch  235 | Step  4700/ 5000 | Train 1.1595e-02 | Test 1.3603e-02 | SO3(train/test) 1.88e-01/1.85e-01 | Fail(train/test) 0/0 | LR 1.61e-04 | 3.6s
# Epoch  236 | Step  4720/ 5000 | Train 1.1593e-02 | Test 1.3589e-02 | SO3(train/test) 1.88e-01/1.85e-01 | Fail(train/test) 0/0 | LR 1.53e-04 | 3.4s
# Epoch  237 | Step  4740/ 5000 | Train 1.1591e-02 | Test 1.3548e-02 | SO3(train/test) 1.88e-01/1.84e-01 | Fail(train/test) 0/0 | LR 1.46e-04 | 3.4s
# Epoch  238 | Step  4760/ 5000 | Train 1.1575e-02 | Test 1.3550e-02 | SO3(train/test) 1.88e-01/1.84e-01 | Fail(train/test) 0/0 | LR 1.39e-04 | 3.4s
# Epoch  239 | Step  4780/ 5000 | Train 1.1576e-02 | Test 1.3572e-02 | SO3(train/test) 1.88e-01/1.85e-01 | Fail(train/test) 0/0 | LR 1.33e-04 | 3.5s
# Epoch  240 | Step  4800/ 5000 | Train 1.1547e-02 | Test 1.3533e-02 | SO3(train/test) 1.88e-01/1.85e-01 | Fail(train/test) 0/0 | LR 1.27e-04 | 3.5s
# Epoch  241 | Step  4820/ 5000 | Train 1.1528e-02 | Test 1.3485e-02 | SO3(train/test) 1.88e-01/1.84e-01 | Fail(train/test) 0/0 | LR 1.22e-04 | 3.5s
# Epoch  242 | Step  4840/ 5000 | Train 1.1526e-02 | Test 1.3490e-02 | SO3(train/test) 1.88e-01/1.85e-01 | Fail(train/test) 0/0 | LR 1.17e-04 | 3.5s
# Epoch  243 | Step  4860/ 5000 | Train 1.1508e-02 | Test 1.3487e-02 | SO3(train/test) 1.88e-01/1.85e-01 | Fail(train/test) 0/0 | LR 1.13e-04 | 3.6s
# Epoch  244 | Step  4880/ 5000 | Train 1.1482e-02 | Test 1.3491e-02 | SO3(train/test) 1.88e-01/1.85e-01 | Fail(train/test) 0/0 | LR 1.10e-04 | 3.5s
# Epoch  245 | Step  4900/ 5000 | Train 1.1489e-02 | Test 1.3493e-02 | SO3(train/test) 1.88e-01/1.85e-01 | Fail(train/test) 0/0 | LR 1.07e-04 | 3.6s
# Epoch  246 | Step  4920/ 5000 | Train 1.1481e-02 | Test 1.3443e-02 | SO3(train/test) 1.88e-01/1.85e-01 | Fail(train/test) 0/0 | LR 1.04e-04 | 3.5s
# Epoch  247 | Step  4940/ 5000 | Train 1.1486e-02 | Test 1.3449e-02 | SO3(train/test) 1.88e-01/1.85e-01 | Fail(train/test) 0/0 | LR 1.02e-04 | 3.5s
# Epoch  248 | Step  4960/ 5000 | Train 1.1459e-02 | Test 1.3426e-02 | SO3(train/test) 1.88e-01/1.84e-01 | Fail(train/test) 0/0 | LR 1.01e-04 | 3.6s
# Epoch  249 | Step  4980/ 5000 | Train 1.1459e-02 | Test 1.3365e-02 | SO3(train/test) 1.88e-01/1.84e-01 | Fail(train/test) 0/0 | LR 1.00e-04 | 3.7s
# Epoch  250 | Step  5000/ 5000 | Train 1.1430e-02 | Test 1.3362e-02 | SO3(train/test) 1.88e-01/1.85e-01 | Fail(train/test) 0/0 | LR 1.00e-04 | 3.6s
# Reached target optimizer steps: 5000/5000
# Done. Best validation score: failure_rate=0.0000, test_loss=1.3362e-02 (epoch 250)
# Running detailed evaluation...
# Block evaluation profile: clean
# Block evaluation noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0052 +/- 0.0038  (max 0.0176)
# Rotation geo [rad]:  0.0130 +/- 0.0074  (max 0.0422)
# Lin vel RMSE [m/s]:  0.0138 +/- 0.0097
# Ang vel RMSE [r/s]:  0.0022 +/- 0.0011
# Components:  u=0.0149  v=0.0149  w=0.0041  p=0.0015  q=0.0022  r=0.0020
# SO(3) violation:  |det-1|=7.42e-02  ||RR^T-I||=2.08e-01
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# Block evaluation profile: nominal_eval
# Block evaluation noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0055 +/- 0.0037  (max 0.0182)
# Rotation geo [rad]:  0.0168 +/- 0.0084  (max 0.0569)
# Lin vel RMSE [m/s]:  0.0148 +/- 0.0093
# Ang vel RMSE [r/s]:  0.0039 +/- 0.0019
# Components:  u=0.0166  v=0.0153  w=0.0056  p=0.0051  q=0.0024  r=0.0024
# SO(3) violation:  |det-1|=7.44e-02  ||RR^T-I||=2.08e-01
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# Block evaluation profile: heading_biased_eval
# Block evaluation noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0072 +/- 0.0041  (max 0.0221)
# Rotation geo [rad]:  0.0380 +/- 0.0116  (max 0.0756)
# Lin vel RMSE [m/s]:  0.0163 +/- 0.0101
# Ang vel RMSE [r/s]:  0.0039 +/- 0.0019
# Components:  u=0.0180  v=0.0177  w=0.0058  p=0.0051  q=0.0024  r=0.0024
# SO(3) violation:  |det-1|=7.43e-02  ||RR^T-I||=2.08e-01
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Block Evaluation Relative To Clean
# ==================================================
# [nominal_eval]
# position_rmse: ratio=1.054  degradation=+5.4%
# rotation_geodesic: ratio=1.296  degradation=+29.6%
# velocity_rmse: ratio=1.075  degradation=+7.5%
# angular_rmse: ratio=1.791  degradation=+79.1%
# failure_rate: ratio=1.000  degradation=+0.0%
# [heading_biased_eval]
# position_rmse: ratio=1.392  degradation=+39.2%
# rotation_geodesic: ratio=2.931  degradation=+193.1%
# velocity_rmse: ratio=1.185  degradation=+18.5%
# angular_rmse: ratio=1.794  degradation=+79.4%
# failure_rate: ratio=1.000  degradation=+0.0%
# Running held-out trajectory evaluation...
# Held-out evaluation profile: clean
# Held-out evaluation noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0045 (median 0.0040, p95 0.0086)
# Rotation geo [rad]:  0.0100 (median 0.0091, p95 0.0174)
# Lin vel RMSE [m/s]:  0.0104  Ang vel RMSE [r/s]:  0.0018
# SO(3) violation:  |det-1|=6.28e-02  ||RR^T-I||=1.83e-01
# Noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# [CHIRP] pos=0.0035 m, rot=0.0089 rad, success=1.0000
# [OU] pos=0.0051 m, rot=0.0128 rad, success=1.0000
# [PRBS] pos=0.0044 m, rot=0.0079 rad, success=1.0000
# Held-out evaluation profile: nominal_eval
# Held-out evaluation noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0046 (median 0.0042, p95 0.0088)
# Rotation geo [rad]:  0.0146 (median 0.0139, p95 0.0211)
# Lin vel RMSE [m/s]:  0.0115  Ang vel RMSE [r/s]:  0.0036
# SO(3) violation:  |det-1|=6.30e-02  ||RR^T-I||=1.84e-01
# Noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# [CHIRP] pos=0.0037 m, rot=0.0137 rad, success=1.0000
# [OU] pos=0.0052 m, rot=0.0170 rad, success=1.0000
# [PRBS] pos=0.0046 m, rot=0.0129 rad, success=1.0000
# Held-out evaluation profile: degraded_eval
# Held-out evaluation noise budget: protocol=iid_noisy_ic | profile=degraded_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0053 (median 0.0049, p95 0.0092)
# Rotation geo [rad]:  0.0252 (median 0.0246, p95 0.0303)
# Lin vel RMSE [m/s]:  0.0140  Ang vel RMSE [r/s]:  0.0062
# SO(3) violation:  |det-1|=6.37e-02  ||RR^T-I||=1.86e-01
# Noise budget: protocol=iid_noisy_ic | profile=degraded_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250]
# [CHIRP] pos=0.0045 m, rot=0.0245 rad, success=1.0000
# [OU] pos=0.0058 m, rot=0.0269 rad, success=1.0000
# [PRBS] pos=0.0053 m, rot=0.0239 rad, success=1.0000
# Held-out evaluation profile: heading_biased_eval
# Held-out evaluation noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0061 (median 0.0057, p95 0.0096)
# Rotation geo [rad]:  0.0374 (median 0.0369, p95 0.0413)
# Lin vel RMSE [m/s]:  0.0126  Ang vel RMSE [r/s]:  0.0036
# SO(3) violation:  |det-1|=6.30e-02  ||RR^T-I||=1.84e-01
# Noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# [CHIRP] pos=0.0053 m, rot=0.0368 rad, success=1.0000
# [OU] pos=0.0065 m, rot=0.0385 rad, success=1.0000
# [PRBS] pos=0.0061 m, rot=0.0367 rad, success=1.0000
# ==================================================
# Held-Out Evaluation Relative To Clean
# ==================================================
# [nominal_eval]
# position_rmse: ratio=1.040  degradation=+4.0%
# rotation_geodesic: ratio=1.465  degradation=+46.5%
# velocity_rmse: ratio=1.103  degradation=+10.3%
# angular_rmse: ratio=2.034  degradation=+103.4%
# success_rate: ratio=1.000  degradation=+0.0%
# trajectory_failure_rate: ratio=1.000  degradation=+0.0%
# [degraded_eval]
# position_rmse: ratio=1.198  degradation=+19.8%
# rotation_geodesic: ratio=2.520  degradation=+152.0%
# velocity_rmse: ratio=1.343  degradation=+34.3%
# angular_rmse: ratio=3.545  degradation=+254.5%
# success_rate: ratio=1.000  degradation=+0.0%
# trajectory_failure_rate: ratio=1.000  degradation=+0.0%
# [heading_biased_eval]
# position_rmse: ratio=1.363  degradation=+36.3%
# rotation_geodesic: ratio=3.746  degradation=+274.6%
# velocity_rmse: ratio=1.211  degradation=+21.1%
# angular_rmse: ratio=2.034  degradation=+103.4%
# success_rate: ratio=1.000  degradation=+0.0%
# trajectory_failure_rate: ratio=1.000  degradation=+0.0%
#
# Training finished. Results: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed46
# Training sweep complete.
# Manifest: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/runs.tsv
# Next step:
#   scripts/batch_eval_models.sh --suite-dir "/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate"
#
# Training complete.
# Suite directory: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate
# Next step:
#   bash scripts/eval_all_models_noise_profile.sh --suite-dir "/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate"
# [audit] /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate
#                                                   suite_name    group         model_type  seed train_noise_protocol  best_epoch  best_loss  noise_warmup_epochs  noise_ramp_epochs  noise_mix_ratio  epoch_scale_at_best  is_effectively_clean_at_best
# sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate baseline blackbox_fullstate    42                clean         250   0.011799                   20                 80              0.5                  0.0                          True
# sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate baseline blackbox_fullstate    43                clean         250   0.012905                   20                 80              0.5                  0.0                          True
# sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate baseline blackbox_fullstate    44                clean         247   0.013503                   20                 80              0.5                  0.0                          True
# sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate baseline blackbox_fullstate    45                clean         250   0.013572                   20                 80              0.5                  0.0                          True
# sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate baseline blackbox_fullstate    46                clean         250   0.013362                   20                 80              0.5                  0.0                          True
# [validate_v4] skipped: v4lite not in PHASE1A_PROTOCOLS=clean

# %% [markdown]
# ## 4. Decision rollout eval (clean suite x 4 robustness profiles)
# Evaluates the clean-trained suite across `clean nominal_eval degraded_eval heading_biased_eval` (iid eval protocol) plus the `v4_lite` eval at `nominal_eval`.

# %%
os.environ["MODE"] = "decision_eval"
# !bash scripts/run_phase1a_oc_v4lite.sh
# Out:
# [phase1a]
# MODE=decision_eval
# RUN_TAG=t2_wpfrag_blackbox_fullstate
# DATASET=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# DEVICE=cuda
# PHASE1A_MODELS=blackbox_fullstate
# PHASE1A_PROTOCOLS=clean
# SMOKE1_MODELS=blackbox_fullstate
# SMOKE_SEEDS=42
# DECISION_SEEDS=42 43 44 45 46
# NOISE_REFERENCE=remus100_dr
# PHASE1A_LOG_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_logs/t2_wpfrag_blackbox_fullstate
# PHASE1A_METADATA_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_metadata_t2_wpfrag_blackbox_fullstate
# [eval] suite=sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate eval_protocol=iid_noisy_ic profiles=clean nominal_eval degraded_eval heading_biased_eval
# Suite directory: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate
# Manifest: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/runs.tsv
# Mode: resampled
# [eval] baseline_blackbox_fullstate_seed42
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=clean | noise_protocol=clean | noise_budget=protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000] | scenarios=PRBS,CHIRP,OU | trajectories=90 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_131812/clean
# [scenario 1/3] PRBS | 30 trajectories
# [1/90] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=5h04m42.1s
# [5/90] PRBS seed=46 done | reason=pred_divergence | sim_time=19.35s | eta=58m12.3s
# [10/90] PRBS seed=51 done | reason=pred_divergence | sim_time=15.95s | eta=27m23.5s
# [15/90] PRBS seed=56 done | reason=completed | sim_time=60.00s | eta=17m07.3s
# [20/90] PRBS seed=61 done | reason=pred_divergence | sim_time=15.75s | eta=11m59.1s
# [25/90] PRBS seed=66 done | reason=completed | sim_time=60.00s | eta=8m54.3s
# [30/90] PRBS seed=71 done | reason=pred_divergence | sim_time=56.35s | eta=6m51.0s
# [scenario done] PRBS | completed=13/30 | gt_div=0 | model_fail=17 | H=60.0s cond_n=13/30 | pos_med=98.1704 m | pos_p95=137.4073 m | rot_med=3.0673 rad | completion=0.433 | elapsed=3m25.5s
# [scenario 2/3] CHIRP | 30 trajectories
# [31/90] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=13m08.7s
# [35/90] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=10m51.2s
# [40/90] CHIRP seed=100051 done | reason=completed | sim_time=60.00s | eta=8m38.1s
# [45/90] CHIRP seed=100056 done | reason=completed | sim_time=60.00s | eta=6m54.5s
# [50/90] CHIRP seed=100061 done | reason=completed | sim_time=60.00s | eta=5m31.6s
# [55/90] CHIRP seed=100066 done | reason=completed | sim_time=60.00s | eta=4m23.8s
# [60/90] CHIRP seed=100071 done | reason=completed | sim_time=60.00s | eta=3m27.2s
# [scenario done] CHIRP | completed=20/30 | gt_div=0 | model_fail=10 | H=60.0s cond_n=20/30 | pos_med=89.0942 m | pos_p95=141.7936 m | rot_med=3.0498 rad | completion=0.667 | elapsed=6m54.5s
# [scenario 3/3] OU | 30 trajectories
# [61/90] OU seed=200042 done | reason=pred_divergence | sim_time=29.35s | eta=4m56.3s
# [65/90] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=3m59.8s
# [70/90] OU seed=200051 done | reason=pred_divergence | sim_time=36.95s | eta=2m58.1s
# [75/90] OU seed=200056 done | reason=pred_divergence | sim_time=49.35s | eta=2m04.7s
# [80/90] OU seed=200061 done | reason=completed | sim_time=60.00s | eta=1m17.9s
# [85/90] OU seed=200066 done | reason=pred_divergence | sim_time=57.95s | eta=36.7s
# [90/90] OU seed=200071 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=18/30 | gt_div=0 | model_fail=12 | H=60.0s cond_n=18/30 | pos_med=81.1859 m | pos_p95=129.9531 m | rot_med=2.9937 rad | completion=0.600 | elapsed=10m23.5s
# Benchmark finished in 10m42.5s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_131812/clean
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: Full-State Black-Box [baseline/core]
# Canonical model type: blackbox_fullstate
# Energy semantics: not_comparable
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 30
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=11.6213 m | pos p95=17.2620 m | rot median=2.9997 rad | total vel median=0.4026 m/s | rel vel median=0.1977 m/s | cond_n=87/90 | completion=0.967 | gt_fail_by_h=0.000 | model_fail_by_h=0.033
# H=30.0s | pos median=38.4589 m | pos p95=64.3230 m | rot median=3.0312 rad | total vel median=0.9133 m/s | rel vel median=0.5064 m/s | cond_n=71/90 | completion=0.789 | gt_fail_by_h=0.000 | model_fail_by_h=0.211
# H=60.0s | pos median=85.4530 m | pos p95=137.4626 m | rot median=3.0345 rad | total vel median=0.8389 m/s | rel vel median=0.4752 m/s | cond_n=51/90 | completion=0.567 | gt_fail_by_h=0.000 | model_fail_by_h=0.433
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=90 | completed=51 (0.567) | gt_divergence=0 (0.000) | pred_divergence=39 (0.433) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=30 | completed=13 (0.433) | gt_divergence=0 (0.000) | pred_divergence=17 (0.567) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=12.4560 m | pos p95=17.4491 m | rot median=3.0398 rad | total vel median=0.3662 m/s | rel vel median=0.2581 m/s | cond_n=29/30 | completion=0.967 | gt_fail_by_h=0.000 | model_fail_by_h=0.033
#   H=30.0s | pos median=47.1627 m | pos p95=66.4672 m | rot median=3.0571 rad | total vel median=0.7993 m/s | rel vel median=0.4047 m/s | cond_n=22/30 | completion=0.733 | gt_fail_by_h=0.000 | model_fail_by_h=0.267
#   H=60.0s | pos median=98.1704 m | pos p95=137.4073 m | rot median=3.0673 rad | total vel median=0.7871 m/s | rel vel median=0.5456 m/s | cond_n=13/30 | completion=0.433 | gt_fail_by_h=0.000 | model_fail_by_h=0.567
#
# CHIRP
#   n=30 | completed=20 (0.667) | gt_divergence=0 (0.000) | pred_divergence=10 (0.333) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=11.4717 m | pos p95=16.5258 m | rot median=2.9949 rad | total vel median=0.4441 m/s | rel vel median=0.1977 m/s | cond_n=29/30 | completion=0.967 | gt_fail_by_h=0.000 | model_fail_by_h=0.033
#   H=30.0s | pos median=36.6626 m | pos p95=58.9452 m | rot median=3.0312 rad | total vel median=1.3492 m/s | rel vel median=0.6349 m/s | cond_n=23/30 | completion=0.767 | gt_fail_by_h=0.000 | model_fail_by_h=0.233
#   H=60.0s | pos median=89.0942 m | pos p95=141.7936 m | rot median=3.0498 rad | total vel median=1.0451 m/s | rel vel median=0.4490 m/s | cond_n=20/30 | completion=0.667 | gt_fail_by_h=0.000 | model_fail_by_h=0.333
#
# OU
#   n=30 | completed=18 (0.600) | gt_divergence=0 (0.000) | pred_divergence=12 (0.400) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=11.4126 m | pos p95=17.1749 m | rot median=2.9182 rad | total vel median=0.3768 m/s | rel vel median=0.1753 m/s | cond_n=29/30 | completion=0.967 | gt_fail_by_h=0.000 | model_fail_by_h=0.033
#   H=30.0s | pos median=38.7230 m | pos p95=63.4960 m | rot median=2.9383 rad | total vel median=0.7990 m/s | rel vel median=0.4271 m/s | cond_n=26/30 | completion=0.867 | gt_fail_by_h=0.000 | model_fail_by_h=0.133
#   H=60.0s | pos median=81.1859 m | pos p95=129.9531 m | rot median=2.9937 rad | total vel median=0.7593 m/s | rel vel median=0.4609 m/s | cond_n=18/30 | completion=0.600 | gt_fail_by_h=0.000 | model_fail_by_h=0.400
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Earliest rollout failures
#   OU seed=200060 | reason=pred_divergence | sim_time=1.55s | pos=nan m | rot=nan rad | total_vel_violation=0
#   CHIRP seed=100065 | reason=pred_divergence | sim_time=3.95s | pos=nan m | rot=nan rad | total_vel_violation=0
#   PRBS seed=69 | reason=pred_divergence | sim_time=3.95s | pos=nan m | rot=nan rad | total_vel_violation=0
#   PRBS seed=49 | reason=pred_divergence | sim_time=11.75s | pos=nan m | rot=nan rad | total_vel_violation=0
#   OU seed=200055 | reason=pred_divergence | sim_time=14.15s | pos=nan m | rot=nan rad | total_vel_violation=0
#
# Largest completed terminal errors
#   CHIRP seed=100045 | reason=completed | sim_time=60.00s | pos=143.3470 m | rot=2.8255 rad | total_vel_violation=0
#   CHIRP seed=100055 | reason=completed | sim_time=60.00s | pos=141.7118 m | rot=2.7929 rad | total_vel_violation=0
#   PRBS seed=60 | reason=completed | sim_time=60.00s | pos=137.7392 m | rot=3.0358 rad | total_vel_violation=0
#   PRBS seed=67 | reason=completed | sim_time=60.00s | pos=137.1860 m | rot=2.9778 rad | total_vel_violation=0
#   OU seed=200061 | reason=completed | sim_time=60.00s | pos=134.6502 m | rot=2.6703 rad | total_vel_violation=1
#
# Completed rollouts with velocity violations
#   OU seed=200061 | reason=completed | sim_time=60.00s | pos=134.6502 m | rot=2.6703 rad | total_vel_violation=1
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=128.9447 m | rot=3.0673 rad | total_vel_violation=1
#   CHIRP seed=100068 | reason=completed | sim_time=60.00s | pos=127.9812 m | rot=3.0805 rad | total_vel_violation=1
#   OU seed=200049 | reason=completed | sim_time=60.00s | pos=123.6487 m | rot=3.0345 rad | total_vel_violation=1
#   CHIRP seed=100058 | reason=completed | sim_time=60.00s | pos=121.5813 m | rot=3.0515 rad | total_vel_violation=1
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# OU seed=200060 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_131812/clean/diagnostic_plots/rollout_failure_OU_seed200060.png
# CHIRP seed=100065 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_131812/clean/diagnostic_plots/rollout_failure_CHIRP_seed100065.png
# PRBS seed=69 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_131812/clean/diagnostic_plots/rollout_failure_PRBS_seed69.png
# PRBS seed=49 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_131812/clean/diagnostic_plots/rollout_failure_PRBS_seed49.png
# OU seed=200055 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_131812/clean/diagnostic_plots/rollout_failure_OU_seed200055.png
# OU seed=200061 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_131812/clean/diagnostic_plots/velocity_violation_OU_seed200061.png
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=nominal_eval | noise_protocol=iid_noisy_ic | noise_budget=protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | scenarios=PRBS,CHIRP,OU | trajectories=90 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_131812/nominal_eval
# [scenario 1/3] PRBS | 30 trajectories
# [1/90] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=8m31.8s
# [5/90] PRBS seed=46 done | reason=pred_divergence | sim_time=19.35s | eta=1m37.9s
# [10/90] PRBS seed=51 done | reason=pred_divergence | sim_time=15.95s | eta=46.2s
# [15/90] PRBS seed=56 done | reason=completed | sim_time=60.00s | eta=29.0s
# [20/90] PRBS seed=61 done | reason=pred_divergence | sim_time=15.75s | eta=20.3s
# [25/90] PRBS seed=66 done | reason=completed | sim_time=60.00s | eta=15.1s
# [30/90] PRBS seed=71 done | reason=pred_divergence | sim_time=56.35s | eta=11.7s
# [scenario done] PRBS | completed=13/30 | gt_div=0 | model_fail=17 | H=60.0s cond_n=13/30 | pos_med=98.1901 m | pos_p95=137.4063 m | rot_med=3.0664 rad | completion=0.433 | elapsed=5.9s
# [scenario 2/3] CHIRP | 30 trajectories
# [31/90] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=22.4s
# [35/90] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=18.5s
# [40/90] CHIRP seed=100051 done | reason=completed | sim_time=60.00s | eta=14.7s
# [45/90] CHIRP seed=100056 done | reason=completed | sim_time=60.00s | eta=11.8s
# [50/90] CHIRP seed=100061 done | reason=completed | sim_time=60.00s | eta=9.5s
# [55/90] CHIRP seed=100066 done | reason=completed | sim_time=60.00s | eta=7.5s
# [60/90] CHIRP seed=100071 done | reason=completed | sim_time=60.00s | eta=5.9s
# [scenario done] CHIRP | completed=20/30 | gt_div=0 | model_fail=10 | H=60.0s cond_n=20/30 | pos_med=89.1151 m | pos_p95=141.8209 m | rot_med=3.0499 rad | completion=0.667 | elapsed=11.9s
# [scenario 3/3] OU | 30 trajectories
# [61/90] OU seed=200042 done | reason=pred_divergence | sim_time=29.35s | eta=8.4s
# [65/90] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=6.8s
# [70/90] OU seed=200051 done | reason=pred_divergence | sim_time=36.95s | eta=5.1s
# [75/90] OU seed=200056 done | reason=pred_divergence | sim_time=49.35s | eta=3.5s
# [80/90] OU seed=200061 done | reason=completed | sim_time=60.00s | eta=2.2s
# [85/90] OU seed=200066 done | reason=pred_divergence | sim_time=57.95s | eta=1.0s
# [90/90] OU seed=200071 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=18/30 | gt_div=0 | model_fail=12 | H=60.0s cond_n=18/30 | pos_med=81.1901 m | pos_p95=129.8983 m | rot_med=2.9941 rad | completion=0.600 | elapsed=17.8s
# Benchmark finished in 36.0s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_131812/nominal_eval
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: Full-State Black-Box [baseline/core]
# Canonical model type: blackbox_fullstate
# Energy semantics: not_comparable
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 30
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=11.5876 m | pos p95=17.2560 m | rot median=2.9986 rad | total vel median=0.4105 m/s | rel vel median=0.1980 m/s | cond_n=87/90 | completion=0.967 | gt_fail_by_h=0.000 | model_fail_by_h=0.033
# H=30.0s | pos median=38.4487 m | pos p95=64.2857 m | rot median=3.0295 rad | total vel median=0.9121 m/s | rel vel median=0.5051 m/s | cond_n=71/90 | completion=0.789 | gt_fail_by_h=0.000 | model_fail_by_h=0.211
# H=60.0s | pos median=85.4165 m | pos p95=137.4621 m | rot median=3.0345 rad | total vel median=0.8390 m/s | rel vel median=0.4740 m/s | cond_n=51/90 | completion=0.567 | gt_fail_by_h=0.000 | model_fail_by_h=0.433
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=90 | completed=51 (0.567) | gt_divergence=0 (0.000) | pred_divergence=39 (0.433) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=30 | completed=13 (0.433) | gt_divergence=0 (0.000) | pred_divergence=17 (0.567) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=12.4631 m | pos p95=17.4606 m | rot median=3.0413 rad | total vel median=0.3716 m/s | rel vel median=0.2582 m/s | cond_n=29/30 | completion=0.967 | gt_fail_by_h=0.000 | model_fail_by_h=0.033
#   H=30.0s | pos median=47.1908 m | pos p95=66.3904 m | rot median=3.0570 rad | total vel median=0.7984 m/s | rel vel median=0.3999 m/s | cond_n=22/30 | completion=0.733 | gt_fail_by_h=0.000 | model_fail_by_h=0.267
#   H=60.0s | pos median=98.1901 m | pos p95=137.4063 m | rot median=3.0664 rad | total vel median=0.7871 m/s | rel vel median=0.5460 m/s | cond_n=13/30 | completion=0.433 | gt_fail_by_h=0.000 | model_fail_by_h=0.567
#
# CHIRP
#   n=30 | completed=20 (0.667) | gt_divergence=0 (0.000) | pred_divergence=10 (0.333) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=11.4565 m | pos p95=16.4920 m | rot median=2.9947 rad | total vel median=0.4423 m/s | rel vel median=0.1965 m/s | cond_n=29/30 | completion=0.967 | gt_fail_by_h=0.000 | model_fail_by_h=0.033
#   H=30.0s | pos median=36.6698 m | pos p95=58.9469 m | rot median=3.0295 rad | total vel median=1.3492 m/s | rel vel median=0.6331 m/s | cond_n=23/30 | completion=0.767 | gt_fail_by_h=0.000 | model_fail_by_h=0.233
#   H=60.0s | pos median=89.1151 m | pos p95=141.8209 m | rot median=3.0499 rad | total vel median=1.0452 m/s | rel vel median=0.4484 m/s | cond_n=20/30 | completion=0.667 | gt_fail_by_h=0.000 | model_fail_by_h=0.333
#
# OU
#   n=30 | completed=18 (0.600) | gt_divergence=0 (0.000) | pred_divergence=12 (0.400) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=11.4507 m | pos p95=17.1642 m | rot median=2.9165 rad | total vel median=0.3765 m/s | rel vel median=0.1759 m/s | cond_n=29/30 | completion=0.967 | gt_fail_by_h=0.000 | model_fail_by_h=0.033
#   H=30.0s | pos median=38.7229 m | pos p95=63.4947 m | rot median=2.9385 rad | total vel median=0.7986 m/s | rel vel median=0.4240 m/s | cond_n=26/30 | completion=0.867 | gt_fail_by_h=0.000 | model_fail_by_h=0.133
#   H=60.0s | pos median=81.1901 m | pos p95=129.8983 m | rot median=2.9941 rad | total vel median=0.7595 m/s | rel vel median=0.4600 m/s | cond_n=18/30 | completion=0.600 | gt_fail_by_h=0.000 | model_fail_by_h=0.400
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Earliest rollout failures
#   OU seed=200060 | reason=pred_divergence | sim_time=1.55s | pos=nan m | rot=nan rad | total_vel_violation=0
#   CHIRP seed=100065 | reason=pred_divergence | sim_time=3.95s | pos=nan m | rot=nan rad | total_vel_violation=0
#   PRBS seed=69 | reason=pred_divergence | sim_time=3.95s | pos=nan m | rot=nan rad | total_vel_violation=0
#   PRBS seed=49 | reason=pred_divergence | sim_time=11.75s | pos=nan m | rot=nan rad | total_vel_violation=0
#   OU seed=200055 | reason=pred_divergence | sim_time=14.15s | pos=nan m | rot=nan rad | total_vel_violation=0
#
# Largest completed terminal errors
#   CHIRP seed=100045 | reason=completed | sim_time=60.00s | pos=143.1106 m | rot=2.8237 rad | total_vel_violation=0
#   CHIRP seed=100055 | reason=completed | sim_time=60.00s | pos=141.7530 m | rot=2.7930 rad | total_vel_violation=0
#   PRBS seed=60 | reason=completed | sim_time=60.00s | pos=137.7413 m | rot=3.0357 rad | total_vel_violation=0
#   PRBS seed=67 | reason=completed | sim_time=60.00s | pos=137.1829 m | rot=2.9777 rad | total_vel_violation=0
#   OU seed=200061 | reason=completed | sim_time=60.00s | pos=134.3832 m | rot=2.6684 rad | total_vel_violation=1
#
# Completed rollouts with velocity violations
#   OU seed=200061 | reason=completed | sim_time=60.00s | pos=134.3832 m | rot=2.6684 rad | total_vel_violation=1
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=128.6552 m | rot=3.0664 rad | total_vel_violation=1
#   CHIRP seed=100068 | reason=completed | sim_time=60.00s | pos=127.9881 m | rot=3.0805 rad | total_vel_violation=1
#   OU seed=200049 | reason=completed | sim_time=60.00s | pos=123.7139 m | rot=3.0345 rad | total_vel_violation=1
#   CHIRP seed=100058 | reason=completed | sim_time=60.00s | pos=121.5778 m | rot=3.0517 rad | total_vel_violation=1
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# OU seed=200060 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_131812/nominal_eval/diagnostic_plots/rollout_failure_OU_seed200060.png
# CHIRP seed=100065 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_131812/nominal_eval/diagnostic_plots/rollout_failure_CHIRP_seed100065.png
# PRBS seed=69 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_131812/nominal_eval/diagnostic_plots/rollout_failure_PRBS_seed69.png
# PRBS seed=49 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_131812/nominal_eval/diagnostic_plots/rollout_failure_PRBS_seed49.png
# OU seed=200055 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_131812/nominal_eval/diagnostic_plots/rollout_failure_OU_seed200055.png
# OU seed=200061 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_131812/nominal_eval/diagnostic_plots/velocity_violation_OU_seed200061.png
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=degraded_eval | noise_protocol=iid_noisy_ic | noise_budget=protocol=iid_noisy_ic | profile=degraded_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250] | scenarios=PRBS,CHIRP,OU | trajectories=90 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_131812/degraded_eval
# [scenario 1/3] PRBS | 30 trajectories
# [1/90] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=8m10.5s
# [5/90] PRBS seed=46 done | reason=pred_divergence | sim_time=19.35s | eta=1m33.8s
# [10/90] PRBS seed=51 done | reason=pred_divergence | sim_time=15.95s | eta=44.3s
# [15/90] PRBS seed=56 done | reason=completed | sim_time=60.00s | eta=27.7s
# [20/90] PRBS seed=61 done | reason=pred_divergence | sim_time=15.75s | eta=19.5s
# [25/90] PRBS seed=66 done | reason=completed | sim_time=60.00s | eta=14.5s
# [30/90] PRBS seed=71 done | reason=pred_divergence | sim_time=56.15s | eta=11.2s
# [scenario done] PRBS | completed=13/30 | gt_div=0 | model_fail=17 | H=60.0s cond_n=13/30 | pos_med=98.2237 m | pos_p95=137.4240 m | rot_med=3.0653 rad | completion=0.433 | elapsed=5.6s
# [scenario 2/3] CHIRP | 30 trajectories
# [31/90] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=21.6s
# [35/90] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=17.9s
# [40/90] CHIRP seed=100051 done | reason=completed | sim_time=60.00s | eta=14.2s
# [45/90] CHIRP seed=100056 done | reason=completed | sim_time=60.00s | eta=11.4s
# [50/90] CHIRP seed=100061 done | reason=completed | sim_time=60.00s | eta=9.1s
# [55/90] CHIRP seed=100066 done | reason=completed | sim_time=60.00s | eta=7.3s
# [60/90] CHIRP seed=100071 done | reason=completed | sim_time=60.00s | eta=5.7s
# [scenario done] CHIRP | completed=20/30 | gt_div=0 | model_fail=10 | H=60.0s cond_n=20/30 | pos_med=89.1528 m | pos_p95=141.8272 m | rot_med=3.0500 rad | completion=0.667 | elapsed=11.5s
# [scenario 3/3] OU | 30 trajectories
# [61/90] OU seed=200042 done | reason=pred_divergence | sim_time=29.35s | eta=8.2s
# [65/90] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=6.6s
# [70/90] OU seed=200051 done | reason=pred_divergence | sim_time=37.15s | eta=4.9s
# [75/90] OU seed=200056 done | reason=pred_divergence | sim_time=49.35s | eta=3.4s
# [80/90] OU seed=200061 done | reason=completed | sim_time=60.00s | eta=2.2s
# [85/90] OU seed=200066 done | reason=pred_divergence | sim_time=57.95s | eta=1.0s
# [90/90] OU seed=200071 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=18/30 | gt_div=0 | model_fail=12 | H=60.0s cond_n=18/30 | pos_med=81.1898 m | pos_p95=129.8347 m | rot_med=2.9945 rad | completion=0.600 | elapsed=17.3s
# Benchmark finished in 35.4s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_131812/degraded_eval
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: Full-State Black-Box [baseline/core]
# Canonical model type: blackbox_fullstate
# Energy semantics: not_comparable
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 30
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=11.5537 m | pos p95=17.2459 m | rot median=2.9975 rad | total vel median=0.4166 m/s | rel vel median=0.1999 m/s | cond_n=87/90 | completion=0.967 | gt_fail_by_h=0.000 | model_fail_by_h=0.033
# H=30.0s | pos median=38.4384 m | pos p95=64.2558 m | rot median=3.0268 rad | total vel median=0.9085 m/s | rel vel median=0.5051 m/s | cond_n=71/90 | completion=0.789 | gt_fail_by_h=0.000 | model_fail_by_h=0.211
# H=60.0s | pos median=85.3894 m | pos p95=137.4813 m | rot median=3.0345 rad | total vel median=0.8392 m/s | rel vel median=0.4721 m/s | cond_n=51/90 | completion=0.567 | gt_fail_by_h=0.000 | model_fail_by_h=0.433
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=90 | completed=51 (0.567) | gt_divergence=0 (0.000) | pred_divergence=39 (0.433) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=30 | completed=13 (0.433) | gt_divergence=0 (0.000) | pred_divergence=17 (0.567) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=12.4840 m | pos p95=17.4759 m | rot median=3.0407 rad | total vel median=0.3770 m/s | rel vel median=0.2583 m/s | cond_n=29/30 | completion=0.967 | gt_fail_by_h=0.000 | model_fail_by_h=0.033
#   H=30.0s | pos median=47.2136 m | pos p95=66.3126 m | rot median=3.0568 rad | total vel median=0.7981 m/s | rel vel median=0.3957 m/s | cond_n=22/30 | completion=0.733 | gt_fail_by_h=0.000 | model_fail_by_h=0.267
#   H=60.0s | pos median=98.2237 m | pos p95=137.4240 m | rot median=3.0653 rad | total vel median=0.7872 m/s | rel vel median=0.5464 m/s | cond_n=13/30 | completion=0.433 | gt_fail_by_h=0.000 | model_fail_by_h=0.567
#
# CHIRP
#   n=30 | completed=20 (0.667) | gt_divergence=0 (0.000) | pred_divergence=10 (0.333) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=11.4407 m | pos p95=16.4564 m | rot median=2.9945 rad | total vel median=0.4407 m/s | rel vel median=0.1953 m/s | cond_n=29/30 | completion=0.967 | gt_fail_by_h=0.000 | model_fail_by_h=0.033
#   H=30.0s | pos median=36.6779 m | pos p95=58.9486 m | rot median=3.0268 rad | total vel median=1.3494 m/s | rel vel median=0.6320 m/s | cond_n=23/30 | completion=0.767 | gt_fail_by_h=0.000 | model_fail_by_h=0.233
#   H=60.0s | pos median=89.1528 m | pos p95=141.8272 m | rot median=3.0500 rad | total vel median=1.0453 m/s | rel vel median=0.4477 m/s | cond_n=20/30 | completion=0.667 | gt_fail_by_h=0.000 | model_fail_by_h=0.333
#
# OU
#   n=30 | completed=18 (0.600) | gt_divergence=0 (0.000) | pred_divergence=12 (0.400) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=11.4889 m | pos p95=17.1498 m | rot median=2.9142 rad | total vel median=0.3763 m/s | rel vel median=0.1776 m/s | cond_n=29/30 | completion=0.967 | gt_fail_by_h=0.000 | model_fail_by_h=0.033
#   H=30.0s | pos median=38.7192 m | pos p95=63.4818 m | rot median=2.9384 rad | total vel median=0.7980 m/s | rel vel median=0.4165 m/s | cond_n=26/30 | completion=0.867 | gt_fail_by_h=0.000 | model_fail_by_h=0.133
#   H=60.0s | pos median=81.1898 m | pos p95=129.8347 m | rot median=2.9945 rad | total vel median=0.7598 m/s | rel vel median=0.4586 m/s | cond_n=18/30 | completion=0.600 | gt_fail_by_h=0.000 | model_fail_by_h=0.400
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Earliest rollout failures
#   OU seed=200060 | reason=pred_divergence | sim_time=1.55s | pos=nan m | rot=nan rad | total_vel_violation=0
#   CHIRP seed=100065 | reason=pred_divergence | sim_time=3.95s | pos=nan m | rot=nan rad | total_vel_violation=0
#   PRBS seed=69 | reason=pred_divergence | sim_time=3.95s | pos=nan m | rot=nan rad | total_vel_violation=0
#   PRBS seed=49 | reason=pred_divergence | sim_time=11.75s | pos=nan m | rot=nan rad | total_vel_violation=0
#   OU seed=200055 | reason=pred_divergence | sim_time=14.15s | pos=nan m | rot=nan rad | total_vel_violation=0
#
# Largest completed terminal errors
#   CHIRP seed=100045 | reason=completed | sim_time=60.00s | pos=142.8726 m | rot=2.8218 rad | total_vel_violation=0
#   CHIRP seed=100055 | reason=completed | sim_time=60.00s | pos=141.7722 m | rot=2.7930 rad | total_vel_violation=0
#   PRBS seed=60 | reason=completed | sim_time=60.00s | pos=137.7679 m | rot=3.0357 rad | total_vel_violation=0
#   PRBS seed=67 | reason=completed | sim_time=60.00s | pos=137.1948 m | rot=2.9776 rad | total_vel_violation=0
#   CHIRP seed=100042 | reason=completed | sim_time=60.00s | pos=134.1411 m | rot=2.6044 rad | total_vel_violation=0
#
# Completed rollouts with velocity violations
#   OU seed=200061 | reason=completed | sim_time=60.00s | pos=134.0835 m | rot=2.6666 rad | total_vel_violation=1
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=128.3188 m | rot=3.0653 rad | total_vel_violation=1
#   CHIRP seed=100068 | reason=completed | sim_time=60.00s | pos=127.9943 m | rot=3.0804 rad | total_vel_violation=1
#   OU seed=200049 | reason=completed | sim_time=60.00s | pos=123.7844 m | rot=3.0345 rad | total_vel_violation=1
#   CHIRP seed=100058 | reason=completed | sim_time=60.00s | pos=121.5717 m | rot=3.0519 rad | total_vel_violation=1
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# OU seed=200060 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_131812/degraded_eval/diagnostic_plots/rollout_failure_OU_seed200060.png
# CHIRP seed=100065 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_131812/degraded_eval/diagnostic_plots/rollout_failure_CHIRP_seed100065.png
# PRBS seed=69 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_131812/degraded_eval/diagnostic_plots/rollout_failure_PRBS_seed69.png
# PRBS seed=49 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_131812/degraded_eval/diagnostic_plots/rollout_failure_PRBS_seed49.png
# OU seed=200055 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_131812/degraded_eval/diagnostic_plots/rollout_failure_OU_seed200055.png
# OU seed=200061 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_131812/degraded_eval/diagnostic_plots/velocity_violation_OU_seed200061.png
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=heading_biased_eval | noise_protocol=iid_noisy_ic | noise_budget=protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350] | scenarios=PRBS,CHIRP,OU | trajectories=90 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_131812/heading_biased_eval
# [scenario 1/3] PRBS | 30 trajectories
# [1/90] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=8m10.0s
# [5/90] PRBS seed=46 done | reason=pred_divergence | sim_time=19.35s | eta=1m33.8s
# [10/90] PRBS seed=51 done | reason=pred_divergence | sim_time=15.95s | eta=44.2s
# [15/90] PRBS seed=56 done | reason=completed | sim_time=60.00s | eta=27.7s
# [20/90] PRBS seed=61 done | reason=pred_divergence | sim_time=15.95s | eta=19.4s
# [25/90] PRBS seed=66 done | reason=completed | sim_time=60.00s | eta=14.5s
# [30/90] PRBS seed=71 done | reason=pred_divergence | sim_time=56.35s | eta=11.2s
# [scenario done] PRBS | completed=13/30 | gt_div=0 | model_fail=17 | H=60.0s cond_n=13/30 | pos_med=98.2876 m | pos_p95=137.4291 m | rot_med=3.0674 rad | completion=0.433 | elapsed=5.6s
# [scenario 2/3] CHIRP | 30 trajectories
# [31/90] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=21.6s
# [35/90] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=17.8s
# [40/90] CHIRP seed=100051 done | reason=completed | sim_time=60.00s | eta=14.2s
# [45/90] CHIRP seed=100056 done | reason=completed | sim_time=60.00s | eta=11.4s
# [50/90] CHIRP seed=100061 done | reason=completed | sim_time=60.00s | eta=9.1s
# [55/90] CHIRP seed=100066 done | reason=completed | sim_time=60.00s | eta=7.3s
# [60/90] CHIRP seed=100071 done | reason=completed | sim_time=60.00s | eta=5.7s
# [scenario done] CHIRP | completed=20/30 | gt_div=0 | model_fail=10 | H=60.0s cond_n=20/30 | pos_med=89.0311 m | pos_p95=142.0717 m | rot_med=3.0499 rad | completion=0.667 | elapsed=11.4s
# [scenario 3/3] OU | 30 trajectories
# [61/90] OU seed=200042 done | reason=pred_divergence | sim_time=29.15s | eta=8.2s
# [65/90] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=6.6s
# [70/90] OU seed=200051 done | reason=pred_divergence | sim_time=36.95s | eta=4.9s
# [75/90] OU seed=200056 done | reason=pred_divergence | sim_time=49.35s | eta=3.4s
# [80/90] OU seed=200061 done | reason=completed | sim_time=60.00s | eta=2.2s
# [85/90] OU seed=200066 done | reason=pred_divergence | sim_time=57.95s | eta=1.0s
# [90/90] OU seed=200071 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=18/30 | gt_div=0 | model_fail=12 | H=60.0s cond_n=18/30 | pos_med=81.1564 m | pos_p95=129.8221 m | rot_med=2.9932 rad | completion=0.600 | elapsed=17.3s
# Benchmark finished in 35.3s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_131812/heading_biased_eval
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: Full-State Black-Box [baseline/core]
# Canonical model type: blackbox_fullstate
# Energy semantics: not_comparable
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 30
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=11.6043 m | pos p95=17.2042 m | rot median=3.0005 rad | total vel median=0.4105 m/s | rel vel median=0.1982 m/s | cond_n=87/90 | completion=0.967 | gt_fail_by_h=0.000 | model_fail_by_h=0.033
# H=30.0s | pos median=38.3793 m | pos p95=64.2464 m | rot median=3.0314 rad | total vel median=0.9108 m/s | rel vel median=0.5061 m/s | cond_n=71/90 | completion=0.789 | gt_fail_by_h=0.000 | model_fail_by_h=0.211
# H=60.0s | pos median=85.5535 m | pos p95=137.5052 m | rot median=3.0346 rad | total vel median=0.8394 m/s | rel vel median=0.4710 m/s | cond_n=51/90 | completion=0.567 | gt_fail_by_h=0.000 | model_fail_by_h=0.433
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=90 | completed=51 (0.567) | gt_divergence=0 (0.000) | pred_divergence=39 (0.433) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=30 | completed=13 (0.433) | gt_divergence=0 (0.000) | pred_divergence=17 (0.567) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=12.5115 m | pos p95=17.4612 m | rot median=3.0403 rad | total vel median=0.3732 m/s | rel vel median=0.2576 m/s | cond_n=29/30 | completion=0.967 | gt_fail_by_h=0.000 | model_fail_by_h=0.033
#   H=30.0s | pos median=47.1949 m | pos p95=66.3770 m | rot median=3.0569 rad | total vel median=0.7969 m/s | rel vel median=0.3981 m/s | cond_n=22/30 | completion=0.733 | gt_fail_by_h=0.000 | model_fail_by_h=0.267
#   H=60.0s | pos median=98.2876 m | pos p95=137.4291 m | rot median=3.0674 rad | total vel median=0.7870 m/s | rel vel median=0.5453 m/s | cond_n=13/30 | completion=0.433 | gt_fail_by_h=0.000 | model_fail_by_h=0.567
#
# CHIRP
#   n=30 | completed=20 (0.667) | gt_divergence=0 (0.000) | pred_divergence=10 (0.333) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=11.4317 m | pos p95=16.3744 m | rot median=2.9947 rad | total vel median=0.4405 m/s | rel vel median=0.1974 m/s | cond_n=29/30 | completion=0.967 | gt_fail_by_h=0.000 | model_fail_by_h=0.033
#   H=30.0s | pos median=36.6806 m | pos p95=58.9323 m | rot median=3.0314 rad | total vel median=1.3520 m/s | rel vel median=0.6306 m/s | cond_n=23/30 | completion=0.767 | gt_fail_by_h=0.000 | model_fail_by_h=0.233
#   H=60.0s | pos median=89.0311 m | pos p95=142.0717 m | rot median=3.0499 rad | total vel median=1.0445 m/s | rel vel median=0.4484 m/s | cond_n=20/30 | completion=0.667 | gt_fail_by_h=0.000 | model_fail_by_h=0.333
#
# OU
#   n=30 | completed=18 (0.600) | gt_divergence=0 (0.000) | pred_divergence=12 (0.400) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=11.4700 m | pos p95=17.1134 m | rot median=2.9193 rad | total vel median=0.3765 m/s | rel vel median=0.1772 m/s | cond_n=29/30 | completion=0.967 | gt_fail_by_h=0.000 | model_fail_by_h=0.033
#   H=30.0s | pos median=38.6634 m | pos p95=63.4579 m | rot median=2.9383 rad | total vel median=0.8011 m/s | rel vel median=0.4161 m/s | cond_n=26/30 | completion=0.867 | gt_fail_by_h=0.000 | model_fail_by_h=0.133
#   H=60.0s | pos median=81.1564 m | pos p95=129.8221 m | rot median=2.9932 rad | total vel median=0.7593 m/s | rel vel median=0.4589 m/s | cond_n=18/30 | completion=0.600 | gt_fail_by_h=0.000 | model_fail_by_h=0.400
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Earliest rollout failures
#   OU seed=200060 | reason=pred_divergence | sim_time=1.55s | pos=nan m | rot=nan rad | total_vel_violation=0
#   CHIRP seed=100065 | reason=pred_divergence | sim_time=3.55s | pos=nan m | rot=nan rad | total_vel_violation=0
#   PRBS seed=69 | reason=pred_divergence | sim_time=4.15s | pos=nan m | rot=nan rad | total_vel_violation=0
#   PRBS seed=49 | reason=pred_divergence | sim_time=11.75s | pos=nan m | rot=nan rad | total_vel_violation=0
#   OU seed=200055 | reason=pred_divergence | sim_time=14.15s | pos=nan m | rot=nan rad | total_vel_violation=0
#
# Largest completed terminal errors
#   CHIRP seed=100045 | reason=completed | sim_time=60.00s | pos=142.9960 m | rot=2.8232 rad | total_vel_violation=0
#   CHIRP seed=100055 | reason=completed | sim_time=60.00s | pos=142.0231 m | rot=2.7930 rad | total_vel_violation=0
#   PRBS seed=60 | reason=completed | sim_time=60.00s | pos=137.8857 m | rot=3.0358 rad | total_vel_violation=0
#   PRBS seed=67 | reason=completed | sim_time=60.00s | pos=137.1248 m | rot=2.9779 rad | total_vel_violation=0
#   CHIRP seed=100042 | reason=completed | sim_time=60.00s | pos=134.2033 m | rot=2.6045 rad | total_vel_violation=0
#
# Completed rollouts with velocity violations
#   OU seed=200061 | reason=completed | sim_time=60.00s | pos=134.1548 m | rot=2.6673 rad | total_vel_violation=1
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=128.9307 m | rot=3.0674 rad | total_vel_violation=1
#   CHIRP seed=100068 | reason=completed | sim_time=60.00s | pos=127.9820 m | rot=3.0803 rad | total_vel_violation=1
#   OU seed=200049 | reason=completed | sim_time=60.00s | pos=123.6933 m | rot=3.0346 rad | total_vel_violation=1
#   CHIRP seed=100058 | reason=completed | sim_time=60.00s | pos=121.5621 m | rot=3.0517 rad | total_vel_violation=1
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# OU seed=200060 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_131812/heading_biased_eval/diagnostic_plots/rollout_failure_OU_seed200060.png
# CHIRP seed=100065 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_131812/heading_biased_eval/diagnostic_plots/rollout_failure_CHIRP_seed100065.png
# ...
#   H=30.0s | pos median=42.0357 m | pos p95=49.4350 m | rot median=3.0584 rad | total vel median=0.6027 m/s | rel vel median=0.3997 m/s | cond_n=22/30 | completion=0.733 | gt_fail_by_h=0.000 | model_fail_by_h=0.267
#   H=60.0s | pos median=109.9225 m | pos p95=122.2482 m | rot median=2.9529 rad | total vel median=0.7268 m/s | rel vel median=0.5742 m/s | cond_n=6/30 | completion=0.200 | gt_fail_by_h=0.000 | model_fail_by_h=0.800
#
# OU
#   n=30 | completed=7 (0.233) | gt_divergence=0 (0.000) | pred_divergence=23 (0.767) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=12.0270 m | pos p95=17.7805 m | rot median=2.8841 rad | total vel median=0.2723 m/s | rel vel median=0.1271 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=35.4120 m | pos p95=53.3529 m | rot median=2.9853 rad | total vel median=0.5426 m/s | rel vel median=0.2314 m/s | cond_n=23/30 | completion=0.767 | gt_fail_by_h=0.000 | model_fail_by_h=0.233
#   H=60.0s | pos median=68.0125 m | pos p95=90.5716 m | rot median=2.9728 rad | total vel median=0.5600 m/s | rel vel median=0.2396 m/s | cond_n=7/30 | completion=0.233 | gt_fail_by_h=0.000 | model_fail_by_h=0.767
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Earliest rollout failures
#   PRBS seed=65 | reason=pred_divergence | sim_time=10.75s | pos=nan m | rot=nan rad | total_vel_violation=0
#   CHIRP seed=100062 | reason=pred_divergence | sim_time=11.95s | pos=nan m | rot=nan rad | total_vel_violation=0
#   CHIRP seed=100043 | reason=pred_divergence | sim_time=12.35s | pos=nan m | rot=nan rad | total_vel_violation=0
#   CHIRP seed=100053 | reason=pred_divergence | sim_time=12.55s | pos=nan m | rot=nan rad | total_vel_violation=0
#   CHIRP seed=100048 | reason=pred_divergence | sim_time=15.75s | pos=nan m | rot=nan rad | total_vel_violation=0
#
# Largest completed terminal errors
#   PRBS seed=59 | reason=completed | sim_time=60.00s | pos=130.4463 m | rot=3.0760 rad | total_vel_violation=0
#   CHIRP seed=100061 | reason=completed | sim_time=60.00s | pos=123.7624 m | rot=3.0261 rad | total_vel_violation=1
#   CHIRP seed=100063 | reason=completed | sim_time=60.00s | pos=117.7055 m | rot=3.0879 rad | total_vel_violation=1
#   CHIRP seed=100051 | reason=completed | sim_time=60.00s | pos=114.3777 m | rot=2.9028 rad | total_vel_violation=0
#   PRBS seed=62 | reason=completed | sim_time=60.00s | pos=113.1637 m | rot=3.1206 rad | total_vel_violation=0
#
# Completed rollouts with velocity violations
#   CHIRP seed=100061 | reason=completed | sim_time=60.00s | pos=123.7624 m | rot=3.0261 rad | total_vel_violation=1
#   CHIRP seed=100063 | reason=completed | sim_time=60.00s | pos=117.7055 m | rot=3.0879 rad | total_vel_violation=1
#   CHIRP seed=100066 | reason=completed | sim_time=60.00s | pos=105.4673 m | rot=3.0029 rad | total_vel_violation=1
#   PRBS seed=43 | reason=completed | sim_time=60.00s | pos=99.8381 m | rot=2.6118 rad | total_vel_violation=1
#   OU seed=200068 | reason=completed | sim_time=60.00s | pos=93.7989 m | rot=3.0898 rad | total_vel_violation=1
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# PRBS seed=65 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed45/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260525_142106/diagnostic_plots/rollout_failure_PRBS_seed65.png
# CHIRP seed=100062 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed45/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260525_142106/diagnostic_plots/rollout_failure_CHIRP_seed100062.png
# CHIRP seed=100043 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed45/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260525_142106/diagnostic_plots/rollout_failure_CHIRP_seed100043.png
# CHIRP seed=100053 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed45/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260525_142106/diagnostic_plots/rollout_failure_CHIRP_seed100053.png
# CHIRP seed=100048 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed45/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260525_142106/diagnostic_plots/rollout_failure_CHIRP_seed100048.png
# CHIRP seed=100061 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed45/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260525_142106/diagnostic_plots/velocity_violation_CHIRP_seed100061.png
# [eval] baseline_blackbox_fullstate_seed46
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed46/best_model.pt | device=cuda | mode=resampled | noise_profile=nominal_eval | noise_protocol=v4_lite | noise_budget=protocol=v4_lite | profile=nominal_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | scenarios=PRBS,CHIRP,OU | trajectories=90 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260525_142144
# [scenario 1/3] PRBS | 30 trajectories
# [1/90] PRBS seed=42 done | reason=pred_divergence | sim_time=22.15s | eta=4m49.8s
# [5/90] PRBS seed=46 done | reason=pred_divergence | sim_time=8.35s | eta=55.5s
# [10/90] PRBS seed=51 done | reason=pred_divergence | sim_time=10.15s | eta=26.2s
# [15/90] PRBS seed=56 done | reason=pred_divergence | sim_time=26.15s | eta=16.4s
# [20/90] PRBS seed=61 done | reason=pred_divergence | sim_time=12.15s | eta=11.5s
# [25/90] PRBS seed=66 done | reason=pred_divergence | sim_time=14.95s | eta=8.6s
# [30/90] PRBS seed=71 done | reason=pred_divergence | sim_time=18.55s | eta=6.6s
# [scenario done] PRBS | completed=0/30 | gt_div=0 | model_fail=30 | H=60.0s cond_n=0/30 | pos_med=nan m | pos_p95=nan m | rot_med=nan rad | completion=0.000 | elapsed=3.3s
# [scenario 2/3] CHIRP | 30 trajectories
# [31/90] CHIRP seed=100042 done | reason=pred_divergence | sim_time=14.95s | eta=12.8s
# [35/90] CHIRP seed=100046 done | reason=pred_divergence | sim_time=31.95s | eta=10.6s
# [40/90] CHIRP seed=100051 done | reason=pred_divergence | sim_time=27.55s | eta=8.5s
# [45/90] CHIRP seed=100056 done | reason=pred_divergence | sim_time=16.95s | eta=6.8s
# [50/90] CHIRP seed=100061 done | reason=pred_divergence | sim_time=5.95s | eta=5.4s
# [55/90] CHIRP seed=100066 done | reason=pred_divergence | sim_time=18.95s | eta=4.3s
# [60/90] CHIRP seed=100071 done | reason=pred_divergence | sim_time=18.15s | eta=3.4s
# [scenario done] CHIRP | completed=0/30 | gt_div=0 | model_fail=30 | H=60.0s cond_n=0/30 | pos_med=nan m | pos_p95=nan m | rot_med=nan rad | completion=0.000 | elapsed=6.8s
# [scenario 3/3] OU | 30 trajectories
# [61/90] OU seed=200042 done | reason=pred_divergence | sim_time=19.75s | eta=4.9s
# [65/90] OU seed=200046 done | reason=pred_divergence | sim_time=25.55s | eta=4.0s
# [70/90] OU seed=200051 done | reason=pred_divergence | sim_time=21.35s | eta=3.0s
# [75/90] OU seed=200056 done | reason=pred_divergence | sim_time=25.15s | eta=2.1s
# [80/90] OU seed=200061 done | reason=pred_divergence | sim_time=13.95s | eta=1.3s
# [85/90] OU seed=200066 done | reason=pred_divergence | sim_time=17.95s | eta=0.6s
# [90/90] OU seed=200071 done | reason=pred_divergence | sim_time=13.95s | eta=0.0s
# [scenario done] OU | completed=0/30 | gt_div=0 | model_fail=30 | H=60.0s cond_n=0/30 | pos_med=nan m | pos_p95=nan m | rot_med=nan rad | completion=0.000 | elapsed=10.4s
# Benchmark finished in 26.4s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260525_142144
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed46/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: Full-State Black-Box [baseline/core]
# Canonical model type: blackbox_fullstate
# Energy semantics: not_comparable
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 30
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=11.6284 m | pos p95=23.9015 m | rot median=3.0668 rad | total vel median=0.5360 m/s | rel vel median=0.1819 m/s | cond_n=77/90 | completion=0.856 | gt_fail_by_h=0.000 | model_fail_by_h=0.144
# H=30.0s | pos median=49.4351 m | pos p95=74.3536 m | rot median=3.0395 rad | total vel median=1.5819 m/s | rel vel median=1.3785 m/s | cond_n=7/90 | completion=0.078 | gt_fail_by_h=0.000 | model_fail_by_h=0.922
# H=60.0s | pos median=nan m | pos p95=nan m | rot median=nan rad | total vel median=nan m/s | rel vel median=nan m/s | cond_n=0/90 | completion=0.000 | gt_fail_by_h=0.000 | model_fail_by_h=1.000
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=90 | completed=0 (0.000) | gt_divergence=0 (0.000) | pred_divergence=90 (1.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=30 | completed=0 (0.000) | gt_divergence=0 (0.000) | pred_divergence=30 (1.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=10.8668 m | pos p95=23.5885 m | rot median=3.0781 rad | total vel median=0.5872 m/s | rel vel median=0.1690 m/s | cond_n=25/30 | completion=0.833 | gt_fail_by_h=0.000 | model_fail_by_h=0.167
#   H=30.0s | pos median=62.9859 m | pos p95=75.1816 m | rot median=2.9494 rad | total vel median=1.7016 m/s | rel vel median=1.4599 m/s | cond_n=2/30 | completion=0.067 | gt_fail_by_h=0.000 | model_fail_by_h=0.933
#   H=60.0s | pos median=nan m | pos p95=nan m | rot median=nan rad | total vel median=nan m/s | rel vel median=nan m/s | cond_n=0/30 | completion=0.000 | gt_fail_by_h=0.000 | model_fail_by_h=1.000
#
# CHIRP
#   n=30 | completed=0 (0.000) | gt_divergence=0 (0.000) | pred_divergence=30 (1.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=11.6284 m | pos p95=22.3096 m | rot median=3.0683 rad | total vel median=0.4203 m/s | rel vel median=0.1629 m/s | cond_n=25/30 | completion=0.833 | gt_fail_by_h=0.000 | model_fail_by_h=0.167
#   H=30.0s | pos median=30.4611 m | pos p95=30.8319 m | rot median=3.1005 rad | total vel median=0.8038 m/s | rel vel median=0.7939 m/s | cond_n=2/30 | completion=0.067 | gt_fail_by_h=0.000 | model_fail_by_h=0.933
#   H=60.0s | pos median=nan m | pos p95=nan m | rot median=nan rad | total vel median=nan m/s | rel vel median=nan m/s | cond_n=0/30 | completion=0.000 | gt_fail_by_h=0.000 | model_fail_by_h=1.000
#
# OU
#   n=30 | completed=0 (0.000) | gt_divergence=0 (0.000) | pred_divergence=30 (1.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=11.9713 m | pos p95=24.0610 m | rot median=3.0327 rad | total vel median=0.4311 m/s | rel vel median=0.2256 m/s | cond_n=27/30 | completion=0.900 | gt_fail_by_h=0.000 | model_fail_by_h=0.100
#   H=30.0s | pos median=65.9484 m | pos p95=68.9286 m | rot median=3.0395 rad | total vel median=1.6715 m/s | rel vel median=1.3785 m/s | cond_n=3/30 | completion=0.100 | gt_fail_by_h=0.000 | model_fail_by_h=0.900
#   H=60.0s | pos median=nan m | pos p95=nan m | rot median=nan rad | total vel median=nan m/s | rel vel median=nan m/s | cond_n=0/30 | completion=0.000 | gt_fail_by_h=0.000 | model_fail_by_h=1.000
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Earliest rollout failures
#   OU seed=200060 | reason=pred_divergence | sim_time=1.15s | pos=nan m | rot=nan rad | total_vel_violation=0
#   PRBS seed=69 | reason=pred_divergence | sim_time=3.75s | pos=nan m | rot=nan rad | total_vel_violation=0
#   CHIRP seed=100048 | reason=pred_divergence | sim_time=4.95s | pos=nan m | rot=nan rad | total_vel_violation=0
#   CHIRP seed=100053 | reason=pred_divergence | sim_time=5.55s | pos=nan m | rot=nan rad | total_vel_violation=0
#   CHIRP seed=100061 | reason=pred_divergence | sim_time=5.95s | pos=nan m | rot=nan rad | total_vel_violation=0
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# OU seed=200060 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260525_142144/diagnostic_plots/rollout_failure_OU_seed200060.png
# PRBS seed=69 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260525_142144/diagnostic_plots/rollout_failure_PRBS_seed69.png
# CHIRP seed=100048 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260525_142144/diagnostic_plots/rollout_failure_CHIRP_seed100048.png
# CHIRP seed=100053 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260525_142144/diagnostic_plots/rollout_failure_CHIRP_seed100053.png
# CHIRP seed=100061 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260525_142144/diagnostic_plots/rollout_failure_CHIRP_seed100061.png
# OU seed=200055 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_blackbox_fullstate/baseline_blackbox_fullstate_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260525_142144/diagnostic_plots/rollout_failure_OU_seed200055.png
# Batch evaluation complete.

# %% [markdown]
# ## 5. Provenance injection (per-run `_audit_meta/`)
# Records git HEAD + environment fingerprint into every decision run dir so these runs are distinguishable from catalog-era drift.

# %%
# Inject per-run provenance. The training flow does NOT write these automatically,
# so for paper-grade evidence we record them here (see docs/provenance_audit_phnode_full_clean.md sec 5.2).
import os, sys, subprocess, datetime
from pathlib import Path
import torch

RUN_TAG = os.environ["RUN_TAG"]
ckpt = PROJECT_DIR / "checkpoints"
# clean-only sweep: only the clean suite exists, but we scan the full triple defensively.
suites = [ckpt / f"sweep_oc_phase1a_decision_{p}_{RUN_TAG}" for p in ("clean", "iid", "v4lite")]

def _sh(args):
    try:
        return subprocess.run(args, cwd=PROJECT_DIR, capture_output=True, text=True).stdout.strip()
    except Exception as exc:  # noqa: BLE001
        return f"<unavailable: {exc}>"

head = _sh(["git", "rev-parse", "HEAD"])
diffstat = _sh(["git", "diff", "HEAD", "--stat"])
env_txt = "\n".join([
    f"python={sys.version.split()[0]}",
    f"torch={torch.__version__}",
    f"cuda={torch.version.cuda}",
    f"cudnn={torch.backends.cudnn.version()}",
    f"gpu={torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'cpu'}",
    f"captured_at={datetime.datetime.now().isoformat()}",
])

n = 0
for suite in suites:
    if not suite.exists():
        continue
    for cfg in suite.rglob("config.json"):
        run_dir = cfg.parent
        meta = run_dir / "_audit_meta"
        meta.mkdir(exist_ok=True)
        (meta / "code_revision.txt").write_text(f"git_head={head}\n\n{diffstat}\n")
        (meta / "environment.txt").write_text(env_txt + "\n")
        n += 1
print(f"provenance written for {n} run dirs")
print("git_head =", head)
# Out:
# provenance written for 5 run dirs
# git_head =

# %% [markdown]
# ## 6. Anomaly scan
# Flags any run with the `no successful training batches` catastrophic-gradient signature. For black-box models a clean-mirror collapse is a legitimate instability result — flag and handle per B1 (exclude from the quantitative aggregate, annotate).

# %%
# Quick anomaly scan: catch seed46/seed43-style catastrophic training before trusting numbers.
# Black-box models are collapse-prone (blackbox_fullstate collapsed in the 2026-04 catalog:
# s44=86.8m, s42/s43=nan), so a clean-mirror collapse here is a LEGITIMATE black-box instability
# finding, not an artifact -- still flag it and handle per the B1 policy (exclude from the
# quantitative aggregate, annotate transparently).
import os, re
from pathlib import Path

RUN_TAG = os.environ["RUN_TAG"]
ckpt = PROJECT_DIR / "checkpoints"
suites = [ckpt / f"sweep_oc_phase1a_decision_{p}_{RUN_TAG}" for p in ("clean", "iid", "v4lite")]

print(f"{'suite':<48}{'run':<32}{'best_epoch':>10}{'best_loss':>14}{'nbad':>6}  flag")
for suite in suites:
    if not suite.exists():
        continue
    for cfg in sorted(suite.rglob("config.json")):
        run_dir = cfg.parent
        log = run_dir / "training.log"
        text = log.read_text() if log.exists() else ""
        nbad = text.count("no successful training batches")
        best_epoch, best_loss = "?", "?"
        m = re.findall(r"[Bb]est.*?epoch[^0-9]*([0-9]+).*?([0-9]+\.[0-9eE+-]+)", text)
        if m:
            best_epoch, best_loss = m[-1]
        flag = "  <-- CHECK (possible artifact / instability)" if nbad > 0 else ""
        print(f"{suite.name[:46]:<48}{run_dir.name[:30]:<32}{str(best_epoch):>10}{str(best_loss):>14}{nbad:>6}{flag}")
print("\nFlagged seeds: handle per B1 (exclude from aggregate via train_anomaly, annotate).")
# Out:
# suite                                           run                             best_epoch     best_loss  nbad  flag
# sweep_oc_phase1a_decision_clean_t2_wpfrag_blac  baseline_blackbox_fullstate_se           ?             ?     0
# sweep_oc_phase1a_decision_clean_t2_wpfrag_blac  baseline_blackbox_fullstate_se           ?             ?     0
# sweep_oc_phase1a_decision_clean_t2_wpfrag_blac  baseline_blackbox_fullstate_se           ?             ?     0
# sweep_oc_phase1a_decision_clean_t2_wpfrag_blac  baseline_blackbox_fullstate_se           ?             ?     0
# sweep_oc_phase1a_decision_clean_t2_wpfrag_blac  baseline_blackbox_fullstate_se           ?             ?     0
#
# Flagged seeds: handle per B1 (exclude from aggregate via train_anomaly, annotate).

# %% [markdown]
# ## 7. Next step (after all three black-box notebooks finish)
# 1. Ensure `checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_{blackbox_fullstate,se3_momentum_blackbox,se3_accel_blackbox}` are synced back.
# 2. Locally rerun `python scripts/export_section8_t2_evidence.py` (black-box models are already in MODELS).
# 3. The clean rows append to `analysis/section8_current_evidence/aggregate.csv` for the §8 structured-vs-black-box table.
# 4. No shared-catalog rebuild is needed — the export reads the decision suites directly.
