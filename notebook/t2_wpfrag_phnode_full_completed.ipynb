# %% [markdown]
# # T2 WP-Frag current-evidence rerun — `phnode_full`
#
# **Goal.** Reproduce current-main (`g3_5_7` mirror) evidence for this one model so the
# paper Results section (chapter section 8) can be cited from a single, machine-reproducible
# suite instead of catalog-era cloud numbers contaminated by environment drift.
#
# **Matrix (this notebook).** `phnode_full` x {clean, iid_noisy_ic@nominal_train, v4_lite@nominal_train} x seeds {42,43,44,45,46} = 15 training runs, then every trained
# suite is evaluated across {clean, nominal_eval, degraded_eval, heading_biased_eval}.
#
# **Parallelism.** Run the four `t2_wpfrag_*` notebooks (one per model:
# `phnode_full`, `phnode_qforce`, `ablate_no_lift`, `ablate_no_mass_prior`) in separate
# Colab sessions. They use distinct `RUN_TAG`s and do not collide.
#
# **Why these knobs differ from phase1a:** (1) `IID_EVAL_PROFILES` is the full 4-profile
# robustness set so clean-vs-noisy matched comparison is available; (2) a provenance cell
# writes per-run `_audit_meta/` (the trainer does not). noise schedule defaults
# (warmup=20, ramp=80, mix_ratio=0.5) match the repo `nominal_train` contract.
#
# **After all four finish:** sync `checkpoints/` back, then locally rebuild the catalog
# (`scripts/build_oc_data_catalog.py`) and export the section-8 current-evidence tables.
#
# > Watch list while running: `phnode_full` seeds 42/46, `ablate_no_lift` seeds 43/44 —
# > these were catalog-era anomalies. The anomaly-scan cell flags any recurrence.

# %%
# !nvidia-smi
# Out:
# Sat May 23 14:43:50 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   41C    P8             12W /   72W |       0MiB /  23034MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import torch
print(f"PyTorch: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"CUDA: {torch.version.cuda}")
print(f"cuDNN: {torch.backends.cudnn.version()}")
# Out:
# PyTorch: 2.10.0+cu128
# CUDA available: True
# CUDA: 12.8
# cuDNN: 91002

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
from pathlib import Path

PROJECT_DIR = Path(os.environ.get(
    "AUV_PROJECT_DIR",
    "/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7",
))
assert PROJECT_DIR.exists(), f"Project directory not found: {PROJECT_DIR}"
# %cd $PROJECT_DIR
# Out:
# /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7

# %%
# %pip install -q torchdiffeq pandas

# %% [markdown]
# ## 0. Configuration

# %%
import os

# Runtime
os.environ["PYTHON_BIN"] = "python"
os.environ["DEVICE"] = "cuda"
os.environ["LOCAL_PROXY_ROOT"] = "/content/_proxy_suites"

# ---- T2 identity (one model per notebook) ----
os.environ["RUN_TAG"] = "t2_wpfrag_phnode_full"
os.environ["DATASET"] = "data/auv_oc_traj1000_blk150_s23_d0be9434.pkl"
os.environ["NOISE_REFERENCE"] = "remus100_dr"
os.environ["PHASE1A_LOG_DIR"] = str(PROJECT_DIR / "checkpoints" / "phase1a_logs" / os.environ["RUN_TAG"])
os.environ["PHASE1A_METADATA_DIR"] = str(PROJECT_DIR / "checkpoints" / f"phase1a_metadata_{os.environ['RUN_TAG']}")

# ---- T2 matrix: single model x 3 protocols x 5 seeds ----
os.environ["PHASE1A_MODELS"] = "phnode_full"
os.environ["SMOKE1_MODELS"] = "phnode_full"
os.environ["SMOKE_SEEDS"] = "42"                 # cheap protocol-correctness gate (1 seed)
os.environ["DECISION_SEEDS"] = "42 43 44 45 46"  # full current-evidence seed set

# ---- Evaluation contract ----
os.environ["SMOKE_EVAL_NUM_TRAJ_PER_SCENARIO"] = "6"
os.environ["DECISION_EVAL_NUM_TRAJ_PER_SCENARIO"] = "30"
os.environ["EVAL_TIMES"] = "10 30 60"
os.environ["EVAL_SCENARIOS"] = "PRBS CHIRP OU"
os.environ["EVAL_BASE_SEED"] = "42"
os.environ["EVAL_NOISE_SEED"] = "2024"
os.environ["EVAL_PROGRESS_EVERY"] = "5"
os.environ["EVAL_NUM_DIAGNOSTIC_PLOTS"] = "6"
# Full robustness set: evaluates clean/iid/v4lite suites across all 4 profiles (caveat B).
os.environ["IID_EVAL_PROFILES"] = "clean nominal_eval degraded_eval heading_biased_eval"
os.environ["V4_EVAL_PROFILES"] = "nominal_eval"

# ---- Audit gate ----
os.environ["STRICT_ZERO_NOISE_AUDIT"] = "1"
os.environ["SOFT_MIN_EPOCH_SCALE"] = "0.05"

print("RUN_TAG       =", os.environ["RUN_TAG"])
print("PHASE1A_MODELS=", os.environ["PHASE1A_MODELS"])
print("DECISION_SEEDS=", os.environ["DECISION_SEEDS"])
print("IID_EVAL_PROFILES=", os.environ["IID_EVAL_PROFILES"])
# Out:
# RUN_TAG       = t2_wpfrag_phnode_full
# PHASE1A_MODELS= phnode_full
# DECISION_SEEDS= 42 43 44 45 46
# IID_EVAL_PROFILES= clean nominal_eval degraded_eval heading_biased_eval

# %% [markdown]
# ## 1. Preflight
# Confirms all target suite/proxy dirs are absent and saves suite-level run config + environment metadata. If it fails, change `RUN_TAG` or remove the target dirs.

# %%
os.environ["MODE"] = "preflight"
# !bash scripts/run_phase1a_oc_v4lite.sh
# Out:
# [phase1a]
# MODE=preflight
# RUN_TAG=t2_wpfrag_phnode_full
# DATASET=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# DEVICE=cuda
# PHASE1A_MODELS=phnode_full
# SMOKE1_MODELS=phnode_full
# SMOKE_SEEDS=42
# DECISION_SEEDS=42 43 44 45 46
# NOISE_REFERENCE=remus100_dr
# PHASE1A_LOG_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_logs/t2_wpfrag_phnode_full
# PHASE1A_METADATA_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_metadata_t2_wpfrag_phnode_full
# Preflight passed: all Phase-1A target suite/proxy directories are absent.
# [metadata] /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_metadata_t2_wpfrag_phnode_full

# %% [markdown]
# ## 2. Smoke gate (seed 42, all 3 protocols)
# Cheap protocol-correctness check (especially the `v4_lite` trajectory-consistent IC path and the strict zero-noise audit for `clean`). Important for `phnode_qforce`, which was not in the phase1a smoke set. Smoke results are flow-validation only — never cited.

# %%
os.environ["MODE"] = "smoke1_train"
# !bash scripts/run_phase1a_oc_v4lite.sh
# Out:
# [phase1a]
# MODE=smoke1_train
# RUN_TAG=t2_wpfrag_phnode_full
# DATASET=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# DEVICE=cuda
# PHASE1A_MODELS=phnode_full
# SMOKE1_MODELS=phnode_full
# SMOKE_SEEDS=42
# DECISION_SEEDS=42 43 44 45 46
# NOISE_REFERENCE=remus100_dr
# PHASE1A_LOG_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_logs/t2_wpfrag_phnode_full
# PHASE1A_METADATA_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_metadata_t2_wpfrag_phnode_full
# [train] suite=sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_full models=phnode_full seeds=42 protocol=auto
# Training all models with profile-based noisy IC.
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Group: all
# Explicit models: phnode_full
# Seeds: 42
# Noise config: protocol=auto, profile=clean, scale=1.0, warmup=20, ramp=80, mix_ratio=0.5
# Auto-eval profiles: block=[clean nominal_eval heading_biased_eval] heldout=[clean nominal_eval degraded_eval heading_biased_eval]
# Suite directory: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_full
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Models (1): phnode_full
# Seeds: 42
# [train] main_phnode_full_seed42
# Loading dataset...
# Loaded: 83850 train, 21000 test, t_eval=[0.   0.05 0.1  0.15 0.2 ]
# Dataset split: trajectory | train trajectories: 559 | test trajectories: 140
# Dataset ID: d0be9434
# Dataset path: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl | velocity convention: body_total | state dim: 27
# Position std: [0.1508, 0.1400, 0.0370]
# Velocity std: u=0.4722, v=0.0898, w=0.0718, p=0.0248, q=0.0906, r=0.0526
# Actuator std: a0=0.1543, a1=0.1555, a2=299.0037
# Training noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# Model: pH NODE Full [main/core] | canonical type: phnode_full
# Model parameters: 62,803
# Training dataset: id=d0be9434 | path=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Mass matrix initialized from physics
# Training: epochs<=300, target_steps=5000, warmup_steps=400, lr=6.00e-03 -> 1.00e-04, solver=rk4, so3_reg=1.00e-03
# Train samples: 83850, Test samples: 21000
# Epoch    1 | Step    20/ 5000 | Train 4.3508e+00 | Test 5.0458e+00 | SO3(train/test) 1.26e-07/1.27e-07 | Fail(train/test) 0/0 | LR 4.10e-04 | 8.1s
# Epoch    2 | Step    40/ 5000 | Train 3.5849e+00 | Test 4.3046e+00 | SO3(train/test) 1.19e-07/1.20e-07 | Fail(train/test) 0/0 | LR 7.05e-04 | 6.1s
# Epoch    3 | Step    60/ 5000 | Train 2.9504e+00 | Test 3.2210e+00 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.00e-03 | 5.9s
# Epoch    4 | Step    80/ 5000 | Train 1.7819e+00 | Test 1.0436e+00 | SO3(train/test) 1.20e-07/1.49e-07 | Fail(train/test) 0/0 | LR 1.29e-03 | 6.0s
# Epoch    5 | Step   100/ 5000 | Train 7.7154e-01 | Test 6.1857e-01 | SO3(train/test) 1.29e-07/1.15e-07 | Fail(train/test) 0/0 | LR 1.59e-03 | 6.0s
# Epoch    6 | Step   120/ 5000 | Train 7.3271e-01 | Test 7.2985e-01 | SO3(train/test) 1.15e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.88e-03 | 6.1s
# Epoch    7 | Step   140/ 5000 | Train 7.3189e-01 | Test 7.0204e-01 | SO3(train/test) 1.19e-07/1.23e-07 | Fail(train/test) 0/0 | LR 2.18e-03 | 5.9s
# Epoch    8 | Step   160/ 5000 | Train 9.1646e-01 | Test 1.3657e+00 | SO3(train/test) 1.88e-07/4.19e-07 | Fail(train/test) 0/0 | LR 2.47e-03 | 6.0s
# Epoch    9 | Step   180/ 5000 | Train 6.4671e-01 | Test 4.2992e-01 | SO3(train/test) 2.93e-07/1.80e-07 | Fail(train/test) 0/0 | LR 2.77e-03 | 5.9s
# Epoch   10 | Step   200/ 5000 | Train 4.0102e-01 | Test 3.2272e-01 | SO3(train/test) 1.32e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.06e-03 | 6.1s
# Epoch   11 | Step   220/ 5000 | Train 5.4610e-01 | Test 7.6371e-01 | SO3(train/test) 1.17e-07/1.29e-07 | Fail(train/test) 0/0 | LR 3.36e-03 | 5.9s
# Epoch   12 | Step   240/ 5000 | Train 6.8852e-01 | Test 1.3301e+00 | SO3(train/test) 1.22e-07/1.23e-07 | Fail(train/test) 0/0 | LR 3.65e-03 | 6.0s
# Epoch   13 | Step   260/ 5000 | Train 9.8837e-01 | Test 1.7049e+00 | SO3(train/test) 1.39e-07/1.64e-07 | Fail(train/test) 0/0 | LR 3.95e-03 | 5.9s
# Epoch   14 | Step   280/ 5000 | Train 1.2011e+00 | Test 1.1263e+00 | SO3(train/test) 6.34e-07/9.02e-07 | Fail(train/test) 0/0 | LR 4.24e-03 | 6.0s
# Epoch   15 | Step   300/ 5000 | Train 7.0657e-01 | Test 4.1899e-01 | SO3(train/test) 2.46e-07/2.21e-07 | Fail(train/test) 0/0 | LR 4.54e-03 | 6.0s
# Epoch   16 | Step   320/ 5000 | Train 3.6999e-01 | Test 4.1457e-01 | SO3(train/test) 1.52e-07/1.28e-07 | Fail(train/test) 0/0 | LR 4.83e-03 | 6.0s
# Epoch   17 | Step   340/ 5000 | Train 8.2631e-01 | Test 1.2798e+02 | SO3(train/test) 4.09e-07/2.30e-04 | Fail(train/test) 0/0 | LR 5.13e-03 | 5.9s
# Epoch   18 | Step   360/ 5000 | Train 9.8227e+00 | Test 1.6472e+00 | SO3(train/test) 1.36e-05/1.22e-07 | Fail(train/test) 0/0 | LR 5.42e-03 | 6.0s
# Epoch   19 | Step   380/ 5000 | Train 9.0113e-01 | Test 1.5542e+00 | SO3(train/test) 1.21e-07/1.32e-07 | Fail(train/test) 0/0 | LR 5.72e-03 | 5.9s
# Epoch   20 | Step   400/ 5000 | Train 6.4581e-01 | Test 4.2124e-01 | SO3(train/test) 1.17e-07/1.13e-07 | Fail(train/test) 0/0 | LR 6.00e-03 | 6.0s
# Epoch   21 | Step   420/ 5000 | Train 4.9859e-01 | Test 2.5856e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 6.00e-03 | 5.9s
# Epoch   22 | Step   440/ 5000 | Train 1.1076e+00 | Test 3.2183e+00 | SO3(train/test) 1.18e-07/1.27e-07 | Fail(train/test) 0/0 | LR 6.00e-03 | 5.9s
# Epoch   23 | Step   460/ 5000 | Train 1.0052e+00 | Test 8.8541e-01 | SO3(train/test) 1.37e-07/1.89e-07 | Fail(train/test) 0/0 | LR 6.00e-03 | 6.0s
# Epoch   24 | Step   480/ 5000 | Train 5.1725e-01 | Test 4.3019e-01 | SO3(train/test) 1.27e-07/1.14e-07 | Fail(train/test) 0/0 | LR 6.00e-03 | 5.9s
# Epoch   25 | Step   500/ 5000 | Train 4.2138e-01 | Test 7.0924e-01 | SO3(train/test) 1.14e-07/1.13e-07 | Fail(train/test) 0/0 | LR 5.99e-03 | 6.0s
# Epoch   26 | Step   520/ 5000 | Train 7.3917e-01 | Test 6.1279e-01 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.99e-03 | 5.8s
# Epoch   27 | Step   540/ 5000 | Train 5.5732e-01 | Test 4.9149e-01 | SO3(train/test) 1.14e-07/1.13e-07 | Fail(train/test) 0/0 | LR 5.99e-03 | 6.0s
# Epoch   28 | Step   560/ 5000 | Train 4.0944e-01 | Test 2.9991e-01 | SO3(train/test) 1.13e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.98e-03 | 5.9s
# Epoch   29 | Step   580/ 5000 | Train 3.3119e-01 | Test 3.8784e-01 | SO3(train/test) 1.14e-07/1.13e-07 | Fail(train/test) 0/0 | LR 5.98e-03 | 6.1s
# Epoch   30 | Step   600/ 5000 | Train 2.9614e-01 | Test 3.7977e-01 | SO3(train/test) 1.13e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.97e-03 | 6.1s
# Epoch   31 | Step   620/ 5000 | Train 2.6610e-01 | Test 1.7794e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.97e-03 | 6.0s
# Epoch   32 | Step   640/ 5000 | Train 3.4427e-01 | Test 4.2377e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.96e-03 | 5.9s
# Epoch   33 | Step   660/ 5000 | Train 2.9494e-01 | Test 3.0951e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.95e-03 | 6.0s
# Epoch   34 | Step   680/ 5000 | Train 3.0940e-01 | Test 2.4717e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 5.95e-03 | 6.0s
# Epoch   35 | Step   700/ 5000 | Train 2.4540e-01 | Test 2.1880e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.94e-03 | 6.1s
# Epoch   36 | Step   720/ 5000 | Train 2.5469e-01 | Test 3.5887e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.93e-03 | 6.0s
# Epoch   37 | Step   740/ 5000 | Train 1.8363e-01 | Test 1.2469e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.92e-03 | 6.0s
# Epoch   38 | Step   760/ 5000 | Train 2.0243e-01 | Test 2.5875e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.91e-03 | 5.9s
# Epoch   39 | Step   780/ 5000 | Train 1.9395e-01 | Test 2.3579e-01 | SO3(train/test) 1.14e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.90e-03 | 5.9s
# Epoch   40 | Step   800/ 5000 | Train 2.7430e-01 | Test 2.6487e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.89e-03 | 6.0s
# Epoch   41 | Step   820/ 5000 | Train 2.0269e-01 | Test 2.5005e-01 | SO3(train/test) 1.14e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.88e-03 | 6.0s
# Epoch   42 | Step   840/ 5000 | Train 3.7915e-01 | Test 4.9165e-01 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.87e-03 | 6.0s
# Epoch   43 | Step   860/ 5000 | Train 2.0918e-01 | Test 1.2922e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.86e-03 | 6.0s
# Epoch   44 | Step   880/ 5000 | Train 3.1596e-01 | Test 4.9138e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.84e-03 | 6.0s
# Epoch   45 | Step   900/ 5000 | Train 3.7134e-01 | Test 2.8780e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.83e-03 | 6.0s
# Epoch   46 | Step   920/ 5000 | Train 3.8193e-01 | Test 4.0802e-01 | SO3(train/test) 1.14e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.82e-03 | 5.9s
# Epoch   47 | Step   940/ 5000 | Train 2.0748e-01 | Test 1.2967e-01 | SO3(train/test) 1.14e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.80e-03 | 5.9s
# Epoch   48 | Step   960/ 5000 | Train 2.7099e-01 | Test 3.0930e-01 | SO3(train/test) 1.15e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.79e-03 | 6.0s
# Epoch   49 | Step   980/ 5000 | Train 1.7944e-01 | Test 1.3753e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.77e-03 | 5.9s
# Epoch   50 | Step  1000/ 5000 | Train 1.1704e-01 | Test 9.1627e-02 | SO3(train/test) 1.15e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.76e-03 | 6.1s
# Epoch   51 | Step  1020/ 5000 | Train 2.3458e-01 | Test 1.9837e-01 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.74e-03 | 5.9s
# Epoch   52 | Step  1040/ 5000 | Train 1.7602e-01 | Test 2.2454e-01 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.72e-03 | 5.9s
# Epoch   53 | Step  1060/ 5000 | Train 1.1398e-01 | Test 1.0144e-01 | SO3(train/test) 1.14e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.71e-03 | 5.9s
# Epoch   54 | Step  1080/ 5000 | Train 1.4875e-01 | Test 1.7859e-01 | SO3(train/test) 1.15e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.69e-03 | 6.0s
# Epoch   55 | Step  1100/ 5000 | Train 1.5380e-01 | Test 1.1351e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.67e-03 | 6.1s
# Epoch   56 | Step  1120/ 5000 | Train 1.0199e-01 | Test 1.2991e-01 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.65e-03 | 6.0s
# Epoch   57 | Step  1140/ 5000 | Train 1.1197e-01 | Test 1.2931e-01 | SO3(train/test) 1.15e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.63e-03 | 5.9s
# Epoch   58 | Step  1160/ 5000 | Train 8.4732e-02 | Test 8.0641e-02 | SO3(train/test) 1.16e-07/1.17e-07 | Fail(train/test) 0/0 | LR 5.61e-03 | 6.0s
# Epoch   59 | Step  1180/ 5000 | Train 8.6915e-02 | Test 1.3275e-01 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 5.59e-03 | 5.9s
# Epoch   60 | Step  1200/ 5000 | Train 2.1926e-01 | Test 1.5293e-01 | SO3(train/test) 1.16e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.57e-03 | 6.0s
# Epoch   61 | Step  1220/ 5000 | Train 1.6092e-01 | Test 1.0480e-01 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.55e-03 | 6.1s
# Epoch   62 | Step  1240/ 5000 | Train 9.0895e-02 | Test 9.5688e-02 | SO3(train/test) 1.16e-07/1.17e-07 | Fail(train/test) 0/0 | LR 5.53e-03 | 6.0s
# Epoch   63 | Step  1260/ 5000 | Train 7.5114e-02 | Test 8.9048e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.51e-03 | 6.1s
# Epoch   64 | Step  1280/ 5000 | Train 7.0856e-02 | Test 6.5896e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.48e-03 | 6.0s
# Epoch   65 | Step  1300/ 5000 | Train 6.8714e-02 | Test 7.0324e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.46e-03 | 6.2s
# Epoch   66 | Step  1320/ 5000 | Train 5.8493e-02 | Test 1.0690e-01 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.44e-03 | 6.0s
# Epoch   67 | Step  1340/ 5000 | Train 7.5651e-02 | Test 8.7984e-02 | SO3(train/test) 1.16e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.41e-03 | 6.1s
# Epoch   68 | Step  1360/ 5000 | Train 8.7879e-02 | Test 8.0786e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.39e-03 | 6.0s
# Epoch   69 | Step  1380/ 5000 | Train 6.5190e-02 | Test 6.8278e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.36e-03 | 6.0s
# Epoch   70 | Step  1400/ 5000 | Train 7.1615e-02 | Test 1.0761e-01 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.34e-03 | 6.0s
# Epoch   71 | Step  1420/ 5000 | Train 6.6949e-02 | Test 6.2039e-02 | SO3(train/test) 1.15e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.31e-03 | 6.0s
# Epoch   72 | Step  1440/ 5000 | Train 6.9502e-02 | Test 5.8650e-02 | SO3(train/test) 1.16e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.29e-03 | 5.9s
# Epoch   73 | Step  1460/ 5000 | Train 7.7124e-02 | Test 6.3036e-02 | SO3(train/test) 1.16e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.26e-03 | 6.0s
# Epoch   74 | Step  1480/ 5000 | Train 6.1404e-02 | Test 5.9311e-02 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.23e-03 | 5.8s
# Epoch   75 | Step  1500/ 5000 | Train 5.6825e-02 | Test 8.3078e-02 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.21e-03 | 6.0s
# Epoch   76 | Step  1520/ 5000 | Train 8.8365e-02 | Test 6.7274e-02 | SO3(train/test) 1.16e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.18e-03 | 5.8s
# Epoch   77 | Step  1540/ 5000 | Train 5.9874e-02 | Test 4.7619e-02 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.15e-03 | 6.0s
# Epoch   78 | Step  1560/ 5000 | Train 4.6362e-02 | Test 4.4534e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.12e-03 | 5.9s
# Epoch   79 | Step  1580/ 5000 | Train 7.1124e-02 | Test 4.5532e-02 | SO3(train/test) 1.16e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.09e-03 | 6.0s
# Epoch   80 | Step  1600/ 5000 | Train 4.4796e-02 | Test 5.4336e-02 | SO3(train/test) 1.16e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.06e-03 | 6.1s
# Epoch   81 | Step  1620/ 5000 | Train 6.5072e-02 | Test 5.5401e-02 | SO3(train/test) 1.16e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.03e-03 | 5.9s
# Epoch   82 | Step  1640/ 5000 | Train 4.2136e-02 | Test 3.9637e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.00e-03 | 6.0s
# Epoch   83 | Step  1660/ 5000 | Train 3.6180e-02 | Test 3.6724e-02 | SO3(train/test) 1.15e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.97e-03 | 6.0s
# Epoch   84 | Step  1680/ 5000 | Train 3.5026e-02 | Test 4.2196e-02 | SO3(train/test) 1.16e-07/1.15e-07 | Fail(train/test) 0/0 | LR 4.94e-03 | 6.1s
# Epoch   85 | Step  1700/ 5000 | Train 3.1617e-02 | Test 3.0568e-02 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 4.91e-03 | 6.2s
# Epoch   86 | Step  1720/ 5000 | Train 3.6397e-02 | Test 3.2962e-02 | SO3(train/test) 1.16e-07/1.15e-07 | Fail(train/test) 0/0 | LR 4.88e-03 | 6.0s
# Epoch   87 | Step  1740/ 5000 | Train 2.9300e-02 | Test 2.5068e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.85e-03 | 6.0s
# Epoch   88 | Step  1760/ 5000 | Train 2.7222e-02 | Test 2.6289e-02 | SO3(train/test) 1.16e-07/1.15e-07 | Fail(train/test) 0/0 | LR 4.82e-03 | 6.0s
# Epoch   89 | Step  1780/ 5000 | Train 2.3673e-02 | Test 1.6500e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.78e-03 | 6.0s
# Epoch   90 | Step  1800/ 5000 | Train 2.1020e-02 | Test 2.4197e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.75e-03 | 6.2s
# Epoch   91 | Step  1820/ 5000 | Train 1.6720e-02 | Test 1.3625e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.72e-03 | 6.0s
# Epoch   92 | Step  1840/ 5000 | Train 1.1516e-02 | Test 1.1032e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.68e-03 | 6.1s
# Epoch   93 | Step  1860/ 5000 | Train 1.1379e-02 | Test 1.3947e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.65e-03 | 6.0s
# Epoch   94 | Step  1880/ 5000 | Train 1.9458e-02 | Test 1.6386e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.62e-03 | 6.0s
# Epoch   95 | Step  1900/ 5000 | Train 1.6805e-02 | Test 1.1705e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.58e-03 | 6.2s
# Epoch   96 | Step  1920/ 5000 | Train 1.7272e-02 | Test 1.0341e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.55e-03 | 6.1s
# Epoch   97 | Step  1940/ 5000 | Train 1.5317e-02 | Test 9.4265e-03 | SO3(train/test) 1.16e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.51e-03 | 6.0s
# Epoch   98 | Step  1960/ 5000 | Train 2.6895e-02 | Test 2.6610e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.48e-03 | 6.2s
# Epoch   99 | Step  1980/ 5000 | Train 1.5651e-02 | Test 1.3285e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.44e-03 | 6.0s
# Epoch  100 | Step  2000/ 5000 | Train 1.1298e-02 | Test 1.5591e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.41e-03 | 6.2s
# Epoch  101 | Step  2020/ 5000 | Train 1.3338e-02 | Test 1.7737e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.37e-03 | 6.0s
# Epoch  102 | Step  2040/ 5000 | Train 1.3850e-02 | Test 1.5130e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.33e-03 | 6.1s
# Epoch  103 | Step  2060/ 5000 | Train 1.3803e-02 | Test 1.5082e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.30e-03 | 6.0s
# Epoch  104 | Step  2080/ 5000 | Train 1.3570e-02 | Test 1.7037e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.26e-03 | 6.1s
# Epoch  105 | Step  2100/ 5000 | Train 1.2729e-02 | Test 1.1249e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.22e-03 | 6.1s
# Epoch  106 | Step  2120/ 5000 | Train 1.2498e-02 | Test 1.7916e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.19e-03 | 6.1s
# Epoch  107 | Step  2140/ 5000 | Train 1.2070e-02 | Test 1.1470e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.15e-03 | 6.0s
# Epoch  108 | Step  2160/ 5000 | Train 1.1073e-02 | Test 1.1382e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.11e-03 | 6.0s
# Epoch  109 | Step  2180/ 5000 | Train 1.0554e-02 | Test 9.9167e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.08e-03 | 6.0s
# Epoch  110 | Step  2200/ 5000 | Train 1.0220e-02 | Test 9.7358e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.04e-03 | 6.1s
# Epoch  111 | Step  2220/ 5000 | Train 9.5013e-03 | Test 8.8022e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.00e-03 | 5.9s
# Epoch  112 | Step  2240/ 5000 | Train 9.5715e-03 | Test 1.0344e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.96e-03 | 5.9s
# Epoch  113 | Step  2260/ 5000 | Train 8.4847e-03 | Test 8.7496e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 3.92e-03 | 6.0s
# Epoch  114 | Step  2280/ 5000 | Train 6.5405e-03 | Test 5.7298e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 3.88e-03 | 6.0s
# Epoch  115 | Step  2300/ 5000 | Train 5.6093e-03 | Test 5.4338e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.85e-03 | 6.1s
# Epoch  116 | Step  2320/ 5000 | Train 7.7676e-03 | Test 3.9060e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.81e-03 | 5.9s
# Epoch  117 | Step  2340/ 5000 | Train 3.0149e-02 | Test 2.1199e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.77e-03 | 6.1s
# Epoch  118 | Step  2360/ 5000 | Train 1.2030e-02 | Test 7.5166e-03 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 3.73e-03 | 6.0s
# Epoch  119 | Step  2380/ 5000 | Train 6.8106e-03 | Test 6.0536e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.69e-03 | 6.1s
# Epoch  120 | Step  2400/ 5000 | Train 5.6695e-03 | Test 5.6104e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.65e-03 | 6.0s
# Epoch  121 | Step  2420/ 5000 | Train 6.9481e-03 | Test 8.8678e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.61e-03 | 6.0s
# Epoch  122 | Step  2440/ 5000 | Train 7.2220e-03 | Test 6.4598e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 3.57e-03 | 5.9s
# Epoch  123 | Step  2460/ 5000 | Train 8.2209e-03 | Test 7.5858e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 3.53e-03 | 6.0s
# Epoch  124 | Step  2480/ 5000 | Train 8.1925e-03 | Test 9.6034e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.49e-03 | 5.9s
# Epoch  125 | Step  2500/ 5000 | Train 7.9389e-03 | Test 8.1562e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 3.45e-03 | 6.1s
# Epoch  126 | Step  2520/ 5000 | Train 7.8767e-03 | Test 8.4579e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.41e-03 | 5.9s
# Epoch  127 | Step  2540/ 5000 | Train 7.7061e-03 | Test 8.4431e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 3.37e-03 | 5.9s
# Epoch  128 | Step  2560/ 5000 | Train 7.6026e-03 | Test 5.8559e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.33e-03 | 6.0s
# Epoch  129 | Step  2580/ 5000 | Train 7.4011e-03 | Test 6.9336e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.29e-03 | 6.1s
# Epoch  130 | Step  2600/ 5000 | Train 7.1158e-03 | Test 6.7846e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.25e-03 | 6.0s
# Epoch  131 | Step  2620/ 5000 | Train 7.0407e-03 | Test 7.2844e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 3.21e-03 | 6.0s
# Epoch  132 | Step  2640/ 5000 | Train 6.5979e-03 | Test 9.0459e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 3.17e-03 | 5.9s
# Epoch  133 | Step  2660/ 5000 | Train 6.6205e-03 | Test 6.2311e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.13e-03 | 6.0s
# Epoch  134 | Step  2680/ 5000 | Train 5.1717e-03 | Test 4.9348e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.09e-03 | 5.9s
# Epoch  135 | Step  2700/ 5000 | Train 4.5712e-03 | Test 4.7296e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.05e-03 | 6.1s
# Epoch  136 | Step  2720/ 5000 | Train 4.4522e-03 | Test 4.5939e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.01e-03 | 6.0s
# Epoch  137 | Step  2740/ 5000 | Train 4.4498e-03 | Test 4.6060e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.97e-03 | 5.9s
# Epoch  138 | Step  2760/ 5000 | Train 4.3950e-03 | Test 4.6743e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 2.93e-03 | 6.0s
# Epoch  139 | Step  2780/ 5000 | Train 4.4077e-03 | Test 4.6899e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.89e-03 | 5.9s
# Epoch  140 | Step  2800/ 5000 | Train 4.3680e-03 | Test 4.5483e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.85e-03 | 6.1s
# Epoch  141 | Step  2820/ 5000 | Train 4.3231e-03 | Test 4.4734e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.81e-03 | 5.9s
# Epoch  142 | Step  2840/ 5000 | Train 4.3222e-03 | Test 4.5260e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.77e-03 | 6.0s
# Epoch  143 | Step  2860/ 5000 | Train 4.3013e-03 | Test 4.5705e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 2.73e-03 | 6.0s
# Epoch  144 | Step  2880/ 5000 | Train 4.3114e-03 | Test 4.5063e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.69e-03 | 5.9s
# Epoch  145 | Step  2900/ 5000 | Train 4.2899e-03 | Test 4.4182e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.65e-03 | 6.1s
# Epoch  146 | Step  2920/ 5000 | Train 4.2455e-03 | Test 4.4095e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 2.61e-03 | 6.0s
# Epoch  147 | Step  2940/ 5000 | Train 4.2753e-03 | Test 4.5756e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.57e-03 | 5.9s
# Epoch  148 | Step  2960/ 5000 | Train 4.2865e-03 | Test 4.6231e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.53e-03 | 6.0s
# Epoch  149 | Step  2980/ 5000 | Train 4.2598e-03 | Test 4.6052e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.49e-03 | 6.0s
# Epoch  150 | Step  3000/ 5000 | Train 4.2496e-03 | Test 4.3722e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.45e-03 | 6.1s
# Epoch  151 | Step  3020/ 5000 | Train 4.1948e-03 | Test 4.4371e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.41e-03 | 5.9s
# Epoch  152 | Step  3040/ 5000 | Train 4.2077e-03 | Test 4.3348e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.37e-03 | 6.0s
# Epoch  153 | Step  3060/ 5000 | Train 4.1915e-03 | Test 4.4586e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.33e-03 | 5.9s
# Epoch  154 | Step  3080/ 5000 | Train 4.1770e-03 | Test 4.4342e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.29e-03 | 5.9s
# Epoch  155 | Step  3100/ 5000 | Train 4.2375e-03 | Test 4.3903e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.25e-03 | 6.1s
# Epoch  156 | Step  3120/ 5000 | Train 4.1501e-03 | Test 4.3289e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.21e-03 | 6.0s
# Epoch  157 | Step  3140/ 5000 | Train 4.1760e-03 | Test 4.3446e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.18e-03 | 6.0s
# Epoch  158 | Step  3160/ 5000 | Train 4.1565e-03 | Test 4.4207e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.14e-03 | 5.9s
# Epoch  159 | Step  3180/ 5000 | Train 4.1887e-03 | Test 4.5321e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.10e-03 | 6.0s
# Epoch  160 | Step  3200/ 5000 | Train 4.2178e-03 | Test 4.6350e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 2.06e-03 | 6.0s
# Epoch  161 | Step  3220/ 5000 | Train 4.1700e-03 | Test 4.3121e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.02e-03 | 6.1s
# Epoch  162 | Step  3240/ 5000 | Train 4.1159e-03 | Test 4.3742e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.99e-03 | 6.0s
# Epoch  163 | Step  3260/ 5000 | Train 4.0985e-03 | Test 4.3301e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.95e-03 | 6.1s
# Epoch  164 | Step  3280/ 5000 | Train 4.0950e-03 | Test 4.2987e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.91e-03 | 5.9s
# Epoch  165 | Step  3300/ 5000 | Train 4.0919e-03 | Test 4.2645e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.87e-03 | 6.2s
# Epoch  166 | Step  3320/ 5000 | Train 4.0683e-03 | Test 4.3022e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.84e-03 | 6.0s
# Epoch  167 | Step  3340/ 5000 | Train 4.0866e-03 | Test 4.2424e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.80e-03 | 6.0s
# Epoch  168 | Step  3360/ 5000 | Train 4.0376e-03 | Test 4.2625e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.76e-03 | 5.9s
# Epoch  169 | Step  3380/ 5000 | Train 4.0610e-03 | Test 4.2723e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.73e-03 | 5.9s
# Epoch  170 | Step  3400/ 5000 | Train 4.0859e-03 | Test 4.4388e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.69e-03 | 6.0s
# Epoch  171 | Step  3420/ 5000 | Train 4.0776e-03 | Test 4.2380e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.66e-03 | 6.0s
# Epoch  172 | Step  3440/ 5000 | Train 4.0367e-03 | Test 4.2740e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.62e-03 | 5.9s
# Epoch  173 | Step  3460/ 5000 | Train 4.0638e-03 | Test 4.2112e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.59e-03 | 5.9s
# Epoch  174 | Step  3480/ 5000 | Train 4.0135e-03 | Test 4.1906e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.55e-03 | 6.0s
# Epoch  175 | Step  3500/ 5000 | Train 4.0114e-03 | Test 4.2469e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.52e-03 | 6.1s
# Epoch  176 | Step  3520/ 5000 | Train 4.0200e-03 | Test 4.1859e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.48e-03 | 6.0s
# Epoch  177 | Step  3540/ 5000 | Train 3.9995e-03 | Test 4.2360e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.45e-03 | 6.0s
# Epoch  178 | Step  3560/ 5000 | Train 4.0110e-03 | Test 4.2138e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.41e-03 | 6.1s
# Epoch  179 | Step  3580/ 5000 | Train 3.9958e-03 | Test 4.2396e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.38e-03 | 6.0s
# Epoch  180 | Step  3600/ 5000 | Train 4.0176e-03 | Test 4.1609e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.35e-03 | 6.1s
# Epoch  181 | Step  3620/ 5000 | Train 3.9814e-03 | Test 4.1607e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.31e-03 | 5.9s
# Epoch  182 | Step  3640/ 5000 | Train 3.9819e-03 | Test 4.2195e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.28e-03 | 6.0s
# Epoch  183 | Step  3660/ 5000 | Train 4.0017e-03 | Test 4.1686e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.25e-03 | 5.9s
# Epoch  184 | Step  3680/ 5000 | Train 3.9633e-03 | Test 4.1421e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.22e-03 | 5.9s
# Epoch  185 | Step  3700/ 5000 | Train 3.9643e-03 | Test 4.1742e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.19e-03 | 6.0s
# Epoch  186 | Step  3720/ 5000 | Train 3.9669e-03 | Test 4.1576e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.16e-03 | 5.9s
# Epoch  187 | Step  3740/ 5000 | Train 3.9807e-03 | Test 4.1390e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.13e-03 | 5.9s
# Epoch  188 | Step  3760/ 5000 | Train 3.9700e-03 | Test 4.1251e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.10e-03 | 6.0s
# Epoch  189 | Step  3780/ 5000 | Train 3.9583e-03 | Test 4.1591e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.07e-03 | 5.9s
# Epoch  190 | Step  3800/ 5000 | Train 3.9530e-03 | Test 4.1596e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.04e-03 | 6.0s
# Epoch  191 | Step  3820/ 5000 | Train 3.9546e-03 | Test 4.1449e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.01e-03 | 6.0s
# Epoch  192 | Step  3840/ 5000 | Train 3.9424e-03 | Test 4.0992e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 9.77e-04 | 6.0s
# Epoch  193 | Step  3860/ 5000 | Train 3.9285e-03 | Test 4.1314e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 9.49e-04 | 5.9s
# Epoch  194 | Step  3880/ 5000 | Train 3.9318e-03 | Test 4.1085e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 9.21e-04 | 6.0s
# Epoch  195 | Step  3900/ 5000 | Train 3.9291e-03 | Test 4.0974e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 8.93e-04 | 6.1s
# Epoch  196 | Step  3920/ 5000 | Train 3.9306e-03 | Test 4.1361e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 8.66e-04 | 5.9s
# Epoch  197 | Step  3940/ 5000 | Train 3.9398e-03 | Test 4.1112e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 8.39e-04 | 5.9s
# Epoch  198 | Step  3960/ 5000 | Train 3.9220e-03 | Test 4.0973e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 8.12e-04 | 5.9s
# Epoch  199 | Step  3980/ 5000 | Train 3.9210e-03 | Test 4.0969e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 7.86e-04 | 5.9s
# Epoch  200 | Step  4000/ 5000 | Train 3.9340e-03 | Test 4.0881e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 7.61e-04 | 6.1s
# Epoch  201 | Step  4020/ 5000 | Train 3.9256e-03 | Test 4.1157e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 7.35e-04 | 6.0s
# Epoch  202 | Step  4040/ 5000 | Train 3.9087e-03 | Test 4.0894e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 7.11e-04 | 6.0s
# Epoch  203 | Step  4060/ 5000 | Train 3.9123e-03 | Test 4.0957e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 6.86e-04 | 6.0s
# Epoch  204 | Step  4080/ 5000 | Train 3.9146e-03 | Test 4.1050e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 6.62e-04 | 6.0s
# Epoch  205 | Step  4100/ 5000 | Train 3.9174e-03 | Test 4.1023e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 6.39e-04 | 6.1s
# Epoch  206 | Step  4120/ 5000 | Train 3.9060e-03 | Test 4.0753e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 6.16e-04 | 5.9s
# Epoch  207 | Step  4140/ 5000 | Train 3.9030e-03 | Test 4.0858e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 5.93e-04 | 5.9s
# Epoch  208 | Step  4160/ 5000 | Train 3.8979e-03 | Test 4.0832e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 5.71e-04 | 5.9s
# Epoch  209 | Step  4180/ 5000 | Train 3.8947e-03 | Test 4.0707e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 5.50e-04 | 6.0s
# Epoch  210 | Step  4200/ 5000 | Train 3.8894e-03 | Test 4.0762e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 5.29e-04 | 6.0s
# Epoch  211 | Step  4220/ 5000 | Train 3.9005e-03 | Test 4.0584e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 5.08e-04 | 6.0s
# Epoch  212 | Step  4240/ 5000 | Train 3.8907e-03 | Test 4.0545e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.88e-04 | 5.9s
# Epoch  213 | Step  4260/ 5000 | Train 3.8865e-03 | Test 4.0788e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.68e-04 | 5.9s
# Epoch  214 | Step  4280/ 5000 | Train 3.8885e-03 | Test 4.0570e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.49e-04 | 5.9s
# Epoch  215 | Step  4300/ 5000 | Train 3.8775e-03 | Test 4.0805e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.30e-04 | 6.1s
# Epoch  216 | Step  4320/ 5000 | Train 3.8833e-03 | Test 4.0435e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.12e-04 | 6.0s
# Epoch  217 | Step  4340/ 5000 | Train 3.8762e-03 | Test 4.0555e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 3.94e-04 | 6.0s
# Epoch  218 | Step  4360/ 5000 | Train 3.8760e-03 | Test 4.0499e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.77e-04 | 5.9s
# Epoch  219 | Step  4380/ 5000 | Train 3.8734e-03 | Test 4.1043e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.60e-04 | 5.8s
# Epoch  220 | Step  4400/ 5000 | Train 3.8867e-03 | Test 4.0668e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.44e-04 | 6.0s
# Epoch  221 | Step  4420/ 5000 | Train 3.8728e-03 | Test 4.0749e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.28e-04 | 5.9s
# Epoch  222 | Step  4440/ 5000 | Train 3.8772e-03 | Test 4.0446e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.12e-04 | 5.9s
# Epoch  223 | Step  4460/ 5000 | Train 3.8728e-03 | Test 4.0528e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.98e-04 | 5.9s
# Epoch  224 | Step  4480/ 5000 | Train 3.8712e-03 | Test 4.0509e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.83e-04 | 5.9s
# Epoch  225 | Step  4500/ 5000 | Train 3.8596e-03 | Test 4.0463e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.70e-04 | 5.9s
# Epoch  226 | Step  4520/ 5000 | Train 3.8641e-03 | Test 4.0376e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.57e-04 | 5.9s
# Epoch  227 | Step  4540/ 5000 | Train 3.8676e-03 | Test 4.0466e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.44e-04 | 5.9s
# Epoch  228 | Step  4560/ 5000 | Train 3.8716e-03 | Test 4.0406e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.32e-04 | 5.9s
# Epoch  229 | Step  4580/ 5000 | Train 3.8640e-03 | Test 4.0403e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.20e-04 | 6.0s
# Epoch  230 | Step  4600/ 5000 | Train 3.8614e-03 | Test 4.0381e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.09e-04 | 6.1s
# Epoch  231 | Step  4620/ 5000 | Train 3.8637e-03 | Test 4.0383e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.98e-04 | 6.0s
# Epoch  232 | Step  4640/ 5000 | Train 3.8638e-03 | Test 4.0347e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.88e-04 | 6.0s
# Epoch  233 | Step  4660/ 5000 | Train 3.8634e-03 | Test 4.0356e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.79e-04 | 5.9s
# Epoch  234 | Step  4680/ 5000 | Train 3.8553e-03 | Test 4.0315e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.70e-04 | 6.0s
# Epoch  235 | Step  4700/ 5000 | Train 3.8636e-03 | Test 4.0291e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.61e-04 | 6.1s
# Epoch  236 | Step  4720/ 5000 | Train 3.8586e-03 | Test 4.0322e-03 | SO3(train/test) 1.17e-07/1.18e-07 | Fail(train/test) 0/0 | LR 1.53e-04 | 6.0s
# Epoch  237 | Step  4740/ 5000 | Train 3.8603e-03 | Test 4.0274e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.46e-04 | 6.1s
# Epoch  238 | Step  4760/ 5000 | Train 3.8580e-03 | Test 4.0275e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.39e-04 | 6.1s
# Epoch  239 | Step  4780/ 5000 | Train 3.8591e-03 | Test 4.0284e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.33e-04 | 6.0s
# Epoch  240 | Step  4800/ 5000 | Train 3.8576e-03 | Test 4.0294e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.27e-04 | 6.1s
# Epoch  241 | Step  4820/ 5000 | Train 3.8543e-03 | Test 4.0282e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.22e-04 | 6.0s
# Epoch  242 | Step  4840/ 5000 | Train 3.8496e-03 | Test 4.0327e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.17e-04 | 6.0s
# Epoch  243 | Step  4860/ 5000 | Train 3.8539e-03 | Test 4.0294e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.13e-04 | 6.1s
# Epoch  244 | Step  4880/ 5000 | Train 3.8562e-03 | Test 4.0228e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.10e-04 | 6.0s
# Epoch  245 | Step  4900/ 5000 | Train 3.8529e-03 | Test 4.0222e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.07e-04 | 6.2s
# Epoch  246 | Step  4920/ 5000 | Train 3.8527e-03 | Test 4.0268e-03 | SO3(train/test) 1.17e-07/1.18e-07 | Fail(train/test) 0/0 | LR 1.04e-04 | 6.0s
# Epoch  247 | Step  4940/ 5000 | Train 3.8527e-03 | Test 4.0249e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.02e-04 | 6.0s
# Epoch  248 | Step  4960/ 5000 | Train 3.8593e-03 | Test 4.0233e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.01e-04 | 6.0s
# Epoch  249 | Step  4980/ 5000 | Train 3.8458e-03 | Test 4.0214e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.00e-04 | 6.1s
# Epoch  250 | Step  5000/ 5000 | Train 3.8531e-03 | Test 4.0249e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.00e-04 | 6.1s
# Reached target optimizer steps: 5000/5000
# Done. Best validation score: failure_rate=0.0000, test_loss=4.0214e-03 (epoch 249)
# Running detailed evaluation...
# Block evaluation profile: clean
# Block evaluation noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0001 +/- 0.0001  (max 0.0005)
# Rotation geo [rad]:  0.0005 +/- 0.0000  (max 0.0006)
# Lin vel RMSE [m/s]:  0.0015 +/- 0.0011
# Ang vel RMSE [r/s]:  0.0006 +/- 0.0004
# Components:  u=0.0024  v=0.0003  w=0.0003  p=0.0005  q=0.0006  r=0.0005
# SO(3) violation:  |det-1|=6.51e-08  ||RR^T-I||=1.28e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# Block evaluation profile: nominal_eval
# Block evaluation noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0013 +/- 0.0008  (max 0.0055)
# Rotation geo [rad]:  0.0082 +/- 0.0058  (max 0.0367)
# Lin vel RMSE [m/s]:  0.0045 +/- 0.0021
# Ang vel RMSE [r/s]:  0.0032 +/- 0.0020
# Components:  u=0.0056  v=0.0030  w=0.0030  p=0.0051  q=0.0009  r=0.0012
# SO(3) violation:  |det-1|=2.80e-07  ||RR^T-I||=6.12e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# Block evaluation profile: heading_biased_eval
# Block evaluation noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0049 +/- 0.0017  (max 0.0109)
# Rotation geo [rad]:  0.0351 +/- 0.0096  (max 0.0656)
# Lin vel RMSE [m/s]:  0.0080 +/- 0.0038
# Ang vel RMSE [r/s]:  0.0032 +/- 0.0020
# Components:  u=0.0078  v=0.0089  w=0.0033  p=0.0051  q=0.0009  r=0.0012
# SO(3) violation:  |det-1|=2.98e-07  ||RR^T-I||=6.36e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Block Evaluation Relative To Clean
# ==================================================
# [nominal_eval]
# position_rmse: ratio=10.241  degradation=+924.1%
# rotation_geodesic: ratio=16.735  degradation=+1573.5%
# velocity_rmse: ratio=3.111  degradation=+211.1%
# angular_rmse: ratio=5.364  degradation=+436.4%
# failure_rate: ratio=1.000  degradation=+0.0%
# [heading_biased_eval]
# position_rmse: ratio=39.121  degradation=+3812.1%
# rotation_geodesic: ratio=71.782  degradation=+7078.2%
# velocity_rmse: ratio=5.484  degradation=+448.4%
# angular_rmse: ratio=5.358  degradation=+435.8%
# failure_rate: ratio=1.000  degradation=+0.0%
# Running held-out trajectory evaluation...
# Held-out evaluation profile: clean
# Held-out evaluation noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0001 (median 0.0001, p95 0.0002)
# Rotation geo [rad]:  0.0005 (median 0.0005, p95 0.0005)
# Lin vel RMSE [m/s]:  0.0012  Ang vel RMSE [r/s]:  0.0005
# SO(3) violation:  |det-1|=6.04e-08  ||RR^T-I||=1.17e-07
# Noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# [CHIRP] pos=0.0000 m, rot=0.0005 rad, success=1.0000
# [OU] pos=0.0001 m, rot=0.0005 rad, success=1.0000
# [PRBS] pos=0.0001 m, rot=0.0005 rad, success=1.0000
# Held-out evaluation profile: nominal_eval
# Held-out evaluation noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0011 (median 0.0011, p95 0.0014)
# Rotation geo [rad]:  0.0086 (median 0.0085, p95 0.0095)
# Lin vel RMSE [m/s]:  0.0043  Ang vel RMSE [r/s]:  0.0031
# SO(3) violation:  |det-1|=2.94e-07  ||RR^T-I||=6.27e-07
# Noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# [CHIRP] pos=0.0011 m, rot=0.0085 rad, success=1.0000
# [OU] pos=0.0011 m, rot=0.0086 rad, success=1.0000
# [PRBS] pos=0.0011 m, rot=0.0085 rad, success=1.0000
# Held-out evaluation profile: degraded_eval
# Held-out evaluation noise budget: protocol=iid_noisy_ic | profile=degraded_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0026 (median 0.0025, p95 0.0033)
# Rotation geo [rad]:  0.0209 (median 0.0208, p95 0.0233)
# Lin vel RMSE [m/s]:  0.0085  Ang vel RMSE [r/s]:  0.0061
# SO(3) violation:  |det-1|=2.95e-07  ||RR^T-I||=6.29e-07
# Noise budget: protocol=iid_noisy_ic | profile=degraded_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250]
# [CHIRP] pos=0.0025 m, rot=0.0209 rad, success=1.0000
# [OU] pos=0.0025 m, rot=0.0211 rad, success=1.0000
# [PRBS] pos=0.0027 m, rot=0.0208 rad, success=1.0000
# Held-out evaluation profile: heading_biased_eval
# Held-out evaluation noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0040 (median 0.0040, p95 0.0052)
# ...
# Epoch  234 | Step  4680/ 5000 | Train 2.1019e-02 | Test 6.3731e-03 | SO3(train/test) 3.68e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.70e-04 | 6.3s
# Epoch  235 | Step  4700/ 5000 | Train 2.1394e-02 | Test 6.4909e-03 | SO3(train/test) 3.71e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.61e-04 | 6.2s
# Epoch  236 | Step  4720/ 5000 | Train 2.1358e-02 | Test 6.3260e-03 | SO3(train/test) 3.69e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.53e-04 | 6.1s
# Epoch  237 | Step  4740/ 5000 | Train 2.1171e-02 | Test 6.4510e-03 | SO3(train/test) 3.68e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.46e-04 | 6.2s
# Epoch  238 | Step  4760/ 5000 | Train 2.1205e-02 | Test 6.3720e-03 | SO3(train/test) 3.68e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.39e-04 | 6.2s
# Epoch  239 | Step  4780/ 5000 | Train 2.1121e-02 | Test 6.4260e-03 | SO3(train/test) 3.66e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.33e-04 | 6.2s
# Epoch  240 | Step  4800/ 5000 | Train 2.1395e-02 | Test 6.3795e-03 | SO3(train/test) 3.71e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.27e-04 | 6.2s
# Epoch  241 | Step  4820/ 5000 | Train 2.1133e-02 | Test 6.4156e-03 | SO3(train/test) 3.69e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.22e-04 | 6.2s
# Epoch  242 | Step  4840/ 5000 | Train 2.1237e-02 | Test 6.3325e-03 | SO3(train/test) 3.70e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.17e-04 | 6.1s
# Epoch  243 | Step  4860/ 5000 | Train 2.1390e-02 | Test 6.4801e-03 | SO3(train/test) 3.67e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.13e-04 | 6.3s
# Epoch  244 | Step  4880/ 5000 | Train 2.1276e-02 | Test 6.4183e-03 | SO3(train/test) 3.69e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.10e-04 | 6.1s
# Epoch  245 | Step  4900/ 5000 | Train 2.1107e-02 | Test 6.3921e-03 | SO3(train/test) 3.68e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.07e-04 | 6.1s
# Epoch  246 | Step  4920/ 5000 | Train 2.1279e-02 | Test 6.4482e-03 | SO3(train/test) 3.65e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.04e-04 | 6.1s
# Epoch  247 | Step  4940/ 5000 | Train 2.1175e-02 | Test 6.4258e-03 | SO3(train/test) 3.69e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.02e-04 | 6.1s
# Epoch  248 | Step  4960/ 5000 | Train 2.1208e-02 | Test 6.3501e-03 | SO3(train/test) 3.68e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.01e-04 | 6.2s
# Epoch  249 | Step  4980/ 5000 | Train 2.1043e-02 | Test 6.4399e-03 | SO3(train/test) 3.67e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.00e-04 | 6.2s
# Epoch  250 | Step  5000/ 5000 | Train 2.1056e-02 | Test 6.4439e-03 | SO3(train/test) 3.68e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.00e-04 | 6.2s
# Reached target optimizer steps: 5000/5000
# Done. Best validation score: failure_rate=0.0000, test_loss=6.2970e-03 (epoch 204)
# Running detailed evaluation...
# Block evaluation profile: clean
# Block evaluation noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0001 +/- 0.0001  (max 0.0008)
# Rotation geo [rad]:  0.0005 +/- 0.0000  (max 0.0007)
# Lin vel RMSE [m/s]:  0.0017 +/- 0.0013
# Ang vel RMSE [r/s]:  0.0011 +/- 0.0006
# Components:  u=0.0027  v=0.0004  w=0.0004  p=0.0012  q=0.0010  r=0.0006
# SO(3) violation:  |det-1|=6.36e-08  ||RR^T-I||=1.29e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# Block evaluation profile: nominal_eval
# Block evaluation noise budget: protocol=v4_lite | profile=nominal_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0012 +/- 0.0008  (max 0.0045)
# Rotation geo [rad]:  0.0076 +/- 0.0053  (max 0.0304)
# Lin vel RMSE [m/s]:  0.0045 +/- 0.0021
# Ang vel RMSE [r/s]:  0.0031 +/- 0.0017
# Components:  u=0.0056  v=0.0029  w=0.0030  p=0.0047  q=0.0012  r=0.0012
# SO(3) violation:  |det-1|=2.98e-07  ||RR^T-I||=6.47e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=v4_lite | profile=nominal_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# Block evaluation profile: heading_biased_eval
# Block evaluation noise budget: protocol=v4_lite | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0050 +/- 0.0016  (max 0.0094)
# Rotation geo [rad]:  0.0360 +/- 0.0089  (max 0.0634)
# Lin vel RMSE [m/s]:  0.0080 +/- 0.0039
# Ang vel RMSE [r/s]:  0.0030 +/- 0.0017
# Components:  u=0.0080  v=0.0087  w=0.0033  p=0.0047  q=0.0012  r=0.0012
# SO(3) violation:  |det-1|=2.88e-07  ||RR^T-I||=6.09e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=v4_lite | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Block Evaluation Relative To Clean
# ==================================================
# [nominal_eval]
# position_rmse: ratio=8.337  degradation=+733.7%
# rotation_geodesic: ratio=15.518  degradation=+1451.8%
# velocity_rmse: ratio=2.702  degradation=+170.2%
# angular_rmse: ratio=2.870  degradation=+187.0%
# failure_rate: ratio=1.000  degradation=+0.0%
# [heading_biased_eval]
# position_rmse: ratio=35.162  degradation=+3416.2%
# rotation_geodesic: ratio=73.303  degradation=+7230.3%
# velocity_rmse: ratio=4.834  degradation=+383.4%
# angular_rmse: ratio=2.864  degradation=+186.4%
# failure_rate: ratio=1.000  degradation=+0.0%
# Running held-out trajectory evaluation...
# Held-out evaluation profile: clean
# Held-out evaluation noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0001 (median 0.0001, p95 0.0002)
# Rotation geo [rad]:  0.0005 (median 0.0005, p95 0.0005)
# Lin vel RMSE [m/s]:  0.0014  Ang vel RMSE [r/s]:  0.0009
# SO(3) violation:  |det-1|=6.04e-08  ||RR^T-I||=1.17e-07
# Noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# [CHIRP] pos=0.0000 m, rot=0.0005 rad, success=1.0000
# [OU] pos=0.0002 m, rot=0.0005 rad, success=1.0000
# [PRBS] pos=0.0001 m, rot=0.0005 rad, success=1.0000
# Held-out evaluation profile: nominal_eval
# Held-out evaluation noise budget: protocol=v4_lite | profile=nominal_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0011 (median 0.0011, p95 0.0015)
# Rotation geo [rad]:  0.0087 (median 0.0086, p95 0.0105)
# Lin vel RMSE [m/s]:  0.0044  Ang vel RMSE [r/s]:  0.0028
# SO(3) violation:  |det-1|=2.91e-07  ||RR^T-I||=6.19e-07
# Noise budget: protocol=v4_lite | profile=nominal_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# [CHIRP] pos=0.0010 m, rot=0.0086 rad, success=1.0000
# [OU] pos=0.0011 m, rot=0.0086 rad, success=1.0000
# [PRBS] pos=0.0012 m, rot=0.0088 rad, success=1.0000
# Held-out evaluation profile: degraded_eval
# Held-out evaluation noise budget: protocol=v4_lite | profile=degraded_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0026 (median 0.0026, p95 0.0035)
# Rotation geo [rad]:  0.0212 (median 0.0211, p95 0.0258)
# Lin vel RMSE [m/s]:  0.0085  Ang vel RMSE [r/s]:  0.0053
# SO(3) violation:  |det-1|=2.93e-07  ||RR^T-I||=6.25e-07
# Noise budget: protocol=v4_lite | profile=degraded_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250]
# [CHIRP] pos=0.0025 m, rot=0.0209 rad, success=1.0000
# [OU] pos=0.0025 m, rot=0.0210 rad, success=1.0000
# [PRBS] pos=0.0027 m, rot=0.0214 rad, success=1.0000
# Held-out evaluation profile: heading_biased_eval
# Held-out evaluation noise budget: protocol=v4_lite | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0041 (median 0.0039, p95 0.0053)
# Rotation geo [rad]:  0.0356 (median 0.0356, p95 0.0406)
# Lin vel RMSE [m/s]:  0.0070  Ang vel RMSE [r/s]:  0.0028
# SO(3) violation:  |det-1|=2.95e-07  ||RR^T-I||=6.27e-07
# Noise budget: protocol=v4_lite | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# [CHIRP] pos=0.0039 m, rot=0.0354 rad, success=1.0000
# [OU] pos=0.0039 m, rot=0.0357 rad, success=1.0000
# [PRBS] pos=0.0042 m, rot=0.0357 rad, success=1.0000
# ==================================================
# Held-Out Evaluation Relative To Clean
# ==================================================
# [nominal_eval]
# position_rmse: ratio=9.173  degradation=+817.3%
# rotation_geodesic: ratio=17.640  degradation=+1664.0%
# velocity_rmse: ratio=3.099  degradation=+209.9%
# angular_rmse: ratio=3.067  degradation=+206.7%
# success_rate: ratio=1.000  degradation=+0.0%
# trajectory_failure_rate: ratio=1.000  degradation=+0.0%
# [degraded_eval]
# position_rmse: ratio=21.552  degradation=+2055.2%
# rotation_geodesic: ratio=43.141  degradation=+4214.1%
# velocity_rmse: ratio=6.048  degradation=+504.8%
# angular_rmse: ratio=5.808  degradation=+480.8%
# success_rate: ratio=1.000  degradation=+0.0%
# trajectory_failure_rate: ratio=1.000  degradation=+0.0%
# [heading_biased_eval]
# position_rmse: ratio=33.543  degradation=+3254.3%
# rotation_geodesic: ratio=72.585  degradation=+7158.5%
# velocity_rmse: ratio=4.961  degradation=+396.1%
# angular_rmse: ratio=3.067  degradation=+206.7%
# success_rate: ratio=1.000  degradation=+0.0%
# trajectory_failure_rate: ratio=1.000  degradation=+0.0%
#
# Training finished. Results: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_phnode_full/main_phnode_full_seed42
# Training sweep complete.
# Manifest: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_phnode_full/runs.tsv
# Next step:
#   scripts/batch_eval_models.sh --suite-dir "/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_phnode_full"
#
# Training complete.
# Suite directory: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_phnode_full
# Next step:
#   bash scripts/eval_all_models_noise_profile.sh --suite-dir "/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_phnode_full"
# [audit] /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_full
# [audit] /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_phnode_full
# [audit] /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_phnode_full
#                                           suite_name group  model_type  seed train_noise_protocol  best_epoch  best_loss  noise_warmup_epochs  noise_ramp_epochs  noise_mix_ratio  epoch_scale_at_best  is_effectively_clean_at_best
#  sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_full  main phnode_full    42                clean         249   0.004021                   20                 80              0.5                  0.0                          True
#    sweep_oc_phase1a_smoke1_iid_t2_wpfrag_phnode_full  main phnode_full    42         iid_noisy_ic         245   0.006216                   20                 80              0.5                  1.0                         False
# sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_phnode_full  main phnode_full    42              v4_lite         204   0.006297                   20                 80              0.5                  1.0                         False
# + /usr/bin/python3 /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/scripts/validate_v4_lite_protocol.py --run-dir /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_phnode_full/main_phnode_full_seed42
# v4_lite protocol validation saved to: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_phnode_full/main_phnode_full_seed42/v4_lite_protocol_validation.json
# overall_passed=True
# same_epoch_stability: passed=True
# epoch_resampling: passed=True
# heading_bias_overlay: passed=True
# [validate] /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_phnode_full/main_phnode_full_seed42/v4_lite_protocol_validation.json

# %%
os.environ["MODE"] = "smoke1_eval"
# !bash scripts/run_phase1a_oc_v4lite.sh
# Out:
# [phase1a]
# MODE=smoke1_eval
# RUN_TAG=t2_wpfrag_phnode_full
# DATASET=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# DEVICE=cuda
# PHASE1A_MODELS=phnode_full
# SMOKE1_MODELS=phnode_full
# SMOKE_SEEDS=42
# DECISION_SEEDS=42 43 44 45 46
# NOISE_REFERENCE=remus100_dr
# PHASE1A_LOG_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_logs/t2_wpfrag_phnode_full
# PHASE1A_METADATA_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_metadata_t2_wpfrag_phnode_full
# [eval] suite=sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_full eval_protocol=iid_noisy_ic profiles=clean nominal_eval degraded_eval heading_biased_eval
# Suite directory: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_full
# Manifest: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_full/runs.tsv
# Mode: resampled
# [eval] main_phnode_full_seed42
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_full/main_phnode_full_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=clean | noise_protocol=clean | noise_budget=protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000] | scenarios=PRBS,CHIRP,OU | trajectories=18 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_full/main_phnode_full_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260523_160405/clean
# [scenario 1/3] PRBS | 6 trajectories
# [1/18] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=16m40.7s
# [5/18] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=2m33.1s
# [6/18] PRBS seed=47 done | reason=completed | sim_time=60.00s | eta=1m57.8s
# [scenario done] PRBS | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=0.5238 m | pos_p95=1.6701 m | rot_med=0.0134 rad | completion=1.000 | elapsed=58.9s
# [scenario 2/3] CHIRP | 6 trajectories
# [7/18] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=3m05.1s
# [11/18] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=1m15.0s
# [12/18] CHIRP seed=100047 done | reason=completed | sim_time=60.00s | eta=58.9s
# [scenario done] CHIRP | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=0.8136 m | pos_p95=1.2820 m | rot_med=0.0165 rad | completion=1.000 | elapsed=1m57.8s
# [scenario 3/3] OU | 6 trajectories
# [13/18] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=1m07.8s
# [17/18] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=10.4s
# [18/18] OU seed=200047 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=0.5628 m | pos_p95=0.6721 m | rot_med=0.0189 rad | completion=1.000 | elapsed=2m56.3s
# Benchmark finished in 3m09.6s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_full/main_phnode_full_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260523_160405/clean
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_full/main_phnode_full_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: pH NODE Full [main/core]
# Canonical model type: phnode_full
# Energy semantics: mechanical_energy
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 6
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.0729 m | pos p95=0.1630 m | rot median=0.0059 rad | total vel median=0.0084 m/s | rel vel median=0.0082 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=0.2309 m | pos p95=0.5462 m | rot median=0.0081 rad | total vel median=0.0128 m/s | rel vel median=0.0131 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=0.6208 m | pos p95=1.4648 m | rot median=0.0162 rad | total vel median=0.0122 m/s | rel vel median=0.0125 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=18 | completed=18 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.0855 m | pos p95=0.1921 m | rot median=0.0058 rad | total vel median=0.0106 m/s | rel vel median=0.0117 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.2614 m | pos p95=0.5563 m | rot median=0.0073 rad | total vel median=0.0226 m/s | rel vel median=0.0225 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=0.5238 m | pos p95=1.6701 m | rot median=0.0134 rad | total vel median=0.0196 m/s | rel vel median=0.0217 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.0599 m | pos p95=0.0736 m | rot median=0.0062 rad | total vel median=0.0046 m/s | rel vel median=0.0045 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.1304 m | pos p95=0.4148 m | rot median=0.0083 rad | total vel median=0.0031 m/s | rel vel median=0.0035 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=0.8136 m | pos p95=1.2820 m | rot median=0.0165 rad | total vel median=0.0058 m/s | rel vel median=0.0110 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1159 m | pos p95=0.1496 m | rot median=0.0088 rad | total vel median=0.0137 m/s | rel vel median=0.0129 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.2839 m | pos p95=0.5181 m | rot median=0.0082 rad | total vel median=0.0161 m/s | rel vel median=0.0173 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=0.5628 m | pos p95=0.6721 m | rot median=0.0189 rad | total vel median=0.0218 m/s | rel vel median=0.0190 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Largest completed terminal errors
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=1.8331 m | rot=0.0165 rad | total_vel_violation=0
#   CHIRP seed=100044 | reason=completed | sim_time=60.00s | pos=1.3998 m | rot=0.0258 rad | total_vel_violation=0
#   PRBS seed=46 | reason=completed | sim_time=60.00s | pos=1.1811 m | rot=0.0173 rad | total_vel_violation=0
#   CHIRP seed=100045 | reason=completed | sim_time=60.00s | pos=0.9285 m | rot=0.0152 rad | total_vel_violation=0
#   CHIRP seed=100047 | reason=completed | sim_time=60.00s | pos=0.8849 m | rot=0.0221 rad | total_vel_violation=0
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# PRBS seed=42 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_full/main_phnode_full_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260523_160405/clean/diagnostic_plots/high_terminal_error_PRBS_seed42.png
# CHIRP seed=100044 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_full/main_phnode_full_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260523_160405/clean/diagnostic_plots/high_terminal_error_CHIRP_seed100044.png
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_full/main_phnode_full_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=nominal_eval | noise_protocol=iid_noisy_ic | noise_budget=protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | scenarios=PRBS,CHIRP,OU | trajectories=18 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_full/main_phnode_full_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260523_160405/nominal_eval
# [scenario 1/3] PRBS | 6 trajectories
# [1/18] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=5m21.9s
# [5/18] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=49.3s
# [6/18] PRBS seed=47 done | reason=completed | sim_time=60.00s | eta=37.9s
# [scenario done] PRBS | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=0.6290 m | pos_p95=3.9468 m | rot_med=0.0138 rad | completion=1.000 | elapsed=19.0s
# [scenario 2/3] CHIRP | 6 trajectories
# [7/18] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=59.2s
# [11/18] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=24.0s
# [12/18] CHIRP seed=100047 done | reason=completed | sim_time=60.00s | eta=18.9s
# [scenario done] CHIRP | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=0.7370 m | pos_p95=1.3727 m | rot_med=0.0169 rad | completion=1.000 | elapsed=37.7s
# [scenario 3/3] OU | 6 trajectories
# [13/18] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=21.8s
# [17/18] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=3.3s
# [18/18] OU seed=200047 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=0.7716 m | pos_p95=1.1453 m | rot_med=0.0217 rad | completion=1.000 | elapsed=56.7s
# Benchmark finished in 1m09.3s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_full/main_phnode_full_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260523_160405/nominal_eval
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_full/main_phnode_full_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: pH NODE Full [main/core]
# Canonical model type: phnode_full
# Energy semantics: mechanical_energy
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 6
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.1121 m | pos p95=0.3333 m | rot median=0.0084 rad | total vel median=0.0092 m/s | rel vel median=0.0082 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=0.3495 m | pos p95=1.0263 m | rot median=0.0082 rad | total vel median=0.0126 m/s | rel vel median=0.0132 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=0.7288 m | pos p95=2.8438 m | rot median=0.0169 rad | total vel median=0.0111 m/s | rel vel median=0.0125 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=18 | completed=18 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.2078 m | pos p95=0.4940 m | rot median=0.0086 rad | total vel median=0.0126 m/s | rel vel median=0.0116 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.4633 m | pos p95=1.6671 m | rot median=0.0066 rad | total vel median=0.0227 m/s | rel vel median=0.0225 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=0.6290 m | pos p95=3.9468 m | rot median=0.0138 rad | total vel median=0.0167 m/s | rel vel median=0.0217 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.0705 m | pos p95=0.1172 m | rot median=0.0074 rad | total vel median=0.0045 m/s | rel vel median=0.0044 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.1983 m | pos p95=0.4100 m | rot median=0.0084 rad | total vel median=0.0041 m/s | rel vel median=0.0035 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=0.7370 m | pos p95=1.3727 m | rot median=0.0169 rad | total vel median=0.0063 m/s | rel vel median=0.0110 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1404 m | pos p95=0.2110 m | rot median=0.0142 rad | total vel median=0.0146 m/s | rel vel median=0.0129 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.4335 m | pos p95=0.5413 m | rot median=0.0081 rad | total vel median=0.0168 m/s | rel vel median=0.0172 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=0.7716 m | pos p95=1.1453 m | rot median=0.0217 rad | total vel median=0.0221 m/s | rel vel median=0.0189 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Largest completed terminal errors
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=4.4063 m | rot=0.0360 rad | total_vel_violation=0
#   PRBS seed=46 | reason=completed | sim_time=60.00s | pos=2.5681 m | rot=0.0300 rad | total_vel_violation=0
#   CHIRP seed=100045 | reason=completed | sim_time=60.00s | pos=1.4001 m | rot=0.0205 rad | total_vel_violation=0
#   CHIRP seed=100044 | reason=completed | sim_time=60.00s | pos=1.2903 m | rot=0.0246 rad | total_vel_violation=0
#   OU seed=200042 | reason=completed | sim_time=60.00s | pos=1.1843 m | rot=0.0216 rad | total_vel_violation=0
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# PRBS seed=42 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_full/main_phnode_full_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260523_160405/nominal_eval/diagnostic_plots/high_terminal_error_PRBS_seed42.png
# PRBS seed=46 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_full/main_phnode_full_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260523_160405/nominal_eval/diagnostic_plots/high_terminal_error_PRBS_seed46.png
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_full/main_phnode_full_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=degraded_eval | noise_protocol=iid_noisy_ic | noise_budget=protocol=iid_noisy_ic | profile=degraded_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250] | scenarios=PRBS,CHIRP,OU | trajectories=18 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_full/main_phnode_full_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260523_160405/degraded_eval
# [scenario 1/3] PRBS | 6 trajectories
# [1/18] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=5m17.9s
# [5/18] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=48.7s
# [6/18] PRBS seed=47 done | reason=completed | sim_time=60.00s | eta=37.4s
# [scenario done] PRBS | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=2.0212 m | pos_p95=7.3942 m | rot_med=0.0304 rad | completion=1.000 | elapsed=18.7s
# [scenario 2/3] CHIRP | 6 trajectories
# [7/18] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=59.0s
# [11/18] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=23.9s
# [12/18] CHIRP seed=100047 done | reason=completed | sim_time=60.00s | eta=18.8s
# [scenario done] CHIRP | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=1.0178 m | pos_p95=1.8509 m | rot_med=0.0207 rad | completion=1.000 | elapsed=37.6s
# [scenario 3/3] OU | 6 trajectories
# [13/18] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=21.8s
# [17/18] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=3.3s
# [18/18] OU seed=200047 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=1.2171 m | pos_p95=2.2278 m | rot_med=0.0271 rad | completion=1.000 | elapsed=56.7s
# Benchmark finished in 1m09.3s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_full/main_phnode_full_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260523_160405/degraded_eval
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_full/main_phnode_full_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: pH NODE Full [main/core]
# Canonical model type: phnode_full
# Energy semantics: mechanical_energy
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 6
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.2291 m | pos p95=0.7030 m | rot median=0.0161 rad | total vel median=0.0123 m/s | rel vel median=0.0082 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=0.5994 m | pos p95=2.0824 m | rot median=0.0137 rad | total vel median=0.0122 m/s | rel vel median=0.0133 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=1.2634 m | pos p95=5.1570 m | rot median=0.0231 rad | total vel median=0.0104 m/s | rel vel median=0.0126 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=18 | completed=18 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.4103 m | pos p95=1.0867 m | rot median=0.0252 rad | total vel median=0.0167 m/s | rel vel median=0.0114 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.3794 m | pos p95=3.4122 m | rot median=0.0236 rad | total vel median=0.0189 m/s | rel vel median=0.0225 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=2.0212 m | pos p95=7.3942 m | rot median=0.0304 rad | total vel median=0.0137 m/s | rel vel median=0.0216 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1221 m | pos p95=0.2810 m | rot median=0.0103 rad | total vel median=0.0055 m/s | rel vel median=0.0044 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.4732 m | pos p95=0.6955 m | rot median=0.0119 rad | total vel median=0.0045 m/s | rel vel median=0.0035 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.0178 m | pos p95=1.8509 m | rot median=0.0207 rad | total vel median=0.0067 m/s | rel vel median=0.0110 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1944 m | pos p95=0.3603 m | rot median=0.0144 rad | total vel median=0.0167 m/s | rel vel median=0.0129 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.5501 m | pos p95=0.9909 m | rot median=0.0078 rad | total vel median=0.0178 m/s | rel vel median=0.0171 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.2171 m | pos p95=2.2278 m | rot median=0.0271 rad | total vel median=0.0227 m/s | rel vel median=0.0189 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Largest completed terminal errors
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=8.3264 m | rot=0.0658 rad | total_vel_violation=0
#   PRBS seed=46 | reason=completed | sim_time=60.00s | pos=4.5978 m | rot=0.0485 rad | total_vel_violation=0
#   PRBS seed=45 | reason=completed | sim_time=60.00s | pos=2.5155 m | rot=0.0377 rad | total_vel_violation=0
#   OU seed=200042 | reason=completed | sim_time=60.00s | pos=2.4445 m | rot=0.0369 rad | total_vel_violation=0
#   CHIRP seed=100045 | reason=completed | sim_time=60.00s | pos=2.0090 m | rot=0.0272 rad | total_vel_violation=0
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# PRBS seed=42 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_full/main_phnode_full_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260523_160405/degraded_eval/diagnostic_plots/high_terminal_error_PRBS_seed42.png
# PRBS seed=46 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_full/main_phnode_full_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260523_160405/degraded_eval/diagnostic_plots/high_terminal_error_PRBS_seed46.png
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_full/main_phnode_full_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=heading_biased_eval | noise_protocol=iid_noisy_ic | noise_budget=protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350] | scenarios=PRBS,CHIRP,OU | trajectories=18 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_full/main_phnode_full_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260523_160405/heading_biased_eval
# [scenario 1/3] PRBS | 6 trajectories
# [1/18] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=5m20.0s
# [5/18] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=49.0s
# [6/18] PRBS seed=47 done | reason=completed | sim_time=60.00s | eta=37.7s
# [scenario done] PRBS | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=2.7120 m | pos_p95=3.5825 m | rot_med=0.0269 rad | completion=1.000 | elapsed=18.9s
# [scenario 2/3] CHIRP | 6 trajectories
# [7/18] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=59.1s
# [11/18] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=24.0s
# [12/18] CHIRP seed=100047 done | reason=completed | sim_time=60.00s | eta=18.8s
# [scenario done] CHIRP | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=3.5032 m | pos_p95=4.4688 m | rot_med=0.0497 rad | completion=1.000 | elapsed=37.7s
# [scenario 3/3] OU | 6 trajectories
# [13/18] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=21.8s
# [17/18] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=3.3s
# [18/18] OU seed=200047 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=2.7946 m | pos_p95=3.4853 m | rot_med=0.0393 rad | completion=1.000 | elapsed=56.7s
# Benchmark finished in 1m09.2s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_full/main_phnode_full_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260523_160405/heading_biased_eval
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_full/main_phnode_full_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: pH NODE Full [main/core]
# Canonical model type: phnode_full
# Energy semantics: mechanical_energy
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 6
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.5019 m | pos p95=0.7709 m | rot median=0.0386 rad | total vel median=0.0156 m/s | rel vel median=0.0082 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=1.5027 m | pos p95=2.3658 m | rot median=0.0373 rad | total vel median=0.0156 m/s | rel vel median=0.0141 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=2.8561 m | pos p95=4.4326 m | rot median=0.0393 rad | total vel median=0.0182 m/s | rel vel median=0.0127 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=18 | completed=18 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.4486 m | pos p95=0.6716 m | rot median=0.0379 rad | total vel median=0.0191 m/s | rel vel median=0.0112 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.4038 m | pos p95=2.3455 m | rot median=0.0358 rad | total vel median=0.0187 m/s | rel vel median=0.0224 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=2.7120 m | pos p95=3.5825 m | rot median=0.0269 rad | total vel median=0.0177 m/s | rel vel median=0.0219 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.4813 m | pos p95=0.6156 m | rot median=0.0381 rad | total vel median=0.0123 m/s | rel vel median=0.0046 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.5795 m | pos p95=1.9983 m | rot median=0.0397 rad | total vel median=0.0121 m/s | rel vel median=0.0037 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=3.5032 m | pos p95=4.4688 m | rot median=0.0497 rad | total vel median=0.0141 m/s | rel vel median=0.0109 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.5767 m | pos p95=0.7860 m | rot median=0.0422 rad | total vel median=0.0189 m/s | rel vel median=0.0130 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.5553 m | pos p95=2.2993 m | rot median=0.0373 rad | total vel median=0.0166 m/s | rel vel median=0.0169 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=2.7946 m | pos p95=3.4853 m | rot median=0.0393 rad | total vel median=0.0208 m/s | rel vel median=0.0190 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Largest completed terminal errors
#   CHIRP seed=100045 | reason=completed | sim_time=60.00s | pos=4.4839 m | rot=0.0551 rad | total_vel_violation=0
#   CHIRP seed=100044 | reason=completed | sim_time=60.00s | pos=4.4235 m | rot=0.0584 rad | total_vel_violation=0
#   PRBS seed=43 | reason=completed | sim_time=60.00s | pos=3.6436 m | rot=0.0239 rad | total_vel_violation=0
#   CHIRP seed=100043 | reason=completed | sim_time=60.00s | pos=3.5841 m | rot=0.0498 rad | total_vel_violation=0
#   OU seed=200042 | reason=completed | sim_time=60.00s | pos=3.5123 m | rot=0.0516 rad | total_vel_violation=0
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# CHIRP seed=100045 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_full/main_phnode_full_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260523_160405/heading_biased_eval/diagnostic_plots/high_terminal_error_CHIRP_seed100045.png
# CHIRP seed=100044 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_full/main_phnode_full_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260523_160405/heading_biased_eval/diagnostic_plots/high_terminal_error_CHIRP_seed100044.png
# Batch evaluation complete.
# [eval] suite=sweep_oc_phase1a_smoke1_iid_t2_wpfrag_phnode_full eval_protocol=iid_noisy_ic profiles=clean nominal_eval degraded_eval heading_biased_eval
# Suite directory: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_phnode_full
# Manifest: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_phnode_full/runs.tsv
# Mode: resampled
# [eval] main_phnode_full_seed42
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_phnode_full/main_phnode_full_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=clean | noise_protocol=clean | noise_budget=protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000] | scenarios=PRBS,CHIRP,OU | trajectories=18 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_phnode_full/main_phnode_full_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260523_161046/clean
# [scenario 1/3] PRBS | 6 trajectories
# [1/18] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=16m33.8s
# [5/18] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=2m32.0s
# [6/18] PRBS seed=47 done | reason=completed | sim_time=60.00s | eta=1m57.0s
# [scenario done] PRBS | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=1.0347 m | pos_p95=3.0158 m | rot_med=0.0233 rad | completion=1.000 | elapsed=58.5s
# [scenario 2/3] CHIRP | 6 trajectories
# [7/18] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=3m04.3s
# [11/18] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=1m14.7s
# [12/18] CHIRP seed=100047 done | reason=completed | sim_time=60.00s | eta=58.7s
# [scenario done] CHIRP | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=1.4131 m | pos_p95=1.6353 m | rot_med=0.0217 rad | completion=1.000 | elapsed=1m57.4s
# [scenario 3/3] OU | 6 trajectories
# [13/18] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=1m07.8s
# [17/18] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=10.4s
# [18/18] OU seed=200047 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=0.7875 m | pos_p95=2.5167 m | rot_med=0.0206 rad | completion=1.000 | elapsed=2m56.3s
# Benchmark finished in 3m09.9s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_phnode_full/main_phnode_full_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260523_161046/clean
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_phnode_full/main_phnode_full_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: pH NODE Full [main/core]
# Canonical model type: phnode_full
# Energy semantics: mechanical_energy
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 6
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.1226 m | pos p95=0.3181 m | rot median=0.0084 rad | total vel median=0.0073 m/s | rel vel median=0.0063 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=0.3344 m | pos p95=0.8117 m | rot median=0.0144 rad | total vel median=0.0102 m/s | rel vel median=0.0083 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=1.0347 m | pos p95=2.7913 m | rot median=0.0223 rad | total vel median=0.0148 m/s | rel vel median=0.0148 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=18 | completed=18 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1391 m | pos p95=0.3060 m | rot median=0.0078 rad | total vel median=0.0089 m/s | rel vel median=0.0073 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.4564 m | pos p95=0.7627 m | rot median=0.0148 rad | total vel median=0.0166 m/s | rel vel median=0.0083 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.0347 m | pos p95=3.0158 m | rot median=0.0233 rad | total vel median=0.0191 m/s | rel vel median=0.0192 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.0960 m | pos p95=0.1161 m | rot median=0.0075 rad | total vel median=0.0072 m/s | rel vel median=0.0065 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.3230 m | pos p95=0.4336 m | rot median=0.0149 rad | total vel median=0.0056 m/s | rel vel median=0.0054 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.4131 m | pos p95=1.6353 m | rot median=0.0217 rad | total vel median=0.0058 m/s | rel vel median=0.0114 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1512 m | pos p95=0.2801 m | rot median=0.0138 rad | total vel median=0.0053 m/s | rel vel median=0.0045 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.3684 m | pos p95=0.7892 m | rot median=0.0088 rad | total vel median=0.0225 m/s | rel vel median=0.0211 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=0.7875 m | pos p95=2.5167 m | rot median=0.0206 rad | total vel median=0.0273 m/s | rel vel median=0.0241 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Largest completed terminal errors
#   PRBS seed=46 | reason=completed | sim_time=60.00s | pos=3.3922 m | rot=0.0506 rad | total_vel_violation=0
#   OU seed=200042 | reason=completed | sim_time=60.00s | pos=2.6853 m | rot=0.0661 rad | total_vel_violation=0
#   OU seed=200043 | reason=completed | sim_time=60.00s | pos=2.0107 m | rot=0.0698 rad | total_vel_violation=0
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=1.8868 m | rot=0.0253 rad | total_vel_violation=0
#   CHIRP seed=100047 | reason=completed | sim_time=60.00s | pos=1.6587 m | rot=0.0337 rad | total_vel_violation=0
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# PRBS seed=46 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_phnode_full/main_phnode_full_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260523_161046/clean/diagnostic_plots/high_terminal_error_PRBS_seed46.png
# OU seed=200042 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_phnode_full/main_phnode_full_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260523_161046/clean/diagnostic_plots/high_terminal_error_OU_seed200042.png
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_phnode_full/main_phnode_full_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=nominal_eval | noise_protocol=iid_noisy_ic | noise_budget=protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | scenarios=PRBS,CHIRP,OU | trajectories=18 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_phnode_full/main_phnode_full_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260523_161046/nominal_eval
# [scenario 1/3] PRBS | 6 trajectories
# [1/18] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=5m24.0s
# [5/18] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=49.6s
# [6/18] PRBS seed=47 done | reason=completed | sim_time=60.00s | eta=38.2s
# [scenario done] PRBS | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=1.8920 m | pos_p95=4.6872 m | rot_med=0.0373 rad | completion=1.000 | elapsed=19.1s
# [scenario 2/3] CHIRP | 6 trajectories
# [7/18] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=59.1s
# [11/18] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=23.9s
# [12/18] CHIRP seed=100047 done | reason=completed | sim_time=60.00s | eta=18.8s
# [scenario done] CHIRP | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=1.1555 m | pos_p95=1.8675 m | rot_med=0.0239 rad | completion=1.000 | elapsed=37.6s
# [scenario 3/3] OU | 6 trajectories
# [13/18] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=21.6s
# [17/18] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=3.3s
# [18/18] OU seed=200047 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=1.1058 m | pos_p95=3.2510 m | rot_med=0.0227 rad | completion=1.000 | elapsed=56.3s
# Benchmark finished in 1m09.0s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_phnode_full/main_phnode_full_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260523_161046/nominal_eval
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_phnode_full/main_phnode_full_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: pH NODE Full [main/core]
# Canonical model type: phnode_full
# Energy semantics: mechanical_energy
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 6
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.1535 m | pos p95=0.4306 m | rot median=0.0087 rad | total vel median=0.0080 m/s | rel vel median=0.0062 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=0.4480 m | pos p95=1.4808 m | rot median=0.0165 rad | total vel median=0.0138 m/s | rel vel median=0.0083 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=1.2902 m | pos p95=4.5145 m | rot median=0.0250 rad | total vel median=0.0168 m/s | rel vel median=0.0148 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=18 | completed=18 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.2952 m | pos p95=0.5392 m | rot median=0.0153 rad | total vel median=0.0118 m/s | rel vel median=0.0072 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.0068 m | pos p95=1.7770 m | rot median=0.0256 rad | total vel median=0.0227 m/s | rel vel median=0.0083 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# ...
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_phnode_full/main_phnode_full_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: pH NODE Full [main/core]
# Canonical model type: phnode_full
# Energy semantics: mechanical_energy
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 6
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.1862 m | pos p95=0.3222 m | rot median=0.0146 rad | total vel median=0.0082 m/s | rel vel median=0.0064 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=0.6244 m | pos p95=1.1174 m | rot median=0.0190 rad | total vel median=0.0133 m/s | rel vel median=0.0083 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=1.6304 m | pos p95=3.1242 m | rot median=0.0297 rad | total vel median=0.0181 m/s | rel vel median=0.0148 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=18 | completed=18 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.2093 m | pos p95=0.3577 m | rot median=0.0122 rad | total vel median=0.0104 m/s | rel vel median=0.0072 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.6475 m | pos p95=1.1784 m | rot median=0.0216 rad | total vel median=0.0195 m/s | rel vel median=0.0083 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.5366 m | pos p95=3.5427 m | rot median=0.0304 rad | total vel median=0.0213 m/s | rel vel median=0.0192 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1699 m | pos p95=0.2274 m | rot median=0.0122 rad | total vel median=0.0082 m/s | rel vel median=0.0067 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.6372 m | pos p95=1.0093 m | rot median=0.0194 rad | total vel median=0.0057 m/s | rel vel median=0.0055 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.5768 m | pos p95=2.8059 m | rot median=0.0310 rad | total vel median=0.0057 m/s | rel vel median=0.0114 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1902 m | pos p95=0.2943 m | rot median=0.0179 rad | total vel median=0.0047 m/s | rel vel median=0.0045 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.6244 m | pos p95=0.8652 m | rot median=0.0134 rad | total vel median=0.0237 m/s | rel vel median=0.0209 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.6304 m | pos p95=2.5151 m | rot median=0.0284 rad | total vel median=0.0273 m/s | rel vel median=0.0242 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Largest completed terminal errors
#   PRBS seed=46 | reason=completed | sim_time=60.00s | pos=3.8910 m | rot=0.0552 rad | total_vel_violation=0
#   CHIRP seed=100042 | reason=completed | sim_time=60.00s | pos=2.9889 m | rot=0.0377 rad | total_vel_violation=0
#   OU seed=200042 | reason=completed | sim_time=60.00s | pos=2.7536 m | rot=0.0671 rad | total_vel_violation=0
#   PRBS seed=43 | reason=completed | sim_time=60.00s | pos=2.4981 m | rot=0.0401 rad | total_vel_violation=0
#   CHIRP seed=100047 | reason=completed | sim_time=60.00s | pos=2.2571 m | rot=0.0402 rad | total_vel_violation=0
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# PRBS seed=46 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_phnode_full/main_phnode_full_seed42/rollout_benchmark/phase1a_v4eval_traj6_seed42_20260523_162514/diagnostic_plots/high_terminal_error_PRBS_seed46.png
# CHIRP seed=100042 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_phnode_full/main_phnode_full_seed42/rollout_benchmark/phase1a_v4eval_traj6_seed42_20260523_162514/diagnostic_plots/high_terminal_error_CHIRP_seed100042.png
# Batch evaluation complete.
# [eval] suite=sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_phnode_full eval_protocol=v4_lite profiles=nominal_eval
# Suite directory: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_phnode_full
# Manifest: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_phnode_full/runs.tsv
# Mode: resampled
# [eval] main_phnode_full_seed42
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_phnode_full/main_phnode_full_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=nominal_eval | noise_protocol=v4_lite | noise_budget=protocol=v4_lite | profile=nominal_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | scenarios=PRBS,CHIRP,OU | trajectories=18 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_phnode_full/main_phnode_full_seed42/rollout_benchmark/phase1a_v4eval_traj6_seed42_20260523_162627
# [scenario 1/3] PRBS | 6 trajectories
# [1/18] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=5m07.0s
# [5/18] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=47.0s
# [6/18] PRBS seed=47 done | reason=completed | sim_time=60.00s | eta=36.1s
# [scenario done] PRBS | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=0.6730 m | pos_p95=3.3597 m | rot_med=0.0146 rad | completion=1.000 | elapsed=18.1s
# [scenario 2/3] CHIRP | 6 trajectories
# [7/18] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=56.4s
# [11/18] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=22.8s
# [12/18] CHIRP seed=100047 done | reason=completed | sim_time=60.00s | eta=17.9s
# [scenario done] CHIRP | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=1.8449 m | pos_p95=2.6404 m | rot_med=0.0321 rad | completion=1.000 | elapsed=35.9s
# [scenario 3/3] OU | 6 trajectories
# [13/18] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=20.6s
# [17/18] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=3.2s
# [18/18] OU seed=200047 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=1.0163 m | pos_p95=1.4458 m | rot_med=0.0290 rad | completion=1.000 | elapsed=53.7s
# Benchmark finished in 1m06.9s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_phnode_full/main_phnode_full_seed42/rollout_benchmark/phase1a_v4eval_traj6_seed42_20260523_162627
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_phnode_full/main_phnode_full_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: pH NODE Full [main/core]
# Canonical model type: phnode_full
# Energy semantics: mechanical_energy
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 6
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.1790 m | pos p95=0.3574 m | rot median=0.0117 rad | total vel median=0.0113 m/s | rel vel median=0.0105 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=0.5756 m | pos p95=1.0471 m | rot median=0.0149 rad | total vel median=0.0091 m/s | rel vel median=0.0089 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=1.0226 m | pos p95=2.8890 m | rot median=0.0249 rad | total vel median=0.0187 m/s | rel vel median=0.0166 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=18 | completed=18 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1810 m | pos p95=0.4087 m | rot median=0.0096 rad | total vel median=0.0096 m/s | rel vel median=0.0089 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.3798 m | pos p95=1.1028 m | rot median=0.0149 rad | total vel median=0.0223 m/s | rel vel median=0.0091 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=0.6730 m | pos p95=3.3597 m | rot median=0.0146 rad | total vel median=0.0187 m/s | rel vel median=0.0165 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1677 m | pos p95=0.2552 m | rot median=0.0105 rad | total vel median=0.0089 m/s | rel vel median=0.0093 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.6900 m | pos p95=0.9667 m | rot median=0.0196 rad | total vel median=0.0060 m/s | rel vel median=0.0063 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.8449 m | pos p95=2.6404 m | rot median=0.0321 rad | total vel median=0.0054 m/s | rel vel median=0.0119 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1897 m | pos p95=0.3056 m | rot median=0.0121 rad | total vel median=0.0136 m/s | rel vel median=0.0133 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.5279 m | pos p95=0.6786 m | rot median=0.0171 rad | total vel median=0.0150 m/s | rel vel median=0.0144 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.0163 m | pos p95=1.4458 m | rot median=0.0290 rad | total vel median=0.0329 m/s | rel vel median=0.0269 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Largest completed terminal errors
#   PRBS seed=46 | reason=completed | sim_time=60.00s | pos=3.7452 m | rot=0.0540 rad | total_vel_violation=0
#   CHIRP seed=100042 | reason=completed | sim_time=60.00s | pos=2.7379 m | rot=0.0355 rad | total_vel_violation=0
#   CHIRP seed=100044 | reason=completed | sim_time=60.00s | pos=2.3479 m | rot=0.0488 rad | total_vel_violation=0
#   PRBS seed=43 | reason=completed | sim_time=60.00s | pos=2.2033 m | rot=0.0282 rad | total_vel_violation=0
#   CHIRP seed=100046 | reason=completed | sim_time=60.00s | pos=2.0041 m | rot=0.0374 rad | total_vel_violation=0
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# PRBS seed=46 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_phnode_full/main_phnode_full_seed42/rollout_benchmark/phase1a_v4eval_traj6_seed42_20260523_162627/diagnostic_plots/high_terminal_error_PRBS_seed46.png
# CHIRP seed=100042 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_phnode_full/main_phnode_full_seed42/rollout_benchmark/phase1a_v4eval_traj6_seed42_20260523_162627/diagnostic_plots/high_terminal_error_CHIRP_seed100042.png
# Batch evaluation complete.
# + /usr/bin/python3 /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/scripts/register_existing_runs_as_suite.py --suite-dir /content/_proxy_suites/sweep_oc_phase1a_smoke1_proxy_t2_wpfrag_phnode_full --run main phnode_full 42 clean__main_phnode_full_seed42 /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_full/main_phnode_full_seed42 --run main phnode_full 42 iid__main_phnode_full_seed42 /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_phnode_full/main_phnode_full_seed42 --run main phnode_full 42 v4lite__main_phnode_full_seed42 /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_phnode_full/main_phnode_full_seed42
# Registered suite: /content/_proxy_suites/sweep_oc_phase1a_smoke1_proxy_t2_wpfrag_phnode_full
# Runs: 3
# Manifest: /content/_proxy_suites/sweep_oc_phase1a_smoke1_proxy_t2_wpfrag_phnode_full/runs.tsv
# + /usr/bin/python3 /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/scripts/summarize_sweep.py --suite-dir /content/_proxy_suites/sweep_oc_phase1a_smoke1_proxy_t2_wpfrag_phnode_full
# + /usr/bin/python3 /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/scripts/build_experiment_report.py --suite-dir /content/_proxy_suites/sweep_oc_phase1a_smoke1_proxy_t2_wpfrag_phnode_full
# /content/_proxy_suites/sweep_oc_phase1a_smoke1_proxy_t2_wpfrag_phnode_full/phase1a_decision_brief.md
# [proxy] local: /content/_proxy_suites/sweep_oc_phase1a_smoke1_proxy_t2_wpfrag_phnode_full

# %% [markdown]
# ## 3. Decision train (3 protocols x 5 seeds)
# The 15 evidence-bearing training runs for this model.

# %%
os.environ["MODE"] = "decision_train"
# !bash scripts/run_phase1a_oc_v4lite.sh
# Out:
# Streaming output truncated to the last 5000 lines.
# position_rmse: ratio=24.461  degradation=+2346.1%
# rotation_geodesic: ratio=43.032  degradation=+4203.2%
# velocity_rmse: ratio=6.881  degradation=+588.1%
# angular_rmse: ratio=9.569  degradation=+856.9%
# success_rate: ratio=1.000  degradation=+0.0%
# trajectory_failure_rate: ratio=1.000  degradation=+0.0%
# [heading_biased_eval]
# position_rmse: ratio=37.582  degradation=+3658.2%
# rotation_geodesic: ratio=71.848  degradation=+7084.8%
# velocity_rmse: ratio=5.548  degradation=+454.8%
# angular_rmse: ratio=4.921  degradation=+392.1%
# success_rate: ratio=1.000  degradation=+0.0%
# trajectory_failure_rate: ratio=1.000  degradation=+0.0%
#
# Training finished. Results: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_phnode_full/main_phnode_full_seed44
# [train] main_phnode_full_seed45
# Loading dataset...
# Loaded: 83850 train, 21000 test, t_eval=[0.   0.05 0.1  0.15 0.2 ]
# Dataset split: trajectory | train trajectories: 559 | test trajectories: 140
# Dataset ID: d0be9434
# Dataset path: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl | velocity convention: body_total | state dim: 27
# Position std: [0.1508, 0.1400, 0.0370]
# Velocity std: u=0.4722, v=0.0898, w=0.0718, p=0.0248, q=0.0906, r=0.0526
# Actuator std: a0=0.1543, a1=0.1555, a2=299.0037
# Training noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# Model: pH NODE Full [main/core] | canonical type: phnode_full
# Model parameters: 62,803
# Training dataset: id=d0be9434 | path=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Mass matrix initialized from physics
# Training: epochs<=300, target_steps=5000, warmup_steps=400, lr=6.00e-03 -> 1.00e-04, solver=rk4, so3_reg=1.00e-03
# Train samples: 83850, Test samples: 21000
# Epoch    1 | Step    20/ 5000 | Train 4.3451e+00 | Test 5.0786e+00 | SO3(train/test) 1.26e-07/1.28e-07 | Fail(train/test) 0/0 | LR 4.10e-04 | 6.5s
# Epoch    2 | Step    40/ 5000 | Train 3.6564e+00 | Test 4.4331e+00 | SO3(train/test) 1.19e-07/1.19e-07 | Fail(train/test) 0/0 | LR 7.05e-04 | 5.9s
# Epoch    3 | Step    60/ 5000 | Train 3.0976e+00 | Test 3.4160e+00 | SO3(train/test) 1.16e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.00e-03 | 6.0s
# Epoch    4 | Step    80/ 5000 | Train 2.0926e+00 | Test 1.8760e+00 | SO3(train/test) 1.16e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.29e-03 | 5.9s
# Epoch    5 | Step   100/ 5000 | Train 1.0386e+00 | Test 2.0606e+00 | SO3(train/test) 1.45e-07/1.21e-07 | Fail(train/test) 0/0 | LR 1.59e-03 | 6.1s
# Epoch    6 | Step   120/ 5000 | Train 8.8594e-01 | Test 1.0672e+00 | SO3(train/test) 1.18e-07/1.21e-07 | Fail(train/test) 0/0 | LR 1.88e-03 | 5.9s
# Epoch    7 | Step   140/ 5000 | Train 1.0220e+00 | Test 1.2432e+00 | SO3(train/test) 1.18e-07/1.24e-07 | Fail(train/test) 0/0 | LR 2.18e-03 | 6.0s
# Epoch    8 | Step   160/ 5000 | Train 9.8146e-01 | Test 9.9617e-01 | SO3(train/test) 1.20e-07/1.13e-07 | Fail(train/test) 0/0 | LR 2.47e-03 | 6.0s
# Epoch    9 | Step   180/ 5000 | Train 1.2208e+00 | Test 1.0189e+00 | SO3(train/test) 1.14e-07/1.15e-07 | Fail(train/test) 0/0 | LR 2.77e-03 | 6.0s
# Epoch   10 | Step   200/ 5000 | Train 8.3303e-01 | Test 9.5886e-01 | SO3(train/test) 1.15e-07/1.19e-07 | Fail(train/test) 0/0 | LR 3.06e-03 | 6.0s
# Epoch   11 | Step   220/ 5000 | Train 7.2545e-01 | Test 4.8281e-01 | SO3(train/test) 1.16e-07/1.15e-07 | Fail(train/test) 0/0 | LR 3.36e-03 | 6.0s
# Epoch   12 | Step   240/ 5000 | Train 1.2299e+00 | Test 9.5431e-01 | SO3(train/test) 1.31e-07/1.43e-07 | Fail(train/test) 0/0 | LR 3.65e-03 | 6.0s
# Epoch   13 | Step   260/ 5000 | Train 6.3296e-01 | Test 7.8472e-01 | SO3(train/test) 1.38e-07/1.29e-07 | Fail(train/test) 0/0 | LR 3.95e-03 | 5.9s
# Epoch   14 | Step   280/ 5000 | Train 9.5472e-01 | Test 5.5771e-01 | SO3(train/test) 1.55e-07/1.52e-07 | Fail(train/test) 0/0 | LR 4.24e-03 | 6.0s
# Epoch   15 | Step   300/ 5000 | Train 7.0407e-01 | Test 4.5692e-01 | SO3(train/test) 1.99e-07/1.92e-07 | Fail(train/test) 0/0 | LR 4.54e-03 | 6.1s
# Epoch   16 | Step   320/ 5000 | Train 6.8815e-01 | Test 1.0637e+00 | SO3(train/test) 7.38e-07/1.36e-07 | Fail(train/test) 0/0 | LR 4.83e-03 | 5.9s
# Epoch   17 | Step   340/ 5000 | Train 9.1258e-01 | Test 8.3696e-01 | SO3(train/test) 1.30e-07/1.53e-07 | Fail(train/test) 0/0 | LR 5.13e-03 | 5.9s
# Epoch   18 | Step   360/ 5000 | Train 5.5816e-01 | Test 5.3394e-01 | SO3(train/test) 1.44e-07/1.46e-07 | Fail(train/test) 0/0 | LR 5.42e-03 | 5.9s
# Epoch   19 | Step   380/ 5000 | Train 8.2650e-01 | Test 5.2441e-01 | SO3(train/test) 2.46e-07/1.75e-07 | Fail(train/test) 0/0 | LR 5.72e-03 | 5.9s
# Epoch   20 | Step   400/ 5000 | Train 3.9391e-01 | Test 5.1045e-01 | SO3(train/test) 1.35e-07/1.24e-07 | Fail(train/test) 0/0 | LR 6.00e-03 | 6.0s
# Epoch   21 | Step   420/ 5000 | Train 7.2561e-01 | Test 1.3439e+00 | SO3(train/test) 1.57e-07/1.55e-06 | Fail(train/test) 0/0 | LR 6.00e-03 | 5.9s
# Epoch   22 | Step   440/ 5000 | Train 1.1211e+00 | Test 5.7927e-01 | SO3(train/test) 7.94e-07/1.61e-07 | Fail(train/test) 0/0 | LR 6.00e-03 | 6.0s
# Epoch   23 | Step   460/ 5000 | Train 4.6837e-01 | Test 2.4726e-01 | SO3(train/test) 1.27e-07/1.18e-07 | Fail(train/test) 0/0 | LR 6.00e-03 | 5.9s
# Epoch   24 | Step   480/ 5000 | Train 3.2240e-01 | Test 3.6323e-01 | SO3(train/test) 1.18e-07/1.19e-07 | Fail(train/test) 0/0 | LR 6.00e-03 | 6.0s
# Epoch   25 | Step   500/ 5000 | Train 5.5922e-01 | Test 9.6088e-01 | SO3(train/test) 1.24e-07/2.75e-07 | Fail(train/test) 0/0 | LR 5.99e-03 | 6.1s
# Epoch   26 | Step   520/ 5000 | Train 9.2168e-01 | Test 1.3644e+00 | SO3(train/test) 5.48e-07/2.28e-07 | Fail(train/test) 0/0 | LR 5.99e-03 | 6.0s
# Epoch   27 | Step   540/ 5000 | Train 3.3894e+00 | Test 2.9190e+00 | SO3(train/test) 1.29e-06/1.96e-07 | Fail(train/test) 0/0 | LR 5.99e-03 | 5.9s
# Epoch   28 | Step   560/ 5000 | Train 1.6135e+00 | Test 2.1393e+00 | SO3(train/test) 1.52e-07/1.50e-07 | Fail(train/test) 0/0 | LR 5.98e-03 | 6.0s
# Epoch   29 | Step   580/ 5000 | Train 7.3526e-01 | Test 3.9955e-01 | SO3(train/test) 1.67e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.98e-03 | 5.9s
# Epoch   30 | Step   600/ 5000 | Train 3.8003e-01 | Test 7.4442e-01 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.97e-03 | 6.0s
# Epoch   31 | Step   620/ 5000 | Train 5.7135e-01 | Test 5.0353e-01 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.97e-03 | 5.9s
# Epoch   32 | Step   640/ 5000 | Train 3.8720e-01 | Test 2.4063e-01 | SO3(train/test) 1.15e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.96e-03 | 6.0s
# Epoch   33 | Step   660/ 5000 | Train 3.1809e-01 | Test 2.3944e-01 | SO3(train/test) 1.14e-07/1.13e-07 | Fail(train/test) 0/0 | LR 5.95e-03 | 5.9s
# Epoch   34 | Step   680/ 5000 | Train 2.8370e-01 | Test 2.4829e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.95e-03 | 6.0s
# Epoch   35 | Step   700/ 5000 | Train 1.7519e-01 | Test 1.6548e-01 | SO3(train/test) 1.14e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.94e-03 | 6.0s
# Epoch   36 | Step   720/ 5000 | Train 1.2649e-01 | Test 1.3208e-01 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.93e-03 | 6.0s
# Epoch   37 | Step   740/ 5000 | Train 2.7204e-01 | Test 3.3551e-01 | SO3(train/test) 1.15e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.92e-03 | 5.9s
# Epoch   38 | Step   760/ 5000 | Train 2.6946e-01 | Test 2.1331e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.91e-03 | 5.9s
# Epoch   39 | Step   780/ 5000 | Train 3.1506e-01 | Test 2.8594e-01 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.90e-03 | 6.0s
# Epoch   40 | Step   800/ 5000 | Train 1.5738e-01 | Test 1.2366e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.89e-03 | 6.0s
# Epoch   41 | Step   820/ 5000 | Train 1.5886e-01 | Test 1.5077e-01 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.88e-03 | 6.0s
# Epoch   42 | Step   840/ 5000 | Train 1.5234e-01 | Test 1.1085e-01 | SO3(train/test) 1.15e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.87e-03 | 6.0s
# Epoch   43 | Step   860/ 5000 | Train 1.3689e-01 | Test 1.1080e-01 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.86e-03 | 6.1s
# Epoch   44 | Step   880/ 5000 | Train 1.0931e-01 | Test 1.7555e-01 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.84e-03 | 5.9s
# Epoch   45 | Step   900/ 5000 | Train 1.6367e-01 | Test 1.2839e-01 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.83e-03 | 6.2s
# Epoch   46 | Step   920/ 5000 | Train 1.1267e-01 | Test 8.5452e-02 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.82e-03 | 6.0s
# Epoch   47 | Step   940/ 5000 | Train 1.2664e-01 | Test 2.1623e-01 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.80e-03 | 6.0s
# Epoch   48 | Step   960/ 5000 | Train 1.5689e-01 | Test 1.0093e-01 | SO3(train/test) 1.15e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.79e-03 | 5.9s
# Epoch   49 | Step   980/ 5000 | Train 1.9854e-01 | Test 1.4484e-01 | SO3(train/test) 1.15e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.77e-03 | 6.0s
# Epoch   50 | Step  1000/ 5000 | Train 1.0695e-01 | Test 9.6197e-02 | SO3(train/test) 1.15e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.76e-03 | 6.1s
# Epoch   51 | Step  1020/ 5000 | Train 7.3238e-02 | Test 9.0205e-02 | SO3(train/test) 1.16e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.74e-03 | 6.1s
# Epoch   52 | Step  1040/ 5000 | Train 6.8022e-02 | Test 9.0641e-02 | SO3(train/test) 1.16e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.72e-03 | 6.0s
# Epoch   53 | Step  1060/ 5000 | Train 8.7207e-02 | Test 9.5762e-02 | SO3(train/test) 1.16e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.71e-03 | 6.1s
# Epoch   54 | Step  1080/ 5000 | Train 7.1903e-02 | Test 8.0355e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.69e-03 | 5.9s
# Epoch   55 | Step  1100/ 5000 | Train 6.0120e-02 | Test 6.8985e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.67e-03 | 6.1s
# Epoch   56 | Step  1120/ 5000 | Train 8.0131e-02 | Test 8.1160e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.65e-03 | 6.0s
# Epoch   57 | Step  1140/ 5000 | Train 9.7083e-02 | Test 7.7900e-02 | SO3(train/test) 1.16e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.63e-03 | 6.0s
# Epoch   58 | Step  1160/ 5000 | Train 6.2127e-02 | Test 6.5820e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.61e-03 | 6.0s
# Epoch   59 | Step  1180/ 5000 | Train 5.6799e-02 | Test 7.0929e-02 | SO3(train/test) 1.16e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.59e-03 | 6.0s
# Epoch   60 | Step  1200/ 5000 | Train 6.4120e-02 | Test 9.4235e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.57e-03 | 6.1s
# Epoch   61 | Step  1220/ 5000 | Train 5.7640e-02 | Test 6.7660e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.55e-03 | 5.9s
# Epoch   62 | Step  1240/ 5000 | Train 5.6967e-02 | Test 4.9531e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.53e-03 | 6.0s
# Epoch   63 | Step  1260/ 5000 | Train 9.3886e-02 | Test 8.9864e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.51e-03 | 5.9s
# Epoch   64 | Step  1280/ 5000 | Train 7.2081e-02 | Test 8.1884e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.48e-03 | 6.0s
# Epoch   65 | Step  1300/ 5000 | Train 5.1970e-02 | Test 5.4847e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.46e-03 | 6.1s
# Epoch   66 | Step  1320/ 5000 | Train 4.4658e-02 | Test 4.6519e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.44e-03 | 6.0s
# Epoch   67 | Step  1340/ 5000 | Train 4.7728e-02 | Test 7.9126e-02 | SO3(train/test) 1.16e-07/1.17e-07 | Fail(train/test) 0/0 | LR 5.41e-03 | 5.8s
# Epoch   68 | Step  1360/ 5000 | Train 4.4020e-02 | Test 4.7337e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.39e-03 | 6.0s
# Epoch   69 | Step  1380/ 5000 | Train 3.3687e-02 | Test 3.0726e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.36e-03 | 5.9s
# Epoch   70 | Step  1400/ 5000 | Train 2.4571e-02 | Test 2.5856e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.34e-03 | 6.0s
# Epoch   71 | Step  1420/ 5000 | Train 5.8214e-02 | Test 5.1696e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.31e-03 | 5.9s
# Epoch   72 | Step  1440/ 5000 | Train 3.3500e-02 | Test 3.6263e-02 | SO3(train/test) 1.16e-07/1.17e-07 | Fail(train/test) 0/0 | LR 5.29e-03 | 6.0s
# Epoch   73 | Step  1460/ 5000 | Train 3.8737e-02 | Test 3.5308e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 5.26e-03 | 5.9s
# Epoch   74 | Step  1480/ 5000 | Train 3.4155e-02 | Test 3.5063e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.23e-03 | 6.0s
# Epoch   75 | Step  1500/ 5000 | Train 3.2191e-02 | Test 2.1088e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.21e-03 | 6.0s
# Epoch   76 | Step  1520/ 5000 | Train 3.0127e-02 | Test 2.1643e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.18e-03 | 6.0s
# Epoch   77 | Step  1540/ 5000 | Train 5.1769e-02 | Test 4.1631e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.15e-03 | 5.9s
# Epoch   78 | Step  1560/ 5000 | Train 3.8035e-02 | Test 2.6373e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.12e-03 | 6.0s
# Epoch   79 | Step  1580/ 5000 | Train 2.2708e-02 | Test 2.4141e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.09e-03 | 5.9s
# Epoch   80 | Step  1600/ 5000 | Train 2.3830e-02 | Test 2.2036e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.06e-03 | 6.1s
# Epoch   81 | Step  1620/ 5000 | Train 1.8613e-02 | Test 1.8194e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.03e-03 | 5.9s
# Epoch   82 | Step  1640/ 5000 | Train 1.4736e-02 | Test 1.5638e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.00e-03 | 5.9s
# Epoch   83 | Step  1660/ 5000 | Train 1.3066e-02 | Test 1.3554e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.97e-03 | 5.9s
# Epoch   84 | Step  1680/ 5000 | Train 1.5709e-02 | Test 3.2104e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.94e-03 | 5.9s
# Epoch   85 | Step  1700/ 5000 | Train 2.1736e-02 | Test 3.6018e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.91e-03 | 6.1s
# Epoch   86 | Step  1720/ 5000 | Train 1.9898e-02 | Test 1.9491e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.88e-03 | 5.9s
# Epoch   87 | Step  1740/ 5000 | Train 1.5587e-02 | Test 1.5499e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.85e-03 | 6.0s
# Epoch   88 | Step  1760/ 5000 | Train 1.8134e-02 | Test 1.3260e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.82e-03 | 5.9s
# Epoch   89 | Step  1780/ 5000 | Train 1.1238e-02 | Test 1.1566e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.78e-03 | 5.9s
# Epoch   90 | Step  1800/ 5000 | Train 1.4874e-02 | Test 1.3422e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.75e-03 | 6.1s
# Epoch   91 | Step  1820/ 5000 | Train 1.7654e-02 | Test 1.9732e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.72e-03 | 6.0s
# Epoch   92 | Step  1840/ 5000 | Train 1.6039e-02 | Test 1.2476e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.68e-03 | 5.9s
# Epoch   93 | Step  1860/ 5000 | Train 1.2654e-02 | Test 1.3232e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.65e-03 | 6.0s
# Epoch   94 | Step  1880/ 5000 | Train 1.0598e-02 | Test 1.0055e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.62e-03 | 6.0s
# Epoch   95 | Step  1900/ 5000 | Train 9.1862e-03 | Test 1.0125e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.58e-03 | 6.1s
# Epoch   96 | Step  1920/ 5000 | Train 8.7501e-03 | Test 8.7027e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.55e-03 | 5.9s
# Epoch   97 | Step  1940/ 5000 | Train 8.4157e-03 | Test 1.0896e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.51e-03 | 5.9s
# Epoch   98 | Step  1960/ 5000 | Train 1.0274e-02 | Test 1.2430e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.48e-03 | 6.0s
# Epoch   99 | Step  1980/ 5000 | Train 1.0236e-02 | Test 1.0298e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.44e-03 | 6.0s
# Epoch  100 | Step  2000/ 5000 | Train 1.2053e-02 | Test 1.6247e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.41e-03 | 6.0s
# Epoch  101 | Step  2020/ 5000 | Train 2.3159e-02 | Test 2.7877e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.37e-03 | 5.9s
# Epoch  102 | Step  2040/ 5000 | Train 1.6651e-02 | Test 9.9486e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.33e-03 | 6.0s
# Epoch  103 | Step  2060/ 5000 | Train 1.4363e-02 | Test 1.1680e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.30e-03 | 6.0s
# Epoch  104 | Step  2080/ 5000 | Train 1.3744e-02 | Test 1.0347e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.26e-03 | 6.0s
# Epoch  105 | Step  2100/ 5000 | Train 1.1660e-02 | Test 1.5428e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.22e-03 | 6.0s
# Epoch  106 | Step  2120/ 5000 | Train 1.2491e-02 | Test 1.1794e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.19e-03 | 5.9s
# Epoch  107 | Step  2140/ 5000 | Train 1.1366e-02 | Test 1.5134e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.15e-03 | 5.9s
# Epoch  108 | Step  2160/ 5000 | Train 1.2093e-02 | Test 1.0166e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.11e-03 | 6.0s
# Epoch  109 | Step  2180/ 5000 | Train 8.7827e-03 | Test 9.6264e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.08e-03 | 6.0s
# Epoch  110 | Step  2200/ 5000 | Train 9.5572e-03 | Test 6.5678e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.04e-03 | 6.1s
# Epoch  111 | Step  2220/ 5000 | Train 2.0641e-02 | Test 1.5616e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.00e-03 | 5.9s
# Epoch  112 | Step  2240/ 5000 | Train 1.2589e-02 | Test 1.2403e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.96e-03 | 6.0s
# Epoch  113 | Step  2260/ 5000 | Train 1.0290e-02 | Test 1.0190e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.92e-03 | 5.9s
# Epoch  114 | Step  2280/ 5000 | Train 1.2074e-02 | Test 1.0275e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.88e-03 | 6.0s
# Epoch  115 | Step  2300/ 5000 | Train 9.9267e-03 | Test 1.0369e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.85e-03 | 6.0s
# Epoch  116 | Step  2320/ 5000 | Train 1.0467e-02 | Test 1.0406e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.81e-03 | 6.0s
# Epoch  117 | Step  2340/ 5000 | Train 1.1728e-02 | Test 9.0120e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.77e-03 | 5.9s
# Epoch  118 | Step  2360/ 5000 | Train 7.5361e-03 | Test 9.4551e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.73e-03 | 5.9s
# Epoch  119 | Step  2380/ 5000 | Train 6.9122e-03 | Test 1.2097e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.69e-03 | 5.9s
# Epoch  120 | Step  2400/ 5000 | Train 1.1313e-02 | Test 8.8963e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 3.65e-03 | 6.1s
# Epoch  121 | Step  2420/ 5000 | Train 7.0666e-03 | Test 6.8194e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.61e-03 | 6.0s
# Epoch  122 | Step  2440/ 5000 | Train 6.7369e-03 | Test 6.5640e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.57e-03 | 6.0s
# Epoch  123 | Step  2460/ 5000 | Train 6.9792e-03 | Test 1.0763e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 3.53e-03 | 6.0s
# Epoch  124 | Step  2480/ 5000 | Train 6.8031e-03 | Test 7.2726e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.49e-03 | 6.0s
# Epoch  125 | Step  2500/ 5000 | Train 1.0842e-02 | Test 1.0979e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.45e-03 | 6.0s
# Epoch  126 | Step  2520/ 5000 | Train 1.0852e-02 | Test 8.6911e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.41e-03 | 5.9s
# Epoch  127 | Step  2540/ 5000 | Train 1.0561e-02 | Test 7.9506e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 3.37e-03 | 6.0s
# Epoch  128 | Step  2560/ 5000 | Train 9.7320e-03 | Test 8.5370e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 3.33e-03 | 5.9s
# Epoch  129 | Step  2580/ 5000 | Train 7.4832e-03 | Test 6.7911e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.29e-03 | 6.0s
# Epoch  130 | Step  2600/ 5000 | Train 6.4567e-03 | Test 7.7113e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.25e-03 | 6.0s
# Epoch  131 | Step  2620/ 5000 | Train 6.8336e-03 | Test 1.1054e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.21e-03 | 6.0s
# Epoch  132 | Step  2640/ 5000 | Train 1.0488e-02 | Test 7.4144e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.17e-03 | 5.9s
# Epoch  133 | Step  2660/ 5000 | Train 8.1899e-03 | Test 9.3648e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.13e-03 | 6.0s
# Epoch  134 | Step  2680/ 5000 | Train 7.3571e-03 | Test 8.8282e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.09e-03 | 6.0s
# Epoch  135 | Step  2700/ 5000 | Train 8.8079e-03 | Test 1.2021e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.05e-03 | 6.0s
# Epoch  136 | Step  2720/ 5000 | Train 8.6839e-03 | Test 8.7488e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.01e-03 | 5.9s
# Epoch  137 | Step  2740/ 5000 | Train 7.8055e-03 | Test 5.9453e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.97e-03 | 5.9s
# Epoch  138 | Step  2760/ 5000 | Train 6.5187e-03 | Test 7.0750e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 2.93e-03 | 5.9s
# Epoch  139 | Step  2780/ 5000 | Train 6.6219e-03 | Test 6.4477e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.89e-03 | 6.0s
# Epoch  140 | Step  2800/ 5000 | Train 5.7794e-03 | Test 6.3159e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.85e-03 | 6.0s
# Epoch  141 | Step  2820/ 5000 | Train 5.8832e-03 | Test 6.7977e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 2.81e-03 | 6.0s
# Epoch  142 | Step  2840/ 5000 | Train 5.6406e-03 | Test 6.3537e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 2.77e-03 | 5.9s
# Epoch  143 | Step  2860/ 5000 | Train 5.5932e-03 | Test 5.8707e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.73e-03 | 6.0s
# Epoch  144 | Step  2880/ 5000 | Train 5.5208e-03 | Test 5.2218e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.69e-03 | 6.0s
# Epoch  145 | Step  2900/ 5000 | Train 5.3295e-03 | Test 5.4601e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.65e-03 | 6.1s
# Epoch  146 | Step  2920/ 5000 | Train 6.8528e-03 | Test 9.5045e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.61e-03 | 6.0s
# Epoch  147 | Step  2940/ 5000 | Train 6.8689e-03 | Test 6.3387e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.57e-03 | 5.9s
# Epoch  148 | Step  2960/ 5000 | Train 7.8975e-03 | Test 1.0943e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.53e-03 | 6.1s
# Epoch  149 | Step  2980/ 5000 | Train 7.5128e-03 | Test 9.0627e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.49e-03 | 6.0s
# Epoch  150 | Step  3000/ 5000 | Train 6.3924e-03 | Test 5.9694e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.45e-03 | 6.2s
# Epoch  151 | Step  3020/ 5000 | Train 6.3317e-03 | Test 6.8635e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.41e-03 | 6.0s
# Epoch  152 | Step  3040/ 5000 | Train 6.1665e-03 | Test 6.1448e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.37e-03 | 6.0s
# Epoch  153 | Step  3060/ 5000 | Train 5.3606e-03 | Test 4.9618e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.33e-03 | 5.9s
# Epoch  154 | Step  3080/ 5000 | Train 5.0891e-03 | Test 5.1530e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.29e-03 | 6.1s
# Epoch  155 | Step  3100/ 5000 | Train 5.0555e-03 | Test 5.1424e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 2.25e-03 | 6.1s
# Epoch  156 | Step  3120/ 5000 | Train 4.9838e-03 | Test 5.2876e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.21e-03 | 6.0s
# Epoch  157 | Step  3140/ 5000 | Train 4.8977e-03 | Test 5.4327e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.18e-03 | 6.0s
# Epoch  158 | Step  3160/ 5000 | Train 4.8545e-03 | Test 5.3113e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.14e-03 | 6.0s
# Epoch  159 | Step  3180/ 5000 | Train 4.8488e-03 | Test 5.3471e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 2.10e-03 | 5.9s
# Epoch  160 | Step  3200/ 5000 | Train 4.8278e-03 | Test 4.8229e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.06e-03 | 6.1s
# Epoch  161 | Step  3220/ 5000 | Train 4.9051e-03 | Test 5.1982e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.02e-03 | 5.9s
# Epoch  162 | Step  3240/ 5000 | Train 4.5815e-03 | Test 5.9253e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.99e-03 | 5.9s
# Epoch  163 | Step  3260/ 5000 | Train 4.7904e-03 | Test 5.3025e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.95e-03 | 5.9s
# Epoch  164 | Step  3280/ 5000 | Train 5.4836e-03 | Test 6.8445e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.91e-03 | 5.9s
# Epoch  165 | Step  3300/ 5000 | Train 5.8845e-03 | Test 5.3370e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.87e-03 | 6.0s
# Epoch  166 | Step  3320/ 5000 | Train 4.9600e-03 | Test 4.7165e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.84e-03 | 5.9s
# Epoch  167 | Step  3340/ 5000 | Train 4.6462e-03 | Test 5.4503e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.80e-03 | 5.9s
# Epoch  168 | Step  3360/ 5000 | Train 4.6845e-03 | Test 5.3222e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.76e-03 | 5.9s
# Epoch  169 | Step  3380/ 5000 | Train 4.5720e-03 | Test 5.2654e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.73e-03 | 5.9s
# Epoch  170 | Step  3400/ 5000 | Train 4.5378e-03 | Test 4.9444e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.69e-03 | 6.0s
# Epoch  171 | Step  3420/ 5000 | Train 4.4929e-03 | Test 4.8499e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.66e-03 | 5.9s
# Epoch  172 | Step  3440/ 5000 | Train 5.0051e-03 | Test 5.3044e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.62e-03 | 5.9s
# Epoch  173 | Step  3460/ 5000 | Train 4.9336e-03 | Test 6.9879e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.59e-03 | 5.9s
# Epoch  174 | Step  3480/ 5000 | Train 4.7883e-03 | Test 4.8381e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.55e-03 | 5.9s
# Epoch  175 | Step  3500/ 5000 | Train 4.3130e-03 | Test 4.4972e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.52e-03 | 6.1s
# Epoch  176 | Step  3520/ 5000 | Train 4.1658e-03 | Test 4.3305e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.48e-03 | 6.0s
# Epoch  177 | Step  3540/ 5000 | Train 4.1592e-03 | Test 4.3610e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.45e-03 | 6.0s
# Epoch  178 | Step  3560/ 5000 | Train 4.1498e-03 | Test 4.3079e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.41e-03 | 5.9s
# Epoch  179 | Step  3580/ 5000 | Train 4.1217e-03 | Test 4.3278e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.38e-03 | 6.0s
# Epoch  180 | Step  3600/ 5000 | Train 4.0995e-03 | Test 4.3358e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.35e-03 | 6.0s
# Epoch  181 | Step  3620/ 5000 | Train 4.1109e-03 | Test 4.2613e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.31e-03 | 5.9s
# Epoch  182 | Step  3640/ 5000 | Train 4.0934e-03 | Test 4.2936e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.28e-03 | 6.0s
# Epoch  183 | Step  3660/ 5000 | Train 4.0900e-03 | Test 4.2527e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.25e-03 | 5.9s
# Epoch  184 | Step  3680/ 5000 | Train 4.0731e-03 | Test 4.3513e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.22e-03 | 5.9s
# Epoch  185 | Step  3700/ 5000 | Train 4.0775e-03 | Test 4.2721e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.19e-03 | 6.1s
# Epoch  186 | Step  3720/ 5000 | Train 4.0463e-03 | Test 4.2278e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.16e-03 | 5.9s
# Epoch  187 | Step  3740/ 5000 | Train 4.0577e-03 | Test 4.2215e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.13e-03 | 5.9s
# Epoch  188 | Step  3760/ 5000 | Train 4.1031e-03 | Test 4.2213e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.10e-03 | 5.9s
# Epoch  189 | Step  3780/ 5000 | Train 4.0672e-03 | Test 4.2593e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.07e-03 | 5.9s
# Epoch  190 | Step  3800/ 5000 | Train 4.0509e-03 | Test 4.2432e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.04e-03 | 6.0s
# Epoch  191 | Step  3820/ 5000 | Train 4.0284e-03 | Test 4.2410e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.01e-03 | 5.9s
# Epoch  192 | Step  3840/ 5000 | Train 4.0223e-03 | Test 4.2836e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 9.77e-04 | 5.9s
# Epoch  193 | Step  3860/ 5000 | Train 3.9986e-03 | Test 4.2239e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 9.49e-04 | 5.9s
# Epoch  194 | Step  3880/ 5000 | Train 3.9796e-03 | Test 4.1526e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 9.21e-04 | 5.9s
# Epoch  195 | Step  3900/ 5000 | Train 3.9855e-03 | Test 4.1542e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 8.93e-04 | 6.0s
# Epoch  196 | Step  3920/ 5000 | Train 3.9828e-03 | Test 4.1870e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 8.66e-04 | 6.0s
# Epoch  197 | Step  3940/ 5000 | Train 3.9763e-03 | Test 4.1494e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 8.39e-04 | 6.0s
# Epoch  198 | Step  3960/ 5000 | Train 3.9896e-03 | Test 4.2421e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 8.12e-04 | 6.0s
# Epoch  199 | Step  3980/ 5000 | Train 3.9794e-03 | Test 4.1625e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 7.86e-04 | 5.9s
# Epoch  200 | Step  4000/ 5000 | Train 3.9540e-03 | Test 4.1673e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 7.61e-04 | 6.1s
# Epoch  201 | Step  4020/ 5000 | Train 3.9707e-03 | Test 4.1440e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 7.35e-04 | 5.9s
# Epoch  202 | Step  4040/ 5000 | Train 3.9517e-03 | Test 4.1074e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 7.11e-04 | 5.9s
# Epoch  203 | Step  4060/ 5000 | Train 3.9335e-03 | Test 4.1230e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 6.86e-04 | 6.0s
# Epoch  204 | Step  4080/ 5000 | Train 3.9386e-03 | Test 4.1148e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 6.62e-04 | 5.9s
# Epoch  205 | Step  4100/ 5000 | Train 3.9481e-03 | Test 4.1221e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 6.39e-04 | 6.0s
# Epoch  206 | Step  4120/ 5000 | Train 3.9350e-03 | Test 4.1275e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 6.16e-04 | 5.9s
# Epoch  207 | Step  4140/ 5000 | Train 3.9399e-03 | Test 4.1077e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 5.93e-04 | 5.9s
# Epoch  208 | Step  4160/ 5000 | Train 3.9271e-03 | Test 4.1474e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 5.71e-04 | 6.0s
# Epoch  209 | Step  4180/ 5000 | Train 3.9225e-03 | Test 4.1326e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 5.50e-04 | 5.9s
# Epoch  210 | Step  4200/ 5000 | Train 3.9185e-03 | Test 4.0989e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.29e-04 | 6.1s
# Epoch  211 | Step  4220/ 5000 | Train 3.9283e-03 | Test 4.1054e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 5.08e-04 | 5.9s
# Epoch  212 | Step  4240/ 5000 | Train 3.9235e-03 | Test 4.0907e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.88e-04 | 5.9s
# Epoch  213 | Step  4260/ 5000 | Train 3.9043e-03 | Test 4.0957e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.68e-04 | 6.0s
# Epoch  214 | Step  4280/ 5000 | Train 3.9094e-03 | Test 4.0910e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.49e-04 | 5.9s
# Epoch  215 | Step  4300/ 5000 | Train 3.9029e-03 | Test 4.0739e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.30e-04 | 6.0s
# Epoch  216 | Step  4320/ 5000 | Train 3.8973e-03 | Test 4.0761e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.12e-04 | 5.9s
# Epoch  217 | Step  4340/ 5000 | Train 3.9024e-03 | Test 4.0631e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.94e-04 | 6.0s
# Epoch  218 | Step  4360/ 5000 | Train 3.9010e-03 | Test 4.0980e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 3.77e-04 | 6.0s
# Epoch  219 | Step  4380/ 5000 | Train 3.8946e-03 | Test 4.0645e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.60e-04 | 6.0s
# Epoch  220 | Step  4400/ 5000 | Train 3.8863e-03 | Test 4.0572e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.44e-04 | 6.1s
# Epoch  221 | Step  4420/ 5000 | Train 3.8904e-03 | Test 4.0765e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.28e-04 | 6.0s
# Epoch  222 | Step  4440/ 5000 | Train 3.8867e-03 | Test 4.0759e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.12e-04 | 5.9s
# Epoch  223 | Step  4460/ 5000 | Train 3.8894e-03 | Test 4.0725e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.98e-04 | 6.0s
# Epoch  224 | Step  4480/ 5000 | Train 3.8894e-03 | Test 4.0671e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.83e-04 | 5.9s
# Epoch  225 | Step  4500/ 5000 | Train 3.8811e-03 | Test 4.0418e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.70e-04 | 6.0s
# Epoch  226 | Step  4520/ 5000 | Train 3.8751e-03 | Test 4.0547e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.57e-04 | 5.9s
# Epoch  227 | Step  4540/ 5000 | Train 3.8780e-03 | Test 4.0435e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.44e-04 | 6.0s
# Epoch  228 | Step  4560/ 5000 | Train 3.8801e-03 | Test 4.0768e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.32e-04 | 5.9s
# Epoch  229 | Step  4580/ 5000 | Train 3.8710e-03 | Test 4.0499e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.20e-04 | 6.0s
# Epoch  230 | Step  4600/ 5000 | Train 3.8728e-03 | Test 4.0449e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.09e-04 | 6.0s
# Epoch  231 | Step  4620/ 5000 | Train 3.8708e-03 | Test 4.0422e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.98e-04 | 5.9s
# Epoch  232 | Step  4640/ 5000 | Train 3.8642e-03 | Test 4.0510e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.88e-04 | 5.9s
# Epoch  233 | Step  4660/ 5000 | Train 3.8665e-03 | Test 4.0455e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.79e-04 | 6.0s
# Epoch  234 | Step  4680/ 5000 | Train 3.8672e-03 | Test 4.0474e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.70e-04 | 5.9s
# Epoch  235 | Step  4700/ 5000 | Train 3.8731e-03 | Test 4.0372e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.61e-04 | 6.0s
# Epoch  236 | Step  4720/ 5000 | Train 3.8605e-03 | Test 4.0366e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.53e-04 | 5.9s
# Epoch  237 | Step  4740/ 5000 | Train 3.8703e-03 | Test 4.0378e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.46e-04 | 5.9s
# Epoch  238 | Step  4760/ 5000 | Train 3.8630e-03 | Test 4.0289e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.39e-04 | 5.9s
# Epoch  239 | Step  4780/ 5000 | Train 3.8583e-03 | Test 4.0313e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.33e-04 | 5.9s
# Epoch  240 | Step  4800/ 5000 | Train 3.8631e-03 | Test 4.0318e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.27e-04 | 6.0s
# Epoch  241 | Step  4820/ 5000 | Train 3.8631e-03 | Test 4.0325e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.22e-04 | 6.0s
# Epoch  242 | Step  4840/ 5000 | Train 3.8610e-03 | Test 4.0448e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.17e-04 | 5.9s
# Epoch  243 | Step  4860/ 5000 | Train 3.8639e-03 | Test 4.0324e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.13e-04 | 5.9s
# Epoch  244 | Step  4880/ 5000 | Train 3.8613e-03 | Test 4.0269e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.10e-04 | 5.9s
# Epoch  245 | Step  4900/ 5000 | Train 3.8569e-03 | Test 4.0413e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.07e-04 | 6.0s
# Epoch  246 | Step  4920/ 5000 | Train 3.8567e-03 | Test 4.0303e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.04e-04 | 5.9s
# Epoch  247 | Step  4940/ 5000 | Train 3.8583e-03 | Test 4.0249e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.02e-04 | 5.9s
# Epoch  248 | Step  4960/ 5000 | Train 3.8535e-03 | Test 4.0255e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.01e-04 | 6.0s
# Epoch  249 | Step  4980/ 5000 | Train 3.8509e-03 | Test 4.0255e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.00e-04 | 5.9s
# Epoch  250 | Step  5000/ 5000 | Train 3.8551e-03 | Test 4.0312e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.00e-04 | 6.1s
# Reached target optimizer steps: 5000/5000
# Done. Best validation score: failure_rate=0.0000, test_loss=4.0249e-03 (epoch 247)
# Running detailed evaluation...
# Block evaluation profile: clean
# Block evaluation noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0001 +/- 0.0001  (max 0.0006)
# Rotation geo [rad]:  0.0005 +/- 0.0000  (max 0.0006)
# Lin vel RMSE [m/s]:  0.0012 +/- 0.0009
# Ang vel RMSE [r/s]:  0.0006 +/- 0.0004
# Components:  u=0.0019  v=0.0003  w=0.0003  p=0.0006  q=0.0006  r=0.0004
# SO(3) violation:  |det-1|=6.53e-08  ||RR^T-I||=1.30e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# Block evaluation profile: nominal_eval
# Block evaluation noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0014 +/- 0.0008  (max 0.0053)
# Rotation geo [rad]:  0.0089 +/- 0.0057  (max 0.0347)
# Lin vel RMSE [m/s]:  0.0047 +/- 0.0021
# Ang vel RMSE [r/s]:  0.0030 +/- 0.0020
# Components:  u=0.0059  v=0.0033  w=0.0029  p=0.0048  q=0.0009  r=0.0012
# SO(3) violation:  |det-1|=3.09e-07  ||RR^T-I||=6.40e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# Block evaluation profile: heading_biased_eval
# Block evaluation noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0049 +/- 0.0017  (max 0.0101)
# Rotation geo [rad]:  0.0357 +/- 0.0102  (max 0.0666)
# Lin vel RMSE [m/s]:  0.0080 +/- 0.0037
# Ang vel RMSE [r/s]:  0.0030 +/- 0.0020
# Components:  u=0.0078  v=0.0090  w=0.0032  p=0.0048  q=0.0009  r=0.0012
# SO(3) violation:  |det-1|=2.90e-07  ||RR^T-I||=6.09e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Block Evaluation Relative To Clean
# ==================================================
# [nominal_eval]
# position_rmse: ratio=13.929  degradation=+1292.9%
# rotation_geodesic: ratio=18.144  degradation=+1714.4%
# velocity_rmse: ratio=4.033  degradation=+303.3%
# angular_rmse: ratio=5.141  degradation=+414.1%
# failure_rate: ratio=1.000  degradation=+0.0%
# [heading_biased_eval]
# position_rmse: ratio=49.902  degradation=+4890.2%
# rotation_geodesic: ratio=73.047  degradation=+7204.7%
# velocity_rmse: ratio=6.840  degradation=+584.0%
# angular_rmse: ratio=5.146  degradation=+414.6%
# failure_rate: ratio=1.000  degradation=+0.0%
# Running held-out trajectory evaluation...
# Held-out evaluation profile: clean
# Held-out evaluation noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0001 (median 0.0001, p95 0.0001)
# Rotation geo [rad]:  0.0005 (median 0.0005, p95 0.0005)
# Lin vel RMSE [m/s]:  0.0010  Ang vel RMSE [r/s]:  0.0005
# SO(3) violation:  |det-1|=6.07e-08  ||RR^T-I||=1.17e-07
# Noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# [CHIRP] pos=0.0000 m, rot=0.0005 rad, success=1.0000
# [OU] pos=0.0001 m, rot=0.0005 rad, success=1.0000
# [PRBS] pos=0.0001 m, rot=0.0005 rad, success=1.0000
# Held-out evaluation profile: nominal_eval
# Held-out evaluation noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0011 (median 0.0011, p95 0.0014)
# Rotation geo [rad]:  0.0086 (median 0.0086, p95 0.0094)
# Lin vel RMSE [m/s]:  0.0042  Ang vel RMSE [r/s]:  0.0031
# SO(3) violation:  |det-1|=2.93e-07  ||RR^T-I||=6.22e-07
# Noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# [CHIRP] pos=0.0011 m, rot=0.0086 rad, success=1.0000
# [OU] pos=0.0011 m, rot=0.0086 rad, success=1.0000
# [PRBS] pos=0.0011 m, rot=0.0087 rad, success=1.0000
# Held-out evaluation profile: degraded_eval
# Held-out evaluation noise budget: protocol=iid_noisy_ic | profile=degraded_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0026 (median 0.0026, p95 0.0034)
# Rotation geo [rad]:  0.0211 (median 0.0211, p95 0.0230)
# Lin vel RMSE [m/s]:  0.0085  Ang vel RMSE [r/s]:  0.0061
# SO(3) violation:  |det-1|=2.93e-07  ||RR^T-I||=6.23e-07
# Noise budget: protocol=iid_noisy_ic | profile=degraded_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250]
# [CHIRP] pos=0.0025 m, rot=0.0210 rad, success=1.0000
# [OU] pos=0.0025 m, rot=0.0210 rad, success=1.0000
# [PRBS] pos=0.0027 m, rot=0.0212 rad, success=1.0000
# Held-out evaluation profile: heading_biased_eval
# Held-out evaluation noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0040 (median 0.0039, p95 0.0052)
# Rotation geo [rad]:  0.0351 (median 0.0350, p95 0.0364)
# Lin vel RMSE [m/s]:  0.0068  Ang vel RMSE [r/s]:  0.0031
# SO(3) violation:  |det-1|=2.93e-07  ||RR^T-I||=6.22e-07
# Noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ...
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0001 +/- 0.0001  (max 0.0006)
# Rotation geo [rad]:  0.0005 +/- 0.0000  (max 0.0006)
# Lin vel RMSE [m/s]:  0.0017 +/- 0.0012
# Ang vel RMSE [r/s]:  0.0010 +/- 0.0006
# Components:  u=0.0028  v=0.0004  w=0.0003  p=0.0012  q=0.0009  r=0.0006
# SO(3) violation:  |det-1|=6.37e-08  ||RR^T-I||=1.28e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# Block evaluation profile: nominal_eval
# Block evaluation noise budget: protocol=v4_lite | profile=nominal_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0011 +/- 0.0006  (max 0.0039)
# Rotation geo [rad]:  0.0070 +/- 0.0044  (max 0.0255)
# Lin vel RMSE [m/s]:  0.0048 +/- 0.0022
# Ang vel RMSE [r/s]:  0.0032 +/- 0.0020
# Components:  u=0.0058  v=0.0033  w=0.0032  p=0.0050  q=0.0012  r=0.0013
# SO(3) violation:  |det-1|=2.85e-07  ||RR^T-I||=6.26e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=v4_lite | profile=nominal_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# Block evaluation profile: heading_biased_eval
# Block evaluation noise budget: protocol=v4_lite | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0048 +/- 0.0014  (max 0.0092)
# Rotation geo [rad]:  0.0349 +/- 0.0079  (max 0.0604)
# Lin vel RMSE [m/s]:  0.0079 +/- 0.0039
# Ang vel RMSE [r/s]:  0.0032 +/- 0.0020
# Components:  u=0.0076  v=0.0092  w=0.0036  p=0.0050  q=0.0012  r=0.0013
# SO(3) violation:  |det-1|=3.16e-07  ||RR^T-I||=6.80e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=v4_lite | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Block Evaluation Relative To Clean
# ==================================================
# [nominal_eval]
# position_rmse: ratio=7.492  degradation=+649.2%
# rotation_geodesic: ratio=14.221  degradation=+1322.1%
# velocity_rmse: ratio=2.784  degradation=+178.4%
# angular_rmse: ratio=3.086  degradation=+208.6%
# failure_rate: ratio=1.000  degradation=+0.0%
# [heading_biased_eval]
# position_rmse: ratio=32.839  degradation=+3183.9%
# rotation_geodesic: ratio=70.973  degradation=+6997.3%
# velocity_rmse: ratio=4.615  degradation=+361.5%
# angular_rmse: ratio=3.086  degradation=+208.6%
# failure_rate: ratio=1.000  degradation=+0.0%
# Running held-out trajectory evaluation...
# Held-out evaluation profile: clean
# Held-out evaluation noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0001 (median 0.0001, p95 0.0002)
# Rotation geo [rad]:  0.0005 (median 0.0005, p95 0.0005)
# Lin vel RMSE [m/s]:  0.0014  Ang vel RMSE [r/s]:  0.0009
# SO(3) violation:  |det-1|=6.06e-08  ||RR^T-I||=1.17e-07
# Noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# [CHIRP] pos=0.0000 m, rot=0.0005 rad, success=1.0000
# [OU] pos=0.0001 m, rot=0.0005 rad, success=1.0000
# [PRBS] pos=0.0001 m, rot=0.0005 rad, success=1.0000
# Held-out evaluation profile: nominal_eval
# Held-out evaluation noise budget: protocol=v4_lite | profile=nominal_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0011 (median 0.0011, p95 0.0015)
# Rotation geo [rad]:  0.0087 (median 0.0085, p95 0.0109)
# Lin vel RMSE [m/s]:  0.0044  Ang vel RMSE [r/s]:  0.0028
# SO(3) violation:  |det-1|=2.94e-07  ||RR^T-I||=6.25e-07
# Noise budget: protocol=v4_lite | profile=nominal_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# [CHIRP] pos=0.0011 m, rot=0.0089 rad, success=1.0000
# [OU] pos=0.0011 m, rot=0.0087 rad, success=1.0000
# [PRBS] pos=0.0011 m, rot=0.0087 rad, success=1.0000
# Held-out evaluation profile: degraded_eval
# Held-out evaluation noise budget: protocol=v4_lite | profile=degraded_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0026 (median 0.0026, p95 0.0035)
# Rotation geo [rad]:  0.0213 (median 0.0209, p95 0.0268)
# Lin vel RMSE [m/s]:  0.0085  Ang vel RMSE [r/s]:  0.0053
# SO(3) violation:  |det-1|=2.97e-07  ||RR^T-I||=6.33e-07
# Noise budget: protocol=v4_lite | profile=degraded_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250]
# [CHIRP] pos=0.0026 m, rot=0.0217 rad, success=1.0000
# [OU] pos=0.0026 m, rot=0.0212 rad, success=1.0000
# [PRBS] pos=0.0027 m, rot=0.0212 rad, success=1.0000
# Held-out evaluation profile: heading_biased_eval
# Held-out evaluation noise budget: protocol=v4_lite | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0040 (median 0.0039, p95 0.0054)
# Rotation geo [rad]:  0.0352 (median 0.0354, p95 0.0390)
# Lin vel RMSE [m/s]:  0.0069  Ang vel RMSE [r/s]:  0.0028
# SO(3) violation:  |det-1|=2.91e-07  ||RR^T-I||=6.19e-07
# Noise budget: protocol=v4_lite | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# [CHIRP] pos=0.0038 m, rot=0.0345 rad, success=1.0000
# [OU] pos=0.0039 m, rot=0.0352 rad, success=1.0000
# [PRBS] pos=0.0042 m, rot=0.0354 rad, success=1.0000
# ==================================================
# Held-Out Evaluation Relative To Clean
# ==================================================
# [nominal_eval]
# position_rmse: ratio=9.373  degradation=+837.3%
# rotation_geodesic: ratio=17.751  degradation=+1675.1%
# velocity_rmse: ratio=3.146  degradation=+214.6%
# angular_rmse: ratio=3.126  degradation=+212.6%
# success_rate: ratio=1.000  degradation=+0.0%
# trajectory_failure_rate: ratio=1.000  degradation=+0.0%
# [degraded_eval]
# position_rmse: ratio=21.996  degradation=+2099.6%
# rotation_geodesic: ratio=43.406  degradation=+4240.6%
# velocity_rmse: ratio=6.139  degradation=+513.9%
# angular_rmse: ratio=5.922  degradation=+492.2%
# success_rate: ratio=1.000  degradation=+0.0%
# trajectory_failure_rate: ratio=1.000  degradation=+0.0%
# [heading_biased_eval]
# position_rmse: ratio=33.589  degradation=+3258.9%
# rotation_geodesic: ratio=71.668  degradation=+7066.8%
# velocity_rmse: ratio=4.949  degradation=+394.9%
# angular_rmse: ratio=3.126  degradation=+212.6%
# success_rate: ratio=1.000  degradation=+0.0%
# trajectory_failure_rate: ratio=1.000  degradation=+0.0%
#
# Training finished. Results: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_full/main_phnode_full_seed46
# Training sweep complete.
# Manifest: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_full/runs.tsv
# Next step:
#   scripts/batch_eval_models.sh --suite-dir "/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_full"
#
# Training complete.
# Suite directory: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_full
# Next step:
#   bash scripts/eval_all_models_noise_profile.sh --suite-dir "/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_full"
# [audit] /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_phnode_full
# [audit] /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full
# [audit] /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_full
#                                             suite_name group  model_type  seed train_noise_protocol  best_epoch  best_loss  noise_warmup_epochs  noise_ramp_epochs  noise_mix_ratio  epoch_scale_at_best  is_effectively_clean_at_best
#  sweep_oc_phase1a_decision_clean_t2_wpfrag_phnode_full  main phnode_full    42                clean         249   0.004021                   20                 80              0.5                  0.0                          True
#  sweep_oc_phase1a_decision_clean_t2_wpfrag_phnode_full  main phnode_full    43                clean         247   0.004155                   20                 80              0.5                  0.0                          True
#  sweep_oc_phase1a_decision_clean_t2_wpfrag_phnode_full  main phnode_full    44                clean         242   0.004207                   20                 80              0.5                  0.0                          True
#  sweep_oc_phase1a_decision_clean_t2_wpfrag_phnode_full  main phnode_full    45                clean         247   0.004025                   20                 80              0.5                  0.0                          True
#  sweep_oc_phase1a_decision_clean_t2_wpfrag_phnode_full  main phnode_full    46                clean         250   0.004047                   20                 80              0.5                  0.0                          True
#    sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full  main phnode_full    42         iid_noisy_ic         245   0.006216                   20                 80              0.5                  1.0                         False
#    sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full  main phnode_full    43         iid_noisy_ic         234   0.006302                   20                 80              0.5                  1.0                         False
#    sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full  main phnode_full    44         iid_noisy_ic         248   0.006581                   20                 80              0.5                  1.0                         False
#    sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full  main phnode_full    45         iid_noisy_ic         238   0.006221                   20                 80              0.5                  1.0                         False
#    sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full  main phnode_full    46         iid_noisy_ic         250   0.006382                   20                 80              0.5                  1.0                         False
# sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_full  main phnode_full    42              v4_lite         204   0.006297                   20                 80              0.5                  1.0                         False
# sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_full  main phnode_full    43              v4_lite         248   0.006239                   20                 80              0.5                  1.0                         False
# sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_full  main phnode_full    44              v4_lite         245   0.006270                   20                 80              0.5                  1.0                         False
# sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_full  main phnode_full    45              v4_lite         247   0.006427                   20                 80              0.5                  1.0                         False
# sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_full  main phnode_full    46              v4_lite         234   0.006341                   20                 80              0.5                  1.0                         False
# + /usr/bin/python3 /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/scripts/validate_v4_lite_protocol.py --run-dir /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_full/main_phnode_full_seed42
# v4_lite protocol validation saved to: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_full/main_phnode_full_seed42/v4_lite_protocol_validation.json
# overall_passed=True
# same_epoch_stability: passed=True
# epoch_resampling: passed=True
# heading_bias_overlay: passed=True
# [validate] /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_full/main_phnode_full_seed42/v4_lite_protocol_validation.json

# %% [markdown]
# ## 4. Decision rollout eval (each trained suite x 4 robustness profiles)
# Evaluates the clean / iid / v4lite trained suites across `clean nominal_eval degraded_eval heading_biased_eval` (iid eval protocol) plus the `v4_lite` eval at `nominal_eval`.

# %%
os.environ["MODE"] = "decision_eval"
# !bash scripts/run_phase1a_oc_v4lite.sh
# Out:
# Streaming output truncated to the last 5000 lines.
#   H=10.0s | pos median=0.3142 m | pos p95=0.9267 m | rot median=0.0261 rad | total vel median=0.0182 m/s | rel vel median=0.0112 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.9283 m | pos p95=2.3784 m | rot median=0.0160 rad | total vel median=0.0160 m/s | rel vel median=0.0126 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.6905 m | pos p95=5.3843 m | rot median=0.0217 rad | total vel median=0.0153 m/s | rel vel median=0.0173 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.2776 m | pos p95=0.8113 m | rot median=0.0181 rad | total vel median=0.0098 m/s | rel vel median=0.0054 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.7171 m | pos p95=2.2326 m | rot median=0.0166 rad | total vel median=0.0086 m/s | rel vel median=0.0058 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.4908 m | pos p95=4.6278 m | rot median=0.0188 rad | total vel median=0.0109 m/s | rel vel median=0.0091 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=30 | completed=28 (0.933) | gt_divergence=0 (0.000) | pred_divergence=2 (0.067) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.3486 m | pos p95=0.8966 m | rot median=0.0270 rad | total vel median=0.0148 m/s | rel vel median=0.0138 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.9732 m | pos p95=2.8219 m | rot median=0.0213 rad | total vel median=0.0211 m/s | rel vel median=0.0182 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.9878 m | pos p95=6.5680 m | rot median=0.0346 rad | total vel median=0.0230 m/s | rel vel median=0.0160 m/s | cond_n=28/30 | completion=0.933 | gt_fail_by_h=0.000 | model_fail_by_h=0.067
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Earliest rollout failures
#   OU seed=200051 | reason=pred_divergence | sim_time=43.35s | pos=nan m | rot=nan rad | total_vel_violation=0
#   OU seed=200066 | reason=pred_divergence | sim_time=59.15s | pos=nan m | rot=nan rad | total_vel_violation=0
#
# Largest completed terminal errors
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=8.8692 m | rot=0.0859 rad | total_vel_violation=0
#   OU seed=200059 | reason=completed | sim_time=60.00s | pos=7.0475 m | rot=0.1039 rad | total_vel_violation=0
#   OU seed=200056 | reason=completed | sim_time=60.00s | pos=6.8296 m | rot=0.1245 rad | total_vel_violation=0
#   OU seed=200057 | reason=completed | sim_time=60.00s | pos=6.0823 m | rot=0.0839 rad | total_vel_violation=0
#   CHIRP seed=100064 | reason=completed | sim_time=60.00s | pos=5.8352 m | rot=0.0734 rad | total_vel_violation=0
#
# Completed rollouts with velocity violations
#   OU seed=200055 | reason=completed | sim_time=60.00s | pos=1.8228 m | rot=0.0153 rad | total_vel_violation=1
#   OU seed=200061 | reason=completed | sim_time=60.00s | pos=0.8168 m | rot=0.0198 rad | total_vel_violation=1
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# OU seed=200051 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full/main_phnode_full_seed43/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_003617/degraded_eval/diagnostic_plots/rollout_failure_OU_seed200051.png
# OU seed=200066 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full/main_phnode_full_seed43/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_003617/degraded_eval/diagnostic_plots/rollout_failure_OU_seed200066.png
# OU seed=200055 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full/main_phnode_full_seed43/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_003617/degraded_eval/diagnostic_plots/velocity_violation_OU_seed200055.png
# OU seed=200061 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full/main_phnode_full_seed43/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_003617/degraded_eval/diagnostic_plots/velocity_violation_OU_seed200061.png
# PRBS seed=42 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full/main_phnode_full_seed43/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_003617/degraded_eval/diagnostic_plots/high_terminal_error_PRBS_seed42.png
# OU seed=200059 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full/main_phnode_full_seed43/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_003617/degraded_eval/diagnostic_plots/high_terminal_error_OU_seed200059.png
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full/main_phnode_full_seed43/best_model.pt | device=cuda | mode=resampled | noise_profile=heading_biased_eval | noise_protocol=iid_noisy_ic | noise_budget=protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350] | scenarios=PRBS,CHIRP,OU | trajectories=90 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full/main_phnode_full_seed43/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_003617/heading_biased_eval
# [scenario 1/3] PRBS | 30 trajectories
# [1/90] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=32m17.2s
# [5/90] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=6m10.3s
# [10/90] PRBS seed=51 done | reason=completed | sim_time=60.00s | eta=2m54.4s
# [15/90] PRBS seed=56 done | reason=completed | sim_time=60.00s | eta=1m49.1s
# [20/90] PRBS seed=61 done | reason=completed | sim_time=60.00s | eta=1m16.4s
# [25/90] PRBS seed=66 done | reason=completed | sim_time=60.00s | eta=56.8s
# [30/90] PRBS seed=71 done | reason=completed | sim_time=60.00s | eta=43.7s
# [scenario done] PRBS | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=3.1107 m | pos_p95=4.5774 m | rot_med=0.0315 rad | completion=1.000 | elapsed=21.9s
# [scenario 2/3] CHIRP | 30 trajectories
# [31/90] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=1m23.0s
# [35/90] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=1m08.5s
# [40/90] CHIRP seed=100051 done | reason=completed | sim_time=60.00s | eta=54.5s
# [45/90] CHIRP seed=100056 done | reason=completed | sim_time=60.00s | eta=43.6s
# [50/90] CHIRP seed=100061 done | reason=completed | sim_time=60.00s | eta=34.9s
# [55/90] CHIRP seed=100066 done | reason=completed | sim_time=60.00s | eta=27.8s
# [60/90] CHIRP seed=100071 done | reason=completed | sim_time=60.00s | eta=21.8s
# [scenario done] CHIRP | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=3.1226 m | pos_p95=4.5439 m | rot_med=0.0369 rad | completion=1.000 | elapsed=43.7s
# [scenario 3/3] OU | 30 trajectories
# [61/90] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=31.1s
# [65/90] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=25.1s
# [70/90] OU seed=200051 done | reason=pred_divergence | sim_time=43.35s | eta=18.7s
# [75/90] OU seed=200056 done | reason=completed | sim_time=60.00s | eta=13.1s
# [80/90] OU seed=200061 done | reason=completed | sim_time=60.00s | eta=8.2s
# [85/90] OU seed=200066 done | reason=pred_divergence | sim_time=59.15s | eta=3.8s
# [90/90] OU seed=200071 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=28/30 | gt_div=0 | model_fail=2 | H=60.0s cond_n=28/30 | pos_med=3.2933 m | pos_p95=6.0256 m | rot_med=0.0566 rad | completion=0.933 | elapsed=1m05.5s
# Benchmark finished in 1m23.6s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full/main_phnode_full_seed43/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_003617/heading_biased_eval
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full/main_phnode_full_seed43/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: pH NODE Full [main/core]
# Canonical model type: phnode_full
# Energy semantics: mechanical_energy
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 30
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.4785 m | pos p95=0.8523 m | rot median=0.0364 rad | total vel median=0.0163 m/s | rel vel median=0.0094 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=1.5063 m | pos p95=2.6491 m | rot median=0.0367 rad | total vel median=0.0171 m/s | rel vel median=0.0092 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=3.1413 m | pos p95=5.6179 m | rot median=0.0392 rad | total vel median=0.0178 m/s | rel vel median=0.0137 m/s | cond_n=88/90 | completion=0.978 | gt_fail_by_h=0.000 | model_fail_by_h=0.022
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=90 | completed=88 (0.978) | gt_divergence=0 (0.000) | pred_divergence=2 (0.022) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.4236 m | pos p95=0.8184 m | rot median=0.0361 rad | total vel median=0.0199 m/s | rel vel median=0.0111 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.4719 m | pos p95=2.5988 m | rot median=0.0357 rad | total vel median=0.0192 m/s | rel vel median=0.0123 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=3.1107 m | pos p95=4.5774 m | rot median=0.0315 rad | total vel median=0.0174 m/s | rel vel median=0.0173 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.4598 m | pos p95=0.7328 m | rot median=0.0350 rad | total vel median=0.0123 m/s | rel vel median=0.0056 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.5063 m | pos p95=2.0731 m | rot median=0.0357 rad | total vel median=0.0127 m/s | rel vel median=0.0058 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=3.1226 m | pos p95=4.5439 m | rot median=0.0369 rad | total vel median=0.0137 m/s | rel vel median=0.0091 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=30 | completed=28 (0.933) | gt_divergence=0 (0.000) | pred_divergence=2 (0.067) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.5340 m | pos p95=1.0082 m | rot median=0.0411 rad | total vel median=0.0152 m/s | rel vel median=0.0132 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.5051 m | pos p95=3.0605 m | rot median=0.0461 rad | total vel median=0.0246 m/s | rel vel median=0.0188 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=3.2933 m | pos p95=6.0256 m | rot median=0.0566 rad | total vel median=0.0255 m/s | rel vel median=0.0154 m/s | cond_n=28/30 | completion=0.933 | gt_fail_by_h=0.000 | model_fail_by_h=0.067
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Earliest rollout failures
#   OU seed=200051 | reason=pred_divergence | sim_time=43.35s | pos=nan m | rot=nan rad | total_vel_violation=0
#   OU seed=200066 | reason=pred_divergence | sim_time=59.15s | pos=nan m | rot=nan rad | total_vel_violation=0
#
# Largest completed terminal errors
#   OU seed=200057 | reason=completed | sim_time=60.00s | pos=6.8135 m | rot=0.0945 rad | total_vel_violation=0
#   OU seed=200048 | reason=completed | sim_time=60.00s | pos=6.0258 m | rot=0.0889 rad | total_vel_violation=0
#   OU seed=200071 | reason=completed | sim_time=60.00s | pos=6.0253 m | rot=0.0672 rad | total_vel_violation=0
#   OU seed=200068 | reason=completed | sim_time=60.00s | pos=5.8636 m | rot=0.0896 rad | total_vel_violation=0
#   PRBS seed=62 | reason=completed | sim_time=60.00s | pos=5.7559 m | rot=0.0422 rad | total_vel_violation=0
#
# Completed rollouts with velocity violations
#   OU seed=200061 | reason=completed | sim_time=60.00s | pos=3.2823 m | rot=0.0458 rad | total_vel_violation=1
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# OU seed=200051 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full/main_phnode_full_seed43/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_003617/heading_biased_eval/diagnostic_plots/rollout_failure_OU_seed200051.png
# OU seed=200066 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full/main_phnode_full_seed43/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_003617/heading_biased_eval/diagnostic_plots/rollout_failure_OU_seed200066.png
# OU seed=200061 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full/main_phnode_full_seed43/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_003617/heading_biased_eval/diagnostic_plots/velocity_violation_OU_seed200061.png
# OU seed=200057 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full/main_phnode_full_seed43/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_003617/heading_biased_eval/diagnostic_plots/high_terminal_error_OU_seed200057.png
# OU seed=200048 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full/main_phnode_full_seed43/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_003617/heading_biased_eval/diagnostic_plots/high_terminal_error_OU_seed200048.png
# OU seed=200071 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full/main_phnode_full_seed43/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_003617/heading_biased_eval/diagnostic_plots/high_terminal_error_OU_seed200071.png
# [eval] main_phnode_full_seed44
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full/main_phnode_full_seed44/best_model.pt | device=cuda | mode=resampled | noise_profile=clean | noise_protocol=clean | noise_budget=protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000] | scenarios=PRBS,CHIRP,OU | trajectories=90 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full/main_phnode_full_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_005155/clean
# [scenario 1/3] PRBS | 30 trajectories
# [1/90] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=5h31m39.1s
# [5/90] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=1h03m21.2s
# [10/90] PRBS seed=51 done | reason=completed | sim_time=60.00s | eta=29m48.9s
# [15/90] PRBS seed=56 done | reason=completed | sim_time=60.00s | eta=18m38.1s
# [20/90] PRBS seed=61 done | reason=completed | sim_time=60.00s | eta=13m02.7s
# [25/90] PRBS seed=66 done | reason=completed | sim_time=60.00s | eta=9m41.5s
# [30/90] PRBS seed=71 done | reason=completed | sim_time=60.00s | eta=7m27.3s
# [scenario done] PRBS | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=1.5803 m | pos_p95=3.2958 m | rot_med=0.0437 rad | completion=1.000 | elapsed=3m43.7s
# [scenario 2/3] CHIRP | 30 trajectories
# [31/90] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=14m13.5s
# [35/90] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=11m44.7s
# [40/90] CHIRP seed=100051 done | reason=completed | sim_time=60.00s | eta=9m20.6s
# [45/90] CHIRP seed=100056 done | reason=completed | sim_time=60.00s | eta=7m28.5s
# [50/90] CHIRP seed=100061 done | reason=completed | sim_time=60.00s | eta=5m58.8s
# [55/90] CHIRP seed=100066 done | reason=completed | sim_time=60.00s | eta=4m45.4s
# [60/90] CHIRP seed=100071 done | reason=completed | sim_time=60.00s | eta=3m44.3s
# [scenario done] CHIRP | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=0.5549 m | pos_p95=1.0961 m | rot_med=0.0114 rad | completion=1.000 | elapsed=7m28.6s
# [scenario 3/3] OU | 30 trajectories
# [61/90] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=5m20.7s
# [65/90] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=4m19.5s
# [70/90] OU seed=200051 done | reason=completed | sim_time=60.00s | eta=3m12.7s
# [75/90] OU seed=200056 done | reason=completed | sim_time=60.00s | eta=2m14.9s
# [80/90] OU seed=200061 done | reason=completed | sim_time=60.00s | eta=1m24.3s
# [85/90] OU seed=200066 done | reason=pred_divergence | sim_time=59.35s | eta=39.7s
# [90/90] OU seed=200071 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=29/30 | gt_div=0 | model_fail=1 | H=60.0s cond_n=29/30 | pos_med=1.4232 m | pos_p95=2.6398 m | rot_med=0.0324 rad | completion=0.967 | elapsed=11m14.7s
# Benchmark finished in 11m33.8s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full/main_phnode_full_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_005155/clean
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full/main_phnode_full_seed44/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: pH NODE Full [main/core]
# Canonical model type: phnode_full
# Energy semantics: mechanical_energy
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 30
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.1131 m | pos p95=0.2813 m | rot median=0.0118 rad | total vel median=0.0111 m/s | rel vel median=0.0110 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=0.3995 m | pos p95=0.9422 m | rot median=0.0161 rad | total vel median=0.0109 m/s | rel vel median=0.0094 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=1.0708 m | pos p95=2.8822 m | rot median=0.0286 rad | total vel median=0.0155 m/s | rel vel median=0.0123 m/s | cond_n=89/90 | completion=0.989 | gt_fail_by_h=0.000 | model_fail_by_h=0.011
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=90 | completed=89 (0.989) | gt_divergence=0 (0.000) | pred_divergence=1 (0.011) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.0998 m | pos p95=0.2744 m | rot median=0.0100 rad | total vel median=0.0114 m/s | rel vel median=0.0149 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.4475 m | pos p95=0.9422 m | rot median=0.0173 rad | total vel median=0.0138 m/s | rel vel median=0.0129 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.5803 m | pos p95=3.2958 m | rot median=0.0437 rad | total vel median=0.0173 m/s | rel vel median=0.0135 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1065 m | pos p95=0.1555 m | rot median=0.0124 rad | total vel median=0.0080 m/s | rel vel median=0.0072 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.2403 m | pos p95=0.5105 m | rot median=0.0115 rad | total vel median=0.0081 m/s | rel vel median=0.0073 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=0.5549 m | pos p95=1.0961 m | rot median=0.0114 rad | total vel median=0.0078 m/s | rel vel median=0.0090 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=30 | completed=29 (0.967) | gt_divergence=0 (0.000) | pred_divergence=1 (0.033) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1496 m | pos p95=0.3039 m | rot median=0.0138 rad | total vel median=0.0154 m/s | rel vel median=0.0144 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.5319 m | pos p95=0.9735 m | rot median=0.0217 rad | total vel median=0.0166 m/s | rel vel median=0.0129 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.4232 m | pos p95=2.6398 m | rot median=0.0324 rad | total vel median=0.0270 m/s | rel vel median=0.0183 m/s | cond_n=29/30 | completion=0.967 | gt_fail_by_h=0.000 | model_fail_by_h=0.033
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Earliest rollout failures
#   OU seed=200066 | reason=pred_divergence | sim_time=59.35s | pos=nan m | rot=nan rad | total_vel_violation=0
#
# Largest completed terminal errors
#   PRBS seed=59 | reason=completed | sim_time=60.00s | pos=4.1691 m | rot=0.0789 rad | total_vel_violation=0
#   PRBS seed=61 | reason=completed | sim_time=60.00s | pos=3.5562 m | rot=0.0641 rad | total_vel_violation=0
#   PRBS seed=62 | reason=completed | sim_time=60.00s | pos=2.9777 m | rot=0.0451 rad | total_vel_violation=0
#   PRBS seed=50 | reason=completed | sim_time=60.00s | pos=2.9749 m | rot=0.0529 rad | total_vel_violation=0
#   PRBS seed=68 | reason=completed | sim_time=60.00s | pos=2.9220 m | rot=0.0500 rad | total_vel_violation=0
#
# Completed rollouts with velocity violations
#   OU seed=200055 | reason=completed | sim_time=60.00s | pos=2.5643 m | rot=0.0571 rad | total_vel_violation=1
#   OU seed=200061 | reason=completed | sim_time=60.00s | pos=1.2499 m | rot=0.0356 rad | total_vel_violation=1
#   OU seed=200068 | reason=completed | sim_time=60.00s | pos=1.0024 m | rot=0.0114 rad | total_vel_violation=1
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# OU seed=200066 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full/main_phnode_full_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_005155/clean/diagnostic_plots/rollout_failure_OU_seed200066.png
# OU seed=200055 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full/main_phnode_full_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_005155/clean/diagnostic_plots/velocity_violation_OU_seed200055.png
# OU seed=200061 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full/main_phnode_full_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_005155/clean/diagnostic_plots/velocity_violation_OU_seed200061.png
# OU seed=200068 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full/main_phnode_full_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_005155/clean/diagnostic_plots/velocity_violation_OU_seed200068.png
# PRBS seed=59 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full/main_phnode_full_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_005155/clean/diagnostic_plots/high_terminal_error_PRBS_seed59.png
# PRBS seed=61 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full/main_phnode_full_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_005155/clean/diagnostic_plots/high_terminal_error_PRBS_seed61.png
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full/main_phnode_full_seed44/best_model.pt | device=cuda | mode=resampled | noise_profile=nominal_eval | noise_protocol=iid_noisy_ic | noise_budget=protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | scenarios=PRBS,CHIRP,OU | trajectories=90 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full/main_phnode_full_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_005155/nominal_eval
# [scenario 1/3] PRBS | 30 trajectories
# [1/90] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=32m08.5s
# [5/90] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=6m08.6s
# [10/90] PRBS seed=51 done | reason=completed | sim_time=60.00s | eta=2m53.6s
# [15/90] PRBS seed=56 done | reason=completed | sim_time=60.00s | eta=1m48.6s
# [20/90] PRBS seed=61 done | reason=completed | sim_time=60.00s | eta=1m16.1s
# [25/90] PRBS seed=66 done | reason=completed | sim_time=60.00s | eta=56.5s
# [30/90] PRBS seed=71 done | reason=completed | sim_time=60.00s | eta=43.5s
# [scenario done] PRBS | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=1.7239 m | pos_p95=4.5567 m | rot_med=0.0438 rad | completion=1.000 | elapsed=21.8s
# [scenario 2/3] CHIRP | 30 trajectories
# [31/90] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=1m22.3s
# [35/90] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=1m08.0s
# [40/90] CHIRP seed=100051 done | reason=completed | sim_time=60.00s | eta=54.1s
# [45/90] CHIRP seed=100056 done | reason=completed | sim_time=60.00s | eta=43.3s
# [50/90] CHIRP seed=100061 done | reason=completed | sim_time=60.00s | eta=34.7s
# [55/90] CHIRP seed=100066 done | reason=completed | sim_time=60.00s | eta=27.6s
# [60/90] CHIRP seed=100071 done | reason=completed | sim_time=60.00s | eta=21.7s
# [scenario done] CHIRP | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=0.8976 m | pos_p95=1.9862 m | rot_med=0.0132 rad | completion=1.000 | elapsed=43.4s
# [scenario 3/3] OU | 30 trajectories
# [61/90] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=30.9s
# [65/90] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=25.0s
# [70/90] OU seed=200051 done | reason=completed | sim_time=60.00s | eta=18.6s
# [75/90] OU seed=200056 done | reason=completed | sim_time=60.00s | eta=13.0s
# [80/90] OU seed=200061 done | reason=completed | sim_time=60.00s | eta=8.1s
# [85/90] OU seed=200066 done | reason=pred_divergence | sim_time=59.35s | eta=3.8s
# [90/90] OU seed=200071 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=29/30 | gt_div=0 | model_fail=1 | H=60.0s cond_n=29/30 | pos_med=1.1942 m | pos_p95=3.1747 m | rot_med=0.0340 rad | completion=0.967 | elapsed=1m05.2s
# Benchmark finished in 1m23.7s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full/main_phnode_full_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_005155/nominal_eval
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full/main_phnode_full_seed44/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: pH NODE Full [main/core]
# Canonical model type: phnode_full
# Energy semantics: mechanical_energy
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 30
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.1720 m | pos p95=0.4384 m | rot median=0.0142 rad | total vel median=0.0120 m/s | rel vel median=0.0110 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=0.4948 m | pos p95=1.3251 m | rot median=0.0170 rad | total vel median=0.0118 m/s | rel vel median=0.0094 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=1.1830 m | pos p95=3.3477 m | rot median=0.0294 rad | total vel median=0.0157 m/s | rel vel median=0.0122 m/s | cond_n=89/90 | completion=0.989 | gt_fail_by_h=0.000 | model_fail_by_h=0.011
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=90 | completed=89 (0.989) | gt_divergence=0 (0.000) | pred_divergence=1 (0.011) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1810 m | pos p95=0.4239 m | rot median=0.0111 rad | total vel median=0.0126 m/s | rel vel median=0.0150 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.5288 m | pos p95=1.4709 m | rot median=0.0225 rad | total vel median=0.0143 m/s | rel vel median=0.0127 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.7239 m | pos p95=4.5567 m | rot median=0.0438 rad | total vel median=0.0171 m/s | rel vel median=0.0139 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1504 m | pos p95=0.3365 m | rot median=0.0136 rad | total vel median=0.0080 m/s | rel vel median=0.0072 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.4189 m | pos p95=0.9823 m | rot median=0.0127 rad | total vel median=0.0080 m/s | rel vel median=0.0073 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=0.8976 m | pos p95=1.9862 m | rot median=0.0132 rad | total vel median=0.0082 m/s | rel vel median=0.0090 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=30 | completed=29 (0.967) | gt_divergence=0 (0.000) | pred_divergence=1 (0.033) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.2078 m | pos p95=0.4931 m | rot median=0.0168 rad | total vel median=0.0149 m/s | rel vel median=0.0144 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.5497 m | pos p95=1.4244 m | rot median=0.0254 rad | total vel median=0.0166 m/s | rel vel median=0.0130 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.1942 m | pos p95=3.1747 m | rot median=0.0340 rad | total vel median=0.0272 m/s | rel vel median=0.0183 m/s | cond_n=29/30 | completion=0.967 | gt_fail_by_h=0.000 | model_fail_by_h=0.033
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Earliest rollout failures
#   OU seed=200066 | reason=pred_divergence | sim_time=59.35s | pos=nan m | rot=nan rad | total_vel_violation=0
#
# Largest completed terminal errors
#   PRBS seed=62 | reason=completed | sim_time=60.00s | pos=5.2536 m | rot=0.0636 rad | total_vel_violation=0
#   PRBS seed=68 | reason=completed | sim_time=60.00s | pos=4.7984 m | rot=0.0654 rad | total_vel_violation=0
#   PRBS seed=59 | reason=completed | sim_time=60.00s | pos=4.2613 m | rot=0.0797 rad | total_vel_violation=0
#   OU seed=200056 | reason=completed | sim_time=60.00s | pos=4.1842 m | rot=0.0841 rad | total_vel_violation=0
#   PRBS seed=53 | reason=completed | sim_time=60.00s | pos=3.4125 m | rot=0.0741 rad | total_vel_violation=0
#
# Completed rollouts with velocity violations
#   OU seed=200055 | reason=completed | sim_time=60.00s | pos=1.6380 m | rot=0.0468 rad | total_vel_violation=1
#   OU seed=200061 | reason=completed | sim_time=60.00s | pos=0.9844 m | rot=0.0398 rad | total_vel_violation=1
#   OU seed=200068 | reason=completed | sim_time=60.00s | pos=0.8657 m | rot=0.0090 rad | total_vel_violation=1
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# OU seed=200066 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full/main_phnode_full_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_005155/nominal_eval/diagnostic_plots/rollout_failure_OU_seed200066.png
# OU seed=200055 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full/main_phnode_full_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_005155/nominal_eval/diagnostic_plots/velocity_violation_OU_seed200055.png
# OU seed=200061 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full/main_phnode_full_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_005155/nominal_eval/diagnostic_plots/velocity_violation_OU_seed200061.png
# OU seed=200068 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full/main_phnode_full_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_005155/nominal_eval/diagnostic_plots/velocity_violation_OU_seed200068.png
# PRBS seed=62 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full/main_phnode_full_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_005155/nominal_eval/diagnostic_plots/high_terminal_error_PRBS_seed62.png
# PRBS seed=68 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full/main_phnode_full_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_005155/nominal_eval/diagnostic_plots/high_terminal_error_PRBS_seed68.png
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full/main_phnode_full_seed44/best_model.pt | device=cuda | mode=resampled | noise_profile=degraded_eval | noise_protocol=iid_noisy_ic | noise_budget=protocol=iid_noisy_ic | profile=degraded_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250] | scenarios=PRBS,CHIRP,OU | trajectories=90 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full/main_phnode_full_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_005155/degraded_eval
# [scenario 1/3] PRBS | 30 trajectories
# [1/90] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=32m02.9s
# [5/90] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=6m07.5s
# [10/90] PRBS seed=51 done | reason=completed | sim_time=60.00s | eta=2m53.1s
# [15/90] PRBS seed=56 done | reason=completed | sim_time=60.00s | eta=1m48.2s
# [20/90] PRBS seed=61 done | reason=completed | sim_time=60.00s | eta=1m15.8s
# [25/90] PRBS seed=66 done | reason=completed | sim_time=60.00s | eta=56.4s
# [30/90] PRBS seed=71 done | reason=completed | sim_time=60.00s | eta=43.4s
# [scenario done] PRBS | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=2.1317 m | pos_p95=6.4846 m | rot_med=0.0435 rad | completion=1.000 | elapsed=21.7s
# [scenario 2/3] CHIRP | 30 trajectories
# [31/90] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=1m22.4s
# [35/90] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=1m08.1s
# [40/90] CHIRP seed=100051 done | reason=completed | sim_time=60.00s | eta=54.2s
# [45/90] CHIRP seed=100056 done | reason=completed | sim_time=60.00s | eta=43.4s
# [50/90] CHIRP seed=100061 done | reason=completed | sim_time=60.00s | eta=34.7s
# [55/90] CHIRP seed=100066 done | reason=completed | sim_time=60.00s | eta=27.6s
# [60/90] CHIRP seed=100071 done | reason=completed | sim_time=60.00s | eta=21.7s
# [scenario done] CHIRP | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=1.5991 m | pos_p95=4.4677 m | rot_med=0.0183 rad | completion=1.000 | elapsed=43.5s
# [scenario 3/3] OU | 30 trajectories
# [61/90] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=30.9s
# [65/90] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=25.0s
# [70/90] OU seed=200051 done | reason=completed | sim_time=60.00s | eta=18.6s
# [75/90] OU seed=200056 done | reason=completed | sim_time=60.00s | eta=13.0s
# [80/90] OU seed=200061 done | reason=completed | sim_time=60.00s | eta=8.1s
# [85/90] OU seed=200066 done | reason=pred_divergence | sim_time=59.35s | eta=3.8s
# [90/90] OU seed=200071 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=29/30 | gt_div=0 | model_fail=1 | H=60.0s cond_n=29/30 | pos_med=1.7163 m | pos_p95=5.8020 m | rot_med=0.0441 rad | completion=0.967 | elapsed=1m05.0s
# Benchmark finished in 1m23.6s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full/main_phnode_full_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_005155/degraded_eval
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_full/main_phnode_full_seed44/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: pH NODE Full [main/core]
# Canonical model type: phnode_full
# Energy semantics: mechanical_energy
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 30
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.2921 m | pos p95=0.9340 m | rot median=0.0239 rad | total vel median=0.0130 m/s | rel vel median=0.0110 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=0.8446 m | pos p95=2.7042 m | rot median=0.0235 rad | total vel median=0.0153 m/s | rel vel median=0.0095 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=1.7910 m | pos p95=5.3199 m | rot median=0.0377 rad | total vel median=0.0156 m/s | rel vel median=0.0122 m/s | cond_n=89/90 | completion=0.989 | gt_fail_by_h=0.000 | model_fail_by_h=0.011
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=90 | completed=89 (0.989) | gt_divergence=0 (0.000) | pred_divergence=1 (0.011) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.2841 m | pos p95=0.9294 m | rot median=0.0209 rad | total vel median=0.0175 m/s | rel vel median=0.0153 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.8550 m | pos p95=2.9891 m | rot median=0.0254 rad | total vel median=0.0186 m/s | rel vel median=0.0125 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=2.1317 m | pos p95=6.4846 m | rot median=0.0435 rad | total vel median=0.0182 m/s | rel vel median=0.0143 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.2767 m | pos p95=0.7990 m | rot median=0.0185 rad | total vel median=0.0101 m/s | rel vel median=0.0071 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.7575 m | pos p95=2.1848 m | rot median=0.0181 rad | total vel median=0.0087 m/s | rel vel median=0.0072 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.5991 m | pos p95=4.4677 m | rot median=0.0183 rad | total vel median=0.0097 m/s | rel vel median=0.0089 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=30 | completed=29 (0.967) | gt_divergence=0 (0.000) | pred_divergence=1 (0.033) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.3465 m | pos p95=0.9340 m | rot median=0.0277 rad | total vel median=0.0166 m/s | rel vel median=0.0144 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.0287 m | pos p95=2.7042 m | rot median=0.0296 rad | total vel median=0.0190 m/s | rel vel median=0.0131 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.7163 m | pos p95=5.8020 m | rot median=0.0441 rad | total vel median=0.0269 m/s | rel vel median=0.0182 m/s | cond_n=29/30 | completion=0.967 | gt_fail_by_h=0.000 | model_fail_by_h=0.033
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Earliest rollout failures
#   OU seed=200066 | reason=pred_divergence | sim_time=59.35s | pos=nan m | rot=nan rad | total_vel_violation=0
#
# Largest completed terminal errors
#   PRBS seed=62 | reason=completed | sim_time=60.00s | pos=8.7284 m | rot=0.0936 rad | total_vel_violation=0
#   OU seed=200056 | reason=completed | sim_time=60.00s | pos=7.7022 m | rot=0.1355 rad | total_vel_violation=0
#   PRBS seed=68 | reason=completed | sim_time=60.00s | pos=7.6707 m | rot=0.0889 rad | total_vel_violation=0
#   OU seed=200059 | reason=completed | sim_time=60.00s | pos=6.0595 m | rot=0.0834 rad | total_vel_violation=0
#   OU seed=200060 | reason=completed | sim_time=60.00s | pos=5.4157 m | rot=0.0512 rad | total_vel_violation=0
#
# Completed rollouts with velocity violations
#   OU seed=200061 | reason=completed | sim_time=60.00s | pos=0.8874 m | rot=0.0465 rad | total_vel_violation=1
#   OU seed=200055 | reason=completed | sim_time=60.00s | pos=0.8593 m | rot=0.0338 rad | total_vel_violation=1
#   OU seed=200068 | reason=completed | sim_time=60.00s | pos=0.7838 m | rot=0.0062 rad | total_vel_violation=1
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# ...
#   H=60.0s | pos median=1.2643 m | pos p95=2.5532 m | rot median=0.0270 rad | total vel median=0.0154 m/s | rel vel median=0.0149 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1565 m | pos p95=0.3337 m | rot median=0.0120 rad | total vel median=0.0078 m/s | rel vel median=0.0060 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.5112 m | pos p95=1.0414 m | rot median=0.0128 rad | total vel median=0.0065 m/s | rel vel median=0.0059 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.1421 m | pos p95=2.6566 m | rot median=0.0333 rad | total vel median=0.0091 m/s | rel vel median=0.0087 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=30 | completed=28 (0.933) | gt_divergence=0 (0.000) | pred_divergence=2 (0.067) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1432 m | pos p95=0.2895 m | rot median=0.0120 rad | total vel median=0.0162 m/s | rel vel median=0.0152 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.4857 m | pos p95=1.2127 m | rot median=0.0217 rad | total vel median=0.0176 m/s | rel vel median=0.0155 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.1197 m | pos p95=3.1583 m | rot median=0.0301 rad | total vel median=0.0148 m/s | rel vel median=0.0173 m/s | cond_n=28/30 | completion=0.933 | gt_fail_by_h=0.000 | model_fail_by_h=0.067
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Earliest rollout failures
#   OU seed=200051 | reason=pred_divergence | sim_time=42.75s | pos=nan m | rot=nan rad | total_vel_violation=0
#   OU seed=200066 | reason=pred_divergence | sim_time=58.55s | pos=nan m | rot=nan rad | total_vel_violation=0
#
# Largest completed terminal errors
#   OU seed=200058 | reason=completed | sim_time=60.00s | pos=4.3820 m | rot=0.1024 rad | total_vel_violation=0
#   PRBS seed=61 | reason=completed | sim_time=60.00s | pos=3.6007 m | rot=0.0489 rad | total_vel_violation=0
#   OU seed=200059 | reason=completed | sim_time=60.00s | pos=3.2546 m | rot=0.0611 rad | total_vel_violation=0
#   CHIRP seed=100066 | reason=completed | sim_time=60.00s | pos=3.1195 m | rot=0.0540 rad | total_vel_violation=0
#   OU seed=200070 | reason=completed | sim_time=60.00s | pos=2.9794 m | rot=0.0465 rad | total_vel_violation=0
#
# Completed rollouts with velocity violations
#   OU seed=200061 | reason=completed | sim_time=60.00s | pos=2.6731 m | rot=0.0328 rad | total_vel_violation=1
#   OU seed=200055 | reason=completed | sim_time=60.00s | pos=0.2156 m | rot=0.0103 rad | total_vel_violation=1
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# OU seed=200051 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_full/main_phnode_full_seed45/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260524_031631/diagnostic_plots/rollout_failure_OU_seed200051.png
# OU seed=200066 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_full/main_phnode_full_seed45/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260524_031631/diagnostic_plots/rollout_failure_OU_seed200066.png
# OU seed=200061 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_full/main_phnode_full_seed45/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260524_031631/diagnostic_plots/velocity_violation_OU_seed200061.png
# OU seed=200055 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_full/main_phnode_full_seed45/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260524_031631/diagnostic_plots/velocity_violation_OU_seed200055.png
# OU seed=200058 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_full/main_phnode_full_seed45/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260524_031631/diagnostic_plots/high_terminal_error_OU_seed200058.png
# PRBS seed=61 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_full/main_phnode_full_seed45/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260524_031631/diagnostic_plots/high_terminal_error_PRBS_seed61.png
# [eval] main_phnode_full_seed46
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_full/main_phnode_full_seed46/best_model.pt | device=cuda | mode=resampled | noise_profile=nominal_eval | noise_protocol=v4_lite | noise_budget=protocol=v4_lite | profile=nominal_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | scenarios=PRBS,CHIRP,OU | trajectories=90 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_full/main_phnode_full_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260524_031756
# [scenario 1/3] PRBS | 30 trajectories
# [1/90] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=31m55.8s
# [5/90] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=6m06.1s
# [10/90] PRBS seed=51 done | reason=completed | sim_time=60.00s | eta=2m52.4s
# [15/90] PRBS seed=56 done | reason=completed | sim_time=60.00s | eta=1m47.8s
# [20/90] PRBS seed=61 done | reason=completed | sim_time=60.00s | eta=1m15.5s
# [25/90] PRBS seed=66 done | reason=completed | sim_time=60.00s | eta=56.2s
# [30/90] PRBS seed=71 done | reason=completed | sim_time=60.00s | eta=43.2s
# [scenario done] PRBS | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=1.4493 m | pos_p95=2.8403 m | rot_med=0.0271 rad | completion=1.000 | elapsed=21.6s
# [scenario 2/3] CHIRP | 30 trajectories
# [31/90] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=1m21.3s
# [35/90] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=1m07.2s
# [40/90] CHIRP seed=100051 done | reason=completed | sim_time=60.00s | eta=53.5s
# [45/90] CHIRP seed=100056 done | reason=completed | sim_time=60.00s | eta=42.8s
# [50/90] CHIRP seed=100061 done | reason=completed | sim_time=60.00s | eta=34.2s
# [55/90] CHIRP seed=100066 done | reason=completed | sim_time=60.00s | eta=27.2s
# [60/90] CHIRP seed=100071 done | reason=completed | sim_time=60.00s | eta=21.4s
# [scenario done] CHIRP | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=1.5665 m | pos_p95=2.6671 m | rot_med=0.0280 rad | completion=1.000 | elapsed=42.9s
# [scenario 3/3] OU | 30 trajectories
# [61/90] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=30.4s
# [65/90] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=24.6s
# [70/90] OU seed=200051 done | reason=pred_divergence | sim_time=42.95s | eta=18.3s
# [75/90] OU seed=200056 done | reason=completed | sim_time=60.00s | eta=12.8s
# [80/90] OU seed=200061 done | reason=completed | sim_time=60.00s | eta=8.0s
# [85/90] OU seed=200066 done | reason=pred_divergence | sim_time=58.35s | eta=3.8s
# [90/90] OU seed=200071 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=28/30 | gt_div=0 | model_fail=2 | H=60.0s cond_n=28/30 | pos_med=1.0375 m | pos_p95=3.1549 m | rot_med=0.0265 rad | completion=0.933 | elapsed=1m04.2s
# Benchmark finished in 1m23.2s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_full/main_phnode_full_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260524_031756
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_full/main_phnode_full_seed46/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: pH NODE Full [main/core]
# Canonical model type: phnode_full
# Energy semantics: mechanical_energy
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 30
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.1582 m | pos p95=0.3548 m | rot median=0.0119 rad | total vel median=0.0123 m/s | rel vel median=0.0118 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=0.5225 m | pos p95=1.0334 m | rot median=0.0176 rad | total vel median=0.0132 m/s | rel vel median=0.0099 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=1.2890 m | pos p95=2.9396 m | rot median=0.0277 rad | total vel median=0.0154 m/s | rel vel median=0.0124 m/s | cond_n=88/90 | completion=0.978 | gt_fail_by_h=0.000 | model_fail_by_h=0.022
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=90 | completed=88 (0.978) | gt_divergence=0 (0.000) | pred_divergence=2 (0.022) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1702 m | pos p95=0.3548 m | rot median=0.0091 rad | total vel median=0.0147 m/s | rel vel median=0.0149 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.6195 m | pos p95=0.9786 m | rot median=0.0131 rad | total vel median=0.0153 m/s | rel vel median=0.0134 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.4493 m | pos p95=2.8403 m | rot median=0.0271 rad | total vel median=0.0143 m/s | rel vel median=0.0148 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1520 m | pos p95=0.2970 m | rot median=0.0119 rad | total vel median=0.0092 m/s | rel vel median=0.0089 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.5156 m | pos p95=0.9826 m | rot median=0.0168 rad | total vel median=0.0095 m/s | rel vel median=0.0073 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.5665 m | pos p95=2.6671 m | rot median=0.0280 rad | total vel median=0.0097 m/s | rel vel median=0.0111 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=30 | completed=28 (0.933) | gt_divergence=0 (0.000) | pred_divergence=2 (0.067) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1621 m | pos p95=0.3875 m | rot median=0.0145 rad | total vel median=0.0183 m/s | rel vel median=0.0165 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.4995 m | pos p95=1.1713 m | rot median=0.0199 rad | total vel median=0.0158 m/s | rel vel median=0.0145 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.0375 m | pos p95=3.1549 m | rot median=0.0265 rad | total vel median=0.0261 m/s | rel vel median=0.0214 m/s | cond_n=28/30 | completion=0.933 | gt_fail_by_h=0.000 | model_fail_by_h=0.067
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Earliest rollout failures
#   OU seed=200051 | reason=pred_divergence | sim_time=42.95s | pos=nan m | rot=nan rad | total_vel_violation=0
#   OU seed=200066 | reason=pred_divergence | sim_time=58.35s | pos=nan m | rot=nan rad | total_vel_violation=0
#
# Largest completed terminal errors
#   OU seed=200059 | reason=completed | sim_time=60.00s | pos=3.5859 m | rot=0.0622 rad | total_vel_violation=0
#   PRBS seed=46 | reason=completed | sim_time=60.00s | pos=3.4260 m | rot=0.0480 rad | total_vel_violation=0
#   OU seed=200062 | reason=completed | sim_time=60.00s | pos=3.2605 m | rot=0.0545 rad | total_vel_violation=0
#   CHIRP seed=100064 | reason=completed | sim_time=60.00s | pos=3.0088 m | rot=0.0555 rad | total_vel_violation=0
#   OU seed=200045 | reason=completed | sim_time=60.00s | pos=2.9587 m | rot=0.0732 rad | total_vel_violation=0
#
# Completed rollouts with velocity violations
#   OU seed=200055 | reason=completed | sim_time=60.00s | pos=0.7703 m | rot=0.0049 rad | total_vel_violation=1
#   OU seed=200061 | reason=completed | sim_time=60.00s | pos=0.7555 m | rot=0.0075 rad | total_vel_violation=1
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# OU seed=200051 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_full/main_phnode_full_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260524_031756/diagnostic_plots/rollout_failure_OU_seed200051.png
# OU seed=200066 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_full/main_phnode_full_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260524_031756/diagnostic_plots/rollout_failure_OU_seed200066.png
# OU seed=200055 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_full/main_phnode_full_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260524_031756/diagnostic_plots/velocity_violation_OU_seed200055.png
# OU seed=200061 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_full/main_phnode_full_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260524_031756/diagnostic_plots/velocity_violation_OU_seed200061.png
# OU seed=200059 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_full/main_phnode_full_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260524_031756/diagnostic_plots/high_terminal_error_OU_seed200059.png
# PRBS seed=46 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_full/main_phnode_full_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260524_031756/diagnostic_plots/high_terminal_error_PRBS_seed46.png
# Batch evaluation complete.

# %% [markdown]
# ## 5. Provenance injection (per-run `_audit_meta/`)
# Records git HEAD + environment fingerprint into every decision run dir so these runs are distinguishable from catalog-era drift when the catalog is rebuilt.

# %%
# Inject per-run provenance. The training flow does NOT write these automatically,
# so for paper-grade evidence we record them here (see docs/provenance_audit_phnode_full_clean.md sec 5.2).
import os, sys, subprocess, datetime
from pathlib import Path
import torch

RUN_TAG = os.environ["RUN_TAG"]
ckpt = PROJECT_DIR / "checkpoints"
suites = [ckpt / f"sweep_oc_phase1a_decision_{p}_{RUN_TAG}" for p in ("clean", "iid", "v4lite")]

def _sh(args):
    try:
        return subprocess.run(args, cwd=PROJECT_DIR, capture_output=True, text=True).stdout.strip()
    except Exception as exc:  # noqa: BLE001
        return f"<unavailable: {exc}>"

head = _sh(["git", "rev-parse", "HEAD"])
diffstat = _sh(["git", "diff", "HEAD", "--stat"])
env_txt = "\n".join([
    f"python={sys.version.split()[0]}",
    f"torch={torch.__version__}",
    f"cuda={torch.version.cuda}",
    f"cudnn={torch.backends.cudnn.version()}",
    f"gpu={torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'cpu'}",
    f"captured_at={datetime.datetime.now().isoformat()}",
])

n = 0
for suite in suites:
    if not suite.exists():
        continue
    for cfg in suite.rglob("config.json"):
        run_dir = cfg.parent
        meta = run_dir / "_audit_meta"
        meta.mkdir(exist_ok=True)
        (meta / "code_revision.txt").write_text(f"git_head={head}\n\n{diffstat}\n")
        (meta / "environment.txt").write_text(env_txt + "\n")
        n += 1
print(f"provenance written for {n} run dirs")
print("git_head =", head)
# Out:
# provenance written for 15 run dirs
# git_head =

# %% [markdown]
# ## 6. Anomaly scan
# Flags any run with the `no successful training batches` catastrophic-gradient signature (the seed46 failure mode). A flagged seed must NOT be cited — rerun or annotate.

# %%
# Quick anomaly scan: catch seed46/seed43-style catastrophic training before trusting numbers.
# Flags any run whose training.log contains the "no successful training batches" failure mode.
import os, re
from pathlib import Path

RUN_TAG = os.environ["RUN_TAG"]
ckpt = PROJECT_DIR / "checkpoints"
suites = [ckpt / f"sweep_oc_phase1a_decision_{p}_{RUN_TAG}" for p in ("clean", "iid", "v4lite")]

print(f"{'suite':<48}{'run':<32}{'best_epoch':>10}{'best_loss':>14}{'nbad':>6}  flag")
for suite in suites:
    if not suite.exists():
        continue
    for cfg in sorted(suite.rglob("config.json")):
        run_dir = cfg.parent
        log = run_dir / "training.log"
        text = log.read_text() if log.exists() else ""
        nbad = text.count("no successful training batches")
        best_epoch, best_loss = "?", "?"
        m = re.findall(r"[Bb]est.*?epoch[^0-9]*([0-9]+).*?([0-9]+\.[0-9eE+-]+)", text)
        if m:
            best_epoch, best_loss = m[-1]
        flag = "  <-- CHECK (possible artifact)" if nbad > 0 else ""
        print(f"{suite.name[:46]:<48}{run_dir.name[:30]:<32}{str(best_epoch):>10}{str(best_loss):>14}{nbad:>6}{flag}")
print("\nIf any run is flagged, treat that seed like seed46/seed43: do NOT cite it; rerun or annotate.")
# Out:
# suite                                           run                             best_epoch     best_loss  nbad  flag
# sweep_oc_phase1a_decision_clean_t2_wpfrag_phno  main_phnode_full_seed42                  ?             ?     0
# sweep_oc_phase1a_decision_clean_t2_wpfrag_phno  main_phnode_full_seed43                  ?             ?     0
# sweep_oc_phase1a_decision_clean_t2_wpfrag_phno  main_phnode_full_seed44                  ?             ?     0
# sweep_oc_phase1a_decision_clean_t2_wpfrag_phno  main_phnode_full_seed45                  ?             ?     0
# sweep_oc_phase1a_decision_clean_t2_wpfrag_phno  main_phnode_full_seed46                  ?             ?     0
# sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode  main_phnode_full_seed42                  ?             ?     0
# sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode  main_phnode_full_seed43                  ?             ?     0
# sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode  main_phnode_full_seed44                  ?             ?     0
# sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode  main_phnode_full_seed45                  ?             ?     0
# sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode  main_phnode_full_seed46                  ?             ?     0
# sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phn  main_phnode_full_seed42                  ?             ?     0
# sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phn  main_phnode_full_seed43                  ?             ?     0
# sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phn  main_phnode_full_seed44                  ?             ?     0
# sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phn  main_phnode_full_seed45                  ?             ?     0
# sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phn  main_phnode_full_seed46                  ?             ?     0
#
# If any run is flagged, treat that seed like seed46/seed43: do NOT cite it; rerun or annotate.

# %% [markdown]
# ## 7. Next step (after all 4 notebooks finish)
# 1. Ensure `checkpoints/sweep_oc_phase1a_decision_{clean,iid,v4lite}_t2_wpfrag_*` are synced back to the repo.
# 2. Locally: `conda run -n mytorch1 python scripts/build_oc_data_catalog.py` to ingest the new runs.
# 3. Export the section-8 current-evidence tables from the rebuilt canonical views.
# 4. Re-verify the `ablate_no_lift` noisy-degradation claim is not driven by a seed44 artifact.
