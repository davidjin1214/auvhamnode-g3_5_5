# %% [markdown]
# # T2 WP-Frag current-evidence rerun — `phnode_qforce`
#
# **Goal.** Reproduce current-main (`g3_5_7` mirror) evidence for this one model so the
# paper Results section (chapter section 8) can be cited from a single, machine-reproducible
# suite instead of catalog-era cloud numbers contaminated by environment drift.
#
# **Matrix (this notebook).** `phnode_qforce` x {clean, iid_noisy_ic@nominal_train, v4_lite@nominal_train} x seeds {42,43,44,45,46} = 15 training runs, then every trained
# suite is evaluated across {clean, nominal_eval, degraded_eval, heading_biased_eval}.
#
# **Parallelism.** Run the four `t2_wpfrag_*` notebooks (one per model:
# `phnode_full`, `phnode_qforce`, `ablate_no_lift`, `ablate_no_mass_prior`) in separate
# Colab sessions. They use distinct `RUN_TAG`s and do not collide.
#
# **Why these knobs differ from phase1a:** (1) `IID_EVAL_PROFILES` is the full 4-profile
# robustness set so clean-vs-noisy matched comparison is available; (2) a provenance cell
# writes per-run `_audit_meta/` (the trainer does not). noise schedule defaults
# (warmup=20, ramp=80, mix_ratio=0.5) match the repo `nominal_train` contract.
#
# **After all four finish:** sync `checkpoints/` back, then locally rebuild the catalog
# (`scripts/build_oc_data_catalog.py`) and export the section-8 current-evidence tables.
#
# > Watch list while running: `phnode_full` seeds 42/46, `ablate_no_lift` seeds 43/44 —
# > these were catalog-era anomalies. The anomaly-scan cell flags any recurrence.

# %%
# !nvidia-smi
# Out:
# Sat May 23 16:56:54 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   42C    P8             13W /   72W |       0MiB /  23034MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import torch
print(f"PyTorch: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"CUDA: {torch.version.cuda}")
print(f"cuDNN: {torch.backends.cudnn.version()}")
# Out:
# PyTorch: 2.10.0+cu128
# CUDA available: True
# CUDA: 12.8
# cuDNN: 91002

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
from pathlib import Path

PROJECT_DIR = Path(os.environ.get(
    "AUV_PROJECT_DIR",
    "/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7",
))
assert PROJECT_DIR.exists(), f"Project directory not found: {PROJECT_DIR}"
# %cd $PROJECT_DIR
# Out:
# /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7

# %%
# %pip install -q torchdiffeq pandas

# %% [markdown]
# ## 0. Configuration

# %%
import os

# Runtime
os.environ["PYTHON_BIN"] = "python"
os.environ["DEVICE"] = "cuda"
os.environ["LOCAL_PROXY_ROOT"] = "/content/_proxy_suites"

# ---- T2 identity (one model per notebook) ----
os.environ["RUN_TAG"] = "t2_wpfrag_phnode_qforce"
os.environ["DATASET"] = "data/auv_oc_traj1000_blk150_s23_d0be9434.pkl"
os.environ["NOISE_REFERENCE"] = "remus100_dr"
os.environ["PHASE1A_LOG_DIR"] = str(PROJECT_DIR / "checkpoints" / "phase1a_logs" / os.environ["RUN_TAG"])
os.environ["PHASE1A_METADATA_DIR"] = str(PROJECT_DIR / "checkpoints" / f"phase1a_metadata_{os.environ['RUN_TAG']}")

# ---- T2 matrix: single model x 3 protocols x 5 seeds ----
os.environ["PHASE1A_MODELS"] = "phnode_qforce"
os.environ["SMOKE1_MODELS"] = "phnode_qforce"
os.environ["SMOKE_SEEDS"] = "42"                 # cheap protocol-correctness gate (1 seed)
os.environ["DECISION_SEEDS"] = "42 43 44 45 46"  # full current-evidence seed set

# ---- Evaluation contract ----
os.environ["SMOKE_EVAL_NUM_TRAJ_PER_SCENARIO"] = "6"
os.environ["DECISION_EVAL_NUM_TRAJ_PER_SCENARIO"] = "30"
os.environ["EVAL_TIMES"] = "10 30 60"
os.environ["EVAL_SCENARIOS"] = "PRBS CHIRP OU"
os.environ["EVAL_BASE_SEED"] = "42"
os.environ["EVAL_NOISE_SEED"] = "2024"
os.environ["EVAL_PROGRESS_EVERY"] = "5"
os.environ["EVAL_NUM_DIAGNOSTIC_PLOTS"] = "6"
# Full robustness set: evaluates clean/iid/v4lite suites across all 4 profiles (caveat B).
os.environ["IID_EVAL_PROFILES"] = "clean nominal_eval degraded_eval heading_biased_eval"
os.environ["V4_EVAL_PROFILES"] = "nominal_eval"

# ---- Audit gate ----
os.environ["STRICT_ZERO_NOISE_AUDIT"] = "1"
os.environ["SOFT_MIN_EPOCH_SCALE"] = "0.05"

print("RUN_TAG       =", os.environ["RUN_TAG"])
print("PHASE1A_MODELS=", os.environ["PHASE1A_MODELS"])
print("DECISION_SEEDS=", os.environ["DECISION_SEEDS"])
print("IID_EVAL_PROFILES=", os.environ["IID_EVAL_PROFILES"])
# Out:
# RUN_TAG       = t2_wpfrag_phnode_qforce
# PHASE1A_MODELS= phnode_qforce
# DECISION_SEEDS= 42 43 44 45 46
# IID_EVAL_PROFILES= clean nominal_eval degraded_eval heading_biased_eval

# %% [markdown]
# ## 1. Preflight
# Confirms all target suite/proxy dirs are absent and saves suite-level run config + environment metadata. If it fails, change `RUN_TAG` or remove the target dirs.

# %%
os.environ["MODE"] = "preflight"
# !bash scripts/run_phase1a_oc_v4lite.sh
# Out:
# [phase1a]
# MODE=preflight
# RUN_TAG=t2_wpfrag_phnode_qforce
# DATASET=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# DEVICE=cuda
# PHASE1A_MODELS=phnode_qforce
# SMOKE1_MODELS=phnode_qforce
# SMOKE_SEEDS=42
# DECISION_SEEDS=42 43 44 45 46
# NOISE_REFERENCE=remus100_dr
# PHASE1A_LOG_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_logs/t2_wpfrag_phnode_qforce
# PHASE1A_METADATA_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_metadata_t2_wpfrag_phnode_qforce
# Preflight passed: all Phase-1A target suite/proxy directories are absent.
# [metadata] /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_metadata_t2_wpfrag_phnode_qforce

# %% [markdown]
# ## 2. Smoke gate (seed 42, all 3 protocols)
# Cheap protocol-correctness check (especially the `v4_lite` trajectory-consistent IC path and the strict zero-noise audit for `clean`). Important for `phnode_qforce`, which was not in the phase1a smoke set. Smoke results are flow-validation only — never cited.

# %%
os.environ["MODE"] = "smoke1_train"
# !bash scripts/run_phase1a_oc_v4lite.sh
# Out:
# [phase1a]
# MODE=smoke1_train
# RUN_TAG=t2_wpfrag_phnode_qforce
# DATASET=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# DEVICE=cuda
# PHASE1A_MODELS=phnode_qforce
# SMOKE1_MODELS=phnode_qforce
# SMOKE_SEEDS=42
# DECISION_SEEDS=42 43 44 45 46
# NOISE_REFERENCE=remus100_dr
# PHASE1A_LOG_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_logs/t2_wpfrag_phnode_qforce
# PHASE1A_METADATA_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_metadata_t2_wpfrag_phnode_qforce
# [train] suite=sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_qforce models=phnode_qforce seeds=42 protocol=auto
# Training all models with profile-based noisy IC.
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Group: all
# Explicit models: phnode_qforce
# Seeds: 42
# Noise config: protocol=auto, profile=clean, scale=1.0, warmup=20, ramp=80, mix_ratio=0.5
# Auto-eval profiles: block=[clean nominal_eval heading_biased_eval] heldout=[clean nominal_eval degraded_eval heading_biased_eval]
# Suite directory: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_qforce
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Models (1): phnode_qforce
# Seeds: 42
# [train] baseline_phnode_qforce_seed42
# Loading dataset...
# Loaded: 83850 train, 21000 test, t_eval=[0.   0.05 0.1  0.15 0.2 ]
# Dataset split: trajectory | train trajectories: 559 | test trajectories: 140
# Dataset ID: d0be9434
# Dataset path: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl | velocity convention: body_total | state dim: 27
# Position std: [0.1508, 0.1400, 0.0370]
# Velocity std: u=0.4722, v=0.0898, w=0.0718, p=0.0248, q=0.0906, r=0.0526
# Actuator std: a0=0.1543, a1=0.1555, a2=299.0037
# Training noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# Model: pH NODE q-Force [baseline/core] | canonical type: phnode_qforce
# Model parameters: 63,447
# Training dataset: id=d0be9434 | path=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Mass matrix initialized from physics
# Training: epochs<=300, target_steps=5000, warmup_steps=400, lr=6.00e-03 -> 1.00e-04, solver=rk4, so3_reg=1.00e-03
# Train samples: 83850, Test samples: 21000
# Epoch    1 | Step    20/ 5000 | Train 4.3439e+00 | Test 5.0818e+00 | SO3(train/test) 1.26e-07/1.28e-07 | Fail(train/test) 0/0 | LR 4.10e-04 | 7.4s
# Epoch    2 | Step    40/ 5000 | Train 3.6273e+00 | Test 4.4010e+00 | SO3(train/test) 1.19e-07/1.19e-07 | Fail(train/test) 0/0 | LR 7.05e-04 | 5.5s
# Epoch    3 | Step    60/ 5000 | Train 3.0163e+00 | Test 3.3613e+00 | SO3(train/test) 1.16e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.00e-03 | 5.3s
# Epoch    4 | Step    80/ 5000 | Train 2.3573e+00 | Test 2.2848e+00 | SO3(train/test) 1.15e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.29e-03 | 5.3s
# Epoch    5 | Step   100/ 5000 | Train 1.4017e+00 | Test 1.3165e+00 | SO3(train/test) 1.79e-07/6.03e-07 | Fail(train/test) 0/0 | LR 1.59e-03 | 5.4s
# Epoch    6 | Step   120/ 5000 | Train 8.2318e-01 | Test 7.4009e-01 | SO3(train/test) 3.22e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.88e-03 | 5.5s
# Epoch    7 | Step   140/ 5000 | Train 5.9035e-01 | Test 5.6496e-01 | SO3(train/test) 1.15e-07/1.14e-07 | Fail(train/test) 0/0 | LR 2.18e-03 | 5.3s
# Epoch    8 | Step   160/ 5000 | Train 5.2462e-01 | Test 6.5651e-01 | SO3(train/test) 1.14e-07/1.13e-07 | Fail(train/test) 0/0 | LR 2.47e-03 | 5.3s
# Epoch    9 | Step   180/ 5000 | Train 6.9701e-01 | Test 2.6009e+00 | SO3(train/test) 1.14e-07/1.21e-07 | Fail(train/test) 0/0 | LR 2.77e-03 | 5.3s
# Epoch   10 | Step   200/ 5000 | Train 1.4024e+00 | Test 9.7903e-01 | SO3(train/test) 1.51e-07/2.72e-07 | Fail(train/test) 0/0 | LR 3.06e-03 | 5.4s
# Epoch   11 | Step   220/ 5000 | Train 1.1269e+00 | Test 7.2923e-01 | SO3(train/test) 2.29e-07/9.24e-07 | Fail(train/test) 0/0 | LR 3.36e-03 | 5.3s
# Epoch   12 | Step   240/ 5000 | Train 1.0003e+00 | Test 6.1206e-01 | SO3(train/test) 3.13e-07/1.50e-07 | Fail(train/test) 0/0 | LR 3.65e-03 | 5.3s
# Epoch   13 | Step   260/ 5000 | Train 5.0797e-01 | Test 4.1949e-01 | SO3(train/test) 1.35e-07/1.16e-07 | Fail(train/test) 0/0 | LR 3.95e-03 | 5.4s
# Epoch   14 | Step   280/ 5000 | Train 1.0615e+00 | Test 6.1814e-01 | SO3(train/test) 1.41e-07/1.84e-07 | Fail(train/test) 0/0 | LR 4.24e-03 | 5.4s
# Epoch   15 | Step   300/ 5000 | Train 7.6114e-01 | Test 8.4382e-01 | SO3(train/test) 1.28e-07/1.73e-07 | Fail(train/test) 0/0 | LR 4.54e-03 | 5.4s
# Epoch   16 | Step   320/ 5000 | Train 6.1647e-01 | Test 3.9532e-01 | SO3(train/test) 1.38e-07/1.19e-07 | Fail(train/test) 0/0 | LR 4.83e-03 | 5.3s
# Epoch   17 | Step   340/ 5000 | Train 1.0393e+00 | Test 7.5782e-01 | SO3(train/test) 5.94e-07/1.61e-07 | Fail(train/test) 0/0 | LR 5.13e-03 | 5.3s
# Epoch   18 | Step   360/ 5000 | Train 1.9734e+00 | Test 2.9823e+00 | SO3(train/test) 5.16e-07/1.29e-07 | Fail(train/test) 0/0 | LR 5.42e-03 | 5.3s
# Epoch   19 | Step   380/ 5000 | Train 9.6602e-01 | Test 1.1594e+00 | SO3(train/test) 1.24e-07/1.28e-07 | Fail(train/test) 0/0 | LR 5.72e-03 | 5.3s
# Epoch   20 | Step   400/ 5000 | Train 7.8545e-01 | Test 1.8520e+00 | SO3(train/test) 1.37e-07/2.21e-07 | Fail(train/test) 0/0 | LR 6.00e-03 | 5.4s
# Epoch   21 | Step   420/ 5000 | Train 1.6879e+00 | Test 2.5521e+00 | SO3(train/test) 8.53e-06/1.18e-04 | Fail(train/test) 0/0 | LR 6.00e-03 | 5.4s
# Epoch   22 | Step   440/ 5000 | Train 4.0272e+00 | Test 2.1995e+00 | SO3(train/test) 1.10e-05/1.52e-06 | Fail(train/test) 0/0 | LR 6.00e-03 | 5.4s
# Epoch   23 | Step   460/ 5000 | Train 1.9558e+00 | Test 3.7390e+00 | SO3(train/test) 2.88e-05/3.65e-06 | Fail(train/test) 0/0 | LR 6.00e-03 | 5.4s
# Epoch   24 | Step   480/ 5000 | Train 1.3796e+00 | Test 6.8673e-01 | SO3(train/test) 6.34e-06/9.69e-06 | Fail(train/test) 0/0 | LR 6.00e-03 | 5.4s
# Epoch   25 | Step   500/ 5000 | Train 1.3429e+00 | Test 7.9269e-01 | SO3(train/test) 4.54e-05/1.75e-05 | Fail(train/test) 0/0 | LR 5.99e-03 | 5.4s
# Epoch   26 | Step   520/ 5000 | Train 7.2152e-01 | Test 6.9054e-01 | SO3(train/test) 3.39e-05/5.77e-06 | Fail(train/test) 0/0 | LR 5.99e-03 | 5.4s
# Epoch   27 | Step   540/ 5000 | Train 4.1565e-01 | Test 2.6481e-01 | SO3(train/test) 3.30e-06/6.64e-06 | Fail(train/test) 0/0 | LR 5.99e-03 | 5.3s
# Epoch   28 | Step   560/ 5000 | Train 5.0084e-01 | Test 3.4281e+00 | SO3(train/test) 8.21e-06/8.59e-05 | Fail(train/test) 0/0 | LR 5.98e-03 | 5.3s
# Epoch   29 | Step   580/ 5000 | Train 9.0466e-01 | Test 3.3857e-01 | SO3(train/test) 3.65e-05/3.25e-06 | Fail(train/test) 0/0 | LR 5.98e-03 | 5.3s
# Epoch   30 | Step   600/ 5000 | Train 3.6978e-01 | Test 2.5883e-01 | SO3(train/test) 5.98e-06/2.72e-06 | Fail(train/test) 0/0 | LR 5.97e-03 | 5.4s
# Epoch   31 | Step   620/ 5000 | Train 4.2521e-01 | Test 2.9923e-01 | SO3(train/test) 2.41e-06/1.78e-06 | Fail(train/test) 0/0 | LR 5.97e-03 | 5.4s
# Epoch   32 | Step   640/ 5000 | Train 2.8362e-01 | Test 2.1632e-01 | SO3(train/test) 1.12e-05/1.65e-05 | Fail(train/test) 0/0 | LR 5.96e-03 | 5.3s
# Epoch   33 | Step   660/ 5000 | Train 1.7473e-01 | Test 1.5165e-01 | SO3(train/test) 6.30e-06/4.01e-06 | Fail(train/test) 0/0 | LR 5.95e-03 | 5.3s
# Epoch   34 | Step   680/ 5000 | Train 1.5367e-01 | Test 1.4525e-01 | SO3(train/test) 3.85e-06/6.16e-06 | Fail(train/test) 0/0 | LR 5.95e-03 | 5.2s
# Epoch   35 | Step   700/ 5000 | Train 1.4323e-01 | Test 1.4714e-01 | SO3(train/test) 4.51e-06/6.55e-06 | Fail(train/test) 0/0 | LR 5.94e-03 | 5.5s
# Epoch   36 | Step   720/ 5000 | Train 1.9445e-01 | Test 2.0590e-01 | SO3(train/test) 1.99e-05/4.16e-06 | Fail(train/test) 0/0 | LR 5.93e-03 | 5.4s
# Epoch   37 | Step   740/ 5000 | Train 5.1567e-01 | Test 2.8926e-01 | SO3(train/test) 1.03e-04/1.78e-05 | Fail(train/test) 0/0 | LR 5.92e-03 | 5.3s
# Epoch   38 | Step   760/ 5000 | Train 2.6335e-01 | Test 2.4230e-01 | SO3(train/test) 7.61e-06/1.92e-06 | Fail(train/test) 0/0 | LR 5.91e-03 | 5.3s
# Epoch   39 | Step   780/ 5000 | Train 1.9201e-01 | Test 1.5179e-01 | SO3(train/test) 5.67e-06/7.90e-06 | Fail(train/test) 0/0 | LR 5.90e-03 | 5.3s
# Epoch   40 | Step   800/ 5000 | Train 1.7187e-01 | Test 1.5986e-01 | SO3(train/test) 5.73e-06/7.85e-06 | Fail(train/test) 0/0 | LR 5.89e-03 | 5.6s
# Epoch   41 | Step   820/ 5000 | Train 1.7038e-01 | Test 1.7792e-01 | SO3(train/test) 5.12e-06/8.80e-06 | Fail(train/test) 0/0 | LR 5.88e-03 | 5.3s
# Epoch   42 | Step   840/ 5000 | Train 1.5369e-01 | Test 1.3899e-01 | SO3(train/test) 4.91e-06/2.50e-06 | Fail(train/test) 0/0 | LR 5.87e-03 | 5.4s
# Epoch   43 | Step   860/ 5000 | Train 1.5663e-01 | Test 1.7895e-01 | SO3(train/test) 9.32e-06/1.47e-05 | Fail(train/test) 0/0 | LR 5.86e-03 | 5.3s
# Epoch   44 | Step   880/ 5000 | Train 1.8267e-01 | Test 2.2386e-01 | SO3(train/test) 7.81e-06/8.04e-07 | Fail(train/test) 0/0 | LR 5.84e-03 | 5.3s
# Epoch   45 | Step   900/ 5000 | Train 2.0562e-01 | Test 6.5563e-01 | SO3(train/test) 2.07e-06/2.24e-05 | Fail(train/test) 0/0 | LR 5.83e-03 | 5.5s
# Epoch   46 | Step   920/ 5000 | Train 2.8059e-01 | Test 2.5130e-01 | SO3(train/test) 7.86e-06/1.18e-06 | Fail(train/test) 0/0 | LR 5.82e-03 | 5.3s
# Epoch   47 | Step   940/ 5000 | Train 1.6681e-01 | Test 1.3387e-01 | SO3(train/test) 2.90e-06/4.55e-06 | Fail(train/test) 0/0 | LR 5.80e-03 | 5.4s
# Epoch   48 | Step   960/ 5000 | Train 1.5130e-01 | Test 1.3658e-01 | SO3(train/test) 3.85e-06/5.16e-06 | Fail(train/test) 0/0 | LR 5.79e-03 | 5.3s
# Epoch   49 | Step   980/ 5000 | Train 1.5756e-01 | Test 1.4199e-01 | SO3(train/test) 4.58e-06/7.62e-06 | Fail(train/test) 0/0 | LR 5.77e-03 | 5.3s
# Epoch   50 | Step  1000/ 5000 | Train 1.3139e-01 | Test 1.2085e-01 | SO3(train/test) 3.62e-06/7.06e-06 | Fail(train/test) 0/0 | LR 5.76e-03 | 5.4s
# Epoch   51 | Step  1020/ 5000 | Train 2.6484e-01 | Test 2.2924e-01 | SO3(train/test) 1.72e-05/7.76e-05 | Fail(train/test) 0/0 | LR 5.74e-03 | 5.4s
# Epoch   52 | Step  1040/ 5000 | Train 1.6823e-01 | Test 1.2524e-01 | SO3(train/test) 1.35e-05/5.87e-06 | Fail(train/test) 0/0 | LR 5.72e-03 | 5.4s
# Epoch   53 | Step  1060/ 5000 | Train 1.3607e-01 | Test 1.5273e-01 | SO3(train/test) 3.63e-06/6.60e-06 | Fail(train/test) 0/0 | LR 5.71e-03 | 5.5s
# Epoch   54 | Step  1080/ 5000 | Train 1.3258e-01 | Test 1.2661e-01 | SO3(train/test) 5.84e-06/8.57e-06 | Fail(train/test) 0/0 | LR 5.69e-03 | 5.3s
# Epoch   55 | Step  1100/ 5000 | Train 1.4108e-01 | Test 1.3509e-01 | SO3(train/test) 7.67e-06/8.67e-06 | Fail(train/test) 0/0 | LR 5.67e-03 | 5.4s
# Epoch   56 | Step  1120/ 5000 | Train 1.6412e-01 | Test 1.6342e-01 | SO3(train/test) 6.75e-06/8.96e-06 | Fail(train/test) 0/0 | LR 5.65e-03 | 5.4s
# Epoch   57 | Step  1140/ 5000 | Train 1.3790e-01 | Test 1.0964e-01 | SO3(train/test) 5.77e-06/5.61e-06 | Fail(train/test) 0/0 | LR 5.63e-03 | 5.4s
# Epoch   58 | Step  1160/ 5000 | Train 1.1943e-01 | Test 1.0132e-01 | SO3(train/test) 5.44e-06/6.72e-06 | Fail(train/test) 0/0 | LR 5.61e-03 | 5.3s
# Epoch   59 | Step  1180/ 5000 | Train 9.8746e-02 | Test 9.7555e-02 | SO3(train/test) 4.77e-06/4.89e-06 | Fail(train/test) 0/0 | LR 5.59e-03 | 5.4s
# Epoch   60 | Step  1200/ 5000 | Train 9.7151e-02 | Test 9.5643e-02 | SO3(train/test) 4.42e-06/6.30e-06 | Fail(train/test) 0/0 | LR 5.57e-03 | 5.4s
# Epoch   61 | Step  1220/ 5000 | Train 2.4303e-01 | Test 6.2333e-01 | SO3(train/test) 2.40e-06/5.78e-06 | Fail(train/test) 0/0 | LR 5.55e-03 | 5.4s
# Epoch   62 | Step  1240/ 5000 | Train 2.9577e-01 | Test 1.8796e-01 | SO3(train/test) 4.79e-06/4.96e-06 | Fail(train/test) 0/0 | LR 5.53e-03 | 5.4s
# Epoch   63 | Step  1260/ 5000 | Train 1.3445e-01 | Test 1.0319e-01 | SO3(train/test) 5.35e-06/4.05e-06 | Fail(train/test) 0/0 | LR 5.51e-03 | 5.4s
# Epoch   64 | Step  1280/ 5000 | Train 1.1464e-01 | Test 1.0066e-01 | SO3(train/test) 5.88e-06/5.38e-06 | Fail(train/test) 0/0 | LR 5.48e-03 | 5.4s
# Epoch   65 | Step  1300/ 5000 | Train 9.5248e-02 | Test 9.3323e-02 | SO3(train/test) 4.80e-06/6.27e-06 | Fail(train/test) 0/0 | LR 5.46e-03 | 5.5s
# Epoch   66 | Step  1320/ 5000 | Train 9.1979e-02 | Test 9.0570e-02 | SO3(train/test) 4.93e-06/6.00e-06 | Fail(train/test) 0/0 | LR 5.44e-03 | 5.3s
# Epoch   67 | Step  1340/ 5000 | Train 9.9131e-02 | Test 1.0875e-01 | SO3(train/test) 4.67e-06/3.37e-06 | Fail(train/test) 0/0 | LR 5.41e-03 | 5.3s
# Epoch   68 | Step  1360/ 5000 | Train 9.4775e-02 | Test 9.0119e-02 | SO3(train/test) 4.48e-06/6.47e-06 | Fail(train/test) 0/0 | LR 5.39e-03 | 5.4s
# Epoch   69 | Step  1380/ 5000 | Train 1.2059e-01 | Test 1.0834e-01 | SO3(train/test) 3.14e-06/3.48e-06 | Fail(train/test) 0/0 | LR 5.36e-03 | 5.5s
# Epoch   70 | Step  1400/ 5000 | Train 1.2378e-01 | Test 1.5470e-01 | SO3(train/test) 4.01e-06/1.90e-06 | Fail(train/test) 0/0 | LR 5.34e-03 | 5.6s
# Epoch   71 | Step  1420/ 5000 | Train 1.0154e-01 | Test 1.0200e-01 | SO3(train/test) 3.48e-06/6.16e-06 | Fail(train/test) 0/0 | LR 5.31e-03 | 5.3s
# Epoch   72 | Step  1440/ 5000 | Train 9.4250e-02 | Test 8.2549e-02 | SO3(train/test) 4.50e-06/5.25e-06 | Fail(train/test) 0/0 | LR 5.29e-03 | 5.4s
# Epoch   73 | Step  1460/ 5000 | Train 8.3380e-02 | Test 8.0688e-02 | SO3(train/test) 4.63e-06/6.54e-06 | Fail(train/test) 0/0 | LR 5.26e-03 | 5.5s
# Epoch   74 | Step  1480/ 5000 | Train 9.2197e-02 | Test 9.1514e-02 | SO3(train/test) 5.72e-06/4.04e-06 | Fail(train/test) 0/0 | LR 5.23e-03 | 5.3s
# Epoch   75 | Step  1500/ 5000 | Train 8.6691e-02 | Test 8.1310e-02 | SO3(train/test) 4.48e-06/4.86e-06 | Fail(train/test) 0/0 | LR 5.21e-03 | 5.5s
# Epoch   76 | Step  1520/ 5000 | Train 8.3661e-02 | Test 7.8638e-02 | SO3(train/test) 4.95e-06/6.36e-06 | Fail(train/test) 0/0 | LR 5.18e-03 | 5.4s
# Epoch   77 | Step  1540/ 5000 | Train 7.6536e-02 | Test 7.7530e-02 | SO3(train/test) 5.34e-06/5.37e-06 | Fail(train/test) 0/0 | LR 5.15e-03 | 5.4s
# Epoch   78 | Step  1560/ 5000 | Train 7.4254e-02 | Test 7.8630e-02 | SO3(train/test) 5.44e-06/5.27e-06 | Fail(train/test) 0/0 | LR 5.12e-03 | 5.3s
# Epoch   79 | Step  1580/ 5000 | Train 1.0785e-01 | Test 1.1077e-01 | SO3(train/test) 7.06e-06/5.52e-06 | Fail(train/test) 0/0 | LR 5.09e-03 | 5.4s
# Epoch   80 | Step  1600/ 5000 | Train 9.2671e-02 | Test 8.1459e-02 | SO3(train/test) 6.10e-06/4.52e-06 | Fail(train/test) 0/0 | LR 5.06e-03 | 5.4s
# Epoch   81 | Step  1620/ 5000 | Train 7.2650e-02 | Test 6.9957e-02 | SO3(train/test) 5.85e-06/8.19e-06 | Fail(train/test) 0/0 | LR 5.03e-03 | 5.3s
# Epoch   82 | Step  1640/ 5000 | Train 7.5462e-02 | Test 7.7983e-02 | SO3(train/test) 6.06e-06/6.51e-06 | Fail(train/test) 0/0 | LR 5.00e-03 | 5.3s
# Epoch   83 | Step  1660/ 5000 | Train 9.2210e-02 | Test 1.3914e-01 | SO3(train/test) 5.49e-06/3.99e-06 | Fail(train/test) 0/0 | LR 4.97e-03 | 5.3s
# Epoch   84 | Step  1680/ 5000 | Train 1.2533e-01 | Test 9.1963e-02 | SO3(train/test) 1.26e-05/7.59e-06 | Fail(train/test) 0/0 | LR 4.94e-03 | 5.3s
# Epoch   85 | Step  1700/ 5000 | Train 7.4444e-02 | Test 7.7903e-02 | SO3(train/test) 6.73e-06/6.46e-06 | Fail(train/test) 0/0 | LR 4.91e-03 | 5.4s
# Epoch   86 | Step  1720/ 5000 | Train 7.1332e-02 | Test 7.2217e-02 | SO3(train/test) 6.67e-06/9.15e-06 | Fail(train/test) 0/0 | LR 4.88e-03 | 5.3s
# Epoch   87 | Step  1740/ 5000 | Train 7.7367e-02 | Test 7.5654e-02 | SO3(train/test) 7.54e-06/8.41e-06 | Fail(train/test) 0/0 | LR 4.85e-03 | 5.2s
# Epoch   88 | Step  1760/ 5000 | Train 7.5464e-02 | Test 7.1412e-02 | SO3(train/test) 8.34e-06/9.20e-06 | Fail(train/test) 0/0 | LR 4.82e-03 | 5.3s
# Epoch   89 | Step  1780/ 5000 | Train 6.8662e-02 | Test 9.0606e-02 | SO3(train/test) 8.09e-06/6.64e-06 | Fail(train/test) 0/0 | LR 4.78e-03 | 5.4s
# Epoch   90 | Step  1800/ 5000 | Train 7.3259e-02 | Test 7.1831e-02 | SO3(train/test) 8.01e-06/7.08e-06 | Fail(train/test) 0/0 | LR 4.75e-03 | 5.5s
# Epoch   91 | Step  1820/ 5000 | Train 7.0126e-02 | Test 6.0037e-02 | SO3(train/test) 6.74e-06/7.18e-06 | Fail(train/test) 0/0 | LR 4.72e-03 | 5.4s
# Epoch   92 | Step  1840/ 5000 | Train 6.3055e-02 | Test 5.6755e-02 | SO3(train/test) 6.70e-06/9.12e-06 | Fail(train/test) 0/0 | LR 4.68e-03 | 5.3s
# Epoch   93 | Step  1860/ 5000 | Train 5.8062e-02 | Test 5.6173e-02 | SO3(train/test) 8.08e-06/8.74e-06 | Fail(train/test) 0/0 | LR 4.65e-03 | 5.3s
# Epoch   94 | Step  1880/ 5000 | Train 6.6287e-02 | Test 7.2027e-02 | SO3(train/test) 8.51e-06/8.46e-06 | Fail(train/test) 0/0 | LR 4.62e-03 | 5.3s
# Epoch   95 | Step  1900/ 5000 | Train 7.4004e-02 | Test 7.0896e-02 | SO3(train/test) 7.91e-06/7.03e-06 | Fail(train/test) 0/0 | LR 4.58e-03 | 5.5s
# Epoch   96 | Step  1920/ 5000 | Train 6.6203e-02 | Test 5.8115e-02 | SO3(train/test) 7.26e-06/6.61e-06 | Fail(train/test) 0/0 | LR 4.55e-03 | 5.4s
# Epoch   97 | Step  1940/ 5000 | Train 5.7196e-02 | Test 5.1957e-02 | SO3(train/test) 7.41e-06/8.70e-06 | Fail(train/test) 0/0 | LR 4.51e-03 | 5.3s
# Epoch   98 | Step  1960/ 5000 | Train 5.3442e-02 | Test 4.9800e-02 | SO3(train/test) 8.43e-06/9.94e-06 | Fail(train/test) 0/0 | LR 4.48e-03 | 5.4s
# Epoch   99 | Step  1980/ 5000 | Train 5.1232e-02 | Test 4.6958e-02 | SO3(train/test) 8.70e-06/9.67e-06 | Fail(train/test) 0/0 | LR 4.44e-03 | 5.4s
# Epoch  100 | Step  2000/ 5000 | Train 5.5529e-02 | Test 4.9680e-02 | SO3(train/test) 8.21e-06/7.90e-06 | Fail(train/test) 0/0 | LR 4.41e-03 | 5.5s
# Epoch  101 | Step  2020/ 5000 | Train 4.8593e-02 | Test 4.8342e-02 | SO3(train/test) 8.75e-06/9.89e-06 | Fail(train/test) 0/0 | LR 4.37e-03 | 5.4s
# Epoch  102 | Step  2040/ 5000 | Train 5.4230e-02 | Test 6.4806e-02 | SO3(train/test) 9.31e-06/7.05e-06 | Fail(train/test) 0/0 | LR 4.33e-03 | 5.5s
# Epoch  103 | Step  2060/ 5000 | Train 5.2827e-02 | Test 5.2410e-02 | SO3(train/test) 8.06e-06/8.89e-06 | Fail(train/test) 0/0 | LR 4.30e-03 | 5.4s
# Epoch  104 | Step  2080/ 5000 | Train 4.5590e-02 | Test 4.7661e-02 | SO3(train/test) 8.59e-06/9.06e-06 | Fail(train/test) 0/0 | LR 4.26e-03 | 5.3s
# Epoch  105 | Step  2100/ 5000 | Train 4.4722e-02 | Test 6.5519e-02 | SO3(train/test) 9.80e-06/1.49e-05 | Fail(train/test) 0/0 | LR 4.22e-03 | 5.5s
# Epoch  106 | Step  2120/ 5000 | Train 5.0843e-02 | Test 4.9423e-02 | SO3(train/test) 9.30e-06/1.14e-05 | Fail(train/test) 0/0 | LR 4.19e-03 | 5.3s
# Epoch  107 | Step  2140/ 5000 | Train 4.1976e-02 | Test 4.5210e-02 | SO3(train/test) 9.44e-06/1.19e-05 | Fail(train/test) 0/0 | LR 4.15e-03 | 5.5s
# Epoch  108 | Step  2160/ 5000 | Train 5.6021e-02 | Test 5.2820e-02 | SO3(train/test) 1.16e-05/1.04e-05 | Fail(train/test) 0/0 | LR 4.11e-03 | 5.4s
# Epoch  109 | Step  2180/ 5000 | Train 4.6087e-02 | Test 5.8075e-02 | SO3(train/test) 1.01e-05/1.44e-05 | Fail(train/test) 0/0 | LR 4.08e-03 | 5.4s
# Epoch  110 | Step  2200/ 5000 | Train 6.1412e-02 | Test 6.5231e-02 | SO3(train/test) 1.05e-05/1.29e-05 | Fail(train/test) 0/0 | LR 4.04e-03 | 5.4s
# Epoch  111 | Step  2220/ 5000 | Train 4.9791e-02 | Test 4.8034e-02 | SO3(train/test) 9.47e-06/8.93e-06 | Fail(train/test) 0/0 | LR 4.00e-03 | 5.4s
# Epoch  112 | Step  2240/ 5000 | Train 4.2851e-02 | Test 4.0078e-02 | SO3(train/test) 9.27e-06/1.04e-05 | Fail(train/test) 0/0 | LR 3.96e-03 | 5.4s
# Epoch  113 | Step  2260/ 5000 | Train 3.8676e-02 | Test 4.2846e-02 | SO3(train/test) 1.07e-05/1.22e-05 | Fail(train/test) 0/0 | LR 3.92e-03 | 5.4s
# Epoch  114 | Step  2280/ 5000 | Train 5.6863e-02 | Test 4.6886e-02 | SO3(train/test) 1.16e-05/1.17e-05 | Fail(train/test) 0/0 | LR 3.88e-03 | 5.4s
# Epoch  115 | Step  2300/ 5000 | Train 4.6853e-02 | Test 4.2278e-02 | SO3(train/test) 9.76e-06/9.11e-06 | Fail(train/test) 0/0 | LR 3.85e-03 | 5.5s
# Epoch  116 | Step  2320/ 5000 | Train 3.7500e-02 | Test 3.7740e-02 | SO3(train/test) 9.91e-06/1.29e-05 | Fail(train/test) 0/0 | LR 3.81e-03 | 5.5s
# Epoch  117 | Step  2340/ 5000 | Train 3.8733e-02 | Test 3.8491e-02 | SO3(train/test) 1.12e-05/1.26e-05 | Fail(train/test) 0/0 | LR 3.77e-03 | 5.4s
# Epoch  118 | Step  2360/ 5000 | Train 4.2047e-02 | Test 4.0052e-02 | SO3(train/test) 1.08e-05/1.26e-05 | Fail(train/test) 0/0 | LR 3.73e-03 | 5.5s
# Epoch  119 | Step  2380/ 5000 | Train 3.4744e-02 | Test 3.4940e-02 | SO3(train/test) 1.14e-05/1.34e-05 | Fail(train/test) 0/0 | LR 3.69e-03 | 5.4s
# Epoch  120 | Step  2400/ 5000 | Train 3.3384e-02 | Test 3.6575e-02 | SO3(train/test) 1.22e-05/1.37e-05 | Fail(train/test) 0/0 | LR 3.65e-03 | 5.4s
# Epoch  121 | Step  2420/ 5000 | Train 3.8380e-02 | Test 3.8014e-02 | SO3(train/test) 1.23e-05/1.20e-05 | Fail(train/test) 0/0 | LR 3.61e-03 | 5.3s
# Epoch  122 | Step  2440/ 5000 | Train 3.5109e-02 | Test 3.8887e-02 | SO3(train/test) 1.15e-05/1.39e-05 | Fail(train/test) 0/0 | LR 3.57e-03 | 5.4s
# Epoch  123 | Step  2460/ 5000 | Train 3.4713e-02 | Test 4.2366e-02 | SO3(train/test) 1.20e-05/1.21e-05 | Fail(train/test) 0/0 | LR 3.53e-03 | 5.4s
# Epoch  124 | Step  2480/ 5000 | Train 4.2587e-02 | Test 4.0666e-02 | SO3(train/test) 1.14e-05/9.84e-06 | Fail(train/test) 0/0 | LR 3.49e-03 | 5.4s
# Epoch  125 | Step  2500/ 5000 | Train 3.6722e-02 | Test 3.4265e-02 | SO3(train/test) 1.02e-05/1.19e-05 | Fail(train/test) 0/0 | LR 3.45e-03 | 5.4s
# Epoch  126 | Step  2520/ 5000 | Train 3.2315e-02 | Test 3.2575e-02 | SO3(train/test) 1.11e-05/1.36e-05 | Fail(train/test) 0/0 | LR 3.41e-03 | 5.3s
# Epoch  127 | Step  2540/ 5000 | Train 3.0218e-02 | Test 3.1766e-02 | SO3(train/test) 1.22e-05/1.47e-05 | Fail(train/test) 0/0 | LR 3.37e-03 | 5.3s
# Epoch  128 | Step  2560/ 5000 | Train 2.9791e-02 | Test 3.1545e-02 | SO3(train/test) 1.29e-05/1.56e-05 | Fail(train/test) 0/0 | LR 3.33e-03 | 5.4s
# Epoch  129 | Step  2580/ 5000 | Train 2.9609e-02 | Test 3.0824e-02 | SO3(train/test) 1.32e-05/1.54e-05 | Fail(train/test) 0/0 | LR 3.29e-03 | 5.3s
# Epoch  130 | Step  2600/ 5000 | Train 2.9283e-02 | Test 3.1121e-02 | SO3(train/test) 1.34e-05/1.57e-05 | Fail(train/test) 0/0 | LR 3.25e-03 | 5.5s
# Epoch  131 | Step  2620/ 5000 | Train 3.4720e-02 | Test 4.9391e-02 | SO3(train/test) 1.36e-05/1.51e-05 | Fail(train/test) 0/0 | LR 3.21e-03 | 5.3s
# Epoch  132 | Step  2640/ 5000 | Train 3.9603e-02 | Test 4.0186e-02 | SO3(train/test) 1.25e-05/1.65e-05 | Fail(train/test) 0/0 | LR 3.17e-03 | 5.3s
# Epoch  133 | Step  2660/ 5000 | Train 4.1027e-02 | Test 3.8992e-02 | SO3(train/test) 1.34e-05/1.37e-05 | Fail(train/test) 0/0 | LR 3.13e-03 | 5.5s
# Epoch  134 | Step  2680/ 5000 | Train 4.3427e-02 | Test 4.9997e-02 | SO3(train/test) 1.30e-05/1.37e-05 | Fail(train/test) 0/0 | LR 3.09e-03 | 5.3s
# Epoch  135 | Step  2700/ 5000 | Train 3.4867e-02 | Test 3.4375e-02 | SO3(train/test) 1.11e-05/1.16e-05 | Fail(train/test) 0/0 | LR 3.05e-03 | 5.6s
# Epoch  136 | Step  2720/ 5000 | Train 2.9001e-02 | Test 2.9626e-02 | SO3(train/test) 1.18e-05/1.43e-05 | Fail(train/test) 0/0 | LR 3.01e-03 | 5.3s
# Epoch  137 | Step  2740/ 5000 | Train 2.7668e-02 | Test 2.9802e-02 | SO3(train/test) 1.26e-05/1.46e-05 | Fail(train/test) 0/0 | LR 2.97e-03 | 5.4s
# Epoch  138 | Step  2760/ 5000 | Train 2.7404e-02 | Test 2.9891e-02 | SO3(train/test) 1.31e-05/1.62e-05 | Fail(train/test) 0/0 | LR 2.93e-03 | 5.4s
# Epoch  139 | Step  2780/ 5000 | Train 2.9435e-02 | Test 2.9188e-02 | SO3(train/test) 1.31e-05/1.54e-05 | Fail(train/test) 0/0 | LR 2.89e-03 | 5.4s
# Epoch  140 | Step  2800/ 5000 | Train 2.7467e-02 | Test 2.8769e-02 | SO3(train/test) 1.29e-05/1.60e-05 | Fail(train/test) 0/0 | LR 2.85e-03 | 5.5s
# Epoch  141 | Step  2820/ 5000 | Train 2.7111e-02 | Test 2.8233e-02 | SO3(train/test) 1.31e-05/1.50e-05 | Fail(train/test) 0/0 | LR 2.81e-03 | 5.3s
# Epoch  142 | Step  2840/ 5000 | Train 2.6615e-02 | Test 2.7977e-02 | SO3(train/test) 1.31e-05/1.52e-05 | Fail(train/test) 0/0 | LR 2.77e-03 | 5.5s
# Epoch  143 | Step  2860/ 5000 | Train 2.6010e-02 | Test 2.9618e-02 | SO3(train/test) 1.33e-05/1.45e-05 | Fail(train/test) 0/0 | LR 2.73e-03 | 5.4s
# Epoch  144 | Step  2880/ 5000 | Train 2.7295e-02 | Test 2.8119e-02 | SO3(train/test) 1.31e-05/1.39e-05 | Fail(train/test) 0/0 | LR 2.69e-03 | 5.4s
# Epoch  145 | Step  2900/ 5000 | Train 2.6059e-02 | Test 2.7043e-02 | SO3(train/test) 1.28e-05/1.51e-05 | Fail(train/test) 0/0 | LR 2.65e-03 | 5.5s
# Epoch  146 | Step  2920/ 5000 | Train 2.5244e-02 | Test 2.6632e-02 | SO3(train/test) 1.32e-05/1.57e-05 | Fail(train/test) 0/0 | LR 2.61e-03 | 5.5s
# Epoch  147 | Step  2940/ 5000 | Train 2.5004e-02 | Test 2.6802e-02 | SO3(train/test) 1.34e-05/1.55e-05 | Fail(train/test) 0/0 | LR 2.57e-03 | 5.3s
# Epoch  148 | Step  2960/ 5000 | Train 2.5628e-02 | Test 2.6618e-02 | SO3(train/test) 1.33e-05/1.63e-05 | Fail(train/test) 0/0 | LR 2.53e-03 | 5.3s
# Epoch  149 | Step  2980/ 5000 | Train 2.5259e-02 | Test 2.6860e-02 | SO3(train/test) 1.34e-05/1.53e-05 | Fail(train/test) 0/0 | LR 2.49e-03 | 5.5s
# Epoch  150 | Step  3000/ 5000 | Train 2.6711e-02 | Test 2.6026e-02 | SO3(train/test) 1.32e-05/1.55e-05 | Fail(train/test) 0/0 | LR 2.45e-03 | 5.4s
# Epoch  151 | Step  3020/ 5000 | Train 2.4820e-02 | Test 2.6025e-02 | SO3(train/test) 1.31e-05/1.52e-05 | Fail(train/test) 0/0 | LR 2.41e-03 | 5.3s
# Epoch  152 | Step  3040/ 5000 | Train 2.4584e-02 | Test 2.5668e-02 | SO3(train/test) 1.34e-05/1.54e-05 | Fail(train/test) 0/0 | LR 2.37e-03 | 5.4s
# Epoch  153 | Step  3060/ 5000 | Train 2.4298e-02 | Test 2.5347e-02 | SO3(train/test) 1.35e-05/1.61e-05 | Fail(train/test) 0/0 | LR 2.33e-03 | 5.3s
# Epoch  154 | Step  3080/ 5000 | Train 2.3955e-02 | Test 2.5326e-02 | SO3(train/test) 1.37e-05/1.61e-05 | Fail(train/test) 0/0 | LR 2.29e-03 | 5.3s
# Epoch  155 | Step  3100/ 5000 | Train 2.3989e-02 | Test 2.5399e-02 | SO3(train/test) 1.37e-05/1.59e-05 | Fail(train/test) 0/0 | LR 2.25e-03 | 5.5s
# Epoch  156 | Step  3120/ 5000 | Train 2.3956e-02 | Test 2.5533e-02 | SO3(train/test) 1.37e-05/1.68e-05 | Fail(train/test) 0/0 | LR 2.21e-03 | 5.6s
# Epoch  157 | Step  3140/ 5000 | Train 2.5532e-02 | Test 3.0043e-02 | SO3(train/test) 1.37e-05/1.41e-05 | Fail(train/test) 0/0 | LR 2.18e-03 | 5.3s
# Epoch  158 | Step  3160/ 5000 | Train 3.2485e-02 | Test 3.5891e-02 | SO3(train/test) 1.40e-05/2.08e-05 | Fail(train/test) 0/0 | LR 2.14e-03 | 5.5s
# Epoch  159 | Step  3180/ 5000 | Train 3.2483e-02 | Test 4.4318e-02 | SO3(train/test) 1.31e-05/2.05e-05 | Fail(train/test) 0/0 | LR 2.10e-03 | 5.4s
# Epoch  160 | Step  3200/ 5000 | Train 3.3353e-02 | Test 3.4272e-02 | SO3(train/test) 1.34e-05/1.54e-05 | Fail(train/test) 0/0 | LR 2.06e-03 | 5.5s
# Epoch  161 | Step  3220/ 5000 | Train 3.5088e-02 | Test 3.3866e-02 | SO3(train/test) 1.40e-05/1.21e-05 | Fail(train/test) 0/0 | LR 2.02e-03 | 5.4s
# Epoch  162 | Step  3240/ 5000 | Train 3.2934e-02 | Test 3.6461e-02 | SO3(train/test) 1.29e-05/1.80e-05 | Fail(train/test) 0/0 | LR 1.99e-03 | 5.4s
# Epoch  163 | Step  3260/ 5000 | Train 3.4208e-02 | Test 3.6580e-02 | SO3(train/test) 1.38e-05/1.21e-05 | Fail(train/test) 0/0 | LR 1.95e-03 | 5.4s
# Epoch  164 | Step  3280/ 5000 | Train 3.1215e-02 | Test 2.7848e-02 | SO3(train/test) 1.30e-05/1.42e-05 | Fail(train/test) 0/0 | LR 1.91e-03 | 5.4s
# Epoch  165 | Step  3300/ 5000 | Train 2.9076e-02 | Test 2.7911e-02 | SO3(train/test) 1.25e-05/1.50e-05 | Fail(train/test) 0/0 | LR 1.87e-03 | 5.6s
# Epoch  166 | Step  3320/ 5000 | Train 2.4993e-02 | Test 2.5819e-02 | SO3(train/test) 1.26e-05/1.51e-05 | Fail(train/test) 0/0 | LR 1.84e-03 | 5.4s
# Epoch  167 | Step  3340/ 5000 | Train 2.3758e-02 | Test 2.4824e-02 | SO3(train/test) 1.29e-05/1.52e-05 | Fail(train/test) 0/0 | LR 1.80e-03 | 5.5s
# Epoch  168 | Step  3360/ 5000 | Train 2.3448e-02 | Test 2.4653e-02 | SO3(train/test) 1.32e-05/1.53e-05 | Fail(train/test) 0/0 | LR 1.76e-03 | 5.4s
# Epoch  169 | Step  3380/ 5000 | Train 2.3361e-02 | Test 2.4450e-02 | SO3(train/test) 1.33e-05/1.56e-05 | Fail(train/test) 0/0 | LR 1.73e-03 | 5.4s
# Epoch  170 | Step  3400/ 5000 | Train 2.3115e-02 | Test 2.4331e-02 | SO3(train/test) 1.34e-05/1.60e-05 | Fail(train/test) 0/0 | LR 1.69e-03 | 5.4s
# Epoch  171 | Step  3420/ 5000 | Train 2.3131e-02 | Test 2.4436e-02 | SO3(train/test) 1.35e-05/1.53e-05 | Fail(train/test) 0/0 | LR 1.66e-03 | 5.3s
# Epoch  172 | Step  3440/ 5000 | Train 2.3047e-02 | Test 2.4144e-02 | SO3(train/test) 1.35e-05/1.64e-05 | Fail(train/test) 0/0 | LR 1.62e-03 | 5.5s
# Epoch  173 | Step  3460/ 5000 | Train 2.2915e-02 | Test 2.3998e-02 | SO3(train/test) 1.36e-05/1.60e-05 | Fail(train/test) 0/0 | LR 1.59e-03 | 5.5s
# Epoch  174 | Step  3480/ 5000 | Train 2.2788e-02 | Test 2.3845e-02 | SO3(train/test) 1.36e-05/1.60e-05 | Fail(train/test) 0/0 | LR 1.55e-03 | 5.5s
# Epoch  175 | Step  3500/ 5000 | Train 2.2764e-02 | Test 2.3994e-02 | SO3(train/test) 1.36e-05/1.62e-05 | Fail(train/test) 0/0 | LR 1.52e-03 | 5.4s
# Epoch  176 | Step  3520/ 5000 | Train 2.2707e-02 | Test 2.3744e-02 | SO3(train/test) 1.37e-05/1.62e-05 | Fail(train/test) 0/0 | LR 1.48e-03 | 5.4s
# Epoch  177 | Step  3540/ 5000 | Train 2.2628e-02 | Test 2.3701e-02 | SO3(train/test) 1.37e-05/1.61e-05 | Fail(train/test) 0/0 | LR 1.45e-03 | 5.4s
# Epoch  178 | Step  3560/ 5000 | Train 2.2593e-02 | Test 2.3626e-02 | SO3(train/test) 1.37e-05/1.66e-05 | Fail(train/test) 0/0 | LR 1.41e-03 | 5.4s
# Epoch  179 | Step  3580/ 5000 | Train 2.2456e-02 | Test 2.3482e-02 | SO3(train/test) 1.38e-05/1.61e-05 | Fail(train/test) 0/0 | LR 1.38e-03 | 5.5s
# Epoch  180 | Step  3600/ 5000 | Train 2.2382e-02 | Test 2.3415e-02 | SO3(train/test) 1.38e-05/1.62e-05 | Fail(train/test) 0/0 | LR 1.35e-03 | 5.5s
# Epoch  181 | Step  3620/ 5000 | Train 2.2374e-02 | Test 2.3629e-02 | SO3(train/test) 1.38e-05/1.58e-05 | Fail(train/test) 0/0 | LR 1.31e-03 | 5.4s
# Epoch  182 | Step  3640/ 5000 | Train 2.2390e-02 | Test 2.3559e-02 | SO3(train/test) 1.37e-05/1.59e-05 | Fail(train/test) 0/0 | LR 1.28e-03 | 5.3s
# Epoch  183 | Step  3660/ 5000 | Train 2.2239e-02 | Test 2.3114e-02 | SO3(train/test) 1.38e-05/1.63e-05 | Fail(train/test) 0/0 | LR 1.25e-03 | 5.4s
# Epoch  184 | Step  3680/ 5000 | Train 2.2121e-02 | Test 2.3209e-02 | SO3(train/test) 1.38e-05/1.65e-05 | Fail(train/test) 0/0 | LR 1.22e-03 | 5.4s
# Epoch  185 | Step  3700/ 5000 | Train 2.2120e-02 | Test 2.3213e-02 | SO3(train/test) 1.39e-05/1.63e-05 | Fail(train/test) 0/0 | LR 1.19e-03 | 5.5s
# Epoch  186 | Step  3720/ 5000 | Train 2.2092e-02 | Test 2.3113e-02 | SO3(train/test) 1.39e-05/1.65e-05 | Fail(train/test) 0/0 | LR 1.16e-03 | 5.3s
# Epoch  187 | Step  3740/ 5000 | Train 2.2077e-02 | Test 2.2930e-02 | SO3(train/test) 1.39e-05/1.64e-05 | Fail(train/test) 0/0 | LR 1.13e-03 | 5.4s
# Epoch  188 | Step  3760/ 5000 | Train 2.1943e-02 | Test 2.3001e-02 | SO3(train/test) 1.39e-05/1.64e-05 | Fail(train/test) 0/0 | LR 1.10e-03 | 5.4s
# Epoch  189 | Step  3780/ 5000 | Train 2.1876e-02 | Test 2.2884e-02 | SO3(train/test) 1.39e-05/1.63e-05 | Fail(train/test) 0/0 | LR 1.07e-03 | 5.4s
# Epoch  190 | Step  3800/ 5000 | Train 2.1808e-02 | Test 2.2842e-02 | SO3(train/test) 1.40e-05/1.65e-05 | Fail(train/test) 0/0 | LR 1.04e-03 | 5.5s
# Epoch  191 | Step  3820/ 5000 | Train 2.1803e-02 | Test 2.2791e-02 | SO3(train/test) 1.40e-05/1.62e-05 | Fail(train/test) 0/0 | LR 1.01e-03 | 5.3s
# Epoch  192 | Step  3840/ 5000 | Train 2.1758e-02 | Test 2.2759e-02 | SO3(train/test) 1.39e-05/1.67e-05 | Fail(train/test) 0/0 | LR 9.77e-04 | 5.4s
# Epoch  193 | Step  3860/ 5000 | Train 2.1674e-02 | Test 2.2622e-02 | SO3(train/test) 1.40e-05/1.63e-05 | Fail(train/test) 0/0 | LR 9.49e-04 | 5.3s
# Epoch  194 | Step  3880/ 5000 | Train 2.1614e-02 | Test 2.2550e-02 | SO3(train/test) 1.40e-05/1.65e-05 | Fail(train/test) 0/0 | LR 9.21e-04 | 5.3s
# Epoch  195 | Step  3900/ 5000 | Train 2.1638e-02 | Test 2.2655e-02 | SO3(train/test) 1.40e-05/1.61e-05 | Fail(train/test) 0/0 | LR 8.93e-04 | 5.5s
# Epoch  196 | Step  3920/ 5000 | Train 2.1541e-02 | Test 2.2546e-02 | SO3(train/test) 1.40e-05/1.64e-05 | Fail(train/test) 0/0 | LR 8.66e-04 | 5.3s
# Epoch  197 | Step  3940/ 5000 | Train 2.1594e-02 | Test 2.2483e-02 | SO3(train/test) 1.40e-05/1.65e-05 | Fail(train/test) 0/0 | LR 8.39e-04 | 5.4s
# Epoch  198 | Step  3960/ 5000 | Train 2.1514e-02 | Test 2.2474e-02 | SO3(train/test) 1.41e-05/1.63e-05 | Fail(train/test) 0/0 | LR 8.12e-04 | 5.3s
# Epoch  199 | Step  3980/ 5000 | Train 2.1475e-02 | Test 2.2411e-02 | SO3(train/test) 1.41e-05/1.65e-05 | Fail(train/test) 0/0 | LR 7.86e-04 | 5.4s
# Epoch  200 | Step  4000/ 5000 | Train 2.1388e-02 | Test 2.2300e-02 | SO3(train/test) 1.41e-05/1.64e-05 | Fail(train/test) 0/0 | LR 7.61e-04 | 5.4s
# Epoch  201 | Step  4020/ 5000 | Train 2.1384e-02 | Test 2.2376e-02 | SO3(train/test) 1.41e-05/1.65e-05 | Fail(train/test) 0/0 | LR 7.35e-04 | 5.4s
# Epoch  202 | Step  4040/ 5000 | Train 2.1419e-02 | Test 2.2321e-02 | SO3(train/test) 1.41e-05/1.66e-05 | Fail(train/test) 0/0 | LR 7.11e-04 | 5.5s
# Epoch  203 | Step  4060/ 5000 | Train 2.1366e-02 | Test 2.2277e-02 | SO3(train/test) 1.42e-05/1.63e-05 | Fail(train/test) 0/0 | LR 6.86e-04 | 5.4s
# Epoch  204 | Step  4080/ 5000 | Train 2.1320e-02 | Test 2.2381e-02 | SO3(train/test) 1.41e-05/1.62e-05 | Fail(train/test) 0/0 | LR 6.62e-04 | 5.6s
# Epoch  205 | Step  4100/ 5000 | Train 2.1320e-02 | Test 2.2222e-02 | SO3(train/test) 1.41e-05/1.63e-05 | Fail(train/test) 0/0 | LR 6.39e-04 | 5.5s
# Epoch  206 | Step  4120/ 5000 | Train 2.1253e-02 | Test 2.2175e-02 | SO3(train/test) 1.41e-05/1.65e-05 | Fail(train/test) 0/0 | LR 6.16e-04 | 5.5s
# Epoch  207 | Step  4140/ 5000 | Train 2.1260e-02 | Test 2.2265e-02 | SO3(train/test) 1.41e-05/1.68e-05 | Fail(train/test) 0/0 | LR 5.93e-04 | 5.4s
# Epoch  208 | Step  4160/ 5000 | Train 2.1227e-02 | Test 2.2316e-02 | SO3(train/test) 1.41e-05/1.69e-05 | Fail(train/test) 0/0 | LR 5.71e-04 | 5.5s
# Epoch  209 | Step  4180/ 5000 | Train 2.1171e-02 | Test 2.2067e-02 | SO3(train/test) 1.41e-05/1.65e-05 | Fail(train/test) 0/0 | LR 5.50e-04 | 5.5s
# Epoch  210 | Step  4200/ 5000 | Train 2.1187e-02 | Test 2.2041e-02 | SO3(train/test) 1.42e-05/1.64e-05 | Fail(train/test) 0/0 | LR 5.29e-04 | 5.6s
# Epoch  211 | Step  4220/ 5000 | Train 2.1151e-02 | Test 2.2014e-02 | SO3(train/test) 1.42e-05/1.64e-05 | Fail(train/test) 0/0 | LR 5.08e-04 | 5.5s
# Epoch  212 | Step  4240/ 5000 | Train 2.1102e-02 | Test 2.1956e-02 | SO3(train/test) 1.42e-05/1.64e-05 | Fail(train/test) 0/0 | LR 4.88e-04 | 5.5s
# Epoch  213 | Step  4260/ 5000 | Train 2.1054e-02 | Test 2.2005e-02 | SO3(train/test) 1.42e-05/1.65e-05 | Fail(train/test) 0/0 | LR 4.68e-04 | 5.6s
# Epoch  214 | Step  4280/ 5000 | Train 2.1035e-02 | Test 2.2077e-02 | SO3(train/test) 1.42e-05/1.63e-05 | Fail(train/test) 0/0 | LR 4.49e-04 | 5.5s
# Epoch  215 | Step  4300/ 5000 | Train 2.1044e-02 | Test 2.1951e-02 | SO3(train/test) 1.42e-05/1.67e-05 | Fail(train/test) 0/0 | LR 4.30e-04 | 5.5s
# Epoch  216 | Step  4320/ 5000 | Train 2.1021e-02 | Test 2.1956e-02 | SO3(train/test) 1.42e-05/1.64e-05 | Fail(train/test) 0/0 | LR 4.12e-04 | 5.4s
# Epoch  217 | Step  4340/ 5000 | Train 2.0982e-02 | Test 2.1933e-02 | SO3(train/test) 1.42e-05/1.66e-05 | Fail(train/test) 0/0 | LR 3.94e-04 | 5.3s
# Epoch  218 | Step  4360/ 5000 | Train 2.0979e-02 | Test 2.1888e-02 | SO3(train/test) 1.42e-05/1.66e-05 | Fail(train/test) 0/0 | LR 3.77e-04 | 5.3s
# Epoch  219 | Step  4380/ 5000 | Train 2.0944e-02 | Test 2.1924e-02 | SO3(train/test) 1.42e-05/1.68e-05 | Fail(train/test) 0/0 | LR 3.60e-04 | 5.3s
# Epoch  220 | Step  4400/ 5000 | Train 2.0990e-02 | Test 2.1818e-02 | SO3(train/test) 1.43e-05/1.66e-05 | Fail(train/test) 0/0 | LR 3.44e-04 | 5.4s
# Epoch  221 | Step  4420/ 5000 | Train 2.0937e-02 | Test 2.1865e-02 | SO3(train/test) 1.42e-05/1.64e-05 | Fail(train/test) 0/0 | LR 3.28e-04 | 5.3s
# Epoch  222 | Step  4440/ 5000 | Train 2.0920e-02 | Test 2.1801e-02 | SO3(train/test) 1.42e-05/1.67e-05 | Fail(train/test) 0/0 | LR 3.12e-04 | 5.4s
# Epoch  223 | Step  4460/ 5000 | Train 2.0916e-02 | Test 2.1859e-02 | SO3(train/test) 1.42e-05/1.66e-05 | Fail(train/test) 0/0 | LR 2.98e-04 | 5.4s
# Epoch  224 | Step  4480/ 5000 | Train 2.0931e-02 | Test 2.1855e-02 | SO3(train/test) 1.42e-05/1.68e-05 | Fail(train/test) 0/0 | LR 2.83e-04 | 5.4s
# Epoch  225 | Step  4500/ 5000 | Train 2.0911e-02 | Test 2.1785e-02 | SO3(train/test) 1.43e-05/1.66e-05 | Fail(train/test) 0/0 | LR 2.70e-04 | 5.5s
# Epoch  226 | Step  4520/ 5000 | Train 2.0882e-02 | Test 2.1751e-02 | SO3(train/test) 1.42e-05/1.66e-05 | Fail(train/test) 0/0 | LR 2.57e-04 | 5.4s
# Epoch  227 | Step  4540/ 5000 | Train 2.0840e-02 | Test 2.1726e-02 | SO3(train/test) 1.42e-05/1.66e-05 | Fail(train/test) 0/0 | LR 2.44e-04 | 5.4s
# Epoch  228 | Step  4560/ 5000 | Train 2.0835e-02 | Test 2.1750e-02 | SO3(train/test) 1.42e-05/1.66e-05 | Fail(train/test) 0/0 | LR 2.32e-04 | 5.5s
# Epoch  229 | Step  4580/ 5000 | Train 2.0811e-02 | Test 2.1697e-02 | SO3(train/test) 1.42e-05/1.65e-05 | Fail(train/test) 0/0 | LR 2.20e-04 | 5.4s
# Epoch  230 | Step  4600/ 5000 | Train 2.0808e-02 | Test 2.1719e-02 | SO3(train/test) 1.42e-05/1.65e-05 | Fail(train/test) 0/0 | LR 2.09e-04 | 5.4s
# Epoch  231 | Step  4620/ 5000 | Train 2.0804e-02 | Test 2.1703e-02 | SO3(train/test) 1.43e-05/1.66e-05 | Fail(train/test) 0/0 | LR 1.98e-04 | 5.4s
# Epoch  232 | Step  4640/ 5000 | Train 2.0797e-02 | Test 2.1728e-02 | SO3(train/test) 1.42e-05/1.66e-05 | Fail(train/test) 0/0 | LR 1.88e-04 | 5.4s
# Epoch  233 | Step  4660/ 5000 | Train 2.0810e-02 | Test 2.1714e-02 | SO3(train/test) 1.42e-05/1.68e-05 | Fail(train/test) 0/0 | LR 1.79e-04 | 5.3s
# Epoch  234 | Step  4680/ 5000 | Train 2.0777e-02 | Test 2.1653e-02 | SO3(train/test) 1.43e-05/1.66e-05 | Fail(train/test) 0/0 | LR 1.70e-04 | 5.4s
# Epoch  235 | Step  4700/ 5000 | Train 2.0765e-02 | Test 2.1699e-02 | SO3(train/test) 1.43e-05/1.65e-05 | Fail(train/test) 0/0 | LR 1.61e-04 | 5.4s
# Epoch  236 | Step  4720/ 5000 | Train 2.0743e-02 | Test 2.1691e-02 | SO3(train/test) 1.42e-05/1.66e-05 | Fail(train/test) 0/0 | LR 1.53e-04 | 5.4s
# Epoch  237 | Step  4740/ 5000 | Train 2.0763e-02 | Test 2.1671e-02 | SO3(train/test) 1.43e-05/1.67e-05 | Fail(train/test) 0/0 | LR 1.46e-04 | 5.3s
# Epoch  238 | Step  4760/ 5000 | Train 2.0775e-02 | Test 2.1632e-02 | SO3(train/test) 1.43e-05/1.65e-05 | Fail(train/test) 0/0 | LR 1.39e-04 | 5.4s
# Epoch  239 | Step  4780/ 5000 | Train 2.0730e-02 | Test 2.1610e-02 | SO3(train/test) 1.42e-05/1.65e-05 | Fail(train/test) 0/0 | LR 1.33e-04 | 5.3s
# Epoch  240 | Step  4800/ 5000 | Train 2.0729e-02 | Test 2.1628e-02 | SO3(train/test) 1.43e-05/1.65e-05 | Fail(train/test) 0/0 | LR 1.27e-04 | 5.5s
# Epoch  241 | Step  4820/ 5000 | Train 2.0721e-02 | Test 2.1611e-02 | SO3(train/test) 1.43e-05/1.66e-05 | Fail(train/test) 0/0 | LR 1.22e-04 | 5.3s
# Epoch  242 | Step  4840/ 5000 | Train 2.0710e-02 | Test 2.1614e-02 | SO3(train/test) 1.43e-05/1.66e-05 | Fail(train/test) 0/0 | LR 1.17e-04 | 5.3s
# Epoch  243 | Step  4860/ 5000 | Train 2.0712e-02 | Test 2.1630e-02 | SO3(train/test) 1.43e-05/1.66e-05 | Fail(train/test) 0/0 | LR 1.13e-04 | 5.3s
# Epoch  244 | Step  4880/ 5000 | Train 2.0718e-02 | Test 2.1632e-02 | SO3(train/test) 1.43e-05/1.65e-05 | Fail(train/test) 0/0 | LR 1.10e-04 | 5.3s
# Epoch  245 | Step  4900/ 5000 | Train 2.0698e-02 | Test 2.1594e-02 | SO3(train/test) 1.43e-05/1.65e-05 | Fail(train/test) 0/0 | LR 1.07e-04 | 5.4s
# Epoch  246 | Step  4920/ 5000 | Train 2.0695e-02 | Test 2.1597e-02 | SO3(train/test) 1.43e-05/1.66e-05 | Fail(train/test) 0/0 | LR 1.04e-04 | 5.3s
# Epoch  247 | Step  4940/ 5000 | Train 2.0687e-02 | Test 2.1613e-02 | SO3(train/test) 1.43e-05/1.64e-05 | Fail(train/test) 0/0 | LR 1.02e-04 | 5.3s
# Epoch  248 | Step  4960/ 5000 | Train 2.0683e-02 | Test 2.1604e-02 | SO3(train/test) 1.43e-05/1.65e-05 | Fail(train/test) 0/0 | LR 1.01e-04 | 5.4s
# Epoch  249 | Step  4980/ 5000 | Train 2.0674e-02 | Test 2.1578e-02 | SO3(train/test) 1.43e-05/1.67e-05 | Fail(train/test) 0/0 | LR 1.00e-04 | 5.3s
# Epoch  250 | Step  5000/ 5000 | Train 2.0702e-02 | Test 2.1574e-02 | SO3(train/test) 1.43e-05/1.65e-05 | Fail(train/test) 0/0 | LR 1.00e-04 | 5.5s
# Reached target optimizer steps: 5000/5000
# Done. Best validation score: failure_rate=0.0000, test_loss=2.1574e-02 (epoch 250)
# Running detailed evaluation...
# Block evaluation profile: clean
# Block evaluation noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0018 +/- 0.0014  (max 0.0065)
# Rotation geo [rad]:  0.0021 +/- 0.0015  (max 0.0068)
# Lin vel RMSE [m/s]:  0.0190 +/- 0.0151
# Ang vel RMSE [r/s]:  0.0025 +/- 0.0014
# Components:  u=0.0328  v=0.0012  w=0.0012  p=0.0028  q=0.0023  r=0.0018
# SO(3) violation:  |det-1|=1.62e-05  ||RR^T-I||=2.29e-05
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# Block evaluation profile: nominal_eval
# Block evaluation noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0024 +/- 0.0013  (max 0.0069)
# Rotation geo [rad]:  0.0087 +/- 0.0057  (max 0.0362)
# Lin vel RMSE [m/s]:  0.0205 +/- 0.0146
# Ang vel RMSE [r/s]:  0.0038 +/- 0.0018
# Components:  u=0.0348  v=0.0033  w=0.0033  p=0.0052  q=0.0025  r=0.0021
# SO(3) violation:  |det-1|=1.64e-05  ||RR^T-I||=2.33e-05
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# Block evaluation profile: heading_biased_eval
# Block evaluation noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0053 +/- 0.0018  (max 0.0108)
# Rotation geo [rad]:  0.0352 +/- 0.0097  (max 0.0656)
# Lin vel RMSE [m/s]:  0.0222 +/- 0.0140
# Ang vel RMSE [r/s]:  0.0038 +/- 0.0018
# Components:  u=0.0357  v=0.0091  w=0.0036  p=0.0052  q=0.0025  r=0.0021
# SO(3) violation:  |det-1|=1.64e-05  ||RR^T-I||=2.33e-05
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Block Evaluation Relative To Clean
# ==================================================
# [nominal_eval]
# position_rmse: ratio=1.354  degradation=+35.4%
# rotation_geodesic: ratio=4.204  degradation=+320.4%
# velocity_rmse: ratio=1.080  degradation=+8.0%
# angular_rmse: ratio=1.491  degradation=+49.1%
# failure_rate: ratio=1.000  degradation=+0.0%
# [heading_biased_eval]
# position_rmse: ratio=3.026  degradation=+202.6%
# rotation_geodesic: ratio=16.930  degradation=+1593.0%
# velocity_rmse: ratio=1.169  degradation=+16.9%
# angular_rmse: ratio=1.490  degradation=+49.0%
# failure_rate: ratio=1.000  degradation=+0.0%
# Running held-out trajectory evaluation...
# Held-out evaluation profile: clean
# Held-out evaluation noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0012 (median 0.0012, p95 0.0020)
# Rotation geo [rad]:  0.0017 (median 0.0018, p95 0.0024)
# Lin vel RMSE [m/s]:  0.0125  Ang vel RMSE [r/s]:  0.0018
# SO(3) violation:  |det-1|=1.09e-05  ||RR^T-I||=1.55e-05
# Noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# [CHIRP] pos=0.0004 m, rot=0.0008 rad, success=1.0000
# [OU] pos=0.0012 m, rot=0.0019 rad, success=1.0000
# [PRBS] pos=0.0015 m, rot=0.0020 rad, success=1.0000
# Held-out evaluation profile: nominal_eval
# Held-out evaluation noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0018 (median 0.0017, p95 0.0026)
# Rotation geo [rad]:  0.0089 (median 0.0089, p95 0.0099)
# Lin vel RMSE [m/s]:  0.0148  Ang vel RMSE [r/s]:  0.0030
# SO(3) violation:  |det-1|=1.14e-05  ||RR^T-I||=1.62e-05
# Noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# [CHIRP] pos=0.0013 m, rot=0.0086 rad, success=1.0000
# [OU] pos=0.0018 m, rot=0.0090 rad, success=1.0000
# [PRBS] pos=0.0020 m, rot=0.0090 rad, success=1.0000
# Held-out evaluation profile: degraded_eval
# Held-out evaluation noise budget: protocol=iid_noisy_ic | profile=degraded_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0032 (median 0.0030, p95 0.0042)
# Rotation geo [rad]:  0.0211 (median 0.0210, p95 0.0233)
# Lin vel RMSE [m/s]:  0.0196  Ang vel RMSE [r/s]:  0.0049
# SO(3) violation:  |det-1|=1.26e-05  ||RR^T-I||=1.79e-05
# Noise budget: protocol=iid_noisy_ic | profile=degraded_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250]
# [CHIRP] pos=0.0029 m, rot=0.0209 rad, success=1.0000
# [OU] pos=0.0031 m, rot=0.0212 rad, success=1.0000
# [PRBS] pos=0.0034 m, rot=0.0210 rad, success=1.0000
# Held-out evaluation profile: heading_biased_eval
# Held-out evaluation noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0043 (median 0.0041, p95 0.0057)
# ...
# Epoch  235 | Step  4700/ 5000 | Train 2.1057e-02 | Test 6.2452e-03 | SO3(train/test) 3.70e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.61e-04 | 5.5s
# Epoch  236 | Step  4720/ 5000 | Train 2.1164e-02 | Test 6.2888e-03 | SO3(train/test) 3.68e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.53e-04 | 5.5s
# Epoch  237 | Step  4740/ 5000 | Train 2.0906e-02 | Test 6.3085e-03 | SO3(train/test) 3.68e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.46e-04 | 5.4s
# Epoch  238 | Step  4760/ 5000 | Train 2.1023e-02 | Test 6.2486e-03 | SO3(train/test) 3.69e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.39e-04 | 5.6s
# Epoch  239 | Step  4780/ 5000 | Train 2.0753e-02 | Test 6.2218e-03 | SO3(train/test) 3.68e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.33e-04 | 5.5s
# Epoch  240 | Step  4800/ 5000 | Train 2.1170e-02 | Test 6.2380e-03 | SO3(train/test) 3.71e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.27e-04 | 5.5s
# Epoch  241 | Step  4820/ 5000 | Train 2.1122e-02 | Test 6.3126e-03 | SO3(train/test) 3.68e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.22e-04 | 5.6s
# Epoch  242 | Step  4840/ 5000 | Train 2.1148e-02 | Test 6.2956e-03 | SO3(train/test) 3.70e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.17e-04 | 5.6s
# Epoch  243 | Step  4860/ 5000 | Train 2.1148e-02 | Test 6.2999e-03 | SO3(train/test) 3.68e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.13e-04 | 5.6s
# Epoch  244 | Step  4880/ 5000 | Train 2.1150e-02 | Test 6.3157e-03 | SO3(train/test) 3.68e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.10e-04 | 5.5s
# Epoch  245 | Step  4900/ 5000 | Train 2.0967e-02 | Test 6.2531e-03 | SO3(train/test) 3.67e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.07e-04 | 5.5s
# Epoch  246 | Step  4920/ 5000 | Train 2.1117e-02 | Test 6.2888e-03 | SO3(train/test) 3.65e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.04e-04 | 5.4s
# Epoch  247 | Step  4940/ 5000 | Train 2.0991e-02 | Test 6.2911e-03 | SO3(train/test) 3.68e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.02e-04 | 5.5s
# Epoch  248 | Step  4960/ 5000 | Train 2.0909e-02 | Test 6.2705e-03 | SO3(train/test) 3.68e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.01e-04 | 5.6s
# Epoch  249 | Step  4980/ 5000 | Train 2.0865e-02 | Test 6.2506e-03 | SO3(train/test) 3.67e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.00e-04 | 5.6s
# Epoch  250 | Step  5000/ 5000 | Train 2.0986e-02 | Test 6.2143e-03 | SO3(train/test) 3.67e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.00e-04 | 5.6s
# Reached target optimizer steps: 5000/5000
# Done. Best validation score: failure_rate=0.0000, test_loss=6.2043e-03 (epoch 218)
# Running detailed evaluation...
# Block evaluation profile: clean
# Block evaluation noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0002 +/- 0.0001  (max 0.0006)
# Rotation geo [rad]:  0.0005 +/- 0.0000  (max 0.0007)
# Lin vel RMSE [m/s]:  0.0019 +/- 0.0014
# Ang vel RMSE [r/s]:  0.0010 +/- 0.0006
# Components:  u=0.0031  v=0.0004  w=0.0004  p=0.0012  q=0.0007  r=0.0005
# SO(3) violation:  |det-1|=6.09e-08  ||RR^T-I||=1.28e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# Block evaluation profile: nominal_eval
# Block evaluation noise budget: protocol=v4_lite | profile=nominal_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0012 +/- 0.0008  (max 0.0045)
# Rotation geo [rad]:  0.0076 +/- 0.0053  (max 0.0302)
# Lin vel RMSE [m/s]:  0.0047 +/- 0.0022
# Ang vel RMSE [r/s]:  0.0029 +/- 0.0017
# Components:  u=0.0060  v=0.0029  w=0.0030  p=0.0045  q=0.0010  r=0.0012
# SO(3) violation:  |det-1|=3.00e-07  ||RR^T-I||=6.48e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=v4_lite | profile=nominal_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# Block evaluation profile: heading_biased_eval
# Block evaluation noise budget: protocol=v4_lite | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0050 +/- 0.0016  (max 0.0094)
# Rotation geo [rad]:  0.0361 +/- 0.0089  (max 0.0634)
# Lin vel RMSE [m/s]:  0.0082 +/- 0.0040
# Ang vel RMSE [r/s]:  0.0029 +/- 0.0017
# Components:  u=0.0083  v=0.0087  w=0.0033  p=0.0045  q=0.0010  r=0.0012
# SO(3) violation:  |det-1|=2.91e-07  ||RR^T-I||=6.14e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=v4_lite | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Block Evaluation Relative To Clean
# ==================================================
# [nominal_eval]
# position_rmse: ratio=7.396  degradation=+639.6%
# rotation_geodesic: ratio=15.542  degradation=+1454.2%
# velocity_rmse: ratio=2.482  degradation=+148.2%
# angular_rmse: ratio=3.052  degradation=+205.2%
# failure_rate: ratio=1.000  degradation=+0.0%
# [heading_biased_eval]
# position_rmse: ratio=30.908  degradation=+2990.8%
# rotation_geodesic: ratio=73.382  degradation=+7238.2%
# velocity_rmse: ratio=4.346  degradation=+334.6%
# angular_rmse: ratio=3.045  degradation=+204.5%
# failure_rate: ratio=1.000  degradation=+0.0%
# Running held-out trajectory evaluation...
# Held-out evaluation profile: clean
# Held-out evaluation noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0001 (median 0.0001, p95 0.0002)
# Rotation geo [rad]:  0.0005 (median 0.0005, p95 0.0005)
# Lin vel RMSE [m/s]:  0.0016  Ang vel RMSE [r/s]:  0.0008
# SO(3) violation:  |det-1|=6.04e-08  ||RR^T-I||=1.17e-07
# Noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# [CHIRP] pos=0.0000 m, rot=0.0005 rad, success=1.0000
# [OU] pos=0.0002 m, rot=0.0005 rad, success=1.0000
# [PRBS] pos=0.0002 m, rot=0.0005 rad, success=1.0000
# Held-out evaluation profile: nominal_eval
# Held-out evaluation noise budget: protocol=v4_lite | profile=nominal_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0011 (median 0.0011, p95 0.0015)
# Rotation geo [rad]:  0.0087 (median 0.0086, p95 0.0105)
# Lin vel RMSE [m/s]:  0.0044  Ang vel RMSE [r/s]:  0.0028
# SO(3) violation:  |det-1|=2.91e-07  ||RR^T-I||=6.19e-07
# Noise budget: protocol=v4_lite | profile=nominal_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# [CHIRP] pos=0.0010 m, rot=0.0086 rad, success=1.0000
# [OU] pos=0.0011 m, rot=0.0086 rad, success=1.0000
# [PRBS] pos=0.0012 m, rot=0.0088 rad, success=1.0000
# Held-out evaluation profile: degraded_eval
# Held-out evaluation noise budget: protocol=v4_lite | profile=degraded_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0026 (median 0.0026, p95 0.0035)
# Rotation geo [rad]:  0.0212 (median 0.0211, p95 0.0258)
# Lin vel RMSE [m/s]:  0.0086  Ang vel RMSE [r/s]:  0.0053
# SO(3) violation:  |det-1|=2.92e-07  ||RR^T-I||=6.25e-07
# Noise budget: protocol=v4_lite | profile=degraded_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250]
# [CHIRP] pos=0.0025 m, rot=0.0209 rad, success=1.0000
# [OU] pos=0.0025 m, rot=0.0210 rad, success=1.0000
# [PRBS] pos=0.0027 m, rot=0.0214 rad, success=1.0000
# Held-out evaluation profile: heading_biased_eval
# Held-out evaluation noise budget: protocol=v4_lite | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0041 (median 0.0040, p95 0.0053)
# Rotation geo [rad]:  0.0356 (median 0.0356, p95 0.0406)
# Lin vel RMSE [m/s]:  0.0070  Ang vel RMSE [r/s]:  0.0028
# SO(3) violation:  |det-1|=2.95e-07  ||RR^T-I||=6.27e-07
# Noise budget: protocol=v4_lite | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# [CHIRP] pos=0.0039 m, rot=0.0354 rad, success=1.0000
# [OU] pos=0.0040 m, rot=0.0357 rad, success=1.0000
# [PRBS] pos=0.0042 m, rot=0.0357 rad, success=1.0000
# ==================================================
# Held-Out Evaluation Relative To Clean
# ==================================================
# [nominal_eval]
# position_rmse: ratio=8.164  degradation=+716.4%
# rotation_geodesic: ratio=17.656  degradation=+1665.6%
# velocity_rmse: ratio=2.814  degradation=+181.4%
# angular_rmse: ratio=3.380  degradation=+238.0%
# success_rate: ratio=1.000  degradation=+0.0%
# trajectory_failure_rate: ratio=1.000  degradation=+0.0%
# [degraded_eval]
# position_rmse: ratio=19.139  degradation=+1813.9%
# rotation_geodesic: ratio=43.185  degradation=+4218.5%
# velocity_rmse: ratio=5.426  degradation=+442.6%
# angular_rmse: ratio=6.448  degradation=+544.8%
# success_rate: ratio=1.000  degradation=+0.0%
# trajectory_failure_rate: ratio=1.000  degradation=+0.0%
# [heading_biased_eval]
# position_rmse: ratio=29.781  degradation=+2878.1%
# rotation_geodesic: ratio=72.658  degradation=+7165.8%
# velocity_rmse: ratio=4.455  degradation=+345.5%
# angular_rmse: ratio=3.380  degradation=+238.0%
# success_rate: ratio=1.000  degradation=+0.0%
# trajectory_failure_rate: ratio=1.000  degradation=+0.0%
#
# Training finished. Results: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42
# Training sweep complete.
# Manifest: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_phnode_qforce/runs.tsv
# Next step:
#   scripts/batch_eval_models.sh --suite-dir "/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_phnode_qforce"
#
# Training complete.
# Suite directory: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_phnode_qforce
# Next step:
#   bash scripts/eval_all_models_noise_profile.sh --suite-dir "/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_phnode_qforce"
# [audit] /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_qforce
# [audit] /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_phnode_qforce
# [audit] /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_phnode_qforce
#                                             suite_name    group    model_type  seed train_noise_protocol  best_epoch  best_loss  noise_warmup_epochs  noise_ramp_epochs  noise_mix_ratio  epoch_scale_at_best  is_effectively_clean_at_best
#  sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_qforce baseline phnode_qforce    42                clean         250   0.021574                   20                 80              0.5                  0.0                          True
#    sweep_oc_phase1a_smoke1_iid_t2_wpfrag_phnode_qforce baseline phnode_qforce    42         iid_noisy_ic         247   0.023692                   20                 80              0.5                  1.0                         False
# sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_phnode_qforce baseline phnode_qforce    42              v4_lite         218   0.006204                   20                 80              0.5                  1.0                         False
# + /usr/bin/python3 /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/scripts/validate_v4_lite_protocol.py --run-dir /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42
# v4_lite protocol validation saved to: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/v4_lite_protocol_validation.json
# overall_passed=True
# same_epoch_stability: passed=True
# epoch_resampling: passed=True
# heading_bias_overlay: passed=True
# [validate] /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/v4_lite_protocol_validation.json

# %%
os.environ["MODE"] = "smoke1_eval"
# !bash scripts/run_phase1a_oc_v4lite.sh
# Out:
# [phase1a]
# MODE=smoke1_eval
# RUN_TAG=t2_wpfrag_phnode_qforce
# DATASET=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# DEVICE=cuda
# PHASE1A_MODELS=phnode_qforce
# SMOKE1_MODELS=phnode_qforce
# SMOKE_SEEDS=42
# DECISION_SEEDS=42 43 44 45 46
# NOISE_REFERENCE=remus100_dr
# PHASE1A_LOG_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_logs/t2_wpfrag_phnode_qforce
# PHASE1A_METADATA_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_metadata_t2_wpfrag_phnode_qforce
# [eval] suite=sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_qforce eval_protocol=iid_noisy_ic profiles=clean nominal_eval degraded_eval heading_biased_eval
# Suite directory: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_qforce
# Manifest: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_qforce/runs.tsv
# Mode: resampled
# [eval] baseline_phnode_qforce_seed42
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=clean | noise_protocol=clean | noise_budget=protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000] | scenarios=PRBS,CHIRP,OU | trajectories=18 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260523_180949/clean
# [scenario 1/3] PRBS | 6 trajectories
# [1/18] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=15m23.2s
# [5/18] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=2m21.2s
# [6/18] PRBS seed=47 done | reason=completed | sim_time=60.00s | eta=1m48.6s
# [scenario done] PRBS | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=4.8636 m | pos_p95=10.6547 m | rot_med=0.1154 rad | completion=1.000 | elapsed=54.4s
# [scenario 2/3] CHIRP | 6 trajectories
# [7/18] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=2m50.4s
# [11/18] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=1m09.0s
# [12/18] CHIRP seed=100047 done | reason=completed | sim_time=60.00s | eta=54.2s
# [scenario done] CHIRP | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=2.0843 m | pos_p95=4.1218 m | rot_med=0.0552 rad | completion=1.000 | elapsed=1m48.5s
# [scenario 3/3] OU | 6 trajectories
# [13/18] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=1m02.7s
# [17/18] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=9.6s
# [18/18] OU seed=200047 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=5.1771 m | pos_p95=14.6719 m | rot_med=0.2061 rad | completion=1.000 | elapsed=2m43.0s
# Benchmark finished in 2m56.2s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260523_180949/clean
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: pH NODE q-Force [baseline/core]
# Canonical model type: phnode_qforce
# Energy semantics: not_comparable
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 6
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.6309 m | pos p95=2.2509 m | rot median=0.0235 rad | total vel median=0.0938 m/s | rel vel median=0.0947 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=1.9583 m | pos p95=3.7826 m | rot median=0.0443 rad | total vel median=0.1047 m/s | rel vel median=0.1060 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=4.1172 m | pos p95=13.3741 m | rot median=0.0902 rad | total vel median=0.0971 m/s | rel vel median=0.0995 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=18 | completed=18 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=1.3115 m | pos p95=2.3575 m | rot median=0.0224 rad | total vel median=0.1211 m/s | rel vel median=0.1167 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=2.0480 m | pos p95=3.3500 m | rot median=0.0600 rad | total vel median=0.1434 m/s | rel vel median=0.1542 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=4.8636 m | pos p95=10.6547 m | rot median=0.1154 rad | total vel median=0.2004 m/s | rel vel median=0.2157 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.4785 m | pos p95=0.8286 m | rot median=0.0160 rad | total vel median=0.0479 m/s | rel vel median=0.0475 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.1688 m | pos p95=1.5982 m | rot median=0.0362 rad | total vel median=0.0743 m/s | rel vel median=0.0818 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=2.0843 m | pos p95=4.1218 m | rot median=0.0552 rad | total vel median=0.0367 m/s | rel vel median=0.0394 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.9380 m | pos p95=2.1605 m | rot median=0.0709 rad | total vel median=0.1730 m/s | rel vel median=0.1696 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=2.9703 m | pos p95=3.9289 m | rot median=0.0972 rad | total vel median=0.1429 m/s | rel vel median=0.1386 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=5.1771 m | pos p95=14.6719 m | rot median=0.2061 rad | total vel median=0.0868 m/s | rel vel median=0.0947 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Largest completed terminal errors
#   OU seed=200046 | reason=completed | sim_time=60.00s | pos=15.2126 m | rot=0.5957 rad | total_vel_violation=0
#   OU seed=200043 | reason=completed | sim_time=60.00s | pos=13.0496 m | rot=0.4330 rad | total_vel_violation=0
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=12.2075 m | rot=0.2186 rad | total_vel_violation=0
#   PRBS seed=43 | reason=completed | sim_time=60.00s | pos=5.9961 m | rot=0.1232 rad | total_vel_violation=0
#   OU seed=200042 | reason=completed | sim_time=60.00s | pos=5.8097 m | rot=0.1020 rad | total_vel_violation=0
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# OU seed=200046 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260523_180949/clean/diagnostic_plots/high_terminal_error_OU_seed200046.png
# OU seed=200043 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260523_180949/clean/diagnostic_plots/high_terminal_error_OU_seed200043.png
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=nominal_eval | noise_protocol=iid_noisy_ic | noise_budget=protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | scenarios=PRBS,CHIRP,OU | trajectories=18 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260523_180949/nominal_eval
# [scenario 1/3] PRBS | 6 trajectories
# [1/18] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=4m08.1s
# [5/18] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=38.0s
# [6/18] PRBS seed=47 done | reason=completed | sim_time=60.00s | eta=29.2s
# [scenario done] PRBS | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=4.4787 m | pos_p95=8.7529 m | rot_med=0.1134 rad | completion=1.000 | elapsed=14.6s
# [scenario 2/3] CHIRP | 6 trajectories
# [7/18] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=45.5s
# [11/18] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=18.4s
# [12/18] CHIRP seed=100047 done | reason=completed | sim_time=60.00s | eta=14.5s
# [scenario done] CHIRP | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=2.0279 m | pos_p95=3.7750 m | rot_med=0.0524 rad | completion=1.000 | elapsed=29.0s
# [scenario 3/3] OU | 6 trajectories
# [13/18] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=16.7s
# [17/18] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=2.6s
# [18/18] OU seed=200047 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=5.0272 m | pos_p95=14.5794 m | rot_med=0.2031 rad | completion=1.000 | elapsed=43.5s
# Benchmark finished in 56.1s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260523_180949/nominal_eval
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: pH NODE q-Force [baseline/core]
# Canonical model type: phnode_qforce
# Energy semantics: not_comparable
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 6
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.6272 m | pos p95=2.2176 m | rot median=0.0214 rad | total vel median=0.0945 m/s | rel vel median=0.0951 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=1.9012 m | pos p95=3.5399 m | rot median=0.0401 rad | total vel median=0.1044 m/s | rel vel median=0.1060 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=3.7720 m | pos p95=13.0627 m | rot median=0.0809 rad | total vel median=0.0962 m/s | rel vel median=0.0995 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=18 | completed=18 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=1.3127 m | pos p95=2.3523 m | rot median=0.0199 rad | total vel median=0.1154 m/s | rel vel median=0.1163 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=2.0023 m | pos p95=2.5272 m | rot median=0.0481 rad | total vel median=0.1429 m/s | rel vel median=0.1542 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=4.4787 m | pos p95=8.7529 m | rot median=0.1134 rad | total vel median=0.1982 m/s | rel vel median=0.2157 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.4988 m | pos p95=0.8472 m | rot median=0.0163 rad | total vel median=0.0490 m/s | rel vel median=0.0488 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.0239 m | pos p95=1.7797 m | rot median=0.0323 rad | total vel median=0.0742 m/s | rel vel median=0.0818 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=2.0279 m | pos p95=3.7750 m | rot median=0.0524 rad | total vel median=0.0360 m/s | rel vel median=0.0394 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.9175 m | pos p95=2.1333 m | rot median=0.0669 rad | total vel median=0.1729 m/s | rel vel median=0.1694 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=2.9948 m | pos p95=3.7635 m | rot median=0.0918 rad | total vel median=0.1433 m/s | rel vel median=0.1386 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=5.0272 m | pos p95=14.5794 m | rot median=0.2031 rad | total vel median=0.0863 m/s | rel vel median=0.0945 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Largest completed terminal errors
#   OU seed=200046 | reason=completed | sim_time=60.00s | pos=15.2113 m | rot=0.5959 rad | total_vel_violation=0
#   OU seed=200043 | reason=completed | sim_time=60.00s | pos=12.6835 m | rot=0.4274 rad | total_vel_violation=0
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=9.7436 m | rot=0.2001 rad | total_vel_violation=0
#   PRBS seed=47 | reason=completed | sim_time=60.00s | pos=5.7807 m | rot=0.1137 rad | total_vel_violation=0
#   OU seed=200042 | reason=completed | sim_time=60.00s | pos=5.2347 m | rot=0.0916 rad | total_vel_violation=0
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# OU seed=200046 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260523_180949/nominal_eval/diagnostic_plots/high_terminal_error_OU_seed200046.png
# OU seed=200043 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260523_180949/nominal_eval/diagnostic_plots/high_terminal_error_OU_seed200043.png
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=degraded_eval | noise_protocol=iid_noisy_ic | noise_budget=protocol=iid_noisy_ic | profile=degraded_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250] | scenarios=PRBS,CHIRP,OU | trajectories=18 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260523_180949/degraded_eval
# [scenario 1/3] PRBS | 6 trajectories
# [1/18] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=4m06.4s
# [5/18] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=37.7s
# [6/18] PRBS seed=47 done | reason=completed | sim_time=60.00s | eta=29.0s
# [scenario done] PRBS | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=3.7491 m | pos_p95=6.3931 m | rot_med=0.1118 rad | completion=1.000 | elapsed=14.5s
# [scenario 2/3] CHIRP | 6 trajectories
# [7/18] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=45.6s
# [11/18] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=18.5s
# [12/18] CHIRP seed=100047 done | reason=completed | sim_time=60.00s | eta=14.5s
# [scenario done] CHIRP | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=2.0687 m | pos_p95=4.3317 m | rot_med=0.0503 rad | completion=1.000 | elapsed=29.0s
# [scenario 3/3] OU | 6 trajectories
# [13/18] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=16.8s
# [17/18] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=2.6s
# [18/18] OU seed=200047 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=4.8370 m | pos_p95=14.4437 m | rot_med=0.1981 rad | completion=1.000 | elapsed=43.6s
# Benchmark finished in 56.2s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260523_180949/degraded_eval
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: pH NODE q-Force [baseline/core]
# Canonical model type: phnode_qforce
# Energy semantics: not_comparable
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 6
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.7303 m | pos p95=2.2133 m | rot median=0.0288 rad | total vel median=0.0953 m/s | rel vel median=0.0955 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=1.9521 m | pos p95=3.3187 m | rot median=0.0414 rad | total vel median=0.1039 m/s | rel vel median=0.1060 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=3.7491 m | pos p95=12.6013 m | rot median=0.0757 rad | total vel median=0.0949 m/s | rel vel median=0.0996 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=18 | completed=18 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=1.5118 m | pos p95=2.3929 m | rot median=0.0306 rad | total vel median=0.1107 m/s | rel vel median=0.1160 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.9521 m | pos p95=2.7353 m | rot median=0.0459 rad | total vel median=0.1420 m/s | rel vel median=0.1542 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=3.7491 m | pos p95=6.3931 m | rot median=0.1118 rad | total vel median=0.1993 m/s | rel vel median=0.2157 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.5555 m | pos p95=0.8639 m | rot median=0.0166 rad | total vel median=0.0501 m/s | rel vel median=0.0502 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.0262 m | pos p95=2.1012 m | rot median=0.0341 rad | total vel median=0.0740 m/s | rel vel median=0.0819 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=2.0687 m | pos p95=4.3317 m | rot median=0.0503 rad | total vel median=0.0353 m/s | rel vel median=0.0393 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.9087 m | pos p95=2.1013 m | rot median=0.0621 rad | total vel median=0.1729 m/s | rel vel median=0.1692 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=3.0339 m | pos p95=3.5361 m | rot median=0.0845 rad | total vel median=0.1439 m/s | rel vel median=0.1386 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=4.8370 m | pos p95=14.4437 m | rot median=0.1981 rad | total vel median=0.0855 m/s | rel vel median=0.0943 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Largest completed terminal errors
#   OU seed=200046 | reason=completed | sim_time=60.00s | pos=15.2114 m | rot=0.5963 rad | total_vel_violation=0
#   OU seed=200043 | reason=completed | sim_time=60.00s | pos=12.1407 m | rot=0.4190 rad | total_vel_violation=0
#   PRBS seed=47 | reason=completed | sim_time=60.00s | pos=6.5186 m | rot=0.1241 rad | total_vel_violation=0
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=6.0169 m | rot=0.1719 rad | total_vel_violation=0
#   OU seed=200045 | reason=completed | sim_time=60.00s | pos=5.2438 m | rot=0.0389 rad | total_vel_violation=0
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# OU seed=200046 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260523_180949/degraded_eval/diagnostic_plots/high_terminal_error_OU_seed200046.png
# OU seed=200043 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260523_180949/degraded_eval/diagnostic_plots/high_terminal_error_OU_seed200043.png
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=heading_biased_eval | noise_protocol=iid_noisy_ic | noise_budget=protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350] | scenarios=PRBS,CHIRP,OU | trajectories=18 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260523_180949/heading_biased_eval
# [scenario 1/3] PRBS | 6 trajectories
# [1/18] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=4m04.0s
# [5/18] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=37.3s
# [6/18] PRBS seed=47 done | reason=completed | sim_time=60.00s | eta=28.7s
# [scenario done] PRBS | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=5.1363 m | pos_p95=12.7254 m | rot_med=0.1225 rad | completion=1.000 | elapsed=14.4s
# [scenario 2/3] CHIRP | 6 trajectories
# [7/18] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=45.4s
# [11/18] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=18.4s
# [12/18] CHIRP seed=100047 done | reason=completed | sim_time=60.00s | eta=14.5s
# [scenario done] CHIRP | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=1.9766 m | pos_p95=4.3510 m | rot_med=0.0366 rad | completion=1.000 | elapsed=28.9s
# [scenario 3/3] OU | 6 trajectories
# [13/18] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=16.7s
# [17/18] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=2.6s
# [18/18] OU seed=200047 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=5.6169 m | pos_p95=12.4125 m | rot_med=0.1696 rad | completion=1.000 | elapsed=43.5s
# Benchmark finished in 56.1s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260523_180949/heading_biased_eval
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: pH NODE q-Force [baseline/core]
# Canonical model type: phnode_qforce
# Energy semantics: not_comparable
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 6
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.8875 m | pos p95=2.3497 m | rot median=0.0411 rad | total vel median=0.0949 m/s | rel vel median=0.0948 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=2.2179 m | pos p95=4.8104 m | rot median=0.0461 rad | total vel median=0.1063 m/s | rel vel median=0.1065 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=3.8987 m | pos p95=13.2134 m | rot median=0.0815 rad | total vel median=0.0852 m/s | rel vel median=0.0998 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=18 | completed=18 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=1.4980 m | pos p95=2.3050 m | rot median=0.0458 rad | total vel median=0.1146 m/s | rel vel median=0.1166 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=2.5453 m | pos p95=4.2428 m | rot median=0.0468 rad | total vel median=0.1445 m/s | rel vel median=0.1542 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=5.1363 m | pos p95=12.7254 m | rot median=0.1225 rad | total vel median=0.2096 m/s | rel vel median=0.2158 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.8054 m | pos p95=0.8820 m | rot median=0.0233 rad | total vel median=0.0470 m/s | rel vel median=0.0488 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.4109 m | pos p95=2.0560 m | rot median=0.0153 rad | total vel median=0.0798 m/s | rel vel median=0.0818 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.9766 m | pos p95=4.3510 m | rot median=0.0366 rad | total vel median=0.0327 m/s | rel vel median=0.0393 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=1.3013 m | pos p95=2.2976 m | rot median=0.0611 rad | total vel median=0.1739 m/s | rel vel median=0.1695 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=2.9425 m | pos p95=4.8947 m | rot median=0.1014 rad | total vel median=0.1389 m/s | rel vel median=0.1389 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=5.6169 m | pos p95=12.4125 m | rot median=0.1696 rad | total vel median=0.0839 m/s | rel vel median=0.0939 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Largest completed terminal errors
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=14.2221 m | rot=0.2337 rad | total_vel_violation=0
#   OU seed=200046 | reason=completed | sim_time=60.00s | pos=13.0354 m | rot=0.5609 rad | total_vel_violation=0
#   OU seed=200043 | reason=completed | sim_time=60.00s | pos=10.5440 m | rot=0.3937 rad | total_vel_violation=0
#   PRBS seed=47 | reason=completed | sim_time=60.00s | pos=8.2354 m | rot=0.1488 rad | total_vel_violation=0
#   OU seed=200045 | reason=completed | sim_time=60.00s | pos=7.4376 m | rot=0.0502 rad | total_vel_violation=0
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# PRBS seed=42 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260523_180949/heading_biased_eval/diagnostic_plots/high_terminal_error_PRBS_seed42.png
# OU seed=200046 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260523_180949/heading_biased_eval/diagnostic_plots/high_terminal_error_OU_seed200046.png
# Batch evaluation complete.
# [eval] suite=sweep_oc_phase1a_smoke1_iid_t2_wpfrag_phnode_qforce eval_protocol=iid_noisy_ic profiles=clean nominal_eval degraded_eval heading_biased_eval
# Suite directory: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_phnode_qforce
# Manifest: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_phnode_qforce/runs.tsv
# Mode: resampled
# [eval] baseline_phnode_qforce_seed42
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=clean | noise_protocol=clean | noise_budget=protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000] | scenarios=PRBS,CHIRP,OU | trajectories=18 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260523_181537/clean
# [scenario 1/3] PRBS | 6 trajectories
# [1/18] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=15m21.3s
# [5/18] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=2m20.9s
# [6/18] PRBS seed=47 done | reason=completed | sim_time=60.00s | eta=1m48.4s
# [scenario done] PRBS | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=2.5784 m | pos_p95=3.6497 m | rot_med=0.0404 rad | completion=1.000 | elapsed=54.2s
# [scenario 2/3] CHIRP | 6 trajectories
# [7/18] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=2m50.1s
# [11/18] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=1m08.9s
# [12/18] CHIRP seed=100047 done | reason=completed | sim_time=60.00s | eta=54.1s
# [scenario done] CHIRP | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=3.0778 m | pos_p95=3.7993 m | rot_med=0.0240 rad | completion=1.000 | elapsed=1m48.3s
# [scenario 3/3] OU | 6 trajectories
# [13/18] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=1m02.6s
# [17/18] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=9.6s
# [18/18] OU seed=200047 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=5.2821 m | pos_p95=12.3768 m | rot_med=0.1859 rad | completion=1.000 | elapsed=2m42.8s
# Benchmark finished in 2m56.1s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260523_181537/clean
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: pH NODE q-Force [baseline/core]
# Canonical model type: phnode_qforce
# Energy semantics: not_comparable
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 6
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.7658 m | pos p95=1.8946 m | rot median=0.0283 rad | total vel median=0.1183 m/s | rel vel median=0.1183 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=1.5913 m | pos p95=3.4086 m | rot median=0.0370 rad | total vel median=0.0832 m/s | rel vel median=0.0916 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=3.1531 m | pos p95=9.7938 m | rot median=0.0339 rad | total vel median=0.1208 m/s | rel vel median=0.1035 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=18 | completed=18 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=1.7829 m | pos p95=1.8979 m | rot median=0.0193 rad | total vel median=0.1051 m/s | rel vel median=0.1116 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.4493 m | pos p95=2.8990 m | rot median=0.0278 rad | total vel median=0.1734 m/s | rel vel median=0.1794 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=2.5784 m | pos p95=3.6497 m | rot median=0.0404 rad | total vel median=0.2565 m/s | rel vel median=0.2421 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.5962 m | pos p95=1.0581 m | rot median=0.0215 rad | total vel median=0.0486 m/s | rel vel median=0.0498 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.4767 m | pos p95=2.4655 m | rot median=0.0255 rad | total vel median=0.0557 m/s | rel vel median=0.0551 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=3.0778 m | pos p95=3.7993 m | rot median=0.0240 rad | total vel median=0.0450 m/s | rel vel median=0.0562 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.9634 m | pos p95=1.8922 m | rot median=0.0640 rad | total vel median=0.1438 m/s | rel vel median=0.1433 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=2.8251 m | pos p95=3.5285 m | rot median=0.0942 rad | total vel median=0.1249 m/s | rel vel median=0.1249 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=5.2821 m | pos p95=12.3768 m | rot median=0.1859 rad | total vel median=0.1685 m/s | rel vel median=0.1483 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Largest completed terminal errors
#   OU seed=200046 | reason=completed | sim_time=60.00s | pos=13.4530 m | rot=0.5501 rad | total_vel_violation=0
#   OU seed=200043 | reason=completed | sim_time=60.00s | pos=9.1480 m | rot=0.4957 rad | total_vel_violation=0
#   OU seed=200042 | reason=completed | sim_time=60.00s | pos=6.4026 m | rot=0.1464 rad | total_vel_violation=0
#   OU seed=200045 | reason=completed | sim_time=60.00s | pos=4.1617 m | rot=0.0131 rad | total_vel_violation=0
#   CHIRP seed=100047 | reason=completed | sim_time=60.00s | pos=3.9888 m | rot=0.0419 rad | total_vel_violation=0
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# OU seed=200046 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260523_181537/clean/diagnostic_plots/high_terminal_error_OU_seed200046.png
# OU seed=200043 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260523_181537/clean/diagnostic_plots/high_terminal_error_OU_seed200043.png
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=nominal_eval | noise_protocol=iid_noisy_ic | noise_budget=protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | scenarios=PRBS,CHIRP,OU | trajectories=18 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260523_181537/nominal_eval
# [scenario 1/3] PRBS | 6 trajectories
# [1/18] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=4m08.8s
# [5/18] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=38.1s
# [6/18] PRBS seed=47 done | reason=completed | sim_time=60.00s | eta=29.3s
# [scenario done] PRBS | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=2.4603 m | pos_p95=3.1973 m | rot_med=0.0357 rad | completion=1.000 | elapsed=14.7s
# [scenario 2/3] CHIRP | 6 trajectories
# [7/18] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=45.8s
# [11/18] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=18.6s
# [12/18] CHIRP seed=100047 done | reason=completed | sim_time=60.00s | eta=14.6s
# [scenario done] CHIRP | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=2.8986 m | pos_p95=4.2695 m | rot_med=0.0219 rad | completion=1.000 | elapsed=29.2s
# [scenario 3/3] OU | 6 trajectories
# [13/18] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=16.8s
# [17/18] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=2.6s
# [18/18] OU seed=200047 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=5.0504 m | pos_p95=12.3028 m | rot_med=0.1828 rad | completion=1.000 | elapsed=43.7s
# Benchmark finished in 56.3s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260523_181537/nominal_eval
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: pH NODE q-Force [baseline/core]
# Canonical model type: phnode_qforce
# Energy semantics: not_comparable
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 6
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.8611 m | pos p95=1.9050 m | rot median=0.0299 rad | total vel median=0.1191 m/s | rel vel median=0.1187 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=1.8499 m | pos p95=3.3780 m | rot median=0.0309 rad | total vel median=0.0841 m/s | rel vel median=0.0918 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=3.1178 m | pos p95=9.5134 m | rot median=0.0326 rad | total vel median=0.1196 m/s | rel vel median=0.1037 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=18 | completed=18 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
# ...
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: pH NODE q-Force [baseline/core]
# Canonical model type: phnode_qforce
# Energy semantics: not_comparable
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 6
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.7759 m | pos p95=1.9014 m | rot median=0.0302 rad | total vel median=0.1172 m/s | rel vel median=0.1182 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=1.8273 m | pos p95=3.2754 m | rot median=0.0447 rad | total vel median=0.0839 m/s | rel vel median=0.0917 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=3.3699 m | pos p95=10.0405 m | rot median=0.0319 rad | total vel median=0.1232 m/s | rel vel median=0.1034 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=18 | completed=18 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=1.7938 m | pos p95=1.8921 m | rot median=0.0241 rad | total vel median=0.1034 m/s | rel vel median=0.1104 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.5330 m | pos p95=2.9180 m | rot median=0.0224 rad | total vel median=0.1755 m/s | rel vel median=0.1793 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=2.6452 m | pos p95=4.0146 m | rot median=0.0318 rad | total vel median=0.2564 m/s | rel vel median=0.2420 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.6005 m | pos p95=1.0789 m | rot median=0.0266 rad | total vel median=0.0482 m/s | rel vel median=0.0490 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.8487 m | pos p95=2.3213 m | rot median=0.0288 rad | total vel median=0.0567 m/s | rel vel median=0.0551 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=3.3699 m | pos p95=3.9244 m | rot median=0.0291 rad | total vel median=0.0447 m/s | rel vel median=0.0562 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.9542 m | pos p95=1.9055 m | rot median=0.0659 rad | total vel median=0.1444 m/s | rel vel median=0.1434 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=2.8861 m | pos p95=3.4518 m | rot median=0.0910 rad | total vel median=0.1256 m/s | rel vel median=0.1250 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=5.0001 m | pos p95=12.4029 m | rot median=0.1891 rad | total vel median=0.1688 m/s | rel vel median=0.1486 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Largest completed terminal errors
#   OU seed=200046 | reason=completed | sim_time=60.00s | pos=13.3872 m | rot=0.5491 rad | total_vel_violation=0
#   OU seed=200043 | reason=completed | sim_time=60.00s | pos=9.4499 m | rot=0.5007 rad | total_vel_violation=0
#   OU seed=200042 | reason=completed | sim_time=60.00s | pos=6.4333 m | rot=0.1469 rad | total_vel_violation=0
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=4.3175 m | rot=0.1338 rad | total_vel_violation=0
#   CHIRP seed=100042 | reason=completed | sim_time=60.00s | pos=4.0641 m | rot=0.0095 rad | total_vel_violation=0
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# OU seed=200046 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/rollout_benchmark/phase1a_v4eval_traj6_seed42_20260523_182813/diagnostic_plots/high_terminal_error_OU_seed200046.png
# OU seed=200043 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/rollout_benchmark/phase1a_v4eval_traj6_seed42_20260523_182813/diagnostic_plots/high_terminal_error_OU_seed200043.png
# Batch evaluation complete.
# [eval] suite=sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_phnode_qforce eval_protocol=v4_lite profiles=nominal_eval
# Suite directory: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_phnode_qforce
# Manifest: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_phnode_qforce/runs.tsv
# Mode: resampled
# [eval] baseline_phnode_qforce_seed42
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=nominal_eval | noise_protocol=v4_lite | noise_budget=protocol=v4_lite | profile=nominal_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | scenarios=PRBS,CHIRP,OU | trajectories=18 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/rollout_benchmark/phase1a_v4eval_traj6_seed42_20260523_182914
# [scenario 1/3] PRBS | 6 trajectories
# [1/18] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=4m06.9s
# [5/18] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=37.8s
# [6/18] PRBS seed=47 done | reason=completed | sim_time=60.00s | eta=29.1s
# [scenario done] PRBS | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=1.0624 m | pos_p95=1.5359 m | rot_med=0.0156 rad | completion=1.000 | elapsed=14.6s
# [scenario 2/3] CHIRP | 6 trajectories
# [7/18] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=45.0s
# [11/18] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=18.2s
# [12/18] CHIRP seed=100047 done | reason=completed | sim_time=60.00s | eta=14.3s
# [scenario done] CHIRP | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=0.9785 m | pos_p95=2.1978 m | rot_med=0.0127 rad | completion=1.000 | elapsed=28.7s
# [scenario 3/3] OU | 6 trajectories
# [13/18] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=16.4s
# [17/18] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=2.5s
# [18/18] OU seed=200047 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=1.5486 m | pos_p95=2.3182 m | rot_med=0.0310 rad | completion=1.000 | elapsed=42.8s
# Benchmark finished in 56.0s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/rollout_benchmark/phase1a_v4eval_traj6_seed42_20260523_182914
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: pH NODE q-Force [baseline/core]
# Canonical model type: phnode_qforce
# Energy semantics: not_comparable
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 6
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.1671 m | pos p95=0.3212 m | rot median=0.0117 rad | total vel median=0.0092 m/s | rel vel median=0.0090 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=0.4858 m | pos p95=0.9524 m | rot median=0.0145 rad | total vel median=0.0105 m/s | rel vel median=0.0097 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=1.0624 m | pos p95=2.5303 m | rot median=0.0168 rad | total vel median=0.0152 m/s | rel vel median=0.0161 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=18 | completed=18 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1496 m | pos p95=0.4178 m | rot median=0.0083 rad | total vel median=0.0109 m/s | rel vel median=0.0104 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.3937 m | pos p95=0.6360 m | rot median=0.0136 rad | total vel median=0.0182 m/s | rel vel median=0.0190 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.0624 m | pos p95=1.5359 m | rot median=0.0156 rad | total vel median=0.0245 m/s | rel vel median=0.0244 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1563 m | pos p95=0.2514 m | rot median=0.0104 rad | total vel median=0.0064 m/s | rel vel median=0.0063 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.4608 m | pos p95=0.9163 m | rot median=0.0105 rad | total vel median=0.0048 m/s | rel vel median=0.0037 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=0.9785 m | pos p95=2.1978 m | rot median=0.0127 rad | total vel median=0.0044 m/s | rel vel median=0.0086 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.2157 m | pos p95=0.2877 m | rot median=0.0147 rad | total vel median=0.0149 m/s | rel vel median=0.0148 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.6964 m | pos p95=0.9312 m | rot median=0.0216 rad | total vel median=0.0203 m/s | rel vel median=0.0179 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.5486 m | pos p95=2.3182 m | rot median=0.0310 rad | total vel median=0.0308 m/s | rel vel median=0.0250 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Largest completed terminal errors
#   CHIRP seed=100042 | reason=completed | sim_time=60.00s | pos=2.5785 m | rot=0.0323 rad | total_vel_violation=0
#   OU seed=200047 | reason=completed | sim_time=60.00s | pos=2.5218 m | rot=0.0384 rad | total_vel_violation=0
#   OU seed=200043 | reason=completed | sim_time=60.00s | pos=1.7073 m | rot=0.0722 rad | total_vel_violation=0
#   OU seed=200045 | reason=completed | sim_time=60.00s | pos=1.6893 m | rot=0.0091 rad | total_vel_violation=0
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=1.6708 m | rot=0.0200 rad | total_vel_violation=0
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# CHIRP seed=100042 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/rollout_benchmark/phase1a_v4eval_traj6_seed42_20260523_182914/diagnostic_plots/high_terminal_error_CHIRP_seed100042.png
# OU seed=200047 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/rollout_benchmark/phase1a_v4eval_traj6_seed42_20260523_182914/diagnostic_plots/high_terminal_error_OU_seed200047.png
# Batch evaluation complete.
# + /usr/bin/python3 /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/scripts/register_existing_runs_as_suite.py --suite-dir /content/_proxy_suites/sweep_oc_phase1a_smoke1_proxy_t2_wpfrag_phnode_qforce --run baseline phnode_qforce 42 clean__baseline_phnode_qforce_seed42 /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42 --run baseline phnode_qforce 42 iid__baseline_phnode_qforce_seed42 /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42 --run baseline phnode_qforce 42 v4lite__baseline_phnode_qforce_seed42 /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42
# Registered suite: /content/_proxy_suites/sweep_oc_phase1a_smoke1_proxy_t2_wpfrag_phnode_qforce
# Runs: 3
# Manifest: /content/_proxy_suites/sweep_oc_phase1a_smoke1_proxy_t2_wpfrag_phnode_qforce/runs.tsv
# + /usr/bin/python3 /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/scripts/summarize_sweep.py --suite-dir /content/_proxy_suites/sweep_oc_phase1a_smoke1_proxy_t2_wpfrag_phnode_qforce
# + /usr/bin/python3 /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/scripts/build_experiment_report.py --suite-dir /content/_proxy_suites/sweep_oc_phase1a_smoke1_proxy_t2_wpfrag_phnode_qforce
# /content/_proxy_suites/sweep_oc_phase1a_smoke1_proxy_t2_wpfrag_phnode_qforce/phase1a_decision_brief.md
# [proxy] local: /content/_proxy_suites/sweep_oc_phase1a_smoke1_proxy_t2_wpfrag_phnode_qforce

# %% [markdown]
# ## 3. Decision train (3 protocols x 5 seeds)
# The 15 evidence-bearing training runs for this model.

# %%
os.environ["MODE"] = "decision_train"
# !bash scripts/run_phase1a_oc_v4lite.sh
# Out:
# Streaming output truncated to the last 5000 lines.
# position_rmse: ratio=2.873  degradation=+187.3%
# rotation_geodesic: ratio=12.605  degradation=+1160.5%
# velocity_rmse: ratio=1.632  degradation=+63.2%
# angular_rmse: ratio=2.999  degradation=+199.9%
# success_rate: ratio=1.000  degradation=+0.0%
# trajectory_failure_rate: ratio=1.000  degradation=+0.0%
# [heading_biased_eval]
# position_rmse: ratio=3.899  degradation=+289.9%
# rotation_geodesic: ratio=20.938  degradation=+1993.8%
# velocity_rmse: ratio=1.335  degradation=+33.5%
# angular_rmse: ratio=1.790  degradation=+79.0%
# success_rate: ratio=1.000  degradation=+0.0%
# trajectory_failure_rate: ratio=1.000  degradation=+0.0%
#
# Training finished. Results: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed44
# [train] baseline_phnode_qforce_seed45
# Loading dataset...
# Loaded: 83850 train, 21000 test, t_eval=[0.   0.05 0.1  0.15 0.2 ]
# Dataset split: trajectory | train trajectories: 559 | test trajectories: 140
# Dataset ID: d0be9434
# Dataset path: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl | velocity convention: body_total | state dim: 27
# Position std: [0.1508, 0.1400, 0.0370]
# Velocity std: u=0.4722, v=0.0898, w=0.0718, p=0.0248, q=0.0906, r=0.0526
# Actuator std: a0=0.1543, a1=0.1555, a2=299.0037
# Training noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# Model: pH NODE q-Force [baseline/core] | canonical type: phnode_qforce
# Model parameters: 63,447
# Training dataset: id=d0be9434 | path=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Mass matrix initialized from physics
# Training: epochs<=300, target_steps=5000, warmup_steps=400, lr=6.00e-03 -> 1.00e-04, solver=rk4, so3_reg=1.00e-03
# Train samples: 83850, Test samples: 21000
# Epoch    1 | Step    20/ 5000 | Train 4.3840e+00 | Test 5.1160e+00 | SO3(train/test) 1.26e-07/1.28e-07 | Fail(train/test) 0/0 | LR 4.10e-04 | 5.8s
# Epoch    2 | Step    40/ 5000 | Train 3.6770e+00 | Test 4.5255e+00 | SO3(train/test) 1.19e-07/1.20e-07 | Fail(train/test) 0/0 | LR 7.05e-04 | 5.3s
# Epoch    3 | Step    60/ 5000 | Train 3.2038e+00 | Test 3.7102e+00 | SO3(train/test) 1.16e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.00e-03 | 5.2s
# Epoch    4 | Step    80/ 5000 | Train 2.1870e+00 | Test 2.1653e+00 | SO3(train/test) 1.17e-07/1.34e-07 | Fail(train/test) 0/0 | LR 1.29e-03 | 5.3s
# Epoch    5 | Step   100/ 5000 | Train 9.9540e-01 | Test 1.3540e+00 | SO3(train/test) 1.39e-07/1.22e-07 | Fail(train/test) 0/0 | LR 1.59e-03 | 5.4s
# Epoch    6 | Step   120/ 5000 | Train 9.6599e-01 | Test 7.4975e-01 | SO3(train/test) 1.18e-07/1.20e-07 | Fail(train/test) 0/0 | LR 1.88e-03 | 5.3s
# Epoch    7 | Step   140/ 5000 | Train 6.1818e-01 | Test 5.2408e-01 | SO3(train/test) 1.19e-07/1.14e-07 | Fail(train/test) 0/0 | LR 2.18e-03 | 5.4s
# Epoch    8 | Step   160/ 5000 | Train 5.5009e-01 | Test 5.9207e-01 | SO3(train/test) 1.14e-07/1.15e-07 | Fail(train/test) 0/0 | LR 2.47e-03 | 5.3s
# Epoch    9 | Step   180/ 5000 | Train 8.2716e-01 | Test 4.6237e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 2.77e-03 | 5.5s
# Epoch   10 | Step   200/ 5000 | Train 7.6720e-01 | Test 5.8527e-01 | SO3(train/test) 1.15e-07/1.16e-07 | Fail(train/test) 0/0 | LR 3.06e-03 | 5.3s
# Epoch   11 | Step   220/ 5000 | Train 6.7451e-01 | Test 1.3438e+00 | SO3(train/test) 1.19e-07/1.29e-07 | Fail(train/test) 0/0 | LR 3.36e-03 | 5.2s
# Epoch   12 | Step   240/ 5000 | Train 6.7054e-01 | Test 5.8495e-01 | SO3(train/test) 1.22e-07/1.23e-07 | Fail(train/test) 0/0 | LR 3.65e-03 | 5.3s
# Epoch   13 | Step   260/ 5000 | Train 6.1459e-01 | Test 5.9843e-01 | SO3(train/test) 1.23e-07/1.25e-07 | Fail(train/test) 0/0 | LR 3.95e-03 | 5.4s
# Epoch   14 | Step   280/ 5000 | Train 5.2754e-01 | Test 8.2266e-01 | SO3(train/test) 1.19e-07/1.18e-07 | Fail(train/test) 0/0 | LR 4.24e-03 | 5.3s
# Epoch   15 | Step   300/ 5000 | Train 8.0362e-01 | Test 1.2887e+00 | SO3(train/test) 1.25e-07/6.41e-07 | Fail(train/test) 0/0 | LR 4.54e-03 | 5.2s
# Epoch   16 | Step   320/ 5000 | Train 1.0417e+01 | Test 3.7287e+00 | SO3(train/test) 1.31e-05/1.45e-05 | Fail(train/test) 0/0 | LR 4.83e-03 | 5.4s
# Epoch   17 | Step   340/ 5000 | Train 1.5723e+00 | Test 1.7444e+00 | SO3(train/test) 1.12e-06/1.66e-07 | Fail(train/test) 0/0 | LR 5.13e-03 | 5.3s
# Epoch   18 | Step   360/ 5000 | Train 2.3669e+00 | Test 2.8621e+00 | SO3(train/test) 1.44e-06/8.28e-06 | Fail(train/test) 0/0 | LR 5.42e-03 | 5.4s
# Epoch   19 | Step   380/ 5000 | Train 3.7612e+00 | Test 5.6975e+00 | SO3(train/test) 9.33e-06/7.01e-06 | Fail(train/test) 0/0 | LR 5.72e-03 | 5.3s
# Epoch   20 | Step   400/ 5000 | Train 2.3585e+00 | Test 6.8053e-01 | SO3(train/test) 5.10e-05/2.20e-05 | Fail(train/test) 0/0 | LR 6.00e-03 | 5.2s
# Epoch   21 | Step   420/ 5000 | Train 8.0485e-01 | Test 4.4389e-01 | SO3(train/test) 1.26e-05/9.88e-06 | Fail(train/test) 0/0 | LR 6.00e-03 | 5.3s
# Epoch   22 | Step   440/ 5000 | Train 3.8406e-01 | Test 2.7598e-01 | SO3(train/test) 4.84e-06/1.57e-05 | Fail(train/test) 0/0 | LR 6.00e-03 | 5.2s
# Epoch   23 | Step   460/ 5000 | Train 3.3547e-01 | Test 2.0448e-01 | SO3(train/test) 1.13e-05/6.20e-06 | Fail(train/test) 0/0 | LR 6.00e-03 | 5.4s
# Epoch   24 | Step   480/ 5000 | Train 6.0028e-01 | Test 4.0544e-01 | SO3(train/test) 1.86e-05/4.11e-06 | Fail(train/test) 0/0 | LR 6.00e-03 | 5.3s
# Epoch   25 | Step   500/ 5000 | Train 3.9624e-01 | Test 4.0361e-01 | SO3(train/test) 9.90e-06/1.70e-06 | Fail(train/test) 0/0 | LR 5.99e-03 | 5.3s
# Epoch   26 | Step   520/ 5000 | Train 4.0538e-01 | Test 3.8814e-01 | SO3(train/test) 5.87e-06/7.12e-06 | Fail(train/test) 0/0 | LR 5.99e-03 | 5.4s
# Epoch   27 | Step   540/ 5000 | Train 8.0108e-01 | Test 2.9006e-01 | SO3(train/test) 4.57e-05/1.51e-05 | Fail(train/test) 0/0 | LR 5.99e-03 | 5.3s
# Epoch   28 | Step   560/ 5000 | Train 2.6975e-01 | Test 2.1941e-01 | SO3(train/test) 1.26e-05/1.50e-05 | Fail(train/test) 0/0 | LR 5.98e-03 | 5.6s
# Epoch   29 | Step   580/ 5000 | Train 3.1552e-01 | Test 2.0772e-01 | SO3(train/test) 9.84e-06/1.62e-05 | Fail(train/test) 0/0 | LR 5.98e-03 | 5.3s
# Epoch   30 | Step   600/ 5000 | Train 2.1252e-01 | Test 2.5575e-01 | SO3(train/test) 1.42e-05/2.75e-05 | Fail(train/test) 0/0 | LR 5.97e-03 | 5.3s
# Epoch   31 | Step   620/ 5000 | Train 2.0568e-01 | Test 1.6252e-01 | SO3(train/test) 1.37e-05/1.21e-05 | Fail(train/test) 0/0 | LR 5.97e-03 | 5.3s
# Epoch   32 | Step   640/ 5000 | Train 1.8484e-01 | Test 3.0123e-01 | SO3(train/test) 9.49e-06/9.30e-06 | Fail(train/test) 0/0 | LR 5.96e-03 | 5.3s
# Epoch   33 | Step   660/ 5000 | Train 1.7056e-01 | Test 1.7097e-01 | SO3(train/test) 8.34e-06/9.97e-06 | Fail(train/test) 0/0 | LR 5.95e-03 | 5.4s
# Epoch   34 | Step   680/ 5000 | Train 1.5985e-01 | Test 1.3055e-01 | SO3(train/test) 8.34e-06/1.19e-05 | Fail(train/test) 0/0 | LR 5.95e-03 | 5.3s
# Epoch   35 | Step   700/ 5000 | Train 1.4472e-01 | Test 1.5442e-01 | SO3(train/test) 1.01e-05/1.85e-05 | Fail(train/test) 0/0 | LR 5.94e-03 | 5.4s
# Epoch   36 | Step   720/ 5000 | Train 1.4871e-01 | Test 1.6419e-01 | SO3(train/test) 9.94e-06/9.80e-06 | Fail(train/test) 0/0 | LR 5.93e-03 | 5.3s
# Epoch   37 | Step   740/ 5000 | Train 1.4650e-01 | Test 2.2197e-01 | SO3(train/test) 1.28e-05/3.19e-05 | Fail(train/test) 0/0 | LR 5.92e-03 | 5.4s
# Epoch   38 | Step   760/ 5000 | Train 1.6551e-01 | Test 1.7260e-01 | SO3(train/test) 1.15e-05/8.80e-06 | Fail(train/test) 0/0 | LR 5.91e-03 | 5.4s
# Epoch   39 | Step   780/ 5000 | Train 1.4706e-01 | Test 1.4374e-01 | SO3(train/test) 1.25e-05/9.49e-06 | Fail(train/test) 0/0 | LR 5.90e-03 | 5.4s
# Epoch   40 | Step   800/ 5000 | Train 1.4151e-01 | Test 1.4902e-01 | SO3(train/test) 1.04e-05/1.14e-05 | Fail(train/test) 0/0 | LR 5.89e-03 | 5.4s
# Epoch   41 | Step   820/ 5000 | Train 1.5639e-01 | Test 1.5850e-01 | SO3(train/test) 1.29e-05/9.28e-06 | Fail(train/test) 0/0 | LR 5.88e-03 | 5.3s
# Epoch   42 | Step   840/ 5000 | Train 2.9089e-01 | Test 2.3622e-01 | SO3(train/test) 2.30e-05/2.18e-05 | Fail(train/test) 0/0 | LR 5.87e-03 | 5.4s
# Epoch   43 | Step   860/ 5000 | Train 2.1634e-01 | Test 2.1189e-01 | SO3(train/test) 1.40e-05/1.07e-05 | Fail(train/test) 0/0 | LR 5.86e-03 | 5.4s
# Epoch   44 | Step   880/ 5000 | Train 1.8634e-01 | Test 1.6660e-01 | SO3(train/test) 8.50e-06/7.49e-06 | Fail(train/test) 0/0 | LR 5.84e-03 | 5.3s
# Epoch   45 | Step   900/ 5000 | Train 1.4350e-01 | Test 1.4828e-01 | SO3(train/test) 8.55e-06/9.10e-06 | Fail(train/test) 0/0 | LR 5.83e-03 | 5.3s
# Epoch   46 | Step   920/ 5000 | Train 1.6749e-01 | Test 1.3626e-01 | SO3(train/test) 1.13e-05/1.33e-05 | Fail(train/test) 0/0 | LR 5.82e-03 | 5.2s
# Epoch   47 | Step   940/ 5000 | Train 1.3852e-01 | Test 1.3994e-01 | SO3(train/test) 1.49e-05/2.86e-05 | Fail(train/test) 0/0 | LR 5.80e-03 | 5.4s
# Epoch   48 | Step   960/ 5000 | Train 1.3573e-01 | Test 1.1517e-01 | SO3(train/test) 1.30e-05/8.36e-06 | Fail(train/test) 0/0 | LR 5.79e-03 | 5.4s
# Epoch   49 | Step   980/ 5000 | Train 1.2870e-01 | Test 1.0181e-01 | SO3(train/test) 1.13e-05/1.19e-05 | Fail(train/test) 0/0 | LR 5.77e-03 | 5.3s
# Epoch   50 | Step  1000/ 5000 | Train 1.1711e-01 | Test 1.1057e-01 | SO3(train/test) 1.09e-05/1.37e-05 | Fail(train/test) 0/0 | LR 5.76e-03 | 5.3s
# Epoch   51 | Step  1020/ 5000 | Train 9.9803e-02 | Test 1.0270e-01 | SO3(train/test) 1.10e-05/1.49e-05 | Fail(train/test) 0/0 | LR 5.74e-03 | 5.4s
# Epoch   52 | Step  1040/ 5000 | Train 1.0925e-01 | Test 1.1377e-01 | SO3(train/test) 1.12e-05/8.87e-06 | Fail(train/test) 0/0 | LR 5.72e-03 | 5.4s
# Epoch   53 | Step  1060/ 5000 | Train 9.5072e-02 | Test 9.0171e-02 | SO3(train/test) 1.01e-05/9.58e-06 | Fail(train/test) 0/0 | LR 5.71e-03 | 5.3s
# Epoch   54 | Step  1080/ 5000 | Train 9.4724e-02 | Test 8.4438e-02 | SO3(train/test) 1.08e-05/1.21e-05 | Fail(train/test) 0/0 | LR 5.69e-03 | 5.4s
# Epoch   55 | Step  1100/ 5000 | Train 8.5851e-02 | Test 9.3388e-02 | SO3(train/test) 1.11e-05/8.38e-06 | Fail(train/test) 0/0 | LR 5.67e-03 | 5.3s
# Epoch   56 | Step  1120/ 5000 | Train 8.3766e-02 | Test 9.1004e-02 | SO3(train/test) 1.09e-05/1.53e-05 | Fail(train/test) 0/0 | LR 5.65e-03 | 5.3s
# Epoch   57 | Step  1140/ 5000 | Train 1.1875e-01 | Test 1.1189e-01 | SO3(train/test) 1.65e-05/2.50e-05 | Fail(train/test) 0/0 | LR 5.63e-03 | 5.2s
# Epoch   58 | Step  1160/ 5000 | Train 9.3856e-02 | Test 7.9554e-02 | SO3(train/test) 1.35e-05/1.31e-05 | Fail(train/test) 0/0 | LR 5.61e-03 | 5.4s
# Epoch   59 | Step  1180/ 5000 | Train 8.3937e-02 | Test 1.1120e-01 | SO3(train/test) 1.36e-05/1.52e-05 | Fail(train/test) 0/0 | LR 5.59e-03 | 5.4s
# Epoch   60 | Step  1200/ 5000 | Train 8.2485e-02 | Test 8.3643e-02 | SO3(train/test) 1.42e-05/1.87e-05 | Fail(train/test) 0/0 | LR 5.57e-03 | 5.3s
# Epoch   61 | Step  1220/ 5000 | Train 8.3263e-02 | Test 8.1692e-02 | SO3(train/test) 1.29e-05/1.82e-05 | Fail(train/test) 0/0 | LR 5.55e-03 | 5.3s
# Epoch   62 | Step  1240/ 5000 | Train 7.5749e-02 | Test 7.3932e-02 | SO3(train/test) 1.30e-05/1.43e-05 | Fail(train/test) 0/0 | LR 5.53e-03 | 5.2s
# Epoch   63 | Step  1260/ 5000 | Train 7.7701e-02 | Test 7.5513e-02 | SO3(train/test) 1.45e-05/1.74e-05 | Fail(train/test) 0/0 | LR 5.51e-03 | 5.4s
# Epoch   64 | Step  1280/ 5000 | Train 7.2556e-02 | Test 7.3313e-02 | SO3(train/test) 1.42e-05/1.53e-05 | Fail(train/test) 0/0 | LR 5.48e-03 | 5.2s
# Epoch   65 | Step  1300/ 5000 | Train 8.4362e-02 | Test 8.7751e-02 | SO3(train/test) 1.51e-05/1.97e-05 | Fail(train/test) 0/0 | LR 5.46e-03 | 5.2s
# Epoch   66 | Step  1320/ 5000 | Train 7.1277e-02 | Test 6.3143e-02 | SO3(train/test) 1.61e-05/1.72e-05 | Fail(train/test) 0/0 | LR 5.44e-03 | 5.3s
# Epoch   67 | Step  1340/ 5000 | Train 6.1077e-02 | Test 6.5876e-02 | SO3(train/test) 1.59e-05/1.86e-05 | Fail(train/test) 0/0 | LR 5.41e-03 | 5.2s
# Epoch   68 | Step  1360/ 5000 | Train 7.4675e-02 | Test 6.4897e-02 | SO3(train/test) 1.82e-05/2.16e-05 | Fail(train/test) 0/0 | LR 5.39e-03 | 5.5s
# Epoch   69 | Step  1380/ 5000 | Train 5.9062e-02 | Test 7.6004e-02 | SO3(train/test) 1.74e-05/2.12e-05 | Fail(train/test) 0/0 | LR 5.36e-03 | 5.3s
# Epoch   70 | Step  1400/ 5000 | Train 8.3940e-02 | Test 7.7115e-02 | SO3(train/test) 1.83e-05/2.28e-05 | Fail(train/test) 0/0 | LR 5.34e-03 | 5.4s
# Epoch   71 | Step  1420/ 5000 | Train 6.6582e-02 | Test 6.5838e-02 | SO3(train/test) 1.73e-05/2.02e-05 | Fail(train/test) 0/0 | LR 5.31e-03 | 5.3s
# Epoch   72 | Step  1440/ 5000 | Train 7.0210e-02 | Test 7.4446e-02 | SO3(train/test) 1.78e-05/1.87e-05 | Fail(train/test) 0/0 | LR 5.29e-03 | 5.3s
# Epoch   73 | Step  1460/ 5000 | Train 6.3899e-02 | Test 6.7056e-02 | SO3(train/test) 1.60e-05/1.88e-05 | Fail(train/test) 0/0 | LR 5.26e-03 | 5.4s
# Epoch   74 | Step  1480/ 5000 | Train 6.1006e-02 | Test 7.2797e-02 | SO3(train/test) 1.72e-05/1.76e-05 | Fail(train/test) 0/0 | LR 5.23e-03 | 5.3s
# Epoch   75 | Step  1500/ 5000 | Train 5.9352e-02 | Test 5.4843e-02 | SO3(train/test) 1.78e-05/1.95e-05 | Fail(train/test) 0/0 | LR 5.21e-03 | 5.3s
# Epoch   76 | Step  1520/ 5000 | Train 5.7395e-02 | Test 6.5857e-02 | SO3(train/test) 1.85e-05/2.00e-05 | Fail(train/test) 0/0 | LR 5.18e-03 | 5.2s
# Epoch   77 | Step  1540/ 5000 | Train 1.3379e-01 | Test 1.0550e-01 | SO3(train/test) 3.54e-05/2.67e-05 | Fail(train/test) 0/0 | LR 5.15e-03 | 5.3s
# Epoch   78 | Step  1560/ 5000 | Train 7.4994e-02 | Test 6.6418e-02 | SO3(train/test) 2.16e-05/2.28e-05 | Fail(train/test) 0/0 | LR 5.12e-03 | 5.4s
# Epoch   79 | Step  1580/ 5000 | Train 5.6615e-02 | Test 6.5143e-02 | SO3(train/test) 1.80e-05/1.85e-05 | Fail(train/test) 0/0 | LR 5.09e-03 | 5.3s
# Epoch   80 | Step  1600/ 5000 | Train 5.6338e-02 | Test 5.4342e-02 | SO3(train/test) 1.82e-05/1.89e-05 | Fail(train/test) 0/0 | LR 5.06e-03 | 5.3s
# Epoch   81 | Step  1620/ 5000 | Train 5.9307e-02 | Test 5.6471e-02 | SO3(train/test) 1.84e-05/2.10e-05 | Fail(train/test) 0/0 | LR 5.03e-03 | 5.3s
# Epoch   82 | Step  1640/ 5000 | Train 5.7435e-02 | Test 7.5943e-02 | SO3(train/test) 1.75e-05/2.62e-05 | Fail(train/test) 0/0 | LR 5.00e-03 | 5.3s
# Epoch   83 | Step  1660/ 5000 | Train 5.3609e-02 | Test 5.6974e-02 | SO3(train/test) 1.76e-05/1.91e-05 | Fail(train/test) 0/0 | LR 4.97e-03 | 5.4s
# Epoch   84 | Step  1680/ 5000 | Train 5.1673e-02 | Test 5.1237e-02 | SO3(train/test) 1.79e-05/2.11e-05 | Fail(train/test) 0/0 | LR 4.94e-03 | 5.3s
# Epoch   85 | Step  1700/ 5000 | Train 5.6754e-02 | Test 6.0341e-02 | SO3(train/test) 1.85e-05/2.33e-05 | Fail(train/test) 0/0 | LR 4.91e-03 | 5.3s
# Epoch   86 | Step  1720/ 5000 | Train 5.2903e-02 | Test 5.9370e-02 | SO3(train/test) 1.68e-05/1.84e-05 | Fail(train/test) 0/0 | LR 4.88e-03 | 5.3s
# Epoch   87 | Step  1740/ 5000 | Train 5.2211e-02 | Test 6.5469e-02 | SO3(train/test) 1.78e-05/1.71e-05 | Fail(train/test) 0/0 | LR 4.85e-03 | 5.2s
# Epoch   88 | Step  1760/ 5000 | Train 4.9208e-02 | Test 4.9444e-02 | SO3(train/test) 1.70e-05/1.88e-05 | Fail(train/test) 0/0 | LR 4.82e-03 | 5.3s
# Epoch   89 | Step  1780/ 5000 | Train 4.9921e-02 | Test 5.6362e-02 | SO3(train/test) 1.76e-05/1.96e-05 | Fail(train/test) 0/0 | LR 4.78e-03 | 5.3s
# Epoch   90 | Step  1800/ 5000 | Train 4.9843e-02 | Test 5.2089e-02 | SO3(train/test) 1.69e-05/1.76e-05 | Fail(train/test) 0/0 | LR 4.75e-03 | 5.2s
# Epoch   91 | Step  1820/ 5000 | Train 6.5808e-02 | Test 5.7362e-02 | SO3(train/test) 1.95e-05/2.11e-05 | Fail(train/test) 0/0 | LR 4.72e-03 | 5.3s
# Epoch   92 | Step  1840/ 5000 | Train 4.5435e-02 | Test 4.9820e-02 | SO3(train/test) 1.75e-05/1.73e-05 | Fail(train/test) 0/0 | LR 4.68e-03 | 5.3s
# Epoch   93 | Step  1860/ 5000 | Train 4.4472e-02 | Test 4.4113e-02 | SO3(train/test) 1.74e-05/1.91e-05 | Fail(train/test) 0/0 | LR 4.65e-03 | 5.3s
# Epoch   94 | Step  1880/ 5000 | Train 4.2462e-02 | Test 4.3527e-02 | SO3(train/test) 1.75e-05/1.83e-05 | Fail(train/test) 0/0 | LR 4.62e-03 | 5.3s
# Epoch   95 | Step  1900/ 5000 | Train 4.1728e-02 | Test 4.5322e-02 | SO3(train/test) 1.74e-05/1.76e-05 | Fail(train/test) 0/0 | LR 4.58e-03 | 5.2s
# Epoch   96 | Step  1920/ 5000 | Train 4.0469e-02 | Test 4.6964e-02 | SO3(train/test) 1.72e-05/1.74e-05 | Fail(train/test) 0/0 | LR 4.55e-03 | 5.3s
# Epoch   97 | Step  1940/ 5000 | Train 3.9287e-02 | Test 4.1590e-02 | SO3(train/test) 1.68e-05/1.91e-05 | Fail(train/test) 0/0 | LR 4.51e-03 | 5.3s
# Epoch   98 | Step  1960/ 5000 | Train 4.4257e-02 | Test 4.0200e-02 | SO3(train/test) 1.65e-05/2.07e-05 | Fail(train/test) 0/0 | LR 4.48e-03 | 5.4s
# Epoch   99 | Step  1980/ 5000 | Train 4.5320e-02 | Test 4.4470e-02 | SO3(train/test) 1.73e-05/1.79e-05 | Fail(train/test) 0/0 | LR 4.44e-03 | 5.3s
# Epoch  100 | Step  2000/ 5000 | Train 5.6662e-02 | Test 4.1793e-02 | SO3(train/test) 1.60e-05/1.50e-05 | Fail(train/test) 0/0 | LR 4.41e-03 | 5.3s
# Epoch  101 | Step  2020/ 5000 | Train 4.5270e-02 | Test 4.7156e-02 | SO3(train/test) 1.55e-05/2.07e-05 | Fail(train/test) 0/0 | LR 4.37e-03 | 5.3s
# Epoch  102 | Step  2040/ 5000 | Train 3.9931e-02 | Test 4.4619e-02 | SO3(train/test) 1.59e-05/1.85e-05 | Fail(train/test) 0/0 | LR 4.33e-03 | 5.3s
# Epoch  103 | Step  2060/ 5000 | Train 3.7418e-02 | Test 3.8365e-02 | SO3(train/test) 1.54e-05/1.58e-05 | Fail(train/test) 0/0 | LR 4.30e-03 | 5.4s
# Epoch  104 | Step  2080/ 5000 | Train 3.6668e-02 | Test 4.1656e-02 | SO3(train/test) 1.53e-05/1.62e-05 | Fail(train/test) 0/0 | LR 4.26e-03 | 5.3s
# Epoch  105 | Step  2100/ 5000 | Train 3.5184e-02 | Test 3.4899e-02 | SO3(train/test) 1.50e-05/1.72e-05 | Fail(train/test) 0/0 | LR 4.22e-03 | 5.3s
# Epoch  106 | Step  2120/ 5000 | Train 3.1025e-02 | Test 3.2534e-02 | SO3(train/test) 1.62e-05/1.87e-05 | Fail(train/test) 0/0 | LR 4.19e-03 | 5.3s
# Epoch  107 | Step  2140/ 5000 | Train 2.9961e-02 | Test 3.3863e-02 | SO3(train/test) 1.71e-05/1.94e-05 | Fail(train/test) 0/0 | LR 4.15e-03 | 5.3s
# Epoch  108 | Step  2160/ 5000 | Train 3.3206e-02 | Test 3.4591e-02 | SO3(train/test) 1.71e-05/1.97e-05 | Fail(train/test) 0/0 | LR 4.11e-03 | 5.5s
# Epoch  109 | Step  2180/ 5000 | Train 3.0902e-02 | Test 3.2783e-02 | SO3(train/test) 1.66e-05/1.89e-05 | Fail(train/test) 0/0 | LR 4.08e-03 | 5.2s
# Epoch  110 | Step  2200/ 5000 | Train 3.4088e-02 | Test 3.5255e-02 | SO3(train/test) 1.56e-05/1.83e-05 | Fail(train/test) 0/0 | LR 4.04e-03 | 5.2s
# Epoch  111 | Step  2220/ 5000 | Train 3.5161e-02 | Test 4.7470e-02 | SO3(train/test) 1.47e-05/1.82e-05 | Fail(train/test) 0/0 | LR 4.00e-03 | 5.3s
# Epoch  112 | Step  2240/ 5000 | Train 3.2726e-02 | Test 3.9379e-02 | SO3(train/test) 1.51e-05/1.85e-05 | Fail(train/test) 0/0 | LR 3.96e-03 | 5.3s
# Epoch  113 | Step  2260/ 5000 | Train 3.4113e-02 | Test 4.8826e-02 | SO3(train/test) 1.48e-05/1.56e-05 | Fail(train/test) 0/0 | LR 3.92e-03 | 5.5s
# Epoch  114 | Step  2280/ 5000 | Train 3.4691e-02 | Test 3.2340e-02 | SO3(train/test) 1.42e-05/1.61e-05 | Fail(train/test) 0/0 | LR 3.88e-03 | 5.3s
# Epoch  115 | Step  2300/ 5000 | Train 3.0498e-02 | Test 3.1874e-02 | SO3(train/test) 1.45e-05/1.61e-05 | Fail(train/test) 0/0 | LR 3.85e-03 | 5.3s
# Epoch  116 | Step  2320/ 5000 | Train 2.7077e-02 | Test 2.9144e-02 | SO3(train/test) 1.56e-05/1.87e-05 | Fail(train/test) 0/0 | LR 3.81e-03 | 5.4s
# Epoch  117 | Step  2340/ 5000 | Train 2.6618e-02 | Test 3.0693e-02 | SO3(train/test) 1.68e-05/2.05e-05 | Fail(train/test) 0/0 | LR 3.77e-03 | 5.4s
# Epoch  118 | Step  2360/ 5000 | Train 2.8307e-02 | Test 2.9202e-02 | SO3(train/test) 1.68e-05/2.01e-05 | Fail(train/test) 0/0 | LR 3.73e-03 | 5.3s
# Epoch  119 | Step  2380/ 5000 | Train 2.7431e-02 | Test 3.2806e-02 | SO3(train/test) 1.70e-05/1.65e-05 | Fail(train/test) 0/0 | LR 3.69e-03 | 5.3s
# Epoch  120 | Step  2400/ 5000 | Train 2.7181e-02 | Test 3.2078e-02 | SO3(train/test) 1.60e-05/1.85e-05 | Fail(train/test) 0/0 | LR 3.65e-03 | 5.3s
# Epoch  121 | Step  2420/ 5000 | Train 2.6808e-02 | Test 2.8742e-02 | SO3(train/test) 1.59e-05/1.87e-05 | Fail(train/test) 0/0 | LR 3.61e-03 | 5.3s
# Epoch  122 | Step  2440/ 5000 | Train 2.5340e-02 | Test 2.6110e-02 | SO3(train/test) 1.64e-05/1.93e-05 | Fail(train/test) 0/0 | LR 3.57e-03 | 5.3s
# Epoch  123 | Step  2460/ 5000 | Train 2.4317e-02 | Test 2.6049e-02 | SO3(train/test) 1.68e-05/2.05e-05 | Fail(train/test) 0/0 | LR 3.53e-03 | 5.4s
# Epoch  124 | Step  2480/ 5000 | Train 2.7947e-02 | Test 3.9247e-02 | SO3(train/test) 1.69e-05/2.25e-05 | Fail(train/test) 0/0 | LR 3.49e-03 | 5.3s
# Epoch  125 | Step  2500/ 5000 | Train 2.9845e-02 | Test 3.2081e-02 | SO3(train/test) 1.53e-05/1.79e-05 | Fail(train/test) 0/0 | LR 3.45e-03 | 5.4s
# Epoch  126 | Step  2520/ 5000 | Train 2.8303e-02 | Test 2.8488e-02 | SO3(train/test) 1.56e-05/1.93e-05 | Fail(train/test) 0/0 | LR 3.41e-03 | 5.5s
# Epoch  127 | Step  2540/ 5000 | Train 2.6503e-02 | Test 2.7205e-02 | SO3(train/test) 1.56e-05/1.83e-05 | Fail(train/test) 0/0 | LR 3.37e-03 | 5.4s
# Epoch  128 | Step  2560/ 5000 | Train 2.4915e-02 | Test 2.6792e-02 | SO3(train/test) 1.62e-05/2.05e-05 | Fail(train/test) 0/0 | LR 3.33e-03 | 5.5s
# Epoch  129 | Step  2580/ 5000 | Train 2.4012e-02 | Test 2.5784e-02 | SO3(train/test) 1.68e-05/2.00e-05 | Fail(train/test) 0/0 | LR 3.29e-03 | 5.5s
# Epoch  130 | Step  2600/ 5000 | Train 2.3136e-02 | Test 2.4688e-02 | SO3(train/test) 1.74e-05/2.10e-05 | Fail(train/test) 0/0 | LR 3.25e-03 | 5.4s
# Epoch  131 | Step  2620/ 5000 | Train 2.2844e-02 | Test 2.4428e-02 | SO3(train/test) 1.78e-05/2.07e-05 | Fail(train/test) 0/0 | LR 3.21e-03 | 5.4s
# Epoch  132 | Step  2640/ 5000 | Train 2.2689e-02 | Test 2.4614e-02 | SO3(train/test) 1.80e-05/2.08e-05 | Fail(train/test) 0/0 | LR 3.17e-03 | 5.4s
# Epoch  133 | Step  2660/ 5000 | Train 2.2712e-02 | Test 2.4674e-02 | SO3(train/test) 1.79e-05/1.99e-05 | Fail(train/test) 0/0 | LR 3.13e-03 | 5.5s
# Epoch  134 | Step  2680/ 5000 | Train 2.2817e-02 | Test 2.3948e-02 | SO3(train/test) 1.79e-05/2.08e-05 | Fail(train/test) 0/0 | LR 3.09e-03 | 5.4s
# Epoch  135 | Step  2700/ 5000 | Train 2.2981e-02 | Test 2.4590e-02 | SO3(train/test) 1.78e-05/2.01e-05 | Fail(train/test) 0/0 | LR 3.05e-03 | 5.4s
# Epoch  136 | Step  2720/ 5000 | Train 2.2569e-02 | Test 2.3828e-02 | SO3(train/test) 1.78e-05/2.06e-05 | Fail(train/test) 0/0 | LR 3.01e-03 | 5.5s
# Epoch  137 | Step  2740/ 5000 | Train 2.2254e-02 | Test 2.3967e-02 | SO3(train/test) 1.79e-05/2.16e-05 | Fail(train/test) 0/0 | LR 2.97e-03 | 5.4s
# Epoch  138 | Step  2760/ 5000 | Train 2.2080e-02 | Test 2.3957e-02 | SO3(train/test) 1.81e-05/2.12e-05 | Fail(train/test) 0/0 | LR 2.93e-03 | 5.6s
# Epoch  139 | Step  2780/ 5000 | Train 2.2452e-02 | Test 2.3817e-02 | SO3(train/test) 1.80e-05/2.04e-05 | Fail(train/test) 0/0 | LR 2.89e-03 | 5.5s
# Epoch  140 | Step  2800/ 5000 | Train 2.2209e-02 | Test 2.3245e-02 | SO3(train/test) 1.79e-05/2.08e-05 | Fail(train/test) 0/0 | LR 2.85e-03 | 5.4s
# Epoch  141 | Step  2820/ 5000 | Train 2.1728e-02 | Test 2.3192e-02 | SO3(train/test) 1.81e-05/2.16e-05 | Fail(train/test) 0/0 | LR 2.81e-03 | 5.4s
# Epoch  142 | Step  2840/ 5000 | Train 2.1995e-02 | Test 2.3075e-02 | SO3(train/test) 1.80e-05/2.05e-05 | Fail(train/test) 0/0 | LR 2.77e-03 | 5.3s
# Epoch  143 | Step  2860/ 5000 | Train 2.2020e-02 | Test 2.4258e-02 | SO3(train/test) 1.79e-05/2.04e-05 | Fail(train/test) 0/0 | LR 2.73e-03 | 5.5s
# Epoch  144 | Step  2880/ 5000 | Train 2.1740e-02 | Test 2.3031e-02 | SO3(train/test) 1.79e-05/2.10e-05 | Fail(train/test) 0/0 | LR 2.69e-03 | 5.3s
# Epoch  145 | Step  2900/ 5000 | Train 2.1643e-02 | Test 2.3251e-02 | SO3(train/test) 1.81e-05/2.03e-05 | Fail(train/test) 0/0 | LR 2.65e-03 | 5.3s
# Epoch  146 | Step  2920/ 5000 | Train 2.1662e-02 | Test 2.3241e-02 | SO3(train/test) 1.79e-05/2.14e-05 | Fail(train/test) 0/0 | LR 2.61e-03 | 5.3s
# Epoch  147 | Step  2940/ 5000 | Train 2.1993e-02 | Test 2.3761e-02 | SO3(train/test) 1.81e-05/2.01e-05 | Fail(train/test) 0/0 | LR 2.57e-03 | 5.4s
# Epoch  148 | Step  2960/ 5000 | Train 2.3734e-02 | Test 2.4084e-02 | SO3(train/test) 1.76e-05/1.99e-05 | Fail(train/test) 0/0 | LR 2.53e-03 | 5.7s
# Epoch  149 | Step  2980/ 5000 | Train 2.7418e-02 | Test 3.0545e-02 | SO3(train/test) 1.76e-05/1.68e-05 | Fail(train/test) 0/0 | LR 2.49e-03 | 5.4s
# Epoch  150 | Step  3000/ 5000 | Train 2.5327e-02 | Test 2.5475e-02 | SO3(train/test) 1.66e-05/1.89e-05 | Fail(train/test) 0/0 | LR 2.45e-03 | 5.6s
# Epoch  151 | Step  3020/ 5000 | Train 2.2387e-02 | Test 2.2858e-02 | SO3(train/test) 1.69e-05/2.03e-05 | Fail(train/test) 0/0 | LR 2.41e-03 | 5.6s
# Epoch  152 | Step  3040/ 5000 | Train 2.1322e-02 | Test 2.2521e-02 | SO3(train/test) 1.77e-05/2.08e-05 | Fail(train/test) 0/0 | LR 2.37e-03 | 5.6s
# Epoch  153 | Step  3060/ 5000 | Train 2.1301e-02 | Test 2.2591e-02 | SO3(train/test) 1.79e-05/2.01e-05 | Fail(train/test) 0/0 | LR 2.33e-03 | 5.6s
# Epoch  154 | Step  3080/ 5000 | Train 2.1085e-02 | Test 2.2644e-02 | SO3(train/test) 1.80e-05/2.12e-05 | Fail(train/test) 0/0 | LR 2.29e-03 | 5.5s
# Epoch  155 | Step  3100/ 5000 | Train 2.1150e-02 | Test 2.2239e-02 | SO3(train/test) 1.80e-05/2.11e-05 | Fail(train/test) 0/0 | LR 2.25e-03 | 5.6s
# Epoch  156 | Step  3120/ 5000 | Train 2.0960e-02 | Test 2.2087e-02 | SO3(train/test) 1.81e-05/2.06e-05 | Fail(train/test) 0/0 | LR 2.21e-03 | 5.4s
# Epoch  157 | Step  3140/ 5000 | Train 2.1011e-02 | Test 2.2021e-02 | SO3(train/test) 1.81e-05/2.08e-05 | Fail(train/test) 0/0 | LR 2.18e-03 | 5.5s
# Epoch  158 | Step  3160/ 5000 | Train 2.0827e-02 | Test 2.1978e-02 | SO3(train/test) 1.82e-05/2.08e-05 | Fail(train/test) 0/0 | LR 2.14e-03 | 5.6s
# Epoch  159 | Step  3180/ 5000 | Train 2.1078e-02 | Test 2.2933e-02 | SO3(train/test) 1.81e-05/2.15e-05 | Fail(train/test) 0/0 | LR 2.10e-03 | 5.5s
# Epoch  160 | Step  3200/ 5000 | Train 2.1014e-02 | Test 2.2148e-02 | SO3(train/test) 1.80e-05/2.07e-05 | Fail(train/test) 0/0 | LR 2.06e-03 | 5.5s
# Epoch  161 | Step  3220/ 5000 | Train 2.0811e-02 | Test 2.1738e-02 | SO3(train/test) 1.80e-05/2.06e-05 | Fail(train/test) 0/0 | LR 2.02e-03 | 5.3s
# Epoch  162 | Step  3240/ 5000 | Train 2.0815e-02 | Test 2.1802e-02 | SO3(train/test) 1.80e-05/2.13e-05 | Fail(train/test) 0/0 | LR 1.99e-03 | 5.4s
# Epoch  163 | Step  3260/ 5000 | Train 2.0632e-02 | Test 2.1654e-02 | SO3(train/test) 1.81e-05/2.12e-05 | Fail(train/test) 0/0 | LR 1.95e-03 | 5.4s
# Epoch  164 | Step  3280/ 5000 | Train 2.0672e-02 | Test 2.1899e-02 | SO3(train/test) 1.82e-05/2.08e-05 | Fail(train/test) 0/0 | LR 1.91e-03 | 5.3s
# Epoch  165 | Step  3300/ 5000 | Train 2.0588e-02 | Test 2.1552e-02 | SO3(train/test) 1.82e-05/2.12e-05 | Fail(train/test) 0/0 | LR 1.87e-03 | 5.2s
# Epoch  166 | Step  3320/ 5000 | Train 2.0558e-02 | Test 2.1978e-02 | SO3(train/test) 1.82e-05/2.06e-05 | Fail(train/test) 0/0 | LR 1.84e-03 | 5.3s
# Epoch  167 | Step  3340/ 5000 | Train 2.0513e-02 | Test 2.1710e-02 | SO3(train/test) 1.83e-05/2.10e-05 | Fail(train/test) 0/0 | LR 1.80e-03 | 5.2s
# Epoch  168 | Step  3360/ 5000 | Train 2.0441e-02 | Test 2.1582e-02 | SO3(train/test) 1.82e-05/2.12e-05 | Fail(train/test) 0/0 | LR 1.76e-03 | 5.5s
# Epoch  169 | Step  3380/ 5000 | Train 2.0405e-02 | Test 2.1475e-02 | SO3(train/test) 1.83e-05/2.09e-05 | Fail(train/test) 0/0 | LR 1.73e-03 | 5.3s
# Epoch  170 | Step  3400/ 5000 | Train 2.0366e-02 | Test 2.1646e-02 | SO3(train/test) 1.84e-05/2.09e-05 | Fail(train/test) 0/0 | LR 1.69e-03 | 5.2s
# Epoch  171 | Step  3420/ 5000 | Train 2.0301e-02 | Test 2.1240e-02 | SO3(train/test) 1.83e-05/2.14e-05 | Fail(train/test) 0/0 | LR 1.66e-03 | 5.4s
# Epoch  172 | Step  3440/ 5000 | Train 2.0241e-02 | Test 2.1444e-02 | SO3(train/test) 1.83e-05/2.14e-05 | Fail(train/test) 0/0 | LR 1.62e-03 | 5.3s
# Epoch  173 | Step  3460/ 5000 | Train 2.0282e-02 | Test 2.1298e-02 | SO3(train/test) 1.84e-05/2.08e-05 | Fail(train/test) 0/0 | LR 1.59e-03 | 5.5s
# Epoch  174 | Step  3480/ 5000 | Train 2.0215e-02 | Test 2.1365e-02 | SO3(train/test) 1.83e-05/2.11e-05 | Fail(train/test) 0/0 | LR 1.55e-03 | 5.3s
# Epoch  175 | Step  3500/ 5000 | Train 2.0174e-02 | Test 2.1115e-02 | SO3(train/test) 1.83e-05/2.06e-05 | Fail(train/test) 0/0 | LR 1.52e-03 | 5.4s
# Epoch  176 | Step  3520/ 5000 | Train 2.0110e-02 | Test 2.1240e-02 | SO3(train/test) 1.83e-05/2.12e-05 | Fail(train/test) 0/0 | LR 1.48e-03 | 5.4s
# Epoch  177 | Step  3540/ 5000 | Train 2.0065e-02 | Test 2.1203e-02 | SO3(train/test) 1.83e-05/2.13e-05 | Fail(train/test) 0/0 | LR 1.45e-03 | 5.3s
# Epoch  178 | Step  3560/ 5000 | Train 2.0100e-02 | Test 2.1022e-02 | SO3(train/test) 1.84e-05/2.11e-05 | Fail(train/test) 0/0 | LR 1.41e-03 | 5.4s
# Epoch  179 | Step  3580/ 5000 | Train 1.9993e-02 | Test 2.0889e-02 | SO3(train/test) 1.83e-05/2.07e-05 | Fail(train/test) 0/0 | LR 1.38e-03 | 5.2s
# Epoch  180 | Step  3600/ 5000 | Train 2.0018e-02 | Test 2.1039e-02 | SO3(train/test) 1.84e-05/2.08e-05 | Fail(train/test) 0/0 | LR 1.35e-03 | 5.3s
# Epoch  181 | Step  3620/ 5000 | Train 2.0000e-02 | Test 2.0914e-02 | SO3(train/test) 1.83e-05/2.07e-05 | Fail(train/test) 0/0 | LR 1.31e-03 | 5.4s
# Epoch  182 | Step  3640/ 5000 | Train 1.9937e-02 | Test 2.0878e-02 | SO3(train/test) 1.83e-05/2.11e-05 | Fail(train/test) 0/0 | LR 1.28e-03 | 5.3s
# Epoch  183 | Step  3660/ 5000 | Train 1.9857e-02 | Test 2.0794e-02 | SO3(train/test) 1.83e-05/2.09e-05 | Fail(train/test) 0/0 | LR 1.25e-03 | 5.4s
# Epoch  184 | Step  3680/ 5000 | Train 1.9869e-02 | Test 2.0784e-02 | SO3(train/test) 1.83e-05/2.10e-05 | Fail(train/test) 0/0 | LR 1.22e-03 | 5.4s
# Epoch  185 | Step  3700/ 5000 | Train 1.9826e-02 | Test 2.0828e-02 | SO3(train/test) 1.84e-05/2.09e-05 | Fail(train/test) 0/0 | LR 1.19e-03 | 5.3s
# Epoch  186 | Step  3720/ 5000 | Train 1.9788e-02 | Test 2.0688e-02 | SO3(train/test) 1.84e-05/2.13e-05 | Fail(train/test) 0/0 | LR 1.16e-03 | 5.3s
# Epoch  187 | Step  3740/ 5000 | Train 1.9808e-02 | Test 2.0946e-02 | SO3(train/test) 1.84e-05/2.10e-05 | Fail(train/test) 0/0 | LR 1.13e-03 | 5.3s
# Epoch  188 | Step  3760/ 5000 | Train 1.9954e-02 | Test 2.0862e-02 | SO3(train/test) 1.83e-05/2.11e-05 | Fail(train/test) 0/0 | LR 1.10e-03 | 5.4s
# Epoch  189 | Step  3780/ 5000 | Train 1.9860e-02 | Test 2.0790e-02 | SO3(train/test) 1.83e-05/2.08e-05 | Fail(train/test) 0/0 | LR 1.07e-03 | 5.3s
# Epoch  190 | Step  3800/ 5000 | Train 1.9744e-02 | Test 2.0837e-02 | SO3(train/test) 1.83e-05/2.04e-05 | Fail(train/test) 0/0 | LR 1.04e-03 | 5.3s
# Epoch  191 | Step  3820/ 5000 | Train 1.9737e-02 | Test 2.0742e-02 | SO3(train/test) 1.83e-05/2.09e-05 | Fail(train/test) 0/0 | LR 1.01e-03 | 5.2s
# Epoch  192 | Step  3840/ 5000 | Train 1.9698e-02 | Test 2.0535e-02 | SO3(train/test) 1.83e-05/2.08e-05 | Fail(train/test) 0/0 | LR 9.77e-04 | 5.4s
# Epoch  193 | Step  3860/ 5000 | Train 1.9680e-02 | Test 2.0689e-02 | SO3(train/test) 1.84e-05/2.13e-05 | Fail(train/test) 0/0 | LR 9.49e-04 | 5.4s
# Epoch  194 | Step  3880/ 5000 | Train 1.9640e-02 | Test 2.0509e-02 | SO3(train/test) 1.83e-05/2.08e-05 | Fail(train/test) 0/0 | LR 9.21e-04 | 5.4s
# Epoch  195 | Step  3900/ 5000 | Train 1.9580e-02 | Test 2.0629e-02 | SO3(train/test) 1.83e-05/2.06e-05 | Fail(train/test) 0/0 | LR 8.93e-04 | 5.3s
# Epoch  196 | Step  3920/ 5000 | Train 1.9632e-02 | Test 2.0502e-02 | SO3(train/test) 1.82e-05/2.11e-05 | Fail(train/test) 0/0 | LR 8.66e-04 | 5.4s
# Epoch  197 | Step  3940/ 5000 | Train 1.9564e-02 | Test 2.0465e-02 | SO3(train/test) 1.83e-05/2.10e-05 | Fail(train/test) 0/0 | LR 8.39e-04 | 5.4s
# Epoch  198 | Step  3960/ 5000 | Train 1.9515e-02 | Test 2.0410e-02 | SO3(train/test) 1.84e-05/2.09e-05 | Fail(train/test) 0/0 | LR 8.12e-04 | 5.5s
# Epoch  199 | Step  3980/ 5000 | Train 1.9520e-02 | Test 2.0583e-02 | SO3(train/test) 1.83e-05/2.12e-05 | Fail(train/test) 0/0 | LR 7.86e-04 | 5.3s
# Epoch  200 | Step  4000/ 5000 | Train 1.9528e-02 | Test 2.0400e-02 | SO3(train/test) 1.83e-05/2.11e-05 | Fail(train/test) 0/0 | LR 7.61e-04 | 5.3s
# Epoch  201 | Step  4020/ 5000 | Train 1.9502e-02 | Test 2.0437e-02 | SO3(train/test) 1.84e-05/2.09e-05 | Fail(train/test) 0/0 | LR 7.35e-04 | 5.3s
# Epoch  202 | Step  4040/ 5000 | Train 1.9494e-02 | Test 2.0368e-02 | SO3(train/test) 1.84e-05/2.09e-05 | Fail(train/test) 0/0 | LR 7.11e-04 | 5.3s
# Epoch  203 | Step  4060/ 5000 | Train 1.9456e-02 | Test 2.0499e-02 | SO3(train/test) 1.84e-05/2.07e-05 | Fail(train/test) 0/0 | LR 6.86e-04 | 5.5s
# Epoch  204 | Step  4080/ 5000 | Train 1.9486e-02 | Test 2.0302e-02 | SO3(train/test) 1.84e-05/2.08e-05 | Fail(train/test) 0/0 | LR 6.62e-04 | 5.3s
# Epoch  205 | Step  4100/ 5000 | Train 1.9417e-02 | Test 2.0366e-02 | SO3(train/test) 1.84e-05/2.09e-05 | Fail(train/test) 0/0 | LR 6.39e-04 | 5.3s
# Epoch  206 | Step  4120/ 5000 | Train 1.9380e-02 | Test 2.0403e-02 | SO3(train/test) 1.84e-05/2.10e-05 | Fail(train/test) 0/0 | LR 6.16e-04 | 5.3s
# Epoch  207 | Step  4140/ 5000 | Train 1.9392e-02 | Test 2.0327e-02 | SO3(train/test) 1.84e-05/2.06e-05 | Fail(train/test) 0/0 | LR 5.93e-04 | 5.3s
# Epoch  208 | Step  4160/ 5000 | Train 1.9346e-02 | Test 2.0331e-02 | SO3(train/test) 1.84e-05/2.09e-05 | Fail(train/test) 0/0 | LR 5.71e-04 | 5.4s
# Epoch  209 | Step  4180/ 5000 | Train 1.9335e-02 | Test 2.0265e-02 | SO3(train/test) 1.84e-05/2.10e-05 | Fail(train/test) 0/0 | LR 5.50e-04 | 5.3s
# Epoch  210 | Step  4200/ 5000 | Train 1.9372e-02 | Test 2.0331e-02 | SO3(train/test) 1.84e-05/2.07e-05 | Fail(train/test) 0/0 | LR 5.29e-04 | 5.3s
# Epoch  211 | Step  4220/ 5000 | Train 1.9311e-02 | Test 2.0197e-02 | SO3(train/test) 1.83e-05/2.09e-05 | Fail(train/test) 0/0 | LR 5.08e-04 | 5.2s
# Epoch  212 | Step  4240/ 5000 | Train 1.9310e-02 | Test 2.0224e-02 | SO3(train/test) 1.85e-05/2.09e-05 | Fail(train/test) 0/0 | LR 4.88e-04 | 5.3s
# Epoch  213 | Step  4260/ 5000 | Train 1.9274e-02 | Test 2.0194e-02 | SO3(train/test) 1.84e-05/2.09e-05 | Fail(train/test) 0/0 | LR 4.68e-04 | 5.5s
# Epoch  214 | Step  4280/ 5000 | Train 1.9295e-02 | Test 2.0169e-02 | SO3(train/test) 1.84e-05/2.09e-05 | Fail(train/test) 0/0 | LR 4.49e-04 | 5.3s
# Epoch  215 | Step  4300/ 5000 | Train 1.9281e-02 | Test 2.0193e-02 | SO3(train/test) 1.84e-05/2.08e-05 | Fail(train/test) 0/0 | LR 4.30e-04 | 5.4s
# Epoch  216 | Step  4320/ 5000 | Train 1.9258e-02 | Test 2.0169e-02 | SO3(train/test) 1.84e-05/2.07e-05 | Fail(train/test) 0/0 | LR 4.12e-04 | 5.3s
# Epoch  217 | Step  4340/ 5000 | Train 1.9271e-02 | Test 2.0193e-02 | SO3(train/test) 1.84e-05/2.06e-05 | Fail(train/test) 0/0 | LR 3.94e-04 | 5.3s
# Epoch  218 | Step  4360/ 5000 | Train 1.9224e-02 | Test 2.0164e-02 | SO3(train/test) 1.84e-05/2.07e-05 | Fail(train/test) 0/0 | LR 3.77e-04 | 5.4s
# Epoch  219 | Step  4380/ 5000 | Train 1.9227e-02 | Test 2.0122e-02 | SO3(train/test) 1.84e-05/2.09e-05 | Fail(train/test) 0/0 | LR 3.60e-04 | 5.4s
# Epoch  220 | Step  4400/ 5000 | Train 1.9239e-02 | Test 2.0138e-02 | SO3(train/test) 1.85e-05/2.06e-05 | Fail(train/test) 0/0 | LR 3.44e-04 | 5.4s
# Epoch  221 | Step  4420/ 5000 | Train 1.9208e-02 | Test 2.0123e-02 | SO3(train/test) 1.84e-05/2.07e-05 | Fail(train/test) 0/0 | LR 3.28e-04 | 5.3s
# Epoch  222 | Step  4440/ 5000 | Train 1.9247e-02 | Test 2.0103e-02 | SO3(train/test) 1.84e-05/2.09e-05 | Fail(train/test) 0/0 | LR 3.12e-04 | 5.4s
# Epoch  223 | Step  4460/ 5000 | Train 1.9183e-02 | Test 2.0074e-02 | SO3(train/test) 1.84e-05/2.09e-05 | Fail(train/test) 0/0 | LR 2.98e-04 | 5.4s
# Epoch  224 | Step  4480/ 5000 | Train 1.9183e-02 | Test 2.0071e-02 | SO3(train/test) 1.84e-05/2.08e-05 | Fail(train/test) 0/0 | LR 2.83e-04 | 5.3s
# Epoch  225 | Step  4500/ 5000 | Train 1.9169e-02 | Test 2.0090e-02 | SO3(train/test) 1.84e-05/2.08e-05 | Fail(train/test) 0/0 | LR 2.70e-04 | 5.4s
# Epoch  226 | Step  4520/ 5000 | Train 1.9157e-02 | Test 2.0047e-02 | SO3(train/test) 1.84e-05/2.09e-05 | Fail(train/test) 0/0 | LR 2.57e-04 | 5.3s
# Epoch  227 | Step  4540/ 5000 | Train 1.9167e-02 | Test 2.0118e-02 | SO3(train/test) 1.84e-05/2.08e-05 | Fail(train/test) 0/0 | LR 2.44e-04 | 5.4s
# Epoch  228 | Step  4560/ 5000 | Train 1.9137e-02 | Test 2.0011e-02 | SO3(train/test) 1.84e-05/2.08e-05 | Fail(train/test) 0/0 | LR 2.32e-04 | 5.4s
# Epoch  229 | Step  4580/ 5000 | Train 1.9144e-02 | Test 2.0044e-02 | SO3(train/test) 1.84e-05/2.09e-05 | Fail(train/test) 0/0 | LR 2.20e-04 | 5.4s
# Epoch  230 | Step  4600/ 5000 | Train 1.9144e-02 | Test 2.0044e-02 | SO3(train/test) 1.84e-05/2.08e-05 | Fail(train/test) 0/0 | LR 2.09e-04 | 5.3s
# Epoch  231 | Step  4620/ 5000 | Train 1.9140e-02 | Test 2.0021e-02 | SO3(train/test) 1.84e-05/2.08e-05 | Fail(train/test) 0/0 | LR 1.98e-04 | 5.4s
# Epoch  232 | Step  4640/ 5000 | Train 1.9114e-02 | Test 2.0083e-02 | SO3(train/test) 1.84e-05/2.09e-05 | Fail(train/test) 0/0 | LR 1.88e-04 | 5.3s
# Epoch  233 | Step  4660/ 5000 | Train 1.9116e-02 | Test 2.0048e-02 | SO3(train/test) 1.84e-05/2.09e-05 | Fail(train/test) 0/0 | LR 1.79e-04 | 5.4s
# Epoch  234 | Step  4680/ 5000 | Train 1.9111e-02 | Test 2.0027e-02 | SO3(train/test) 1.84e-05/2.08e-05 | Fail(train/test) 0/0 | LR 1.70e-04 | 5.3s
# Epoch  235 | Step  4700/ 5000 | Train 1.9111e-02 | Test 2.0020e-02 | SO3(train/test) 1.84e-05/2.08e-05 | Fail(train/test) 0/0 | LR 1.61e-04 | 5.2s
# Epoch  236 | Step  4720/ 5000 | Train 1.9108e-02 | Test 2.0001e-02 | SO3(train/test) 1.84e-05/2.08e-05 | Fail(train/test) 0/0 | LR 1.53e-04 | 5.4s
# Epoch  237 | Step  4740/ 5000 | Train 1.9099e-02 | Test 2.0031e-02 | SO3(train/test) 1.84e-05/2.08e-05 | Fail(train/test) 0/0 | LR 1.46e-04 | 5.3s
# Epoch  238 | Step  4760/ 5000 | Train 1.9075e-02 | Test 1.9986e-02 | SO3(train/test) 1.84e-05/2.07e-05 | Fail(train/test) 0/0 | LR 1.39e-04 | 5.4s
# Epoch  239 | Step  4780/ 5000 | Train 1.9092e-02 | Test 1.9979e-02 | SO3(train/test) 1.84e-05/2.09e-05 | Fail(train/test) 0/0 | LR 1.33e-04 | 5.3s
# Epoch  240 | Step  4800/ 5000 | Train 1.9078e-02 | Test 2.0015e-02 | SO3(train/test) 1.84e-05/2.06e-05 | Fail(train/test) 0/0 | LR 1.27e-04 | 5.2s
# Epoch  241 | Step  4820/ 5000 | Train 1.9096e-02 | Test 1.9967e-02 | SO3(train/test) 1.84e-05/2.08e-05 | Fail(train/test) 0/0 | LR 1.22e-04 | 5.3s
# Epoch  242 | Step  4840/ 5000 | Train 1.9067e-02 | Test 1.9971e-02 | SO3(train/test) 1.84e-05/2.09e-05 | Fail(train/test) 0/0 | LR 1.17e-04 | 5.4s
# Epoch  243 | Step  4860/ 5000 | Train 1.9093e-02 | Test 1.9979e-02 | SO3(train/test) 1.84e-05/2.07e-05 | Fail(train/test) 0/0 | LR 1.13e-04 | 5.6s
# Epoch  244 | Step  4880/ 5000 | Train 1.9056e-02 | Test 1.9989e-02 | SO3(train/test) 1.84e-05/2.09e-05 | Fail(train/test) 0/0 | LR 1.10e-04 | 5.5s
# Epoch  245 | Step  4900/ 5000 | Train 1.9085e-02 | Test 2.0017e-02 | SO3(train/test) 1.84e-05/2.08e-05 | Fail(train/test) 0/0 | LR 1.07e-04 | 5.4s
# Epoch  246 | Step  4920/ 5000 | Train 1.9064e-02 | Test 1.9947e-02 | SO3(train/test) 1.84e-05/2.08e-05 | Fail(train/test) 0/0 | LR 1.04e-04 | 5.3s
# Epoch  247 | Step  4940/ 5000 | Train 1.9063e-02 | Test 1.9954e-02 | SO3(train/test) 1.84e-05/2.08e-05 | Fail(train/test) 0/0 | LR 1.02e-04 | 5.5s
# Epoch  248 | Step  4960/ 5000 | Train 1.9070e-02 | Test 1.9972e-02 | SO3(train/test) 1.84e-05/2.08e-05 | Fail(train/test) 0/0 | LR 1.01e-04 | 5.7s
# Epoch  249 | Step  4980/ 5000 | Train 1.9045e-02 | Test 1.9960e-02 | SO3(train/test) 1.84e-05/2.08e-05 | Fail(train/test) 0/0 | LR 1.00e-04 | 5.5s
# Epoch  250 | Step  5000/ 5000 | Train 1.9053e-02 | Test 1.9952e-02 | SO3(train/test) 1.84e-05/2.07e-05 | Fail(train/test) 0/0 | LR 1.00e-04 | 5.4s
# Reached target optimizer steps: 5000/5000
# Done. Best validation score: failure_rate=0.0000, test_loss=1.9947e-02 (epoch 246)
# Running detailed evaluation...
# Block evaluation profile: clean
# Block evaluation noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0017 +/- 0.0013  (max 0.0061)
# Rotation geo [rad]:  0.0023 +/- 0.0017  (max 0.0076)
# Lin vel RMSE [m/s]:  0.0184 +/- 0.0140
# Ang vel RMSE [r/s]:  0.0020 +/- 0.0011
# Components:  u=0.0318  v=0.0012  w=0.0008  p=0.0028  q=0.0013  r=0.0011
# SO(3) violation:  |det-1|=2.01e-05  ||RR^T-I||=2.84e-05
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# Block evaluation profile: nominal_eval
# Block evaluation noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0024 +/- 0.0013  (max 0.0071)
# Rotation geo [rad]:  0.0095 +/- 0.0056  (max 0.0347)
# Lin vel RMSE [m/s]:  0.0203 +/- 0.0135
# Ang vel RMSE [r/s]:  0.0033 +/- 0.0017
# Components:  u=0.0344  v=0.0036  w=0.0031  p=0.0050  q=0.0016  r=0.0016
# SO(3) violation:  |det-1|=2.04e-05  ||RR^T-I||=2.90e-05
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# Block evaluation profile: heading_biased_eval
# Block evaluation noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0053 +/- 0.0018  (max 0.0109)
# Rotation geo [rad]:  0.0359 +/- 0.0102  (max 0.0677)
# Lin vel RMSE [m/s]:  0.0219 +/- 0.0130
# Ang vel RMSE [r/s]:  0.0033 +/- 0.0017
# Components:  u=0.0352  v=0.0093  w=0.0033  p=0.0050  q=0.0016  r=0.0016
# SO(3) violation:  |det-1|=2.04e-05  ||RR^T-I||=2.90e-05
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Block Evaluation Relative To Clean
# ==================================================
# [nominal_eval]
# position_rmse: ratio=1.426  degradation=+42.6%
# rotation_geodesic: ratio=4.064  degradation=+306.4%
# velocity_rmse: ratio=1.103  degradation=+10.3%
# angular_rmse: ratio=1.637  degradation=+63.7%
# failure_rate: ratio=1.000  degradation=+0.0%
# [heading_biased_eval]
# position_rmse: ratio=3.222  degradation=+222.2%
# rotation_geodesic: ratio=15.285  degradation=+1428.5%
# velocity_rmse: ratio=1.190  degradation=+19.0%
# angular_rmse: ratio=1.638  degradation=+63.8%
# failure_rate: ratio=1.000  degradation=+0.0%
# Running held-out trajectory evaluation...
# Held-out evaluation profile: clean
# Held-out evaluation noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0010 (median 0.0010, p95 0.0018)
# Rotation geo [rad]:  0.0019 (median 0.0020, p95 0.0027)
# Lin vel RMSE [m/s]:  0.0115  Ang vel RMSE [r/s]:  0.0015
# SO(3) violation:  |det-1|=1.39e-05  ||RR^T-I||=1.97e-05
# Noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# [CHIRP] pos=0.0004 m, rot=0.0008 rad, success=1.0000
# [OU] pos=0.0010 m, rot=0.0021 rad, success=1.0000
# [PRBS] pos=0.0013 m, rot=0.0022 rad, success=1.0000
# Held-out evaluation profile: nominal_eval
# Held-out evaluation noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0017 (median 0.0016, p95 0.0025)
# Rotation geo [rad]:  0.0091 (median 0.0092, p95 0.0100)
# Lin vel RMSE [m/s]:  0.0140  Ang vel RMSE [r/s]:  0.0027
# SO(3) violation:  |det-1|=1.43e-05  ||RR^T-I||=2.04e-05
# Noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# [CHIRP] pos=0.0013 m, rot=0.0086 rad, success=1.0000
# [OU] pos=0.0017 m, rot=0.0091 rad, success=1.0000
# [PRBS] pos=0.0019 m, rot=0.0093 rad, success=1.0000
# Held-out evaluation profile: degraded_eval
# Held-out evaluation noise budget: protocol=iid_noisy_ic | profile=degraded_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0032 (median 0.0031, p95 0.0041)
# Rotation geo [rad]:  0.0213 (median 0.0214, p95 0.0233)
# Lin vel RMSE [m/s]:  0.0192  Ang vel RMSE [r/s]:  0.0045
# SO(3) violation:  |det-1|=1.54e-05  ||RR^T-I||=2.19e-05
# Noise budget: protocol=iid_noisy_ic | profile=degraded_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250]
# [CHIRP] pos=0.0029 m, rot=0.0210 rad, success=1.0000
# [OU] pos=0.0031 m, rot=0.0213 rad, success=1.0000
# [PRBS] pos=0.0034 m, rot=0.0215 rad, success=1.0000
# Held-out evaluation profile: heading_biased_eval
# Held-out evaluation noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0042 (median 0.0041, p95 0.0056)
# Rotation geo [rad]:  0.0352 (median 0.0351, p95 0.0364)
# Lin vel RMSE [m/s]:  0.0154  Ang vel RMSE [r/s]:  0.0027
# SO(3) violation:  |det-1|=1.43e-05  ||RR^T-I||=2.04e-05
# Noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ...
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0001 +/- 0.0001  (max 0.0004)
# Rotation geo [rad]:  0.0005 +/- 0.0000  (max 0.0007)
# Lin vel RMSE [m/s]:  0.0014 +/- 0.0011
# Ang vel RMSE [r/s]:  0.0008 +/- 0.0005
# Components:  u=0.0024  v=0.0004  w=0.0003  p=0.0011  q=0.0005  r=0.0004
# SO(3) violation:  |det-1|=6.29e-08  ||RR^T-I||=1.29e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# Block evaluation profile: nominal_eval
# Block evaluation noise budget: protocol=v4_lite | profile=nominal_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0011 +/- 0.0006  (max 0.0040)
# Rotation geo [rad]:  0.0070 +/- 0.0044  (max 0.0255)
# Lin vel RMSE [m/s]:  0.0046 +/- 0.0022
# Ang vel RMSE [r/s]:  0.0031 +/- 0.0020
# Components:  u=0.0054  v=0.0033  w=0.0032  p=0.0049  q=0.0009  r=0.0012
# SO(3) violation:  |det-1|=2.85e-07  ||RR^T-I||=6.25e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=v4_lite | profile=nominal_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# Block evaluation profile: heading_biased_eval
# Block evaluation noise budget: protocol=v4_lite | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0048 +/- 0.0014  (max 0.0093)
# Rotation geo [rad]:  0.0349 +/- 0.0079  (max 0.0604)
# Lin vel RMSE [m/s]:  0.0079 +/- 0.0039
# Ang vel RMSE [r/s]:  0.0031 +/- 0.0020
# Components:  u=0.0076  v=0.0092  w=0.0036  p=0.0049  q=0.0009  r=0.0012
# SO(3) violation:  |det-1|=3.12e-07  ||RR^T-I||=6.76e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=v4_lite | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Block Evaluation Relative To Clean
# ==================================================
# [nominal_eval]
# position_rmse: ratio=8.783  degradation=+778.3%
# rotation_geodesic: ratio=14.278  degradation=+1327.8%
# velocity_rmse: ratio=3.162  degradation=+216.2%
# angular_rmse: ratio=3.697  degradation=+269.7%
# failure_rate: ratio=1.000  degradation=+0.0%
# [heading_biased_eval]
# position_rmse: ratio=38.843  degradation=+3784.3%
# rotation_geodesic: ratio=71.247  degradation=+7024.7%
# velocity_rmse: ratio=5.477  degradation=+447.7%
# angular_rmse: ratio=3.697  degradation=+269.7%
# failure_rate: ratio=1.000  degradation=+0.0%
# Running held-out trajectory evaluation...
# Held-out evaluation profile: clean
# Held-out evaluation noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0001 (median 0.0001, p95 0.0001)
# Rotation geo [rad]:  0.0005 (median 0.0005, p95 0.0005)
# Lin vel RMSE [m/s]:  0.0012  Ang vel RMSE [r/s]:  0.0007
# SO(3) violation:  |det-1|=6.05e-08  ||RR^T-I||=1.17e-07
# Noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# [CHIRP] pos=0.0000 m, rot=0.0005 rad, success=1.0000
# [OU] pos=0.0001 m, rot=0.0005 rad, success=1.0000
# [PRBS] pos=0.0001 m, rot=0.0005 rad, success=1.0000
# Held-out evaluation profile: nominal_eval
# Held-out evaluation noise budget: protocol=v4_lite | profile=nominal_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0011 (median 0.0011, p95 0.0014)
# Rotation geo [rad]:  0.0087 (median 0.0085, p95 0.0109)
# Lin vel RMSE [m/s]:  0.0043  Ang vel RMSE [r/s]:  0.0027
# SO(3) violation:  |det-1|=2.94e-07  ||RR^T-I||=6.25e-07
# Noise budget: protocol=v4_lite | profile=nominal_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# [CHIRP] pos=0.0011 m, rot=0.0089 rad, success=1.0000
# [OU] pos=0.0011 m, rot=0.0087 rad, success=1.0000
# [PRBS] pos=0.0011 m, rot=0.0087 rad, success=1.0000
# Held-out evaluation profile: degraded_eval
# Held-out evaluation noise budget: protocol=v4_lite | profile=degraded_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0026 (median 0.0025, p95 0.0035)
# Rotation geo [rad]:  0.0213 (median 0.0209, p95 0.0268)
# Lin vel RMSE [m/s]:  0.0085  Ang vel RMSE [r/s]:  0.0052
# SO(3) violation:  |det-1|=2.97e-07  ||RR^T-I||=6.33e-07
# Noise budget: protocol=v4_lite | profile=degraded_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250]
# [CHIRP] pos=0.0026 m, rot=0.0217 rad, success=1.0000
# [OU] pos=0.0026 m, rot=0.0212 rad, success=1.0000
# [PRBS] pos=0.0027 m, rot=0.0212 rad, success=1.0000
# Held-out evaluation profile: heading_biased_eval
# Held-out evaluation noise budget: protocol=v4_lite | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0040 (median 0.0039, p95 0.0054)
# Rotation geo [rad]:  0.0352 (median 0.0354, p95 0.0390)
# Lin vel RMSE [m/s]:  0.0068  Ang vel RMSE [r/s]:  0.0027
# SO(3) violation:  |det-1|=2.91e-07  ||RR^T-I||=6.19e-07
# Noise budget: protocol=v4_lite | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# [CHIRP] pos=0.0038 m, rot=0.0345 rad, success=1.0000
# [OU] pos=0.0039 m, rot=0.0352 rad, success=1.0000
# [PRBS] pos=0.0042 m, rot=0.0354 rad, success=1.0000
# ==================================================
# Held-Out Evaluation Relative To Clean
# ==================================================
# [nominal_eval]
# position_rmse: ratio=11.084  degradation=+1008.4%
# rotation_geodesic: ratio=17.784  degradation=+1678.4%
# velocity_rmse: ratio=3.660  degradation=+266.0%
# angular_rmse: ratio=3.723  degradation=+272.3%
# success_rate: ratio=1.000  degradation=+0.0%
# trajectory_failure_rate: ratio=1.000  degradation=+0.0%
# [degraded_eval]
# position_rmse: ratio=26.086  degradation=+2508.6%
# rotation_geodesic: ratio=43.485  degradation=+4248.5%
# velocity_rmse: ratio=7.247  degradation=+624.7%
# angular_rmse: ratio=7.156  degradation=+615.6%
# success_rate: ratio=1.000  degradation=+0.0%
# trajectory_failure_rate: ratio=1.000  degradation=+0.0%
# [heading_biased_eval]
# position_rmse: ratio=39.850  degradation=+3885.0%
# rotation_geodesic: ratio=71.789  degradation=+7078.9%
# velocity_rmse: ratio=5.827  degradation=+482.7%
# angular_rmse: ratio=3.723  degradation=+272.3%
# success_rate: ratio=1.000  degradation=+0.0%
# trajectory_failure_rate: ratio=1.000  degradation=+0.0%
#
# Training finished. Results: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed46
# Training sweep complete.
# Manifest: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_qforce/runs.tsv
# Next step:
#   scripts/batch_eval_models.sh --suite-dir "/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_qforce"
#
# Training complete.
# Suite directory: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_qforce
# Next step:
#   bash scripts/eval_all_models_noise_profile.sh --suite-dir "/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_qforce"
# [audit] /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_phnode_qforce
# [audit] /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce
# [audit] /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_qforce
#                                               suite_name    group    model_type  seed train_noise_protocol  best_epoch  best_loss  noise_warmup_epochs  noise_ramp_epochs  noise_mix_ratio  epoch_scale_at_best  is_effectively_clean_at_best
#  sweep_oc_phase1a_decision_clean_t2_wpfrag_phnode_qforce baseline phnode_qforce    42                clean         250   0.021574                   20                 80              0.5                  0.0                          True
#  sweep_oc_phase1a_decision_clean_t2_wpfrag_phnode_qforce baseline phnode_qforce    43                clean         250   0.028440                   20                 80              0.5                  0.0                          True
#  sweep_oc_phase1a_decision_clean_t2_wpfrag_phnode_qforce baseline phnode_qforce    44                clean         250   0.018690                   20                 80              0.5                  0.0                          True
#  sweep_oc_phase1a_decision_clean_t2_wpfrag_phnode_qforce baseline phnode_qforce    45                clean         246   0.019947                   20                 80              0.5                  0.0                          True
#  sweep_oc_phase1a_decision_clean_t2_wpfrag_phnode_qforce baseline phnode_qforce    46                clean         249   0.019188                   20                 80              0.5                  0.0                          True
#    sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce baseline phnode_qforce    42         iid_noisy_ic         247   0.023692                   20                 80              0.5                  1.0                         False
#    sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce baseline phnode_qforce    43         iid_noisy_ic         247   0.020922                   20                 80              0.5                  1.0                         False
#    sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce baseline phnode_qforce    44         iid_noisy_ic         248   0.006175                   20                 80              0.5                  1.0                         False
#    sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce baseline phnode_qforce    45         iid_noisy_ic         248   0.006318                   20                 80              0.5                  1.0                         False
#    sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce baseline phnode_qforce    46         iid_noisy_ic         250   0.020504                   20                 80              0.5                  1.0                         False
# sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_qforce baseline phnode_qforce    42              v4_lite         218   0.006204                   20                 80              0.5                  1.0                         False
# sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_qforce baseline phnode_qforce    43              v4_lite         247   0.021493                   20                 80              0.5                  1.0                         False
# sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_qforce baseline phnode_qforce    44              v4_lite         245   0.006072                   20                 80              0.5                  1.0                         False
# sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_qforce baseline phnode_qforce    45              v4_lite         231   0.006174                   20                 80              0.5                  1.0                         False
# sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_qforce baseline phnode_qforce    46              v4_lite         248   0.006071                   20                 80              0.5                  1.0                         False
# + /usr/bin/python3 /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/scripts/validate_v4_lite_protocol.py --run-dir /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42
# v4_lite protocol validation saved to: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/v4_lite_protocol_validation.json
# overall_passed=True
# same_epoch_stability: passed=True
# epoch_resampling: passed=True
# heading_bias_overlay: passed=True
# [validate] /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed42/v4_lite_protocol_validation.json

# %% [markdown]
# ## 4. Decision rollout eval (each trained suite x 4 robustness profiles)
# Evaluates the clean / iid / v4lite trained suites across `clean nominal_eval degraded_eval heading_biased_eval` (iid eval protocol) plus the `v4_lite` eval at `nominal_eval`.

# %%
os.environ["MODE"] = "decision_eval"
# !bash scripts/run_phase1a_oc_v4lite.sh
# Out:
# Streaming output truncated to the last 5000 lines.
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=90 | completed=89 (0.989) | gt_divergence=0 (0.000) | pred_divergence=1 (0.011) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.5787 m | pos p95=2.6585 m | rot median=0.0312 rad | total vel median=0.1077 m/s | rel vel median=0.1095 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=2.1853 m | pos p95=4.4580 m | rot median=0.0409 rad | total vel median=0.1288 m/s | rel vel median=0.1277 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=3.6688 m | pos p95=8.0412 m | rot median=0.0470 rad | total vel median=0.1344 m/s | rel vel median=0.1429 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.5700 m | pos p95=1.1147 m | rot median=0.0240 rad | total vel median=0.0608 m/s | rel vel median=0.0576 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.7453 m | pos p95=3.3948 m | rot median=0.0255 rad | total vel median=0.0448 m/s | rel vel median=0.0446 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=2.9556 m | pos p95=5.2999 m | rot median=0.0228 rad | total vel median=0.0633 m/s | rel vel median=0.0639 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=30 | completed=29 (0.967) | gt_divergence=0 (0.000) | pred_divergence=1 (0.033) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=1.0181 m | pos p95=2.6383 m | rot median=0.0654 rad | total vel median=0.1380 m/s | rel vel median=0.1268 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=2.8312 m | pos p95=5.3122 m | rot median=0.1085 rad | total vel median=0.1491 m/s | rel vel median=0.1556 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=7.1538 m | pos p95=16.1648 m | rot median=0.1504 rad | total vel median=0.1814 m/s | rel vel median=0.1865 m/s | cond_n=29/30 | completion=0.967 | gt_fail_by_h=0.000 | model_fail_by_h=0.033
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Earliest rollout failures
#   OU seed=200051 | reason=pred_divergence | sim_time=41.35s | pos=nan m | rot=nan rad | total_vel_violation=0
#
# Largest completed terminal errors
#   OU seed=200053 | reason=completed | sim_time=60.00s | pos=18.6401 m | rot=0.2612 rad | total_vel_violation=0
#   OU seed=200055 | reason=completed | sim_time=60.00s | pos=16.7347 m | rot=0.3792 rad | total_vel_violation=0
#   OU seed=200048 | reason=completed | sim_time=60.00s | pos=15.3099 m | rot=0.3830 rad | total_vel_violation=0
#   OU seed=200062 | reason=completed | sim_time=60.00s | pos=11.1994 m | rot=0.1504 rad | total_vel_violation=0
#   OU seed=200045 | reason=completed | sim_time=60.00s | pos=10.0994 m | rot=0.0847 rad | total_vel_violation=0
#
# Completed rollouts with velocity violations
#   OU seed=200061 | reason=completed | sim_time=60.00s | pos=7.8477 m | rot=0.2235 rad | total_vel_violation=1
#   OU seed=200068 | reason=completed | sim_time=60.00s | pos=4.4842 m | rot=0.0324 rad | total_vel_violation=1
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# OU seed=200051 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed43/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_015039/degraded_eval/diagnostic_plots/rollout_failure_OU_seed200051.png
# OU seed=200061 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed43/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_015039/degraded_eval/diagnostic_plots/velocity_violation_OU_seed200061.png
# OU seed=200068 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed43/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_015039/degraded_eval/diagnostic_plots/velocity_violation_OU_seed200068.png
# OU seed=200053 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed43/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_015039/degraded_eval/diagnostic_plots/high_terminal_error_OU_seed200053.png
# OU seed=200055 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed43/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_015039/degraded_eval/diagnostic_plots/high_terminal_error_OU_seed200055.png
# OU seed=200048 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed43/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_015039/degraded_eval/diagnostic_plots/high_terminal_error_OU_seed200048.png
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed43/best_model.pt | device=cuda | mode=resampled | noise_profile=heading_biased_eval | noise_protocol=iid_noisy_ic | noise_budget=protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350] | scenarios=PRBS,CHIRP,OU | trajectories=90 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed43/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_015039/heading_biased_eval
# [scenario 1/3] PRBS | 30 trajectories
# [1/90] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=25m14.4s
# [5/90] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=4m49.5s
# [10/90] PRBS seed=51 done | reason=completed | sim_time=60.00s | eta=2m16.3s
# [15/90] PRBS seed=56 done | reason=completed | sim_time=60.00s | eta=1m25.3s
# [20/90] PRBS seed=61 done | reason=completed | sim_time=60.00s | eta=59.8s
# [25/90] PRBS seed=66 done | reason=completed | sim_time=60.00s | eta=44.4s
# [30/90] PRBS seed=71 done | reason=completed | sim_time=60.00s | eta=34.2s
# [scenario done] PRBS | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=5.2302 m | pos_p95=9.9281 m | rot_med=0.0519 rad | completion=1.000 | elapsed=17.1s
# [scenario 2/3] CHIRP | 30 trajectories
# [31/90] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=1m05.1s
# [35/90] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=53.8s
# [40/90] CHIRP seed=100051 done | reason=completed | sim_time=60.00s | eta=42.8s
# [45/90] CHIRP seed=100056 done | reason=completed | sim_time=60.00s | eta=34.2s
# [50/90] CHIRP seed=100061 done | reason=completed | sim_time=60.00s | eta=27.4s
# [55/90] CHIRP seed=100066 done | reason=completed | sim_time=60.00s | eta=21.8s
# [60/90] CHIRP seed=100071 done | reason=completed | sim_time=60.00s | eta=17.2s
# [scenario done] CHIRP | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=3.5983 m | pos_p95=5.6470 m | rot_med=0.0342 rad | completion=1.000 | elapsed=34.3s
# [scenario 3/3] OU | 30 trajectories
# [61/90] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=24.4s
# [65/90] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=19.8s
# [70/90] OU seed=200051 done | reason=pred_divergence | sim_time=41.35s | eta=14.7s
# [75/90] OU seed=200056 done | reason=completed | sim_time=60.00s | eta=10.3s
# [80/90] OU seed=200061 done | reason=completed | sim_time=60.00s | eta=6.4s
# [85/90] OU seed=200066 done | reason=completed | sim_time=60.00s | eta=3.0s
# [90/90] OU seed=200071 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=29/30 | gt_div=0 | model_fail=1 | H=60.0s cond_n=29/30 | pos_med=7.2930 m | pos_p95=13.9662 m | rot_med=0.1496 rad | completion=0.967 | elapsed=51.5s
# Benchmark finished in 1m09.6s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed43/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_015039/heading_biased_eval
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed43/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: pH NODE q-Force [baseline/core]
# Canonical model type: phnode_qforce
# Energy semantics: not_comparable
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 30
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.8193 m | pos p95=2.5952 m | rot median=0.0405 rad | total vel median=0.0930 m/s | rel vel median=0.0866 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=2.6035 m | pos p95=5.3140 m | rot median=0.0480 rad | total vel median=0.1002 m/s | rel vel median=0.1009 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=5.0505 m | pos p95=11.5673 m | rot median=0.0606 rad | total vel median=0.1232 m/s | rel vel median=0.1196 m/s | cond_n=89/90 | completion=0.989 | gt_fail_by_h=0.000 | model_fail_by_h=0.011
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=90 | completed=89 (0.989) | gt_divergence=0 (0.000) | pred_divergence=1 (0.011) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.6979 m | pos p95=2.6872 m | rot median=0.0388 rad | total vel median=0.1099 m/s | rel vel median=0.1107 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=2.6777 m | pos p95=5.1592 m | rot median=0.0480 rad | total vel median=0.1283 m/s | rel vel median=0.1279 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=5.2302 m | pos p95=9.9281 m | rot median=0.0519 rad | total vel median=0.1355 m/s | rel vel median=0.1428 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.7639 m | pos p95=1.0221 m | rot median=0.0314 rad | total vel median=0.0566 m/s | rel vel median=0.0569 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=2.1688 m | pos p95=3.1245 m | rot median=0.0267 rad | total vel median=0.0450 m/s | rel vel median=0.0445 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=3.5983 m | pos p95=5.6470 m | rot median=0.0342 rad | total vel median=0.0679 m/s | rel vel median=0.0638 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=30 | completed=29 (0.967) | gt_divergence=0 (0.000) | pred_divergence=1 (0.033) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=1.0866 m | pos p95=2.5952 m | rot median=0.0728 rad | total vel median=0.1436 m/s | rel vel median=0.1256 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=2.9210 m | pos p95=6.4989 m | rot median=0.1002 rad | total vel median=0.1594 m/s | rel vel median=0.1555 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=7.2930 m | pos p95=13.9662 m | rot median=0.1496 rad | total vel median=0.1871 m/s | rel vel median=0.1864 m/s | cond_n=29/30 | completion=0.967 | gt_fail_by_h=0.000 | model_fail_by_h=0.033
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Earliest rollout failures
#   OU seed=200051 | reason=pred_divergence | sim_time=41.35s | pos=nan m | rot=nan rad | total_vel_violation=0
#
# Largest completed terminal errors
#   OU seed=200055 | reason=completed | sim_time=60.00s | pos=18.1753 m | rot=0.3953 rad | total_vel_violation=0
#   OU seed=200048 | reason=completed | sim_time=60.00s | pos=14.1315 m | rot=0.3659 rad | total_vel_violation=0
#   OU seed=200053 | reason=completed | sim_time=60.00s | pos=13.7181 m | rot=0.1998 rad | total_vel_violation=0
#   OU seed=200045 | reason=completed | sim_time=60.00s | pos=12.3429 m | rot=0.1090 rad | total_vel_violation=0
#   PRBS seed=63 | reason=completed | sim_time=60.00s | pos=11.5707 m | rot=0.1276 rad | total_vel_violation=0
#
# Completed rollouts with velocity violations
#   OU seed=200068 | reason=completed | sim_time=60.00s | pos=6.6751 m | rot=0.0606 rad | total_vel_violation=1
#   OU seed=200061 | reason=completed | sim_time=60.00s | pos=5.5897 m | rot=0.1977 rad | total_vel_violation=1
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# OU seed=200051 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed43/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_015039/heading_biased_eval/diagnostic_plots/rollout_failure_OU_seed200051.png
# OU seed=200068 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed43/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_015039/heading_biased_eval/diagnostic_plots/velocity_violation_OU_seed200068.png
# OU seed=200061 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed43/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_015039/heading_biased_eval/diagnostic_plots/velocity_violation_OU_seed200061.png
# OU seed=200055 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed43/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_015039/heading_biased_eval/diagnostic_plots/high_terminal_error_OU_seed200055.png
# OU seed=200048 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed43/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_015039/heading_biased_eval/diagnostic_plots/high_terminal_error_OU_seed200048.png
# OU seed=200053 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed43/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_015039/heading_biased_eval/diagnostic_plots/high_terminal_error_OU_seed200053.png
# [eval] baseline_phnode_qforce_seed44
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed44/best_model.pt | device=cuda | mode=resampled | noise_profile=clean | noise_protocol=clean | noise_budget=protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000] | scenarios=PRBS,CHIRP,OU | trajectories=90 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_020518/clean
# [scenario 1/3] PRBS | 30 trajectories
# [1/90] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=5h19m46.7s
# [5/90] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=1h01m05.1s
# [10/90] PRBS seed=51 done | reason=completed | sim_time=60.00s | eta=28m44.9s
# [15/90] PRBS seed=56 done | reason=completed | sim_time=60.00s | eta=17m58.2s
# [20/90] PRBS seed=61 done | reason=completed | sim_time=60.00s | eta=12m34.8s
# [25/90] PRBS seed=66 done | reason=completed | sim_time=60.00s | eta=9m20.7s
# [30/90] PRBS seed=71 done | reason=completed | sim_time=60.00s | eta=7m11.4s
# [scenario done] PRBS | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=0.6374 m | pos_p95=2.3946 m | rot_med=0.0068 rad | completion=1.000 | elapsed=3m35.7s
# [scenario 2/3] CHIRP | 30 trajectories
# [31/90] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=13m41.9s
# [35/90] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=11m18.7s
# [40/90] CHIRP seed=100051 done | reason=completed | sim_time=60.00s | eta=8m59.9s
# [45/90] CHIRP seed=100056 done | reason=completed | sim_time=60.00s | eta=7m11.9s
# [50/90] CHIRP seed=100061 done | reason=completed | sim_time=60.00s | eta=5m45.5s
# [55/90] CHIRP seed=100066 done | reason=completed | sim_time=60.00s | eta=4m34.9s
# [60/90] CHIRP seed=100071 done | reason=completed | sim_time=60.00s | eta=3m36.0s
# [scenario done] CHIRP | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=0.6688 m | pos_p95=1.4282 m | rot_med=0.0140 rad | completion=1.000 | elapsed=7m12.0s
# [scenario 3/3] OU | 30 trajectories
# [61/90] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=5m08.2s
# [65/90] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=4m09.3s
# [70/90] OU seed=200051 done | reason=completed | sim_time=60.00s | eta=3m05.2s
# [75/90] OU seed=200056 done | reason=completed | sim_time=60.00s | eta=2m09.7s
# [80/90] OU seed=200061 done | reason=completed | sim_time=60.00s | eta=1m21.0s
# [85/90] OU seed=200066 done | reason=pred_divergence | sim_time=58.95s | eta=38.1s
# [90/90] OU seed=200071 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=29/30 | gt_div=0 | model_fail=1 | H=60.0s cond_n=29/30 | pos_med=1.3461 m | pos_p95=2.6223 m | rot_med=0.0249 rad | completion=0.967 | elapsed=10m48.3s
# Benchmark finished in 11m07.1s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_020518/clean
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed44/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: pH NODE q-Force [baseline/core]
# Canonical model type: phnode_qforce
# Energy semantics: not_comparable
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 30
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.1012 m | pos p95=0.2823 m | rot median=0.0076 rad | total vel median=0.0100 m/s | rel vel median=0.0106 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=0.3119 m | pos p95=0.7548 m | rot median=0.0118 rad | total vel median=0.0118 m/s | rel vel median=0.0106 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=0.7291 m | pos p95=2.3984 m | rot median=0.0153 rad | total vel median=0.0125 m/s | rel vel median=0.0123 m/s | cond_n=89/90 | completion=0.989 | gt_fail_by_h=0.000 | model_fail_by_h=0.011
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=90 | completed=89 (0.989) | gt_divergence=0 (0.000) | pred_divergence=1 (0.011) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1027 m | pos p95=0.3451 m | rot median=0.0045 rad | total vel median=0.0145 m/s | rel vel median=0.0126 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.3071 m | pos p95=0.7548 m | rot median=0.0087 rad | total vel median=0.0149 m/s | rel vel median=0.0150 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=0.6374 m | pos p95=2.3946 m | rot median=0.0068 rad | total vel median=0.0142 m/s | rel vel median=0.0154 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.0744 m | pos p95=0.1372 m | rot median=0.0083 rad | total vel median=0.0087 m/s | rel vel median=0.0078 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.2462 m | pos p95=0.5021 m | rot median=0.0082 rad | total vel median=0.0078 m/s | rel vel median=0.0069 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=0.6688 m | pos p95=1.4282 m | rot median=0.0140 rad | total vel median=0.0087 m/s | rel vel median=0.0096 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=30 | completed=29 (0.967) | gt_divergence=0 (0.000) | pred_divergence=1 (0.033) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1344 m | pos p95=0.2601 m | rot median=0.0086 rad | total vel median=0.0130 m/s | rel vel median=0.0136 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.4053 m | pos p95=0.8955 m | rot median=0.0190 rad | total vel median=0.0163 m/s | rel vel median=0.0136 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.3461 m | pos p95=2.6223 m | rot median=0.0249 rad | total vel median=0.0202 m/s | rel vel median=0.0203 m/s | cond_n=29/30 | completion=0.967 | gt_fail_by_h=0.000 | model_fail_by_h=0.033
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Earliest rollout failures
#   OU seed=200066 | reason=pred_divergence | sim_time=58.95s | pos=nan m | rot=nan rad | total_vel_violation=0
#
# Largest completed terminal errors
#   OU seed=200049 | reason=completed | sim_time=60.00s | pos=2.8613 m | rot=0.0801 rad | total_vel_violation=0
#   OU seed=200068 | reason=completed | sim_time=60.00s | pos=2.6726 m | rot=0.0453 rad | total_vel_violation=0
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=2.6406 m | rot=0.0282 rad | total_vel_violation=0
#   OU seed=200061 | reason=completed | sim_time=60.00s | pos=2.5469 m | rot=0.0249 rad | total_vel_violation=1
#   PRBS seed=46 | reason=completed | sim_time=60.00s | pos=2.4288 m | rot=0.0352 rad | total_vel_violation=0
#
# Completed rollouts with velocity violations
#   OU seed=200061 | reason=completed | sim_time=60.00s | pos=2.5469 m | rot=0.0249 rad | total_vel_violation=1
#   OU seed=200055 | reason=completed | sim_time=60.00s | pos=1.2003 m | rot=0.0205 rad | total_vel_violation=1
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# OU seed=200066 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_020518/clean/diagnostic_plots/rollout_failure_OU_seed200066.png
# OU seed=200061 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_020518/clean/diagnostic_plots/velocity_violation_OU_seed200061.png
# OU seed=200055 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_020518/clean/diagnostic_plots/velocity_violation_OU_seed200055.png
# OU seed=200049 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_020518/clean/diagnostic_plots/high_terminal_error_OU_seed200049.png
# OU seed=200068 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_020518/clean/diagnostic_plots/high_terminal_error_OU_seed200068.png
# PRBS seed=42 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_020518/clean/diagnostic_plots/high_terminal_error_PRBS_seed42.png
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed44/best_model.pt | device=cuda | mode=resampled | noise_profile=nominal_eval | noise_protocol=iid_noisy_ic | noise_budget=protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | scenarios=PRBS,CHIRP,OU | trajectories=90 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_020518/nominal_eval
# [scenario 1/3] PRBS | 30 trajectories
# [1/90] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=25m31.8s
# [5/90] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=4m52.8s
# [10/90] PRBS seed=51 done | reason=completed | sim_time=60.00s | eta=2m17.9s
# [15/90] PRBS seed=56 done | reason=completed | sim_time=60.00s | eta=1m26.3s
# [20/90] PRBS seed=61 done | reason=completed | sim_time=60.00s | eta=1m00.4s
# [25/90] PRBS seed=66 done | reason=completed | sim_time=60.00s | eta=44.9s
# [30/90] PRBS seed=71 done | reason=completed | sim_time=60.00s | eta=34.6s
# [scenario done] PRBS | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=0.9076 m | pos_p95=2.8903 m | rot_med=0.0095 rad | completion=1.000 | elapsed=17.3s
# [scenario 2/3] CHIRP | 30 trajectories
# [31/90] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=1m05.6s
# [35/90] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=54.1s
# [40/90] CHIRP seed=100051 done | reason=completed | sim_time=60.00s | eta=43.1s
# [45/90] CHIRP seed=100056 done | reason=completed | sim_time=60.00s | eta=34.5s
# [50/90] CHIRP seed=100061 done | reason=completed | sim_time=60.00s | eta=27.6s
# [55/90] CHIRP seed=100066 done | reason=completed | sim_time=60.00s | eta=22.0s
# [60/90] CHIRP seed=100071 done | reason=completed | sim_time=60.00s | eta=17.3s
# [scenario done] CHIRP | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=0.7385 m | pos_p95=2.5398 m | rot_med=0.0143 rad | completion=1.000 | elapsed=34.6s
# [scenario 3/3] OU | 30 trajectories
# [61/90] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=24.7s
# [65/90] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=20.0s
# [70/90] OU seed=200051 done | reason=completed | sim_time=60.00s | eta=14.9s
# [75/90] OU seed=200056 done | reason=completed | sim_time=60.00s | eta=10.4s
# [80/90] OU seed=200061 done | reason=completed | sim_time=60.00s | eta=6.5s
# [85/90] OU seed=200066 done | reason=pred_divergence | sim_time=58.95s | eta=3.1s
# [90/90] OU seed=200071 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=29/30 | gt_div=0 | model_fail=1 | H=60.0s cond_n=29/30 | pos_med=1.2545 m | pos_p95=3.5550 m | rot_med=0.0276 rad | completion=0.967 | elapsed=52.1s
# Benchmark finished in 1m10.4s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_020518/nominal_eval
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed44/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: pH NODE q-Force [baseline/core]
# Canonical model type: phnode_qforce
# Energy semantics: not_comparable
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 30
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.1659 m | pos p95=0.4308 m | rot median=0.0105 rad | total vel median=0.0119 m/s | rel vel median=0.0105 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=0.4200 m | pos p95=1.2435 m | rot median=0.0130 rad | total vel median=0.0125 m/s | rel vel median=0.0106 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=0.9005 m | pos p95=3.1729 m | rot median=0.0175 rad | total vel median=0.0126 m/s | rel vel median=0.0123 m/s | cond_n=89/90 | completion=0.989 | gt_fail_by_h=0.000 | model_fail_by_h=0.011
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=90 | completed=89 (0.989) | gt_divergence=0 (0.000) | pred_divergence=1 (0.011) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1677 m | pos p95=0.4184 m | rot median=0.0089 rad | total vel median=0.0162 m/s | rel vel median=0.0127 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.4093 m | pos p95=1.0949 m | rot median=0.0129 rad | total vel median=0.0153 m/s | rel vel median=0.0150 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=0.9076 m | pos p95=2.8903 m | rot median=0.0095 rad | total vel median=0.0140 m/s | rel vel median=0.0155 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1332 m | pos p95=0.3530 m | rot median=0.0107 rad | total vel median=0.0102 m/s | rel vel median=0.0079 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.3419 m | pos p95=1.1346 m | rot median=0.0092 rad | total vel median=0.0081 m/s | rel vel median=0.0069 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=0.7385 m | pos p95=2.5398 m | rot median=0.0143 rad | total vel median=0.0094 m/s | rel vel median=0.0096 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=30 | completed=29 (0.967) | gt_divergence=0 (0.000) | pred_divergence=1 (0.033) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1915 m | pos p95=0.4261 m | rot median=0.0130 rad | total vel median=0.0137 m/s | rel vel median=0.0136 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.4412 m | pos p95=1.3272 m | rot median=0.0210 rad | total vel median=0.0172 m/s | rel vel median=0.0137 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.2545 m | pos p95=3.5550 m | rot median=0.0276 rad | total vel median=0.0217 m/s | rel vel median=0.0203 m/s | cond_n=29/30 | completion=0.967 | gt_fail_by_h=0.000 | model_fail_by_h=0.033
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Earliest rollout failures
#   OU seed=200066 | reason=pred_divergence | sim_time=58.95s | pos=nan m | rot=nan rad | total_vel_violation=0
#
# Largest completed terminal errors
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=5.2397 m | rot=0.0477 rad | total_vel_violation=0
#   OU seed=200056 | reason=completed | sim_time=60.00s | pos=3.8036 m | rot=0.0874 rad | total_vel_violation=0
#   PRBS seed=46 | reason=completed | sim_time=60.00s | pos=3.7941 m | rot=0.0476 rad | total_vel_violation=0
#   OU seed=200059 | reason=completed | sim_time=60.00s | pos=3.7508 m | rot=0.0758 rad | total_vel_violation=0
#   OU seed=200057 | reason=completed | sim_time=60.00s | pos=3.2613 m | rot=0.0486 rad | total_vel_violation=0
#
# Completed rollouts with velocity violations
#   OU seed=200061 | reason=completed | sim_time=60.00s | pos=2.1167 m | rot=0.0208 rad | total_vel_violation=1
#   OU seed=200055 | reason=completed | sim_time=60.00s | pos=0.2757 m | rot=0.0088 rad | total_vel_violation=1
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# OU seed=200066 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_020518/nominal_eval/diagnostic_plots/rollout_failure_OU_seed200066.png
# OU seed=200061 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_020518/nominal_eval/diagnostic_plots/velocity_violation_OU_seed200061.png
# OU seed=200055 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_020518/nominal_eval/diagnostic_plots/velocity_violation_OU_seed200055.png
# PRBS seed=42 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_020518/nominal_eval/diagnostic_plots/high_terminal_error_PRBS_seed42.png
# OU seed=200056 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_020518/nominal_eval/diagnostic_plots/high_terminal_error_OU_seed200056.png
# PRBS seed=46 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_020518/nominal_eval/diagnostic_plots/high_terminal_error_PRBS_seed46.png
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed44/best_model.pt | device=cuda | mode=resampled | noise_profile=degraded_eval | noise_protocol=iid_noisy_ic | noise_budget=protocol=iid_noisy_ic | profile=degraded_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250] | scenarios=PRBS,CHIRP,OU | trajectories=90 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_020518/degraded_eval
# [scenario 1/3] PRBS | 30 trajectories
# [1/90] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=25m46.6s
# [5/90] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=4m55.6s
# [10/90] PRBS seed=51 done | reason=completed | sim_time=60.00s | eta=2m19.2s
# [15/90] PRBS seed=56 done | reason=completed | sim_time=60.00s | eta=1m27.1s
# [20/90] PRBS seed=61 done | reason=completed | sim_time=60.00s | eta=1m01.0s
# [25/90] PRBS seed=66 done | reason=completed | sim_time=60.00s | eta=45.4s
# [30/90] PRBS seed=71 done | reason=completed | sim_time=60.00s | eta=34.9s
# [scenario done] PRBS | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=2.0189 m | pos_p95=5.5121 m | rot_med=0.0227 rad | completion=1.000 | elapsed=17.5s
# [scenario 2/3] CHIRP | 30 trajectories
# [31/90] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=1m06.4s
# [35/90] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=54.8s
# [40/90] CHIRP seed=100051 done | reason=completed | sim_time=60.00s | eta=43.6s
# [45/90] CHIRP seed=100056 done | reason=completed | sim_time=60.00s | eta=34.9s
# [50/90] CHIRP seed=100061 done | reason=completed | sim_time=60.00s | eta=28.0s
# [55/90] CHIRP seed=100066 done | reason=completed | sim_time=60.00s | eta=22.2s
# [60/90] CHIRP seed=100071 done | reason=completed | sim_time=60.00s | eta=17.5s
# [scenario done] CHIRP | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=1.2784 m | pos_p95=5.0145 m | rot_med=0.0175 rad | completion=1.000 | elapsed=35.0s
# [scenario 3/3] OU | 30 trajectories
# [61/90] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=24.8s
# [65/90] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=20.1s
# [70/90] OU seed=200051 done | reason=completed | sim_time=60.00s | eta=14.9s
# [75/90] OU seed=200056 done | reason=completed | sim_time=60.00s | eta=10.5s
# [80/90] OU seed=200061 done | reason=completed | sim_time=60.00s | eta=6.5s
# [85/90] OU seed=200066 done | reason=pred_divergence | sim_time=58.95s | eta=3.1s
# [90/90] OU seed=200071 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=29/30 | gt_div=0 | model_fail=1 | H=60.0s cond_n=29/30 | pos_med=1.7334 m | pos_p95=6.0138 m | rot_med=0.0344 rad | completion=0.967 | elapsed=52.3s
# Benchmark finished in 1m10.6s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_020518/degraded_eval
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed44/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: pH NODE q-Force [baseline/core]
# Canonical model type: phnode_qforce
# Energy semantics: not_comparable
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 30
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.3146 m | pos p95=0.9373 m | rot median=0.0223 rad | total vel median=0.0140 m/s | rel vel median=0.0104 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=0.8932 m | pos p95=2.5450 m | rot median=0.0209 rad | total vel median=0.0141 m/s | rel vel median=0.0106 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=1.6872 m | pos p95=5.6425 m | rot median=0.0243 rad | total vel median=0.0145 m/s | rel vel median=0.0123 m/s | cond_n=89/90 | completion=0.989 | gt_fail_by_h=0.000 | model_fail_by_h=0.011
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=90 | completed=89 (0.989) | gt_divergence=0 (0.000) | pred_divergence=1 (0.011) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.3332 m | pos p95=0.9072 m | rot median=0.0241 rad | total vel median=0.0192 m/s | rel vel median=0.0129 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.0544 m | pos p95=2.1876 m | rot median=0.0187 rad | total vel median=0.0184 m/s | rel vel median=0.0150 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=2.0189 m | pos p95=5.5121 m | rot median=0.0227 rad | total vel median=0.0157 m/s | rel vel median=0.0155 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.2432 m | pos p95=0.8203 m | rot median=0.0166 rad | total vel median=0.0111 m/s | rel vel median=0.0081 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.6146 m | pos p95=2.3815 m | rot median=0.0145 rad | total vel median=0.0101 m/s | rel vel median=0.0067 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.2784 m | pos p95=5.0145 m | rot median=0.0175 rad | total vel median=0.0101 m/s | rel vel median=0.0096 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=30 | completed=29 (0.967) | gt_divergence=0 (0.000) | pred_divergence=1 (0.033) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.3613 m | pos p95=0.9023 m | rot median=0.0253 rad | total vel median=0.0160 m/s | rel vel median=0.0135 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.0546 m | pos p95=2.6925 m | rot median=0.0239 rad | total vel median=0.0181 m/s | rel vel median=0.0139 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.7334 m | pos p95=6.0138 m | rot median=0.0344 rad | total vel median=0.0204 m/s | rel vel median=0.0201 m/s | cond_n=29/30 | completion=0.967 | gt_fail_by_h=0.000 | model_fail_by_h=0.033
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Earliest rollout failures
#   OU seed=200066 | reason=pred_divergence | sim_time=58.95s | pos=nan m | rot=nan rad | total_vel_violation=0
#
# Largest completed terminal errors
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=9.1852 m | rot=0.0776 rad | total_vel_violation=0
#   OU seed=200056 | reason=completed | sim_time=60.00s | pos=7.3229 m | rot=0.1389 rad | total_vel_violation=0
#   OU seed=200059 | reason=completed | sim_time=60.00s | pos=6.5016 m | rot=0.1046 rad | total_vel_violation=0
#   PRBS seed=46 | reason=completed | sim_time=60.00s | pos=5.8014 m | rot=0.0658 rad | total_vel_violation=0
#   CHIRP seed=100064 | reason=completed | sim_time=60.00s | pos=5.7718 m | rot=0.0685 rad | total_vel_violation=0
#
# Completed rollouts with velocity violations
#   OU seed=200061 | reason=completed | sim_time=60.00s | pos=1.4792 m | rot=0.0152 rad | total_vel_violation=1
# ...
#   H=60.0s | pos median=0.9363 m | pos p95=2.8854 m | rot median=0.0157 rad | total vel median=0.0165 m/s | rel vel median=0.0142 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1567 m | pos p95=0.3065 m | rot median=0.0115 rad | total vel median=0.0141 m/s | rel vel median=0.0135 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.4096 m | pos p95=0.9114 m | rot median=0.0101 rad | total vel median=0.0121 m/s | rel vel median=0.0109 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=0.9088 m | pos p95=2.0174 m | rot median=0.0115 rad | total vel median=0.0122 m/s | rel vel median=0.0110 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.2325 m | pos p95=0.3223 m | rot median=0.0141 rad | total vel median=0.0137 m/s | rel vel median=0.0134 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.4952 m | pos p95=1.1303 m | rot median=0.0232 rad | total vel median=0.0132 m/s | rel vel median=0.0106 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.3045 m | pos p95=2.6476 m | rot median=0.0243 rad | total vel median=0.0254 m/s | rel vel median=0.0209 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Largest completed terminal errors
#   PRBS seed=63 | reason=completed | sim_time=60.00s | pos=3.7391 m | rot=0.0342 rad | total_vel_violation=0
#   PRBS seed=46 | reason=completed | sim_time=60.00s | pos=3.5268 m | rot=0.0545 rad | total_vel_violation=0
#   OU seed=200047 | reason=completed | sim_time=60.00s | pos=2.8445 m | rot=0.0368 rad | total_vel_violation=0
#   OU seed=200057 | reason=completed | sim_time=60.00s | pos=2.7944 m | rot=0.0432 rad | total_vel_violation=0
#   CHIRP seed=100068 | reason=completed | sim_time=60.00s | pos=2.5507 m | rot=0.0372 rad | total_vel_violation=0
#
# Completed rollouts with velocity violations
#   OU seed=200068 | reason=completed | sim_time=60.00s | pos=2.4683 m | rot=0.0366 rad | total_vel_violation=1
#   OU seed=200055 | reason=completed | sim_time=60.00s | pos=1.0653 m | rot=0.0145 rad | total_vel_violation=1
#   OU seed=200061 | reason=completed | sim_time=60.00s | pos=0.7739 m | rot=0.0263 rad | total_vel_violation=1
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# OU seed=200068 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed45/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260524_041928/diagnostic_plots/velocity_violation_OU_seed200068.png
# OU seed=200055 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed45/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260524_041928/diagnostic_plots/velocity_violation_OU_seed200055.png
# OU seed=200061 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed45/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260524_041928/diagnostic_plots/velocity_violation_OU_seed200061.png
# PRBS seed=63 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed45/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260524_041928/diagnostic_plots/high_terminal_error_PRBS_seed63.png
# PRBS seed=46 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed45/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260524_041928/diagnostic_plots/high_terminal_error_PRBS_seed46.png
# OU seed=200047 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed45/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260524_041928/diagnostic_plots/high_terminal_error_OU_seed200047.png
# [eval] baseline_phnode_qforce_seed46
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed46/best_model.pt | device=cuda | mode=resampled | noise_profile=nominal_eval | noise_protocol=v4_lite | noise_budget=protocol=v4_lite | profile=nominal_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | scenarios=PRBS,CHIRP,OU | trajectories=90 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260524_042042
# [scenario 1/3] PRBS | 30 trajectories
# [1/90] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=25m16.7s
# [5/90] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=4m49.9s
# [10/90] PRBS seed=51 done | reason=completed | sim_time=60.00s | eta=2m16.6s
# [15/90] PRBS seed=56 done | reason=completed | sim_time=60.00s | eta=1m25.4s
# [20/90] PRBS seed=61 done | reason=completed | sim_time=60.00s | eta=59.9s
# [25/90] PRBS seed=66 done | reason=completed | sim_time=60.00s | eta=44.5s
# [30/90] PRBS seed=71 done | reason=completed | sim_time=60.00s | eta=34.3s
# [scenario done] PRBS | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=0.7731 m | pos_p95=2.7237 m | rot_med=0.0145 rad | completion=1.000 | elapsed=17.2s
# [scenario 2/3] CHIRP | 30 trajectories
# [31/90] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=1m04.5s
# [35/90] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=53.3s
# [40/90] CHIRP seed=100051 done | reason=completed | sim_time=60.00s | eta=42.4s
# [45/90] CHIRP seed=100056 done | reason=completed | sim_time=60.00s | eta=34.0s
# [50/90] CHIRP seed=100061 done | reason=completed | sim_time=60.00s | eta=27.2s
# [55/90] CHIRP seed=100066 done | reason=completed | sim_time=60.00s | eta=21.6s
# [60/90] CHIRP seed=100071 done | reason=completed | sim_time=60.00s | eta=17.0s
# [scenario done] CHIRP | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=1.3542 m | pos_p95=2.3576 m | rot_med=0.0269 rad | completion=1.000 | elapsed=34.0s
# [scenario 3/3] OU | 30 trajectories
# [61/90] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=24.1s
# [65/90] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=19.5s
# [70/90] OU seed=200051 done | reason=completed | sim_time=60.00s | eta=14.5s
# [75/90] OU seed=200056 done | reason=completed | sim_time=60.00s | eta=10.2s
# [80/90] OU seed=200061 done | reason=completed | sim_time=60.00s | eta=6.3s
# [85/90] OU seed=200066 done | reason=pred_divergence | sim_time=58.95s | eta=3.0s
# [90/90] OU seed=200071 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=29/30 | gt_div=0 | model_fail=1 | H=60.0s cond_n=29/30 | pos_med=1.2416 m | pos_p95=3.3019 m | rot_med=0.0298 rad | completion=0.967 | elapsed=50.9s
# Benchmark finished in 1m10.1s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260524_042042
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed46/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: pH NODE q-Force [baseline/core]
# Canonical model type: phnode_qforce
# Energy semantics: not_comparable
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 30
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.1381 m | pos p95=0.3031 m | rot median=0.0083 rad | total vel median=0.0087 m/s | rel vel median=0.0071 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=0.4252 m | pos p95=1.1063 m | rot median=0.0159 rad | total vel median=0.0117 m/s | rel vel median=0.0081 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=1.2188 m | pos p95=2.9527 m | rot median=0.0245 rad | total vel median=0.0098 m/s | rel vel median=0.0116 m/s | cond_n=89/90 | completion=0.989 | gt_fail_by_h=0.000 | model_fail_by_h=0.011
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=90 | completed=89 (0.989) | gt_divergence=0 (0.000) | pred_divergence=1 (0.011) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1230 m | pos p95=0.3471 m | rot median=0.0077 rad | total vel median=0.0112 m/s | rel vel median=0.0104 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.4208 m | pos p95=1.1795 m | rot median=0.0105 rad | total vel median=0.0161 m/s | rel vel median=0.0155 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=0.7731 m | pos p95=2.7237 m | rot median=0.0145 rad | total vel median=0.0101 m/s | rel vel median=0.0149 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1280 m | pos p95=0.2846 m | rot median=0.0083 rad | total vel median=0.0057 m/s | rel vel median=0.0050 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.4352 m | pos p95=0.9435 m | rot median=0.0159 rad | total vel median=0.0065 m/s | rel vel median=0.0058 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.3542 m | pos p95=2.3576 m | rot median=0.0269 rad | total vel median=0.0079 m/s | rel vel median=0.0073 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=30 | completed=29 (0.967) | gt_divergence=0 (0.000) | pred_divergence=1 (0.033) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1485 m | pos p95=0.2904 m | rot median=0.0096 rad | total vel median=0.0153 m/s | rel vel median=0.0148 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.4369 m | pos p95=0.8704 m | rot median=0.0197 rad | total vel median=0.0170 m/s | rel vel median=0.0135 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.2416 m | pos p95=3.3019 m | rot median=0.0298 rad | total vel median=0.0219 m/s | rel vel median=0.0157 m/s | cond_n=29/30 | completion=0.967 | gt_fail_by_h=0.000 | model_fail_by_h=0.033
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Earliest rollout failures
#   OU seed=200066 | reason=pred_divergence | sim_time=58.95s | pos=nan m | rot=nan rad | total_vel_violation=0
#
# Largest completed terminal errors
#   OU seed=200068 | reason=completed | sim_time=60.00s | pos=3.6619 m | rot=0.0615 rad | total_vel_violation=0
#   OU seed=200059 | reason=completed | sim_time=60.00s | pos=3.4792 m | rot=0.0966 rad | total_vel_violation=0
#   PRBS seed=63 | reason=completed | sim_time=60.00s | pos=3.4440 m | rot=0.0423 rad | total_vel_violation=0
#   CHIRP seed=100042 | reason=completed | sim_time=60.00s | pos=3.1299 m | rot=0.0466 rad | total_vel_violation=0
#   OU seed=200057 | reason=completed | sim_time=60.00s | pos=3.0361 m | rot=0.0571 rad | total_vel_violation=0
#
# Completed rollouts with velocity violations
#   OU seed=200055 | reason=completed | sim_time=60.00s | pos=2.2302 m | rot=0.0395 rad | total_vel_violation=1
#   OU seed=200061 | reason=completed | sim_time=60.00s | pos=1.3351 m | rot=0.0162 rad | total_vel_violation=1
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# OU seed=200066 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260524_042042/diagnostic_plots/rollout_failure_OU_seed200066.png
# OU seed=200055 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260524_042042/diagnostic_plots/velocity_violation_OU_seed200055.png
# OU seed=200061 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260524_042042/diagnostic_plots/velocity_violation_OU_seed200061.png
# OU seed=200068 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260524_042042/diagnostic_plots/high_terminal_error_OU_seed200068.png
# OU seed=200059 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260524_042042/diagnostic_plots/high_terminal_error_OU_seed200059.png
# PRBS seed=63 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phnode_qforce/baseline_phnode_qforce_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260524_042042/diagnostic_plots/high_terminal_error_PRBS_seed63.png
# Batch evaluation complete.

# %% [markdown]
# ## 5. Provenance injection (per-run `_audit_meta/`)
# Records git HEAD + environment fingerprint into every decision run dir so these runs are distinguishable from catalog-era drift when the catalog is rebuilt.

# %%
# Inject per-run provenance. The training flow does NOT write these automatically,
# so for paper-grade evidence we record them here (see docs/provenance_audit_phnode_full_clean.md sec 5.2).
import os, sys, subprocess, datetime
from pathlib import Path
import torch

RUN_TAG = os.environ["RUN_TAG"]
ckpt = PROJECT_DIR / "checkpoints"
suites = [ckpt / f"sweep_oc_phase1a_decision_{p}_{RUN_TAG}" for p in ("clean", "iid", "v4lite")]

def _sh(args):
    try:
        return subprocess.run(args, cwd=PROJECT_DIR, capture_output=True, text=True).stdout.strip()
    except Exception as exc:  # noqa: BLE001
        return f"<unavailable: {exc}>"

head = _sh(["git", "rev-parse", "HEAD"])
diffstat = _sh(["git", "diff", "HEAD", "--stat"])
env_txt = "\n".join([
    f"python={sys.version.split()[0]}",
    f"torch={torch.__version__}",
    f"cuda={torch.version.cuda}",
    f"cudnn={torch.backends.cudnn.version()}",
    f"gpu={torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'cpu'}",
    f"captured_at={datetime.datetime.now().isoformat()}",
])

n = 0
for suite in suites:
    if not suite.exists():
        continue
    for cfg in suite.rglob("config.json"):
        run_dir = cfg.parent
        meta = run_dir / "_audit_meta"
        meta.mkdir(exist_ok=True)
        (meta / "code_revision.txt").write_text(f"git_head={head}\n\n{diffstat}\n")
        (meta / "environment.txt").write_text(env_txt + "\n")
        n += 1
print(f"provenance written for {n} run dirs")
print("git_head =", head)
# Out:
# provenance written for 15 run dirs
# git_head =

# %% [markdown]
# ## 6. Anomaly scan
# Flags any run with the `no successful training batches` catastrophic-gradient signature (the seed46 failure mode). A flagged seed must NOT be cited — rerun or annotate.

# %%
# Quick anomaly scan: catch seed46/seed43-style catastrophic training before trusting numbers.
# Flags any run whose training.log contains the "no successful training batches" failure mode.
import os, re
from pathlib import Path

RUN_TAG = os.environ["RUN_TAG"]
ckpt = PROJECT_DIR / "checkpoints"
suites = [ckpt / f"sweep_oc_phase1a_decision_{p}_{RUN_TAG}" for p in ("clean", "iid", "v4lite")]

print(f"{'suite':<48}{'run':<32}{'best_epoch':>10}{'best_loss':>14}{'nbad':>6}  flag")
for suite in suites:
    if not suite.exists():
        continue
    for cfg in sorted(suite.rglob("config.json")):
        run_dir = cfg.parent
        log = run_dir / "training.log"
        text = log.read_text() if log.exists() else ""
        nbad = text.count("no successful training batches")
        best_epoch, best_loss = "?", "?"
        m = re.findall(r"[Bb]est.*?epoch[^0-9]*([0-9]+).*?([0-9]+\.[0-9eE+-]+)", text)
        if m:
            best_epoch, best_loss = m[-1]
        flag = "  <-- CHECK (possible artifact)" if nbad > 0 else ""
        print(f"{suite.name[:46]:<48}{run_dir.name[:30]:<32}{str(best_epoch):>10}{str(best_loss):>14}{nbad:>6}{flag}")
print("\nIf any run is flagged, treat that seed like seed46/seed43: do NOT cite it; rerun or annotate.")
# Out:
# suite                                           run                             best_epoch     best_loss  nbad  flag
# sweep_oc_phase1a_decision_clean_t2_wpfrag_phno  baseline_phnode_qforce_seed42            ?             ?     0
# sweep_oc_phase1a_decision_clean_t2_wpfrag_phno  baseline_phnode_qforce_seed43            ?             ?     0
# sweep_oc_phase1a_decision_clean_t2_wpfrag_phno  baseline_phnode_qforce_seed44            ?             ?     0
# sweep_oc_phase1a_decision_clean_t2_wpfrag_phno  baseline_phnode_qforce_seed45            ?             ?     0
# sweep_oc_phase1a_decision_clean_t2_wpfrag_phno  baseline_phnode_qforce_seed46            ?             ?     0
# sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode  baseline_phnode_qforce_seed42            ?             ?     0
# sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode  baseline_phnode_qforce_seed43            ?             ?     0
# sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode  baseline_phnode_qforce_seed44            ?             ?     0
# sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode  baseline_phnode_qforce_seed45            ?             ?     0
# sweep_oc_phase1a_decision_iid_t2_wpfrag_phnode  baseline_phnode_qforce_seed46            ?             ?     0
# sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phn  baseline_phnode_qforce_seed42            ?             ?     0
# sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phn  baseline_phnode_qforce_seed43            ?             ?     0
# sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phn  baseline_phnode_qforce_seed44            ?             ?     0
# sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phn  baseline_phnode_qforce_seed45            ?             ?     0
# sweep_oc_phase1a_decision_v4lite_t2_wpfrag_phn  baseline_phnode_qforce_seed46            ?             ?     0
#
# If any run is flagged, treat that seed like seed46/seed43: do NOT cite it; rerun or annotate.

# %% [markdown]
# ## 7. Next step (after all 4 notebooks finish)
# 1. Ensure `checkpoints/sweep_oc_phase1a_decision_{clean,iid,v4lite}_t2_wpfrag_*` are synced back to the repo.
# 2. Locally: `conda run -n mytorch1 python scripts/build_oc_data_catalog.py` to ingest the new runs.
# 3. Export the section-8 current-evidence tables from the rebuilt canonical views.
# 4. Re-verify the `ablate_no_lift` noisy-degradation claim is not driven by a seed44 artifact.
