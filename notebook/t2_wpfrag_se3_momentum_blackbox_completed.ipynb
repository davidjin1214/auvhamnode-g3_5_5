# %% [markdown]
# # Black-box current-evidence rerun (clean-only) — `se3_momentum_blackbox`
#
# **Goal.** Regenerate a black-box / semi-structured baseline on the current-main
# (`g3_5_7` mirror) regime so the chapter-section-8 "structured >> black-box" claim has a
# clean-mirror anchor directly comparable to the four T2 models. Catalog-era black-box numbers
# come from the 2026-04 `sweep_oc_core_default_*` suite — a different regime that collapsed
# `phnode_full` on 3/6 clean seeds and flipped `phnode_qforce` clean 0.57<->3.76, so they
# cannot be cross-compared with T2.
#
# **Matrix (this notebook).** `se3_momentum_blackbox` x {clean} x seeds {42,43,44,45,46} = 5 training
# runs (clean-only via `PHASE1A_PROTOCOLS=clean`), then the clean suite is evaluated across
# {clean, nominal_eval, degraded_eval, heading_biased_eval} under iid_noisy_ic + v4_lite eval
# protocols — identical to the eval the T2 clean suites received.
#
# **Parallelism.** Run the three black-box notebooks (`blackbox_fullstate`,
# `se3_momentum_blackbox`, `se3_accel_blackbox`) in separate Colab sessions. Distinct
# `RUN_TAG`s, no collision.
#
# **After all three finish:** sync `checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_*`
# back, then locally rerun `scripts/export_section8_t2_evidence.py` — the black-box models are
# already in its MODELS list, so the clean rows append to `aggregate.csv` automatically.
#
# > Watch list: black-box models are collapse-prone (`blackbox_fullstate` was nan/86.8m in the
# > old catalog). The anomaly-scan cell flags any clean-mirror collapse; a real collapse is a
# > legitimate instability finding (handle per B1: exclude from aggregate, annotate).

# %%
# !nvidia-smi
# Out:
# Mon May 25 11:44:05 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   51C    P8             13W /   72W |       0MiB /  23034MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import torch
print(f"PyTorch: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"CUDA: {torch.version.cuda}")
print(f"cuDNN: {torch.backends.cudnn.version()}")
# Out:
# PyTorch: 2.10.0+cu128
# CUDA available: True
# CUDA: 12.8
# cuDNN: 91002

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
from pathlib import Path

PROJECT_DIR = Path(os.environ.get(
    "AUV_PROJECT_DIR",
    "/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7",
))
assert PROJECT_DIR.exists(), f"Project directory not found: {PROJECT_DIR}"
# %cd $PROJECT_DIR
# Out:
# /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7

# %%
# %pip install -q torchdiffeq pandas

# %% [markdown]
# ## 0. Configuration

# %%
import os

# Runtime
os.environ["PYTHON_BIN"] = "python"
os.environ["DEVICE"] = "cuda"
os.environ["LOCAL_PROXY_ROOT"] = "/content/_proxy_suites"

# ---- identity (one black-box model per notebook) ----
os.environ["RUN_TAG"] = "t2_wpfrag_se3_momentum_blackbox"
os.environ["DATASET"] = "data/auv_oc_traj1000_blk150_s23_d0be9434.pkl"
os.environ["NOISE_REFERENCE"] = "remus100_dr"
os.environ["PHASE1A_LOG_DIR"] = str(PROJECT_DIR / "checkpoints" / "phase1a_logs" / os.environ["RUN_TAG"])
os.environ["PHASE1A_METADATA_DIR"] = str(PROJECT_DIR / "checkpoints" / f"phase1a_metadata_{os.environ['RUN_TAG']}")

# ---- matrix: single black-box model x CLEAN-ONLY x 5 seeds ----
os.environ["PHASE1A_MODELS"] = "se3_momentum_blackbox"
os.environ["SMOKE1_MODELS"] = "se3_momentum_blackbox"
os.environ["PHASE1A_PROTOCOLS"] = "clean"        # clean-only knob (driver default is "clean iid v4lite")
os.environ["SMOKE_SEEDS"] = "42"                 # cheap protocol-correctness gate (1 seed)
os.environ["DECISION_SEEDS"] = "42 43 44 45 46"  # full current-evidence seed set (matches T2)

# ---- Evaluation contract (identical to T2 clean suite) ----
os.environ["SMOKE_EVAL_NUM_TRAJ_PER_SCENARIO"] = "6"
os.environ["DECISION_EVAL_NUM_TRAJ_PER_SCENARIO"] = "30"
os.environ["EVAL_TIMES"] = "10 30 60"
os.environ["EVAL_SCENARIOS"] = "PRBS CHIRP OU"
os.environ["EVAL_BASE_SEED"] = "42"
os.environ["EVAL_NOISE_SEED"] = "2024"
os.environ["EVAL_PROGRESS_EVERY"] = "5"
os.environ["EVAL_NUM_DIAGNOSTIC_PLOTS"] = "6"
# Full robustness set: evaluate the clean-trained suite across all 4 profiles (caveat B).
os.environ["IID_EVAL_PROFILES"] = "clean nominal_eval degraded_eval heading_biased_eval"
os.environ["V4_EVAL_PROFILES"] = "nominal_eval"

# ---- Audit gate ----
os.environ["STRICT_ZERO_NOISE_AUDIT"] = "1"
os.environ["SOFT_MIN_EPOCH_SCALE"] = "0.05"

print("RUN_TAG          =", os.environ["RUN_TAG"])
print("PHASE1A_MODELS   =", os.environ["PHASE1A_MODELS"])
print("PHASE1A_PROTOCOLS=", os.environ["PHASE1A_PROTOCOLS"])
print("DECISION_SEEDS   =", os.environ["DECISION_SEEDS"])
print("IID_EVAL_PROFILES=", os.environ["IID_EVAL_PROFILES"])
# Out:
# RUN_TAG          = t2_wpfrag_se3_momentum_blackbox
# PHASE1A_MODELS   = se3_momentum_blackbox
# PHASE1A_PROTOCOLS= clean
# DECISION_SEEDS   = 42 43 44 45 46
# IID_EVAL_PROFILES= clean nominal_eval degraded_eval heading_biased_eval

# %% [markdown]
# ## 1. Preflight
# Confirms target suite/proxy dirs are absent and saves suite-level run config + environment metadata. If it fails, change `RUN_TAG` or remove the target dirs.

# %%
os.environ["MODE"] = "preflight"
# !bash scripts/run_phase1a_oc_v4lite.sh
# Out:
# [phase1a]
# MODE=preflight
# RUN_TAG=t2_wpfrag_se3_momentum_blackbox
# DATASET=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# DEVICE=cuda
# PHASE1A_MODELS=se3_momentum_blackbox
# PHASE1A_PROTOCOLS=clean
# SMOKE1_MODELS=se3_momentum_blackbox
# SMOKE_SEEDS=42
# DECISION_SEEDS=42 43 44 45 46
# NOISE_REFERENCE=remus100_dr
# PHASE1A_LOG_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_logs/t2_wpfrag_se3_momentum_blackbox
# PHASE1A_METADATA_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_metadata_t2_wpfrag_se3_momentum_blackbox
# Preflight passed: all Phase-1A target suite/proxy directories are absent.
# [metadata] /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_metadata_t2_wpfrag_se3_momentum_blackbox

# %% [markdown]
# ## 2. Smoke gate (seed 42, clean only)
# Cheap protocol-correctness check for the clean path + strict zero-noise audit. Smoke results are flow-validation only — never cited.

# %%
os.environ["MODE"] = "smoke1_train"
# !bash scripts/run_phase1a_oc_v4lite.sh
# Out:
# [phase1a]
# MODE=smoke1_train
# RUN_TAG=t2_wpfrag_se3_momentum_blackbox
# DATASET=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# DEVICE=cuda
# PHASE1A_MODELS=se3_momentum_blackbox
# PHASE1A_PROTOCOLS=clean
# SMOKE1_MODELS=se3_momentum_blackbox
# SMOKE_SEEDS=42
# DECISION_SEEDS=42 43 44 45 46
# NOISE_REFERENCE=remus100_dr
# PHASE1A_LOG_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_logs/t2_wpfrag_se3_momentum_blackbox
# PHASE1A_METADATA_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_metadata_t2_wpfrag_se3_momentum_blackbox
# [train] suite=sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox models=se3_momentum_blackbox seeds=42 protocol=auto
# Training all models with profile-based noisy IC.
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Group: all
# Explicit models: se3_momentum_blackbox
# Seeds: 42
# Noise config: protocol=auto, profile=clean, scale=1.0, warmup=20, ramp=80, mix_ratio=0.5
# Auto-eval profiles: block=[clean nominal_eval heading_biased_eval] heldout=[clean nominal_eval degraded_eval heading_biased_eval]
# Suite directory: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Models (1): se3_momentum_blackbox
# Seeds: 42
# [train] baseline_se3_momentum_blackbox_seed42
# Loading dataset...
# Loaded: 83850 train, 21000 test, t_eval=[0.   0.05 0.1  0.15 0.2 ]
# Dataset split: trajectory | train trajectories: 559 | test trajectories: 140
# Dataset ID: d0be9434
# Dataset path: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl | velocity convention: body_total | state dim: 27
# Position std: [0.1508, 0.1400, 0.0370]
# Velocity std: u=0.4722, v=0.0898, w=0.0718, p=0.0248, q=0.0906, r=0.0526
# Actuator std: a0=0.1543, a1=0.1555, a2=299.0037
# Training noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# Model: SE(3) Momentum Black-Box [baseline/core] | canonical type: se3_momentum_blackbox
# Model parameters: 64,683
# Training dataset: id=d0be9434 | path=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Mass matrix initialized from physics
# Training: epochs<=300, target_steps=5000, warmup_steps=400, lr=6.00e-03 -> 1.00e-04, solver=rk4, so3_reg=1.00e-03
# Train samples: 83850, Test samples: 21000
# Epoch    1 | Step    20/ 5000 | Train 4.6159e-01 | Test 4.3687e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 4.10e-04 | 5.9s
# Epoch    2 | Step    40/ 5000 | Train 4.7678e-01 | Test 4.5966e-01 | SO3(train/test) 1.13e-07/1.12e-07 | Fail(train/test) 0/0 | LR 7.05e-04 | 3.9s
# Epoch    3 | Step    60/ 5000 | Train 4.5008e-01 | Test 4.2621e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 1.00e-03 | 3.9s
# Epoch    4 | Step    80/ 5000 | Train 4.4224e-01 | Test 4.1929e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 1.29e-03 | 3.9s
# Epoch    5 | Step   100/ 5000 | Train 4.3121e-01 | Test 4.0953e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 1.59e-03 | 3.9s
# Epoch    6 | Step   120/ 5000 | Train 4.2605e-01 | Test 3.8299e-01 | SO3(train/test) 1.13e-07/1.14e-07 | Fail(train/test) 0/0 | LR 1.88e-03 | 3.8s
# Epoch    7 | Step   140/ 5000 | Train 4.1757e-01 | Test 4.1411e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 2.18e-03 | 3.8s
# Epoch    8 | Step   160/ 5000 | Train 3.9710e-01 | Test 3.6081e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 2.47e-03 | 4.0s
# Epoch    9 | Step   180/ 5000 | Train 3.7895e-01 | Test 3.6460e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 2.77e-03 | 3.8s
# Epoch   10 | Step   200/ 5000 | Train 3.6962e-01 | Test 3.4525e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 3.06e-03 | 3.8s
# Epoch   11 | Step   220/ 5000 | Train 3.5821e-01 | Test 3.3817e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 3.36e-03 | 3.9s
# Epoch   12 | Step   240/ 5000 | Train 3.5682e-01 | Test 3.7303e-01 | SO3(train/test) 1.13e-07/1.14e-07 | Fail(train/test) 0/0 | LR 3.65e-03 | 3.8s
# Epoch   13 | Step   260/ 5000 | Train 3.5782e-01 | Test 3.4697e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 3.95e-03 | 3.8s
# Epoch   14 | Step   280/ 5000 | Train 3.5896e-01 | Test 3.4538e-01 | SO3(train/test) 1.13e-07/1.14e-07 | Fail(train/test) 0/0 | LR 4.24e-03 | 3.9s
# Epoch   15 | Step   300/ 5000 | Train 3.4578e-01 | Test 3.3032e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 4.54e-03 | 3.9s
# Epoch   16 | Step   320/ 5000 | Train 3.4000e-01 | Test 3.4848e-01 | SO3(train/test) 1.13e-07/1.14e-07 | Fail(train/test) 0/0 | LR 4.83e-03 | 3.8s
# Epoch   17 | Step   340/ 5000 | Train 3.4641e-01 | Test 5.3486e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 5.13e-03 | 3.9s
# Epoch   18 | Step   360/ 5000 | Train 3.8467e-01 | Test 3.0233e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 5.42e-03 | 4.0s
# Epoch   19 | Step   380/ 5000 | Train 4.5469e-01 | Test 3.3223e-01 | SO3(train/test) 1.13e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.72e-03 | 3.8s
# Epoch   20 | Step   400/ 5000 | Train 4.0640e-01 | Test 3.6856e-01 | SO3(train/test) 1.13e-07/1.14e-07 | Fail(train/test) 0/0 | LR 6.00e-03 | 3.8s
# Epoch   21 | Step   420/ 5000 | Train 3.0664e-01 | Test 2.4006e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 6.00e-03 | 4.0s
# Epoch   22 | Step   440/ 5000 | Train 2.4875e-01 | Test 3.3829e-01 | SO3(train/test) 1.14e-07/1.13e-07 | Fail(train/test) 0/0 | LR 6.00e-03 | 3.8s
# Epoch   23 | Step   460/ 5000 | Train 2.2006e-01 | Test 2.1507e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 6.00e-03 | 3.8s
# Epoch   24 | Step   480/ 5000 | Train 2.0045e-01 | Test 1.7029e-01 | SO3(train/test) 1.14e-07/1.13e-07 | Fail(train/test) 0/0 | LR 6.00e-03 | 4.0s
# Epoch   25 | Step   500/ 5000 | Train 1.7692e-01 | Test 1.8559e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.99e-03 | 3.8s
# Epoch   26 | Step   520/ 5000 | Train 1.6996e-01 | Test 2.1048e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.99e-03 | 3.8s
# Epoch   27 | Step   540/ 5000 | Train 1.6426e-01 | Test 1.7678e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.99e-03 | 4.0s
# Epoch   28 | Step   560/ 5000 | Train 1.4934e-01 | Test 1.3154e-01 | SO3(train/test) 1.13e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.98e-03 | 3.9s
# Epoch   29 | Step   580/ 5000 | Train 1.3867e-01 | Test 1.4971e-01 | SO3(train/test) 1.14e-07/1.13e-07 | Fail(train/test) 0/0 | LR 5.98e-03 | 3.9s
# Epoch   30 | Step   600/ 5000 | Train 1.2745e-01 | Test 1.3196e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.97e-03 | 3.9s
# Epoch   31 | Step   620/ 5000 | Train 1.1766e-01 | Test 1.3000e-01 | SO3(train/test) 1.14e-07/1.13e-07 | Fail(train/test) 0/0 | LR 5.97e-03 | 3.9s
# Epoch   32 | Step   640/ 5000 | Train 1.1726e-01 | Test 9.6851e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.96e-03 | 3.8s
# Epoch   33 | Step   660/ 5000 | Train 1.5706e-01 | Test 1.5625e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.95e-03 | 3.8s
# Epoch   34 | Step   680/ 5000 | Train 1.4144e-01 | Test 1.2134e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.95e-03 | 4.0s
# Epoch   35 | Step   700/ 5000 | Train 1.0257e-01 | Test 1.0541e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.94e-03 | 3.8s
# Epoch   36 | Step   720/ 5000 | Train 9.1306e-02 | Test 8.7644e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.93e-03 | 3.8s
# Epoch   37 | Step   740/ 5000 | Train 8.6961e-02 | Test 7.4070e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.92e-03 | 3.9s
# Epoch   38 | Step   760/ 5000 | Train 8.6211e-02 | Test 6.9658e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.91e-03 | 3.8s
# Epoch   39 | Step   780/ 5000 | Train 9.1080e-02 | Test 1.0366e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.90e-03 | 3.9s
# Epoch   40 | Step   800/ 5000 | Train 1.0946e-01 | Test 1.0776e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.89e-03 | 3.9s
# Epoch   41 | Step   820/ 5000 | Train 9.7900e-02 | Test 8.5375e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.88e-03 | 3.8s
# Epoch   42 | Step   840/ 5000 | Train 1.1355e-01 | Test 1.4437e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.87e-03 | 3.8s
# Epoch   43 | Step   860/ 5000 | Train 1.3663e-01 | Test 1.2757e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.86e-03 | 3.9s
# Epoch   44 | Step   880/ 5000 | Train 1.0113e-01 | Test 9.0693e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.84e-03 | 3.9s
# Epoch   45 | Step   900/ 5000 | Train 8.4521e-02 | Test 7.1517e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.83e-03 | 3.9s
# Epoch   46 | Step   920/ 5000 | Train 7.5062e-02 | Test 7.7876e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.82e-03 | 3.9s
# Epoch   47 | Step   940/ 5000 | Train 7.4829e-02 | Test 9.4168e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.80e-03 | 3.9s
# Epoch   48 | Step   960/ 5000 | Train 7.6841e-02 | Test 8.0178e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.79e-03 | 3.8s
# Epoch   49 | Step   980/ 5000 | Train 7.2800e-02 | Test 7.8452e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.77e-03 | 3.8s
# Epoch   50 | Step  1000/ 5000 | Train 7.2146e-02 | Test 8.2633e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.76e-03 | 4.1s
# Epoch   51 | Step  1020/ 5000 | Train 7.2771e-02 | Test 8.8208e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.74e-03 | 3.8s
# Epoch   52 | Step  1040/ 5000 | Train 7.2633e-02 | Test 7.3340e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.72e-03 | 3.9s
# Epoch   53 | Step  1060/ 5000 | Train 6.9904e-02 | Test 7.3285e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.71e-03 | 3.9s
# Epoch   54 | Step  1080/ 5000 | Train 6.9354e-02 | Test 7.3987e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.69e-03 | 3.8s
# Epoch   55 | Step  1100/ 5000 | Train 6.8751e-02 | Test 7.2907e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.67e-03 | 3.8s
# Epoch   56 | Step  1120/ 5000 | Train 6.8103e-02 | Test 7.2376e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.65e-03 | 3.9s
# Epoch   57 | Step  1140/ 5000 | Train 6.7955e-02 | Test 7.7346e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.63e-03 | 3.9s
# Epoch   58 | Step  1160/ 5000 | Train 7.0455e-02 | Test 6.0162e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.61e-03 | 3.8s
# Epoch   59 | Step  1180/ 5000 | Train 6.7229e-02 | Test 6.8702e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.59e-03 | 3.9s
# Epoch   60 | Step  1200/ 5000 | Train 6.5581e-02 | Test 6.6441e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.57e-03 | 4.1s
# Epoch   61 | Step  1220/ 5000 | Train 6.4933e-02 | Test 6.4849e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.55e-03 | 3.9s
# Epoch   62 | Step  1240/ 5000 | Train 6.3910e-02 | Test 6.6548e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.53e-03 | 3.9s
# Epoch   63 | Step  1260/ 5000 | Train 6.3217e-02 | Test 6.6340e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.51e-03 | 4.0s
# Epoch   64 | Step  1280/ 5000 | Train 6.2828e-02 | Test 6.7450e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.48e-03 | 3.8s
# Epoch   65 | Step  1300/ 5000 | Train 6.2496e-02 | Test 6.6247e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.46e-03 | 3.8s
# Epoch   66 | Step  1320/ 5000 | Train 6.1651e-02 | Test 6.6073e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.44e-03 | 4.0s
# Epoch   67 | Step  1340/ 5000 | Train 6.1110e-02 | Test 6.1246e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.41e-03 | 3.8s
# Epoch   68 | Step  1360/ 5000 | Train 5.9863e-02 | Test 5.9238e-02 | SO3(train/test) 1.14e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.39e-03 | 3.8s
# Epoch   69 | Step  1380/ 5000 | Train 5.8864e-02 | Test 5.9469e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.36e-03 | 3.9s
# Epoch   70 | Step  1400/ 5000 | Train 5.8080e-02 | Test 5.8035e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.34e-03 | 3.9s
# Epoch   71 | Step  1420/ 5000 | Train 5.7754e-02 | Test 5.6700e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.31e-03 | 3.9s
# Epoch   72 | Step  1440/ 5000 | Train 5.6965e-02 | Test 5.6234e-02 | SO3(train/test) 1.14e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.29e-03 | 3.9s
# Epoch   73 | Step  1460/ 5000 | Train 5.5916e-02 | Test 5.5048e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.26e-03 | 3.9s
# Epoch   74 | Step  1480/ 5000 | Train 5.5321e-02 | Test 5.2260e-02 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.23e-03 | 3.8s
# Epoch   75 | Step  1500/ 5000 | Train 5.3198e-02 | Test 5.4163e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.21e-03 | 3.9s
# Epoch   76 | Step  1520/ 5000 | Train 5.0068e-02 | Test 4.7725e-02 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.18e-03 | 3.9s
# Epoch   77 | Step  1540/ 5000 | Train 4.5219e-02 | Test 4.4845e-02 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.15e-03 | 3.8s
# Epoch   78 | Step  1560/ 5000 | Train 4.2486e-02 | Test 4.9945e-02 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.12e-03 | 3.8s
# Epoch   79 | Step  1580/ 5000 | Train 4.1690e-02 | Test 5.3376e-02 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.09e-03 | 3.9s
# Epoch   80 | Step  1600/ 5000 | Train 6.6391e-02 | Test 1.0101e-01 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.06e-03 | 3.9s
# Epoch   81 | Step  1620/ 5000 | Train 9.7379e-02 | Test 1.4781e-01 | SO3(train/test) 1.15e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.03e-03 | 3.9s
# Epoch   82 | Step  1640/ 5000 | Train 9.0552e-02 | Test 6.8881e-02 | SO3(train/test) 1.14e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.00e-03 | 3.9s
# Epoch   83 | Step  1660/ 5000 | Train 1.0804e-01 | Test 5.6025e-02 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 4.97e-03 | 3.9s
# Epoch   84 | Step  1680/ 5000 | Train 7.6892e-02 | Test 1.1966e-01 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 4.94e-03 | 3.8s
# Epoch   85 | Step  1700/ 5000 | Train 5.7056e-02 | Test 5.7453e-02 | SO3(train/test) 1.15e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.91e-03 | 3.9s
# Epoch   86 | Step  1720/ 5000 | Train 4.0573e-02 | Test 3.8233e-02 | SO3(train/test) 1.15e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.88e-03 | 3.9s
# Epoch   87 | Step  1740/ 5000 | Train 3.8609e-02 | Test 3.0238e-02 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 4.85e-03 | 3.9s
# Epoch   88 | Step  1760/ 5000 | Train 5.1590e-02 | Test 1.1147e-01 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.82e-03 | 3.9s
# Epoch   89 | Step  1780/ 5000 | Train 4.5783e-02 | Test 3.2649e-02 | SO3(train/test) 1.15e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.78e-03 | 3.9s
# Epoch   90 | Step  1800/ 5000 | Train 4.1928e-02 | Test 1.1146e-01 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.75e-03 | 3.9s
# Epoch   91 | Step  1820/ 5000 | Train 7.1017e-02 | Test 3.8575e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.72e-03 | 3.8s
# Epoch   92 | Step  1840/ 5000 | Train 3.8760e-02 | Test 2.9319e-02 | SO3(train/test) 1.16e-07/1.15e-07 | Fail(train/test) 0/0 | LR 4.68e-03 | 4.0s
# Epoch   93 | Step  1860/ 5000 | Train 3.5212e-02 | Test 4.9180e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.65e-03 | 3.8s
# Epoch   94 | Step  1880/ 5000 | Train 3.4282e-02 | Test 3.5102e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.62e-03 | 3.8s
# Epoch   95 | Step  1900/ 5000 | Train 3.3882e-02 | Test 2.9364e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.58e-03 | 3.9s
# Epoch   96 | Step  1920/ 5000 | Train 3.1948e-02 | Test 4.2551e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.55e-03 | 3.9s
# Epoch   97 | Step  1940/ 5000 | Train 3.2042e-02 | Test 3.3864e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.51e-03 | 3.8s
# Epoch   98 | Step  1960/ 5000 | Train 3.2028e-02 | Test 2.9437e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.48e-03 | 3.9s
# Epoch   99 | Step  1980/ 5000 | Train 3.0425e-02 | Test 3.8622e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.44e-03 | 3.9s
# Epoch  100 | Step  2000/ 5000 | Train 3.0419e-02 | Test 3.4281e-02 | SO3(train/test) 1.16e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.41e-03 | 3.9s
# Epoch  101 | Step  2020/ 5000 | Train 3.0842e-02 | Test 2.9739e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.37e-03 | 3.9s
# Epoch  102 | Step  2040/ 5000 | Train 2.9365e-02 | Test 3.4502e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.33e-03 | 4.0s
# Epoch  103 | Step  2060/ 5000 | Train 2.9250e-02 | Test 3.5941e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.30e-03 | 3.9s
# Epoch  104 | Step  2080/ 5000 | Train 3.0647e-02 | Test 3.0904e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.26e-03 | 3.8s
# Epoch  105 | Step  2100/ 5000 | Train 2.8760e-02 | Test 2.9512e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.22e-03 | 3.9s
# Epoch  106 | Step  2120/ 5000 | Train 2.8877e-02 | Test 3.9631e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.19e-03 | 3.9s
# Epoch  107 | Step  2140/ 5000 | Train 3.2006e-02 | Test 3.6267e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.15e-03 | 3.8s
# Epoch  108 | Step  2160/ 5000 | Train 3.0005e-02 | Test 3.6856e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.11e-03 | 4.0s
# Epoch  109 | Step  2180/ 5000 | Train 2.8642e-02 | Test 2.9792e-02 | SO3(train/test) 1.16e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.08e-03 | 3.9s
# Epoch  110 | Step  2200/ 5000 | Train 2.7093e-02 | Test 2.3957e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.04e-03 | 3.8s
# Epoch  111 | Step  2220/ 5000 | Train 2.5569e-02 | Test 3.3422e-02 | SO3(train/test) 1.16e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.00e-03 | 3.9s
# Epoch  112 | Step  2240/ 5000 | Train 2.5557e-02 | Test 2.6118e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 3.96e-03 | 3.8s
# Epoch  113 | Step  2260/ 5000 | Train 2.5400e-02 | Test 2.2597e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 3.92e-03 | 3.9s
# Epoch  114 | Step  2280/ 5000 | Train 2.4551e-02 | Test 3.1941e-02 | SO3(train/test) 1.16e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.88e-03 | 3.8s
# Epoch  115 | Step  2300/ 5000 | Train 2.4571e-02 | Test 2.7236e-02 | SO3(train/test) 1.16e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.85e-03 | 3.8s
# Epoch  116 | Step  2320/ 5000 | Train 2.5005e-02 | Test 2.4130e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 3.81e-03 | 3.9s
# Epoch  117 | Step  2340/ 5000 | Train 2.4340e-02 | Test 2.5979e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 3.77e-03 | 3.8s
# Epoch  118 | Step  2360/ 5000 | Train 2.3815e-02 | Test 2.8774e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 3.73e-03 | 3.8s
# Epoch  119 | Step  2380/ 5000 | Train 2.4951e-02 | Test 2.5174e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 3.69e-03 | 3.9s
# Epoch  120 | Step  2400/ 5000 | Train 2.3695e-02 | Test 3.0200e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.65e-03 | 3.8s
# Epoch  121 | Step  2420/ 5000 | Train 2.3341e-02 | Test 2.1405e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.61e-03 | 3.9s
# Epoch  122 | Step  2440/ 5000 | Train 2.2777e-02 | Test 1.9167e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.57e-03 | 3.8s
# Epoch  123 | Step  2460/ 5000 | Train 2.1966e-02 | Test 3.0509e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.53e-03 | 3.9s
# Epoch  124 | Step  2480/ 5000 | Train 2.2037e-02 | Test 2.2219e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.49e-03 | 3.8s
# Epoch  125 | Step  2500/ 5000 | Train 2.1912e-02 | Test 1.9811e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 3.45e-03 | 3.8s
# Epoch  126 | Step  2520/ 5000 | Train 2.1133e-02 | Test 2.6485e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 3.41e-03 | 3.8s
# Epoch  127 | Step  2540/ 5000 | Train 2.1163e-02 | Test 2.2634e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.37e-03 | 3.8s
# Epoch  128 | Step  2560/ 5000 | Train 2.1451e-02 | Test 2.1174e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.33e-03 | 3.8s
# Epoch  129 | Step  2580/ 5000 | Train 2.0907e-02 | Test 2.3352e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.29e-03 | 4.0s
# Epoch  130 | Step  2600/ 5000 | Train 2.0725e-02 | Test 1.9794e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 3.25e-03 | 3.9s
# Epoch  131 | Step  2620/ 5000 | Train 2.0138e-02 | Test 1.7893e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.21e-03 | 3.9s
# Epoch  132 | Step  2640/ 5000 | Train 1.9404e-02 | Test 2.3739e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.17e-03 | 3.9s
# Epoch  133 | Step  2660/ 5000 | Train 1.9340e-02 | Test 2.0238e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.13e-03 | 3.8s
# Epoch  134 | Step  2680/ 5000 | Train 1.9392e-02 | Test 1.8476e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.09e-03 | 3.9s
# Epoch  135 | Step  2700/ 5000 | Train 1.8761e-02 | Test 2.3326e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 3.05e-03 | 3.8s
# Epoch  136 | Step  2720/ 5000 | Train 1.9234e-02 | Test 1.8787e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 3.01e-03 | 3.8s
# Epoch  137 | Step  2740/ 5000 | Train 1.9368e-02 | Test 1.8394e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.97e-03 | 3.9s
# Epoch  138 | Step  2760/ 5000 | Train 1.8426e-02 | Test 2.2020e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.93e-03 | 3.8s
# Epoch  139 | Step  2780/ 5000 | Train 1.8294e-02 | Test 2.0153e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 2.89e-03 | 3.8s
# Epoch  140 | Step  2800/ 5000 | Train 2.3442e-02 | Test 3.3060e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 2.85e-03 | 3.9s
# Epoch  141 | Step  2820/ 5000 | Train 1.9219e-02 | Test 2.0149e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.81e-03 | 3.8s
# Epoch  142 | Step  2840/ 5000 | Train 1.5768e-02 | Test 1.5390e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.77e-03 | 3.9s
# Epoch  143 | Step  2860/ 5000 | Train 1.4072e-02 | Test 1.6709e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.73e-03 | 3.8s
# Epoch  144 | Step  2880/ 5000 | Train 1.4423e-02 | Test 1.4425e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.69e-03 | 4.0s
# Epoch  145 | Step  2900/ 5000 | Train 1.3418e-02 | Test 1.4920e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.65e-03 | 3.9s
# Epoch  146 | Step  2920/ 5000 | Train 1.3222e-02 | Test 1.2568e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.61e-03 | 3.9s
# Epoch  147 | Step  2940/ 5000 | Train 1.1676e-02 | Test 1.2107e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.57e-03 | 3.9s
# Epoch  148 | Step  2960/ 5000 | Train 1.1248e-02 | Test 1.1983e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.53e-03 | 3.8s
# Epoch  149 | Step  2980/ 5000 | Train 1.2310e-02 | Test 2.4596e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.49e-03 | 3.9s
# Epoch  150 | Step  3000/ 5000 | Train 1.4637e-02 | Test 1.3754e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 2.45e-03 | 4.0s
# Epoch  151 | Step  3020/ 5000 | Train 1.1705e-02 | Test 1.1255e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 2.41e-03 | 3.8s
# Epoch  152 | Step  3040/ 5000 | Train 1.1080e-02 | Test 1.0665e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.37e-03 | 3.9s
# Epoch  153 | Step  3060/ 5000 | Train 1.2802e-02 | Test 3.9177e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 2.33e-03 | 3.9s
# Epoch  154 | Step  3080/ 5000 | Train 3.1185e-02 | Test 1.3486e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 2.29e-03 | 3.8s
# Epoch  155 | Step  3100/ 5000 | Train 1.6688e-02 | Test 2.2711e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.25e-03 | 4.0s
# Epoch  156 | Step  3120/ 5000 | Train 2.3505e-02 | Test 1.7463e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.21e-03 | 3.9s
# Epoch  157 | Step  3140/ 5000 | Train 1.5309e-02 | Test 1.2756e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.18e-03 | 3.8s
# Epoch  158 | Step  3160/ 5000 | Train 1.0932e-02 | Test 1.0319e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 2.14e-03 | 3.8s
# Epoch  159 | Step  3180/ 5000 | Train 2.0052e-02 | Test 3.2830e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.10e-03 | 3.9s
# Epoch  160 | Step  3200/ 5000 | Train 1.8319e-02 | Test 1.2478e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 2.06e-03 | 3.9s
# Epoch  161 | Step  3220/ 5000 | Train 1.0160e-02 | Test 9.7890e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 2.02e-03 | 3.8s
# Epoch  162 | Step  3240/ 5000 | Train 8.9913e-03 | Test 9.4471e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.99e-03 | 3.9s
# Epoch  163 | Step  3260/ 5000 | Train 8.5112e-03 | Test 8.9297e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.95e-03 | 3.9s
# Epoch  164 | Step  3280/ 5000 | Train 8.3440e-03 | Test 8.8334e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.91e-03 | 3.8s
# Epoch  165 | Step  3300/ 5000 | Train 8.1438e-03 | Test 8.5109e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.87e-03 | 4.0s
# Epoch  166 | Step  3320/ 5000 | Train 7.9637e-03 | Test 8.7881e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.84e-03 | 3.9s
# Epoch  167 | Step  3340/ 5000 | Train 7.8499e-03 | Test 8.2564e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.80e-03 | 3.8s
# Epoch  168 | Step  3360/ 5000 | Train 7.7670e-03 | Test 8.1950e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.76e-03 | 3.8s
# Epoch  169 | Step  3380/ 5000 | Train 7.7439e-03 | Test 8.0860e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.73e-03 | 4.0s
# Epoch  170 | Step  3400/ 5000 | Train 1.3189e-02 | Test 1.9986e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.69e-03 | 3.8s
# Epoch  171 | Step  3420/ 5000 | Train 1.6831e-02 | Test 9.4123e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.66e-03 | 3.9s
# Epoch  172 | Step  3440/ 5000 | Train 8.2943e-03 | Test 8.1434e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.62e-03 | 3.9s
# Epoch  173 | Step  3460/ 5000 | Train 7.4003e-03 | Test 7.6834e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.59e-03 | 3.9s
# Epoch  174 | Step  3480/ 5000 | Train 7.1203e-03 | Test 7.4752e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.55e-03 | 3.8s
# Epoch  175 | Step  3500/ 5000 | Train 6.9885e-03 | Test 7.3918e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.52e-03 | 3.9s
# Epoch  176 | Step  3520/ 5000 | Train 6.8644e-03 | Test 7.2326e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.48e-03 | 4.0s
# Epoch  177 | Step  3540/ 5000 | Train 6.7794e-03 | Test 7.2129e-03 | SO3(train/test) 1.17e-07/1.18e-07 | Fail(train/test) 0/0 | LR 1.45e-03 | 3.8s
# Epoch  178 | Step  3560/ 5000 | Train 6.6871e-03 | Test 7.0544e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.41e-03 | 3.9s
# Epoch  179 | Step  3580/ 5000 | Train 6.6260e-03 | Test 6.9884e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.38e-03 | 3.9s
# Epoch  180 | Step  3600/ 5000 | Train 6.5323e-03 | Test 6.9256e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.35e-03 | 3.8s
# Epoch  181 | Step  3620/ 5000 | Train 6.4759e-03 | Test 6.8545e-03 | SO3(train/test) 1.17e-07/1.18e-07 | Fail(train/test) 0/0 | LR 1.31e-03 | 3.9s
# Epoch  182 | Step  3640/ 5000 | Train 6.4366e-03 | Test 6.7386e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.28e-03 | 3.9s
# Epoch  183 | Step  3660/ 5000 | Train 6.3761e-03 | Test 6.7011e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.25e-03 | 3.9s
# Epoch  184 | Step  3680/ 5000 | Train 6.2800e-03 | Test 6.6093e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.22e-03 | 3.9s
# Epoch  185 | Step  3700/ 5000 | Train 6.2204e-03 | Test 6.6109e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.19e-03 | 3.9s
# Epoch  186 | Step  3720/ 5000 | Train 6.1642e-03 | Test 6.5226e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.16e-03 | 3.9s
# Epoch  187 | Step  3740/ 5000 | Train 6.1354e-03 | Test 6.5341e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.13e-03 | 3.8s
# Epoch  188 | Step  3760/ 5000 | Train 6.0843e-03 | Test 6.4358e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.10e-03 | 3.9s
# Epoch  189 | Step  3780/ 5000 | Train 6.0256e-03 | Test 6.3984e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.07e-03 | 3.9s
# Epoch  190 | Step  3800/ 5000 | Train 5.9798e-03 | Test 6.4252e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.04e-03 | 3.8s
# Epoch  191 | Step  3820/ 5000 | Train 5.9615e-03 | Test 6.3876e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.01e-03 | 3.9s
# Epoch  192 | Step  3840/ 5000 | Train 5.9380e-03 | Test 6.2987e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 9.77e-04 | 4.0s
# Epoch  193 | Step  3860/ 5000 | Train 5.9077e-03 | Test 6.2460e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 9.49e-04 | 3.8s
# Epoch  194 | Step  3880/ 5000 | Train 5.8389e-03 | Test 6.2029e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 9.21e-04 | 3.8s
# Epoch  195 | Step  3900/ 5000 | Train 5.8447e-03 | Test 6.2603e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 8.93e-04 | 3.9s
# Epoch  196 | Step  3920/ 5000 | Train 5.7921e-03 | Test 6.1474e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 8.66e-04 | 3.8s
# Epoch  197 | Step  3940/ 5000 | Train 5.7767e-03 | Test 6.1250e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 8.39e-04 | 4.0s
# Epoch  198 | Step  3960/ 5000 | Train 5.7273e-03 | Test 6.1099e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 8.12e-04 | 3.9s
# Epoch  199 | Step  3980/ 5000 | Train 5.7095e-03 | Test 6.0876e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 7.86e-04 | 3.8s
# Epoch  200 | Step  4000/ 5000 | Train 5.6924e-03 | Test 6.0645e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 7.61e-04 | 3.8s
# Epoch  201 | Step  4020/ 5000 | Train 5.6527e-03 | Test 6.0245e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 7.35e-04 | 3.9s
# Epoch  202 | Step  4040/ 5000 | Train 5.6332e-03 | Test 6.0030e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 7.11e-04 | 3.8s
# Epoch  203 | Step  4060/ 5000 | Train 5.6064e-03 | Test 6.0054e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 6.86e-04 | 3.8s
# Epoch  204 | Step  4080/ 5000 | Train 5.5965e-03 | Test 5.9764e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 6.62e-04 | 3.9s
# Epoch  205 | Step  4100/ 5000 | Train 5.5822e-03 | Test 5.9729e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 6.39e-04 | 3.9s
# Epoch  206 | Step  4120/ 5000 | Train 5.5723e-03 | Test 5.9286e-03 | SO3(train/test) 1.17e-07/1.18e-07 | Fail(train/test) 0/0 | LR 6.16e-04 | 3.8s
# Epoch  207 | Step  4140/ 5000 | Train 5.5466e-03 | Test 5.8956e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 5.93e-04 | 3.9s
# Epoch  208 | Step  4160/ 5000 | Train 5.5275e-03 | Test 5.8889e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 5.71e-04 | 3.9s
# Epoch  209 | Step  4180/ 5000 | Train 5.5230e-03 | Test 5.8966e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 5.50e-04 | 3.8s
# Epoch  210 | Step  4200/ 5000 | Train 5.5034e-03 | Test 5.8867e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 5.29e-04 | 3.8s
# Epoch  211 | Step  4220/ 5000 | Train 5.4734e-03 | Test 5.8261e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 5.08e-04 | 3.9s
# Epoch  212 | Step  4240/ 5000 | Train 5.4673e-03 | Test 5.8051e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.88e-04 | 3.8s
# Epoch  213 | Step  4260/ 5000 | Train 5.4512e-03 | Test 5.8013e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.68e-04 | 3.9s
# Epoch  214 | Step  4280/ 5000 | Train 5.4349e-03 | Test 5.8061e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.49e-04 | 4.0s
# Epoch  215 | Step  4300/ 5000 | Train 5.4238e-03 | Test 5.8232e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.30e-04 | 3.8s
# Epoch  216 | Step  4320/ 5000 | Train 5.4157e-03 | Test 5.7825e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.12e-04 | 3.8s
# Epoch  217 | Step  4340/ 5000 | Train 5.4042e-03 | Test 5.7617e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.94e-04 | 3.9s
# Epoch  218 | Step  4360/ 5000 | Train 5.4096e-03 | Test 5.7551e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.77e-04 | 4.0s
# Epoch  219 | Step  4380/ 5000 | Train 5.3943e-03 | Test 5.7433e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.60e-04 | 3.8s
# Epoch  220 | Step  4400/ 5000 | Train 5.3905e-03 | Test 5.7290e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.44e-04 | 3.8s
# Epoch  221 | Step  4420/ 5000 | Train 5.3720e-03 | Test 5.7137e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.28e-04 | 3.9s
# Epoch  222 | Step  4440/ 5000 | Train 5.3614e-03 | Test 5.6992e-03 | SO3(train/test) 1.18e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.12e-04 | 3.8s
# Epoch  223 | Step  4460/ 5000 | Train 5.3521e-03 | Test 5.7171e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.98e-04 | 3.8s
# Epoch  224 | Step  4480/ 5000 | Train 5.3379e-03 | Test 5.6866e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.83e-04 | 4.0s
# Epoch  225 | Step  4500/ 5000 | Train 5.3412e-03 | Test 5.7097e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.70e-04 | 3.9s
# Epoch  226 | Step  4520/ 5000 | Train 5.3328e-03 | Test 5.6734e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.57e-04 | 3.8s
# Epoch  227 | Step  4540/ 5000 | Train 5.3284e-03 | Test 5.6790e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.44e-04 | 3.9s
# Epoch  228 | Step  4560/ 5000 | Train 5.3110e-03 | Test 5.6810e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.32e-04 | 3.9s
# Epoch  229 | Step  4580/ 5000 | Train 5.3103e-03 | Test 5.6691e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.20e-04 | 3.8s
# Epoch  230 | Step  4600/ 5000 | Train 5.2962e-03 | Test 5.6646e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.09e-04 | 3.9s
# Epoch  231 | Step  4620/ 5000 | Train 5.2962e-03 | Test 5.6453e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.98e-04 | 3.9s
# Epoch  232 | Step  4640/ 5000 | Train 5.2965e-03 | Test 5.6393e-03 | SO3(train/test) 1.17e-07/1.18e-07 | Fail(train/test) 0/0 | LR 1.88e-04 | 3.8s
# Epoch  233 | Step  4660/ 5000 | Train 5.2858e-03 | Test 5.6503e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.79e-04 | 3.9s
# Epoch  234 | Step  4680/ 5000 | Train 5.2813e-03 | Test 5.6351e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.70e-04 | 4.0s
# Epoch  235 | Step  4700/ 5000 | Train 5.2817e-03 | Test 5.6249e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.61e-04 | 3.9s
# Epoch  236 | Step  4720/ 5000 | Train 5.2672e-03 | Test 5.6190e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.53e-04 | 3.9s
# Epoch  237 | Step  4740/ 5000 | Train 5.2716e-03 | Test 5.6168e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.46e-04 | 4.0s
# Epoch  238 | Step  4760/ 5000 | Train 5.2627e-03 | Test 5.6072e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.39e-04 | 3.8s
# Epoch  239 | Step  4780/ 5000 | Train 5.2585e-03 | Test 5.6249e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.33e-04 | 4.0s
# Epoch  240 | Step  4800/ 5000 | Train 5.2587e-03 | Test 5.6008e-03 | SO3(train/test) 1.17e-07/1.18e-07 | Fail(train/test) 0/0 | LR 1.27e-04 | 3.9s
# Epoch  241 | Step  4820/ 5000 | Train 5.2572e-03 | Test 5.6054e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.22e-04 | 3.9s
# Epoch  242 | Step  4840/ 5000 | Train 5.2502e-03 | Test 5.5990e-03 | SO3(train/test) 1.18e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.17e-04 | 3.8s
# Epoch  243 | Step  4860/ 5000 | Train 5.2407e-03 | Test 5.6005e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.13e-04 | 3.9s
# Epoch  244 | Step  4880/ 5000 | Train 5.2473e-03 | Test 5.5953e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.10e-04 | 3.9s
# Epoch  245 | Step  4900/ 5000 | Train 5.2387e-03 | Test 5.5908e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.07e-04 | 3.9s
# Epoch  246 | Step  4920/ 5000 | Train 5.2371e-03 | Test 5.5908e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.04e-04 | 3.9s
# Epoch  247 | Step  4940/ 5000 | Train 5.2314e-03 | Test 5.5855e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.02e-04 | 3.9s
# Epoch  248 | Step  4960/ 5000 | Train 5.2362e-03 | Test 5.5854e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.01e-04 | 3.8s
# Epoch  249 | Step  4980/ 5000 | Train 5.2318e-03 | Test 5.5803e-03 | SO3(train/test) 1.17e-07/1.18e-07 | Fail(train/test) 0/0 | LR 1.00e-04 | 3.9s
# Epoch  250 | Step  5000/ 5000 | Train 5.2293e-03 | Test 5.5841e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.00e-04 | 3.8s
# Reached target optimizer steps: 5000/5000
# Done. Best validation score: failure_rate=0.0000, test_loss=5.5803e-03 (epoch 249)
# Running detailed evaluation...
# Block evaluation profile: clean
# Block evaluation noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0002 +/- 0.0001  (max 0.0010)
# Rotation geo [rad]:  0.0005 +/- 0.0000  (max 0.0006)
# Lin vel RMSE [m/s]:  0.0025 +/- 0.0017
# Ang vel RMSE [r/s]:  0.0011 +/- 0.0006
# Components:  u=0.0037  v=0.0009  w=0.0012  p=0.0007  q=0.0012  r=0.0010
# SO(3) violation:  |det-1|=6.31e-08  ||RR^T-I||=1.31e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# Block evaluation profile: nominal_eval
# Block evaluation noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0013 +/- 0.0008  (max 0.0056)
# Rotation geo [rad]:  0.0082 +/- 0.0058  (max 0.0367)
# Lin vel RMSE [m/s]:  0.0051 +/- 0.0023
# Ang vel RMSE [r/s]:  0.0034 +/- 0.0020
# Components:  u=0.0065  v=0.0032  w=0.0034  p=0.0051  q=0.0015  r=0.0015
# SO(3) violation:  |det-1|=2.75e-07  ||RR^T-I||=6.11e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# Block evaluation profile: heading_biased_eval
# Block evaluation noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0049 +/- 0.0017  (max 0.0109)
# Rotation geo [rad]:  0.0351 +/- 0.0096  (max 0.0656)
# Lin vel RMSE [m/s]:  0.0084 +/- 0.0038
# Ang vel RMSE [r/s]:  0.0034 +/- 0.0020
# Components:  u=0.0086  v=0.0090  w=0.0037  p=0.0051  q=0.0015  r=0.0015
# SO(3) violation:  |det-1|=2.97e-07  ||RR^T-I||=6.35e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Block Evaluation Relative To Clean
# ==================================================
# [nominal_eval]
# position_rmse: ratio=5.991  degradation=+499.1%
# rotation_geodesic: ratio=16.625  degradation=+1562.5%
# velocity_rmse: ratio=2.059  degradation=+105.9%
# angular_rmse: ratio=3.023  degradation=+202.3%
# failure_rate: ratio=1.000  degradation=+0.0%
# [heading_biased_eval]
# position_rmse: ratio=22.570  degradation=+2157.0%
# rotation_geodesic: ratio=71.293  degradation=+7029.3%
# velocity_rmse: ratio=3.373  degradation=+237.3%
# angular_rmse: ratio=3.020  degradation=+202.0%
# failure_rate: ratio=1.000  degradation=+0.0%
# Running held-out trajectory evaluation...
# Held-out evaluation profile: clean
# Held-out evaluation noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0002 (median 0.0002, p95 0.0003)
# Rotation geo [rad]:  0.0005 (median 0.0005, p95 0.0005)
# Lin vel RMSE [m/s]:  0.0021  Ang vel RMSE [r/s]:  0.0009
# SO(3) violation:  |det-1|=6.03e-08  ||RR^T-I||=1.18e-07
# Noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# [CHIRP] pos=0.0001 m, rot=0.0005 rad, success=1.0000
# [OU] pos=0.0002 m, rot=0.0005 rad, success=1.0000
# [PRBS] pos=0.0002 m, rot=0.0005 rad, success=1.0000
# Held-out evaluation profile: nominal_eval
# Held-out evaluation noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0011 (median 0.0011, p95 0.0014)
# Rotation geo [rad]:  0.0086 (median 0.0085, p95 0.0095)
# Lin vel RMSE [m/s]:  0.0047  Ang vel RMSE [r/s]:  0.0033
# SO(3) violation:  |det-1|=2.95e-07  ||RR^T-I||=6.28e-07
# Noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# [CHIRP] pos=0.0011 m, rot=0.0085 rad, success=1.0000
# [OU] pos=0.0011 m, rot=0.0086 rad, success=1.0000
# [PRBS] pos=0.0012 m, rot=0.0085 rad, success=1.0000
# Held-out evaluation profile: degraded_eval
# Held-out evaluation noise budget: protocol=iid_noisy_ic | profile=degraded_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0026 (median 0.0025, p95 0.0033)
# Rotation geo [rad]:  0.0209 (median 0.0208, p95 0.0233)
# Lin vel RMSE [m/s]:  0.0088  Ang vel RMSE [r/s]:  0.0062
# SO(3) violation:  |det-1|=2.95e-07  ||RR^T-I||=6.28e-07
# Noise budget: protocol=iid_noisy_ic | profile=degraded_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250]
# [CHIRP] pos=0.0025 m, rot=0.0209 rad, success=1.0000
# [OU] pos=0.0025 m, rot=0.0211 rad, success=1.0000
# [PRBS] pos=0.0027 m, rot=0.0208 rad, success=1.0000
# Held-out evaluation profile: heading_biased_eval
# Held-out evaluation noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0040 (median 0.0040, p95 0.0052)
# Rotation geo [rad]:  0.0350 (median 0.0350, p95 0.0362)
# Lin vel RMSE [m/s]:  0.0072  Ang vel RMSE [r/s]:  0.0033
# SO(3) violation:  |det-1|=2.91e-07  ||RR^T-I||=6.22e-07
# Noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# [CHIRP] pos=0.0039 m, rot=0.0353 rad, success=1.0000
# [OU] pos=0.0039 m, rot=0.0349 rad, success=1.0000
# [PRBS] pos=0.0041 m, rot=0.0351 rad, success=1.0000
# ==================================================
# Held-Out Evaluation Relative To Clean
# ==================================================
# [nominal_eval]
# position_rmse: ratio=6.073  degradation=+507.3%
# rotation_geodesic: ratio=17.448  degradation=+1644.8%
# velocity_rmse: ratio=2.247  degradation=+124.7%
# angular_rmse: ratio=3.456  degradation=+245.6%
# success_rate: ratio=1.000  degradation=+0.0%
# trajectory_failure_rate: ratio=1.000  degradation=+0.0%
# [degraded_eval]
# position_rmse: ratio=14.098  degradation=+1309.8%
# rotation_geodesic: ratio=42.666  degradation=+4166.6%
# velocity_rmse: ratio=4.162  degradation=+316.2%
# angular_rmse: ratio=6.547  degradation=+554.7%
# success_rate: ratio=1.000  degradation=+0.0%
# trajectory_failure_rate: ratio=1.000  degradation=+0.0%
# [heading_biased_eval]
# position_rmse: ratio=21.669  degradation=+2066.9%
# rotation_geodesic: ratio=71.423  degradation=+7042.3%
# velocity_rmse: ratio=3.405  degradation=+240.5%
# angular_rmse: ratio=3.456  degradation=+245.6%
# success_rate: ratio=1.000  degradation=+0.0%
# trajectory_failure_rate: ratio=1.000  degradation=+0.0%
#
# Training finished. Results: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42
# Training sweep complete.
# Manifest: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox/runs.tsv
# Next step:
#   scripts/batch_eval_models.sh --suite-dir "/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox"
#
# Training complete.
# Suite directory: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox
# Next step:
#   bash scripts/eval_all_models_noise_profile.sh --suite-dir "/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox"
# [audit] /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox
#                                                    suite_name    group            model_type  seed train_noise_protocol  best_epoch  best_loss  noise_warmup_epochs  noise_ramp_epochs  noise_mix_ratio  epoch_scale_at_best  is_effectively_clean_at_best
# sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox baseline se3_momentum_blackbox    42                clean         249    0.00558                   20                 80              0.5                  0.0                          True
# [validate_v4] skipped: v4lite not in PHASE1A_PROTOCOLS=clean

# %%
os.environ["MODE"] = "smoke1_eval"
# !bash scripts/run_phase1a_oc_v4lite.sh
# Out:
# [phase1a]
# MODE=smoke1_eval
# RUN_TAG=t2_wpfrag_se3_momentum_blackbox
# DATASET=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# DEVICE=cuda
# PHASE1A_MODELS=se3_momentum_blackbox
# PHASE1A_PROTOCOLS=clean
# SMOKE1_MODELS=se3_momentum_blackbox
# SMOKE_SEEDS=42
# DECISION_SEEDS=42 43 44 45 46
# NOISE_REFERENCE=remus100_dr
# PHASE1A_LOG_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_logs/t2_wpfrag_se3_momentum_blackbox
# PHASE1A_METADATA_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_metadata_t2_wpfrag_se3_momentum_blackbox
# [eval] suite=sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox eval_protocol=iid_noisy_ic profiles=clean nominal_eval degraded_eval heading_biased_eval
# Suite directory: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox
# Manifest: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox/runs.tsv
# Mode: resampled
# [eval] baseline_se3_momentum_blackbox_seed42
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=clean | noise_protocol=clean | noise_budget=protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000] | scenarios=PRBS,CHIRP,OU | trajectories=18 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_120257/clean
# [scenario 1/3] PRBS | 6 trajectories
# [1/18] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=13m36.8s
# [5/18] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=2m05.0s
# [6/18] PRBS seed=47 done | reason=completed | sim_time=60.00s | eta=1m36.1s
# [scenario done] PRBS | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=2.1252 m | pos_p95=3.9492 m | rot_med=0.0411 rad | completion=1.000 | elapsed=48.1s
# [scenario 2/3] CHIRP | 6 trajectories
# [7/18] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=2m30.8s
# [11/18] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=1m01.1s
# [12/18] CHIRP seed=100047 done | reason=completed | sim_time=60.00s | eta=48.0s
# [scenario done] CHIRP | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=1.1442 m | pos_p95=2.8479 m | rot_med=0.0256 rad | completion=1.000 | elapsed=1m36.0s
# [scenario 3/3] OU | 6 trajectories
# [13/18] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=55.6s
# [17/18] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=8.5s
# [18/18] OU seed=200047 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=0.8774 m | pos_p95=2.1121 m | rot_med=0.0304 rad | completion=1.000 | elapsed=2m24.6s
# Benchmark finished in 2m37.9s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_120257/clean
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: SE(3) Momentum Black-Box [baseline/core]
# Canonical model type: se3_momentum_blackbox
# Energy semantics: not_comparable
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 6
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.1345 m | pos p95=0.3103 m | rot median=0.0155 rad | total vel median=0.0152 m/s | rel vel median=0.0127 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=0.5590 m | pos p95=1.1901 m | rot median=0.0182 rad | total vel median=0.0143 m/s | rel vel median=0.0157 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=1.1442 m | pos p95=3.6555 m | rot median=0.0329 rad | total vel median=0.0298 m/s | rel vel median=0.0265 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=18 | completed=18 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1205 m | pos p95=0.3075 m | rot median=0.0175 rad | total vel median=0.0224 m/s | rel vel median=0.0186 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.8271 m | pos p95=1.1119 m | rot median=0.0286 rad | total vel median=0.0339 m/s | rel vel median=0.0353 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=2.1252 m | pos p95=3.9492 m | rot median=0.0411 rad | total vel median=0.0392 m/s | rel vel median=0.0405 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.0907 m | pos p95=0.2538 m | rot median=0.0071 rad | total vel median=0.0090 m/s | rel vel median=0.0076 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.3910 m | pos p95=1.1511 m | rot median=0.0182 rad | total vel median=0.0058 m/s | rel vel median=0.0055 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.1442 m | pos p95=2.8479 m | rot median=0.0256 rad | total vel median=0.0084 m/s | rel vel median=0.0102 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.2146 m | pos p95=0.2935 m | rot median=0.0216 rad | total vel median=0.0193 m/s | rel vel median=0.0166 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.5590 m | pos p95=1.0778 m | rot median=0.0129 rad | total vel median=0.0255 m/s | rel vel median=0.0249 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=0.8774 m | pos p95=2.1121 m | rot median=0.0304 rad | total vel median=0.0383 m/s | rel vel median=0.0341 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Largest completed terminal errors
#   PRBS seed=46 | reason=completed | sim_time=60.00s | pos=4.0716 m | rot=0.0751 rad | total_vel_violation=0
#   PRBS seed=43 | reason=completed | sim_time=60.00s | pos=3.5821 m | rot=0.0732 rad | total_vel_violation=0
#   CHIRP seed=100043 | reason=completed | sim_time=60.00s | pos=3.0939 m | rot=0.0542 rad | total_vel_violation=0
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=2.2845 m | rot=0.0407 rad | total_vel_violation=0
#   OU seed=200044 | reason=completed | sim_time=60.00s | pos=2.2081 m | rot=0.0371 rad | total_vel_violation=0
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# PRBS seed=46 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_120257/clean/diagnostic_plots/high_terminal_error_PRBS_seed46.png
# PRBS seed=43 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_120257/clean/diagnostic_plots/high_terminal_error_PRBS_seed43.png
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=nominal_eval | noise_protocol=iid_noisy_ic | noise_budget=protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | scenarios=PRBS,CHIRP,OU | trajectories=18 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_120257/nominal_eval
# [scenario 1/3] PRBS | 6 trajectories
# [1/18] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=2m25.6s
# [5/18] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=22.3s
# [6/18] PRBS seed=47 done | reason=completed | sim_time=60.00s | eta=17.2s
# [scenario done] PRBS | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=3.7692 m | pos_p95=5.3100 m | rot_med=0.0584 rad | completion=1.000 | elapsed=8.6s
# [scenario 2/3] CHIRP | 6 trajectories
# [7/18] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=26.7s
# [11/18] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=10.8s
# [12/18] CHIRP seed=100047 done | reason=completed | sim_time=60.00s | eta=8.5s
# [scenario done] CHIRP | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=0.9766 m | pos_p95=2.4719 m | rot_med=0.0258 rad | completion=1.000 | elapsed=17.1s
# [scenario 3/3] OU | 6 trajectories
# [13/18] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=9.7s
# [17/18] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=1.5s
# [18/18] OU seed=200047 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=1.1647 m | pos_p95=2.4413 m | rot_med=0.0343 rad | completion=1.000 | elapsed=25.3s
# Benchmark finished in 37.8s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_120257/nominal_eval
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: SE(3) Momentum Black-Box [baseline/core]
# Canonical model type: se3_momentum_blackbox
# Energy semantics: not_comparable
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 6
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.2205 m | pos p95=0.4098 m | rot median=0.0226 rad | total vel median=0.0158 m/s | rel vel median=0.0127 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=0.6904 m | pos p95=1.7476 m | rot median=0.0182 rad | total vel median=0.0131 m/s | rel vel median=0.0157 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=1.1647 m | pos p95=4.9441 m | rot median=0.0343 rad | total vel median=0.0287 m/s | rel vel median=0.0265 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=18 | completed=18 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.3196 m | pos p95=0.4627 m | rot median=0.0259 rad | total vel median=0.0260 m/s | rel vel median=0.0185 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.5395 m | pos p95=2.0073 m | rot median=0.0438 rad | total vel median=0.0310 m/s | rel vel median=0.0353 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=3.7692 m | pos p95=5.3100 m | rot median=0.0584 rad | total vel median=0.0410 m/s | rel vel median=0.0404 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.0751 m | pos p95=0.1975 m | rot median=0.0066 rad | total vel median=0.0085 m/s | rel vel median=0.0076 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.2536 m | pos p95=0.9539 m | rot median=0.0161 rad | total vel median=0.0057 m/s | rel vel median=0.0055 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=0.9766 m | pos p95=2.4719 m | rot median=0.0258 rad | total vel median=0.0086 m/s | rel vel median=0.0102 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.2340 m | pos p95=0.3721 m | rot median=0.0278 rad | total vel median=0.0201 m/s | rel vel median=0.0166 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.6904 m | pos p95=1.2507 m | rot median=0.0154 rad | total vel median=0.0255 m/s | rel vel median=0.0249 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.1647 m | pos p95=2.4413 m | rot median=0.0343 rad | total vel median=0.0386 m/s | rel vel median=0.0341 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Largest completed terminal errors
#   PRBS seed=46 | reason=completed | sim_time=60.00s | pos=5.4625 m | rot=0.0879 rad | total_vel_violation=0
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=4.8527 m | rot=0.0600 rad | total_vel_violation=0
#   PRBS seed=43 | reason=completed | sim_time=60.00s | pos=4.4029 m | rot=0.0818 rad | total_vel_violation=0
#   PRBS seed=45 | reason=completed | sim_time=60.00s | pos=3.1355 m | rot=0.0567 rad | total_vel_violation=0
#   CHIRP seed=100043 | reason=completed | sim_time=60.00s | pos=2.5983 m | rot=0.0487 rad | total_vel_violation=0
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# PRBS seed=46 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_120257/nominal_eval/diagnostic_plots/high_terminal_error_PRBS_seed46.png
# PRBS seed=42 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_120257/nominal_eval/diagnostic_plots/high_terminal_error_PRBS_seed42.png
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=degraded_eval | noise_protocol=iid_noisy_ic | noise_budget=protocol=iid_noisy_ic | profile=degraded_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250] | scenarios=PRBS,CHIRP,OU | trajectories=18 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_120257/degraded_eval
# [scenario 1/3] PRBS | 6 trajectories
# [1/18] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=2m23.9s
# [5/18] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=22.0s
# [6/18] PRBS seed=47 done | reason=completed | sim_time=60.00s | eta=17.0s
# [scenario done] PRBS | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=5.2070 m | pos_p95=8.4523 m | rot_med=0.0843 rad | completion=1.000 | elapsed=8.5s
# [scenario 2/3] CHIRP | 6 trajectories
# [7/18] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=26.6s
# [11/18] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=10.8s
# [12/18] CHIRP seed=100047 done | reason=completed | sim_time=60.00s | eta=8.5s
# [scenario done] CHIRP | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=1.4009 m | pos_p95=2.0189 m | rot_med=0.0279 rad | completion=1.000 | elapsed=17.0s
# [scenario 3/3] OU | 6 trajectories
# [13/18] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=9.7s
# [17/18] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=1.5s
# [18/18] OU seed=200047 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=1.6624 m | pos_p95=2.9522 m | rot_med=0.0433 rad | completion=1.000 | elapsed=25.4s
# Benchmark finished in 37.9s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_120257/degraded_eval
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: SE(3) Momentum Black-Box [baseline/core]
# Canonical model type: se3_momentum_blackbox
# Energy semantics: not_comparable
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 6
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.2804 m | pos p95=0.7108 m | rot median=0.0256 rad | total vel median=0.0171 m/s | rel vel median=0.0126 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=0.7545 m | pos p95=2.9418 m | rot median=0.0215 rad | total vel median=0.0148 m/s | rel vel median=0.0157 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=1.7179 m | pos p95=7.6914 m | rot median=0.0381 rad | total vel median=0.0280 m/s | rel vel median=0.0264 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=18 | completed=18 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.5383 m | pos p95=1.0335 m | rot median=0.0399 rad | total vel median=0.0312 m/s | rel vel median=0.0185 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=2.3945 m | pos p95=3.7825 m | rot median=0.0614 rad | total vel median=0.0272 m/s | rel vel median=0.0353 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=5.2070 m | pos p95=8.4523 m | rot median=0.0843 rad | total vel median=0.0443 m/s | rel vel median=0.0404 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1161 m | pos p95=0.2236 m | rot median=0.0121 rad | total vel median=0.0081 m/s | rel vel median=0.0076 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.4074 m | pos p95=0.7419 m | rot median=0.0186 rad | total vel median=0.0054 m/s | rel vel median=0.0055 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.4009 m | pos p95=2.0189 m | rot median=0.0279 rad | total vel median=0.0090 m/s | rel vel median=0.0102 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.3031 m | pos p95=0.5129 m | rot median=0.0360 rad | total vel median=0.0217 m/s | rel vel median=0.0165 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.0674 m | pos p95=1.5562 m | rot median=0.0215 rad | total vel median=0.0242 m/s | rel vel median=0.0249 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.6624 m | pos p95=2.9522 m | rot median=0.0433 rad | total vel median=0.0383 m/s | rel vel median=0.0341 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Largest completed terminal errors
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=8.7693 m | rot=0.0894 rad | total_vel_violation=0
#   PRBS seed=46 | reason=completed | sim_time=60.00s | pos=7.5012 m | rot=0.1066 rad | total_vel_violation=0
#   PRBS seed=43 | reason=completed | sim_time=60.00s | pos=5.5752 m | rot=0.0940 rad | total_vel_violation=0
#   PRBS seed=45 | reason=completed | sim_time=60.00s | pos=4.8389 m | rot=0.0792 rad | total_vel_violation=0
#   OU seed=200044 | reason=completed | sim_time=60.00s | pos=3.0277 m | rot=0.0521 rad | total_vel_violation=0
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# PRBS seed=42 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_120257/degraded_eval/diagnostic_plots/high_terminal_error_PRBS_seed42.png
# PRBS seed=46 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_120257/degraded_eval/diagnostic_plots/high_terminal_error_PRBS_seed46.png
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=heading_biased_eval | noise_protocol=iid_noisy_ic | noise_budget=protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350] | scenarios=PRBS,CHIRP,OU | trajectories=18 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_120257/heading_biased_eval
# [scenario 1/3] PRBS | 6 trajectories
# [1/18] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=2m24.0s
# [5/18] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=22.1s
# [6/18] PRBS seed=47 done | reason=completed | sim_time=60.00s | eta=17.0s
# [scenario done] PRBS | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=3.0475 m | pos_p95=7.2160 m | rot_med=0.0452 rad | completion=1.000 | elapsed=8.5s
# [scenario 2/3] CHIRP | 6 trajectories
# [7/18] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=26.6s
# [11/18] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=10.8s
# [12/18] CHIRP seed=100047 done | reason=completed | sim_time=60.00s | eta=8.5s
# [scenario done] CHIRP | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=2.4573 m | pos_p95=4.8490 m | rot_med=0.0196 rad | completion=1.000 | elapsed=17.0s
# [scenario 3/3] OU | 6 trajectories
# [13/18] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=9.7s
# [17/18] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=1.5s
# [18/18] OU seed=200047 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=3.2354 m | pos_p95=4.5072 m | rot_med=0.0632 rad | completion=1.000 | elapsed=25.4s
# Benchmark finished in 37.8s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_120257/heading_biased_eval
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: SE(3) Momentum Black-Box [baseline/core]
# Canonical model type: se3_momentum_blackbox
# Energy semantics: not_comparable
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 6
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.5595 m | pos p95=0.8827 m | rot median=0.0438 rad | total vel median=0.0183 m/s | rel vel median=0.0130 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=1.6168 m | pos p95=3.3967 m | rot median=0.0417 rad | total vel median=0.0195 m/s | rel vel median=0.0156 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=2.7043 m | pos p95=6.0220 m | rot median=0.0467 rad | total vel median=0.0302 m/s | rel vel median=0.0263 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=18 | completed=18 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.4970 m | pos p95=0.8222 m | rot median=0.0516 rad | total vel median=0.0298 m/s | rel vel median=0.0192 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.5997 m | pos p95=3.6255 m | rot median=0.0346 rad | total vel median=0.0245 m/s | rel vel median=0.0352 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=3.0475 m | pos p95=7.2160 m | rot median=0.0452 rad | total vel median=0.0465 m/s | rel vel median=0.0407 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.5368 m | pos p95=0.5826 m | rot median=0.0352 rad | total vel median=0.0097 m/s | rel vel median=0.0077 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.5589 m | pos p95=2.1557 m | rot median=0.0321 rad | total vel median=0.0069 m/s | rel vel median=0.0055 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=2.4573 m | pos p95=4.8490 m | rot median=0.0196 rad | total vel median=0.0119 m/s | rel vel median=0.0104 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.6589 m | pos p95=0.8738 m | rot median=0.0498 rad | total vel median=0.0247 m/s | rel vel median=0.0163 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.8461 m | pos p95=2.5357 m | rot median=0.0483 rad | total vel median=0.0246 m/s | rel vel median=0.0249 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=3.2354 m | pos p95=4.5072 m | rot median=0.0632 rad | total vel median=0.0403 m/s | rel vel median=0.0338 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Largest completed terminal errors
#   PRBS seed=43 | reason=completed | sim_time=60.00s | pos=7.7135 m | rot=0.1165 rad | total_vel_violation=0
#   PRBS seed=45 | reason=completed | sim_time=60.00s | pos=5.7235 m | rot=0.0908 rad | total_vel_violation=0
#   CHIRP seed=100046 | reason=completed | sim_time=60.00s | pos=5.1311 m | rot=0.0762 rad | total_vel_violation=0
#   OU seed=200043 | reason=completed | sim_time=60.00s | pos=4.5220 m | rot=0.0965 rad | total_vel_violation=0
#   OU seed=200044 | reason=completed | sim_time=60.00s | pos=4.4629 m | rot=0.0780 rad | total_vel_violation=0
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# PRBS seed=43 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_120257/heading_biased_eval/diagnostic_plots/high_terminal_error_PRBS_seed43.png
# PRBS seed=45 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260525_120257/heading_biased_eval/diagnostic_plots/high_terminal_error_PRBS_seed45.png
# Batch evaluation complete.
# [eval] suite=sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox eval_protocol=v4_lite profiles=nominal_eval
# Suite directory: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox
# Manifest: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox/runs.tsv
# Mode: resampled
# [eval] baseline_se3_momentum_blackbox_seed42
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=nominal_eval | noise_protocol=v4_lite | noise_budget=protocol=v4_lite | profile=nominal_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | scenarios=PRBS,CHIRP,OU | trajectories=18 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_v4eval_traj6_seed42_20260525_120732
# [scenario 1/3] PRBS | 6 trajectories
# [1/18] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=2m23.1s
# [5/18] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=21.9s
# [6/18] PRBS seed=47 done | reason=completed | sim_time=60.00s | eta=16.9s
# [scenario done] PRBS | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=2.1801 m | pos_p95=5.1851 m | rot_med=0.0434 rad | completion=1.000 | elapsed=8.5s
# [scenario 2/3] CHIRP | 6 trajectories
# [7/18] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=25.7s
# [11/18] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=10.4s
# [12/18] CHIRP seed=100047 done | reason=completed | sim_time=60.00s | eta=8.2s
# [scenario done] CHIRP | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=0.9492 m | pos_p95=3.1073 m | rot_med=0.0254 rad | completion=1.000 | elapsed=16.4s
# [scenario 3/3] OU | 6 trajectories
# [13/18] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=9.4s
# [17/18] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=1.4s
# [18/18] OU seed=200047 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=1.0873 m | pos_p95=2.9782 m | rot_med=0.0286 rad | completion=1.000 | elapsed=24.4s
# Benchmark finished in 37.5s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_v4eval_traj6_seed42_20260525_120732
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: SE(3) Momentum Black-Box [baseline/core]
# Canonical model type: se3_momentum_blackbox
# Energy semantics: not_comparable
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 6
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.2031 m | pos p95=0.3934 m | rot median=0.0156 rad | total vel median=0.0151 m/s | rel vel median=0.0128 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=0.6334 m | pos p95=1.7890 m | rot median=0.0155 rad | total vel median=0.0139 m/s | rel vel median=0.0156 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=1.2695 m | pos p95=4.6734 m | rot median=0.0287 rad | total vel median=0.0296 m/s | rel vel median=0.0265 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=18 | completed=18 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1549 m | pos p95=0.4499 m | rot median=0.0190 rad | total vel median=0.0245 m/s | rel vel median=0.0186 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.8544 m | pos p95=2.0342 m | rot median=0.0310 rad | total vel median=0.0317 m/s | rel vel median=0.0353 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=2.1801 m | pos p95=5.1851 m | rot median=0.0434 rad | total vel median=0.0431 m/s | rel vel median=0.0405 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1729 m | pos p95=0.3111 m | rot median=0.0115 rad | total vel median=0.0102 m/s | rel vel median=0.0076 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.5918 m | pos p95=1.2775 m | rot median=0.0135 rad | total vel median=0.0070 m/s | rel vel median=0.0056 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=0.9492 m | pos p95=3.1073 m | rot median=0.0254 rad | total vel median=0.0089 m/s | rel vel median=0.0102 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.2416 m | pos p95=0.3505 m | rot median=0.0231 rad | total vel median=0.0191 m/s | rel vel median=0.0167 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.7063 m | pos p95=1.4943 m | rot median=0.0136 rad | total vel median=0.0268 m/s | rel vel median=0.0249 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.0873 m | pos p95=2.9782 m | rot median=0.0286 rad | total vel median=0.0374 m/s | rel vel median=0.0341 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Largest completed terminal errors
#   PRBS seed=43 | reason=completed | sim_time=60.00s | pos=5.3983 m | rot=0.0923 rad | total_vel_violation=0
#   PRBS seed=46 | reason=completed | sim_time=60.00s | pos=4.5454 m | rot=0.0795 rad | total_vel_violation=0
#   CHIRP seed=100043 | reason=completed | sim_time=60.00s | pos=3.4650 m | rot=0.0584 rad | total_vel_violation=0
#   OU seed=200044 | reason=completed | sim_time=60.00s | pos=3.4608 m | rot=0.0597 rad | total_vel_violation=0
#   PRBS seed=45 | reason=completed | sim_time=60.00s | pos=2.6605 m | rot=0.0504 rad | total_vel_violation=0
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# PRBS seed=43 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_v4eval_traj6_seed42_20260525_120732/diagnostic_plots/high_terminal_error_PRBS_seed43.png
# PRBS seed=46 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_v4eval_traj6_seed42_20260525_120732/diagnostic_plots/high_terminal_error_PRBS_seed46.png
# Batch evaluation complete.
# + /usr/bin/python3 /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/scripts/register_existing_runs_as_suite.py --suite-dir /content/_proxy_suites/sweep_oc_phase1a_smoke1_proxy_t2_wpfrag_se3_momentum_blackbox --run baseline se3_momentum_blackbox 42 clean__baseline_se3_momentum_blackbox_seed42 /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42
# Registered suite: /content/_proxy_suites/sweep_oc_phase1a_smoke1_proxy_t2_wpfrag_se3_momentum_blackbox
# Runs: 1
# Manifest: /content/_proxy_suites/sweep_oc_phase1a_smoke1_proxy_t2_wpfrag_se3_momentum_blackbox/runs.tsv
# + /usr/bin/python3 /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/scripts/summarize_sweep.py --suite-dir /content/_proxy_suites/sweep_oc_phase1a_smoke1_proxy_t2_wpfrag_se3_momentum_blackbox
# + /usr/bin/python3 /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/scripts/build_experiment_report.py --suite-dir /content/_proxy_suites/sweep_oc_phase1a_smoke1_proxy_t2_wpfrag_se3_momentum_blackbox
# /content/_proxy_suites/sweep_oc_phase1a_smoke1_proxy_t2_wpfrag_se3_momentum_blackbox/phase1a_decision_brief.md
# [proxy] local: /content/_proxy_suites/sweep_oc_phase1a_smoke1_proxy_t2_wpfrag_se3_momentum_blackbox

# %% [markdown]
# ## 3. Decision train (clean x 5 seeds)
# The 5 evidence-bearing clean training runs for this black-box model.

# %%
os.environ["MODE"] = "decision_train"
# !bash scripts/run_phase1a_oc_v4lite.sh
# Out:
# [phase1a]
# MODE=decision_train
# RUN_TAG=t2_wpfrag_se3_momentum_blackbox
# DATASET=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# DEVICE=cuda
# PHASE1A_MODELS=se3_momentum_blackbox
# PHASE1A_PROTOCOLS=clean
# SMOKE1_MODELS=se3_momentum_blackbox
# SMOKE_SEEDS=42
# DECISION_SEEDS=42 43 44 45 46
# NOISE_REFERENCE=remus100_dr
# PHASE1A_LOG_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_logs/t2_wpfrag_se3_momentum_blackbox
# PHASE1A_METADATA_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_metadata_t2_wpfrag_se3_momentum_blackbox
# [train] suite=sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox models=se3_momentum_blackbox seeds=42 43 44 45 46 protocol=auto
# Training all models with profile-based noisy IC.
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Group: all
# Explicit models: se3_momentum_blackbox
# Seeds: 42 43 44 45 46
# Noise config: protocol=auto, profile=clean, scale=1.0, warmup=20, ramp=80, mix_ratio=0.5
# Auto-eval profiles: block=[clean nominal_eval heading_biased_eval] heldout=[clean nominal_eval degraded_eval heading_biased_eval]
# Suite directory: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Models (1): se3_momentum_blackbox
# Seeds: 42 43 44 45 46
# [train] baseline_se3_momentum_blackbox_seed42
# Loading dataset...
# Loaded: 83850 train, 21000 test, t_eval=[0.   0.05 0.1  0.15 0.2 ]
# Dataset split: trajectory | train trajectories: 559 | test trajectories: 140
# Dataset ID: d0be9434
# Dataset path: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl | velocity convention: body_total | state dim: 27
# Position std: [0.1508, 0.1400, 0.0370]
# Velocity std: u=0.4722, v=0.0898, w=0.0718, p=0.0248, q=0.0906, r=0.0526
# Actuator std: a0=0.1543, a1=0.1555, a2=299.0037
# Training noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# Model: SE(3) Momentum Black-Box [baseline/core] | canonical type: se3_momentum_blackbox
# Model parameters: 64,683
# Training dataset: id=d0be9434 | path=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Mass matrix initialized from physics
# Training: epochs<=300, target_steps=5000, warmup_steps=400, lr=6.00e-03 -> 1.00e-04, solver=rk4, so3_reg=1.00e-03
# Train samples: 83850, Test samples: 21000
# Epoch    1 | Step    20/ 5000 | Train 4.6159e-01 | Test 4.3687e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 4.10e-04 | 4.2s
# Epoch    2 | Step    40/ 5000 | Train 4.7678e-01 | Test 4.5966e-01 | SO3(train/test) 1.13e-07/1.12e-07 | Fail(train/test) 0/0 | LR 7.05e-04 | 4.0s
# Epoch    3 | Step    60/ 5000 | Train 4.5008e-01 | Test 4.2621e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 1.00e-03 | 3.8s
# Epoch    4 | Step    80/ 5000 | Train 4.4224e-01 | Test 4.1929e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 1.29e-03 | 3.8s
# Epoch    5 | Step   100/ 5000 | Train 4.3121e-01 | Test 4.0953e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 1.59e-03 | 3.9s
# Epoch    6 | Step   120/ 5000 | Train 4.2605e-01 | Test 3.8299e-01 | SO3(train/test) 1.13e-07/1.14e-07 | Fail(train/test) 0/0 | LR 1.88e-03 | 3.8s
# Epoch    7 | Step   140/ 5000 | Train 4.1757e-01 | Test 4.1411e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 2.18e-03 | 3.8s
# Epoch    8 | Step   160/ 5000 | Train 3.9710e-01 | Test 3.6081e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 2.47e-03 | 3.9s
# Epoch    9 | Step   180/ 5000 | Train 3.7895e-01 | Test 3.6460e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 2.77e-03 | 3.9s
# Epoch   10 | Step   200/ 5000 | Train 3.6962e-01 | Test 3.4525e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 3.06e-03 | 3.8s
# Epoch   11 | Step   220/ 5000 | Train 3.5821e-01 | Test 3.3817e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 3.36e-03 | 3.8s
# Epoch   12 | Step   240/ 5000 | Train 3.5682e-01 | Test 3.7303e-01 | SO3(train/test) 1.13e-07/1.14e-07 | Fail(train/test) 0/0 | LR 3.65e-03 | 3.9s
# Epoch   13 | Step   260/ 5000 | Train 3.5782e-01 | Test 3.4697e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 3.95e-03 | 3.8s
# Epoch   14 | Step   280/ 5000 | Train 3.5896e-01 | Test 3.4538e-01 | SO3(train/test) 1.13e-07/1.14e-07 | Fail(train/test) 0/0 | LR 4.24e-03 | 3.7s
# Epoch   15 | Step   300/ 5000 | Train 3.4578e-01 | Test 3.3032e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 4.54e-03 | 3.9s
# Epoch   16 | Step   320/ 5000 | Train 3.4000e-01 | Test 3.4848e-01 | SO3(train/test) 1.13e-07/1.14e-07 | Fail(train/test) 0/0 | LR 4.83e-03 | 3.8s
# Epoch   17 | Step   340/ 5000 | Train 3.4641e-01 | Test 5.3486e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 5.13e-03 | 3.8s
# Epoch   18 | Step   360/ 5000 | Train 3.8467e-01 | Test 3.0233e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 5.42e-03 | 3.8s
# Epoch   19 | Step   380/ 5000 | Train 4.5469e-01 | Test 3.3223e-01 | SO3(train/test) 1.13e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.72e-03 | 3.8s
# Epoch   20 | Step   400/ 5000 | Train 4.0640e-01 | Test 3.6856e-01 | SO3(train/test) 1.13e-07/1.14e-07 | Fail(train/test) 0/0 | LR 6.00e-03 | 3.8s
# Epoch   21 | Step   420/ 5000 | Train 3.0664e-01 | Test 2.4006e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 6.00e-03 | 3.8s
# Epoch   22 | Step   440/ 5000 | Train 2.4875e-01 | Test 3.3829e-01 | SO3(train/test) 1.14e-07/1.13e-07 | Fail(train/test) 0/0 | LR 6.00e-03 | 3.9s
# Epoch   23 | Step   460/ 5000 | Train 2.2006e-01 | Test 2.1507e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 6.00e-03 | 3.9s
# Epoch   24 | Step   480/ 5000 | Train 2.0045e-01 | Test 1.7029e-01 | SO3(train/test) 1.14e-07/1.13e-07 | Fail(train/test) 0/0 | LR 6.00e-03 | 3.8s
# Epoch   25 | Step   500/ 5000 | Train 1.7692e-01 | Test 1.8559e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.99e-03 | 3.9s
# Epoch   26 | Step   520/ 5000 | Train 1.6996e-01 | Test 2.1048e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.99e-03 | 3.7s
# Epoch   27 | Step   540/ 5000 | Train 1.6426e-01 | Test 1.7678e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.99e-03 | 3.7s
# Epoch   28 | Step   560/ 5000 | Train 1.4934e-01 | Test 1.3154e-01 | SO3(train/test) 1.13e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.98e-03 | 3.8s
# Epoch   29 | Step   580/ 5000 | Train 1.3867e-01 | Test 1.4971e-01 | SO3(train/test) 1.14e-07/1.13e-07 | Fail(train/test) 0/0 | LR 5.98e-03 | 3.9s
# Epoch   30 | Step   600/ 5000 | Train 1.2745e-01 | Test 1.3196e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.97e-03 | 3.8s
# Epoch   31 | Step   620/ 5000 | Train 1.1766e-01 | Test 1.3000e-01 | SO3(train/test) 1.14e-07/1.13e-07 | Fail(train/test) 0/0 | LR 5.97e-03 | 3.8s
# Epoch   32 | Step   640/ 5000 | Train 1.1726e-01 | Test 9.6851e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.96e-03 | 3.9s
# Epoch   33 | Step   660/ 5000 | Train 1.5706e-01 | Test 1.5625e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.95e-03 | 3.7s
# Epoch   34 | Step   680/ 5000 | Train 1.4144e-01 | Test 1.2134e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.95e-03 | 3.9s
# Epoch   35 | Step   700/ 5000 | Train 1.0257e-01 | Test 1.0541e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.94e-03 | 3.9s
# Epoch   36 | Step   720/ 5000 | Train 9.1306e-02 | Test 8.7644e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.93e-03 | 3.8s
# Epoch   37 | Step   740/ 5000 | Train 8.6961e-02 | Test 7.4070e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.92e-03 | 3.8s
# Epoch   38 | Step   760/ 5000 | Train 8.6211e-02 | Test 6.9658e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.91e-03 | 3.9s
# Epoch   39 | Step   780/ 5000 | Train 9.1080e-02 | Test 1.0366e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.90e-03 | 3.8s
# Epoch   40 | Step   800/ 5000 | Train 1.0946e-01 | Test 1.0776e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.89e-03 | 3.8s
# Epoch   41 | Step   820/ 5000 | Train 9.7900e-02 | Test 8.5375e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.88e-03 | 3.8s
# Epoch   42 | Step   840/ 5000 | Train 1.1355e-01 | Test 1.4437e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.87e-03 | 3.8s
# Epoch   43 | Step   860/ 5000 | Train 1.3663e-01 | Test 1.2757e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.86e-03 | 3.7s
# Epoch   44 | Step   880/ 5000 | Train 1.0113e-01 | Test 9.0693e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.84e-03 | 3.9s
# Epoch   45 | Step   900/ 5000 | Train 8.4521e-02 | Test 7.1517e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.83e-03 | 3.9s
# Epoch   46 | Step   920/ 5000 | Train 7.5062e-02 | Test 7.7876e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.82e-03 | 3.8s
# Epoch   47 | Step   940/ 5000 | Train 7.4829e-02 | Test 9.4168e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.80e-03 | 3.8s
# Epoch   48 | Step   960/ 5000 | Train 7.6841e-02 | Test 8.0178e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.79e-03 | 3.8s
# Epoch   49 | Step   980/ 5000 | Train 7.2800e-02 | Test 7.8452e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.77e-03 | 3.8s
# Epoch   50 | Step  1000/ 5000 | Train 7.2146e-02 | Test 8.2633e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.76e-03 | 3.8s
# Epoch   51 | Step  1020/ 5000 | Train 7.2771e-02 | Test 8.8208e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.74e-03 | 3.8s
# Epoch   52 | Step  1040/ 5000 | Train 7.2633e-02 | Test 7.3340e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.72e-03 | 3.8s
# Epoch   53 | Step  1060/ 5000 | Train 6.9904e-02 | Test 7.3285e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.71e-03 | 3.7s
# Epoch   54 | Step  1080/ 5000 | Train 6.9354e-02 | Test 7.3987e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.69e-03 | 3.8s
# Epoch   55 | Step  1100/ 5000 | Train 6.8751e-02 | Test 7.2907e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.67e-03 | 3.9s
# Epoch   56 | Step  1120/ 5000 | Train 6.8103e-02 | Test 7.2376e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.65e-03 | 3.8s
# Epoch   57 | Step  1140/ 5000 | Train 6.7955e-02 | Test 7.7346e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.63e-03 | 3.8s
# Epoch   58 | Step  1160/ 5000 | Train 7.0455e-02 | Test 6.0162e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.61e-03 | 3.9s
# Epoch   59 | Step  1180/ 5000 | Train 6.7229e-02 | Test 6.8702e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.59e-03 | 3.8s
# Epoch   60 | Step  1200/ 5000 | Train 6.5581e-02 | Test 6.6441e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.57e-03 | 3.7s
# Epoch   61 | Step  1220/ 5000 | Train 6.4933e-02 | Test 6.4849e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.55e-03 | 3.8s
# Epoch   62 | Step  1240/ 5000 | Train 6.3910e-02 | Test 6.6548e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.53e-03 | 3.9s
# Epoch   63 | Step  1260/ 5000 | Train 6.3217e-02 | Test 6.6340e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.51e-03 | 3.8s
# Epoch   64 | Step  1280/ 5000 | Train 6.2828e-02 | Test 6.7450e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.48e-03 | 3.8s
# Epoch   65 | Step  1300/ 5000 | Train 6.2496e-02 | Test 6.6247e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.46e-03 | 4.0s
# Epoch   66 | Step  1320/ 5000 | Train 6.1651e-02 | Test 6.6073e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.44e-03 | 3.8s
# Epoch   67 | Step  1340/ 5000 | Train 6.1110e-02 | Test 6.1246e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.41e-03 | 3.8s
# Epoch   68 | Step  1360/ 5000 | Train 5.9863e-02 | Test 5.9238e-02 | SO3(train/test) 1.14e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.39e-03 | 3.9s
# Epoch   69 | Step  1380/ 5000 | Train 5.8864e-02 | Test 5.9469e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.36e-03 | 3.8s
# Epoch   70 | Step  1400/ 5000 | Train 5.8080e-02 | Test 5.8035e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.34e-03 | 3.8s
# Epoch   71 | Step  1420/ 5000 | Train 5.7754e-02 | Test 5.6700e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.31e-03 | 3.9s
# Epoch   72 | Step  1440/ 5000 | Train 5.6965e-02 | Test 5.6234e-02 | SO3(train/test) 1.14e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.29e-03 | 3.8s
# Epoch   73 | Step  1460/ 5000 | Train 5.5916e-02 | Test 5.5048e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.26e-03 | 3.8s
# Epoch   74 | Step  1480/ 5000 | Train 5.5321e-02 | Test 5.2260e-02 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.23e-03 | 3.8s
# Epoch   75 | Step  1500/ 5000 | Train 5.3198e-02 | Test 5.4163e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.21e-03 | 3.9s
# Epoch   76 | Step  1520/ 5000 | Train 5.0068e-02 | Test 4.7725e-02 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.18e-03 | 3.9s
# Epoch   77 | Step  1540/ 5000 | Train 4.5219e-02 | Test 4.4845e-02 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.15e-03 | 3.8s
# Epoch   78 | Step  1560/ 5000 | Train 4.2486e-02 | Test 4.9945e-02 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.12e-03 | 3.9s
# Epoch   79 | Step  1580/ 5000 | Train 4.1690e-02 | Test 5.3376e-02 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.09e-03 | 3.8s
# Epoch   80 | Step  1600/ 5000 | Train 6.6391e-02 | Test 1.0101e-01 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.06e-03 | 3.8s
# Epoch   81 | Step  1620/ 5000 | Train 9.7379e-02 | Test 1.4781e-01 | SO3(train/test) 1.15e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.03e-03 | 3.9s
# Epoch   82 | Step  1640/ 5000 | Train 9.0552e-02 | Test 6.8881e-02 | SO3(train/test) 1.14e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.00e-03 | 3.8s
# Epoch   83 | Step  1660/ 5000 | Train 1.0804e-01 | Test 5.6025e-02 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 4.97e-03 | 3.8s
# Epoch   84 | Step  1680/ 5000 | Train 7.6892e-02 | Test 1.1966e-01 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 4.94e-03 | 3.9s
# Epoch   85 | Step  1700/ 5000 | Train 5.7056e-02 | Test 5.7453e-02 | SO3(train/test) 1.15e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.91e-03 | 3.8s
# Epoch   86 | Step  1720/ 5000 | Train 4.0573e-02 | Test 3.8233e-02 | SO3(train/test) 1.15e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.88e-03 | 3.9s
# Epoch   87 | Step  1740/ 5000 | Train 3.8609e-02 | Test 3.0238e-02 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 4.85e-03 | 3.8s
# Epoch   88 | Step  1760/ 5000 | Train 5.1590e-02 | Test 1.1147e-01 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.82e-03 | 3.8s
# Epoch   89 | Step  1780/ 5000 | Train 4.5783e-02 | Test 3.2649e-02 | SO3(train/test) 1.15e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.78e-03 | 3.8s
# Epoch   90 | Step  1800/ 5000 | Train 4.1928e-02 | Test 1.1146e-01 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.75e-03 | 3.8s
# Epoch   91 | Step  1820/ 5000 | Train 7.1017e-02 | Test 3.8575e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.72e-03 | 3.8s
# Epoch   92 | Step  1840/ 5000 | Train 3.8760e-02 | Test 2.9319e-02 | SO3(train/test) 1.16e-07/1.15e-07 | Fail(train/test) 0/0 | LR 4.68e-03 | 3.9s
# Epoch   93 | Step  1860/ 5000 | Train 3.5212e-02 | Test 4.9180e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.65e-03 | 3.8s
# Epoch   94 | Step  1880/ 5000 | Train 3.4282e-02 | Test 3.5102e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.62e-03 | 3.8s
# Epoch   95 | Step  1900/ 5000 | Train 3.3882e-02 | Test 2.9364e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.58e-03 | 3.9s
# Epoch   96 | Step  1920/ 5000 | Train 3.1948e-02 | Test 4.2551e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.55e-03 | 3.8s
# Epoch   97 | Step  1940/ 5000 | Train 3.2042e-02 | Test 3.3864e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.51e-03 | 3.9s
# Epoch   98 | Step  1960/ 5000 | Train 3.2028e-02 | Test 2.9437e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.48e-03 | 3.8s
# Epoch   99 | Step  1980/ 5000 | Train 3.0425e-02 | Test 3.8622e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.44e-03 | 3.8s
# Epoch  100 | Step  2000/ 5000 | Train 3.0419e-02 | Test 3.4281e-02 | SO3(train/test) 1.16e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.41e-03 | 3.8s
# Epoch  101 | Step  2020/ 5000 | Train 3.0842e-02 | Test 2.9739e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.37e-03 | 3.8s
# Epoch  102 | Step  2040/ 5000 | Train 2.9365e-02 | Test 3.4502e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.33e-03 | 3.8s
# Epoch  103 | Step  2060/ 5000 | Train 2.9250e-02 | Test 3.5941e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.30e-03 | 3.7s
# Epoch  104 | Step  2080/ 5000 | Train 3.0647e-02 | Test 3.0904e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.26e-03 | 3.8s
# Epoch  105 | Step  2100/ 5000 | Train 2.8760e-02 | Test 2.9512e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.22e-03 | 3.8s
# Epoch  106 | Step  2120/ 5000 | Train 2.8877e-02 | Test 3.9631e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.19e-03 | 3.8s
# Epoch  107 | Step  2140/ 5000 | Train 3.2006e-02 | Test 3.6267e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.15e-03 | 3.9s
# Epoch  108 | Step  2160/ 5000 | Train 3.0005e-02 | Test 3.6856e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.11e-03 | 3.8s
# Epoch  109 | Step  2180/ 5000 | Train 2.8642e-02 | Test 2.9792e-02 | SO3(train/test) 1.16e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.08e-03 | 3.8s
# Epoch  110 | Step  2200/ 5000 | Train 2.7093e-02 | Test 2.3957e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.04e-03 | 3.8s
# Epoch  111 | Step  2220/ 5000 | Train 2.5569e-02 | Test 3.3422e-02 | SO3(train/test) 1.16e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.00e-03 | 3.8s
# Epoch  112 | Step  2240/ 5000 | Train 2.5557e-02 | Test 2.6118e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 3.96e-03 | 3.8s
# Epoch  113 | Step  2260/ 5000 | Train 2.5400e-02 | Test 2.2597e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 3.92e-03 | 3.9s
# Epoch  114 | Step  2280/ 5000 | Train 2.4551e-02 | Test 3.1941e-02 | SO3(train/test) 1.16e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.88e-03 | 3.8s
# Epoch  115 | Step  2300/ 5000 | Train 2.4571e-02 | Test 2.7236e-02 | SO3(train/test) 1.16e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.85e-03 | 3.8s
# Epoch  116 | Step  2320/ 5000 | Train 2.5005e-02 | Test 2.4130e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 3.81e-03 | 3.8s
# Epoch  117 | Step  2340/ 5000 | Train 2.4340e-02 | Test 2.5979e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 3.77e-03 | 3.9s
# Epoch  118 | Step  2360/ 5000 | Train 2.3815e-02 | Test 2.8774e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 3.73e-03 | 3.9s
# Epoch  119 | Step  2380/ 5000 | Train 2.4951e-02 | Test 2.5174e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 3.69e-03 | 3.8s
# Epoch  120 | Step  2400/ 5000 | Train 2.3695e-02 | Test 3.0200e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.65e-03 | 3.8s
# Epoch  121 | Step  2420/ 5000 | Train 2.3341e-02 | Test 2.1405e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.61e-03 | 3.8s
# Epoch  122 | Step  2440/ 5000 | Train 2.2777e-02 | Test 1.9167e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.57e-03 | 3.8s
# Epoch  123 | Step  2460/ 5000 | Train 2.1966e-02 | Test 3.0509e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.53e-03 | 3.8s
# Epoch  124 | Step  2480/ 5000 | Train 2.2037e-02 | Test 2.2219e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.49e-03 | 3.8s
# Epoch  125 | Step  2500/ 5000 | Train 2.1912e-02 | Test 1.9811e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 3.45e-03 | 3.8s
# Epoch  126 | Step  2520/ 5000 | Train 2.1133e-02 | Test 2.6485e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 3.41e-03 | 3.8s
# Epoch  127 | Step  2540/ 5000 | Train 2.1163e-02 | Test 2.2634e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.37e-03 | 3.8s
# Epoch  128 | Step  2560/ 5000 | Train 2.1451e-02 | Test 2.1174e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.33e-03 | 3.9s
# Epoch  129 | Step  2580/ 5000 | Train 2.0907e-02 | Test 2.3352e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.29e-03 | 3.8s
# Epoch  130 | Step  2600/ 5000 | Train 2.0725e-02 | Test 1.9794e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 3.25e-03 | 3.8s
# Epoch  131 | Step  2620/ 5000 | Train 2.0138e-02 | Test 1.7893e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.21e-03 | 3.8s
# Epoch  132 | Step  2640/ 5000 | Train 1.9404e-02 | Test 2.3739e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.17e-03 | 3.8s
# Epoch  133 | Step  2660/ 5000 | Train 1.9340e-02 | Test 2.0238e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.13e-03 | 3.8s
# Epoch  134 | Step  2680/ 5000 | Train 1.9392e-02 | Test 1.8476e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.09e-03 | 3.9s
# Epoch  135 | Step  2700/ 5000 | Train 1.8761e-02 | Test 2.3326e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 3.05e-03 | 3.8s
# Epoch  136 | Step  2720/ 5000 | Train 1.9234e-02 | Test 1.8787e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 3.01e-03 | 3.8s
# Epoch  137 | Step  2740/ 5000 | Train 1.9368e-02 | Test 1.8394e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.97e-03 | 3.9s
# Epoch  138 | Step  2760/ 5000 | Train 1.8426e-02 | Test 2.2020e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.93e-03 | 3.8s
# Epoch  139 | Step  2780/ 5000 | Train 1.8294e-02 | Test 2.0153e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 2.89e-03 | 3.9s
# Epoch  140 | Step  2800/ 5000 | Train 2.3442e-02 | Test 3.3060e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 2.85e-03 | 3.9s
# Epoch  141 | Step  2820/ 5000 | Train 1.9219e-02 | Test 2.0149e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.81e-03 | 3.7s
# Epoch  142 | Step  2840/ 5000 | Train 1.5768e-02 | Test 1.5390e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.77e-03 | 3.8s
# Epoch  143 | Step  2860/ 5000 | Train 1.4072e-02 | Test 1.6709e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.73e-03 | 3.8s
# Epoch  144 | Step  2880/ 5000 | Train 1.4423e-02 | Test 1.4425e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.69e-03 | 3.8s
# Epoch  145 | Step  2900/ 5000 | Train 1.3418e-02 | Test 1.4920e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.65e-03 | 3.8s
# Epoch  146 | Step  2920/ 5000 | Train 1.3222e-02 | Test 1.2568e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.61e-03 | 3.8s
# Epoch  147 | Step  2940/ 5000 | Train 1.1676e-02 | Test 1.2107e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.57e-03 | 3.8s
# Epoch  148 | Step  2960/ 5000 | Train 1.1248e-02 | Test 1.1983e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.53e-03 | 3.8s
# Epoch  149 | Step  2980/ 5000 | Train 1.2310e-02 | Test 2.4596e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.49e-03 | 3.9s
# Epoch  150 | Step  3000/ 5000 | Train 1.4637e-02 | Test 1.3754e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 2.45e-03 | 3.9s
# Epoch  151 | Step  3020/ 5000 | Train 1.1705e-02 | Test 1.1255e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 2.41e-03 | 3.8s
# Epoch  152 | Step  3040/ 5000 | Train 1.1080e-02 | Test 1.0665e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.37e-03 | 3.9s
# Epoch  153 | Step  3060/ 5000 | Train 1.2802e-02 | Test 3.9177e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 2.33e-03 | 3.9s
# Epoch  154 | Step  3080/ 5000 | Train 3.1185e-02 | Test 1.3486e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 2.29e-03 | 3.7s
# Epoch  155 | Step  3100/ 5000 | Train 1.6688e-02 | Test 2.2711e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.25e-03 | 3.9s
# Epoch  156 | Step  3120/ 5000 | Train 2.3505e-02 | Test 1.7463e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.21e-03 | 3.8s
# Epoch  157 | Step  3140/ 5000 | Train 1.5309e-02 | Test 1.2756e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.18e-03 | 3.8s
# Epoch  158 | Step  3160/ 5000 | Train 1.0932e-02 | Test 1.0319e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 2.14e-03 | 3.8s
# Epoch  159 | Step  3180/ 5000 | Train 2.0052e-02 | Test 3.2830e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.10e-03 | 3.8s
# Epoch  160 | Step  3200/ 5000 | Train 1.8319e-02 | Test 1.2478e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 2.06e-03 | 4.0s
# Epoch  161 | Step  3220/ 5000 | Train 1.0160e-02 | Test 9.7890e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 2.02e-03 | 3.8s
# Epoch  162 | Step  3240/ 5000 | Train 8.9913e-03 | Test 9.4471e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.99e-03 | 3.8s
# Epoch  163 | Step  3260/ 5000 | Train 8.5112e-03 | Test 8.9297e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.95e-03 | 3.9s
# Epoch  164 | Step  3280/ 5000 | Train 8.3440e-03 | Test 8.8334e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.91e-03 | 3.8s
# Epoch  165 | Step  3300/ 5000 | Train 8.1438e-03 | Test 8.5109e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.87e-03 | 3.8s
# Epoch  166 | Step  3320/ 5000 | Train 7.9637e-03 | Test 8.7881e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.84e-03 | 3.9s
# Epoch  167 | Step  3340/ 5000 | Train 7.8499e-03 | Test 8.2564e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.80e-03 | 3.8s
# Epoch  168 | Step  3360/ 5000 | Train 7.7670e-03 | Test 8.1950e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.76e-03 | 3.8s
# Epoch  169 | Step  3380/ 5000 | Train 7.7439e-03 | Test 8.0860e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.73e-03 | 3.9s
# Epoch  170 | Step  3400/ 5000 | Train 1.3189e-02 | Test 1.9986e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.69e-03 | 3.9s
# Epoch  171 | Step  3420/ 5000 | Train 1.6831e-02 | Test 9.4123e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.66e-03 | 3.8s
# Epoch  172 | Step  3440/ 5000 | Train 8.2943e-03 | Test 8.1434e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.62e-03 | 3.9s
# Epoch  173 | Step  3460/ 5000 | Train 7.4003e-03 | Test 7.6834e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.59e-03 | 3.8s
# Epoch  174 | Step  3480/ 5000 | Train 7.1203e-03 | Test 7.4752e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.55e-03 | 3.8s
# Epoch  175 | Step  3500/ 5000 | Train 6.9885e-03 | Test 7.3918e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.52e-03 | 3.8s
# Epoch  176 | Step  3520/ 5000 | Train 6.8644e-03 | Test 7.2326e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.48e-03 | 4.0s
# Epoch  177 | Step  3540/ 5000 | Train 6.7794e-03 | Test 7.2129e-03 | SO3(train/test) 1.17e-07/1.18e-07 | Fail(train/test) 0/0 | LR 1.45e-03 | 3.8s
# Epoch  178 | Step  3560/ 5000 | Train 6.6871e-03 | Test 7.0544e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.41e-03 | 3.8s
# Epoch  179 | Step  3580/ 5000 | Train 6.6260e-03 | Test 6.9884e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.38e-03 | 3.9s
# Epoch  180 | Step  3600/ 5000 | Train 6.5323e-03 | Test 6.9256e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.35e-03 | 3.8s
# Epoch  181 | Step  3620/ 5000 | Train 6.4759e-03 | Test 6.8545e-03 | SO3(train/test) 1.17e-07/1.18e-07 | Fail(train/test) 0/0 | LR 1.31e-03 | 3.9s
# Epoch  182 | Step  3640/ 5000 | Train 6.4366e-03 | Test 6.7386e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.28e-03 | 3.9s
# Epoch  183 | Step  3660/ 5000 | Train 6.3761e-03 | Test 6.7011e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.25e-03 | 3.8s
# Epoch  184 | Step  3680/ 5000 | Train 6.2800e-03 | Test 6.6093e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.22e-03 | 3.8s
# Epoch  185 | Step  3700/ 5000 | Train 6.2204e-03 | Test 6.6109e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.19e-03 | 3.9s
# Epoch  186 | Step  3720/ 5000 | Train 6.1642e-03 | Test 6.5226e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.16e-03 | 3.8s
# Epoch  187 | Step  3740/ 5000 | Train 6.1354e-03 | Test 6.5341e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.13e-03 | 3.8s
# Epoch  188 | Step  3760/ 5000 | Train 6.0843e-03 | Test 6.4358e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.10e-03 | 3.8s
# Epoch  189 | Step  3780/ 5000 | Train 6.0256e-03 | Test 6.3984e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.07e-03 | 3.9s
# Epoch  190 | Step  3800/ 5000 | Train 5.9798e-03 | Test 6.4252e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.04e-03 | 3.8s
# Epoch  191 | Step  3820/ 5000 | Train 5.9615e-03 | Test 6.3876e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.01e-03 | 3.9s
# Epoch  192 | Step  3840/ 5000 | Train 5.9380e-03 | Test 6.2987e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 9.77e-04 | 3.9s
# Epoch  193 | Step  3860/ 5000 | Train 5.9077e-03 | Test 6.2460e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 9.49e-04 | 3.8s
# Epoch  194 | Step  3880/ 5000 | Train 5.8389e-03 | Test 6.2029e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 9.21e-04 | 3.8s
# Epoch  195 | Step  3900/ 5000 | Train 5.8447e-03 | Test 6.2603e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 8.93e-04 | 3.8s
# Epoch  196 | Step  3920/ 5000 | Train 5.7921e-03 | Test 6.1474e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 8.66e-04 | 3.8s
# Epoch  197 | Step  3940/ 5000 | Train 5.7767e-03 | Test 6.1250e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 8.39e-04 | 3.9s
# Epoch  198 | Step  3960/ 5000 | Train 5.7273e-03 | Test 6.1099e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 8.12e-04 | 3.8s
# Epoch  199 | Step  3980/ 5000 | Train 5.7095e-03 | Test 6.0876e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 7.86e-04 | 3.8s
# Epoch  200 | Step  4000/ 5000 | Train 5.6924e-03 | Test 6.0645e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 7.61e-04 | 3.8s
# Epoch  201 | Step  4020/ 5000 | Train 5.6527e-03 | Test 6.0245e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 7.35e-04 | 3.8s
# Epoch  202 | Step  4040/ 5000 | Train 5.6332e-03 | Test 6.0030e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 7.11e-04 | 4.0s
# Epoch  203 | Step  4060/ 5000 | Train 5.6064e-03 | Test 6.0054e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 6.86e-04 | 3.8s
# Epoch  204 | Step  4080/ 5000 | Train 5.5965e-03 | Test 5.9764e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 6.62e-04 | 3.8s
# Epoch  205 | Step  4100/ 5000 | Train 5.5822e-03 | Test 5.9729e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 6.39e-04 | 3.9s
# Epoch  206 | Step  4120/ 5000 | Train 5.5723e-03 | Test 5.9286e-03 | SO3(train/test) 1.17e-07/1.18e-07 | Fail(train/test) 0/0 | LR 6.16e-04 | 3.8s
# Epoch  207 | Step  4140/ 5000 | Train 5.5466e-03 | Test 5.8956e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 5.93e-04 | 3.8s
# Epoch  208 | Step  4160/ 5000 | Train 5.5275e-03 | Test 5.8889e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 5.71e-04 | 3.9s
# Epoch  209 | Step  4180/ 5000 | Train 5.5230e-03 | Test 5.8966e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 5.50e-04 | 3.8s
# Epoch  210 | Step  4200/ 5000 | Train 5.5034e-03 | Test 5.8867e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 5.29e-04 | 3.8s
# Epoch  211 | Step  4220/ 5000 | Train 5.4734e-03 | Test 5.8261e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 5.08e-04 | 3.8s
# Epoch  212 | Step  4240/ 5000 | Train 5.4673e-03 | Test 5.8051e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.88e-04 | 3.9s
# Epoch  213 | Step  4260/ 5000 | Train 5.4512e-03 | Test 5.8013e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.68e-04 | 3.7s
# Epoch  214 | Step  4280/ 5000 | Train 5.4349e-03 | Test 5.8061e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.49e-04 | 3.8s
# Epoch  215 | Step  4300/ 5000 | Train 5.4238e-03 | Test 5.8232e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.30e-04 | 3.9s
# Epoch  216 | Step  4320/ 5000 | Train 5.4157e-03 | Test 5.7825e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.12e-04 | 3.8s
# Epoch  217 | Step  4340/ 5000 | Train 5.4042e-03 | Test 5.7617e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.94e-04 | 3.8s
# Epoch  218 | Step  4360/ 5000 | Train 5.4096e-03 | Test 5.7551e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.77e-04 | 4.0s
# Epoch  219 | Step  4380/ 5000 | Train 5.3943e-03 | Test 5.7433e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.60e-04 | 3.8s
# Epoch  220 | Step  4400/ 5000 | Train 5.3905e-03 | Test 5.7290e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.44e-04 | 3.8s
# Epoch  221 | Step  4420/ 5000 | Train 5.3720e-03 | Test 5.7137e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.28e-04 | 3.8s
# Epoch  222 | Step  4440/ 5000 | Train 5.3614e-03 | Test 5.6992e-03 | SO3(train/test) 1.18e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.12e-04 | 3.9s
# Epoch  223 | Step  4460/ 5000 | Train 5.3521e-03 | Test 5.7171e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.98e-04 | 3.9s
# Epoch  224 | Step  4480/ 5000 | Train 5.3379e-03 | Test 5.6866e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.83e-04 | 3.8s
# Epoch  225 | Step  4500/ 5000 | Train 5.3412e-03 | Test 5.7097e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.70e-04 | 3.9s
# Epoch  226 | Step  4520/ 5000 | Train 5.3328e-03 | Test 5.6734e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.57e-04 | 3.8s
# Epoch  227 | Step  4540/ 5000 | Train 5.3284e-03 | Test 5.6790e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.44e-04 | 3.8s
# Epoch  228 | Step  4560/ 5000 | Train 5.3110e-03 | Test 5.6810e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.32e-04 | 3.8s
# Epoch  229 | Step  4580/ 5000 | Train 5.3103e-03 | Test 5.6691e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.20e-04 | 3.8s
# Epoch  230 | Step  4600/ 5000 | Train 5.2962e-03 | Test 5.6646e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.09e-04 | 3.8s
# Epoch  231 | Step  4620/ 5000 | Train 5.2962e-03 | Test 5.6453e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.98e-04 | 3.9s
# Epoch  232 | Step  4640/ 5000 | Train 5.2965e-03 | Test 5.6393e-03 | SO3(train/test) 1.17e-07/1.18e-07 | Fail(train/test) 0/0 | LR 1.88e-04 | 3.8s
# Epoch  233 | Step  4660/ 5000 | Train 5.2858e-03 | Test 5.6503e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.79e-04 | 3.9s
# Epoch  234 | Step  4680/ 5000 | Train 5.2813e-03 | Test 5.6351e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.70e-04 | 3.8s
# Epoch  235 | Step  4700/ 5000 | Train 5.2817e-03 | Test 5.6249e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.61e-04 | 3.8s
# Epoch  236 | Step  4720/ 5000 | Train 5.2672e-03 | Test 5.6190e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.53e-04 | 3.7s
# Epoch  237 | Step  4740/ 5000 | Train 5.2716e-03 | Test 5.6168e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.46e-04 | 3.7s
# Epoch  238 | Step  4760/ 5000 | Train 5.2627e-03 | Test 5.6072e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.39e-04 | 3.8s
# Epoch  239 | Step  4780/ 5000 | Train 5.2585e-03 | Test 5.6249e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.33e-04 | 3.9s
# Epoch  240 | Step  4800/ 5000 | Train 5.2587e-03 | Test 5.6008e-03 | SO3(train/test) 1.17e-07/1.18e-07 | Fail(train/test) 0/0 | LR 1.27e-04 | 3.8s
# Epoch  241 | Step  4820/ 5000 | Train 5.2572e-03 | Test 5.6054e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.22e-04 | 3.9s
# Epoch  242 | Step  4840/ 5000 | Train 5.2502e-03 | Test 5.5990e-03 | SO3(train/test) 1.18e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.17e-04 | 3.8s
# Epoch  243 | Step  4860/ 5000 | Train 5.2407e-03 | Test 5.6005e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.13e-04 | 3.8s
# Epoch  244 | Step  4880/ 5000 | Train 5.2473e-03 | Test 5.5953e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.10e-04 | 3.9s
# Epoch  245 | Step  4900/ 5000 | Train 5.2387e-03 | Test 5.5908e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.07e-04 | 3.8s
# Epoch  246 | Step  4920/ 5000 | Train 5.2371e-03 | Test 5.5908e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.04e-04 | 3.8s
# Epoch  247 | Step  4940/ 5000 | Train 5.2314e-03 | Test 5.5855e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.02e-04 | 3.8s
# Epoch  248 | Step  4960/ 5000 | Train 5.2362e-03 | Test 5.5854e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.01e-04 | 3.9s
# Epoch  249 | Step  4980/ 5000 | Train 5.2318e-03 | Test 5.5803e-03 | SO3(train/test) 1.17e-07/1.18e-07 | Fail(train/test) 0/0 | LR 1.00e-04 | 3.8s
# Epoch  250 | Step  5000/ 5000 | Train 5.2293e-03 | Test 5.5841e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.00e-04 | 3.8s
# Reached target optimizer steps: 5000/5000
# Done. Best validation score: failure_rate=0.0000, test_loss=5.5803e-03 (epoch 249)
# Running detailed evaluation...
# Block evaluation profile: clean
# Block evaluation noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0002 +/- 0.0001  (max 0.0010)
# Rotation geo [rad]:  0.0005 +/- 0.0000  (max 0.0006)
# Lin vel RMSE [m/s]:  0.0025 +/- 0.0017
# Ang vel RMSE [r/s]:  0.0011 +/- 0.0006
# Components:  u=0.0037  v=0.0009  w=0.0012  p=0.0007  q=0.0012  r=0.0010
# SO(3) violation:  |det-1|=6.31e-08  ||RR^T-I||=1.31e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# Block evaluation profile: nominal_eval
# Block evaluation noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0013 +/- 0.0008  (max 0.0056)
# Rotation geo [rad]:  0.0082 +/- 0.0058  (max 0.0367)
# Lin vel RMSE [m/s]:  0.0051 +/- 0.0023
# Ang vel RMSE [r/s]:  0.0034 +/- 0.0020
# Components:  u=0.0065  v=0.0032  w=0.0034  p=0.0051  q=0.0015  r=0.0015
# SO(3) violation:  |det-1|=2.75e-07  ||RR^T-I||=6.11e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# Block evaluation profile: heading_biased_eval
# Block evaluation noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0049 +/- 0.0017  (max 0.0109)
# Rotation geo [rad]:  0.0351 +/- 0.0096  (max 0.0656)
# Lin vel RMSE [m/s]:  0.0084 +/- 0.0038
# Ang vel RMSE [r/s]:  0.0034 +/- 0.0020
# Components:  u=0.0086  v=0.0090  w=0.0037  p=0.0051  q=0.0015  r=0.0015
# SO(3) violation:  |det-1|=2.97e-07  ||RR^T-I||=6.35e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Block Evaluation Relative To Clean
# ==================================================
# [nominal_eval]
# position_rmse: ratio=5.991  degradation=+499.1%
# rotation_geodesic: ratio=16.625  degradation=+1562.5%
# velocity_rmse: ratio=2.059  degradation=+105.9%
# angular_rmse: ratio=3.023  degradation=+202.3%
# failure_rate: ratio=1.000  degradation=+0.0%
# [heading_biased_eval]
# position_rmse: ratio=22.570  degradation=+2157.0%
# rotation_geodesic: ratio=71.293  degradation=+7029.3%
# velocity_rmse: ratio=3.373  degradation=+237.3%
# angular_rmse: ratio=3.020  degradation=+202.0%
# failure_rate: ratio=1.000  degradation=+0.0%
# Running held-out trajectory evaluation...
# Held-out evaluation profile: clean
# Held-out evaluation noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0002 (median 0.0002, p95 0.0003)
# Rotation geo [rad]:  0.0005 (median 0.0005, p95 0.0005)
# Lin vel RMSE [m/s]:  0.0021  Ang vel RMSE [r/s]:  0.0009
# SO(3) violation:  |det-1|=6.03e-08  ||RR^T-I||=1.18e-07
# Noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# [CHIRP] pos=0.0001 m, rot=0.0005 rad, success=1.0000
# [OU] pos=0.0002 m, rot=0.0005 rad, success=1.0000
# [PRBS] pos=0.0002 m, rot=0.0005 rad, success=1.0000
# Held-out evaluation profile: nominal_eval
# Held-out evaluation noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0011 (median 0.0011, p95 0.0014)
# Rotation geo [rad]:  0.0086 (median 0.0085, p95 0.0095)
# Lin vel RMSE [m/s]:  0.0047  Ang vel RMSE [r/s]:  0.0033
# SO(3) violation:  |det-1|=2.95e-07  ||RR^T-I||=6.28e-07
# Noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# [CHIRP] pos=0.0011 m, rot=0.0085 rad, success=1.0000
# [OU] pos=0.0011 m, rot=0.0086 rad, success=1.0000
# [PRBS] pos=0.0012 m, rot=0.0085 rad, success=1.0000
# Held-out evaluation profile: degraded_eval
# Held-out evaluation noise budget: protocol=iid_noisy_ic | profile=degraded_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0026 (median 0.0025, p95 0.0033)
# Rotation geo [rad]:  0.0209 (median 0.0208, p95 0.0233)
# Lin vel RMSE [m/s]:  0.0088  Ang vel RMSE [r/s]:  0.0062
# SO(3) violation:  |det-1|=2.95e-07  ||RR^T-I||=6.28e-07
# Noise budget: protocol=iid_noisy_ic | profile=degraded_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250]
# [CHIRP] pos=0.0025 m, rot=0.0209 rad, success=1.0000
# [OU] pos=0.0025 m, rot=0.0211 rad, success=1.0000
# [PRBS] pos=0.0027 m, rot=0.0208 rad, success=1.0000
# Held-out evaluation profile: heading_biased_eval
# Held-out evaluation noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ...
# Epoch  231 | Step  4620/ 5000 | Train 5.8275e-03 | Test 6.3232e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.98e-04 | 3.8s
# Epoch  232 | Step  4640/ 5000 | Train 5.8080e-03 | Test 6.2950e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.88e-04 | 3.8s
# Epoch  233 | Step  4660/ 5000 | Train 5.7793e-03 | Test 6.2805e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.79e-04 | 4.0s
# Epoch  234 | Step  4680/ 5000 | Train 5.7553e-03 | Test 6.2479e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.70e-04 | 3.9s
# Epoch  235 | Step  4700/ 5000 | Train 5.7359e-03 | Test 6.2341e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.61e-04 | 3.8s
# Epoch  236 | Step  4720/ 5000 | Train 5.7193e-03 | Test 6.2145e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.53e-04 | 3.9s
# Epoch  237 | Step  4740/ 5000 | Train 5.7060e-03 | Test 6.1880e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.46e-04 | 3.9s
# Epoch  238 | Step  4760/ 5000 | Train 5.6862e-03 | Test 6.1752e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.39e-04 | 3.8s
# Epoch  239 | Step  4780/ 5000 | Train 5.6795e-03 | Test 6.1671e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.33e-04 | 3.9s
# Epoch  240 | Step  4800/ 5000 | Train 5.6737e-03 | Test 6.1476e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.27e-04 | 3.9s
# Epoch  241 | Step  4820/ 5000 | Train 5.6656e-03 | Test 6.1457e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.22e-04 | 3.8s
# Epoch  242 | Step  4840/ 5000 | Train 5.6509e-03 | Test 6.1322e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.17e-04 | 3.8s
# Epoch  243 | Step  4860/ 5000 | Train 5.6444e-03 | Test 6.1128e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.13e-04 | 3.9s
# Epoch  244 | Step  4880/ 5000 | Train 5.6320e-03 | Test 6.1002e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.10e-04 | 3.9s
# Epoch  245 | Step  4900/ 5000 | Train 5.6210e-03 | Test 6.1123e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.07e-04 | 3.8s
# Epoch  246 | Step  4920/ 5000 | Train 5.6179e-03 | Test 6.0952e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.04e-04 | 3.9s
# Epoch  247 | Step  4940/ 5000 | Train 5.6120e-03 | Test 6.0780e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.02e-04 | 3.9s
# Epoch  248 | Step  4960/ 5000 | Train 5.6078e-03 | Test 6.0736e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.01e-04 | 3.9s
# Epoch  249 | Step  4980/ 5000 | Train 5.5944e-03 | Test 6.0738e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.00e-04 | 3.9s
# Epoch  250 | Step  5000/ 5000 | Train 5.5980e-03 | Test 6.0597e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.00e-04 | 3.9s
# Reached target optimizer steps: 5000/5000
# Done. Best validation score: failure_rate=0.0000, test_loss=6.0597e-03 (epoch 250)
# Running detailed evaluation...
# Block evaluation profile: clean
# Block evaluation noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0002 +/- 0.0001  (max 0.0010)
# Rotation geo [rad]:  0.0005 +/- 0.0000  (max 0.0009)
# Lin vel RMSE [m/s]:  0.0024 +/- 0.0016
# Ang vel RMSE [r/s]:  0.0012 +/- 0.0007
# Components:  u=0.0035  v=0.0008  w=0.0012  p=0.0008  q=0.0010  r=0.0012
# SO(3) violation:  |det-1|=6.22e-08  ||RR^T-I||=1.27e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# Block evaluation profile: nominal_eval
# Block evaluation noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0013 +/- 0.0008  (max 0.0078)
# Rotation geo [rad]:  0.0085 +/- 0.0060  (max 0.0449)
# Lin vel RMSE [m/s]:  0.0052 +/- 0.0023
# Ang vel RMSE [r/s]:  0.0034 +/- 0.0019
# Components:  u=0.0069  v=0.0034  w=0.0033  p=0.0050  q=0.0013  r=0.0017
# SO(3) violation:  |det-1|=2.98e-07  ||RR^T-I||=6.34e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# Block evaluation profile: heading_biased_eval
# Block evaluation noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0049 +/- 0.0016  (max 0.0104)
# Rotation geo [rad]:  0.0352 +/- 0.0099  (max 0.0653)
# Lin vel RMSE [m/s]:  0.0086 +/- 0.0039
# Ang vel RMSE [r/s]:  0.0034 +/- 0.0019
# Components:  u=0.0091  v=0.0092  w=0.0036  p=0.0050  q=0.0013  r=0.0017
# SO(3) violation:  |det-1|=2.76e-07  ||RR^T-I||=6.02e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Block Evaluation Relative To Clean
# ==================================================
# [nominal_eval]
# position_rmse: ratio=6.268  degradation=+526.8%
# rotation_geodesic: ratio=17.251  degradation=+1625.1%
# velocity_rmse: ratio=2.171  degradation=+117.1%
# angular_rmse: ratio=2.913  degradation=+191.3%
# failure_rate: ratio=1.000  degradation=+0.0%
# [heading_biased_eval]
# position_rmse: ratio=23.122  degradation=+2212.2%
# rotation_geodesic: ratio=71.333  degradation=+7033.3%
# velocity_rmse: ratio=3.582  degradation=+258.2%
# angular_rmse: ratio=2.918  degradation=+191.8%
# failure_rate: ratio=1.000  degradation=+0.0%
# Running held-out trajectory evaluation...
# Held-out evaluation profile: clean
# Held-out evaluation noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0002 (median 0.0002, p95 0.0003)
# Rotation geo [rad]:  0.0005 (median 0.0005, p95 0.0005)
# Lin vel RMSE [m/s]:  0.0021  Ang vel RMSE [r/s]:  0.0010
# SO(3) violation:  |det-1|=6.02e-08  ||RR^T-I||=1.17e-07
# Noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# [CHIRP] pos=0.0001 m, rot=0.0005 rad, success=1.0000
# [OU] pos=0.0002 m, rot=0.0005 rad, success=1.0000
# [PRBS] pos=0.0002 m, rot=0.0005 rad, success=1.0000
# Held-out evaluation profile: nominal_eval
# Held-out evaluation noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0011 (median 0.0011, p95 0.0014)
# Rotation geo [rad]:  0.0087 (median 0.0086, p95 0.0093)
# Lin vel RMSE [m/s]:  0.0047  Ang vel RMSE [r/s]:  0.0033
# SO(3) violation:  |det-1|=2.89e-07  ||RR^T-I||=6.20e-07
# Noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# [CHIRP] pos=0.0011 m, rot=0.0087 rad, success=1.0000
# [OU] pos=0.0011 m, rot=0.0086 rad, success=1.0000
# [PRBS] pos=0.0012 m, rot=0.0086 rad, success=1.0000
# Held-out evaluation profile: degraded_eval
# Held-out evaluation noise budget: protocol=iid_noisy_ic | profile=degraded_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0026 (median 0.0026, p95 0.0033)
# Rotation geo [rad]:  0.0212 (median 0.0211, p95 0.0229)
# Lin vel RMSE [m/s]:  0.0088  Ang vel RMSE [r/s]:  0.0062
# SO(3) violation:  |det-1|=2.94e-07  ||RR^T-I||=6.26e-07
# Noise budget: protocol=iid_noisy_ic | profile=degraded_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250]
# [CHIRP] pos=0.0026 m, rot=0.0213 rad, success=1.0000
# [OU] pos=0.0026 m, rot=0.0211 rad, success=1.0000
# [PRBS] pos=0.0027 m, rot=0.0211 rad, success=1.0000
# Held-out evaluation profile: heading_biased_eval
# Held-out evaluation noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0040 (median 0.0039, p95 0.0052)
# Rotation geo [rad]:  0.0353 (median 0.0352, p95 0.0366)
# Lin vel RMSE [m/s]:  0.0072  Ang vel RMSE [r/s]:  0.0033
# SO(3) violation:  |det-1|=2.91e-07  ||RR^T-I||=6.20e-07
# Noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# [CHIRP] pos=0.0039 m, rot=0.0352 rad, success=1.0000
# [OU] pos=0.0039 m, rot=0.0352 rad, success=1.0000
# [PRBS] pos=0.0042 m, rot=0.0353 rad, success=1.0000
# ==================================================
# Held-Out Evaluation Relative To Clean
# ==================================================
# [nominal_eval]
# position_rmse: ratio=6.250  degradation=+525.0%
# rotation_geodesic: ratio=17.626  degradation=+1662.6%
# velocity_rmse: ratio=2.279  degradation=+127.9%
# angular_rmse: ratio=3.287  degradation=+228.7%
# success_rate: ratio=1.000  degradation=+0.0%
# trajectory_failure_rate: ratio=1.000  degradation=+0.0%
# [degraded_eval]
# position_rmse: ratio=14.546  degradation=+1354.6%
# rotation_geodesic: ratio=43.102  degradation=+4210.2%
# velocity_rmse: ratio=4.249  degradation=+324.9%
# angular_rmse: ratio=6.214  degradation=+521.4%
# success_rate: ratio=1.000  degradation=+0.0%
# trajectory_failure_rate: ratio=1.000  degradation=+0.0%
# [heading_biased_eval]
# position_rmse: ratio=22.275  degradation=+2127.5%
# rotation_geodesic: ratio=71.786  degradation=+7078.6%
# velocity_rmse: ratio=3.483  degradation=+248.3%
# angular_rmse: ratio=3.287  degradation=+228.7%
# success_rate: ratio=1.000  degradation=+0.0%
# trajectory_failure_rate: ratio=1.000  degradation=+0.0%
#
# Training finished. Results: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed46
# Training sweep complete.
# Manifest: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/runs.tsv
# Next step:
#   scripts/batch_eval_models.sh --suite-dir "/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox"
#
# Training complete.
# Suite directory: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox
# Next step:
#   bash scripts/eval_all_models_noise_profile.sh --suite-dir "/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox"
# [audit] /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox
#                                                      suite_name    group            model_type  seed train_noise_protocol  best_epoch  best_loss  noise_warmup_epochs  noise_ramp_epochs  noise_mix_ratio  epoch_scale_at_best  is_effectively_clean_at_best
# sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox baseline se3_momentum_blackbox    42                clean         249   0.005580                   20                 80              0.5                  0.0                          True
# sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox baseline se3_momentum_blackbox    43                clean         250   0.005484                   20                 80              0.5                  0.0                          True
# sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox baseline se3_momentum_blackbox    44                clean         250   0.006357                   20                 80              0.5                  0.0                          True
# sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox baseline se3_momentum_blackbox    45                clean         250   0.007581                   20                 80              0.5                  0.0                          True
# sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox baseline se3_momentum_blackbox    46                clean         250   0.006060                   20                 80              0.5                  0.0                          True
# [validate_v4] skipped: v4lite not in PHASE1A_PROTOCOLS=clean

# %% [markdown]
# ## 4. Decision rollout eval (clean suite x 4 robustness profiles)
# Evaluates the clean-trained suite across `clean nominal_eval degraded_eval heading_biased_eval` (iid eval protocol) plus the `v4_lite` eval at `nominal_eval`.

# %%
os.environ["MODE"] = "decision_eval"
# !bash scripts/run_phase1a_oc_v4lite.sh
# Out:
# [phase1a]
# MODE=decision_eval
# RUN_TAG=t2_wpfrag_se3_momentum_blackbox
# DATASET=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# DEVICE=cuda
# PHASE1A_MODELS=se3_momentum_blackbox
# PHASE1A_PROTOCOLS=clean
# SMOKE1_MODELS=se3_momentum_blackbox
# SMOKE_SEEDS=42
# DECISION_SEEDS=42 43 44 45 46
# NOISE_REFERENCE=remus100_dr
# PHASE1A_LOG_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_logs/t2_wpfrag_se3_momentum_blackbox
# PHASE1A_METADATA_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_metadata_t2_wpfrag_se3_momentum_blackbox
# [eval] suite=sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox eval_protocol=iid_noisy_ic profiles=clean nominal_eval degraded_eval heading_biased_eval
# Suite directory: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox
# Manifest: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/runs.tsv
# Mode: resampled
# [eval] baseline_se3_momentum_blackbox_seed42
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=clean | noise_protocol=clean | noise_budget=protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000] | scenarios=PRBS,CHIRP,OU | trajectories=90 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_133241/clean
# [scenario 1/3] PRBS | 30 trajectories
# [1/90] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=5h08m06.9s
# [5/90] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=58m51.4s
# [10/90] PRBS seed=51 done | reason=completed | sim_time=60.00s | eta=27m42.0s
# [15/90] PRBS seed=56 done | reason=completed | sim_time=60.00s | eta=17m18.8s
# [20/90] PRBS seed=61 done | reason=completed | sim_time=60.00s | eta=12m07.2s
# [25/90] PRBS seed=66 done | reason=completed | sim_time=60.00s | eta=9m00.3s
# [30/90] PRBS seed=71 done | reason=completed | sim_time=60.00s | eta=6m55.6s
# [scenario done] PRBS | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=1.2060 m | pos_p95=2.9982 m | rot_med=0.0256 rad | completion=1.000 | elapsed=3m27.8s
# [scenario 2/3] CHIRP | 30 trajectories
# [31/90] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=13m11.6s
# [35/90] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=10m53.6s
# [40/90] CHIRP seed=100051 done | reason=completed | sim_time=60.00s | eta=8m39.9s
# [45/90] CHIRP seed=100056 done | reason=completed | sim_time=60.00s | eta=6m56.0s
# [50/90] CHIRP seed=100061 done | reason=completed | sim_time=60.00s | eta=5m32.8s
# [55/90] CHIRP seed=100066 done | reason=completed | sim_time=60.00s | eta=4m24.7s
# [60/90] CHIRP seed=100071 done | reason=completed | sim_time=60.00s | eta=3m28.0s
# [scenario done] CHIRP | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=1.4826 m | pos_p95=2.5763 m | rot_med=0.0323 rad | completion=1.000 | elapsed=6m56.0s
# [scenario 3/3] OU | 30 trajectories
# [61/90] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=4m57.4s
# [65/90] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=4m00.6s
# [70/90] OU seed=200051 done | reason=completed | sim_time=60.00s | eta=2m58.7s
# [75/90] OU seed=200056 done | reason=completed | sim_time=60.00s | eta=2m05.1s
# [80/90] OU seed=200061 done | reason=completed | sim_time=60.00s | eta=1m18.2s
# [85/90] OU seed=200066 done | reason=pred_divergence | sim_time=58.75s | eta=36.8s
# [90/90] OU seed=200071 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=29/30 | gt_div=0 | model_fail=1 | H=60.0s cond_n=29/30 | pos_med=1.8239 m | pos_p95=4.0956 m | rot_med=0.0372 rad | completion=0.967 | elapsed=10m25.7s
# Benchmark finished in 10m44.3s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_133241/clean
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: SE(3) Momentum Black-Box [baseline/core]
# Canonical model type: se3_momentum_blackbox
# Energy semantics: not_comparable
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 30
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.1430 m | pos p95=0.3670 m | rot median=0.0128 rad | total vel median=0.0148 m/s | rel vel median=0.0135 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=0.4944 m | pos p95=1.1720 m | rot median=0.0182 rad | total vel median=0.0172 m/s | rel vel median=0.0162 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=1.4476 m | pos p95=3.3868 m | rot median=0.0328 rad | total vel median=0.0222 m/s | rel vel median=0.0197 m/s | cond_n=89/90 | completion=0.989 | gt_fail_by_h=0.000 | model_fail_by_h=0.011
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=90 | completed=89 (0.989) | gt_divergence=0 (0.000) | pred_divergence=1 (0.011) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1423 m | pos p95=0.3334 m | rot median=0.0118 rad | total vel median=0.0262 m/s | rel vel median=0.0236 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.5041 m | pos p95=1.0080 m | rot median=0.0175 rad | total vel median=0.0229 m/s | rel vel median=0.0239 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.2060 m | pos p95=2.9982 m | rot median=0.0256 rad | total vel median=0.0256 m/s | rel vel median=0.0211 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1021 m | pos p95=0.2106 m | rot median=0.0112 rad | total vel median=0.0078 m/s | rel vel median=0.0071 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.3910 m | pos p95=1.0309 m | rot median=0.0177 rad | total vel median=0.0092 m/s | rel vel median=0.0079 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.4826 m | pos p95=2.5763 m | rot median=0.0323 rad | total vel median=0.0099 m/s | rel vel median=0.0078 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=30 | completed=29 (0.967) | gt_divergence=0 (0.000) | pred_divergence=1 (0.033) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.2051 m | pos p95=0.3993 m | rot median=0.0191 rad | total vel median=0.0162 m/s | rel vel median=0.0164 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.6307 m | pos p95=1.6334 m | rot median=0.0248 rad | total vel median=0.0255 m/s | rel vel median=0.0238 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.8239 m | pos p95=4.0956 m | rot median=0.0372 rad | total vel median=0.0334 m/s | rel vel median=0.0318 m/s | cond_n=29/30 | completion=0.967 | gt_fail_by_h=0.000 | model_fail_by_h=0.033
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Earliest rollout failures
#   OU seed=200066 | reason=pred_divergence | sim_time=58.75s | pos=nan m | rot=nan rad | total_vel_violation=0
#
# Largest completed terminal errors
#   OU seed=200068 | reason=completed | sim_time=60.00s | pos=8.4008 m | rot=0.1239 rad | total_vel_violation=0
#   OU seed=200049 | reason=completed | sim_time=60.00s | pos=4.2633 m | rot=0.0770 rad | total_vel_violation=0
#   PRBS seed=46 | reason=completed | sim_time=60.00s | pos=4.0715 m | rot=0.0751 rad | total_vel_violation=0
#   OU seed=200061 | reason=completed | sim_time=60.00s | pos=3.8440 m | rot=0.0168 rad | total_vel_violation=1
#   PRBS seed=43 | reason=completed | sim_time=60.00s | pos=3.5821 m | rot=0.0732 rad | total_vel_violation=0
#
# Completed rollouts with velocity violations
#   OU seed=200061 | reason=completed | sim_time=60.00s | pos=3.8440 m | rot=0.0168 rad | total_vel_violation=1
#   OU seed=200055 | reason=completed | sim_time=60.00s | pos=2.7579 m | rot=0.0612 rad | total_vel_violation=1
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# OU seed=200066 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_133241/clean/diagnostic_plots/rollout_failure_OU_seed200066.png
# OU seed=200061 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_133241/clean/diagnostic_plots/velocity_violation_OU_seed200061.png
# OU seed=200055 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_133241/clean/diagnostic_plots/velocity_violation_OU_seed200055.png
# OU seed=200068 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_133241/clean/diagnostic_plots/high_terminal_error_OU_seed200068.png
# OU seed=200049 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_133241/clean/diagnostic_plots/high_terminal_error_OU_seed200049.png
# PRBS seed=46 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_133241/clean/diagnostic_plots/high_terminal_error_PRBS_seed46.png
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=nominal_eval | noise_protocol=iid_noisy_ic | noise_budget=protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | scenarios=PRBS,CHIRP,OU | trajectories=90 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_133241/nominal_eval
# [scenario 1/3] PRBS | 30 trajectories
# [1/90] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=15m35.4s
# [5/90] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=2m58.9s
# [10/90] PRBS seed=51 done | reason=completed | sim_time=60.00s | eta=1m24.3s
# [15/90] PRBS seed=56 done | reason=completed | sim_time=60.00s | eta=52.8s
# [20/90] PRBS seed=61 done | reason=completed | sim_time=60.00s | eta=37.0s
# [25/90] PRBS seed=66 done | reason=completed | sim_time=60.00s | eta=27.6s
# [30/90] PRBS seed=71 done | reason=completed | sim_time=60.00s | eta=21.2s
# [scenario done] PRBS | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=1.1881 m | pos_p95=4.6503 m | rot_med=0.0252 rad | completion=1.000 | elapsed=10.6s
# [scenario 2/3] CHIRP | 30 trajectories
# [31/90] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=40.2s
# [35/90] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=33.2s
# [40/90] CHIRP seed=100051 done | reason=completed | sim_time=60.00s | eta=26.4s
# [45/90] CHIRP seed=100056 done | reason=completed | sim_time=60.00s | eta=21.2s
# [50/90] CHIRP seed=100061 done | reason=completed | sim_time=60.00s | eta=16.9s
# [55/90] CHIRP seed=100066 done | reason=completed | sim_time=60.00s | eta=13.5s
# [60/90] CHIRP seed=100071 done | reason=completed | sim_time=60.00s | eta=10.6s
# [scenario done] CHIRP | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=1.8256 m | pos_p95=2.6792 m | rot_med=0.0304 rad | completion=1.000 | elapsed=21.2s
# [scenario 3/3] OU | 30 trajectories
# [61/90] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=15.1s
# [65/90] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=12.2s
# [70/90] OU seed=200051 done | reason=completed | sim_time=60.00s | eta=9.1s
# [75/90] OU seed=200056 done | reason=completed | sim_time=60.00s | eta=6.3s
# [80/90] OU seed=200061 done | reason=completed | sim_time=60.00s | eta=4.0s
# [85/90] OU seed=200066 done | reason=pred_divergence | sim_time=58.75s | eta=1.9s
# [90/90] OU seed=200071 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=29/30 | gt_div=0 | model_fail=1 | H=60.0s cond_n=29/30 | pos_med=1.7952 m | pos_p95=4.5791 m | rot_med=0.0513 rad | completion=0.967 | elapsed=31.8s
# Benchmark finished in 49.7s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_133241/nominal_eval
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: SE(3) Momentum Black-Box [baseline/core]
# Canonical model type: se3_momentum_blackbox
# Energy semantics: not_comparable
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 30
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.2129 m | pos p95=0.4920 m | rot median=0.0169 rad | total vel median=0.0149 m/s | rel vel median=0.0135 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=0.6758 m | pos p95=1.8103 m | rot median=0.0211 rad | total vel median=0.0179 m/s | rel vel median=0.0161 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=1.4870 m | pos p95=4.4625 m | rot median=0.0311 rad | total vel median=0.0238 m/s | rel vel median=0.0197 m/s | cond_n=89/90 | completion=0.989 | gt_fail_by_h=0.000 | model_fail_by_h=0.011
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=90 | completed=89 (0.989) | gt_divergence=0 (0.000) | pred_divergence=1 (0.011) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.2160 m | pos p95=0.3933 m | rot median=0.0174 rad | total vel median=0.0259 m/s | rel vel median=0.0236 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.5882 m | pos p95=1.8509 m | rot median=0.0189 rad | total vel median=0.0234 m/s | rel vel median=0.0242 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.1881 m | pos p95=4.6503 m | rot median=0.0252 rad | total vel median=0.0264 m/s | rel vel median=0.0211 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1668 m | pos p95=0.3729 m | rot median=0.0158 rad | total vel median=0.0086 m/s | rel vel median=0.0072 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.6974 m | pos p95=1.0571 m | rot median=0.0203 rad | total vel median=0.0095 m/s | rel vel median=0.0080 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.8256 m | pos p95=2.6792 m | rot median=0.0304 rad | total vel median=0.0107 m/s | rel vel median=0.0079 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=30 | completed=29 (0.967) | gt_divergence=0 (0.000) | pred_divergence=1 (0.033) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.2388 m | pos p95=0.6177 m | rot median=0.0214 rad | total vel median=0.0181 m/s | rel vel median=0.0163 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.7534 m | pos p95=1.8455 m | rot median=0.0258 rad | total vel median=0.0259 m/s | rel vel median=0.0238 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.7952 m | pos p95=4.5791 m | rot median=0.0513 rad | total vel median=0.0349 m/s | rel vel median=0.0318 m/s | cond_n=29/30 | completion=0.967 | gt_fail_by_h=0.000 | model_fail_by_h=0.033
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Earliest rollout failures
#   OU seed=200066 | reason=pred_divergence | sim_time=58.75s | pos=nan m | rot=nan rad | total_vel_violation=0
#
# Largest completed terminal errors
#   OU seed=200068 | reason=completed | sim_time=60.00s | pos=8.1336 m | rot=0.1209 rad | total_vel_violation=0
#   PRBS seed=46 | reason=completed | sim_time=60.00s | pos=5.4625 m | rot=0.0879 rad | total_vel_violation=0
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=4.8527 m | rot=0.0600 rad | total_vel_violation=0
#   OU seed=200059 | reason=completed | sim_time=60.00s | pos=4.6304 m | rot=0.0581 rad | total_vel_violation=0
#   OU seed=200071 | reason=completed | sim_time=60.00s | pos=4.5022 m | rot=0.0655 rad | total_vel_violation=0
#
# Completed rollouts with velocity violations
#   OU seed=200061 | reason=completed | sim_time=60.00s | pos=3.4292 m | rot=0.0119 rad | total_vel_violation=1
#   OU seed=200055 | reason=completed | sim_time=60.00s | pos=1.7358 m | rot=0.0513 rad | total_vel_violation=1
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# OU seed=200066 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_133241/nominal_eval/diagnostic_plots/rollout_failure_OU_seed200066.png
# OU seed=200061 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_133241/nominal_eval/diagnostic_plots/velocity_violation_OU_seed200061.png
# OU seed=200055 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_133241/nominal_eval/diagnostic_plots/velocity_violation_OU_seed200055.png
# OU seed=200068 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_133241/nominal_eval/diagnostic_plots/high_terminal_error_OU_seed200068.png
# PRBS seed=46 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_133241/nominal_eval/diagnostic_plots/high_terminal_error_PRBS_seed46.png
# PRBS seed=42 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_133241/nominal_eval/diagnostic_plots/high_terminal_error_PRBS_seed42.png
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=degraded_eval | noise_protocol=iid_noisy_ic | noise_budget=protocol=iid_noisy_ic | profile=degraded_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250] | scenarios=PRBS,CHIRP,OU | trajectories=90 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_133241/degraded_eval
# [scenario 1/3] PRBS | 30 trajectories
# [1/90] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=15m23.8s
# [5/90] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=2m56.7s
# [10/90] PRBS seed=51 done | reason=completed | sim_time=60.00s | eta=1m23.3s
# [15/90] PRBS seed=56 done | reason=completed | sim_time=60.00s | eta=52.2s
# [20/90] PRBS seed=61 done | reason=completed | sim_time=60.00s | eta=36.6s
# [25/90] PRBS seed=66 done | reason=completed | sim_time=60.00s | eta=27.2s
# [30/90] PRBS seed=71 done | reason=completed | sim_time=60.00s | eta=21.0s
# [scenario done] PRBS | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=2.0228 m | pos_p95=7.2537 m | rot_med=0.0252 rad | completion=1.000 | elapsed=10.5s
# [scenario 2/3] CHIRP | 30 trajectories
# [31/90] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=39.8s
# [35/90] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=32.8s
# [40/90] CHIRP seed=100051 done | reason=completed | sim_time=60.00s | eta=26.2s
# [45/90] CHIRP seed=100056 done | reason=completed | sim_time=60.00s | eta=20.9s
# [50/90] CHIRP seed=100061 done | reason=completed | sim_time=60.00s | eta=16.8s
# [55/90] CHIRP seed=100066 done | reason=completed | sim_time=60.00s | eta=13.3s
# [60/90] CHIRP seed=100071 done | reason=completed | sim_time=60.00s | eta=10.5s
# [scenario done] CHIRP | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=2.0958 m | pos_p95=4.4040 m | rot_med=0.0342 rad | completion=1.000 | elapsed=21.0s
# [scenario 3/3] OU | 30 trajectories
# [61/90] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=15.0s
# [65/90] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=12.1s
# [70/90] OU seed=200051 done | reason=completed | sim_time=60.00s | eta=9.0s
# [75/90] OU seed=200056 done | reason=completed | sim_time=60.00s | eta=6.3s
# [80/90] OU seed=200061 done | reason=completed | sim_time=60.00s | eta=3.9s
# [85/90] OU seed=200066 done | reason=pred_divergence | sim_time=58.75s | eta=1.9s
# [90/90] OU seed=200071 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=29/30 | gt_div=0 | model_fail=1 | H=60.0s cond_n=29/30 | pos_med=2.0850 m | pos_p95=7.1575 m | rot_med=0.0500 rad | completion=0.967 | elapsed=31.7s
# Benchmark finished in 49.5s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_133241/degraded_eval
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: SE(3) Momentum Black-Box [baseline/core]
# Canonical model type: se3_momentum_blackbox
# Energy semantics: not_comparable
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 30
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.3374 m | pos p95=1.0035 m | rot median=0.0280 rad | total vel median=0.0181 m/s | rel vel median=0.0135 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=0.9708 m | pos p95=2.9542 m | rot median=0.0273 rad | total vel median=0.0189 m/s | rel vel median=0.0158 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=2.0850 m | pos p95=6.8722 m | rot median=0.0398 rad | total vel median=0.0234 m/s | rel vel median=0.0197 m/s | cond_n=89/90 | completion=0.989 | gt_fail_by_h=0.000 | model_fail_by_h=0.011
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=90 | completed=89 (0.989) | gt_divergence=0 (0.000) | pred_divergence=1 (0.011) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.3374 m | pos p95=0.9071 m | rot median=0.0306 rad | total vel median=0.0297 m/s | rel vel median=0.0235 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.9332 m | pos p95=3.1202 m | rot median=0.0257 rad | total vel median=0.0256 m/s | rel vel median=0.0246 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=2.0228 m | pos p95=7.2537 m | rot median=0.0252 rad | total vel median=0.0267 m/s | rel vel median=0.0211 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.2776 m | pos p95=0.8467 m | rot median=0.0235 rad | total vel median=0.0093 m/s | rel vel median=0.0073 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.9160 m | pos p95=2.0876 m | rot median=0.0267 rad | total vel median=0.0120 m/s | rel vel median=0.0080 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=2.0958 m | pos p95=4.4040 m | rot median=0.0342 rad | total vel median=0.0134 m/s | rel vel median=0.0079 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=30 | completed=29 (0.967) | gt_divergence=0 (0.000) | pred_divergence=1 (0.033) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.4023 m | pos p95=1.0820 m | rot median=0.0289 rad | total vel median=0.0227 m/s | rel vel median=0.0162 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.2250 m | pos p95=3.1227 m | rot median=0.0287 rad | total vel median=0.0256 m/s | rel vel median=0.0238 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=2.0850 m | pos p95=7.1575 m | rot median=0.0500 rad | total vel median=0.0325 m/s | rel vel median=0.0317 m/s | cond_n=29/30 | completion=0.967 | gt_fail_by_h=0.000 | model_fail_by_h=0.033
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Earliest rollout failures
#   OU seed=200066 | reason=pred_divergence | sim_time=58.75s | pos=nan m | rot=nan rad | total_vel_violation=0
#
# Largest completed terminal errors
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=8.7693 m | rot=0.0894 rad | total_vel_violation=0
#   OU seed=200068 | reason=completed | sim_time=60.00s | pos=7.6750 m | rot=0.1159 rad | total_vel_violation=0
#   PRBS seed=46 | reason=completed | sim_time=60.00s | pos=7.5012 m | rot=0.1066 rad | total_vel_violation=0
#   OU seed=200059 | reason=completed | sim_time=60.00s | pos=7.4268 m | rot=0.0866 rad | total_vel_violation=0
#   PRBS seed=62 | reason=completed | sim_time=60.00s | pos=6.9513 m | rot=0.0528 rad | total_vel_violation=0
#
# Completed rollouts with velocity violations
#   OU seed=200061 | reason=completed | sim_time=60.00s | pos=2.8183 m | rot=0.0048 rad | total_vel_violation=1
#   OU seed=200055 | reason=completed | sim_time=60.00s | pos=0.4338 m | rot=0.0389 rad | total_vel_violation=1
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# OU seed=200066 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_133241/degraded_eval/diagnostic_plots/rollout_failure_OU_seed200066.png
# OU seed=200061 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_133241/degraded_eval/diagnostic_plots/velocity_violation_OU_seed200061.png
# OU seed=200055 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_133241/degraded_eval/diagnostic_plots/velocity_violation_OU_seed200055.png
# PRBS seed=42 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_133241/degraded_eval/diagnostic_plots/high_terminal_error_PRBS_seed42.png
# OU seed=200068 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_133241/degraded_eval/diagnostic_plots/high_terminal_error_OU_seed200068.png
# PRBS seed=46 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_133241/degraded_eval/diagnostic_plots/high_terminal_error_PRBS_seed46.png
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=heading_biased_eval | noise_protocol=iid_noisy_ic | noise_budget=protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350] | scenarios=PRBS,CHIRP,OU | trajectories=90 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_133241/heading_biased_eval
# [scenario 1/3] PRBS | 30 trajectories
# [1/90] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=15m24.5s
# [5/90] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=2m56.8s
# [10/90] PRBS seed=51 done | reason=completed | sim_time=60.00s | eta=1m23.3s
# [15/90] PRBS seed=56 done | reason=completed | sim_time=60.00s | eta=52.2s
# [20/90] PRBS seed=61 done | reason=completed | sim_time=60.00s | eta=36.6s
# [25/90] PRBS seed=66 done | reason=completed | sim_time=60.00s | eta=27.2s
# [30/90] PRBS seed=71 done | reason=completed | sim_time=60.00s | eta=21.0s
# [scenario done] PRBS | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=2.9986 m | pos_p95=6.5299 m | rot_med=0.0359 rad | completion=1.000 | elapsed=10.5s
# [scenario 2/3] CHIRP | 30 trajectories
# [31/90] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=39.5s
# [35/90] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=32.6s
# [40/90] CHIRP seed=100051 done | reason=completed | sim_time=60.00s | eta=26.0s
# [45/90] CHIRP seed=100056 done | reason=completed | sim_time=60.00s | eta=20.8s
# [50/90] CHIRP seed=100061 done | reason=completed | sim_time=60.00s | eta=16.6s
# [55/90] CHIRP seed=100066 done | reason=completed | sim_time=60.00s | eta=13.2s
# [60/90] CHIRP seed=100071 done | reason=completed | sim_time=60.00s | eta=10.4s
# [scenario done] CHIRP | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=2.6494 m | pos_p95=5.6105 m | rot_med=0.0444 rad | completion=1.000 | elapsed=20.9s
# [scenario 3/3] OU | 30 trajectories
# [61/90] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=14.8s
# [65/90] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=12.0s
# [70/90] OU seed=200051 done | reason=completed | sim_time=60.00s | eta=8.9s
# [75/90] OU seed=200056 done | reason=completed | sim_time=60.00s | eta=6.2s
# [80/90] OU seed=200061 done | reason=completed | sim_time=60.00s | eta=3.9s
# [85/90] OU seed=200066 done | reason=pred_divergence | sim_time=58.75s | eta=1.8s
# [90/90] OU seed=200071 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=29/30 | gt_div=0 | model_fail=1 | H=60.0s cond_n=29/30 | pos_med=3.5222 m | pos_p95=7.5307 m | rot_med=0.0625 rad | completion=0.967 | elapsed=31.2s
# Benchmark finished in 49.0s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_133241/heading_biased_eval
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: SE(3) Momentum Black-Box [baseline/core]
# Canonical model type: se3_momentum_blackbox
# Energy semantics: not_comparable
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 30
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.5205 m | pos p95=0.9586 m | rot median=0.0376 rad | total vel median=0.0183 m/s | rel vel median=0.0136 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=1.6047 m | pos p95=2.9344 m | rot median=0.0373 rad | total vel median=0.0205 m/s | rel vel median=0.0159 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=3.1442 m | pos p95=6.6660 m | rot median=0.0482 rad | total vel median=0.0240 m/s | rel vel median=0.0197 m/s | cond_n=89/90 | completion=0.989 | gt_fail_by_h=0.000 | model_fail_by_h=0.011
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=90 | completed=89 (0.989) | gt_divergence=0 (0.000) | pred_divergence=1 (0.011) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.4419 m | pos p95=0.9072 m | rot median=0.0369 rad | total vel median=0.0271 m/s | rel vel median=0.0235 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.5400 m | pos p95=3.1155 m | rot median=0.0345 rad | total vel median=0.0251 m/s | rel vel median=0.0238 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=2.9986 m | pos p95=6.5299 m | rot median=0.0359 rad | total vel median=0.0267 m/s | rel vel median=0.0212 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.5228 m | pos p95=0.7477 m | rot median=0.0312 rad | total vel median=0.0114 m/s | rel vel median=0.0072 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.4217 m | pos p95=2.4700 m | rot median=0.0325 rad | total vel median=0.0111 m/s | rel vel median=0.0080 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=2.6494 m | pos p95=5.6105 m | rot median=0.0444 rad | total vel median=0.0128 m/s | rel vel median=0.0080 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=30 | completed=29 (0.967) | gt_divergence=0 (0.000) | pred_divergence=1 (0.033) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.5771 m | pos p95=1.1738 m | rot median=0.0412 rad | total vel median=0.0265 m/s | rel vel median=0.0161 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.8000 m | pos p95=3.1019 m | rot median=0.0506 rad | total vel median=0.0267 m/s | rel vel median=0.0238 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=3.5222 m | pos p95=7.5307 m | rot median=0.0625 rad | total vel median=0.0365 m/s | rel vel median=0.0319 m/s | cond_n=29/30 | completion=0.967 | gt_fail_by_h=0.000 | model_fail_by_h=0.033
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Earliest rollout failures
#   OU seed=200066 | reason=pred_divergence | sim_time=58.75s | pos=nan m | rot=nan rad | total_vel_violation=0
#
# Largest completed terminal errors
#   OU seed=200068 | reason=completed | sim_time=60.00s | pos=11.2127 m | rot=0.1542 rad | total_vel_violation=0
#   PRBS seed=43 | reason=completed | sim_time=60.00s | pos=7.7135 m | rot=0.1165 rad | total_vel_violation=0
#   OU seed=200060 | reason=completed | sim_time=60.00s | pos=7.5698 m | rot=0.0614 rad | total_vel_violation=0
#   OU seed=200071 | reason=completed | sim_time=60.00s | pos=7.4719 m | rot=0.1014 rad | total_vel_violation=0
#   PRBS seed=62 | reason=completed | sim_time=60.00s | pos=7.1897 m | rot=0.0549 rad | total_vel_violation=0
#
# Completed rollouts with velocity violations
#   OU seed=200061 | reason=completed | sim_time=60.00s | pos=1.2594 m | rot=0.0234 rad | total_vel_violation=1
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# OU seed=200066 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_133241/heading_biased_eval/diagnostic_plots/rollout_failure_OU_seed200066.png
# OU seed=200061 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_133241/heading_biased_eval/diagnostic_plots/velocity_violation_OU_seed200061.png
# OU seed=200068 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_133241/heading_biased_eval/diagnostic_plots/high_terminal_error_OU_seed200068.png
# PRBS seed=43 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_133241/heading_biased_eval/diagnostic_plots/high_terminal_error_PRBS_seed43.png
# OU seed=200060 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_133241/heading_biased_eval/diagnostic_plots/high_terminal_error_OU_seed200060.png
# OU seed=200071 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed42/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_133241/heading_biased_eval/diagnostic_plots/high_terminal_error_OU_seed200071.png
# [eval] baseline_se3_momentum_blackbox_seed43
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed43/best_model.pt | device=cuda | mode=resampled | noise_profile=clean | noise_protocol=clean | noise_budget=protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000] | scenarios=PRBS,CHIRP,OU | trajectories=90 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed43/rollout_benchmark/phase1a_iideval_traj30_seed42_20260525_134557/clean
# [scenario 1/3] PRBS | 30 trajectories
# [1/90] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=5h11m10.3s
# [5/90] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=59m26.5s
# [10/90] PRBS seed=51 done | reason=completed | sim_time=60.00s | eta=27m58.5s
# [15/90] PRBS seed=56 done | reason=completed | sim_time=60.00s | eta=17m29.1s
# [20/90] PRBS seed=61 done | reason=completed | sim_time=60.00s | eta=12m14.5s
# [25/90] PRBS seed=66 done | reason=completed | sim_time=60.00s | eta=9m05.6s
# [30/90] PRBS seed=71 done | reason=completed | sim_time=60.00s | eta=6m59.8s
# [scenario done] PRBS | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=0.7818 m | pos_p95=2.3238 m | rot_med=0.0155 rad | completion=1.000 | elapsed=3m29.9s
# [scenario 2/3] CHIRP | 30 trajectories
# [31/90] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=13m19.0s
# [35/90] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=10m59.7s
# [40/90] CHIRP seed=100051 done | reason=completed | sim_time=60.00s | eta=8m44.8s
# ...
#   H=10.0s | pos median=0.1965 m | pos p95=0.4048 m | rot median=0.0248 rad | total vel median=0.0140 m/s | rel vel median=0.0124 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.7913 m | pos p95=2.1716 m | rot median=0.0330 rad | total vel median=0.0203 m/s | rel vel median=0.0145 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.8737 m | pos p95=4.1479 m | rot median=0.0273 rad | total vel median=0.0145 m/s | rel vel median=0.0133 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=30 | completed=28 (0.933) | gt_divergence=0 (0.000) | pred_divergence=2 (0.067) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.3208 m | pos p95=0.7318 m | rot median=0.0313 rad | total vel median=0.0198 m/s | rel vel median=0.0200 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.9848 m | pos p95=2.3260 m | rot median=0.0423 rad | total vel median=0.0259 m/s | rel vel median=0.0264 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=2.4928 m | pos p95=5.7173 m | rot median=0.0680 rad | total vel median=0.0375 m/s | rel vel median=0.0315 m/s | cond_n=28/30 | completion=0.933 | gt_fail_by_h=0.000 | model_fail_by_h=0.067
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Earliest rollout failures
#   OU seed=200051 | reason=pred_divergence | sim_time=42.35s | pos=nan m | rot=nan rad | total_vel_violation=0
#   OU seed=200066 | reason=pred_divergence | sim_time=59.35s | pos=nan m | rot=nan rad | total_vel_violation=0
#
# Largest completed terminal errors
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=7.7253 m | rot=0.1375 rad | total_vel_violation=0
#   OU seed=200068 | reason=completed | sim_time=60.00s | pos=7.4711 m | rot=0.1095 rad | total_vel_violation=1
#   OU seed=200045 | reason=completed | sim_time=60.00s | pos=5.8035 m | rot=0.0975 rad | total_vel_violation=0
#   CHIRP seed=100061 | reason=completed | sim_time=60.00s | pos=5.6236 m | rot=0.0308 rad | total_vel_violation=0
#   PRBS seed=66 | reason=completed | sim_time=60.00s | pos=5.5783 m | rot=0.0515 rad | total_vel_violation=0
#
# Completed rollouts with velocity violations
#   OU seed=200068 | reason=completed | sim_time=60.00s | pos=7.4711 m | rot=0.1095 rad | total_vel_violation=1
#   OU seed=200061 | reason=completed | sim_time=60.00s | pos=4.5346 m | rot=0.0418 rad | total_vel_violation=1
#   OU seed=200055 | reason=completed | sim_time=60.00s | pos=2.8115 m | rot=0.0532 rad | total_vel_violation=1
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# OU seed=200051 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed45/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260525_144212/diagnostic_plots/rollout_failure_OU_seed200051.png
# OU seed=200066 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed45/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260525_144212/diagnostic_plots/rollout_failure_OU_seed200066.png
# OU seed=200068 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed45/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260525_144212/diagnostic_plots/velocity_violation_OU_seed200068.png
# OU seed=200061 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed45/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260525_144212/diagnostic_plots/velocity_violation_OU_seed200061.png
# OU seed=200055 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed45/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260525_144212/diagnostic_plots/velocity_violation_OU_seed200055.png
# PRBS seed=42 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed45/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260525_144212/diagnostic_plots/high_terminal_error_PRBS_seed42.png
# [eval] baseline_se3_momentum_blackbox_seed46
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed46/best_model.pt | device=cuda | mode=resampled | noise_profile=nominal_eval | noise_protocol=v4_lite | noise_budget=protocol=v4_lite | profile=nominal_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | scenarios=PRBS,CHIRP,OU | trajectories=90 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260525_144306
# [scenario 1/3] PRBS | 30 trajectories
# [1/90] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=16m10.8s
# [5/90] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=3m05.6s
# [10/90] PRBS seed=51 done | reason=completed | sim_time=60.00s | eta=1m27.5s
# [15/90] PRBS seed=56 done | reason=completed | sim_time=60.00s | eta=54.8s
# [20/90] PRBS seed=61 done | reason=completed | sim_time=60.00s | eta=38.4s
# [25/90] PRBS seed=66 done | reason=completed | sim_time=60.00s | eta=28.6s
# [30/90] PRBS seed=71 done | reason=completed | sim_time=60.00s | eta=22.0s
# [scenario done] PRBS | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=1.0769 m | pos_p95=4.3748 m | rot_med=0.0196 rad | completion=1.000 | elapsed=11.0s
# [scenario 2/3] CHIRP | 30 trajectories
# [31/90] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=41.0s
# [35/90] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=33.9s
# [40/90] CHIRP seed=100051 done | reason=completed | sim_time=60.00s | eta=27.0s
# [45/90] CHIRP seed=100056 done | reason=completed | sim_time=60.00s | eta=21.6s
# [50/90] CHIRP seed=100061 done | reason=completed | sim_time=60.00s | eta=17.3s
# [55/90] CHIRP seed=100066 done | reason=completed | sim_time=60.00s | eta=13.8s
# [60/90] CHIRP seed=100071 done | reason=completed | sim_time=60.00s | eta=10.8s
# [scenario done] CHIRP | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=1.2277 m | pos_p95=3.2115 m | rot_med=0.0288 rad | completion=1.000 | elapsed=21.7s
# [scenario 3/3] OU | 30 trajectories
# [61/90] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=15.3s
# [65/90] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=12.4s
# [70/90] OU seed=200051 done | reason=pred_divergence | sim_time=43.35s | eta=9.2s
# [75/90] OU seed=200056 done | reason=completed | sim_time=60.00s | eta=6.4s
# [80/90] OU seed=200061 done | reason=completed | sim_time=60.00s | eta=4.0s
# [85/90] OU seed=200066 done | reason=pred_divergence | sim_time=58.95s | eta=1.9s
# [90/90] OU seed=200071 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=28/30 | gt_div=0 | model_fail=2 | H=60.0s cond_n=28/30 | pos_med=1.7748 m | pos_p95=4.2559 m | rot_med=0.0498 rad | completion=0.933 | elapsed=32.3s
# Benchmark finished in 50.9s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260525_144306
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed46/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: SE(3) Momentum Black-Box [baseline/core]
# Canonical model type: se3_momentum_blackbox
# Energy semantics: not_comparable
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 30
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.1953 m | pos p95=0.4139 m | rot median=0.0182 rad | total vel median=0.0185 m/s | rel vel median=0.0172 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=0.6238 m | pos p95=1.5451 m | rot median=0.0224 rad | total vel median=0.0204 m/s | rel vel median=0.0203 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=1.3277 m | pos p95=4.1315 m | rot median=0.0333 rad | total vel median=0.0216 m/s | rel vel median=0.0186 m/s | cond_n=88/90 | completion=0.978 | gt_fail_by_h=0.000 | model_fail_by_h=0.022
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=90 | completed=88 (0.978) | gt_divergence=0 (0.000) | pred_divergence=2 (0.022) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1755 m | pos p95=0.3528 m | rot median=0.0122 rad | total vel median=0.0264 m/s | rel vel median=0.0229 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.5100 m | pos p95=1.6517 m | rot median=0.0191 rad | total vel median=0.0244 m/s | rel vel median=0.0215 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.0769 m | pos p95=4.3748 m | rot median=0.0196 rad | total vel median=0.0235 m/s | rel vel median=0.0244 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1592 m | pos p95=0.4230 m | rot median=0.0211 rad | total vel median=0.0152 m/s | rel vel median=0.0131 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.5888 m | pos p95=1.4501 m | rot median=0.0179 rad | total vel median=0.0153 m/s | rel vel median=0.0125 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.2277 m | pos p95=3.2115 m | rot median=0.0288 rad | total vel median=0.0142 m/s | rel vel median=0.0118 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=30 | completed=28 (0.933) | gt_divergence=0 (0.000) | pred_divergence=2 (0.067) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.2732 m | pos p95=0.4139 m | rot median=0.0195 rad | total vel median=0.0204 m/s | rel vel median=0.0203 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.8475 m | pos p95=1.6782 m | rot median=0.0328 rad | total vel median=0.0283 m/s | rel vel median=0.0259 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.7748 m | pos p95=4.2559 m | rot median=0.0498 rad | total vel median=0.0326 m/s | rel vel median=0.0281 m/s | cond_n=28/30 | completion=0.933 | gt_fail_by_h=0.000 | model_fail_by_h=0.067
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Earliest rollout failures
#   OU seed=200051 | reason=pred_divergence | sim_time=43.35s | pos=nan m | rot=nan rad | total_vel_violation=0
#   OU seed=200066 | reason=pred_divergence | sim_time=58.95s | pos=nan m | rot=nan rad | total_vel_violation=0
#
# Largest completed terminal errors
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=5.9340 m | rot=0.0727 rad | total_vel_violation=0
#   PRBS seed=68 | reason=completed | sim_time=60.00s | pos=5.1974 m | rot=0.0583 rad | total_vel_violation=0
#   OU seed=200056 | reason=completed | sim_time=60.00s | pos=4.6872 m | rot=0.0898 rad | total_vel_violation=0
#   OU seed=200064 | reason=completed | sim_time=60.00s | pos=4.2675 m | rot=0.2649 rad | total_vel_violation=0
#   OU seed=200059 | reason=completed | sim_time=60.00s | pos=4.2343 m | rot=0.0580 rad | total_vel_violation=0
#
# Completed rollouts with velocity violations
#   OU seed=200061 | reason=completed | sim_time=60.00s | pos=1.5677 m | rot=0.0162 rad | total_vel_violation=1
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# OU seed=200051 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260525_144306/diagnostic_plots/rollout_failure_OU_seed200051.png
# OU seed=200066 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260525_144306/diagnostic_plots/rollout_failure_OU_seed200066.png
# OU seed=200061 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260525_144306/diagnostic_plots/velocity_violation_OU_seed200061.png
# PRBS seed=42 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260525_144306/diagnostic_plots/high_terminal_error_PRBS_seed42.png
# PRBS seed=68 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260525_144306/diagnostic_plots/high_terminal_error_PRBS_seed68.png
# OU seed=200056 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_momentum_blackbox/baseline_se3_momentum_blackbox_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260525_144306/diagnostic_plots/high_terminal_error_OU_seed200056.png
# Batch evaluation complete.

# %% [markdown]
# ## 5. Provenance injection (per-run `_audit_meta/`)
# Records git HEAD + environment fingerprint into every decision run dir so these runs are distinguishable from catalog-era drift.

# %%
# Inject per-run provenance. The training flow does NOT write these automatically,
# so for paper-grade evidence we record them here (see docs/provenance_audit_phnode_full_clean.md sec 5.2).
import os, sys, subprocess, datetime
from pathlib import Path
import torch

RUN_TAG = os.environ["RUN_TAG"]
ckpt = PROJECT_DIR / "checkpoints"
# clean-only sweep: only the clean suite exists, but we scan the full triple defensively.
suites = [ckpt / f"sweep_oc_phase1a_decision_{p}_{RUN_TAG}" for p in ("clean", "iid", "v4lite")]

def _sh(args):
    try:
        return subprocess.run(args, cwd=PROJECT_DIR, capture_output=True, text=True).stdout.strip()
    except Exception as exc:  # noqa: BLE001
        return f"<unavailable: {exc}>"

head = _sh(["git", "rev-parse", "HEAD"])
diffstat = _sh(["git", "diff", "HEAD", "--stat"])
env_txt = "\n".join([
    f"python={sys.version.split()[0]}",
    f"torch={torch.__version__}",
    f"cuda={torch.version.cuda}",
    f"cudnn={torch.backends.cudnn.version()}",
    f"gpu={torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'cpu'}",
    f"captured_at={datetime.datetime.now().isoformat()}",
])

n = 0
for suite in suites:
    if not suite.exists():
        continue
    for cfg in suite.rglob("config.json"):
        run_dir = cfg.parent
        meta = run_dir / "_audit_meta"
        meta.mkdir(exist_ok=True)
        (meta / "code_revision.txt").write_text(f"git_head={head}\n\n{diffstat}\n")
        (meta / "environment.txt").write_text(env_txt + "\n")
        n += 1
print(f"provenance written for {n} run dirs")
print("git_head =", head)
# Out:
# provenance written for 5 run dirs
# git_head =

# %% [markdown]
# ## 6. Anomaly scan
# Flags any run with the `no successful training batches` catastrophic-gradient signature. For black-box models a clean-mirror collapse is a legitimate instability result — flag and handle per B1 (exclude from the quantitative aggregate, annotate).

# %%
# Quick anomaly scan: catch seed46/seed43-style catastrophic training before trusting numbers.
# Black-box models are collapse-prone (blackbox_fullstate collapsed in the 2026-04 catalog:
# s44=86.8m, s42/s43=nan), so a clean-mirror collapse here is a LEGITIMATE black-box instability
# finding, not an artifact -- still flag it and handle per the B1 policy (exclude from the
# quantitative aggregate, annotate transparently).
import os, re
from pathlib import Path

RUN_TAG = os.environ["RUN_TAG"]
ckpt = PROJECT_DIR / "checkpoints"
suites = [ckpt / f"sweep_oc_phase1a_decision_{p}_{RUN_TAG}" for p in ("clean", "iid", "v4lite")]

print(f"{'suite':<48}{'run':<32}{'best_epoch':>10}{'best_loss':>14}{'nbad':>6}  flag")
for suite in suites:
    if not suite.exists():
        continue
    for cfg in sorted(suite.rglob("config.json")):
        run_dir = cfg.parent
        log = run_dir / "training.log"
        text = log.read_text() if log.exists() else ""
        nbad = text.count("no successful training batches")
        best_epoch, best_loss = "?", "?"
        m = re.findall(r"[Bb]est.*?epoch[^0-9]*([0-9]+).*?([0-9]+\.[0-9eE+-]+)", text)
        if m:
            best_epoch, best_loss = m[-1]
        flag = "  <-- CHECK (possible artifact / instability)" if nbad > 0 else ""
        print(f"{suite.name[:46]:<48}{run_dir.name[:30]:<32}{str(best_epoch):>10}{str(best_loss):>14}{nbad:>6}{flag}")
print("\nFlagged seeds: handle per B1 (exclude from aggregate via train_anomaly, annotate).")
# Out:
# suite                                           run                             best_epoch     best_loss  nbad  flag
# sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_  baseline_se3_momentum_blackbox           ?             ?     0
# sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_  baseline_se3_momentum_blackbox           ?             ?     0
# sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_  baseline_se3_momentum_blackbox           ?             ?     0
# sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_  baseline_se3_momentum_blackbox           ?             ?     0
# sweep_oc_phase1a_decision_clean_t2_wpfrag_se3_  baseline_se3_momentum_blackbox           ?             ?     0
#
# Flagged seeds: handle per B1 (exclude from aggregate via train_anomaly, annotate).

# %% [markdown]
# ## 7. Next step (after all three black-box notebooks finish)
# 1. Ensure `checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_{blackbox_fullstate,se3_momentum_blackbox,se3_accel_blackbox}` are synced back.
# 2. Locally rerun `python scripts/export_section8_t2_evidence.py` (black-box models are already in MODELS).
# 3. The clean rows append to `analysis/section8_current_evidence/aggregate.csv` for the §8 structured-vs-black-box table.
# 4. No shared-catalog rebuild is needed — the export reads the decision suites directly.
