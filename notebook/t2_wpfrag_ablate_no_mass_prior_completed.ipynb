# %% [markdown]
# # T2 WP-Frag current-evidence rerun — `ablate_no_mass_prior`
#
# **Goal.** Reproduce current-main (`g3_5_7` mirror) evidence for this one model so the
# paper Results section (chapter section 8) can be cited from a single, machine-reproducible
# suite instead of catalog-era cloud numbers contaminated by environment drift.
#
# **Matrix (this notebook).** `ablate_no_mass_prior` x {clean, iid_noisy_ic@nominal_train, v4_lite@nominal_train} x seeds {42,43,44,45,46} = 15 training runs, then every trained
# suite is evaluated across {clean, nominal_eval, degraded_eval, heading_biased_eval}.
#
# **Parallelism.** Run the four `t2_wpfrag_*` notebooks (one per model:
# `phnode_full`, `phnode_qforce`, `ablate_no_lift`, `ablate_no_mass_prior`) in separate
# Colab sessions. They use distinct `RUN_TAG`s and do not collide.
#
# **Why these knobs differ from phase1a:** (1) `IID_EVAL_PROFILES` is the full 4-profile
# robustness set so clean-vs-noisy matched comparison is available; (2) a provenance cell
# writes per-run `_audit_meta/` (the trainer does not). noise schedule defaults
# (warmup=20, ramp=80, mix_ratio=0.5) match the repo `nominal_train` contract.
#
# **After all four finish:** sync `checkpoints/` back, then locally rebuild the catalog
# (`scripts/build_oc_data_catalog.py`) and export the section-8 current-evidence tables.
#
# > Watch list while running: `phnode_full` seeds 42/46, `ablate_no_lift` seeds 43/44 —
# > these were catalog-era anomalies. The anomaly-scan cell flags any recurrence.

# %%
# !nvidia-smi
# Out:
# Sun May 24 03:30:34 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   40C    P8             12W /   72W |       0MiB /  23034MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import torch
print(f"PyTorch: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"CUDA: {torch.version.cuda}")
print(f"cuDNN: {torch.backends.cudnn.version()}")
# Out:
# PyTorch: 2.10.0+cu128
# CUDA available: True
# CUDA: 12.8
# cuDNN: 91002

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
from pathlib import Path

PROJECT_DIR = Path(os.environ.get(
    "AUV_PROJECT_DIR",
    "/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7",
))
assert PROJECT_DIR.exists(), f"Project directory not found: {PROJECT_DIR}"
# %cd $PROJECT_DIR
# Out:
# /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7

# %%
# %pip install -q torchdiffeq pandas

# %% [markdown]
# ## 0. Configuration

# %%
import os

# Runtime
os.environ["PYTHON_BIN"] = "python"
os.environ["DEVICE"] = "cuda"
os.environ["LOCAL_PROXY_ROOT"] = "/content/_proxy_suites"

# ---- T2 identity (one model per notebook) ----
os.environ["RUN_TAG"] = "t2_wpfrag_ablate_no_mass_prior"
os.environ["DATASET"] = "data/auv_oc_traj1000_blk150_s23_d0be9434.pkl"
os.environ["NOISE_REFERENCE"] = "remus100_dr"
os.environ["PHASE1A_LOG_DIR"] = str(PROJECT_DIR / "checkpoints" / "phase1a_logs" / os.environ["RUN_TAG"])
os.environ["PHASE1A_METADATA_DIR"] = str(PROJECT_DIR / "checkpoints" / f"phase1a_metadata_{os.environ['RUN_TAG']}")

# ---- T2 matrix: single model x 3 protocols x 5 seeds ----
os.environ["PHASE1A_MODELS"] = "ablate_no_mass_prior"
os.environ["SMOKE1_MODELS"] = "ablate_no_mass_prior"
os.environ["SMOKE_SEEDS"] = "42"                 # cheap protocol-correctness gate (1 seed)
os.environ["DECISION_SEEDS"] = "42 43 44 45 46"  # full current-evidence seed set

# ---- Evaluation contract ----
os.environ["SMOKE_EVAL_NUM_TRAJ_PER_SCENARIO"] = "6"
os.environ["DECISION_EVAL_NUM_TRAJ_PER_SCENARIO"] = "30"
os.environ["EVAL_TIMES"] = "10 30 60"
os.environ["EVAL_SCENARIOS"] = "PRBS CHIRP OU"
os.environ["EVAL_BASE_SEED"] = "42"
os.environ["EVAL_NOISE_SEED"] = "2024"
os.environ["EVAL_PROGRESS_EVERY"] = "5"
os.environ["EVAL_NUM_DIAGNOSTIC_PLOTS"] = "6"
# Full robustness set: evaluates clean/iid/v4lite suites across all 4 profiles (caveat B).
os.environ["IID_EVAL_PROFILES"] = "clean nominal_eval degraded_eval heading_biased_eval"
os.environ["V4_EVAL_PROFILES"] = "nominal_eval"

# ---- Audit gate ----
os.environ["STRICT_ZERO_NOISE_AUDIT"] = "1"
os.environ["SOFT_MIN_EPOCH_SCALE"] = "0.05"

print("RUN_TAG       =", os.environ["RUN_TAG"])
print("PHASE1A_MODELS=", os.environ["PHASE1A_MODELS"])
print("DECISION_SEEDS=", os.environ["DECISION_SEEDS"])
print("IID_EVAL_PROFILES=", os.environ["IID_EVAL_PROFILES"])
# Out:
# RUN_TAG       = t2_wpfrag_ablate_no_mass_prior
# PHASE1A_MODELS= ablate_no_mass_prior
# DECISION_SEEDS= 42 43 44 45 46
# IID_EVAL_PROFILES= clean nominal_eval degraded_eval heading_biased_eval

# %% [markdown]
# ## 1. Preflight
# Confirms all target suite/proxy dirs are absent and saves suite-level run config + environment metadata. If it fails, change `RUN_TAG` or remove the target dirs.

# %%
os.environ["MODE"] = "preflight"
# !bash scripts/run_phase1a_oc_v4lite.sh
# Out:
# [phase1a]
# MODE=preflight
# RUN_TAG=t2_wpfrag_ablate_no_mass_prior
# DATASET=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# DEVICE=cuda
# PHASE1A_MODELS=ablate_no_mass_prior
# SMOKE1_MODELS=ablate_no_mass_prior
# SMOKE_SEEDS=42
# DECISION_SEEDS=42 43 44 45 46
# NOISE_REFERENCE=remus100_dr
# PHASE1A_LOG_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_logs/t2_wpfrag_ablate_no_mass_prior
# PHASE1A_METADATA_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_metadata_t2_wpfrag_ablate_no_mass_prior
# Preflight passed: all Phase-1A target suite/proxy directories are absent.
# [metadata] /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_metadata_t2_wpfrag_ablate_no_mass_prior

# %% [markdown]
# ## 2. Smoke gate (seed 42, all 3 protocols)
# Cheap protocol-correctness check (especially the `v4_lite` trajectory-consistent IC path and the strict zero-noise audit for `clean`). Important for `phnode_qforce`, which was not in the phase1a smoke set. Smoke results are flow-validation only — never cited.

# %%
os.environ["MODE"] = "smoke1_train"
# !bash scripts/run_phase1a_oc_v4lite.sh
# Out:
# [phase1a]
# MODE=smoke1_train
# RUN_TAG=t2_wpfrag_ablate_no_mass_prior
# DATASET=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# DEVICE=cuda
# PHASE1A_MODELS=ablate_no_mass_prior
# SMOKE1_MODELS=ablate_no_mass_prior
# SMOKE_SEEDS=42
# DECISION_SEEDS=42 43 44 45 46
# NOISE_REFERENCE=remus100_dr
# PHASE1A_LOG_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_logs/t2_wpfrag_ablate_no_mass_prior
# PHASE1A_METADATA_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_metadata_t2_wpfrag_ablate_no_mass_prior
# [train] suite=sweep_oc_phase1a_smoke1_clean_t2_wpfrag_ablate_no_mass_prior models=ablate_no_mass_prior seeds=42 protocol=auto
# Training all models with profile-based noisy IC.
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Group: all
# Explicit models: ablate_no_mass_prior
# Seeds: 42
# Noise config: protocol=auto, profile=clean, scale=1.0, warmup=20, ramp=80, mix_ratio=0.5
# Auto-eval profiles: block=[clean nominal_eval heading_biased_eval] heldout=[clean nominal_eval degraded_eval heading_biased_eval]
# Suite directory: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_ablate_no_mass_prior
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Models (1): ablate_no_mass_prior
# Seeds: 42
# [train] ablation_ablate_no_mass_prior_seed42
# Loading dataset...
# Loaded: 83850 train, 21000 test, t_eval=[0.   0.05 0.1  0.15 0.2 ]
# Dataset split: trajectory | train trajectories: 559 | test trajectories: 140
# Dataset ID: d0be9434
# Dataset path: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl | velocity convention: body_total | state dim: 27
# Position std: [0.1508, 0.1400, 0.0370]
# Velocity std: u=0.4722, v=0.0898, w=0.0718, p=0.0248, q=0.0906, r=0.0526
# Actuator std: a0=0.1543, a1=0.1555, a2=299.0037
# Training noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# Model: Ablation: No Mass Prior [ablation/ablation] | canonical type: ablate_no_mass_prior
# Model parameters: 62,803
# Training dataset: id=d0be9434 | path=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Mass matrix initialized from physics
# Training: epochs<=300, target_steps=5000, warmup_steps=400, lr=6.00e-03 -> 1.00e-04, solver=rk4, so3_reg=1.00e-03
# Train samples: 83850, Test samples: 21000
# Epoch    1 | Step    20/ 5000 | Train 5.3981e-01 | Test 5.2851e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 4.10e-04 | 8.3s
# Epoch    2 | Step    40/ 5000 | Train 4.8358e-01 | Test 4.0125e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 7.05e-04 | 6.3s
# Epoch    3 | Step    60/ 5000 | Train 3.7129e-01 | Test 3.5758e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 1.00e-03 | 6.1s
# Epoch    4 | Step    80/ 5000 | Train 3.3689e-01 | Test 3.2149e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 1.29e-03 | 6.2s
# Epoch    5 | Step   100/ 5000 | Train 2.9747e-01 | Test 2.7182e-01 | SO3(train/test) 1.13e-07/1.14e-07 | Fail(train/test) 0/0 | LR 1.59e-03 | 6.1s
# Epoch    6 | Step   120/ 5000 | Train 2.6475e-01 | Test 2.9442e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 1.88e-03 | 6.3s
# Epoch    7 | Step   140/ 5000 | Train 2.6064e-01 | Test 2.5145e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 2.18e-03 | 6.1s
# Epoch    8 | Step   160/ 5000 | Train 2.4722e-01 | Test 2.4122e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 2.47e-03 | 6.2s
# Epoch    9 | Step   180/ 5000 | Train 2.4234e-01 | Test 2.3580e-01 | SO3(train/test) 1.14e-07/1.15e-07 | Fail(train/test) 0/0 | LR 2.77e-03 | 6.1s
# Epoch   10 | Step   200/ 5000 | Train 2.3756e-01 | Test 2.2616e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 3.06e-03 | 6.2s
# Epoch   11 | Step   220/ 5000 | Train 2.2887e-01 | Test 2.1488e-01 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 3.36e-03 | 6.1s
# Epoch   12 | Step   240/ 5000 | Train 2.2177e-01 | Test 2.0954e-01 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 3.65e-03 | 6.2s
# Epoch   13 | Step   260/ 5000 | Train 2.1218e-01 | Test 2.0249e-01 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 3.95e-03 | 6.1s
# Epoch   14 | Step   280/ 5000 | Train 2.0077e-01 | Test 1.9484e-01 | SO3(train/test) 1.16e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.24e-03 | 6.1s
# Epoch   15 | Step   300/ 5000 | Train 1.9102e-01 | Test 1.8485e-01 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.54e-03 | 6.3s
# Epoch   16 | Step   320/ 5000 | Train 1.8319e-01 | Test 1.8745e-01 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.83e-03 | 6.2s
# Epoch   17 | Step   340/ 5000 | Train 1.7551e-01 | Test 1.6743e-01 | SO3(train/test) 1.18e-07/1.18e-07 | Fail(train/test) 0/0 | LR 5.13e-03 | 6.2s
# Epoch   18 | Step   360/ 5000 | Train 1.6741e-01 | Test 1.7409e-01 | SO3(train/test) 1.18e-07/1.18e-07 | Fail(train/test) 0/0 | LR 5.42e-03 | 6.1s
# Epoch   19 | Step   380/ 5000 | Train 1.6152e-01 | Test 1.7034e-01 | SO3(train/test) 1.18e-07/1.19e-07 | Fail(train/test) 0/0 | LR 5.72e-03 | 6.1s
# Epoch   20 | Step   400/ 5000 | Train 1.6374e-01 | Test 1.7898e-01 | SO3(train/test) 1.19e-07/1.19e-07 | Fail(train/test) 0/0 | LR 6.00e-03 | 6.2s
# Epoch   21 | Step   420/ 5000 | Train 1.5556e-01 | Test 1.6543e-01 | SO3(train/test) 1.19e-07/1.18e-07 | Fail(train/test) 0/0 | LR 6.00e-03 | 6.3s
# Epoch   22 | Step   440/ 5000 | Train 1.4092e-01 | Test 1.4488e-01 | SO3(train/test) 1.19e-07/1.19e-07 | Fail(train/test) 0/0 | LR 6.00e-03 | 6.3s
# Epoch   23 | Step   460/ 5000 | Train 1.3016e-01 | Test 1.2034e-01 | SO3(train/test) 1.19e-07/1.19e-07 | Fail(train/test) 0/0 | LR 6.00e-03 | 6.3s
# Epoch   24 | Step   480/ 5000 | Train 1.2300e-01 | Test 1.2896e-01 | SO3(train/test) 1.19e-07/1.18e-07 | Fail(train/test) 0/0 | LR 6.00e-03 | 6.2s
# Epoch   25 | Step   500/ 5000 | Train 1.1861e-01 | Test 1.1401e-01 | SO3(train/test) 1.19e-07/1.18e-07 | Fail(train/test) 0/0 | LR 5.99e-03 | 6.2s
# Epoch   26 | Step   520/ 5000 | Train 1.1293e-01 | Test 1.1343e-01 | SO3(train/test) 1.18e-07/1.18e-07 | Fail(train/test) 0/0 | LR 5.99e-03 | 6.1s
# Epoch   27 | Step   540/ 5000 | Train 1.1051e-01 | Test 1.1347e-01 | SO3(train/test) 1.18e-07/1.18e-07 | Fail(train/test) 0/0 | LR 5.99e-03 | 6.2s
# Epoch   28 | Step   560/ 5000 | Train 1.0583e-01 | Test 1.0511e-01 | SO3(train/test) 1.18e-07/1.17e-07 | Fail(train/test) 0/0 | LR 5.98e-03 | 6.3s
# Epoch   29 | Step   580/ 5000 | Train 9.9091e-02 | Test 1.0107e-01 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 5.98e-03 | 6.2s
# Epoch   30 | Step   600/ 5000 | Train 9.5854e-02 | Test 1.0373e-01 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 5.97e-03 | 6.2s
# Epoch   31 | Step   620/ 5000 | Train 9.4554e-02 | Test 1.0032e-01 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.97e-03 | 6.3s
# Epoch   32 | Step   640/ 5000 | Train 9.1512e-02 | Test 8.9943e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 5.96e-03 | 6.0s
# Epoch   33 | Step   660/ 5000 | Train 9.2087e-02 | Test 9.6333e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 5.95e-03 | 6.2s
# Epoch   34 | Step   680/ 5000 | Train 9.1451e-02 | Test 1.0221e-01 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.95e-03 | 6.2s
# Epoch   35 | Step   700/ 5000 | Train 9.5448e-02 | Test 1.0708e-01 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.94e-03 | 6.3s
# Epoch   36 | Step   720/ 5000 | Train 1.0453e-01 | Test 1.0916e-01 | SO3(train/test) 1.16e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.93e-03 |
-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.87e-03 | 6.3s
# Epoch  166 | Step  3320/ 5000 | Train 1.1732e-02 | Test 1.3789e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.84e-03 | 6.1s
# Epoch  167 | Step  3340/ 5000 | Train 1.1431e-02 | Test 1.2743e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.80e-03 | 6.2s
# Epoch  168 | Step  3360/ 5000 | Train 1.1142e-02 | Test 1.2688e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.76e-03 | 6.2s
# Epoch  169 | Step  3380/ 5000 | Train 1.0764e-02 | Test 1.2125e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.73e-03 | 6.2s
# Epoch  170 | Step  3400/ 5000 | Train 1.0527e-02 | Test 1.2400e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.69e-03 | 6.2s
# Epoch  171 | Step  3420/ 5000 | Train 1.0254e-02 | Test 1.0311e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.66e-03 | 6.3s
# Epoch  172 | Step  3440/ 5000 | Train 9.9711e-03 | Test 1.1191e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.62e-03 | 6.3s
# Epoch  173 | Step  3460/ 5000 | Train 9.5973e-03 | Test 1.0162e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.59e-03 | 6.2s
# Epoch  174 | Step  3480/ 5000 | Train 9.2266e-03 | Test 1.0094e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.55e-03 | 6.1s
# Epoch  175 | Step  3500/ 5000 | Train 9.0700e-03 | Test 1.0828e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.52e-03 | 6.3s
# Epoch  176 | Step  3520/ 5000 | Train 8.8499e-03 | Test 1.0206e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.48e-03 | 6.1s
# Epoch  177 | Step  3540/ 5000 | Train 8.6102e-03 | Test 9.4628e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.45e-03 | 6.2s
# Epoch  178 | Step  3560/ 5000 | Train 8.4067e-03 | Test 8.4336e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.41e-03 | 6.2s
# Epoch  179 | Step  3580/ 5000 | Train 8.2517e-03 | Test 8.7653e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.38e-03 | 6.2s
# Epoch  180 | Step  3600/ 5000 | Train 8.0838e-03 | Test 8.9367e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.35e-03 | 6.2s
# Epoch  181 | Step  3620/ 5000 | Train 7.7922e-03 | Test 7.9152e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.31e-03 | 6.2s
# Epoch  182 | Step  3640/ 5000 | Train 7.6672e-03 | Test 7.8524e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.28e-03 | 6.3s
# Epoch  183 | Step  3660/ 5000 | Train 7.6090e-03 | Test 8.2985e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.25e-03 | 6.2s
# Epoch  184 | Step  3680/ 5000 | Train 7.5459e-03 | Test 7.6119e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.22e-03 | 6.1s
# Epoch  185 | Step  3700/ 5000 | Train 7.3746e-03 | Test 8.6216e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.19e-03 | 6.3s
# Epoch  186 | Step  3720/ 5000 | Train 7.1890e-03 | Test 8.0064e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.16e-03 | 6.1s
# Epoch  187 | Step  3740/ 5000 | Train 7.0607e-03 | Test 7.2541e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.13e-03 | 6.2s
# Epoch  188 | Step  3760/ 5000 | Train 6.9030e-03 | Test 7.3200e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.10e-03 | 6.1s
# Epoch  189 | Step  3780/ 5000 | Train 6.7474e-03 | Test 6.9293e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.07e-03 | 6.2s
# Epoch  190 | Step  3800/ 5000 | Train 6.6365e-03 | Test 6.7015e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.04e-03 | 6.2s
# Epoch  191 | Step  3820/ 5000 | Train 6.5283e-03 | Test 7.0106e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.01e-03 | 6.2s
# Epoch  192 | Step  3840/ 5000 | Train 6.5330e-03 | Test 6.9894e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 9.77e-04 | 6.1s
# Epoch  193 | Step  3860/ 5000 | Train 6.4045e-03 | Test 6.7405e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 9.49e-04 | 6.2s
# Epoch  194 | Step  3880/ 5000 | Train 6.2848e-03 | Test 7.2488e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 9.21e-04 | 6.2s
# Epoch  195 | Step  3900/ 5000 | Train 6.4035e-03 | Test 6.7497e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 8.93e-04 | 6.3s
# Epoch  196 | Step  3920/ 5000 | Train 6.3418e-03 | Test 6.0930e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 8.66e-04 | 6.1s
# Epoch  197 | Step  3940/ 5000 | Train 5.6928e-03 | Test 5.7977e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 8.39e-04 | 6.3s
# Epoch  198 | Step  3960/ 5000 | Train 5.5395e-03 | Test 5.7741e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 8.12e-04 | 6.1s
# Epoch  199 | Step  3980/ 5000 | Train 5.4147e-03 | Test 5.6704e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 7.86e-04 | 6.2s
# Epoch  200 | Step  4000/ 5000 | Train 5.4174e-03 | Test 5.7269e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 7.61e-04 | 6.3s
# Epoch  201 | Step  4020/ 5000 | Train 5.3499e-03 | Test 5.5745e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 7.35e-04 | 6.2s
# Epoch  202 | Step  4040/ 5000 | Train 5.2925e-03 | Test 5.5423e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 7.11e-04 | 6.1s
# Epoch  203 | Step  4060/ 5000 | Train 5.2509e-03 | Test 5.4856e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 6.86e-04 | 6.2s
# Epoch  204 | Step  4080/ 5000 | Train 5.2009e-03 | Test 5.5258e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 6.62e-04 | 6.2s
# Epoch  205 | Step  4100/ 5000 | Train 5.1968e-03 | Test 5.4284e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 6.39e-04 | 6.3s
# Epoch  206 | Step  4120/ 5000 | Train 5.1825e-03 | Test 5.4553e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 6.16e-04 | 6.2s
# Epoch  207 | Step  4140/ 5000 | Train 5.1273e-03 | Test 5.3454e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 5.93e-04 | 6.2s
# Epoch  208 | Step  4160/ 5000 | Train 5.0784e-03 | Test 5.3121e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 5.71e-04 | 6.3s
# Epoch  209 | Step  4180/ 5000 | Train 5.0423e-03 | Test 5.2585e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.50e-04 | 6.3s
# Epoch  210 | Step  4200/ 5000 | Train 5.0357e-03 | Test 5.2883e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 5.29e-04 | 6.3s
# Epoch  211 | Step  4220/ 5000 | Train 5.0157e-03 | Test 5.2273e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.08e-04 | 6.1s
# Epoch  212 | Step  4240/ 5000 | Train 4.9924e-03 | Test 5.1992e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.88e-04 | 6.3s
# Epoch  213 | Step  4260/ 5000 | Train 4.9646e-03 | Test 5.1758e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.68e-04 | 6.1s
# Epoch  214 | Step  4280/ 5000 | Train 4.9705e-03 | Test 5.2088e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.49e-04 | 6.2s
# Epoch  215 | Step  4300/ 5000 | Train 4.9351e-03 | Test 5.2034e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.30e-04 | 6.3s
# Epoch  216 | Step  4320/ 5000 | Train 4.9284e-03 | Test 5.1559e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.12e-04 | 6.2s
# Epoch  217 | Step  4340/ 5000 | Train 4.9065e-03 | Test 5.1350e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 3.94e-04 | 6.1s
# Epoch  218 | Step  4360/ 5000 | Train 4.9082e-03 | Test 5.1279e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.77e-04 | 6.1s
# Epoch  219 | Step  4380/ 5000 | Train 4.8842e-03 | Test 5.0974e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 3.60e-04 | 6.1s
# Epoch  220 | Step  4400/ 5000 | Train 4.8840e-03 | Test 5.1451e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 3.44e-04 | 6.3s
# Epoch  221 | Step  4420/ 5000 | Train 4.8819e-03 | Test 5.0745e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 3.28e-04 | 6.2s
# Epoch  222 | Step  4440/ 5000 | Train 4.8735e-03 | Test 5.1128e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.12e-04 | 6.2s
# Epoch  223 | Step  4460/ 5000 | Train 4.8587e-03 | Test 5.0791e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.98e-04 | 6.1s
# Epoch  224 | Step  4480/ 5000 | Train 4.8364e-03 | Test 5.0821e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.83e-04 | 6.2s
# Epoch  225 | Step  4500/ 5000 | Train 4.8163e-03 | Test 5.0423e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.70e-04 | 6.2s
# Epoch  226 | Step  4520/ 5000 | Train 4.8176e-03 | Test 5.0277e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.57e-04 | 6.1s
# Epoch  227 | Step  4540/ 5000 | Train 4.8153e-03 | Test 5.0432e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.44e-04 | 6.1s
# Epoch  228 | Step  4560/ 5000 | Train 4.8081e-03 | Test 5.0499e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.32e-04 | 6.1s
# Epoch  229 | Step  4580/ 5000 | Train 4.7962e-03 | Test 5.0122e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.20e-04 | 6.1s
# Epoch  230 | Step  4600/ 5000 | Train 4.7856e-03 | Test 5.0111e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 2.09e-04 | 6.3s
# Epoch  231 | Step  4620/ 5000 | Train 4.7858e-03 | Test 5.0433e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.98e-04 | 6.1s
# Epoch  232 | Step  4640/ 5000 | Train 4.7760e-03 | Test 5.0089e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.88e-04 | 6.1s
# Epoch  233 | Step  4660/ 5000 | Train 4.7715e-03 | Test 4.9875e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.79e-04 | 6.1s
# Epoch  234 | Step  4680/ 5000 | Train 4.7565e-03 | Test 4.9826e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.70e-04 | 6.2s
# Epoch  235 | Step  4700/ 5000 | Train 4.7655e-03 | Test 4.9939e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.61e-04 | 6.3s
# Epoch  236 | Step  4720/ 5000 | Train 4.7577e-03 | Test 4.9840e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.53e-04 | 6.1s
# Epoch  237 | Step  4740/ 5000 | Train 4.7503e-03 | Test 4.9586e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.46e-04 | 6.1s
# Epoch  238 | Step  4760/ 5000 | Train 4.7453e-03 | Test 4.9956e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.39e-04 | 6.2s
# Epoch  239 | Step  4780/ 5000 | Train 4.7405e-03 | Test 4.9610e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.33e-04 | 6.2s
# Epoch  240 | Step  4800/ 5000 | Train 4.7391e-03 | Test 4.9673e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.27e-04 | 6.3s
# Epoch  241 | Step  4820/ 5000 | Train 4.7334e-03 | Test 4.9591e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.22e-04 | 6.1s
# Epoch  242 | Step  4840/ 5000 | Train 4.7242e-03 | Test 4.9579e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.17e-04 | 6.1s
# Epoch  243 | Step  4860/ 5000 | Train 4.7229e-03 | Test 4.9694e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.13e-04 | 6.2s
# Epoch  244 | Step  4880/ 5000 | Train 4.7291e-03 | Test 4.9531e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.10e-04 | 6.2s
# Epoch  245 | Step  4900/ 5000 | Train 4.7197e-03 | Test 4.9677e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.07e-04 | 6.3s
# Epoch  246 | Step  4920/ 5000 | Train 4.7173e-03 | Test 4.9727e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.04e-04 | 6.2s
# Epoch  247 | Step  4940/ 5000 | Train 4.7158e-03 | Test 4.9573e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.02e-04 | 6.1s
# Epoch  248 | Step  4960/ 5000 | Train 4.7185e-03 | Test 4.9346e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.01e-04 | 6.2s
# Epoch  249 | Step  4980/ 5000 | Train 4.7000e-03 | Test 4.9402e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.00e-04 | 6.2s
# Epoch  250 | Step  5000/ 5000 | Train 4.7100e-03 | Test 4.9226e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.00e-04 | 6.3s
# Reached target optimizer steps: 5000/5000
# Done. Best validation score: failure_rate=0.0000, test_loss=4.9226e-03 (epoch 250)
# Running detailed evaluation...
# Block evaluation profile: clean
# Block evaluation noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0001 +/- 0.0001  (max 0.0005)
# Rotation geo [rad]:  0.0005 +/- 0.0000  (max 0.0009)
# Lin vel RMSE [m/s]:  0.0014 +/- 0.0010
# Ang vel RMSE [r/s]:  0.0011 +/- 0.0007
# Components:  u=0.0021  v=0.0007  w=0.0004  p=0.0007  q=0.0012  r=0.0009
# SO(3) violation:  |det-1|=6.19e-08  ||RR^T-I||=1.27e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# Block evaluation profile: nominal_eval
# Block evaluation noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0013 +/- 0.0008  (max 0.0056)
# Rotation geo [rad]:  0.0082 +/- 0.0058  (max 0.0368)
# Lin vel RMSE [m/s]:  0.0045 +/- 0.0021
# Ang vel RMSE [r/s]:  0.0034 +/- 0.0020
# Components:  u=0.0055  v=0.0031  w=0.0030  p=0.0051  q=0.0014  r=0.0015
# SO(3) violation:  |det-1|=2.80e-07  ||RR^T-I||=6.11e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# Block evaluation profile: heading_biased_eval
# Block evaluation noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0049 +/- 0.0017  (max 0.0109)
# Rotation geo [rad]:  0.0351 +/- 0.0096  (max 0.0657)
# Lin vel RMSE [m/s]:  0.0080 +/- 0.0038
# Ang vel RMSE [r/s]:  0.0034 +/- 0.0020
# Components:  u=0.0077  v=0.0090  w=0.0033  p=0.0051  q=0.0014  r=0.0015
# SO(3) violation:  |det-1|=2.96e-07  ||RR^T-I||=6.32e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Block Evaluation Relative To Clean
# ==================================================
# [nominal_eval]
# position_rmse: ratio=10.963  degradation=+996.3%
# rotation_geodesic: ratio=16.638  degradation=+1563.8%
# velocity_rmse: ratio=3.274  degradation=+227.4%
# angular_rmse: ratio=3.183  degradation=+218.3%
# failure_rate: ratio=1.000  degradation=+0.0%
# [heading_biased_eval]
# position_rmse: ratio=41.849  degradation=+4084.9%
# rotation_geodesic: ratio=71.339  degradation=+7033.9%
# velocity_rmse: ratio=5.781  degradation=+478.1%
# angular_rmse: ratio=3.180  degradation=+218.0%
# failure_rate: ratio=1.000  degradation=+0.0%
# Running held-out trajectory evaluation...
# Held-out evaluation profile: clean
# Held-out evaluation noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0001 (median 0.0001, p95 0.0001)
# Rotation geo [rad]:  0.0005 (median 0.0005, p95 0.0005)
# Lin vel RMSE [m/s]:  0.0011  Ang vel RMSE [r/s]:  0.0009
# SO(3) violation:  |det-1|=6.04e-08  ||RR^T-I||=1.17e-07
# Noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# [CHIRP] pos=0.0001 m, rot=0.0005 rad, success=1.0000
# [OU] pos=0.0001 m, rot=0.0005 rad, success=1.0000
# [PRBS] pos=0.0001 m, rot=0.0005 rad, success=1.0000
# Held-out evaluation profile: nominal_eval
# Held-out evaluation noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0011 (median 0.0011, p95 0.0014)
# Rotation geo [rad]:  0.0086 (median 0.0085, p95 0.0095)
# Lin vel RMSE [m/s]:  0.0042  Ang vel RMSE [r/s]:  0.0032
# SO(3) violation:  |det-1|=2.95e-07  ||RR^T-I||=6.28e-07
# Noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# [CHIRP] pos=0.0011 m, rot=0.0085 rad, success=1.0000
# [OU] pos=0.0011 m, rot=0.0086 rad, success=1.0000
# [PRBS] pos=0.0011 m, rot=0.0085 rad, success=1.0000
# Held-out evaluation profile: degraded_eval
# Held-out evaluation noise budget: protocol=iid_noisy_ic | profile=degraded_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0026 (median 0.0025, p95 0.0033)
# Rotation geo [rad]:  0.0209 (median 0.0208, p95 0.0233)
# Lin vel RMSE [m/s]:  0.0085  Ang vel RMSE [r/s]:  0.0061
# SO(3) violation:  |det-1|=2.95e-07  ||RR^T-I||=6.28e-07
# Noise budget: protocol=iid_noisy_ic | profile=degraded_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250]
# [CHIRP] pos=0.0025 m, rot=0.0209 rad, success=1.0000
# [OU] pos=0.0025 m, rot=0.0211 rad, success=1.0000
# [PRBS] pos=0.0027 m, rot=0.0208 rad, success=1.0000
# Held-out evaluation profile: heading_biased_eval
# Held-out evaluation noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Held-Out Trajectory Evaluation
# ...
# Epoch  236 | Step  4720/ 5000 | Train 2.1846e-02 | Test 6.7488e-03 | SO3(train/test) 3.69e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.53e-04 | 6.2s
# Epoch  237 | Step  4740/ 5000 | Train 2.1542e-02 | Test 6.8299e-03 | SO3(train/test) 3.68e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.46e-04 | 6.2s
# Epoch  238 | Step  4760/ 5000 | Train 2.1747e-02 | Test 6.8470e-03 | SO3(train/test) 3.68e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.39e-04 | 6.3s
# Epoch  239 | Step  4780/ 5000 | Train 2.1355e-02 | Test 6.6729e-03 | SO3(train/test) 3.66e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.33e-04 | 6.2s
# Epoch  240 | Step  4800/ 5000 | Train 2.1900e-02 | Test 6.7349e-03 | SO3(train/test) 3.70e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.27e-04 | 6.0s
# Epoch  241 | Step  4820/ 5000 | Train 2.1778e-02 | Test 6.8243e-03 | SO3(train/test) 3.67e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.22e-04 | 6.1s
# Epoch  242 | Step  4840/ 5000 | Train 2.1755e-02 | Test 6.7511e-03 | SO3(train/test) 3.69e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.17e-04 | 6.2s
# Epoch  243 | Step  4860/ 5000 | Train 2.1681e-02 | Test 6.8037e-03 | SO3(train/test) 3.67e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.13e-04 | 6.3s
# Epoch  244 | Step  4880/ 5000 | Train 2.1808e-02 | Test 6.9121e-03 | SO3(train/test) 3.70e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.10e-04 | 6.2s
# Epoch  245 | Step  4900/ 5000 | Train 2.1659e-02 | Test 6.7005e-03 | SO3(train/test) 3.67e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.07e-04 | 6.2s
# Epoch  246 | Step  4920/ 5000 | Train 2.1661e-02 | Test 6.7566e-03 | SO3(train/test) 3.65e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.04e-04 | 6.1s
# Epoch  247 | Step  4940/ 5000 | Train 2.1617e-02 | Test 6.8042e-03 | SO3(train/test) 3.67e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.02e-04 | 6.2s
# Epoch  248 | Step  4960/ 5000 | Train 2.1814e-02 | Test 6.7006e-03 | SO3(train/test) 3.69e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.01e-04 | 6.2s
# Epoch  249 | Step  4980/ 5000 | Train 2.1621e-02 | Test 6.8521e-03 | SO3(train/test) 3.66e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.00e-04 | 6.2s
# Epoch  250 | Step  5000/ 5000 | Train 2.1474e-02 | Test 6.7509e-03 | SO3(train/test) 3.66e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.00e-04 | 6.1s
# Reached target optimizer steps: 5000/5000
# Done. Best validation score: failure_rate=0.0000, test_loss=6.6729e-03 (epoch 239)
# Running detailed evaluation...
# Block evaluation profile: clean
# Block evaluation noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0001 +/- 0.0001  (max 0.0005)
# Rotation geo [rad]:  0.0005 +/- 0.0000  (max 0.0008)
# Lin vel RMSE [m/s]:  0.0015 +/- 0.0010
# Ang vel RMSE [r/s]:  0.0012 +/- 0.0007
# Components:  u=0.0023  v=0.0007  w=0.0004  p=0.0012  q=0.0012  r=0.0008
# SO(3) violation:  |det-1|=6.05e-08  ||RR^T-I||=1.25e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# Block evaluation profile: nominal_eval
# Block evaluation noise budget: protocol=v4_lite | profile=nominal_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0012 +/- 0.0008  (max 0.0044)
# Rotation geo [rad]:  0.0076 +/- 0.0053  (max 0.0301)
# Lin vel RMSE [m/s]:  0.0044 +/- 0.0021
# Ang vel RMSE [r/s]:  0.0031 +/- 0.0017
# Components:  u=0.0054  v=0.0030  w=0.0030  p=0.0047  q=0.0014  r=0.0014
# SO(3) violation:  |det-1|=3.00e-07  ||RR^T-I||=6.48e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=v4_lite | profile=nominal_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# Block evaluation profile: heading_biased_eval
# Block evaluation noise budget: protocol=v4_lite | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0050 +/- 0.0016  (max 0.0094)
# Rotation geo [rad]:  0.0361 +/- 0.0089  (max 0.0634)
# Lin vel RMSE [m/s]:  0.0079 +/- 0.0040
# Ang vel RMSE [r/s]:  0.0031 +/- 0.0017
# Components:  u=0.0078  v=0.0087  w=0.0033  p=0.0047  q=0.0014  r=0.0014
# SO(3) violation:  |det-1|=2.92e-07  ||RR^T-I||=6.12e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=v4_lite | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Block Evaluation Relative To Clean
# ==================================================
# [nominal_eval]
# position_rmse: ratio=9.412  degradation=+841.2%
# rotation_geodesic: ratio=15.437  degradation=+1443.7%
# velocity_rmse: ratio=2.966  degradation=+196.6%
# angular_rmse: ratio=2.556  degradation=+155.6%
# failure_rate: ratio=1.000  degradation=+0.0%
# [heading_biased_eval]
# position_rmse: ratio=39.585  degradation=+3858.5%
# rotation_geodesic: ratio=72.918  degradation=+7191.8%
# velocity_rmse: ratio=5.344  degradation=+434.4%
# angular_rmse: ratio=2.551  degradation=+155.1%
# failure_rate: ratio=1.000  degradation=+0.0%
# Running held-out trajectory evaluation...
# Held-out evaluation profile: clean
# Held-out evaluation noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0001 (median 0.0001, p95 0.0002)
# Rotation geo [rad]:  0.0005 (median 0.0005, p95 0.0005)
# Lin vel RMSE [m/s]:  0.0012  Ang vel RMSE [r/s]:  0.0011
# SO(3) violation:  |det-1|=6.01e-08  ||RR^T-I||=1.17e-07
# Noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# [CHIRP] pos=0.0001 m, rot=0.0005 rad, success=1.0000
# [OU] pos=0.0001 m, rot=0.0005 rad, success=1.0000
# [PRBS] pos=0.0001 m, rot=0.0005 rad, success=1.0000
# Held-out evaluation profile: nominal_eval
# Held-out evaluation noise budget: protocol=v4_lite | profile=nominal_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0011 (median 0.0011, p95 0.0014)
# Rotation geo [rad]:  0.0087 (median 0.0086, p95 0.0105)
# Lin vel RMSE [m/s]:  0.0043  Ang vel RMSE [r/s]:  0.0029
# SO(3) violation:  |det-1|=2.91e-07  ||RR^T-I||=6.19e-07
# Noise budget: protocol=v4_lite | profile=nominal_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# [CHIRP] pos=0.0011 m, rot=0.0086 rad, success=1.0000
# [OU] pos=0.0011 m, rot=0.0086 rad, success=1.0000
# [PRBS] pos=0.0012 m, rot=0.0088 rad, success=1.0000
# Held-out evaluation profile: degraded_eval
# Held-out evaluation noise budget: protocol=v4_lite | profile=degraded_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0026 (median 0.0026, p95 0.0035)
# Rotation geo [rad]:  0.0212 (median 0.0211, p95 0.0258)
# Lin vel RMSE [m/s]:  0.0084  Ang vel RMSE [r/s]:  0.0054
# SO(3) violation:  |det-1|=2.93e-07  ||RR^T-I||=6.25e-07
# Noise budget: protocol=v4_lite | profile=degraded_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250]
# [CHIRP] pos=0.0025 m, rot=0.0209 rad, success=1.0000
# [OU] pos=0.0025 m, rot=0.0210 rad, success=1.0000
# [PRBS] pos=0.0027 m, rot=0.0214 rad, success=1.0000
# Held-out evaluation profile: heading_biased_eval
# Held-out evaluation noise budget: protocol=v4_lite | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0041 (median 0.0039, p95 0.0053)
# Rotation geo [rad]:  0.0356 (median 0.0356, p95 0.0406)
# Lin vel RMSE [m/s]:  0.0069  Ang vel RMSE [r/s]:  0.0029
# SO(3) violation:  |det-1|=2.95e-07  ||RR^T-I||=6.27e-07
# Noise budget: protocol=v4_lite | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# [CHIRP] pos=0.0039 m, rot=0.0354 rad, success=1.0000
# [OU] pos=0.0039 m, rot=0.0357 rad, success=1.0000
# [PRBS] pos=0.0042 m, rot=0.0357 rad, success=1.0000
# ==================================================
# Held-Out Evaluation Relative To Clean
# ==================================================
# [nominal_eval]
# position_rmse: ratio=10.940  degradation=+994.0%
# rotation_geodesic: ratio=17.571  degradation=+1657.1%
# velocity_rmse: ratio=3.567  degradation=+256.7%
# angular_rmse: ratio=2.737  degradation=+173.7%
# success_rate: ratio=1.000  degradation=+0.0%
# trajectory_failure_rate: ratio=1.000  degradation=+0.0%
# [degraded_eval]
# position_rmse: ratio=25.799  degradation=+2479.9%
# rotation_geodesic: ratio=42.972  degradation=+4197.2%
# velocity_rmse: ratio=7.085  degradation=+608.5%
# angular_rmse: ratio=5.091  degradation=+409.1%
# success_rate: ratio=1.000  degradation=+0.0%
# trajectory_failure_rate: ratio=1.000  degradation=+0.0%
# [heading_biased_eval]
# position_rmse: ratio=40.185  degradation=+3918.5%
# rotation_geodesic: ratio=72.302  degradation=+7130.2%
# velocity_rmse: ratio=5.785  degradation=+478.5%
# angular_rmse: ratio=2.737  degradation=+173.7%
# success_rate: ratio=1.000  degradation=+0.0%
# trajectory_failure_rate: ratio=1.000  degradation=+0.0%
#
# Training finished. Results: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42
# Training sweep complete.
# Manifest: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_ablate_no_mass_prior/runs.tsv
# Next step:
#   scripts/batch_eval_models.sh --suite-dir "/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_ablate_no_mass_prior"
#
# Training complete.
# Suite directory: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_ablate_no_mass_prior
# Next step:
#   bash scripts/eval_all_models_noise_profile.sh --suite-dir "/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_ablate_no_mass_prior"
# [audit] /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_ablate_no_mass_prior
# [audit] /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_ablate_no_mass_prior
# [audit] /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_ablate_no_mass_prior
#                                                    suite_name    group           model_type  seed train_noise_protocol  best_epoch  best_loss  noise_warmup_epochs  noise_ramp_epochs  noise_mix_ratio  epoch_scale_at_best  is_effectively_clean_at_best
#  sweep_oc_phase1a_smoke1_clean_t2_wpfrag_ablate_no_mass_prior ablation ablate_no_mass_prior    42                clean         250   0.004923                   20                 80              0.5                  0.0                          True
#    sweep_oc_phase1a_smoke1_iid_t2_wpfrag_ablate_no_mass_prior ablation ablate_no_mass_prior    42         iid_noisy_ic         249   0.006579                   20                 80              0.5                  1.0                         False
# sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_ablate_no_mass_prior ablation ablate_no_mass_prior    42              v4_lite         239   0.006673                   20                 80              0.5                  1.0                         False
# + /usr/bin/python3 /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/scripts/validate_v4_lite_protocol.py --run-dir /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42
# v4_lite protocol validation saved to: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/v4_lite_protocol_validation.json
# overall_passed=True
# same_epoch_stability: passed=True
# epoch_resampling: passed=True
# heading_bias_overlay: passed=True
# [validate] /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/v4_lite_protocol_validation.json

# %%
os.environ["MODE"] = "smoke1_eval"
# !bash scripts/run_phase1a_oc_v4lite.sh
# Out:
# [phase1a]
# MODE=smoke1_eval
# RUN_TAG=t2_wpfrag_ablate_no_mass_prior
# DATASET=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# DEVICE=cuda
# PHASE1A_MODELS=ablate_no_mass_prior
# SMOKE1_MODELS=ablate_no_mass_prior
# SMOKE_SEEDS=42
# DECISION_SEEDS=42 43 44 45 46
# NOISE_REFERENCE=remus100_dr
# PHASE1A_LOG_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_logs/t2_wpfrag_ablate_no_mass_prior
# PHASE1A_METADATA_DIR=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/phase1a_metadata_t2_wpfrag_ablate_no_mass_prior
# [eval] suite=sweep_oc_phase1a_smoke1_clean_t2_wpfrag_ablate_no_mass_prior eval_protocol=iid_noisy_ic profiles=clean nominal_eval degraded_eval heading_biased_eval
# Suite directory: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_ablate_no_mass_prior
# Manifest: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_ablate_no_mass_prior/runs.tsv
# Mode: resampled
# [eval] ablation_ablate_no_mass_prior_seed42
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=clean | noise_protocol=clean | noise_budget=protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000] | scenarios=PRBS,CHIRP,OU | trajectories=18 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260524_045317/clean
# [scenario 1/3] PRBS | 6 trajectories
# [1/18] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=16m30.6s
# [5/18] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=2m31.5s
# [6/18] PRBS seed=47 done | reason=completed | sim_time=60.00s | eta=1m56.6s
# [scenario done] PRBS | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=1.0488 m | pos_p95=2.0201 m | rot_med=0.0139 rad | completion=1.000 | elapsed=58.3s
# [scenario 2/3] CHIRP | 6 trajectories
# [7/18] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=3m03.2s
# [11/18] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=1m14.2s
# [12/18] CHIRP seed=100047 done | reason=completed | sim_time=60.00s | eta=58.3s
# [scenario done] CHIRP | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=0.7994 m | pos_p95=1.3147 m | rot_med=0.0131 rad | completion=1.000 | elapsed=1m56.6s
# [scenario 3/3] OU | 6 trajectories
# [13/18] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=1m07.6s
# [17/18] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=10.3s
# [18/18] OU seed=200047 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=0.9184 m | pos_p95=2.7794 m | rot_med=0.0229 rad | completion=1.000 | elapsed=2m55.8s
# Benchmark finished in 3m09.2s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260524_045317/clean
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: Ablation: No Mass Prior [ablation/ablation]
# Canonical model type: ablate_no_mass_prior
# Energy semantics: mechanical_energy
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 6
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.1059 m | pos p95=0.1996 m | rot median=0.0116 rad | total vel median=0.0089 m/s | rel vel median=0.0097 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=0.4199 m | pos p95=0.8726 m | rot median=0.0138 rad | total vel median=0.0092 m/s | rel vel median=0.0103 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=0.9469 m | pos p95=2.3460 m | rot median=0.0165 rad | total vel median=0.0138 m/s | rel vel median=0.0135 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=18 | completed=18 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.0984 m | pos p95=0.1851 m | rot median=0.0117 rad | total vel median=0.0073 m/s | rel vel median=0.0083 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.4393 m | pos p95=0.5892 m | rot median=0.0149 rad | total vel median=0.0071 m/s | rel vel median=0.0088 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.0488 m | pos p95=2.0201 m | rot median=0.0139 rad | total vel median=0.0114 m/s | rel vel median=0.0109 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1464 m | pos p95=0.2065 m | rot median=0.0108 rad | total vel median=0.0100 m/s | rel vel median=0.0104 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.3560 m | pos p95=0.7787 m | rot median=0.0137 rad | total vel median=0.0081 m/s | rel vel median=0.0086 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=0.7994 m | pos p95=1.3147 m | rot median=0.0131 rad | total vel median=0.0138 m/s | rel vel median=0.0125 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.0642 m | pos p95=0.1579 m | rot median=0.0109 rad | total vel median=0.0087 m/s | rel vel median=0.0083 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.3685 m | pos p95=0.8866 m | rot median=0.0202 rad | total vel median=0.0166 m/s | rel vel median=0.0142 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=0.9184 m | pos p95=2.7794 m | rot median=0.0229 rad | total vel median=0.0155 m/s | rel vel median=0.0213 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Largest completed terminal errors
#   OU seed=200043 | reason=completed | sim_time=60.00s | pos=3.0210 m | rot=0.0886 rad | total_vel_violation=0
#   PRBS seed=44 | reason=completed | sim_time=60.00s | pos=2.2269 m | rot=0.0294 rad | total_vel_violation=0
#   OU seed=200045 | reason=completed | sim_time=60.00s | pos=2.0548 m | rot=0.0267 rad | total_vel_violation=0
#   CHIRP seed=100046 | reason=completed | sim_time=60.00s | pos=1.4057 m | rot=0.0467 rad | total_vel_violation=0
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=1.3996 m | rot=0.0166 rad | total_vel_violation=0
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# OU seed=200043 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260524_045317/clean/diagnostic_plots/high_terminal_error_OU_seed200043.png
# PRBS seed=44 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260524_045317/clean/diagnostic_plots/high_terminal_error_PRBS_seed44.png
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=nominal_eval | noise_protocol=iid_noisy_ic | noise_budget=protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | scenarios=PRBS,CHIRP,OU | trajectories=18 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260524_045317/nominal_eval
# [scenario 1/3] PRBS | 6 trajectories
# [1/18] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=5m19.7s
# [5/18] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=48.9s
# [6/18] PRBS seed=47 done | reason=completed | sim_time=60.00s | eta=37.6s
# [scenario done] PRBS | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=1.5841 m | pos_p95=3.6139 m | rot_med=0.0230 rad | completion=1.000 | elapsed=18.9s
# [scenario 2/3] CHIRP | 6 trajectories
# [7/18] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=58.9s
# [11/18] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=23.9s
# [12/18] CHIRP seed=100047 done | reason=completed | sim_time=60.00s | eta=18.7s
# [scenario done] CHIRP | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=1.0722 m | pos_p95=1.5995 m | rot_med=0.0143 rad | completion=1.000 | elapsed=37.5s
# [scenario 3/3] OU | 6 trajectories
# [13/18] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=21.7s
# [17/18] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=3.3s
# [18/18] OU seed=200047 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=1.1734 m | pos_p95=3.1492 m | rot_med=0.0282 rad | completion=1.000 | elapsed=56.5s
# Benchmark finished in 1m09.1s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260524_045317/nominal_eval
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: Ablation: No Mass Prior [ablation/ablation]
# Canonical model type: ablate_no_mass_prior
# Energy semantics: mechanical_energy
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 6
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.1723 m | pos p95=0.3593 m | rot median=0.0135 rad | total vel median=0.0091 m/s | rel vel median=0.0097 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=0.5162 m | pos p95=1.2939 m | rot median=0.0168 rad | total vel median=0.0094 m/s | rel vel median=0.0102 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=1.2220 m | pos p95=3.4928 m | rot median=0.0230 rad | total vel median=0.0135 m/s | rel vel median=0.0135 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=18 | completed=18 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.2062 m | pos p95=0.5372 m | rot median=0.0183 rad | total vel median=0.0081 m/s | rel vel median=0.0084 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.7950 m | pos p95=1.4850 m | rot median=0.0162 rad | total vel median=0.0094 m/s | rel vel median=0.0088 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.5841 m | pos p95=3.6139 m | rot median=0.0230 rad | total vel median=0.0120 m/s | rel vel median=0.0109 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1733 m | pos p95=0.2907 m | rot median=0.0135 rad | total vel median=0.0105 m/s | rel vel median=0.0104 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.5056 m | pos p95=1.0590 m | rot median=0.0152 rad | total vel median=0.0076 m/s | rel vel median=0.0086 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.0722 m | pos p95=1.5995 m | rot median=0.0143 rad | total vel median=0.0135 m/s | rel vel median=0.0125 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1064 m | pos p95=0.2421 m | rot median=0.0122 rad | total vel median=0.0082 m/s | rel vel median=0.0084 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.5162 m | pos p95=1.0768 m | rot median=0.0233 rad | total vel median=0.0168 m/s | rel vel median=0.0142 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.1734 m | pos p95=3.1492 m | rot median=0.0282 rad | total vel median=0.0165 m/s | rel vel median=0.0213 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Largest completed terminal errors
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=3.9832 m | rot=0.0366 rad | total_vel_violation=0
#   OU seed=200043 | reason=completed | sim_time=60.00s | pos=3.4062 m | rot=0.0931 rad | total_vel_violation=0
#   PRBS seed=46 | reason=completed | sim_time=60.00s | pos=2.5061 m | rot=0.0206 rad | total_vel_violation=0
#   OU seed=200045 | reason=completed | sim_time=60.00s | pos=2.3783 m | rot=0.0308 rad | total_vel_violation=0
#   PRBS seed=44 | reason=completed | sim_time=60.00s | pos=1.9282 m | rot=0.0255 rad | total_vel_violation=0
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# PRBS seed=42 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260524_045317/nominal_eval/diagnostic_plots/high_terminal_error_PRBS_seed42.png
# OU seed=200043 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260524_045317/nominal_eval/diagnostic_plots/high_terminal_error_OU_seed200043.png
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=degraded_eval | noise_protocol=iid_noisy_ic | noise_budget=protocol=iid_noisy_ic | profile=degraded_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250] | scenarios=PRBS,CHIRP,OU | trajectories=18 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260524_045317/degraded_eval
# [scenario 1/3] PRBS | 6 trajectories
# [1/18] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=5m24.1s
# [5/18] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=49.6s
# [6/18] PRBS seed=47 done | reason=completed | sim_time=60.00s | eta=38.2s
# [scenario done] PRBS | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=2.1644 m | pos_p95=7.0940 m | rot_med=0.0176 rad | completion=1.000 | elapsed=19.1s
# [scenario 2/3] CHIRP | 6 trajectories
# [7/18] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=59.7s
# [11/18] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=24.2s
# [12/18] CHIRP seed=100047 done | reason=completed | sim_time=60.00s | eta=19.0s
# [scenario done] CHIRP | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=1.4244 m | pos_p95=2.5617 m | rot_med=0.0195 rad | completion=1.000 | elapsed=38.0s
# [scenario 3/3] OU | 6 trajectories
# [13/18] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=21.9s
# [17/18] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=3.3s
# [18/18] OU seed=200047 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=2.0717 m | pos_p95=3.7071 m | rot_med=0.0362 rad | completion=1.000 | elapsed=57.0s
# Benchmark finished in 1m09.6s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260524_045317/degraded_eval
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: Ablation: No Mass Prior [ablation/ablation]
# Canonical model type: ablate_no_mass_prior
# Energy semantics: mechanical_energy
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 6
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.2495 m | pos p95=0.7255 m | rot median=0.0184 rad | total vel median=0.0096 m/s | rel vel median=0.0097 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=0.8109 m | pos p95=2.5571 m | rot median=0.0242 rad | total vel median=0.0110 m/s | rel vel median=0.0102 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=1.5931 m | pos p95=5.0255 m | rot median=0.0273 rad | total vel median=0.0142 m/s | rel vel median=0.0135 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=18 | completed=18 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.3674 m | pos p95=1.1299 m | rot median=0.0316 rad | total vel median=0.0116 m/s | rel vel median=0.0086 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.3873 m | pos p95=3.3047 m | rot median=0.0219 rad | total vel median=0.0110 m/s | rel vel median=0.0087 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=2.1644 m | pos p95=7.0940 m | rot median=0.0176 rad | total vel median=0.0142 m/s | rel vel median=0.0109 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.2495 m | pos p95=0.4452 m | rot median=0.0161 rad | total vel median=0.0113 m/s | rel vel median=0.0104 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.7290 m | pos p95=1.5332 m | rot median=0.0158 rad | total vel median=0.0072 m/s | rel vel median=0.0086 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.4244 m | pos p95=2.5617 m | rot median=0.0195 rad | total vel median=0.0131 m/s | rel vel median=0.0125 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1421 m | pos p95=0.4010 m | rot median=0.0194 rad | total vel median=0.0079 m/s | rel vel median=0.0085 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.7445 m | pos p95=1.4575 m | rot median=0.0323 rad | total vel median=0.0181 m/s | rel vel median=0.0141 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=2.0717 m | pos p95=3.7071 m | rot median=0.0362 rad | total vel median=0.0162 m/s | rel vel median=0.0213 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Largest completed terminal errors
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=7.9559 m | rot=0.0670 rad | total_vel_violation=0
#   PRBS seed=46 | reason=completed | sim_time=60.00s | pos=4.5084 m | rot=0.0387 rad | total_vel_violation=0
#   OU seed=200043 | reason=completed | sim_time=60.00s | pos=3.9896 m | rot=0.1001 rad | total_vel_violation=0
#   OU seed=200045 | reason=completed | sim_time=60.00s | pos=2.8595 m | rot=0.0370 rad | total_vel_violation=0
#   PRBS seed=45 | reason=completed | sim_time=60.00s | pos=2.8485 m | rot=0.0155 rad | total_vel_violation=0
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# PRBS seed=42 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260524_045317/degraded_eval/diagnostic_plots/high_terminal_error_PRBS_seed42.png
# PRBS seed=46 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260524_045317/degraded_eval/diagnostic_plots/high_terminal_error_PRBS_seed46.png
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=heading_biased_eval | noise_protocol=iid_noisy_ic | noise_budget=protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350] | scenarios=PRBS,CHIRP,OU | trajectories=18 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260524_045317/heading_biased_eval
# [scenario 1/3] PRBS | 6 trajectories
# [1/18] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=5m20.5s
# [5/18] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=49.1s
# [6/18] PRBS seed=47 done | reason=completed | sim_time=60.00s | eta=37.7s
# [scenario done] PRBS | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=1.7982 m | pos_p95=3.6069 m | rot_med=0.0133 rad | completion=1.000 | elapsed=18.9s
# [scenario 2/3] CHIRP | 6 trajectories
# [7/18] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=59.5s
# [11/18] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=24.1s
# [12/18] CHIRP seed=100047 done | reason=completed | sim_time=60.00s | eta=18.9s
# [scenario done] CHIRP | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=2.8378 m | pos_p95=4.2849 m | rot_med=0.0394 rad | completion=1.000 | elapsed=37.9s
# [scenario 3/3] OU | 6 trajectories
# [13/18] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=21.9s
# [17/18] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=3.4s
# [18/18] OU seed=200047 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=3.5238 m | pos_p95=5.6390 m | rot_med=0.0629 rad | completion=1.000 | elapsed=57.0s
# Benchmark finished in 1m09.5s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260524_045317/heading_biased_eval
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: Ablation: No Mass Prior [ablation/ablation]
# Canonical model type: ablate_no_mass_prior
# Energy semantics: mechanical_energy
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 6
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.5422 m | pos p95=0.8052 m | rot median=0.0368 rad | total vel median=0.0124 m/s | rel vel median=0.0099 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=1.3861 m | pos p95=2.7295 m | rot median=0.0286 rad | total vel median=0.0129 m/s | rel vel median=0.0100 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=2.9749 m | pos p95=5.2210 m | rot median=0.0342 rad | total vel median=0.0201 m/s | rel vel median=0.0134 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=18 | completed=18 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.4306 m | pos p95=0.6207 m | rot median=0.0280 rad | total vel median=0.0153 m/s | rel vel median=0.0081 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.1391 m | pos p95=2.7749 m | rot median=0.0229 rad | total vel median=0.0103 m/s | rel vel median=0.0086 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.7982 m | pos p95=3.6069 m | rot median=0.0133 rad | total vel median=0.0170 m/s | rel vel median=0.0110 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.5446 m | pos p95=0.6117 m | rot median=0.0369 rad | total vel median=0.0168 m/s | rel vel median=0.0103 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.3027 m | pos p95=2.0231 m | rot median=0.0287 rad | total vel median=0.0097 m/s | rel vel median=0.0086 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=2.8378 m | pos p95=4.2849 m | rot median=0.0394 rad | total vel median=0.0204 m/s | rel vel median=0.0123 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.5501 m | pos p95=0.8435 m | rot median=0.0450 rad | total vel median=0.0080 m/s | rel vel median=0.0085 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.5881 m | pos p95=2.5469 m | rot median=0.0567 rad | total vel median=0.0235 m/s | rel vel median=0.0140 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=3.5238 m | pos p95=5.6390 m | rot median=0.0629 rad | total vel median=0.0242 m/s | rel vel median=0.0210 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Largest completed terminal errors
#   OU seed=200043 | reason=completed | sim_time=60.00s | pos=5.8131 m | rot=0.1228 rad | total_vel_violation=0
#   OU seed=200045 | reason=completed | sim_time=60.00s | pos=5.1165 m | rot=0.0654 rad | total_vel_violation=0
#   CHIRP seed=100045 | reason=completed | sim_time=60.00s | pos=4.5153 m | rot=0.0465 rad | total_vel_violation=0
#   PRBS seed=45 | reason=completed | sim_time=60.00s | pos=3.7464 m | rot=0.0110 rad | total_vel_violation=0
#   CHIRP seed=100043 | reason=completed | sim_time=60.00s | pos=3.5938 m | rot=0.0627 rad | total_vel_violation=0
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# OU seed=200043 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260524_045317/heading_biased_eval/diagnostic_plots/high_terminal_error_OU_seed200043.png
# OU seed=200045 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260524_045317/heading_biased_eval/diagnostic_plots/high_terminal_error_OU_seed200045.png
# Batch evaluation complete.
# [eval] suite=sweep_oc_phase1a_smoke1_iid_t2_wpfrag_ablate_no_mass_prior eval_protocol=iid_noisy_ic profiles=clean nominal_eval degraded_eval heading_biased_eval
# Suite directory: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_ablate_no_mass_prior
# Manifest: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_ablate_no_mass_prior/runs.tsv
# Mode: resampled
# [eval] ablation_ablate_no_mass_prior_seed42
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=clean | noise_protocol=clean | noise_budget=protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000] | scenarios=PRBS,CHIRP,OU | trajectories=18 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260524_045958/clean
# [scenario 1/3] PRBS | 6 trajectories
# [1/18] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=16m36.2s
# [5/18] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=2m32.4s
# [6/18] PRBS seed=47 done | reason=completed | sim_time=60.00s | eta=1m57.2s
# [scenario done] PRBS | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=1.3944 m | pos_p95=1.6838 m | rot_med=0.0182 rad | completion=1.000 | elapsed=58.7s
# [scenario 2/3] CHIRP | 6 trajectories
# [7/18] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=3m04.6s
# [11/18] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=1m14.8s
# [12/18] CHIRP seed=100047 done | reason=completed | sim_time=60.00s | eta=58.8s
# [scenario done] CHIRP | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=0.5941 m | pos_p95=0.7282 m | rot_med=0.0134 rad | completion=1.000 | elapsed=1m57.5s
# [scenario 3/3] OU | 6 trajectories
# [13/18] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=1m07.8s
# [17/18] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=10.4s
# [18/18] OU seed=200047 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=0.9805 m | pos_p95=2.3504 m | rot_med=0.0263 rad | completion=1.000 | elapsed=2m56.4s
# Benchmark finished in 3m09.8s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260524_045958/clean
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: Ablation: No Mass Prior [ablation/ablation]
# Canonical model type: ablate_no_mass_prior
# Energy semantics: mechanical_energy
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 6
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.1489 m | pos p95=0.2655 m | rot median=0.0088 rad | total vel median=0.0118 m/s | rel vel median=0.0112 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=0.3571 m | pos p95=0.8082 m | rot median=0.0145 rad | total vel median=0.0098 m/s | rel vel median=0.0110 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=0.8059 m | pos p95=1.8788 m | rot median=0.0168 rad | total vel median=0.0181 m/s | rel vel median=0.0160 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=18 | completed=18 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1295 m | pos p95=0.2602 m | rot median=0.0088 rad | total vel median=0.0084 m/s | rel vel median=0.0093 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.3858 m | pos p95=0.5942 m | rot median=0.0145 rad | total vel median=0.0076 m/s | rel vel median=0.0101 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.3944 m | pos p95=1.6838 m | rot median=0.0182 rad | total vel median=0.0252 m/s | rel vel median=0.0166 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1715 m | pos p95=0.2111 m | rot median=0.0070 rad | total vel median=0.0137 m/s | rel vel median=0.0129 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.2865 m | pos p95=0.4096 m | rot median=0.0050 rad | total vel median=0.0078 m/s | rel vel median=0.0078 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=0.5941 m | pos p95=0.7282 m | rot median=0.0134 rad | total vel median=0.0096 m/s | rel vel median=0.0148 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1534 m | pos p95=0.2409 m | rot median=0.0149 rad | total vel median=0.0120 m/s | rel vel median=0.0115 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.4874 m | pos p95=0.8514 m | rot median=0.0220 rad | total vel median=0.0206 m/s | rel vel median=0.0207 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=0.9805 m | pos p95=2.3504 m | rot median=0.0263 rad | total vel median=0.0223 m/s | rel vel median=0.0207 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Largest completed terminal errors
#   OU seed=200043 | reason=completed | sim_time=60.00s | pos=2.5846 m | rot=0.0757 rad | total_vel_violation=0
#   PRBS seed=44 | reason=completed | sim_time=60.00s | pos=1.7543 m | rot=0.0209 rad | total_vel_violation=0
#   OU seed=200047 | reason=completed | sim_time=60.00s | pos=1.6479 m | rot=0.0209 rad | total_vel_violation=0
#   PRBS seed=46 | reason=completed | sim_time=60.00s | pos=1.4723 m | rot=0.0197 rad | total_vel_violation=0
#   PRBS seed=45 | reason=completed | sim_time=60.00s | pos=1.4219 m | rot=0.0435 rad | total_vel_violation=0
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# OU seed=200043 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260524_045958/clean/diagnostic_plots/high_terminal_error_OU_seed200043.png
# PRBS seed=44 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260524_045958/clean/diagnostic_plots/high_terminal_error_PRBS_seed44.png
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=nominal_eval | noise_protocol=iid_noisy_ic | noise_budget=protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | scenarios=PRBS,CHIRP,OU | trajectories=18 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260524_045958/nominal_eval
# [scenario 1/3] PRBS | 6 trajectories
# [1/18] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=5m29.8s
# [5/18] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=50.5s
# [6/18] PRBS seed=47 done | reason=completed | sim_time=60.00s | eta=38.8s
# [scenario done] PRBS | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=1.1160 m | pos_p95=2.7042 m | rot_med=0.0146 rad | completion=1.000 | elapsed=19.4s
# [scenario 2/3] CHIRP | 6 trajectories
# [7/18] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=1m01.0s
# [11/18] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=24.7s
# [12/18] CHIRP seed=100047 done | reason=completed | sim_time=60.00s | eta=19.4s
# [scenario done] CHIRP | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=0.6372 m | pos_p95=1.0308 m | rot_med=0.0133 rad | completion=1.000 | elapsed=38.9s
# [scenario 3/3] OU | 6 trajectories
# [13/18] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=22.5s
# [17/18] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=3.4s
# [18/18] OU seed=200047 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=1.3516 m | pos_p95=2.7091 m | rot_med=0.0258 rad | completion=1.000 | elapsed=58.5s
# Benchmark finished in 1m11.1s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/rollout_benchmark/phase1a_iideval_traj6_seed42_20260524_045958/nominal_eval
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: Ablation: No Mass Prior [ablation/ablation]
# Canonical model type: ablate_no_mass_prior
# Energy semantics: mechanical_energy
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 6
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.2073 m | pos p95=0.3969 m | rot median=0.0118 rad | total vel median=0.0125 m/s | rel vel median=0.0112 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=0.3962 m | pos p95=1.1186 m | rot median=0.0141 rad | total vel median=0.0103 m/s | rel vel median=0.0110 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# ...
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 6
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.1843 m | pos p95=0.2728 m | rot median=0.0116 rad | total vel median=0.0113 m/s | rel vel median=0.0112 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=0.5452 m | pos p95=0.8460 m | rot median=0.0163 rad | total vel median=0.0108 m/s | rel vel median=0.0108 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=1.1650 m | pos p95=2.2597 m | rot median=0.0165 rad | total vel median=0.0181 m/s | rel vel median=0.0160 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=18 | completed=18 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1777 m | pos p95=0.3163 m | rot median=0.0091 rad | total vel median=0.0087 m/s | rel vel median=0.0093 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.4953 m | pos p95=0.7279 m | rot median=0.0154 rad | total vel median=0.0090 m/s | rel vel median=0.0101 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.3411 m | pos p95=1.8822 m | rot median=0.0161 rad | total vel median=0.0243 m/s | rel vel median=0.0166 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1843 m | pos p95=0.2067 m | rot median=0.0115 rad | total vel median=0.0133 m/s | rel vel median=0.0130 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.4061 m | pos p95=0.7739 m | rot median=0.0119 rad | total vel median=0.0089 m/s | rel vel median=0.0079 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=0.8491 m | pos p95=1.3485 m | rot median=0.0116 rad | total vel median=0.0104 m/s | rel vel median=0.0148 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1716 m | pos p95=0.2559 m | rot median=0.0214 rad | total vel median=0.0119 m/s | rel vel median=0.0114 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.5972 m | pos p95=1.0163 m | rot median=0.0224 rad | total vel median=0.0210 m/s | rel vel median=0.0207 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.3354 m | pos p95=2.2787 m | rot median=0.0312 rad | total vel median=0.0222 m/s | rel vel median=0.0207 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Largest completed terminal errors
#   OU seed=200047 | reason=completed | sim_time=60.00s | pos=2.2866 m | rot=0.0277 rad | total_vel_violation=0
#   OU seed=200043 | reason=completed | sim_time=60.00s | pos=2.2550 m | rot=0.0718 rad | total_vel_violation=0
#   PRBS seed=46 | reason=completed | sim_time=60.00s | pos=2.0372 m | rot=0.0249 rad | total_vel_violation=0
#   OU seed=200045 | reason=completed | sim_time=60.00s | pos=1.5975 m | rot=0.0403 rad | total_vel_violation=0
#   PRBS seed=43 | reason=completed | sim_time=60.00s | pos=1.4172 m | rot=0.0103 rad | total_vel_violation=0
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# OU seed=200047 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/rollout_benchmark/phase1a_v4eval_traj6_seed42_20260524_051438/diagnostic_plots/high_terminal_error_OU_seed200047.png
# OU seed=200043 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/rollout_benchmark/phase1a_v4eval_traj6_seed42_20260524_051438/diagnostic_plots/high_terminal_error_OU_seed200043.png
# Batch evaluation complete.
# [eval] suite=sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_ablate_no_mass_prior eval_protocol=v4_lite profiles=nominal_eval
# Suite directory: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_ablate_no_mass_prior
# Manifest: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_ablate_no_mass_prior/runs.tsv
# Mode: resampled
# [eval] ablation_ablate_no_mass_prior_seed42
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/best_model.pt | device=cuda | mode=resampled | noise_profile=nominal_eval | noise_protocol=v4_lite | noise_budget=protocol=v4_lite | profile=nominal_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | scenarios=PRBS,CHIRP,OU | trajectories=18 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/rollout_benchmark/phase1a_v4eval_traj6_seed42_20260524_051551
# [scenario 1/3] PRBS | 6 trajectories
# [1/18] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=5m18.1s
# [5/18] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=48.7s
# [6/18] PRBS seed=47 done | reason=completed | sim_time=60.00s | eta=37.5s
# [scenario done] PRBS | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=1.4307 m | pos_p95=1.9309 m | rot_med=0.0245 rad | completion=1.000 | elapsed=18.8s
# [scenario 2/3] CHIRP | 6 trajectories
# [7/18] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=58.1s
# [11/18] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=23.5s
# [12/18] CHIRP seed=100047 done | reason=completed | sim_time=60.00s | eta=18.5s
# [scenario done] CHIRP | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=0.9453 m | pos_p95=1.1559 m | rot_med=0.0109 rad | completion=1.000 | elapsed=37.0s
# [scenario 3/3] OU | 6 trajectories
# [13/18] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=21.2s
# [17/18] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=3.2s
# [18/18] OU seed=200047 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=6/6 | gt_div=0 | model_fail=0 | H=60.0s cond_n=6/6 | pos_med=1.9950 m | pos_p95=2.7283 m | rot_med=0.0435 rad | completion=1.000 | elapsed=55.1s
# Benchmark finished in 1m08.2s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/rollout_benchmark/phase1a_v4eval_traj6_seed42_20260524_051551
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: Ablation: No Mass Prior [ablation/ablation]
# Canonical model type: ablate_no_mass_prior
# Energy semantics: mechanical_energy
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 6
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.1787 m | pos p95=0.3158 m | rot median=0.0136 rad | total vel median=0.0121 m/s | rel vel median=0.0107 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=0.5813 m | pos p95=0.9028 m | rot median=0.0167 rad | total vel median=0.0134 m/s | rel vel median=0.0118 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=1.1431 m | pos p95=2.6839 m | rot median=0.0208 rad | total vel median=0.0174 m/s | rel vel median=0.0156 m/s | cond_n=18/18 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=18 | completed=18 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1731 m | pos p95=0.3012 m | rot median=0.0102 rad | total vel median=0.0083 m/s | rel vel median=0.0099 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.5813 m | pos p95=0.6905 m | rot median=0.0167 rad | total vel median=0.0109 m/s | rel vel median=0.0106 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.4307 m | pos p95=1.9309 m | rot median=0.0245 rad | total vel median=0.0245 m/s | rel vel median=0.0188 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1787 m | pos p95=0.2021 m | rot median=0.0141 rad | total vel median=0.0137 m/s | rel vel median=0.0132 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.4065 m | pos p95=0.6871 m | rot median=0.0089 rad | total vel median=0.0091 m/s | rel vel median=0.0075 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=0.9453 m | pos p95=1.1559 m | rot median=0.0109 rad | total vel median=0.0111 m/s | rel vel median=0.0136 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=6 | completed=6 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1619 m | pos p95=0.2886 m | rot median=0.0217 rad | total vel median=0.0106 m/s | rel vel median=0.0099 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.7465 m | pos p95=1.0086 m | rot median=0.0242 rad | total vel median=0.0231 m/s | rel vel median=0.0242 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.9950 m | pos p95=2.7283 m | rot median=0.0435 rad | total vel median=0.0244 m/s | rel vel median=0.0222 m/s | cond_n=6/6 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Largest completed terminal errors
#   OU seed=200043 | reason=completed | sim_time=60.00s | pos=2.7468 m | rot=0.0796 rad | total_vel_violation=0
#   OU seed=200045 | reason=completed | sim_time=60.00s | pos=2.6728 m | rot=0.0566 rad | total_vel_violation=0
#   OU seed=200047 | reason=completed | sim_time=60.00s | pos=2.3508 m | rot=0.0356 rad | total_vel_violation=0
#   PRBS seed=46 | reason=completed | sim_time=60.00s | pos=2.0492 m | rot=0.0235 rad | total_vel_violation=0
#   OU seed=200044 | reason=completed | sim_time=60.00s | pos=1.6392 m | rot=0.0515 rad | total_vel_violation=0
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# OU seed=200043 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/rollout_benchmark/phase1a_v4eval_traj6_seed42_20260524_051551/diagnostic_plots/high_terminal_error_OU_seed200043.png
# OU seed=200045 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/rollout_benchmark/phase1a_v4eval_traj6_seed42_20260524_051551/diagnostic_plots/high_terminal_error_OU_seed200045.png
# Batch evaluation complete.
# + /usr/bin/python3 /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/scripts/register_existing_runs_as_suite.py --suite-dir /content/_proxy_suites/sweep_oc_phase1a_smoke1_proxy_t2_wpfrag_ablate_no_mass_prior --run ablation ablate_no_mass_prior 42 clean__ablation_ablate_no_mass_prior_seed42 /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_clean_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42 --run ablation ablate_no_mass_prior 42 iid__ablation_ablate_no_mass_prior_seed42 /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42 --run ablation ablate_no_mass_prior 42 v4lite__ablation_ablate_no_mass_prior_seed42 /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_smoke1_v4lite_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42
# Registered suite: /content/_proxy_suites/sweep_oc_phase1a_smoke1_proxy_t2_wpfrag_ablate_no_mass_prior
# Runs: 3
# Manifest: /content/_proxy_suites/sweep_oc_phase1a_smoke1_proxy_t2_wpfrag_ablate_no_mass_prior/runs.tsv
# + /usr/bin/python3 /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/scripts/summarize_sweep.py --suite-dir /content/_proxy_suites/sweep_oc_phase1a_smoke1_proxy_t2_wpfrag_ablate_no_mass_prior
# + /usr/bin/python3 /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/scripts/build_experiment_report.py --suite-dir /content/_proxy_suites/sweep_oc_phase1a_smoke1_proxy_t2_wpfrag_ablate_no_mass_prior
# /content/_proxy_suites/sweep_oc_phase1a_smoke1_proxy_t2_wpfrag_ablate_no_mass_prior/phase1a_decision_brief.md
# [proxy] local: /content/_proxy_suites/sweep_oc_phase1a_smoke1_proxy_t2_wpfrag_ablate_no_mass_prior

# %% [markdown]
# ## 3. Decision train (3 protocols x 5 seeds)
# The 15 evidence-bearing training runs for this model.

# %%
os.environ["MODE"] = "decision_train"
# !bash scripts/run_phase1a_oc_v4lite.sh
# Out:
# Streaming output truncated to the last 5000 lines.
# position_rmse: ratio=14.170  degradation=+1317.0%
# rotation_geodesic: ratio=42.441  degradation=+4144.1%
# velocity_rmse: ratio=4.128  degradation=+312.8%
# angular_rmse: ratio=5.386  degradation=+438.6%
# success_rate: ratio=1.000  degradation=+0.0%
# trajectory_failure_rate: ratio=1.000  degradation=+0.0%
# [heading_biased_eval]
# position_rmse: ratio=21.741  degradation=+2074.1%
# rotation_geodesic: ratio=70.851  degradation=+6985.1%
# velocity_rmse: ratio=3.385  degradation=+238.5%
# angular_rmse: ratio=2.896  degradation=+189.6%
# success_rate: ratio=1.000  degradation=+0.0%
# trajectory_failure_rate: ratio=1.000  degradation=+0.0%
#
# Training finished. Results: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed44
# [train] ablation_ablate_no_mass_prior_seed45
# Loading dataset...
# Loaded: 83850 train, 21000 test, t_eval=[0.   0.05 0.1  0.15 0.2 ]
# Dataset split: trajectory | train trajectories: 559 | test trajectories: 140
# Dataset ID: d0be9434
# Dataset path: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl | velocity convention: body_total | state dim: 27
# Position std: [0.1508, 0.1400, 0.0370]
# Velocity std: u=0.4722, v=0.0898, w=0.0718, p=0.0248, q=0.0906, r=0.0526
# Actuator std: a0=0.1543, a1=0.1555, a2=299.0037
# Training noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# Model: Ablation: No Mass Prior [ablation/ablation] | canonical type: ablate_no_mass_prior
# Model parameters: 62,803
# Training dataset: id=d0be9434 | path=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Mass matrix initialized from physics
# Training: epochs<=300, target_steps=5000, warmup_steps=400, lr=6.00e-03 -> 1.00e-04, solver=rk4, so3_reg=1.00e-03
# Train samples: 83850, Test samples: 21000
# Epoch    1 | Step    20/ 5000 | Train 5.4090e-01 | Test 5.2862e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 4.10e-04 | 6.5s
# Epoch    2 | Step    40/ 5000 | Train 4.8402e-01 | Test 4.0528e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 7.05e-04 | 6.0s
# Epoch    3 | Step    60/ 5000 | Train 3.7190e-01 | Test 3.5685e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 1.00e-03 | 6.0s
# Epoch    4 | Step    80/ 5000 | Train 3.3536e-01 | Test 3.1588e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 1.29e-03 | 6.1s
# Epoch    5 | Step   100/ 5000 | Train 2.9298e-01 | Test 2.7288e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 1.59e-03 | 6.2s
# Epoch    6 | Step   120/ 5000 | Train 2.6529e-01 | Test 2.5587e-01 | SO3(train/test) 1.13e-07/1.13e-07 | Fail(train/test) 0/0 | LR 1.88e-03 | 6.2s
# Epoch    7 | Step   140/ 5000 | Train 2.5124e-01 | Test 2.5393e-01 | SO3(train/test) 1.14e-07/1.15e-07 | Fail(train/test) 0/0 | LR 2.18e-03 | 6.2s
# Epoch    8 | Step   160/ 5000 | Train 2.4435e-01 | Test 2.4389e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 2.47e-03 | 6.1s
# Epoch    9 | Step   180/ 5000 | Train 2.4453e-01 | Test 2.4066e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 2.77e-03 | 6.1s
# Epoch   10 | Step   200/ 5000 | Train 2.3863e-01 | Test 2.4479e-01 | SO3(train/test) 1.14e-07/1.15e-07 | Fail(train/test) 0/0 | LR 3.06e-03 | 6.0s
# Epoch   11 | Step   220/ 5000 | Train 2.3435e-01 | Test 2.1845e-01 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 3.36e-03 | 5.9s
# Epoch   12 | Step   240/ 5000 | Train 2.4508e-01 | Test 2.2547e-01 | SO3(train/test) 1.15e-07/1.14e-07 | Fail(train/test) 0/0 | LR 3.65e-03 | 6.0s
# Epoch   13 | Step   260/ 5000 | Train 2.2023e-01 | Test 2.0956e-01 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 3.95e-03 | 6.0s
# Epoch   14 | Step   280/ 5000 | Train 2.0799e-01 | Test 1.9417e-01 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.24e-03 | 6.0s
# Epoch   15 | Step   300/ 5000 | Train 2.0015e-01 | Test 2.2105e-01 | SO3(train/test) 1.16e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.54e-03 | 6.0s
# Epoch   16 | Step   320/ 5000 | Train 1.9294e-01 | Test 1.8318e-01 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.83e-03 | 6.0s
# Epoch   17 | Step   340/ 5000 | Train 1.8517e-01 | Test 1.9034e-01 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 5.13e-03 | 6.1s
# Epoch   18 | Step   360/ 5000 | Train 1.7721e-01 | Test 1.7089e-01 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 5.42e-03 | 6.3s
# Epoch   19 | Step   380/ 5000 | Train 1.6893e-01 | Test 1.5826e-01 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 5.72e-03 | 6.1s
# Epoch   20 | Step   400/ 5000 | Train 1.6275e-01 | Test 1.4810e-01 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 6.00e-03 | 6.0s
# Epoch   21 | Step   420/ 5000 | Train 1.5387e-01 | Test 1.4162e-01 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 6.00e-03 | 6.0s
# Epoch   22 | Step   440/ 5000 | Train 1.4424e-01 | Test 1.4368e-01 | SO3(train/test) 1.18e-07/1.19e-07 | Fail(train/test) 0/0 | LR 6.00e-03 | 6.1s
# Epoch   23 | Step   460/ 5000 | Train 1.4071e-01 | Test 1.3846e-01 | SO3(train/test) 1.19e-07/1.19e-07 | Fail(train/test) 0/0 | LR 6.00e-03 | 6.1s
# Epoch   24 | Step   480/ 5000 | Train 1.3384e-01 | Test 1.3101e-01 | SO3(train/test) 1.19e-07/1.19e-07 | Fail(train/test) 0/0 | LR 6.00e-03 | 6.2s
# Epoch   25 | Step   500/ 5000 | Train 1.2333e-01 | Test 1.2708e-01 | SO3(train/test) 1.19e-07/1.18e-07 | Fail(train/test) 0/0 | LR 5.99e-03 | 6.0s
# Epoch   26 | Step   520/ 5000 | Train 1.1683e-01 | Test 1.2404e-01 | SO3(train/test) 1.19e-07/1.19e-07 | Fail(train/test) 0/0 | LR 5.99e-03 | 6.1s
# Epoch   27 | Step   540/ 5000 | Train 1.1136e-01 | Test 1.1354e-01 | SO3(train/test) 1.19e-07/1.18e-07 | Fail(train/test) 0/0 | LR 5.99e-03 | 6.1s
# Epoch   28 | Step   560/ 5000 | Train 1.0778e-01 | Test 1.1249e-01 | SO3(train/test) 1.18e-07/1.18e-07 | Fail(train/test) 0/0 | LR 5.98e-03 | 6.1s
# Epoch   29 | Step   580/ 5000 | Train 1.0370e-01 | Test 1.1173e-01 | SO3(train/test) 1.18e-07/1.17e-07 | Fail(train/test) 0/0 | LR 5.98e-03 | 6.1s
# Epoch   30 | Step   600/ 5000 | Train 1.0118e-01 | Test 1.0690e-01 | SO3(train/test) 1.18e-07/1.17e-07 | Fail(train/test) 0/0 | LR 5.97e-03 | 6.0s
# Epoch   31 | Step   620/ 5000 | Train 9.8564e-02 | Test 1.0799e-01 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 5.97e-03 | 6.0s
# Epoch   32 | Step   640/ 5000 | Train 1.0139e-01 | Test 1.0085e-01 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.96e-03 | 6.0s
# Epoch   33 | Step   660/ 5000 | Train 1.0290e-01 | Test 1.0017e-01 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.95e-03 | 6.1s
# Epoch   34 | Step   680/ 5000 | Train 9.6602e-02 | Test 1.0456e-01 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.95e-03 | 6.0s
# Epoch   35 | Step   700/ 5000 | Train 8.8644e-02 | Test 9.0499e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.94e-03 | 6.0s
# Epoch   36 | Step   720/ 5000 | Train 8.5179e-02 | Test 9.1414e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 5.93e-03 | 6.0s
# Epoch   37 | Step   740/ 5000 | Train 8.6721e-02 | Test 9.4020e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.92e-03 | 6.1s
# Epoch   38 | Step   760/ 5000 | Train 9.4729e-02 | Test 1.3326e-01 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.91e-03 | 6.2s
# Epoch   39 | Step   780/ 5000 | Train 1.0845e-01 | Test 2.7737e-01 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.90e-03 | 6.0s
# Epoch   40 | Step   800/ 5000 | Train 2.9629e-01 | Test 2.9072e-01 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.89e-03 | 5.9s
# Epoch   41 | Step   820/ 5000 | Train 3.1984e-01 | Test 2.7936e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.88e-03 | 5.9s
# Epoch   42 | Step   840/ 5000 | Train 4.1114e-01 | Test 3.1545e-01 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.87e-03 | 6.0s
# Epoch   43 | Step   860/ 5000 | Train 2.0960e-01 | Test 1.6160e-01 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.86e-03 | 6.1s
# Epoch   44 | Step   880/ 5000 | Train 1.4588e-01 | Test 1.3233e-01 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.84e-03 | 6.0s
# Epoch   45 | Step   900/ 5000 | Train 1.6157e-01 | Test 1.3984e-01 | SO3(train/test) 1.15e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.83e-03 | 6.0s
# Epoch   46 | Step   920/ 5000 | Train 1.2969e-01 | Test 1.1090e-01 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.82e-03 | 6.0s
# Epoch   47 | Step   940/ 5000 | Train 1.0207e-01 | Test 9.8713e-02 | SO3(train/test) 1.14e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.80e-03 | 6.0s
# Epoch   48 | Step   960/ 5000 | Train 9.3540e-02 | Test 9.4113e-02 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.79e-03 | 6.1s
# Epoch   49 | Step   980/ 5000 | Train 8.9193e-02 | Test 9.0433e-02 | SO3(train/test) 1.15e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.77e-03 | 6.0s
# Epoch   50 | Step  1000/ 5000 | Train 8.5773e-02 | Test 8.4868e-02 | SO3(train/test) 1.15e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.76e-03 | 6.0s
# Epoch   51 | Step  1020/ 5000 | Train 8.3420e-02 | Test 8.3881e-02 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.74e-03 | 6.0s
# Epoch   52 | Step  1040/ 5000 | Train 8.0558e-02 | Test 8.4951e-02 | SO3(train/test) 1.15e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.72e-03 | 6.0s
# Epoch   53 | Step  1060/ 5000 | Train 7.9097e-02 | Test 8.4071e-02 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.71e-03 | 6.2s
# Epoch   54 | Step  1080/ 5000 | Train 7.7675e-02 | Test 8.2661e-02 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.69e-03 | 6.0s
# Epoch   55 | Step  1100/ 5000 | Train 7.5634e-02 | Test 8.0740e-02 | SO3(train/test) 1.15e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.67e-03 | 6.0s
# Epoch   56 | Step  1120/ 5000 | Train 7.3992e-02 | Test 7.8279e-02 | SO3(train/test) 1.15e-07/1.14e-07 | Fail(train/test) 0/0 | LR 5.65e-03 | 6.0s
# Epoch   57 | Step  1140/ 5000 | Train 7.2048e-02 | Test 8.0928e-02 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.63e-03 | 6.0s
# Epoch   58 | Step  1160/ 5000 | Train 7.1013e-02 | Test 7.5620e-02 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.61e-03 | 6.2s
# Epoch   59 | Step  1180/ 5000 | Train 6.9324e-02 | Test 7.4531e-02 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.59e-03 | 6.0s
# Epoch   60 | Step  1200/ 5000 | Train 6.9294e-02 | Test 7.7675e-02 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.57e-03 | 6.1s
# Epoch   61 | Step  1220/ 5000 | Train 6.8384e-02 | Test 8.5261e-02 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.55e-03 | 6.0s
# Epoch   62 | Step  1240/ 5000 | Train 6.9549e-02 | Test 7.5162e-02 | SO3(train/test) 1.15e-07/1.15e-07 | Fail(train/test) 0/0 | LR 5.53e-03 |
-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 2.10e-03 | 6.1s
# Epoch  160 | Step  3200/ 5000 | Train 1.1299e-02 | Test 1.4052e-02 | SO3(train/test) 1.16e-07/1.16e-07 | Fail(train/test) 0/0 | LR 2.06e-03 | 6.1s
# Epoch  161 | Step  3220/ 5000 | Train 1.3725e-02 | Test 1.7598e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 2.02e-03 | 6.1s
# Epoch  162 | Step  3240/ 5000 | Train 1.1127e-02 | Test 1.0555e-02 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.99e-03 | 6.0s
# Epoch  163 | Step  3260/ 5000 | Train 9.8893e-03 | Test 1.0592e-02 | SO3(train/test) 1.16e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.95e-03 | 6.2s
# Epoch  164 | Step  3280/ 5000 | Train 9.5085e-03 | Test 1.0143e-02 | SO3(train/test) 1.16e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.91e-03 | 6.0s
# Epoch  165 | Step  3300/ 5000 | Train 9.1958e-03 | Test 1.0091e-02 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.87e-03 | 6.1s
# Epoch  166 | Step  3320/ 5000 | Train 8.9969e-03 | Test 9.6241e-03 | SO3(train/test) 1.16e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.84e-03 | 6.0s
# Epoch  167 | Step  3340/ 5000 | Train 8.8099e-03 | Test 9.9192e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.80e-03 | 6.1s
# Epoch  168 | Step  3360/ 5000 | Train 8.6679e-03 | Test 9.9634e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.76e-03 | 6.2s
# Epoch  169 | Step  3380/ 5000 | Train 8.4348e-03 | Test 9.0808e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.73e-03 | 6.1s
# Epoch  170 | Step  3400/ 5000 | Train 8.2320e-03 | Test 9.6040e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.69e-03 | 6.0s
# Epoch  171 | Step  3420/ 5000 | Train 8.2055e-03 | Test 8.4911e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.66e-03 | 6.1s
# Epoch  172 | Step  3440/ 5000 | Train 8.0199e-03 | Test 8.3977e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.62e-03 | 6.1s
# Epoch  173 | Step  3460/ 5000 | Train 7.8009e-03 | Test 8.5237e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.59e-03 | 6.2s
# Epoch  174 | Step  3480/ 5000 | Train 7.6582e-03 | Test 8.0930e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.55e-03 | 6.0s
# Epoch  175 | Step  3500/ 5000 | Train 7.5280e-03 | Test 8.4112e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.52e-03 | 6.0s
# Epoch  176 | Step  3520/ 5000 | Train 7.4227e-03 | Test 8.0648e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.48e-03 | 6.2s
# Epoch  177 | Step  3540/ 5000 | Train 7.2809e-03 | Test 7.9057e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.45e-03 | 6.2s
# Epoch  178 | Step  3560/ 5000 | Train 7.1618e-03 | Test 7.7195e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.41e-03 | 6.1s
# Epoch  179 | Step  3580/ 5000 | Train 7.0288e-03 | Test 7.4469e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.38e-03 | 6.0s
# Epoch  180 | Step  3600/ 5000 | Train 6.8974e-03 | Test 7.3039e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.35e-03 | 6.0s
# Epoch  181 | Step  3620/ 5000 | Train 6.8399e-03 | Test 6.9679e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.31e-03 | 6.0s
# Epoch  182 | Step  3640/ 5000 | Train 6.7071e-03 | Test 7.4347e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.28e-03 | 6.1s
# Epoch  183 | Step  3660/ 5000 | Train 6.6020e-03 | Test 7.0416e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.25e-03 | 6.1s
# Epoch  184 | Step  3680/ 5000 | Train 6.5097e-03 | Test 6.9549e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.22e-03 | 6.0s
# Epoch  185 | Step  3700/ 5000 | Train 6.4613e-03 | Test 6.7324e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.19e-03 | 6.0s
# Epoch  186 | Step  3720/ 5000 | Train 6.4042e-03 | Test 6.7595e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.16e-03 | 6.0s
# Epoch  187 | Step  3740/ 5000 | Train 6.3812e-03 | Test 7.0040e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.13e-03 | 6.0s
# Epoch  188 | Step  3760/ 5000 | Train 6.1939e-03 | Test 6.6253e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.10e-03 | 6.1s
# Epoch  189 | Step  3780/ 5000 | Train 6.0577e-03 | Test 6.4651e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.07e-03 | 6.0s
# Epoch  190 | Step  3800/ 5000 | Train 6.0256e-03 | Test 6.6262e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.04e-03 | 6.1s
# Epoch  191 | Step  3820/ 5000 | Train 5.9890e-03 | Test 6.4742e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.01e-03 | 6.0s
# Epoch  192 | Step  3840/ 5000 | Train 5.9308e-03 | Test 6.2069e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 9.77e-04 | 6.0s
# Epoch  193 | Step  3860/ 5000 | Train 5.8822e-03 | Test 6.0114e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 9.49e-04 | 6.1s
# Epoch  194 | Step  3880/ 5000 | Train 5.8210e-03 | Test 6.5157e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 9.21e-04 | 6.0s
# Epoch  195 | Step  3900/ 5000 | Train 5.7978e-03 | Test 5.9985e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 8.93e-04 | 6.0s
# Epoch  196 | Step  3920/ 5000 | Train 5.6815e-03 | Test 5.7298e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 8.66e-04 | 6.1s
# Epoch  197 | Step  3940/ 5000 | Train 5.6362e-03 | Test 5.7649e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 8.39e-04 | 6.1s
# Epoch  198 | Step  3960/ 5000 | Train 5.3701e-03 | Test 5.6578e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 8.12e-04 | 6.2s
# Epoch  199 | Step  3980/ 5000 | Train 5.2027e-03 | Test 5.5695e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 7.86e-04 | 6.0s
# Epoch  200 | Step  4000/ 5000 | Train 5.1450e-03 | Test 5.5721e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 7.61e-04 | 6.1s
# Epoch  201 | Step  4020/ 5000 | Train 5.1105e-03 | Test 5.3864e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 7.35e-04 | 6.0s
# Epoch  202 | Step  4040/ 5000 | Train 5.0421e-03 | Test 5.3021e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 7.11e-04 | 6.0s
# Epoch  203 | Step  4060/ 5000 | Train 4.9915e-03 | Test 5.2964e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 6.86e-04 | 6.0s
# Epoch  204 | Step  4080/ 5000 | Train 4.9743e-03 | Test 5.2925e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 6.62e-04 | 6.0s
# Epoch  205 | Step  4100/ 5000 | Train 4.9503e-03 | Test 5.1816e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 6.39e-04 | 5.9s
# Epoch  206 | Step  4120/ 5000 | Train 4.8970e-03 | Test 5.1867e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 6.16e-04 | 5.9s
# Epoch  207 | Step  4140/ 5000 | Train 4.8851e-03 | Test 5.2853e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.93e-04 | 6.0s
# Epoch  208 | Step  4160/ 5000 | Train 4.8774e-03 | Test 5.1402e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 5.71e-04 | 6.1s
# Epoch  209 | Step  4180/ 5000 | Train 4.8251e-03 | Test 5.1030e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 5.50e-04 | 6.0s
# Epoch  210 | Step  4200/ 5000 | Train 4.7948e-03 | Test 5.0926e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 5.29e-04 | 6.0s
# Epoch  211 | Step  4220/ 5000 | Train 4.8008e-03 | Test 5.0742e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 5.08e-04 | 6.0s
# Epoch  212 | Step  4240/ 5000 | Train 4.7753e-03 | Test 5.0318e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.88e-04 | 6.0s
# Epoch  213 | Step  4260/ 5000 | Train 4.7433e-03 | Test 5.0077e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.68e-04 | 6.1s
# Epoch  214 | Step  4280/ 5000 | Train 4.7507e-03 | Test 5.0340e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.49e-04 | 6.1s
# Epoch  215 | Step  4300/ 5000 | Train 4.7297e-03 | Test 4.9901e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 4.30e-04 | 6.1s
# Epoch  216 | Step  4320/ 5000 | Train 4.7024e-03 | Test 4.9759e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 4.12e-04 | 6.1s
# Epoch  217 | Step  4340/ 5000 | Train 4.6941e-03 | Test 4.9791e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.94e-04 | 6.0s
# Epoch  218 | Step  4360/ 5000 | Train 4.6809e-03 | Test 4.9278e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.77e-04 | 6.1s
# Epoch  219 | Step  4380/ 5000 | Train 4.6627e-03 | Test 4.9422e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.60e-04 | 6.0s
# Epoch  220 | Step  4400/ 5000 | Train 4.6532e-03 | Test 4.9448e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.44e-04 | 6.0s
# Epoch  221 | Step  4420/ 5000 | Train 4.6494e-03 | Test 4.9182e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.28e-04 | 6.0s
# Epoch  222 | Step  4440/ 5000 | Train 4.6404e-03 | Test 4.8968e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 3.12e-04 | 6.0s
# Epoch  223 | Step  4460/ 5000 | Train 4.6277e-03 | Test 4.8811e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.98e-04 | 6.2s
# Epoch  224 | Step  4480/ 5000 | Train 4.6168e-03 | Test 4.8989e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.83e-04 | 6.0s
# Epoch  225 | Step  4500/ 5000 | Train 4.6056e-03 | Test 4.8571e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.70e-04 | 6.0s
# Epoch  226 | Step  4520/ 5000 | Train 4.5831e-03 | Test 4.8606e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.57e-04 | 6.0s
# Epoch  227 | Step  4540/ 5000 | Train 4.5781e-03 | Test 4.8280e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.44e-04 | 6.0s
# Epoch  228 | Step  4560/ 5000 | Train 4.5722e-03 | Test 4.8270e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.32e-04 | 6.2s
# Epoch  229 | Step  4580/ 5000 | Train 4.5565e-03 | Test 4.8210e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.20e-04 | 6.0s
# Epoch  230 | Step  4600/ 5000 | Train 4.5551e-03 | Test 4.8139e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 2.09e-04 | 6.0s
# Epoch  231 | Step  4620/ 5000 | Train 4.5561e-03 | Test 4.7909e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.98e-04 | 6.0s
# Epoch  232 | Step  4640/ 5000 | Train 4.5340e-03 | Test 4.7894e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.88e-04 | 6.0s
# Epoch  233 | Step  4660/ 5000 | Train 4.5346e-03 | Test 4.7975e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.79e-04 | 6.1s
# Epoch  234 | Step  4680/ 5000 | Train 4.5306e-03 | Test 4.7753e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.70e-04 | 6.1s
# Epoch  235 | Step  4700/ 5000 | Train 4.5287e-03 | Test 4.7783e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.61e-04 | 6.1s
# Epoch  236 | Step  4720/ 5000 | Train 4.5140e-03 | Test 4.7898e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.53e-04 | 6.1s
# Epoch  237 | Step  4740/ 5000 | Train 4.5166e-03 | Test 4.7584e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.46e-04 | 6.0s
# Epoch  238 | Step  4760/ 5000 | Train 4.5066e-03 | Test 4.7600e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.39e-04 | 6.1s
# Epoch  239 | Step  4780/ 5000 | Train 4.4999e-03 | Test 4.7641e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.33e-04 | 6.0s
# Epoch  240 | Step  4800/ 5000 | Train 4.5030e-03 | Test 4.7464e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.27e-04 | 6.1s
# Epoch  241 | Step  4820/ 5000 | Train 4.5013e-03 | Test 4.7517e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.22e-04 | 6.1s
# Epoch  242 | Step  4840/ 5000 | Train 4.4930e-03 | Test 4.7624e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.17e-04 | 6.0s
# Epoch  243 | Step  4860/ 5000 | Train 4.4984e-03 | Test 4.7356e-03 | SO3(train/test) 1.17e-07/1.16e-07 | Fail(train/test) 0/0 | LR 1.13e-04 | 6.1s
# Epoch  244 | Step  4880/ 5000 | Train 4.4873e-03 | Test 4.7378e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.10e-04 | 6.1s
# Epoch  245 | Step  4900/ 5000 | Train 4.4821e-03 | Test 4.7521e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.07e-04 | 6.0s
# Epoch  246 | Step  4920/ 5000 | Train 4.4793e-03 | Test 4.7248e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.04e-04 | 6.1s
# Epoch  247 | Step  4940/ 5000 | Train 4.4768e-03 | Test 4.7202e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.02e-04 | 6.1s
# Epoch  248 | Step  4960/ 5000 | Train 4.4682e-03 | Test 4.7157e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.01e-04 | 6.2s
# Epoch  249 | Step  4980/ 5000 | Train 4.4624e-03 | Test 4.7125e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.00e-04 | 6.1s
# Epoch  250 | Step  5000/ 5000 | Train 4.4657e-03 | Test 4.7171e-03 | SO3(train/test) 1.17e-07/1.17e-07 | Fail(train/test) 0/0 | LR 1.00e-04 | 6.1s
# Reached target optimizer steps: 5000/5000
# Done. Best validation score: failure_rate=0.0000, test_loss=4.7125e-03 (epoch 249)
# Running detailed evaluation...
# Block evaluation profile: clean
# Block evaluation noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0002 +/- 0.0001  (max 0.0009)
# Rotation geo [rad]:  0.0005 +/- 0.0000  (max 0.0007)
# Lin vel RMSE [m/s]:  0.0019 +/- 0.0013
# Ang vel RMSE [r/s]:  0.0010 +/- 0.0006
# Components:  u=0.0031  v=0.0005  w=0.0003  p=0.0007  q=0.0011  r=0.0007
# SO(3) violation:  |det-1|=6.37e-08  ||RR^T-I||=1.29e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# Block evaluation profile: nominal_eval
# Block evaluation noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0014 +/- 0.0008  (max 0.0053)
# Rotation geo [rad]:  0.0089 +/- 0.0057  (max 0.0347)
# Lin vel RMSE [m/s]:  0.0050 +/- 0.0022
# Ang vel RMSE [r/s]:  0.0032 +/- 0.0020
# Components:  u=0.0065  v=0.0033  w=0.0029  p=0.0047  q=0.0014  r=0.0014
# SO(3) violation:  |det-1|=3.07e-07  ||RR^T-I||=6.38e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# Block evaluation profile: heading_biased_eval
# Block evaluation noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0049 +/- 0.0017  (max 0.0101)
# Rotation geo [rad]:  0.0357 +/- 0.0102  (max 0.0665)
# Lin vel RMSE [m/s]:  0.0082 +/- 0.0037
# Ang vel RMSE [r/s]:  0.0032 +/- 0.0020
# Components:  u=0.0083  v=0.0090  w=0.0032  p=0.0047  q=0.0014  r=0.0014
# SO(3) violation:  |det-1|=2.86e-07  ||RR^T-I||=6.09e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Block Evaluation Relative To Clean
# ==================================================
# [nominal_eval]
# position_rmse: ratio=8.369  degradation=+736.9%
# rotation_geodesic: ratio=18.039  degradation=+1703.9%
# velocity_rmse: ratio=2.634  degradation=+163.4%
# angular_rmse: ratio=3.200  degradation=+220.0%
# failure_rate: ratio=1.000  degradation=+0.0%
# [heading_biased_eval]
# position_rmse: ratio=29.856  degradation=+2885.6%
# rotation_geodesic: ratio=72.583  degradation=+7158.3%
# velocity_rmse: ratio=4.317  degradation=+331.7%
# angular_rmse: ratio=3.203  degradation=+220.3%
# failure_rate: ratio=1.000  degradation=+0.0%
# Running held-out trajectory evaluation...
# Held-out evaluation profile: clean
# Held-out evaluation noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0001 (median 0.0001, p95 0.0002)
# Rotation geo [rad]:  0.0005 (median 0.0005, p95 0.0005)
# Lin vel RMSE [m/s]:  0.0015  Ang vel RMSE [r/s]:  0.0009
# SO(3) violation:  |det-1|=6.06e-08  ||RR^T-I||=1.17e-07
# Noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# [CHIRP] pos=0.0001 m, rot=0.0005 rad, success=1.0000
# [OU] pos=0.0002 m, rot=0.0005 rad, success=1.0000
# [PRBS] pos=0.0001 m, rot=0.0005 rad, success=1.0000
# Held-out evaluation profile: nominal_eval
# Held-out evaluation noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0011 (median 0.0011, p95 0.0014)
# Rotation geo [rad]:  0.0086 (median 0.0086, p95 0.0093)
# Lin vel RMSE [m/s]:  0.0044  Ang vel RMSE [r/s]:  0.0032
# SO(3) violation:  |det-1|=2.93e-07  ||RR^T-I||=6.22e-07
# Noise budget: protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# [CHIRP] pos=0.0011 m, rot=0.0086 rad, success=1.0000
# [OU] pos=0.0011 m, rot=0.0086 rad, success=1.0000
# [PRBS] pos=0.0011 m, rot=0.0087 rad, success=1.0000
# Held-out evaluation profile: degraded_eval
# Held-out evaluation noise budget: protocol=iid_noisy_ic | profile=degraded_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0026 (median 0.0026, p95 0.0034)
# Rotation geo [rad]:  0.0211 (median 0.0211, p95 0.0230)
# Lin vel RMSE [m/s]:  0.0086  Ang vel RMSE [r/s]:  0.0061
# SO(3) violation:  |det-1|=2.93e-07  ||RR^T-I||=6.23e-07
# Noise budget: protocol=iid_noisy_ic | profile=degraded_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250]
# [CHIRP] pos=0.0025 m, rot=0.0210 rad, success=1.0000
# [OU] pos=0.0025 m, rot=0.0210 rad, success=1.0000
# [PRBS] pos=0.0027 m, rot=0.0212 rad, success=1.0000
# Held-out evaluation profile: heading_biased_eval
# Held-out evaluation noise budget: protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0040 (median 0.0039, p95 0.0052)
# Rotation geo [rad]:  0.0351 (median 0.0350, p95 0.0364)
# Lin vel RMSE [m/s]:  0.0069  Ang vel RMSE [r/s]:  0.0032
# SO(3) violation:  |det-1|=2.92e-07  ||RR^T-I||=6.22e-07
# ...
# Ang vel RMSE [r/s]:  0.0012 +/- 0.0006
# Components:  u=0.0024  v=0.0007  w=0.0004  p=0.0012  q=0.0011  r=0.0008
# SO(3) violation:  |det-1|=6.22e-08  ||RR^T-I||=1.29e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# Block evaluation profile: nominal_eval
# Block evaluation noise budget: protocol=v4_lite | profile=nominal_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0011 +/- 0.0006  (max 0.0040)
# Rotation geo [rad]:  0.0070 +/- 0.0044  (max 0.0255)
# Lin vel RMSE [m/s]:  0.0046 +/- 0.0021
# Ang vel RMSE [r/s]:  0.0033 +/- 0.0019
# Components:  u=0.0054  v=0.0034  w=0.0032  p=0.0050  q=0.0013  r=0.0014
# SO(3) violation:  |det-1|=2.85e-07  ||RR^T-I||=6.25e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=v4_lite | profile=nominal_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# Block evaluation profile: heading_biased_eval
# Block evaluation noise budget: protocol=v4_lite | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Evaluation Results
# ==================================================
# Position RMSE [m]:   0.0048 +/- 0.0014  (max 0.0093)
# Rotation geo [rad]:  0.0349 +/- 0.0079  (max 0.0604)
# Lin vel RMSE [m/s]:  0.0078 +/- 0.0038
# Ang vel RMSE [r/s]:  0.0033 +/- 0.0019
# Components:  u=0.0073  v=0.0091  w=0.0036  p=0.0050  q=0.0013  r=0.0014
# SO(3) violation:  |det-1|=3.14e-07  ||RR^T-I||=6.76e-07
# Solver failures: 0  Invalid predictions: 0
# Evaluated on 500 samples
# Noise budget: protocol=v4_lite | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Block Evaluation Relative To Clean
# ==================================================
# [nominal_eval]
# position_rmse: ratio=8.467  degradation=+746.7%
# rotation_geodesic: ratio=14.176  degradation=+1317.6%
# velocity_rmse: ratio=3.051  degradation=+205.1%
# angular_rmse: ratio=2.748  degradation=+174.8%
# failure_rate: ratio=1.000  degradation=+0.0%
# [heading_biased_eval]
# position_rmse: ratio=37.472  degradation=+3647.2%
# rotation_geodesic: ratio=70.660  degradation=+6966.0%
# velocity_rmse: ratio=5.154  degradation=+415.4%
# angular_rmse: ratio=2.748  degradation=+174.8%
# failure_rate: ratio=1.000  degradation=+0.0%
# Running held-out trajectory evaluation...
# Held-out evaluation profile: clean
# Held-out evaluation noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0001 (median 0.0001, p95 0.0002)
# Rotation geo [rad]:  0.0005 (median 0.0005, p95 0.0005)
# Lin vel RMSE [m/s]:  0.0012  Ang vel RMSE [r/s]:  0.0011
# SO(3) violation:  |det-1|=6.07e-08  ||RR^T-I||=1.17e-07
# Noise budget: protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000]
# [CHIRP] pos=0.0001 m, rot=0.0005 rad, success=1.0000
# [OU] pos=0.0001 m, rot=0.0005 rad, success=1.0000
# [PRBS] pos=0.0001 m, rot=0.0005 rad, success=1.0000
# Held-out evaluation profile: nominal_eval
# Held-out evaluation noise budget: protocol=v4_lite | profile=nominal_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0011 (median 0.0011, p95 0.0014)
# Rotation geo [rad]:  0.0087 (median 0.0085, p95 0.0108)
# Lin vel RMSE [m/s]:  0.0043  Ang vel RMSE [r/s]:  0.0029
# SO(3) violation:  |det-1|=2.94e-07  ||RR^T-I||=6.25e-07
# Noise budget: protocol=v4_lite | profile=nominal_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100]
# [CHIRP] pos=0.0011 m, rot=0.0089 rad, success=1.0000
# [OU] pos=0.0011 m, rot=0.0087 rad, success=1.0000
# [PRBS] pos=0.0011 m, rot=0.0087 rad, success=1.0000
# Held-out evaluation profile: degraded_eval
# Held-out evaluation noise budget: protocol=v4_lite | profile=degraded_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0026 (median 0.0025, p95 0.0035)
# Rotation geo [rad]:  0.0213 (median 0.0209, p95 0.0268)
# Lin vel RMSE [m/s]:  0.0085  Ang vel RMSE [r/s]:  0.0054
# SO(3) violation:  |det-1|=2.97e-07  ||RR^T-I||=6.33e-07
# Noise budget: protocol=v4_lite | profile=degraded_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250]
# [CHIRP] pos=0.0026 m, rot=0.0217 rad, success=1.0000
# [OU] pos=0.0026 m, rot=0.0212 rad, success=1.0000
# [PRBS] pos=0.0027 m, rot=0.0212 rad, success=1.0000
# Held-out evaluation profile: heading_biased_eval
# Held-out evaluation noise budget: protocol=v4_lite | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# ==================================================
# Held-Out Trajectory Evaluation
# ==================================================
# Trajectories: 140  Success rate: 1.0000
# Position RMSE [m]:   0.0040 (median 0.0039, p95 0.0054)
# Rotation geo [rad]:  0.0352 (median 0.0354, p95 0.0390)
# Lin vel RMSE [m/s]:  0.0068  Ang vel RMSE [r/s]:  0.0029
# SO(3) violation:  |det-1|=2.91e-07  ||RR^T-I||=6.19e-07
# Noise budget: protocol=v4_lite | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350]
# [CHIRP] pos=0.0038 m, rot=0.0345 rad, success=1.0000
# [OU] pos=0.0039 m, rot=0.0352 rad, success=1.0000
# [PRBS] pos=0.0042 m, rot=0.0354 rad, success=1.0000
# ==================================================
# Held-Out Evaluation Relative To Clean
# ==================================================
# [nominal_eval]
# position_rmse: ratio=10.622  degradation=+962.2%
# rotation_geodesic: ratio=17.677  degradation=+1667.7%
# velocity_rmse: ratio=3.484  degradation=+248.4%
# angular_rmse: ratio=2.689  degradation=+168.9%
# success_rate: ratio=1.000  degradation=+0.0%
# trajectory_failure_rate: ratio=1.000  degradation=+0.0%
# [degraded_eval]
# position_rmse: ratio=25.002  degradation=+2400.2%
# rotation_geodesic: ratio=43.228  degradation=+4222.8%
# velocity_rmse: ratio=6.890  degradation=+589.0%
# angular_rmse: ratio=4.985  degradation=+398.5%
# success_rate: ratio=1.000  degradation=+0.0%
# trajectory_failure_rate: ratio=1.000  degradation=+0.0%
# [heading_biased_eval]
# position_rmse: ratio=38.207  degradation=+3720.7%
# rotation_geodesic: ratio=71.375  degradation=+7037.5%
# velocity_rmse: ratio=5.558  degradation=+455.8%
# angular_rmse: ratio=2.689  degradation=+168.9%
# success_rate: ratio=1.000  degradation=+0.0%
# trajectory_failure_rate: ratio=1.000  degradation=+0.0%
#
# Training finished. Results: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed46
# Training sweep complete.
# Manifest: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_ablate_no_mass_prior/runs.tsv
# Next step:
#   scripts/batch_eval_models.sh --suite-dir "/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_ablate_no_mass_prior"
#
# Training complete.
# Suite directory: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_ablate_no_mass_prior
# Next step:
#   bash scripts/eval_all_models_noise_profile.sh --suite-dir "/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_ablate_no_mass_prior"
# [audit] /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_clean_t2_wpfrag_ablate_no_mass_prior
# [audit] /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior
# [audit] /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_ablate_no_mass_prior
#                                                      suite_name    group           model_type  seed train_noise_protocol  best_epoch  best_loss  noise_warmup_epochs  noise_ramp_epochs  noise_mix_ratio  epoch_scale_at_best  is_effectively_clean_at_best
#  sweep_oc_phase1a_decision_clean_t2_wpfrag_ablate_no_mass_prior ablation ablate_no_mass_prior    42                clean         250   0.004923                   20                 80              0.5                  0.0                          True
#  sweep_oc_phase1a_decision_clean_t2_wpfrag_ablate_no_mass_prior ablation ablate_no_mass_prior    43                clean         249   0.005489                   20                 80              0.5                  0.0                          True
#  sweep_oc_phase1a_decision_clean_t2_wpfrag_ablate_no_mass_prior ablation ablate_no_mass_prior    44                clean         248   0.005630                   20                 80              0.5                  0.0                          True
#  sweep_oc_phase1a_decision_clean_t2_wpfrag_ablate_no_mass_prior ablation ablate_no_mass_prior    45                clean         249   0.004713                   20                 80              0.5                  0.0                          True
#  sweep_oc_phase1a_decision_clean_t2_wpfrag_ablate_no_mass_prior ablation ablate_no_mass_prior    46                clean         249   0.004738                   20                 80              0.5                  0.0                          True
#    sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior ablation ablate_no_mass_prior    42         iid_noisy_ic         249   0.006579                   20                 80              0.5                  1.0                         False
#    sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior ablation ablate_no_mass_prior    43         iid_noisy_ic         248   0.007758                   20                 80              0.5                  1.0                         False
#    sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior ablation ablate_no_mass_prior    44         iid_noisy_ic         244   0.007265                   20                 80              0.5                  1.0                         False
#    sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior ablation ablate_no_mass_prior    45         iid_noisy_ic         249   0.006893                   20                 80              0.5                  1.0                         False
#    sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior ablation ablate_no_mass_prior    46         iid_noisy_ic         245   0.006658                   20                 80              0.5                  1.0                         False
# sweep_oc_phase1a_decision_v4lite_t2_wpfrag_ablate_no_mass_prior ablation ablate_no_mass_prior    42              v4_lite         239   0.006673                   20                 80              0.5                  1.0                         False
# sweep_oc_phase1a_decision_v4lite_t2_wpfrag_ablate_no_mass_prior ablation ablate_no_mass_prior    43              v4_lite         245   0.007099                   20                 80              0.5                  1.0                         False
# sweep_oc_phase1a_decision_v4lite_t2_wpfrag_ablate_no_mass_prior ablation ablate_no_mass_prior    44              v4_lite         239   0.007446                   20                 80              0.5                  1.0                         False
# sweep_oc_phase1a_decision_v4lite_t2_wpfrag_ablate_no_mass_prior ablation ablate_no_mass_prior    45              v4_lite         242   0.006988                   20                 80              0.5                  1.0                         False
# sweep_oc_phase1a_decision_v4lite_t2_wpfrag_ablate_no_mass_prior ablation ablate_no_mass_prior    46              v4_lite         247   0.006770                   20                 80              0.5                  1.0                         False
# + /usr/bin/python3 /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/scripts/validate_v4_lite_protocol.py --run-dir /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42
# v4_lite protocol validation saved to: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/v4_lite_protocol_validation.json
# overall_passed=True
# same_epoch_stability: passed=True
# epoch_resampling: passed=True
# heading_bias_overlay: passed=True
# [validate] /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed42/v4_lite_protocol_validation.json

# %% [markdown]
# ## 4. Decision rollout eval (each trained suite x 4 robustness profiles)
# Evaluates the clean / iid / v4lite trained suites across `clean nominal_eval degraded_eval heading_biased_eval` (iid eval protocol) plus the `v4_lite` eval at `nominal_eval`.

# %%
os.environ["MODE"] = "decision_eval"
# !bash scripts/run_phase1a_oc_v4lite.sh
# Out:
# Streaming output truncated to the last 5000 lines.
# CHIRP
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.3154 m | pos p95=0.7478 m | rot median=0.0259 rad | total vel median=0.0175 m/s | rel vel median=0.0123 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.7368 m | pos p95=2.6290 m | rot median=0.0268 rad | total vel median=0.0144 m/s | rel vel median=0.0121 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.9832 m | pos p95=5.4938 m | rot median=0.0406 rad | total vel median=0.0167 m/s | rel vel median=0.0130 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=30 | completed=28 (0.933) | gt_divergence=0 (0.000) | pred_divergence=2 (0.067) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.3677 m | pos p95=0.8971 m | rot median=0.0243 rad | total vel median=0.0210 m/s | rel vel median=0.0189 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.0312 m | pos p95=2.9897 m | rot median=0.0313 rad | total vel median=0.0243 m/s | rel vel median=0.0194 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.9321 m | pos p95=7.1328 m | rot median=0.0304 rad | total vel median=0.0290 m/s | rel vel median=0.0254 m/s | cond_n=28/30 | completion=0.933 | gt_fail_by_h=0.000 | model_fail_by_h=0.067
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Earliest rollout failures
#   OU seed=200051 | reason=pred_divergence | sim_time=42.95s | pos=nan m | rot=nan rad | total_vel_violation=0
#   OU seed=200066 | reason=pred_divergence | sim_time=59.15s | pos=nan m | rot=nan rad | total_vel_violation=0
#
# Largest completed terminal errors
#   PRBS seed=42 | reason=completed | sim_time=60.00s | pos=11.9753 m | rot=0.1379 rad | total_vel_violation=0
#   PRBS seed=46 | reason=completed | sim_time=60.00s | pos=8.8793 m | rot=0.1305 rad | total_vel_violation=0
#   OU seed=200056 | reason=completed | sim_time=60.00s | pos=7.8008 m | rot=0.1159 rad | total_vel_violation=0
#   OU seed=200057 | reason=completed | sim_time=60.00s | pos=7.7143 m | rot=0.1147 rad | total_vel_violation=0
#   PRBS seed=63 | reason=completed | sim_time=60.00s | pos=6.6951 m | rot=0.0983 rad | total_vel_violation=0
#
# Completed rollouts with velocity violations
#   OU seed=200061 | reason=completed | sim_time=60.00s | pos=2.5189 m | rot=0.0248 rad | total_vel_violation=1
#   OU seed=200055 | reason=completed | sim_time=60.00s | pos=1.1123 m | rot=0.0185 rad | total_vel_violation=1
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# OU seed=200051 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed43/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_133306/degraded_eval/diagnostic_plots/rollout_failure_OU_seed200051.png
# OU seed=200066 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed43/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_133306/degraded_eval/diagnostic_plots/rollout_failure_OU_seed200066.png
# OU seed=200061 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed43/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_133306/degraded_eval/diagnostic_plots/velocity_violation_OU_seed200061.png
# OU seed=200055 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed43/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_133306/degraded_eval/diagnostic_plots/velocity_violation_OU_seed200055.png
# PRBS seed=42 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed43/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_133306/degraded_eval/diagnostic_plots/high_terminal_error_PRBS_seed42.png
# PRBS seed=46 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed43/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_133306/degraded_eval/diagnostic_plots/high_terminal_error_PRBS_seed46.png
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed43/best_model.pt | device=cuda | mode=resampled | noise_profile=heading_biased_eval | noise_protocol=iid_noisy_ic | noise_budget=protocol=iid_noisy_ic | profile=heading_biased_eval (base=nominal_eval) | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | rot_bias[yaw=0.0350] | scenarios=PRBS,CHIRP,OU | trajectories=90 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed43/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_133306/heading_biased_eval
# [scenario 1/3] PRBS | 30 trajectories
# [1/90] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=31m55.5s
# [5/90] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=6m06.1s
# [10/90] PRBS seed=51 done | reason=completed | sim_time=60.00s | eta=2m52.4s
# [15/90] PRBS seed=56 done | reason=completed | sim_time=60.00s | eta=1m47.8s
# [20/90] PRBS seed=61 done | reason=completed | sim_time=60.00s | eta=1m15.5s
# [25/90] PRBS seed=66 done | reason=completed | sim_time=60.00s | eta=56.1s
# [30/90] PRBS seed=71 done | reason=completed | sim_time=60.00s | eta=43.2s
# [scenario done] PRBS | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=3.0444 m | pos_p95=7.0799 m | rot_med=0.0499 rad | completion=1.000 | elapsed=21.6s
# [scenario 2/3] CHIRP | 30 trajectories
# [31/90] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=1m22.1s
# [35/90] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=1m07.8s
# [40/90] CHIRP seed=100051 done | reason=completed | sim_time=60.00s | eta=53.9s
# [45/90] CHIRP seed=100056 done | reason=completed | sim_time=60.00s | eta=43.2s
# [50/90] CHIRP seed=100061 done | reason=completed | sim_time=60.00s | eta=34.5s
# [55/90] CHIRP seed=100066 done | reason=completed | sim_time=60.00s | eta=27.5s
# [60/90] CHIRP seed=100071 done | reason=completed | sim_time=60.00s | eta=21.6s
# [scenario done] CHIRP | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=3.2932 m | pos_p95=6.1338 m | rot_med=0.0474 rad | completion=1.000 | elapsed=43.2s
# [scenario 3/3] OU | 30 trajectories
# [61/90] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=30.8s
# [65/90] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=24.9s
# [70/90] OU seed=200051 done | reason=pred_divergence | sim_time=42.95s | eta=18.5s
# [75/90] OU seed=200056 done | reason=completed | sim_time=60.00s | eta=13.0s
# [80/90] OU seed=200061 done | reason=completed | sim_time=60.00s | eta=8.1s
# [85/90] OU seed=200066 done | reason=pred_divergence | sim_time=59.15s | eta=3.8s
# [90/90] OU seed=200071 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=28/30 | gt_div=0 | model_fail=2 | H=60.0s cond_n=28/30 | pos_med=2.8352 m | pos_p95=6.9374 m | rot_med=0.0448 rad | completion=0.933 | elapsed=1m05.0s
# Benchmark finished in 1m23.4s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed43/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_133306/heading_biased_eval
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed43/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: Ablation: No Mass Prior [ablation/ablation]
# Canonical model type: ablate_no_mass_prior
# Energy semantics: mechanical_energy
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 30
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.4795 m | pos p95=0.9767 m | rot median=0.0351 rad | total vel median=0.0196 m/s | rel vel median=0.0152 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=1.4186 m | pos p95=3.0898 m | rot median=0.0355 rad | total vel median=0.0188 m/s | rel vel median=0.0150 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=2.9779 m | pos p95=6.7527 m | rot median=0.0472 rad | total vel median=0.0230 m/s | rel vel median=0.0161 m/s | cond_n=88/90 | completion=0.978 | gt_fail_by_h=0.000 | model_fail_by_h=0.022
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=90 | completed=88 (0.978) | gt_divergence=0 (0.000) | pred_divergence=2 (0.022) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.4237 m | pos p95=0.8987 m | rot median=0.0343 rad | total vel median=0.0208 m/s | rel vel median=0.0180 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.4072 m | pos p95=3.4198 m | rot median=0.0338 rad | total vel median=0.0194 m/s | rel vel median=0.0168 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=3.0444 m | pos p95=7.0799 m | rot median=0.0499 rad | total vel median=0.0233 m/s | rel vel median=0.0163 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.5009 m | pos p95=0.7533 m | rot median=0.0310 rad | total vel median=0.0184 m/s | rel vel median=0.0127 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.6666 m | pos p95=2.5488 m | rot median=0.0358 rad | total vel median=0.0156 m/s | rel vel median=0.0119 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=3.2932 m | pos p95=6.1338 m | rot median=0.0474 rad | total vel median=0.0169 m/s | rel vel median=0.0125 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=30 | completed=28 (0.933) | gt_divergence=0 (0.000) | pred_divergence=2 (0.067) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.5489 m | pos p95=0.9912 m | rot median=0.0365 rad | total vel median=0.0193 m/s | rel vel median=0.0189 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=1.3970 m | pos p95=3.1523 m | rot median=0.0397 rad | total vel median=0.0224 m/s | rel vel median=0.0195 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=2.8352 m | pos p95=6.9374 m | rot median=0.0448 rad | total vel median=0.0336 m/s | rel vel median=0.0253 m/s | cond_n=28/30 | completion=0.933 | gt_fail_by_h=0.000 | model_fail_by_h=0.067
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Earliest rollout failures
#   OU seed=200051 | reason=pred_divergence | sim_time=42.95s | pos=nan m | rot=nan rad | total_vel_violation=0
#   OU seed=200066 | reason=pred_divergence | sim_time=59.15s | pos=nan m | rot=nan rad | total_vel_violation=0
#
# Largest completed terminal errors
#   PRBS seed=56 | reason=completed | sim_time=60.00s | pos=8.7409 m | rot=0.1231 rad | total_vel_violation=0
#   OU seed=200057 | reason=completed | sim_time=60.00s | pos=8.4282 m | rot=0.1252 rad | total_vel_violation=0
#   PRBS seed=48 | reason=completed | sim_time=60.00s | pos=7.3495 m | rot=0.1144 rad | total_vel_violation=0
#   OU seed=200048 | reason=completed | sim_time=60.00s | pos=7.1942 m | rot=0.1246 rad | total_vel_violation=0
#   CHIRP seed=100058 | reason=completed | sim_time=60.00s | pos=6.7540 m | rot=0.1006 rad | total_vel_violation=0
#
# Completed rollouts with velocity violations
#   OU seed=200055 | reason=completed | sim_time=60.00s | pos=2.4993 m | rot=0.0335 rad | total_vel_violation=1
#   OU seed=200061 | reason=completed | sim_time=60.00s | pos=0.8880 m | rot=0.0196 rad | total_vel_violation=1
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# OU seed=200051 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed43/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_133306/heading_biased_eval/diagnostic_plots/rollout_failure_OU_seed200051.png
# OU seed=200066 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed43/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_133306/heading_biased_eval/diagnostic_plots/rollout_failure_OU_seed200066.png
# OU seed=200055 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed43/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_133306/heading_biased_eval/diagnostic_plots/velocity_violation_OU_seed200055.png
# OU seed=200061 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed43/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_133306/heading_biased_eval/diagnostic_plots/velocity_violation_OU_seed200061.png
# PRBS seed=56 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed43/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_133306/heading_biased_eval/diagnostic_plots/high_terminal_error_PRBS_seed56.png
# OU seed=200057 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed43/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_133306/heading_biased_eval/diagnostic_plots/high_terminal_error_OU_seed200057.png
# [eval] ablation_ablate_no_mass_prior_seed44
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed44/best_model.pt | device=cuda | mode=resampled | noise_profile=clean | noise_protocol=clean | noise_budget=protocol=clean | profile=clean | ref=remus100_dr | epoch_scale=0.000 | mix_ratio=0.000 | nu_r_lin_floor[u=0.0000, v=0.0000, w=0.0000] | nu_r_lin_ratio[u=0.0000, v=0.0000, w=0.0000] | nu_r_ang[p=0.0000, q=0.0000, r=0.0000] | rot[roll=0.0000, pitch=0.0000, yaw=0.0000] | scenarios=PRBS,CHIRP,OU | trajectories=90 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_134849/clean
# [scenario 1/3] PRBS | 30 trajectories
# [1/90] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=5h29m32.4s
# [5/90] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=1h02m57.0s
# [10/90] PRBS seed=51 done | reason=completed | sim_time=60.00s | eta=29m37.6s
# [15/90] PRBS seed=56 done | reason=completed | sim_time=60.00s | eta=18m31.1s
# [20/90] PRBS seed=61 done | reason=completed | sim_time=60.00s | eta=12m57.8s
# [25/90] PRBS seed=66 done | reason=completed | sim_time=60.00s | eta=9m37.8s
# [30/90] PRBS seed=71 done | reason=completed | sim_time=60.00s | eta=7m24.5s
# [scenario done] PRBS | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=1.6646 m | pos_p95=3.3024 m | rot_med=0.0369 rad | completion=1.000 | elapsed=3m42.3s
# [scenario 2/3] CHIRP | 30 trajectories
# [31/90] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=14m05.0s
# [35/90] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=11m37.7s
# [40/90] CHIRP seed=100051 done | reason=completed | sim_time=60.00s | eta=9m15.0s
# [45/90] CHIRP seed=100056 done | reason=completed | sim_time=60.00s | eta=7m24.0s
# [50/90] CHIRP seed=100061 done | reason=completed | sim_time=60.00s | eta=5m55.3s
# [55/90] CHIRP seed=100066 done | reason=completed | sim_time=60.00s | eta=4m42.6s
# [60/90] CHIRP seed=100071 done | reason=completed | sim_time=60.00s | eta=3m42.0s
# [scenario done] CHIRP | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=0.8842 m | pos_p95=3.0113 m | rot_med=0.0342 rad | completion=1.000 | elapsed=7m24.1s
# [scenario 3/3] OU | 30 trajectories
# [61/90] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=5m16.7s
# [65/90] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=4m16.2s
# [70/90] OU seed=200051 done | reason=completed | sim_time=60.00s | eta=3m10.4s
# [75/90] OU seed=200056 done | reason=completed | sim_time=60.00s | eta=2m13.3s
# [80/90] OU seed=200061 done | reason=completed | sim_time=60.00s | eta=1m23.3s
# [85/90] OU seed=200066 done | reason=pred_divergence | sim_time=59.55s | eta=39.2s
# [90/90] OU seed=200071 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=29/30 | gt_div=0 | model_fail=1 | H=60.0s cond_n=29/30 | pos_med=1.4385 m | pos_p95=3.3962 m | rot_med=0.0354 rad | completion=0.967 | elapsed=11m06.4s
# Benchmark finished in 11m25.3s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_134849/clean
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed44/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: Ablation: No Mass Prior [ablation/ablation]
# Canonical model type: ablate_no_mass_prior
# Energy semantics: mechanical_energy
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 30
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.1438 m | pos p95=0.2968 m | rot median=0.0118 rad | total vel median=0.0175 m/s | rel vel median=0.0169 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=0.4180 m | pos p95=1.2856 m | rot median=0.0177 rad | total vel median=0.0177 m/s | rel vel median=0.0176 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=1.2972 m | pos p95=3.3962 m | rot median=0.0359 rad | total vel median=0.0207 m/s | rel vel median=0.0161 m/s | cond_n=89/90 | completion=0.989 | gt_fail_by_h=0.000 | model_fail_by_h=0.011
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=90 | completed=89 (0.989) | gt_divergence=0 (0.000) | pred_divergence=1 (0.011) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1193 m | pos p95=0.2478 m | rot median=0.0102 rad | total vel median=0.0171 m/s | rel vel median=0.0171 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.4558 m | pos p95=1.1597 m | rot median=0.0208 rad | total vel median=0.0174 m/s | rel vel median=0.0170 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.6646 m | pos p95=3.3024 m | rot median=0.0369 rad | total vel median=0.0213 m/s | rel vel median=0.0179 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1220 m | pos p95=0.2585 m | rot median=0.0135 rad | total vel median=0.0132 m/s | rel vel median=0.0135 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.3596 m | pos p95=1.0667 m | rot median=0.0113 rad | total vel median=0.0127 m/s | rel vel median=0.0122 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=0.8842 m | pos p95=3.0113 m | rot median=0.0342 rad | total vel median=0.0168 m/s | rel vel median=0.0136 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=30 | completed=29 (0.967) | gt_divergence=0 (0.000) | pred_divergence=1 (0.033) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1948 m | pos p95=0.4191 m | rot median=0.0149 rad | total vel median=0.0222 m/s | rel vel median=0.0229 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.5268 m | pos p95=1.4693 m | rot median=0.0253 rad | total vel median=0.0211 m/s | rel vel median=0.0205 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.4385 m | pos p95=3.3962 m | rot median=0.0354 rad | total vel median=0.0301 m/s | rel vel median=0.0210 m/s | cond_n=29/30 | completion=0.967 | gt_fail_by_h=0.000 | model_fail_by_h=0.033
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Earliest rollout failures
#   OU seed=200066 | reason=pred_divergence | sim_time=59.55s | pos=nan m | rot=nan rad | total_vel_violation=0
#
# Largest completed terminal errors
#   OU seed=200065 | reason=completed | sim_time=60.00s | pos=5.2507 m | rot=0.1460 rad | total_vel_violation=0
#   CHIRP seed=100067 | reason=completed | sim_time=60.00s | pos=3.9657 m | rot=0.0786 rad | total_vel_violation=0
#   PRBS seed=68 | reason=completed | sim_time=60.00s | pos=3.8755 m | rot=0.0365 rad | total_vel_violation=0
#   PRBS seed=59 | reason=completed | sim_time=60.00s | pos=3.4596 m | rot=0.0630 rad | total_vel_violation=0
#   OU seed=200048 | reason=completed | sim_time=60.00s | pos=3.4469 m | rot=0.0768 rad | total_vel_violation=0
#
# Completed rollouts with velocity violations
#   OU seed=200061 | reason=completed | sim_time=60.00s | pos=1.7979 m | rot=0.0317 rad | total_vel_violation=1
#   OU seed=200055 | reason=completed | sim_time=60.00s | pos=0.8333 m | rot=0.0074 rad | total_vel_violation=1
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# OU seed=200066 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_134849/clean/diagnostic_plots/rollout_failure_OU_seed200066.png
# OU seed=200061 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_134849/clean/diagnostic_plots/velocity_violation_OU_seed200061.png
# OU seed=200055 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_134849/clean/diagnostic_plots/velocity_violation_OU_seed200055.png
# OU seed=200065 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_134849/clean/diagnostic_plots/high_terminal_error_OU_seed200065.png
# CHIRP seed=100067 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_134849/clean/diagnostic_plots/high_terminal_error_CHIRP_seed100067.png
# PRBS seed=68 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_134849/clean/diagnostic_plots/high_terminal_error_PRBS_seed68.png
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed44/best_model.pt | device=cuda | mode=resampled | noise_profile=nominal_eval | noise_protocol=iid_noisy_ic | noise_budget=protocol=iid_noisy_ic | profile=nominal_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | scenarios=PRBS,CHIRP,OU | trajectories=90 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_134849/nominal_eval
# [scenario 1/3] PRBS | 30 trajectories
# [1/90] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=32m57.3s
# [5/90] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=6m17.9s
# [10/90] PRBS seed=51 done | reason=completed | sim_time=60.00s | eta=2m58.0s
# [15/90] PRBS seed=56 done | reason=completed | sim_time=60.00s | eta=1m51.3s
# [20/90] PRBS seed=61 done | reason=completed | sim_time=60.00s | eta=1m18.0s
# [25/90] PRBS seed=66 done | reason=completed | sim_time=60.00s | eta=58.0s
# [30/90] PRBS seed=71 done | reason=completed | sim_time=60.00s | eta=44.6s
# [scenario done] PRBS | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=1.7090 m | pos_p95=3.9661 m | rot_med=0.0355 rad | completion=1.000 | elapsed=22.3s
# [scenario 2/3] CHIRP | 30 trajectories
# [31/90] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=1m24.1s
# [35/90] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=1m09.5s
# [40/90] CHIRP seed=100051 done | reason=completed | sim_time=60.00s | eta=55.3s
# [45/90] CHIRP seed=100056 done | reason=completed | sim_time=60.00s | eta=44.2s
# [50/90] CHIRP seed=100061 done | reason=completed | sim_time=60.00s | eta=35.4s
# [55/90] CHIRP seed=100066 done | reason=completed | sim_time=60.00s | eta=28.2s
# [60/90] CHIRP seed=100071 done | reason=completed | sim_time=60.00s | eta=22.1s
# [scenario done] CHIRP | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=1.1134 m | pos_p95=3.2470 m | rot_med=0.0323 rad | completion=1.000 | elapsed=44.3s
# [scenario 3/3] OU | 30 trajectories
# [61/90] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=31.4s
# [65/90] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=25.4s
# [70/90] OU seed=200051 done | reason=completed | sim_time=60.00s | eta=18.9s
# [75/90] OU seed=200056 done | reason=completed | sim_time=60.00s | eta=13.2s
# [80/90] OU seed=200061 done | reason=completed | sim_time=60.00s | eta=8.3s
# [85/90] OU seed=200066 done | reason=pred_divergence | sim_time=59.55s | eta=3.9s
# [90/90] OU seed=200071 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=29/30 | gt_div=0 | model_fail=1 | H=60.0s cond_n=29/30 | pos_med=1.7236 m | pos_p95=4.1894 m | rot_med=0.0404 rad | completion=0.967 | elapsed=1m06.3s
# Benchmark finished in 1m24.7s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_134849/nominal_eval
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed44/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: Ablation: No Mass Prior [ablation/ablation]
# Canonical model type: ablate_no_mass_prior
# Energy semantics: mechanical_energy
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 30
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.1895 m | pos p95=0.5150 m | rot median=0.0144 rad | total vel median=0.0176 m/s | rel vel median=0.0169 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=0.5792 m | pos p95=1.6684 m | rot median=0.0223 rad | total vel median=0.0174 m/s | rel vel median=0.0175 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=1.6001 m | pos p95=4.1894 m | rot median=0.0360 rad | total vel median=0.0210 m/s | rel vel median=0.0161 m/s | cond_n=89/90 | completion=0.989 | gt_fail_by_h=0.000 | model_fail_by_h=0.011
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=90 | completed=89 (0.989) | gt_divergence=0 (0.000) | pred_divergence=1 (0.011) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1768 m | pos p95=0.4170 m | rot median=0.0132 rad | total vel median=0.0173 m/s | rel vel median=0.0171 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.6226 m | pos p95=1.4532 m | rot median=0.0250 rad | total vel median=0.0175 m/s | rel vel median=0.0168 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.7090 m | pos p95=3.9661 m | rot median=0.0355 rad | total vel median=0.0217 m/s | rel vel median=0.0178 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1784 m | pos p95=0.3908 m | rot median=0.0149 rad | total vel median=0.0154 m/s | rel vel median=0.0136 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.5377 m | pos p95=1.2175 m | rot median=0.0141 rad | total vel median=0.0124 m/s | rel vel median=0.0121 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.1134 m | pos p95=3.2470 m | rot median=0.0323 rad | total vel median=0.0179 m/s | rel vel median=0.0136 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=30 | completed=29 (0.967) | gt_divergence=0 (0.000) | pred_divergence=1 (0.033) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.2673 m | pos p95=0.5900 m | rot median=0.0153 rad | total vel median=0.0229 m/s | rel vel median=0.0228 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.7562 m | pos p95=1.7248 m | rot median=0.0273 rad | total vel median=0.0194 m/s | rel vel median=0.0205 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.7236 m | pos p95=4.1894 m | rot median=0.0404 rad | total vel median=0.0306 m/s | rel vel median=0.0210 m/s | cond_n=29/30 | completion=0.967 | gt_fail_by_h=0.000 | model_fail_by_h=0.033
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Earliest rollout failures
#   OU seed=200066 | reason=pred_divergence | sim_time=59.55s | pos=nan m | rot=nan rad | total_vel_violation=0
#
# Largest completed terminal errors
#   PRBS seed=68 | reason=completed | sim_time=60.00s | pos=5.7495 m | rot=0.0517 rad | total_vel_violation=0
#   OU seed=200065 | reason=completed | sim_time=60.00s | pos=4.8796 m | rot=0.1405 rad | total_vel_violation=0
#   CHIRP seed=100067 | reason=completed | sim_time=60.00s | pos=4.4823 m | rot=0.0843 rad | total_vel_violation=0
#   PRBS seed=62 | reason=completed | sim_time=60.00s | pos=4.3196 m | rot=0.0336 rad | total_vel_violation=0
#   OU seed=200059 | reason=completed | sim_time=60.00s | pos=4.1935 m | rot=0.0419 rad | total_vel_violation=0
#
# Completed rollouts with velocity violations
#   OU seed=200055 | reason=completed | sim_time=60.00s | pos=1.8284 m | rot=0.0096 rad | total_vel_violation=1
#   OU seed=200061 | reason=completed | sim_time=60.00s | pos=1.3734 m | rot=0.0277 rad | total_vel_violation=1
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# OU seed=200066 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_134849/nominal_eval/diagnostic_plots/rollout_failure_OU_seed200066.png
# OU seed=200055 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_134849/nominal_eval/diagnostic_plots/velocity_violation_OU_seed200055.png
# OU seed=200061 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_134849/nominal_eval/diagnostic_plots/velocity_violation_OU_seed200061.png
# PRBS seed=68 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_134849/nominal_eval/diagnostic_plots/high_terminal_error_PRBS_seed68.png
# OU seed=200065 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_134849/nominal_eval/diagnostic_plots/high_terminal_error_OU_seed200065.png
# CHIRP seed=100067 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_134849/nominal_eval/diagnostic_plots/high_terminal_error_CHIRP_seed100067.png
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed44/best_model.pt | device=cuda | mode=resampled | noise_profile=degraded_eval | noise_protocol=iid_noisy_ic | noise_budget=protocol=iid_noisy_ic | profile=degraded_eval | ref=remus100_dr | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0060, v=0.0060, w=0.0080] | nu_r_lin_ratio[u=0.0060, v=0.0060, w=0.0060] | nu_r_ang[p=0.0015, q=0.0015, r=0.0030] | rot[roll=0.0040, pitch=0.0040, yaw=0.0250] | scenarios=PRBS,CHIRP,OU | trajectories=90 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_134849/degraded_eval
# [scenario 1/3] PRBS | 30 trajectories
# [1/90] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=32m26.5s
# [5/90] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=6m12.0s
# [10/90] PRBS seed=51 done | reason=completed | sim_time=60.00s | eta=2m55.2s
# [15/90] PRBS seed=56 done | reason=completed | sim_time=60.00s | eta=1m49.6s
# [20/90] PRBS seed=61 done | reason=completed | sim_time=60.00s | eta=1m16.8s
# [25/90] PRBS seed=66 done | reason=completed | sim_time=60.00s | eta=57.1s
# [30/90] PRBS seed=71 done | reason=completed | sim_time=60.00s | eta=43.9s
# [scenario done] PRBS | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=2.2537 m | pos_p95=6.5739 m | rot_med=0.0415 rad | completion=1.000 | elapsed=22.0s
# [scenario 2/3] CHIRP | 30 trajectories
# [31/90] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=1m23.6s
# [35/90] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=1m09.0s
# [40/90] CHIRP seed=100051 done | reason=completed | sim_time=60.00s | eta=54.9s
# [45/90] CHIRP seed=100056 done | reason=completed | sim_time=60.00s | eta=44.0s
# [50/90] CHIRP seed=100061 done | reason=completed | sim_time=60.00s | eta=35.2s
# [55/90] CHIRP seed=100066 done | reason=completed | sim_time=60.00s | eta=28.0s
# [60/90] CHIRP seed=100071 done | reason=completed | sim_time=60.00s | eta=22.0s
# [scenario done] CHIRP | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=2.0997 m | pos_p95=4.9879 m | rot_med=0.0374 rad | completion=1.000 | elapsed=44.0s
# [scenario 3/3] OU | 30 trajectories
# [61/90] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=31.4s
# [65/90] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=25.4s
# [70/90] OU seed=200051 done | reason=completed | sim_time=60.00s | eta=18.9s
# [75/90] OU seed=200056 done | reason=completed | sim_time=60.00s | eta=13.2s
# [80/90] OU seed=200061 done | reason=completed | sim_time=60.00s | eta=8.3s
# [85/90] OU seed=200066 done | reason=pred_divergence | sim_time=59.55s | eta=3.9s
# [90/90] OU seed=200071 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=29/30 | gt_div=0 | model_fail=1 | H=60.0s cond_n=29/30 | pos_med=2.2321 m | pos_p95=6.4775 m | rot_med=0.0469 rad | completion=0.967 | elapsed=1m06.1s
# Benchmark finished in 1m24.3s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed44/rollout_benchmark/phase1a_iideval_traj30_seed42_20260524_134849/degraded_eval
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed44/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: Ablation: No Mass Prior [ablation/ablation]
# Canonical model type: ablate_no_mass_prior
# Energy semantics: mechanical_energy
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 30
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.3410 m | pos p95=0.9912 m | rot median=0.0226 rad | total vel median=0.0202 m/s | rel vel median=0.0169 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=0.8314 m | pos p95=2.7514 m | rot median=0.0289 rad | total vel median=0.0186 m/s | rel vel median=0.0177 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=2.1894 m | pos p95=5.7616 m | rot median=0.0413 rad | total vel median=0.0220 m/s | rel vel median=0.0162 m/s | cond_n=89/90 | completion=0.989 | gt_fail_by_h=0.000 | model_fail_by_h=0.011
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=90 | completed=89 (0.989) | gt_divergence=0 (0.000) | pred_divergence=1 (0.011) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.3413 m | pos p95=0.9630 m | rot median=0.0249 rad | total vel median=0.0191 m/s | rel vel median=0.0170 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.8885 m | pos p95=2.9062 m | rot median=0.0311 rad | total vel median=0.0191 m/s | rel vel median=0.0170 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=2.2537 m | pos p95=6.5739 m | rot median=0.0415 rad | total vel median=0.0227 m/s | rel vel median=0.0178 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.2520 m | pos p95=0.8256 m | rot median=0.0175 rad | total vel median=0.0182 m/s | rel vel median=0.0137 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.8114 m | pos p95=2.2611 m | rot median=0.0208 rad | total vel median=0.0139 m/s | rel vel median=0.0121 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=2.0997 m | pos p95=4.9879 m | rot median=0.0374 rad | total vel median=0.0174 m/s | rel vel median=0.0137 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=30 | completed=29 (0.967) | gt_divergence=0 (0.000) | pred_divergence=1 (0.033) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.3649 m | pos p95=0.9912 m | rot median=0.0269 rad | total vel median=0.0247 m/s | rel vel median=0.0227 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.9103 m | pos p95=2.7333 m | rot median=0.0378 rad | total vel median=0.0234 m/s | rel vel median=0.0205 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=2.2321 m | pos p95=6.4775 m | rot median=0.0469 rad | total vel median=0.0269 m/s | rel vel median=0.0211 m/s | cond_n=29/30 | completion=0.967 | gt_fail_by_h=0.000 | model_fail_by_h=0.033
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Earliest rollout failures
#   OU seed=200066 | reason=pred_divergence | sim_time=59.55s | pos=nan m | rot=nan rad | total_vel_violation=0
#
# Largest completed terminal errors
#   PRBS seed=68 | reason=completed | sim_time=60.00s | pos=8.6229 m | rot=0.0752 rad | total_vel_violation=0
#   PRBS seed=62 | reason=completed | sim_time=60.00s | pos=7.7916 m | rot=0.0631 rad | total_vel_violation=0
#   OU seed=200056 | reason=completed | sim_time=60.00s | pos=7.6643 m | rot=0.1203 rad | total_vel_violation=0
#   OU seed=200059 | reason=completed | sim_time=60.00s | pos=6.9258 m | rot=0.0683 rad | total_vel_violation=0
#   OU seed=200057 | reason=completed | sim_time=60.00s | pos=5.8049 m | rot=0.1054 rad | total_vel_violation=0
#
# Completed rollouts with velocity violations
#   OU seed=200061 | reason=completed | sim_time=60.00s | pos=0.7713 m | rot=0.0222 rad | total_vel_violation=1
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# ...
#   H=10.0s | pos median=0.1745 m | pos p95=0.3219 m | rot median=0.0194 rad | total vel median=0.0176 m/s | rel vel median=0.0166 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.5984 m | pos p95=1.7072 m | rot median=0.0377 rad | total vel median=0.0185 m/s | rel vel median=0.0128 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.1988 m | pos p95=2.8882 m | rot median=0.0160 rad | total vel median=0.0152 m/s | rel vel median=0.0147 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=30 | completed=29 (0.967) | gt_divergence=0 (0.000) | pred_divergence=1 (0.033) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.2071 m | pos p95=0.4836 m | rot median=0.0168 rad | total vel median=0.0245 m/s | rel vel median=0.0237 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.6682 m | pos p95=2.0297 m | rot median=0.0326 rad | total vel median=0.0264 m/s | rel vel median=0.0230 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.9089 m | pos p95=5.1419 m | rot median=0.0498 rad | total vel median=0.0335 m/s | rel vel median=0.0311 m/s | cond_n=29/30 | completion=0.967 | gt_fail_by_h=0.000 | model_fail_by_h=0.033
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Earliest rollout failures
#   OU seed=200066 | reason=pred_divergence | sim_time=58.95s | pos=nan m | rot=nan rad | total_vel_violation=0
#
# Largest completed terminal errors
#   OU seed=200062 | reason=completed | sim_time=60.00s | pos=5.3254 m | rot=0.0454 rad | total_vel_violation=0
#   PRBS seed=63 | reason=completed | sim_time=60.00s | pos=5.3008 m | rot=0.0642 rad | total_vel_violation=0
#   OU seed=200048 | reason=completed | sim_time=60.00s | pos=5.1715 m | rot=0.1425 rad | total_vel_violation=0
#   OU seed=200071 | reason=completed | sim_time=60.00s | pos=5.0975 m | rot=0.0488 rad | total_vel_violation=0
#   OU seed=200047 | reason=completed | sim_time=60.00s | pos=4.6950 m | rot=0.0641 rad | total_vel_violation=0
#
# Completed rollouts with velocity violations
#   OU seed=200055 | reason=completed | sim_time=60.00s | pos=1.8870 m | rot=0.0293 rad | total_vel_violation=1
#   OU seed=200061 | reason=completed | sim_time=60.00s | pos=1.3784 m | rot=0.0594 rad | total_vel_violation=1
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# OU seed=200066 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed45/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260524_161248/diagnostic_plots/rollout_failure_OU_seed200066.png
# OU seed=200055 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed45/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260524_161248/diagnostic_plots/velocity_violation_OU_seed200055.png
# OU seed=200061 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed45/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260524_161248/diagnostic_plots/velocity_violation_OU_seed200061.png
# OU seed=200062 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed45/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260524_161248/diagnostic_plots/high_terminal_error_OU_seed200062.png
# PRBS seed=63 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed45/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260524_161248/diagnostic_plots/high_terminal_error_PRBS_seed63.png
# OU seed=200048 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed45/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260524_161248/diagnostic_plots/high_terminal_error_OU_seed200048.png
# [eval] ablation_ablate_no_mass_prior_seed46
# Starting rollout benchmark | checkpoint=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed46/best_model.pt | device=cuda | mode=resampled | noise_profile=nominal_eval | noise_protocol=v4_lite | noise_budget=protocol=v4_lite | profile=nominal_eval | ref=remus100_dr | traj_corr=0.850 | epoch_scale=1.000 | mix_ratio=0.500 | nu_r_lin_floor[u=0.0030, v=0.0030, w=0.0040] | nu_r_lin_ratio[u=0.0030, v=0.0030, w=0.0030] | nu_r_ang[p=0.0008, q=0.0008, r=0.0015] | rot[roll=0.0020, pitch=0.0020, yaw=0.0100] | scenarios=PRBS,CHIRP,OU | trajectories=90 | max_horizon=60.0s | output_dir=/content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260524_161414
# [scenario 1/3] PRBS | 30 trajectories
# [1/90] PRBS seed=42 done | reason=completed | sim_time=60.00s | eta=31m47.4s
# [5/90] PRBS seed=46 done | reason=completed | sim_time=60.00s | eta=6m04.6s
# [10/90] PRBS seed=51 done | reason=completed | sim_time=60.00s | eta=2m51.7s
# [15/90] PRBS seed=56 done | reason=completed | sim_time=60.00s | eta=1m47.4s
# [20/90] PRBS seed=61 done | reason=completed | sim_time=60.00s | eta=1m15.2s
# [25/90] PRBS seed=66 done | reason=completed | sim_time=60.00s | eta=55.9s
# [30/90] PRBS seed=71 done | reason=completed | sim_time=60.00s | eta=43.1s
# [scenario done] PRBS | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=1.8204 m | pos_p95=3.2678 m | rot_med=0.0245 rad | completion=1.000 | elapsed=21.6s
# [scenario 2/3] CHIRP | 30 trajectories
# [31/90] CHIRP seed=100042 done | reason=completed | sim_time=60.00s | eta=1m21.1s
# [35/90] CHIRP seed=100046 done | reason=completed | sim_time=60.00s | eta=1m07.0s
# [40/90] CHIRP seed=100051 done | reason=completed | sim_time=60.00s | eta=53.3s
# [45/90] CHIRP seed=100056 done | reason=completed | sim_time=60.00s | eta=42.7s
# [50/90] CHIRP seed=100061 done | reason=completed | sim_time=60.00s | eta=34.1s
# [55/90] CHIRP seed=100066 done | reason=completed | sim_time=60.00s | eta=27.2s
# [60/90] CHIRP seed=100071 done | reason=completed | sim_time=60.00s | eta=21.4s
# [scenario done] CHIRP | completed=30/30 | gt_div=0 | model_fail=0 | H=60.0s cond_n=30/30 | pos_med=0.9539 m | pos_p95=2.3086 m | rot_med=0.0177 rad | completion=1.000 | elapsed=42.7s
# [scenario 3/3] OU | 30 trajectories
# [61/90] OU seed=200042 done | reason=completed | sim_time=60.00s | eta=30.5s
# [65/90] OU seed=200046 done | reason=completed | sim_time=60.00s | eta=24.7s
# [70/90] OU seed=200051 done | reason=pred_divergence | sim_time=42.95s | eta=18.3s
# [75/90] OU seed=200056 done | reason=completed | sim_time=60.00s | eta=12.8s
# [80/90] OU seed=200061 done | reason=completed | sim_time=60.00s | eta=8.0s
# [85/90] OU seed=200066 done | reason=pred_divergence | sim_time=58.75s | eta=3.8s
# [90/90] OU seed=200071 done | reason=completed | sim_time=60.00s | eta=0.0s
# [scenario done] OU | completed=28/30 | gt_div=0 | model_fail=2 | H=60.0s cond_n=28/30 | pos_med=2.0465 m | pos_p95=5.3461 m | rot_med=0.0481 rad | completion=0.933 | elapsed=1m04.3s
# Benchmark finished in 1m23.5s
# Results written to /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260524_161414
# Rollout Benchmark Summary
# ================================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed46/best_model.pt
# Dataset: /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_5/data/auv_oc_traj1000_blk150_s23_d0be9434.pkl
# Model: Ablation: No Mass Prior [ablation/ablation]
# Canonical model type: ablate_no_mass_prior
# Energy semantics: mechanical_energy
# Device: cuda
# Mode: resampled
# Generation config source: checkpoint
# Scenarios: PRBS, CHIRP, OU
# Trajectories per scenario: 30
# Horizons: 10.0, 30.0, 60.0
#
# Overall
# --------------------------------------------------------------------------------
# Conditional error statistics use only trajectories that completed to the horizon.
# Primary KPIs are observable-space fields: position, depth, rotation, and total velocity.
# Model-space diagnostics use relative velocity; internal diagnostics cover energy and raw SO(3) quality.
# Per-column field grouping is exported in metric_contract.csv.
# H=10.0s | pos median=0.1734 m | pos p95=0.3565 m | rot median=0.0139 rad | total vel median=0.0141 m/s | rel vel median=0.0139 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=30.0s | pos median=0.5828 m | pos p95=1.6441 m | rot median=0.0200 rad | total vel median=0.0154 m/s | rel vel median=0.0137 m/s | cond_n=90/90 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
# H=60.0s | pos median=1.6172 m | pos p95=4.0879 m | rot median=0.0273 rad | total vel median=0.0163 m/s | rel vel median=0.0156 m/s | cond_n=88/90 | completion=0.978 | gt_fail_by_h=0.000 | model_fail_by_h=0.022
#
# Rollout Outcomes To Max Horizon
# --------------------------------------------------------------------------------
# n=90 | completed=88 (0.978) | gt_divergence=0 (0.000) | pred_divergence=2 (0.022) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#
# By Scenario
# --------------------------------------------------------------------------------
# PRBS
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1704 m | pos p95=0.3491 m | rot median=0.0114 rad | total vel median=0.0150 m/s | rel vel median=0.0157 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.7652 m | pos p95=1.4499 m | rot median=0.0220 rad | total vel median=0.0167 m/s | rel vel median=0.0157 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=1.8204 m | pos p95=3.2678 m | rot median=0.0245 rad | total vel median=0.0166 m/s | rel vel median=0.0172 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# CHIRP
#   n=30 | completed=30 (1.000) | gt_divergence=0 (0.000) | pred_divergence=0 (0.000) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1739 m | pos p95=0.2681 m | rot median=0.0138 rad | total vel median=0.0102 m/s | rel vel median=0.0095 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.4134 m | pos p95=1.0800 m | rot median=0.0153 rad | total vel median=0.0100 m/s | rel vel median=0.0094 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=0.9539 m | pos p95=2.3086 m | rot median=0.0177 rad | total vel median=0.0095 m/s | rel vel median=0.0123 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#
# OU
#   n=30 | completed=28 (0.933) | gt_divergence=0 (0.000) | pred_divergence=2 (0.067) | solver_failure=0 (0.000) | nan_or_inf=0 (0.000)
#   H=10.0s | pos median=0.1777 m | pos p95=0.3935 m | rot median=0.0160 rad | total vel median=0.0209 m/s | rel vel median=0.0196 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=30.0s | pos median=0.6886 m | pos p95=1.7936 m | rot median=0.0370 rad | total vel median=0.0211 m/s | rel vel median=0.0205 m/s | cond_n=30/30 | completion=1.000 | gt_fail_by_h=0.000 | model_fail_by_h=0.000
#   H=60.0s | pos median=2.0465 m | pos p95=5.3461 m | rot median=0.0481 rad | total vel median=0.0233 m/s | rel vel median=0.0192 m/s | cond_n=28/30 | completion=0.933 | gt_fail_by_h=0.000 | model_fail_by_h=0.067
#
# Diagnostic Cases To Max Horizon
# --------------------------------------------------------------------------------
# Earliest rollout failures
#   OU seed=200051 | reason=pred_divergence | sim_time=42.95s | pos=nan m | rot=nan rad | total_vel_violation=0
#   OU seed=200066 | reason=pred_divergence | sim_time=58.75s | pos=nan m | rot=nan rad | total_vel_violation=0
#
# Largest completed terminal errors
#   OU seed=200057 | reason=completed | sim_time=60.00s | pos=6.7076 m | rot=0.1671 rad | total_vel_violation=0
#   PRBS seed=63 | reason=completed | sim_time=60.00s | pos=6.2140 m | rot=0.0729 rad | total_vel_violation=0
#   OU seed=200052 | reason=completed | sim_time=60.00s | pos=5.5377 m | rot=0.0856 rad | total_vel_violation=0
#   OU seed=200062 | reason=completed | sim_time=60.00s | pos=4.9903 m | rot=0.1191 rad | total_vel_violation=0
#   OU seed=200065 | reason=completed | sim_time=60.00s | pos=4.2998 m | rot=0.0947 rad | total_vel_violation=0
#
# Completed rollouts with velocity violations
#   OU seed=200055 | reason=completed | sim_time=60.00s | pos=2.2562 m | rot=0.0683 rad | total_vel_violation=1
#   OU seed=200061 | reason=completed | sim_time=60.00s | pos=1.1550 m | rot=0.0425 rad | total_vel_violation=1
#
# Diagnostic Plot Files
# --------------------------------------------------------------------------------
# OU seed=200051 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260524_161414/diagnostic_plots/rollout_failure_OU_seed200051.png
# OU seed=200066 | label=rollout_failure | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260524_161414/diagnostic_plots/rollout_failure_OU_seed200066.png
# OU seed=200055 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260524_161414/diagnostic_plots/velocity_violation_OU_seed200055.png
# OU seed=200061 | label=velocity_violation | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260524_161414/diagnostic_plots/velocity_violation_OU_seed200061.png
# OU seed=200057 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260524_161414/diagnostic_plots/high_terminal_error_OU_seed200057.png
# PRBS seed=63 | label=high_terminal_error | /content/drive/MyDrive/Colab Notebooks/auvhamnode/g3_5_7/checkpoints/sweep_oc_phase1a_decision_v4lite_t2_wpfrag_ablate_no_mass_prior/ablation_ablate_no_mass_prior_seed46/rollout_benchmark/phase1a_v4eval_traj30_seed42_20260524_161414/diagnostic_plots/high_terminal_error_PRBS_seed63.png
# Batch evaluation complete.

# %% [markdown]
# ## 5. Provenance injection (per-run `_audit_meta/`)
# Records git HEAD + environment fingerprint into every decision run dir so these runs are distinguishable from catalog-era drift when the catalog is rebuilt.

# %%
# Inject per-run provenance. The training flow does NOT write these automatically,
# so for paper-grade evidence we record them here (see docs/provenance_audit_phnode_full_clean.md sec 5.2).
import os, sys, subprocess, datetime
from pathlib import Path
import torch

RUN_TAG = os.environ["RUN_TAG"]
ckpt = PROJECT_DIR / "checkpoints"
suites = [ckpt / f"sweep_oc_phase1a_decision_{p}_{RUN_TAG}" for p in ("clean", "iid", "v4lite")]

def _sh(args):
    try:
        return subprocess.run(args, cwd=PROJECT_DIR, capture_output=True, text=True).stdout.strip()
    except Exception as exc:  # noqa: BLE001
        return f"<unavailable: {exc}>"

head = _sh(["git", "rev-parse", "HEAD"])
diffstat = _sh(["git", "diff", "HEAD", "--stat"])
env_txt = "\n".join([
    f"python={sys.version.split()[0]}",
    f"torch={torch.__version__}",
    f"cuda={torch.version.cuda}",
    f"cudnn={torch.backends.cudnn.version()}",
    f"gpu={torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'cpu'}",
    f"captured_at={datetime.datetime.now().isoformat()}",
])

n = 0
for suite in suites:
    if not suite.exists():
        continue
    for cfg in suite.rglob("config.json"):
        run_dir = cfg.parent
        meta = run_dir / "_audit_meta"
        meta.mkdir(exist_ok=True)
        (meta / "code_revision.txt").write_text(f"git_head={head}\n\n{diffstat}\n")
        (meta / "environment.txt").write_text(env_txt + "\n")
        n += 1
print(f"provenance written for {n} run dirs")
print("git_head =", head)
# Out:
# provenance written for 15 run dirs
# git_head =

# %% [markdown]
# ## 6. Anomaly scan
# Flags any run with the `no successful training batches` catastrophic-gradient signature (the seed46 failure mode). A flagged seed must NOT be cited — rerun or annotate.

# %%
# Quick anomaly scan: catch seed46/seed43-style catastrophic training before trusting numbers.
# Flags any run whose training.log contains the "no successful training batches" failure mode.
import os, re
from pathlib import Path

RUN_TAG = os.environ["RUN_TAG"]
ckpt = PROJECT_DIR / "checkpoints"
suites = [ckpt / f"sweep_oc_phase1a_decision_{p}_{RUN_TAG}" for p in ("clean", "iid", "v4lite")]

print(f"{'suite':<48}{'run':<32}{'best_epoch':>10}{'best_loss':>14}{'nbad':>6}  flag")
for suite in suites:
    if not suite.exists():
        continue
    for cfg in sorted(suite.rglob("config.json")):
        run_dir = cfg.parent
        log = run_dir / "training.log"
        text = log.read_text() if log.exists() else ""
        nbad = text.count("no successful training batches")
        best_epoch, best_loss = "?", "?"
        m = re.findall(r"[Bb]est.*?epoch[^0-9]*([0-9]+).*?([0-9]+\.[0-9eE+-]+)", text)
        if m:
            best_epoch, best_loss = m[-1]
        flag = "  <-- CHECK (possible artifact)" if nbad > 0 else ""
        print(f"{suite.name[:46]:<48}{run_dir.name[:30]:<32}{str(best_epoch):>10}{str(best_loss):>14}{nbad:>6}{flag}")
print("\nIf any run is flagged, treat that seed like seed46/seed43: do NOT cite it; rerun or annotate.")
# Out:
# suite                                           run                             best_epoch     best_loss  nbad  flag
# sweep_oc_phase1a_decision_clean_t2_wpfrag_abla  ablation_ablate_no_mass_prior_           ?             ?     0
# sweep_oc_phase1a_decision_clean_t2_wpfrag_abla  ablation_ablate_no_mass_prior_           ?             ?     0
# sweep_oc_phase1a_decision_clean_t2_wpfrag_abla  ablation_ablate_no_mass_prior_           ?             ?     0
# sweep_oc_phase1a_decision_clean_t2_wpfrag_abla  ablation_ablate_no_mass_prior_           ?             ?     0
# sweep_oc_phase1a_decision_clean_t2_wpfrag_abla  ablation_ablate_no_mass_prior_           ?             ?     0
# sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate  ablation_ablate_no_mass_prior_           ?             ?     0
# sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate  ablation_ablate_no_mass_prior_           ?             ?     0
# sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate  ablation_ablate_no_mass_prior_           ?             ?     0
# sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate  ablation_ablate_no_mass_prior_           ?             ?     0
# sweep_oc_phase1a_decision_iid_t2_wpfrag_ablate  ablation_ablate_no_mass_prior_           ?             ?     0
# sweep_oc_phase1a_decision_v4lite_t2_wpfrag_abl  ablation_ablate_no_mass_prior_           ?             ?     0
# sweep_oc_phase1a_decision_v4lite_t2_wpfrag_abl  ablation_ablate_no_mass_prior_           ?             ?     0
# sweep_oc_phase1a_decision_v4lite_t2_wpfrag_abl  ablation_ablate_no_mass_prior_           ?             ?     0
# sweep_oc_phase1a_decision_v4lite_t2_wpfrag_abl  ablation_ablate_no_mass_prior_           ?             ?     0
# sweep_oc_phase1a_decision_v4lite_t2_wpfrag_abl  ablation_ablate_no_mass_prior_           ?             ?     0
#
# If any run is flagged, treat that seed like seed46/seed43: do NOT cite it; rerun or annotate.

# %% [markdown]
# ## 7. Next step (after all 4 notebooks finish)
# 1. Ensure `checkpoints/sweep_oc_phase1a_decision_{clean,iid,v4lite}_t2_wpfrag_*` are synced back to the repo.
# 2. Locally: `conda run -n mytorch1 python scripts/build_oc_data_catalog.py` to ingest the new runs.
# 3. Export the section-8 current-evidence tables from the rebuilt canonical views.
# 4. Re-verify the `ablate_no_lift` noisy-degradation claim is not driven by a seed44 artifact.
